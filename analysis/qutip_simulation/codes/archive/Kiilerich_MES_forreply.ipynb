# %%
import qutip as qt
from qutip import *
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## general solution for g(t)

# %%
from scipy.integrate import cumulative_trapezoid
from scipy.integrate import quad
from scipy.special import gamma, zeta, eval_hermite, factorial

# Define parameters
kappa = 2.5e-3*2*np.pi*2

# Define sech function
def sech(x):
    return 1 / np.cosh(x)

_kappa_cache = {}

def _N_m(m, kappa):
    numerator = 8 * (1 - 2**(1 - 2*m)) * gamma(2*m + 1) * zeta(2*m)
    denominator = kappa**(2*m + 1)
    return 1.0 / (numerator / denominator)

def _compute_Z_m(m, A_coeffs, kappa):
    Z = 0.0
    for k in range(m // 2 + 1):
        deg_k = m - 2 * k
        A_k = A_coeffs[deg_k]
        inner_sum = 0.0
        for l in range(m // 2 + 1):
            deg_l = m - 2 * l
            A_l = A_coeffs[deg_l]
            Nj_index = m - (k + l)
            Nj = _N_m(Nj_index, kappa)
            inner_sum += A_l / Nj
        Z += A_k * inner_sum
    return 1 / Z

def _get_A_m(m, kappa):
    if kappa not in _kappa_cache:
        _kappa_cache[kappa] = {
            "A_list": {0: [1.0]},
            "Z_dict": {0: kappa / 4},
        }

    A_list = _kappa_cache[kappa]["A_list"]
    Z_dict = _kappa_cache[kappa]["Z_dict"]

    if m in A_list:
        return A_list[m]

    A_m_coeffs = [0.0] * (m + 1)
    A_m_coeffs[m] = 1.0

    for i in range(1, m // 2 + 1):
        lower_m = m - 2 * i
        A_lower = _get_A_m(lower_m, kappa)

        inner_sum = 0.0
        for j in range(0, (m // 2 - i) + 1):
            index_in_A = m - 2 * (i + j)
            if 0 <= index_in_A < len(A_lower):
                A_coeff = A_lower[index_in_A]
                Nj = _N_m(m - (i + j), kappa)
                inner_sum += A_coeff / Nj

        Z = Z_dict.get(lower_m, 1.0)
        for power, coeff in enumerate(A_lower):
            if power < len(A_m_coeffs):
                A_m_coeffs[power] -= inner_sum * Z * coeff

    Z_m = _compute_Z_m(m, A_m_coeffs, kappa)
    Z_dict[m] = Z_m
    A_list[m] = A_m_coeffs
    return A_m_coeffs

def xi_m(t, m, kappa):
    A_coeffs = _get_A_m(m, kappa)
    Zm = _kappa_cache[kappa]["Z_dict"][m]
    A_val = sum(c * t**i for i, c in enumerate(A_coeffs))
    return np.sqrt(Zm) * sech(kappa * t / 2) * A_val

# %%
def f(t, m, kappa):
    return xi_m(t, m, kappa)

def f_prime(t, m, kappa, h=1e-3):
    return (f(t + h, m, kappa) - f(t - h, m, kappa)) / (2 * h)

def compute_g(t_vals, m, kappa, kappa_ph):
    f_vals = f(t_vals, m, kappa_ph)
    f_prime_vals = f_prime(t_vals, m, kappa_ph)
    

    f2_vals = np.abs(f_vals)**2
    integral_vals = cumulative_trapezoid(f2_vals, t_vals, initial=0)
    
    numerator = f_prime_vals + (kappa * f_vals / 2)
    denominator = np.sqrt(kappa * (1 - integral_vals) - f2_vals)
    
    return numerator / denominator

kappa =  0.14*2*np.pi
kappa_ph = 2.5e-3*2*np.pi*2
t_vals = np.linspace(-500, 500, 501)

plt.figure(figsize=(6, 4))
for m in range(4):
    g_vals = compute_g(t_vals, m, kappa, kappa_ph)
    plt.plot(t_vals, np.real(g_vals)/2/np.pi*1e3, label=fr" m={m}")

plt.xlabel("Time (ns)")
plt.ylabel("Amplitude (MHz)")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## QuTiP simulation

# %%
from process_tomography import *
from state_tomography import *
from libys import qtp as ysq
from datataking import search_datadict_miyamura
from qutip import fidelity, Qobj
from analysis import (
    SpatiotemporalAnalysis,demodulate
)

# %%
result_dict_tx = dict(
    data_ph0 = dict(target_freq=9.38, date="2025-08-12", acquire_time="124754", duration=1000),
    data_ph1 = dict(target_freq=9.38, date="2025-08-12", acquire_time="124137", duration=1000),
    data_ph2 = dict(target_freq=9.38, date="2025-08-12", acquire_time="124227", duration=1000),
    data_ph3 = dict(target_freq=9.38, date="2025-08-12", acquire_time="125025", duration=1000),
)
result_dict_rx = dict(
    data_ph0 = dict(target_freq=9.38, date="2025-08-12", acquire_time="110853", duration=1000),
    data_ph1 = dict(target_freq=9.38, date="2025-08-12", acquire_time="110223", duration=1000),
    data_ph2 = dict(target_freq=9.38, date="2025-08-12", acquire_time="110313", duration=1000),
    data_ph3 = dict(target_freq=9.38, date="2025-08-12", acquire_time="110403", duration=1000),
)

num_of_ph_amp = 1
num_of_fogi_timing = 51
f_if = (9.5-9.38)*1e9

header = "C:/Users/qipe/Documents/qutip_simulation/codes/data/CDK184/"
ph0_fo0 = "/2025-08-13/2025-08-13T081809_9c21d1b7-j1_JPA_comm_timing"
ph0_fo1 = "/2025-08-12/2025-08-12T145332_addb4dad-j1_JPA_comm_timing"
ph0_fo2 = "/2025-08-12/2025-08-12T223011_78afd813-j1_JPA_comm_timing"
ph0_fo3 = "/2025-08-12/2025-08-12T162316_371a7ee5-j1_JPA_comm_timing"
ph1_fo0 = "/2025-08-12/2025-08-12T205345_fff72f75-j1_JPA_comm_timing"
ph1_fo1 = "/2025-08-12/2025-08-12T214421_11bce74b-j1_JPA_comm_timing"
ph1_fo2 = "/2025-08-12/2025-08-12T183812_10814b2f-j1_JPA_comm_timing"
ph1_fo3 = "/2025-08-12/2025-08-12T192312_59d17cb7-j1_JPA_comm_timing"
ph2_fo0 = "/2025-08-12/2025-08-12T200813_a3f91ff0-j1_JPA_comm_timing"
ph2_fo1 = "/2025-08-13/2025-08-13T010923_b6800336-j1_JPA_comm_timing"
ph2_fo2 = "/2025-08-13/2025-08-13T015414_fa4288d4-j1_JPA_comm_timing"
ph2_fo3 = "/2025-08-13/2025-08-13T023907_3f311ad9-j1_JPA_comm_timing"
ph3_fo0 = "/2025-08-13/2025-08-13T032400_84bc5ae9-j1_JPA_comm_timing"
ph3_fo1 = "/2025-08-13/2025-08-13T040856_cb5ba4f9-j1_JPA_comm_timing"
ph3_fo2 = "/2025-08-13/2025-08-13T045352_12672ec9-j1_JPA_comm_timing"
ph3_fo3 = "/2025-08-13/2025-08-13T053850_5a9232a6-j1_JPA_comm_timing"

acquisition_00 = SpatiotemporalAnalysis(header, ph0_fo0, header, result_dict_tx['data_ph0'], result_dict_rx['data_ph0'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_01 = SpatiotemporalAnalysis(header, ph0_fo1, header, result_dict_tx['data_ph0'], result_dict_rx['data_ph1'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_02 = SpatiotemporalAnalysis(header, ph0_fo2, header, result_dict_tx['data_ph0'], result_dict_rx['data_ph2'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_03 = SpatiotemporalAnalysis(header, ph0_fo3, header, result_dict_tx['data_ph0'], result_dict_rx['data_ph3'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_10 = SpatiotemporalAnalysis(header, ph1_fo0, header, result_dict_tx['data_ph1'], result_dict_rx['data_ph0'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_11 = SpatiotemporalAnalysis(header, ph1_fo1, header, result_dict_tx['data_ph1'], result_dict_rx['data_ph1'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_12 = SpatiotemporalAnalysis(header, ph1_fo2, header, result_dict_tx['data_ph1'], result_dict_rx['data_ph2'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_13 = SpatiotemporalAnalysis(header, ph1_fo3, header, result_dict_tx['data_ph1'], result_dict_rx['data_ph3'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_20 = SpatiotemporalAnalysis(header, ph2_fo0, header, result_dict_tx['data_ph2'], result_dict_rx['data_ph0'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_21 = SpatiotemporalAnalysis(header, ph2_fo1, header, result_dict_tx['data_ph2'], result_dict_rx['data_ph1'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_22 = SpatiotemporalAnalysis(header, ph2_fo2, header, result_dict_tx['data_ph2'], result_dict_rx['data_ph2'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_23 = SpatiotemporalAnalysis(header, ph2_fo3, header, result_dict_tx['data_ph2'], result_dict_rx['data_ph3'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_30 = SpatiotemporalAnalysis(header, ph3_fo0, header, result_dict_tx['data_ph3'], result_dict_rx['data_ph0'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_31 = SpatiotemporalAnalysis(header, ph3_fo1, header, result_dict_tx['data_ph3'], result_dict_rx['data_ph1'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_32 = SpatiotemporalAnalysis(header, ph3_fo2, header, result_dict_tx['data_ph3'], result_dict_rx['data_ph2'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_33 = SpatiotemporalAnalysis(header, ph3_fo3, header, result_dict_tx['data_ph3'], result_dict_rx['data_ph3'], num_of_ph_amp, num_of_fogi_timing, f_if)

ph_amp = 0
fogi_freq = 17
fig, axs = plt.subplots(2, 2, figsize=(3.2, 2.2) , constrained_layout=True) 
acquisition_00.plot_waveform(ax=axs[0, 0], title="(0, 0)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=False, mode=0)
acquisition_01.plot_waveform(ax=axs[0, 1], title="(0, 1)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=False, mode=0)
acquisition_02.plot_waveform(ax=axs[1, 0], title="(0, 2)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=False, mode=0)
acquisition_03.plot_waveform(ax=axs[1, 1], title="(0, 3)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=False, mode=0)
fig.text(-0.02, 0.55, "Amplitude (arb. unit)", va="center", rotation="vertical")
for ax in axs[-1, :]:
    ax.set_xlabel("Time (ns)")
# plt.tight_layout()
plt.show()
# Out:
# c:\Users\qipe\Documents\qutip_simulation\.venv\Lib\site-packages\matplotlib\cbook.py:1762: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# c:\Users\qipe\Documents\qutip_simulation\.venv\Lib\site-packages\matplotlib\cbook.py:1398: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
acquisitions = [[None for _ in range(4)] for _ in range(4)]

acquisitions[0][0] = acquisition_00
acquisitions[0][1] = acquisition_01
acquisitions[0][2] = acquisition_02
acquisitions[0][3] = acquisition_03

acquisitions[1][0] = acquisition_10
acquisitions[1][1] = acquisition_11
acquisitions[1][2] = acquisition_12
acquisitions[1][3] = acquisition_13

acquisitions[2][0] = acquisition_20
acquisitions[2][1] = acquisition_21
acquisitions[2][2] = acquisition_22
acquisitions[2][3] = acquisition_23

acquisitions[3][0] = acquisition_30
acquisitions[3][1] = acquisition_31
acquisitions[3][2] = acquisition_32
acquisitions[3][3] = acquisition_33

# %% [markdown]
# ### photon emission

# %%
n_cutoff_q = 3
n_cutoff_r = 2
n_cutoff_vc = 3

b = qt.tensor(qt.destroy(n_cutoff_q), qt.qeye(n_cutoff_r), qt.qeye(n_cutoff_vc))
a = qt.tensor(qt.qeye(n_cutoff_q), qt.destroy(n_cutoff_r), qt.qeye(n_cutoff_vc))
vc = qt.tensor(qt.qeye(n_cutoff_q), qt.qeye(n_cutoff_r), qt.destroy(n_cutoff_vc))

zeromatrixxtmp=np.zeros([n_cutoff_q, n_cutoff_q])
zeromatrixxtmp[0,1]=1
gedecayop=Qobj(zeromatrixxtmp)
etog = qt.tensor(gedecayop, qt.qeye(n_cutoff_r), qt.qeye(n_cutoff_vc))
zeromatrixxtmp=np.zeros([n_cutoff_q, n_cutoff_q])
zeromatrixxtmp[1,2]=1
efdecayop=Qobj(zeromatrixxtmp)
ftoe = qt.tensor(efdecayop, qt.qeye(n_cutoff_r), qt.qeye(n_cutoff_vc))
zeromatrixxtmp=np.zeros([n_cutoff_q, n_cutoff_q])
zeromatrixxtmp[0,0]=-1
zeromatrixxtmp[1,1]=1
gedechoop=Qobj(zeromatrixxtmp)
dechoge = qt.tensor(gedechoop, qt.qeye(n_cutoff_r), qt.qeye(n_cutoff_vc))
zeromatrixxtmp=np.zeros([n_cutoff_q, n_cutoff_q])
zeromatrixxtmp[1,1]=-1
zeromatrixxtmp[2,2]=1
efdechoop=Qobj(zeromatrixxtmp)
dechoef = qt.tensor(efdechoop, qt.qeye(n_cutoff_r), qt.qeye(n_cutoff_vc))

g0 = qt.tensor(qt.basis(n_cutoff_q, 0), qt.basis(n_cutoff_r, 0), qt.basis(n_cutoff_vc, 0))
f0 = qt.tensor(qt.basis(n_cutoff_q, 2), qt.basis(n_cutoff_r, 0), qt.basis(n_cutoff_vc, 0))
g1 = qt.tensor(qt.basis(n_cutoff_q, 0), qt.basis(n_cutoff_r, 1), qt.basis(n_cutoff_vc, 0))
e0 = qt.tensor(qt.basis(n_cutoff_q, 1), qt.basis(n_cutoff_r, 0), qt.basis(n_cutoff_vc, 0))
vc1 = qt.tensor(qt.basis(n_cutoff_q, 0), qt.basis(n_cutoff_r, 0), qt.basis(n_cutoff_vc, 1))

alpha = -0.356 * 2 * np.pi
chi = -0.0076 * 2 * np.pi
eta = 0.67
kappa_r = 0.14 * 2 * np.pi
K = 0 * 2 * np.pi

H_fogi = (
    -alpha / 2 * b.dag()*b + alpha * b.dag()*b.dag()*b*b / 2
    +K * a.dag()*a.dag()*a*a / 2 + 2*chi*a.dag()*a*b.dag()*b
)

H_d = -a.dag()*b*b/np.sqrt(2)
H_c = 1j * (np.sqrt(kappa_r)/2) * vc.dag()*a

T1ge=29*1e3
T1ef=22*1e3
T2ge=5*1e3
T2ef=5*1e3
Tphige=1/((1/T2ge-1/T1ge/2)/2)
Tphief=1/((1/T2ef-1/T1ef/2)/2)

e_ops = []
options = qt.Options(atol=1e-9, rtol=1e-9, nsteps=1000, max_step=0.1, store_states=True)
# Out:
# c:\Users\qipe\Documents\qutip_simulation\.venv\Lib\site-packages\qutip\solver\options.py:16: FutureWarning: Dedicated options class are no longer needed, options should be passed as dict to solvers.
#   warnings.warn(

# %%
from scipy.integrate import cumulative_trapezoid
from scipy.interpolate import interp1d

T = 1000 
N = 1001
tgrid = np.linspace(-T, T, N)
dt = tgrid[1] - tgrid[0]
kappa_ph = 2.5e-3 * 2 * np.pi * 2

_eps = 1e-14

g_interps = []
g_interps_rvs = []

for m in range(8): 
    f_vals = f(tgrid, m, kappa_ph)
    f_prime_vals = f_prime(tgrid, m, kappa_ph) 
    f2_vals = np.abs(f_vals)**2
    integral_vals = cumulative_trapezoid(f2_vals, tgrid, initial=0)

    numerator = f_prime_vals + (kappa_r * f_vals / 2)
    denominator = np.sqrt(kappa_r * (1.0 - integral_vals) - f2_vals)
    g_vals = numerator / denominator
    g_interp = interp1d(tgrid, np.real(g_vals), kind='cubic', fill_value='extrapolate')
    g_interps.append(g_interp)

    g_interp_rvs = interp1d(tgrid, np.real(g_vals[::-1]), kind='cubic', fill_value='extrapolate') 
    g_interps_rvs.append(g_interp_rvs)
    
g_u_interps = []
for m in range(8):
    ut_vals = xi_m(tgrid, m, kappa_ph)
    cumint = cumulative_trapezoid(np.abs(ut_vals)**2, tgrid, initial=0)
    eps = 1e-14
    denom = np.sqrt(1.0 - cumint + eps)
    g_vals = np.conjugate(ut_vals) / denom
    g_interp = interp1d(tgrid, g_vals, kind='cubic', fill_value='extrapolate')
    g_u_interps.append(g_interp)

def g_u(t, args):
    m = int(args["input_num"])
    t_local = float(t)
    return float(args["g_u_interps"][m](t_local))

def g_u_conj(t, args):
    return np.conjugate(g_u(t, args))

def g_time(t, args):
    t_local = float(t) - float(args["center"])
    m = int(args["fogi_mode"])
    # access interpolant precomputed above (we'll pass lists via args)
    return float(args["g_interps"][m](t_local))

def g_time_conj(t, args):
    return np.conjugate(g_time(t, args))

def g_time_rvs(t, args):
    t_local = float(t) - float(args["center"])
    m = int(args["fogi_mode"])
    # access interpolant precomputed above (we'll pass lists via args)
    return float(args["g_interps_rvs"][m](t_local))

def g_time_conj_rvs(t, args):
    return np.conjugate(g_time_rvs(t, args))

# %%
base_args = {
    "center": 0.0,
    "fogi_mode": 2,
    "g_interps": g_interps,
    "g_interps_rvs": g_interps_rvs,
    "g_u_interps": g_u_interps,
    "input_num": 0,
    "input": 0,
}
results = {} 

for m in range(1):
    m=m+7
    args_m = base_args.copy()
    args_m["fogi_mode"] = m

    H_m = [
        H_fogi,
        [H_d, g_time], [H_d.dag(), g_time_conj],
    ]
    psi0_m = (g0 + f0).unit()


    def total_c_op(t, args):
        c_op = np.sqrt(kappa_r) * a
        return c_op

    c_ops_m = [
        total_c_op,
        np.sqrt(1/T1ge)*etog, np.sqrt(1/T1ef)*ftoe,
        np.sqrt(1/Tphige)*dechoge, np.sqrt(1/Tphief)*dechoef
    ]

    result_m = qt.mesolve(
        H_m, psi0_m, tgrid, c_ops_m, e_ops=e_ops,
        args=args_m, options=options, progress_bar=True
    )

    results[m] = result_m
    print(f"mode {m} finished")
# Extract states
# Out:
# 10.0%. Run time:   9.27s. Est. time left: 00:00:01:23
# 20.0%. Run time:   9.98s. Est. time left: 00:00:00:39
# 30.0%. Run time:  10.72s. Est. time left: 00:00:00:25
# 40.0%. Run time:  11.43s. Est. time left: 00:00:00:17
# 50.0%. Run time:  12.15s. Est. time left: 00:00:00:12
# 60.0%. Run time:  12.90s. Est. time left: 00:00:00:08
# 70.0%. Run time:  13.62s. Est. time left: 00:00:00:05
# 80.0%. Run time:  14.33s. Est. time left: 00:00:00:03
# 90.0%. Run time:  15.05s. Est. time left: 00:00:00:01
# 100.0%. Run time:  15.75s. Est. time left: 00:00:00:00
# Total run time:  15.75s
# mode 7 finished

# %%
fig, axes = plt.subplots(1, 4, figsize=(12, 2), sharey=True)
plt.subplots_adjust(wspace=0.4)

# Input operators
for i in range(2):
    states = results[7].states
    vcdvc_s = qt.expect(vc.dag() * vc, states)
    ada_s = qt.expect(a.dag() * a, states)
    vcda_s = qt.expect(vc.dag() * a, states)
    advc_s = qt.expect(a.dag() * vc, states)
    gu_values = np.array([g_u(t, base_args) for t in tgrid])
    LdL = (
        gu_values * np.conjugate(gu_values) * vcdvc_s
        + kappa_r * ada_s
        + np.sqrt(kappa_r) * (gu_values * vcda_s + np.conjugate(gu_values) * advc_s)
    )
    axes[i].plot(tgrid, np.sqrt(LdL), label="photon waveform")
    axes[i].set_title(f"m={i}")
    axes[i].set_xlabel(r"Time (ns)")
    if i == 0:
        axes[i].set_ylabel("Amplitude (arb. unit)")
plt.show()



dt = tgrid[1] - tgrid[0]
xi = np.abs(xi_m(tgrid, 9, kappa_ph) ) # shape=(len(tgrid),), 複素数
L_wave = np.sqrt(LdL)
norm = np.sqrt(np.sum(np.abs(L_wave)**2) * (tgrid[1]-tgrid[0]))  # dt をかける
L_wave_normalized = L_wave / norm
plt.plot(tgrid, xi)
plt.plot(tgrid, L_wave_normalized)

overlap = np.sum(np.conjugate(xi) * L_wave_normalized) * dt
overlap_abs2 = np.abs(overlap)**2

print(f"Overlap <xi_m | L>: {overlap}")
print(f"Overlap magnitude squared |<xi_m | L>|^2: {overlap_abs2}")
# Out:
# Overlap <xi_m | L>: (0.770949724226364+0j)
# Overlap magnitude squared |<xi_m | L>|^2: 0.5943634772847067

# %%
base_args = {
    "center": 0.0,
    "fogi_mode": 2,
    "g_interps": g_interps,
    "g_interps_rvs": g_interps_rvs,
    "g_u_interps": g_u_interps,
    "input_num": 0,
    "input": 0,
}
results = {} 

for m in range(1):
    m=m+7
    args_m = base_args.copy()
    args_m["fogi_mode"] = m

    H_m = [
        H_fogi,
        [H_d, g_time], [H_d.dag(), g_time_conj],
    ]
    psi0_m = (g0 + f0).unit()


    def total_c_op(t, args):
        c_op = np.sqrt(kappa_r) * a
        return c_op

    c_ops_m = [
        total_c_op,
        # np.sqrt(1/T1ge)*etog, np.sqrt(1/T1ef)*ftoe,
        # np.sqrt(1/Tphige)*dechoge, np.sqrt(1/Tphief)*dechoef
    ]

    result_m = qt.mesolve(
        H_m, psi0_m, tgrid, c_ops_m, e_ops=e_ops,
        args=args_m, options=options, progress_bar=True
    )

    results[m] = result_m
    print(f"mode {m} finished")
# Extract states
# Out:
# 10.0%. Run time:   0.54s. Est. time left: 00:00:00:04
# 20.0%. Run time:   1.09s. Est. time left: 00:00:00:04
# 30.0%. Run time:   1.79s. Est. time left: 00:00:00:04
# 40.0%. Run time:   2.35s. Est. time left: 00:00:00:03
# 50.0%. Run time:   2.89s. Est. time left: 00:00:00:02
# 60.0%. Run time:   3.43s. Est. time left: 00:00:00:02
# 70.0%. Run time:   3.98s. Est. time left: 00:00:00:01
# 80.0%. Run time:   4.51s. Est. time left: 00:00:00:01
# 90.0%. Run time:   5.05s. Est. time left: 00:00:00:00
# 100.0%. Run time:   5.60s. Est. time left: 00:00:00:00
# Total run time:   5.60s
# mode 7 finished

# %%
fig, axes = plt.subplots(1, 4, figsize=(12, 2), sharey=True)
plt.subplots_adjust(wspace=0.4)

# Input operators
for i in range(2):
    states = results[7].states
    vcdvc_s = qt.expect(vc.dag() * vc, states)
    ada_s = qt.expect(a.dag() * a, states)
    vcda_s = qt.expect(vc.dag() * a, states)
    advc_s = qt.expect(a.dag() * vc, states)
    gu_values = np.array([g_u(t, base_args) for t in tgrid])
    LdL1 = (
        gu_values * np.conjugate(gu_values) * vcdvc_s
        + kappa_r * ada_s
        + np.sqrt(kappa_r) * (gu_values * vcda_s + np.conjugate(gu_values) * advc_s)
    )
    axes[i].plot(tgrid, np.sqrt(LdL), label="photon waveform")
    axes[i].set_title(f"m={i}")
    axes[i].set_xlabel(r"Time (ns)")
    if i == 0:
        axes[i].set_ylabel("Amplitude (arb. unit)")
plt.show()


plt.plot(tgrid, np.sqrt(LdL))
plt.plot(tgrid, np.sqrt(LdL1))
overlap0 = np.sum(np.conjugate(np.sqrt(LdL1)) * np.sqrt(LdL1)) * dt
overlap0_abs2 = np.abs(overlap0)**2
overlap = np.sum(np.conjugate(np.sqrt(LdL)) * np.sqrt(LdL1)) * dt
overlap_abs2 = np.abs(overlap)**2

print(f"Overlap <xi_m | L>: {overlap}")
print(f"Overlap magnitude squared |<xi_m | L>|^2: {overlap_abs2}")
print(np.abs(overlap)/np.abs(overlap0))
# Out:
# Overlap <xi_m | L>: (0.4877762610324373+7.392373070766116e-13j)
# Overlap magnitude squared |<xi_m | L>|^2: 0.23792568082678442
# 0.9776218965577357

# %%
opts = Options(store_states=True, store_final_state=False, nsteps=10000, progress_bar=True)

options = qt.Options(atol=1e-9, rtol=1e-9, nsteps=1000, max_step=0.1, store_states=True)
base_args = {
    "center": 0.0,
    "fogi_mode": 2,
    "g_interps": g_interps,
    "g_interps_rvs": g_interps_rvs,
    "g_u_interps": g_u_interps,
    "input_num": 0,
    "input": 0,
}

args_m = base_args.copy()
args_m["fogi_mode"] = 0
H_m = [
    H_fogi,
    [H_d, g_time], [H_d.dag(), g_time_conj],
    ]
def total_c_op(t, args):
    c_op = np.sqrt(kappa_r) * a
    return c_op

def L_func(t, args):
    return np.sqrt(kappa_r) * a

def L_dag_func(t, args):
    return np.sqrt(kappa_r) * a.dag()

c_ops_m = [
    total_c_op,
    np.sqrt(1/T1ge)*etog, np.sqrt(1/T1ef)*ftoe,
    np.sqrt(1/Tphige)*dechoge, np.sqrt(1/Tphief)*dechoef
]
psi0_m = (g0 + f0).unit()
G1 = qt.correlation_2op_2t(
    H_m,     
    psi0_m,
    tgrid,
    tgrid,
    c_ops_m,
    L_dag_func,
    L_func,
    args=args_m,
    options=opts
)

plt.figure(figsize=(4,3))
plt.imshow(np.abs(G1), extent=[tgrid[0], tgrid[-1], tgrid[0], tgrid[-1]],
           origin="lower", aspect="auto")
plt.xlabel("t2 (ns)")
plt.ylabel("t1 (ns)")
plt.title(r"$|G^{(1)}(t_1,t_2)|$")
plt.colorbar(label="Amplitude")
plt.show()

# %% [markdown]
# ### photon absorption

# %%
base_args = {
    "center": 0.0,
    "fogi_mode": 0,
    "g_interps": g_interps,
    "g_interps_rvs": g_interps_rvs,
    "g_u_interps": g_u_interps,
    "input_num": 0,
    "input": 1,
}
results = {} 

for m in range(4):
    args_mn = base_args.copy()
    args_mn["input_num"] = m

    for n in range(4):
        args_mn["fogi_mode"] = n
        H_m = [
            H_fogi,
            [H_c, g_u], [H_c.dag(), g_u_conj],
            [H_d, g_time_rvs], [H_d.dag(), g_time_conj_rvs],
        ]
        psi0_m = vc1

        def total_c_op(t, args):
            c_op = np.conjugate(g_u(t, args)) * vc + np.sqrt(kappa_r) * a
            return c_op

        c_ops_mn = [
            total_c_op,
            np.sqrt(1/T1ge)*etog, np.sqrt(1/T1ef)*ftoe,
            np.sqrt(1/Tphige)*dechoge, np.sqrt(1/Tphief)*dechoef
        ]

        result_mn = qt.mesolve(
            H_m, psi0_m, tgrid, c_ops_mn, e_ops=e_ops,
            args=args_mn, options=options, progress_bar=True
        )

        results[(m, n)] = result_mn 
    print(f"mode {m} finished")
# Out:
# 10.0%. Run time:   0.58s. Est. time left: 00:00:00:05
# 20.0%. Run time:   1.05s. Est. time left: 00:00:00:04
# 30.0%. Run time:   1.62s. Est. time left: 00:00:00:03
# 40.0%. Run time:   2.07s. Est. time left: 00:00:00:03
# 50.0%. Run time:   2.54s. Est. time left: 00:00:00:02
# 60.0%. Run time:   3.00s. Est. time left: 00:00:00:01
# 70.0%. Run time:   3.50s. Est. time left: 00:00:00:01
# 80.0%. Run time:   3.98s. Est. time left: 00:00:00:00
# 90.0%. Run time:   4.65s. Est. time left: 00:00:00:00
# 100.0%. Run time:   5.42s. Est. time left: 00:00:00:00
# Total run time:   5.42s
# 10.0%. Run time:   0.48s. Est. time left: 00:00:00:04
# 20.0%. Run time:   1.10s. Est. time left: 00:00:00:04
# 30.0%. Run time:   1.61s. Est. time left: 00:00:00:03
# 40.0%. Run time:   2.17s. Est. time left: 00:00:00:03
# 50.0%. Run time:   2.67s. Est. time left: 00:00:00:02
# 60.0%. Run time:   3.41s. Est. time left: 00:00:00:02
# 70.0%. Run time:   4.06s. Est. time left: 00:00:00:01
# 80.0%. Run time:   4.61s. Est. time left: 00:00:00:01
# 90.0%. Run time:   5.19s. Est. time left: 00:00:00:00
# 100.0%. Run time:   5.76s. Est. time left: 00:00:00:00
# Total run time:   5.76s
# 10.0%. Run time:   0.68s. Est. time left: 00:00:00:06
# 20.0%. Run time:   1.73s. Est. time left: 00:00:00:06
# 30.0%. Run time:   2.46s. Est. time left: 00:00:00:05
# 40.0%. Run time:   3.20s. Est. time left: 00:00:00:04
# 50.0%. Run time:   3.77s. Est. time left: 00:00:00:03
# 60.0%. Run time:   4.31s. Est. time left: 00:00:00:02
# 70.0%. Run time:   4.78s. Est. time left: 00:00:00:02
# 80.0%. Run time:   5.24s. Est. time left: 00:00:00:01
# 90.0%. Run time:   5.68s. Est. time left: 00:00:00:00
# 100.0%. Run time:   6.12s. Est. time left: 00:00:00:00
# Total run time:   6.12s
# 10.0%. Run time:   0.47s. Est. time left: 00:00:00:04
# 20.0%. Run time:   0.91s. Est. time left: 00:00:00:03
# 30.0%. Run time:   1.34s. Est. time left: 00:00:00:03
# 40.0%. Run time:   1.78s. Est. time left: 00:00:00:02
# 50.0%. Run time:   2.24s. Est. time left: 00:00:00:02
# 60.0%. Run time:   2.69s. Est. time left: 00:00:00:01
# 70.0%. Run time:   3.32s. Est. time left: 00:00:00:01
# 80.0%. Run time:   3.77s. Est. time left: 00:00:00:00
# 90.0%. Run time:   4.28s. Est. time left: 00:00:00:00
# 100.0%. Run time:   4.79s. Est. time left: 00:00:00:00
# Total run time:   4.79s
# mode 0 finished
# 10.0%. Run time:   0.55s. Est. time left: 00:00:00:04
# 20.0%. Run time:   0.98s. Est. time left: 00:00:00:03
# 30.0%. Run time:   1.44s. Est. time left: 00:00:00:03
# 40.0%. Run time:   1.92s. Est. time left: 00:00:00:02
# 50.0%. Run time:   2.35s. Est. time left: 00:00:00:02
# 60.0%. Run time:   2.81s. Est. time left: 00:00:00:01
# 70.0%. Run time:   3.26s. Est. time left: 00:00:00:01
# 80.0%. Run time:   3.74s. Est. time left: 00:00:00:00
# 90.0%. Run time:   4.24s. Est. time left: 00:00:00:00
# 100.0%. Run time:   4.79s. Est. time left: 00:00:00:00
# Total run time:   4.79s
# 10.0%. Run time:   0.79s. Est. time left: 00:00:00:07
# 20.0%. Run time:   1.32s. Est. time left: 00:00:00:05
# 30.0%. Run time:   2.11s. Est. time left: 00:00:00:04
# 40.0%. Run time:   2.58s. Est. time left: 00:00:00:03
# 50.0%. Run time:   3.08s. Est. time left: 00:00:00:03
# 60.0%. Run time:   5.12s. Est. time left: 00:00:00:03
# 70.0%. Run time:   5.96s. Est. time left: 00:00:00:02
# 80.0%. Run time:   6.43s. Est. time left: 00:00:00:01
# 90.0%. Run time:   7.00s. Est. time left: 00:00:00:00
# 100.0%. Run time:   7.47s. Est. time left: 00:00:00:00
# Total run time:   7.48s
# 10.0%. Run time:   2.67s. Est. time left: 00:00:00:24
# 20.0%. Run time:   4.90s. Est. time left: 00:00:00:19
# 30.0%. Run time:   5.61s. Est. time left: 00:00:00:13
# 40.0%. Run time:   6.27s. Est. time left: 00:00:00:09
# 50.0%. Run time:   6.94s. Est. time left: 00:00:00:06
# 60.0%. Run time:   7.52s. Est. time left: 00:00:00:05
# 70.0%. Run time:   8.06s. Est. time left: 00:00:00:03
# 80.0%. Run time:   8.53s. Est. time left: 00:00:00:02
# 90.0%. Run time:   9.35s. Est. time left: 00:00:00:01
# 100.0%. Run time:   9.94s. Est. time left: 00:00:00:00
# Total run time:   9.95s
# 10.0%. Run time:   0.49s. Est. time left: 00:00:00:04
# 20.0%. Run time:   0.99s. Est. time left: 00:00:00:03
# 30.0%. Run time:   1.56s. Est. time left: 00:00:00:03
# 40.0%. Run time:   2.14s. Est. time left: 00:00:00:03
# 50.0%. Run time:   4.32s. Est. time left: 00:00:00:04
# 60.0%. Run time:   5.24s. Est. time left: 00:00:00:03
# 70.0%. Run time:   5.80s. Est. time left: 00:00:00:02
# 80.0%. Run time:   6.95s. Est. time left: 00:00:00:01
# 90.0%. Run time:   8.83s. Est. time left: 00:00:00:00
# 100.0%. Run time:   9.37s. Est. time left: 00:00:00:00
# Total run time:   9.37s
# mode 1 finished
# 10.0%. Run time:   0.47s. Est. time left: 00:00:00:04
# 20.0%. Run time:   1.00s. Est. time left: 00:00:00:03
# 30.0%. Run time:   2.80s. Est. time left: 00:00:00:06
# 40.0%. Run time:   4.97s. Est. time left: 00:00:00:07
# 50.0%. Run time:   7.02s. Est. time left: 00:00:00:07
# 60.0%. Run time:   8.91s. Est. time left: 00:00:00:05
# 70.0%. Run time:   9.63s. Est. time left: 00:00:00:04
# 80.0%. Run time:  10.37s. Est. time left: 00:00:00:02
# 90.0%. Run time:  10.93s. Est. time left: 00:00:00:01
# 100.0%. Run time:  11.41s. Est. time left: 00:00:00:00
# Total run time:  11.41s
# 10.0%. Run time:   0.62s. Est. time left: 00:00:00:05
# 20.0%. Run time:   1.19s. Est. time left: 00:00:00:04
# 30.0%. Run time:   1.83s. Est. time left: 00:00:00:04
# 40.0%. Run time:   2.65s. Est. time left: 00:00:00:03
# 50.0%. Run time:   3.47s. Est. time left: 00:00:00:03
# 60.0%. Run time:   4.04s. Est. time left: 00:00:00:02
# 70.0%. Run time:   4.52s. Est. time left: 00:00:00:01
# 80.0%. Run time:   5.15s. Est. time left: 00:00:00:01
# 90.0%. Run time:   5.76s. Est. time left: 00:00:00:00
# 100.0%. Run time:   6.39s. Est. time left: 00:00:00:00
# Total run time:   6.39s
# 10.0%. Run time:   0.72s. Est. time left: 00:00:00:06
# 20.0%. Run time:   1.39s. Est. time left: 00:00:00:05
# 30.0%. Run time:   2.33s. Est. time left: 00:00:00:05
# 40.0%. Run time:   3.23s. Est. time left: 00:00:00:04
# 50.0%. Run time:   3.78s. Est. time left: 00:00:00:03
# 60.0%. Run time:   4.26s. Est. time left: 00:00:00:02
# 70.0%. Run time:   4.71s. Est. time left: 00:00:00:02
# 80.0%. Run time:   5.18s. Est. time left: 00:00:00:01
# 90.0%. Run time:   5.66s. Est. time left: 00:00:00:00
# 100.0%. Run time:   6.15s. Est. time left: 00:00:00:00
# Total run time:   6.15s
# 10.0%. Run time:   1.39s. Est. time left: 00:00:00:12
# 20.0%. Run time:   2.76s. Est. time left: 00:00:00:11
# 30.0%. Run time:   3.20s. Est. time left: 00:00:00:07
# 40.0%. Run time:   3.76s. Est. time left: 00:00:00:05
# 50.0%. Run time:   4.21s. Est. time left: 00:00:00:04
# 60.0%. Run time:   4.64s. Est. time left: 00:00:00:03
# 70.0%. Run time:   5.11s. Est. time left: 00:00:00:02
# 80.0%. Run time:   5.62s. Est. time left: 00:00:00:01
# 90.0%. Run time:   6.17s. Est. time left: 00:00:00:00
# 100.0%. Run time:   6.65s. Est. time left: 00:00:00:00
# Total run time:   6.65s
# mode 2 finished
# 10.0%. Run time:   0.60s. Est. time left: 00:00:00:05
# 20.0%. Run time:   1.06s. Est. time left: 00:00:00:04
# 30.0%. Run time:   1.53s. Est. time left: 00:00:00:03
# 40.0%. Run time:   2.05s. Est. time left: 00:00:00:03
# 50.0%. Run time:   2.52s. Est. time left: 00:00:00:02
# 60.0%. Run time:   3.02s. Est. time left: 00:00:00:02
# 70.0%. Run time:   3.48s. Est. time left: 00:00:00:01
# 80.0%. Run time:   4.28s. Est. time left: 00:00:00:01
# 90.0%. Run time:   4.73s. Est. time left: 00:00:00:00
# 100.0%. Run time:   5.57s. Est. time left: 00:00:00:00
# Total run time:   5.57s
# 10.0%. Run time:   1.84s. Est. time left: 00:00:00:16
# 20.0%. Run time:   2.30s. Est. time left: 00:00:00:09
# 30.0%. Run time:   2.73s. Est. time left: 00:00:00:06
# 40.0%. Run time:   3.21s. Est. time left: 00:00:00:04
# 50.0%. Run time:   3.67s. Est. time left: 00:00:00:03
# 60.0%. Run time:   4.12s. Est. time left: 00:00:00:02
# 70.0%. Run time:   4.56s. Est. time left: 00:00:00:01
# 80.0%. Run time:   5.00s. Est. time left: 00:00:00:01
# 90.0%. Run time:   5.48s. Est. time left: 00:00:00:00
# 100.0%. Run time:   5.91s. Est. time left: 00:00:00:00
# Total run time:   5.91s
# 10.0%. Run time:   0.48s. Est. time left: 00:00:00:04
# 20.0%. Run time:   0.92s. Est. time left: 00:00:00:03
# 30.0%. Run time:   1.36s. Est. time left: 00:00:00:03
# 40.0%. Run time:   1.82s. Est. time left: 00:00:00:02
# 50.0%. Run time:   2.27s. Est. time left: 00:00:00:02
# 60.0%. Run time:   2.72s. Est. time left: 00:00:00:01
# 70.0%. Run time:   3.26s. Est. time left: 00:00:00:01
# 80.0%. Run time:   3.74s. Est. time left: 00:00:00:00
# 90.0%. Run time:   4.40s. Est. time left: 00:00:00:00
# 100.0%. Run time:   4.86s. Est. time left: 00:00:00:00
# Total run time:   4.86s
# 10.0%. Run time:   0.47s. Est. time left: 00:00:00:04
# 20.0%. Run time:   0.95s. Est. time left: 00:00:00:03
# 30.0%. Run time:   1.68s. Est. time left: 00:00:00:03
# 40.0%. Run time:   2.81s. Est. time left: 00:00:00:04
# 50.0%. Run time:   3.32s. Est. time left: 00:00:00:03
# 60.0%. Run time:   3.86s. Est. time left: 00:00:00:02
# 70.0%. Run time:   4.39s. Est. time left: 00:00:00:01
# 80.0%. Run time:   4.87s. Est. time left: 00:00:00:01
# 90.0%. Run time:   5.42s. Est. time left: 00:00:00:00
# 100.0%. Run time:   5.94s. Est. time left: 00:00:00:00
# Total run time:   5.94s
# mode 3 finished

# %%
from scipy import interpolate, optimize
from scipy.ndimage import shift as nd_shift

def fit_waveform(time, waveform_exp, waveform_sim, x0=[1.0, 0.0]):

    def func(params):
        scale, shift = params
        sim_shifted = roll_with_interpolation(waveform_sim, shift=-shift)
        return scale * sim_shifted

    def cost_func(params):
        return np.linalg.norm(np.abs(func(params)) - np.abs(waveform_exp))

    best_x = optimize.minimize(cost_func, x0, method='Nelder-Mead').x
    print("best_x:", best_x)

    fitted = func(best_x)
    return fitted, best_x

def roll_with_interpolation(array, shift):
    return nd_shift(array, shift=shift, mode='constant', cval=0.0)

for m in range(4):    
    fig, axes = plt.subplots(1, 4, figsize=(8, 2), sharey=True)
    plt.subplots_adjust(wspace=0.4)

    for n in range(4):
        states = results[(m, n)].states
        vcdvc_s = qt.expect(vc.dag() * vc, states)
        ada_s = qt.expect(a.dag() * a, states)
        vcda_s = qt.expect(vc.dag() * a, states)
        advc_s = qt.expect(a.dag() * vc, states)
        args = {
            "center": 0.0,
            "fogi_mode": n,
            "g_interps": g_interps,
            "g_interps_rvs": g_interps_rvs,
            "g_u_interps": g_u_interps,
            "input_num": m,
            "input": 0,
        }  

        gu_values = np.array([g_u(t, args) for t in tgrid])
        LdL = (
            gu_values * np.conjugate(gu_values) * vcdvc_s
            + kappa_r * ada_s
            + np.sqrt(kappa_r) * (gu_values * vcda_s + np.conjugate(gu_values) * advc_s)
        )
        abs_exp = acquisitions[m][n].get_results()["y_absorbed_signals"][ph_amp][fogi_freq][100:-149]
        fitted_dummy, best_x = fit_waveform(tgrid, np.abs(abs_exp), np.sqrt(LdL), x0=[1.0, 10.0])
        scale, shift_val = best_x
        def apply_fit(waveform, scale, shift_val, time):
            waveform_resampled = np.interp(time, np.linspace(time[0], time[-1], len(waveform)), waveform)
            dt = time[1] - time[0]
            shift_idx = -shift_val / dt 
            return scale * nd_shift(waveform_resampled, shift=shift_idx, mode='constant', cval=0.0)
        
        fitted_abs_sim = apply_fit(np.sqrt(LdL), scale, shift_val, tgrid)
            
        axes[n].plot(tgrid, np.abs(abs_exp)*1e3, lw=4, alpha=0.6, color="tab:blue", label="exp")
        axes[n].plot(tgrid, np.abs(fitted_abs_sim)*1e3, lw=2, alpha=0.8, linestyle="--", color="tab:red", label="sim")
        
        axes[n].set_xlabel(r"Time (ns)")
        if n == 0:
            axes[n].legend()
            axes[n].set_ylabel("Amplitude (arb. unit)")
            axes[n].set_title(f"(m, n)=({m}, {n})")
        else:
            axes[n].set_title(f"({m}, {n})")
    plt.tight_layout()
    plt.show()
# Out:
# best_x: [-1.04793524e-02  2.96508546e+01]
# best_x: [-8.23184251e-03 -1.20690931e+01]
# best_x: [-8.17831507e-03 -1.05850221e+01]
# best_x: [-7.56949359e-03 -1.31079291e+01]
# best_x: [-7.67172577e-03 -8.83371050e+00]
# best_x: [-1.81226385e-02 -5.69999800e+01]
# best_x: [-8.15799047e-03 -1.23711772e+01]
# best_x: [-7.99312202e-03 -1.15796495e+01]
# best_x: [ 7.32124835e-03 -1.37333152e+01]
# best_x: [-8.58013353e-03 -1.33171422e+01]
# best_x: [ 0.00791474 -2.05449696]
# best_x: [-7.7331396e-03 -1.1728183e+01]
# best_x: [ 8.58221928e-03 -1.40386476e+01]
# best_x: [ 7.74861125e-03 -1.31104215e+01]
# best_x: [ 8.25253904e-03 -1.50606160e+01]
# best_x: [-1.30686721e-02 -1.40000385e+01]

# %%
for m in range(4):    
    fig, axes = plt.subplots(1, 4, figsize=(8, 2), sharey=True)
    plt.subplots_adjust(wspace=0.4)

    for n in range(4):
        states = results[(m, n)].states
        vcdvc_s = qt.expect(vc.dag() * vc, states)
        ada_s = qt.expect(a.dag() * a, states)
        vcda_s = qt.expect(vc.dag() * a, states)
        advc_s = qt.expect(a.dag() * vc, states)
        args = {
            "center": 0.0,
            "fogi_mode": n,
            "g_interps": g_interps,
            "g_interps_rvs": g_interps_rvs,
            "g_u_interps": g_u_interps,
            "input_num": m,
            "input": 0,
        }  
        Nt = len(tgrid)
        G1_matrix = np.zeros((Nt, Nt), dtype=complex)

        for i, t1 in enumerate(tgrid):
            for j, t2 in enumerate(tgrid):
                gu_t1 = g_u(t1, args)
                gu_t2 = g_u(t2, args)

                G1_matrix[i, j] = (
                    np.conjugate(gu_t1) * gu_t2 * vcdvc_s[j]  # vcdvc_s[j] = ⟨vc† vc⟩_t2
                    + kappa_r * ada_s[j]                        # ⟨a† a⟩_t2
                    + np.sqrt(kappa_r) * (gu_t2 * vcda_s[j] + np.conjugate(gu_t1) * advc_s[j])
                )
        diag_check = np.all(np.real(np.diag(G1_matrix)) >= 0)
        herm_check = np.allclose(G1_matrix, G1_matrix.conj().T)
        eigs = np.linalg.eigvalsh(G1_matrix)
        print(f"(m,n)=({m},{n}): diag>0? {diag_check}, hermitian? {herm_check}, min eig={eigs.min():.3e}")
        im = axes[n].imshow(np.abs(G1_matrix), extent=[tgrid[0], tgrid[-1], tgrid[0], tgrid[-1]],
                            origin="lower", aspect="auto")
        axes[n].set_title(f"(m, n)=({m}, {n})")
        axes[n].set_xlabel("t2 (ns)")
        if n == 0:
            axes[n].set_ylabel("t1 (ns)")
    cbar = fig.colorbar(im, ax=axes, orientation='vertical', fraction=0.05, pad=0.05)
    cbar.set_label("Amplitude")
    plt.show()
# Out:
# (m,n)=(0,0): diag>0? True, hermitian? False, min eig=-2.323e-03
# (m,n)=(0,1): diag>0? True, hermitian? False, min eig=-5.521e-01
# (m,n)=(0,2): diag>0? True, hermitian? False, min eig=-3.603e-01
# (m,n)=(0,3): diag>0? True, hermitian? False, min eig=-4.450e-01
# (m,n)=(1,0): diag>0? True, hermitian? False, min eig=-4.164e-01
# (m,n)=(1,1): diag>0? True, hermitian? False, min eig=-1.270e-02
# (m,n)=(1,2): diag>0? True, hermitian? False, min eig=-1.100e+00
# (m,n)=(1,3): diag>0? True, hermitian? False, min eig=-1.619e+00
# (m,n)=(2,0): diag>0? True, hermitian? False, min eig=-1.029e+00
# (m,n)=(2,1): diag>0? True, hermitian? False, min eig=-8.400e-01
# (m,n)=(2,2): diag>0? True, hermitian? False, min eig=-3.667e-02
# (m,n)=(2,3): diag>0? True, hermitian? False, min eig=-6.380e-01
# (m,n)=(3,0): diag>0? True, hermitian? False, min eig=-6.439e-01
# (m,n)=(3,1): diag>0? True, hermitian? False, min eig=-4.994e-01
# (m,n)=(3,2): diag>0? True, hermitian? False, min eig=-5.637e-01
# (m,n)=(3,3): diag>0? True, hermitian? False, min eig=-1.213e-01

# %%
base_args = {
    "center": 0.0,
    "fogi_mode": 0,
    "g_interps": g_interps,
    "g_interps_rvs": g_interps_rvs,
    "g_u_interps": g_u_interps,
    "input_num": 0,
    "input": 1,
}

args_mn = base_args.copy()
args_mn["input_num"] = 0

args_mn["fogi_mode"] = 3
H_m = [
    H_fogi,
    [H_c, g_u], [H_c.dag(), g_u_conj],
    [H_d, g_time_rvs], [H_d.dag(), g_time_conj_rvs],
]
psi0_m = vc1

G1 = qt.correlation_2op_2t(
    H_m,     
    psi0_m,
    tgrid,
    tgrid,
    c_ops_mn,
    a,
    a.dag(),
    args=args_mn
)

plt.figure(figsize=(4,3))
plt.imshow(np.abs(G1), extent=[tgrid[0], tgrid[-1], tgrid[0], tgrid[-1]],
           origin="lower", aspect="auto")
plt.xlabel("t2 (ns)")
plt.ylabel("t1 (ns)")
plt.title(r"$|G^{(1)}(t_1,t_2)|$")
plt.colorbar(label="Amplitude")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[71], line 22
#      15 H_m = [
#      16     H_fogi,
#      17     [H_c, g_u], [H_c.dag(), g_u_conj],
#      18     [H_d, g_time_rvs], [H_d.dag(), g_time_conj_rvs],
#      19 ]
#      20 psi0_m = vc1
# ---> 22 G1 = qt.correlation_2op_2t(
#      23     H_m,
#      24     psi0_m,
#      25     tgrid,
#      26     tgrid,
#      27     c_ops_mn,
#      28     a,
#      29     a.dag(),
#      30     args=args_mn
#      31 )
#      33 plt.figure(figsize=(4,3))
#      34 plt.imshow(np.abs(G1), extent=[tgrid[0], tgrid[-1], tgrid[0], tgrid[-1]],
#      35            origin="lower", aspect="auto")
#
# File c:\Users\qipe\Documents\qutip_simulation\.venv\Lib\site-packages\qutip\solver\correlation.py:163, in correlation_2op_2t(H, state0, tlist, taulist, c_ops, a_op, b_op, solver, reverse, args, options)
#     160 else:
#     161     A_op, B_op, C_op = 1, a_op, b_op
# --> 163 return correlation_3op(solver, state0, tlist, taulist, A_op, B_op, C_op)
#
# File c:\Users\qipe\Documents\qutip_simulation\.venv\Lib\site-packages\qutip\solver\correlation.py:483, in correlation_3op(solver, state0, tlist, taulist, A, B, C)
#     480 C = QobjEvo(qeye_like(state0) if C in [None, 1] else C)
#     482 if isinstance(solver, (MESolver, BRSolver)):
# --> 483     out = _correlation_3op_dm(solver, state0, tlist, taulist, A, B, C)
#     484 elif isinstance(solver, MCSolver):
#     485     raise TypeError("Monte Carlo support for correlation was removed. "
#     486                     "Please, tell us on GitHub issues if you need it!")
#
# File c:\Users\qipe\Documents\qutip_simulation\.venv\Lib\site-packages\qutip\solver\correlation.py:514, in _correlation_3op_dm(solver, state0, tlist, taulist, A, B, C)
#     512 for t_idx, rho in enumerate(rho_t):
#     513     t = tlist[t_idx]
# --> 514     corr_mat[t_idx, :] = solver.run(
#     515         C(t) @ rho @ A(t),
#     516         taulist + t,
#     517         e_ops=B
#     518     ).expect[0]
#     519     progress_bar.update()
#     520 progress_bar.finished()
#
# File c:\Users\qipe\Documents\qutip_simulation\.venv\Lib\site-packages\qutip\solver\solver_base.py:184, in Solver.run(self, state0, tlist, args, e_ops)
#     179 stats['preparation time'] += time() - _time_start
#     181 progress_bar = progress_bars[self.options['progress_bar']](
#     182     len(tlist)-1, **self.options['progress_kwargs']
#     183 )
# --> 184 for t, state in self._integrator.run(tlist):
#     185     progress_bar.update()
#     186     results.add(t, self._restore_state(state, copy=False))
#
# File c:\Users\qipe\Documents\qutip_simulation\.venv\Lib\site-packages\qutip\solver\integrator\integrator.py:201, in Integrator.run(self, tlist)
#     187 """
#     188 Integrate the system yielding the state for each times in tlist.
#     189
#    (...)
#     198     The state of the solver at each ``t`` of tlist.
#     199 """
#     200 for t in tlist[1:]:
# --> 201     yield self.integrate(t, False)
#
# File c:\Users\qipe\Documents\qutip_simulation\.venv\Lib\site-packages\qutip\solver\integrator\scipy_integrator.py:110, in IntegratorScipyAdams.integrate(self, t, copy)
#     108 self._check_handle()
#     109 if t != self._ode_solver.t:
# --> 110     self._ode_solver.integrate(t)
#     111 return self.get_state(copy)
#
# File c:\Users\qipe\Documents\qutip_simulation\.venv\Lib\site-packages\scipy\integrate\_ode.py:431, in ode.integrate(self, t, step, relax)
#     428     mth = self._integrator.run
#     430 try:
# --> 431     self._y, self.t = mth(self.f, self.jac or (lambda: None),
#     432                           self._y, self.t, t,
#     433                           self.f_params, self.jac_params)
#     434 except SystemError as e:
#     435     # f2py issue with tuple returns, see ticket 1187.
#     436     raise ValueError(
#     437         'Function to integrate must not return a tuple.'
#     438     ) from e
#
# File c:\Users\qipe\Documents\qutip_simulation\.venv\Lib\site-packages\scipy\integrate\_ode.py:1008, in vode.run(self, f, jac, y0, t0, t1, f_params, jac_params)
#    1004     jac = _vode_banded_jac_wrapper(jac, self.ml, jac_params)
#    1006 args = ((f, jac, y0, t0, t1) + tuple(self.call_args) +
#    1007         (f_params, jac_params))
# -> 1008 y1, t, istate = self.runner(*args)
#    1009 self.istate = istate
#    1010 if istate < 0:
#
# File c:\Users\qipe\Documents\qutip_simulation\.venv\Lib\site-packages\qutip\solver\integrator\scipy_integrator.py:69, in IntegratorScipyAdams._mul_np_vec(self, t, vec)
#      67 state = _data.dense.fast_from_numpy(vec)
#      68 column_unstack_dense(state, self._size, inplace=True)
# ---> 69 out = self.system.matmul_data(t, state)
#      70 column_stack_dense(out, inplace=True)
#      71 return out.as_ndarray().ravel()
#
# File c:\Users\qipe\Documents\qutip_simulation\.venv\Lib\site-packages\qutip\core\cy\qobjevo.pyx:1105, in qutip.core.cy.qobjevo.QobjEvo.matmul_data()
#
# File c:\Users\qipe\Documents\qutip_simulation\.venv\Lib\site-packages\qutip\core\cy\qobjevo.pyx:1117, in qutip.core.cy.qobjevo.QobjEvo.matmul_data()
#
# File c:\Users\qipe\Documents\qutip_simulation\.venv\Lib\site-packages\qutip\core\cy\_element.pyx:167, in qutip.core.cy._element._BaseElement.matmul_data_t()
#
# File c:\Users\qipe\Documents\qutip_simulation\.venv\Lib\site-packages\qutip\core\cy\_element.pyx:367, in qutip.core.cy._element._EvoElement.coeff()
#
# File c:\Users\qipe\Documents\qutip_simulation\.venv\Lib\site-packages\qutip\core\cy\coefficient.pyx:220, in qutip.core.cy.coefficient.FunctionCoefficient.__call__()
#
# Cell In[29], line 63, in g_time_conj_rvs(t, args)
#      60     # access interpolant precomputed above (we'll pass lists via args)
#      61     return float(args["g_interps_rvs"][m](t_local))
# ---> 63 def g_time_conj_rvs(t, args):
#      64     return np.conjugate(g_time_rvs(t, args))
#
# KeyboardInterrupt:

# %%
fig, axs = plt.subplots(2, 2, figsize=(3.2, 2.) , constrained_layout=True, sharex=True,sharey=True) 

abs_exps = []
fitted_abs_sims = []
for m in range(4):    

    n=3
    states = results[(m, n)].states
    vcdvc_s = qt.expect(vc.dag() * vc, states)
    ada_s = qt.expect(a.dag() * a, states)
    vcda_s = qt.expect(vc.dag() * a, states)
    advc_s = qt.expect(a.dag() * vc, states)
    args = {
        "center": 0.0,
        "fogi_mode": n,
        "g_interps": g_interps,
        "g_interps_rvs": g_interps_rvs,
        "g_u_interps": g_u_interps,
        "input_num": m,
        "input": 0,
    }  

    gu_values = np.array([g_u(t, args) for t in tgrid])
    LdL = (
        gu_values * np.conjugate(gu_values) * vcdvc_s
        + kappa_r * ada_s
        + np.sqrt(kappa_r) * (gu_values * vcda_s + np.conjugate(gu_values) * advc_s)
    )
    abs_exp = acquisitions[m][n].get_results()["y_absorbed_signals"][ph_amp][fogi_freq][100:-149]
    fitted_dummy, best_x = fit_waveform(tgrid, np.abs(abs_exp), np.sqrt(LdL), x0=[1.0, 10.0])
    scale, shift_val = best_x
    def apply_fit(waveform, scale, shift_val, time):
        waveform_resampled = np.interp(time, np.linspace(time[0], time[-1], len(waveform)), waveform)
        dt = time[1] - time[0]
        shift_idx = -shift_val / dt 
        return scale * nd_shift(waveform_resampled, shift=shift_idx, mode='constant', cval=0.0)
    
    fitted_abs_sim = apply_fit(np.sqrt(LdL), scale, shift_val, tgrid)
    abs_exps.append(abs_exp)
    fitted_abs_sims.append(fitted_abs_sim)
    
norm = np.max(np.abs(fitted_abs_sims[0]))
axs[0][0].plot(tgrid+500, np.abs(abs_exps[0])/norm, lw=2.5, alpha=0.4, color="tab:blue", label="exp")
axs[0][0].plot(tgrid+500, np.abs(fitted_abs_sims[0])/norm, lw=1.5, alpha=1, linestyle="--", color="tab:blue", label="sim")
axs[0][1].plot(tgrid+500, np.abs(abs_exps[1])/norm,  lw=2.5, alpha=0.4, color="tab:orange", label="exp")
axs[0][1].plot(tgrid+500, np.abs(fitted_abs_sims[1])/norm, lw=1.5, alpha=1, linestyle="--", color="tab:orange", label="sim")
axs[1][0].plot(tgrid+500, np.abs(abs_exps[2])/norm, lw=2.5, alpha=0.4, color="tab:green", label="exp")
axs[1][0].plot(tgrid+500, np.abs(fitted_abs_sims[2])/norm, lw=1.5, alpha=1, linestyle="--", color="tab:green", label="sim")
axs[1][1].plot(tgrid+500, np.abs(abs_exps[3])/norm, lw=2.5, alpha=0.4, color="tab:red", label="exp")
axs[1][1].plot(tgrid+500, np.abs(fitted_abs_sims[3])/norm, lw=1.5, alpha=1 , linestyle="--", color="tab:red", label="sim")

fig.text(-0.05, 0.55, "|Amplitude| (arb. unit)", va="center", rotation="vertical")
for ax in axs[-1, :]:
    ax.set_xlabel("Time (ns)")
    ax.set_ylim(-0.1, 1.1)
    ax.set_xlim(0, 1000)

plt.savefig('Fig3_d1.pdf', bbox_inches='tight')
plt.show()
# Out:
# best_x: [-7.56949359e-03 -1.31079291e+01]
# best_x: [-7.99312202e-03 -1.15796495e+01]
# best_x: [-7.7331396e-03 -1.1728183e+01]
# best_x: [-1.30686721e-02 -1.40000385e+01]

# %% [markdown]
# ## delay dependence

# %%
from scipy.integrate import cumulative_trapezoid
from scipy.interpolate import interp1d

T = 1000 
N = 1001
tgrid = np.linspace(-T, T, N)
dt = tgrid[1] - tgrid[0]
# kappa_ph = 2.5e-3 * 2 * np.pi * 2

_eps = 1e-14

g_interps = []
g_interps_rvs = []

for m in range(8): 
    f_vals = f(tgrid, m, kappa_ph)
    f_prime_vals = f_prime(tgrid, m, kappa_ph) 
    f2_vals = np.abs(f_vals)**2
    integral_vals = cumulative_trapezoid(f2_vals, tgrid, initial=0)

    numerator = f_prime_vals + (kappa_r * f_vals / 2)
    denominator = np.sqrt(kappa_r * (1.0 - integral_vals) - f2_vals)
    g_vals = numerator / denominator
    g_interp = interp1d(tgrid, np.real(g_vals), kind='cubic', fill_value='extrapolate')
    g_interps.append(g_interp)

    g_interp_rvs = interp1d(tgrid, np.real(g_vals[::-1]), kind='cubic', fill_value='extrapolate') 
    g_interps_rvs.append(g_interp_rvs)
    
g_u_interps = []
for m in range(8):
    ut_vals = xi_m(tgrid, m, kappa_ph)
    # ut_vals = hermite(tgrid, m, kappa_ph)
    cumint = cumulative_trapezoid(np.abs(ut_vals)**2, tgrid, initial=0)
    eps = 1e-14
    denom = np.sqrt(1.0 - cumint + eps)
    g_vals = np.conjugate(ut_vals) / denom
    g_interp = interp1d(tgrid, g_vals, kind='cubic', fill_value='extrapolate')
    g_u_interps.append(g_interp)

def g_u(t, args):
    m = int(args["input_num"])
    t_local = float(t)
    return float(args["g_u_interps"][m](t_local))

def g_u_conj(t, args):
    return np.conjugate(g_u(t, args))

def g_time(t, args):
    t_local = float(t) - float(args["center"])
    m = int(args["fogi_mode"])
    # access interpolant precomputed above (we'll pass lists via args)
    return float(args["g_interps"][m](t_local))

def g_time_conj(t, args):
    return np.conjugate(g_time(t, args))

def g_time_rvs(t, args):
    t_local = float(t) - float(args["center"])
    m = int(args["fogi_mode"])
    # access interpolant precomputed above (we'll pass lists via args)
    return float(args["g_interps_rvs"][m](t_local))

def g_time_conj_rvs(t, args):
    return np.conjugate(g_time_rvs(t, args))

# %%
base_args = {
    "center": 0.0,
    "fogi_mode": 0,
    "g_interps": g_interps,
    "g_interps_rvs": g_interps_rvs,
    "g_u_interps": g_u_interps,
    "input_num": 0,
    "input": 1,
}
results = {} 

for m in range(8):
    args_mn = base_args.copy()
    args_mn["input_num"] = m
    n=0

    H_m = [
        H_fogi,
        [H_c, g_u], [H_c.dag(), g_u_conj],
        [H_d, g_time_rvs], [H_d.dag(), g_time_conj_rvs],
    ]
    psi0_m = vc1

    def total_c_op(t, args):
        c_op = np.conjugate(g_u(t, args)) * vc + np.sqrt(kappa_r) * a
        return c_op

    c_ops_mn = [
        total_c_op,
        np.sqrt(1/T1ge)*etog, np.sqrt(1/T1ef)*ftoe,
        np.sqrt(1/Tphige)*dechoge, np.sqrt(1/Tphief)*dechoef
    ]

    result_mn = qt.mesolve(
        H_m, psi0_m, tgrid, c_ops_mn, e_ops=e_ops,
        args=args_mn, options=options, progress_bar=True
    )

    results[(m, n)] = result_mn 
    print(f"mode {m} finished")
# Out:
# c:\Users\qipe\Documents\qutip_simulation\.venv\Lib\site-packages\qutip\solver\solver_base.py:460: FutureWarning: "progress_bar" is now included in options:
#  Use `options={"progress_bar": False / True / "tqdm" / "enhanced"}`
#   warnings.warn(
# 10.0%. Run time:   1.21s. Est. time left: 00:00:00:10
# 20.0%. Run time:   2.18s. Est. time left: 00:00:00:08
# 30.0%. Run time:   3.06s. Est. time left: 00:00:00:07
# 40.0%. Run time:   3.91s. Est. time left: 00:00:00:05
# 50.0%. Run time:   4.80s. Est. time left: 00:00:00:04
# 60.0%. Run time:   5.75s. Est. time left: 00:00:00:03
# 70.0%. Run time:   6.64s. Est. time left: 00:00:00:02
# 80.0%. Run time:   7.51s. Est. time left: 00:00:00:01
# 90.0%. Run time:   8.37s. Est. time left: 00:00:00:00
# 100.0%. Run time:   9.25s. Est. time left: 00:00:00:00
# Total run time:   9.25s
# mode 0 finished
# 10.0%. Run time:   0.90s. Est. time left: 00:00:00:08
# 20.0%. Run time:   1.77s. Est. time left: 00:00:00:07
# 30.0%. Run time:   2.65s. Est. time left: 00:00:00:06
# 40.0%. Run time:   3.55s. Est. time left: 00:00:00:05
# 50.0%. Run time:   4.42s. Est. time left: 00:00:00:04
# 60.0%. Run time:   5.33s. Est. time left: 00:00:00:03
# 70.0%. Run time:   6.66s. Est. time left: 00:00:00:02
# 80.0%. Run time:   7.54s. Est. time left: 00:00:00:01
# 90.0%. Run time:   8.47s. Est. time left: 00:00:00:00
# 100.0%. Run time:   9.33s. Est. time left: 00:00:00:00
# Total run time:   9.33s
# mode 1 finished
# 10.0%. Run time:   0.92s. Est. time left: 00:00:00:08
# 20.0%. Run time:   1.78s. Est. time left: 00:00:00:07
# 30.0%. Run time:   2.68s. Est. time left: 00:00:00:06
# 40.0%. Run time:   3.58s. Est. time left: 00:00:00:05
# 50.0%. Run time:   5.65s. Est. time left: 00:00:00:05
# 60.0%. Run time:   6.83s. Est. time left: 00:00:00:04
# 70.0%. Run time:   7.88s. Est. time left: 00:00:00:03
# 80.0%. Run time:   8.79s. Est. time left: 00:00:00:02
# 90.0%. Run time:   9.66s. Est. time left: 00:00:00:01
# 100.0%. Run time:  10.76s. Est. time left: 00:00:00:00
# Total run time:  10.76s
# mode 2 finished
# 10.0%. Run time:   1.17s. Est. time left: 00:00:00:10
# 20.0%. Run time:   2.14s. Est. time left: 00:00:00:08
# 30.0%. Run time:   3.04s. Est. time left: 00:00:00:07
# 40.0%. Run time:   3.94s. Est. time left: 00:00:00:05
# 50.0%. Run time:   4.79s. Est. time left: 00:00:00:04
# 60.0%. Run time:   5.70s. Est. time left: 00:00:00:03
# 70.0%. Run time:   6.65s. Est. time left: 00:00:00:02
# 80.0%. Run time:   7.55s. Est. time left: 00:00:00:01
# 90.0%. Run time:   8.43s. Est. time left: 00:00:00:00
# 100.0%. Run time:   9.30s. Est. time left: 00:00:00:00
# Total run time:   9.31s
# mode 3 finished
# 10.0%. Run time:   0.92s. Est. time left: 00:00:00:08
# 20.0%. Run time:   1.77s. Est. time left: 00:00:00:07
# 30.0%. Run time:   2.65s. Est. time left: 00:00:00:06
# 40.0%. Run time:   3.52s. Est. time left: 00:00:00:05
# 50.0%. Run time:   4.39s. Est. time left: 00:00:00:04
# 60.0%. Run time:   5.28s. Est. time left: 00:00:00:03
# 70.0%. Run time:   7.87s. Est. time left: 00:00:00:03
# 80.0%. Run time:  10.55s. Est. time left: 00:00:00:02
# 90.0%. Run time:  12.31s. Est. time left: 00:00:00:01
# 100.0%. Run time:  13.24s. Est. time left: 00:00:00:00
# Total run time:  13.24s
# mode 4 finished
# 10.0%. Run time:   0.88s. Est. time left: 00:00:00:07
# 20.0%. Run time:   1.77s. Est. time left: 00:00:00:07
# 30.0%. Run time:   2.63s. Est. time left: 00:00:00:06
# 40.0%. Run time:   3.52s. Est. time left: 00:00:00:05
# 50.0%. Run time:   4.50s. Est. time left: 00:00:00:04
# 60.0%. Run time:   5.45s. Est. time left: 00:00:00:03
# 70.0%. Run time:   6.38s. Est. time left: 00:00:00:02
# 80.0%. Run time:   7.31s. Est. time left: 00:00:00:01
# 90.0%. Run time:   8.53s. Est. time left: 00:00:00:00
# 100.0%. Run time:   9.39s. Est. time left: 00:00:00:00
# Total run time:   9.39s
# mode 5 finished
# 10.0%. Run time:   0.90s. Est. time left: 00:00:00:08
# 20.0%. Run time:   1.78s. Est. time left: 00:00:00:07
# 30.0%. Run time:   2.73s. Est. time left: 00:00:00:06
# 40.0%. Run time:   3.57s. Est. time left: 00:00:00:05
# 50.0%. Run time:   4.54s. Est. time left: 00:00:00:04
# 60.0%. Run time:   5.43s. Est. time left: 00:00:00:03
# 70.0%. Run time:   6.31s. Est. time left: 00:00:00:02
# 80.0%. Run time:   7.19s. Est. time left: 00:00:00:01
# 90.0%. Run time:   8.04s. Est. time left: 00:00:00:00
# 100.0%. Run time:   8.91s. Est. time left: 00:00:00:00
# Total run time:   8.91s
# mode 6 finished
# 10.0%. Run time:   0.89s. Est. time left: 00:00:00:08
# 20.0%. Run time:   1.79s. Est. time left: 00:00:00:07
# 30.0%. Run time:   2.67s. Est. time left: 00:00:00:06
# 40.0%. Run time:   3.52s. Est. time left: 00:00:00:05
# 50.0%. Run time:   4.43s. Est. time left: 00:00:00:04
# 60.0%. Run time:   5.74s. Est. time left: 00:00:00:03
# 70.0%. Run time:   6.62s. Est. time left: 00:00:00:02
# 80.0%. Run time:   7.52s. Est. time left: 00:00:00:01
# 90.0%. Run time:   8.40s. Est. time left: 00:00:00:00
# 100.0%. Run time:   9.28s. Est. time left: 00:00:00:00
# Total run time:   9.28s
# mode 7 finished

# %%
def fit_delay(time, waveform_exp, waveform_sim, x0=[0.0]):
    def func(params):
        shift = params
        sim_shifted = roll_with_interpolation(waveform_sim, shift=-shift)
        return sim_shifted

    def cost_func(params):
        return np.linalg.norm(np.abs(func(params)) - np.abs(waveform_exp))

    best_x = optimize.minimize(cost_func, x0, method='Nelder-Mead').x
    print("best_x:", np.round(best_x*2, 0))

    fitted = func(best_x)
    return fitted, best_x

def fidelity_vs_delay(tgrid, psi_prime, psi_target, T_vals):
    """
    F(T) = |∫ psi'(t) * psi(t - T) dt|^2
    """
    dt = tgrid[1] - tgrid[0]
    F_list = []
    for T in T_vals:
        shifted = np.interp(tgrid, tgrid - T, psi_target, left=0.0, right=0.0)
        overlap = np.trapz(np.conjugate(psi_prime) * shifted, dx=dt)
        F_list.append(np.abs(overlap)**2)
    return np.array(F_list)

all_F_vals = []
mode_labels = []

for m in range(8):    
    fig, axes = plt.subplots(1, 2, figsize=(5, 2.5))
    plt.subplots_adjust(wspace=0.4)

    n=0
    states = results[(m, n)].states
    vcdvc_s = qt.expect(vc.dag() * vc, states)
    ada_s = qt.expect(a.dag() * a, states)
    vcda_s = qt.expect(vc.dag() * a, states)
    advc_s = qt.expect(a.dag() * vc, states)
    args = {
        "center": 0.0,
        "fogi_mode": n,
        "g_interps": g_interps,
        "g_interps_rvs": g_interps_rvs,
        "g_u_interps": g_u_interps,
        "input_num": m,
        "input": 0,
    }  

    gu_values = np.array([g_u(t, args) for t in tgrid])
    LdL = (
        gu_values * np.conjugate(gu_values) * vcdvc_s
        + kappa_r * ada_s
        + np.sqrt(kappa_r) * (gu_values * vcda_s + np.conjugate(gu_values) * advc_s)
    )
    input_xi = xi_m(tgrid, m, kappa_ph)
    
    axes[0].plot(tgrid, np.abs(input_xi)*1e1, lw=1, alpha=0.6, color="tab:blue", linestyle=":", label=rf"$\psi_{m}(t)$")
    if m ==0:
        axes[0].plot(tgrid, np.abs(np.sqrt(LdL))*1e1, lw=1, alpha=0.8, color="tab:orange", label="abs")
    if m > 0:
        axes[0].plot(tgrid, np.abs(np.sqrt(LdL))*1e1, lw=1, alpha=0.8, color="tab:orange", label=rf"$\psi_{m-1}'(t)$")
        shifted_xi = xi_m(tgrid, m-1, kappa_ph)
        axes[0].plot(tgrid, np.abs(shifted_xi)*1e1, lw=1, alpha=0.8, color="tab:red", label= rf"$\psi_{m-1}(t)$")

        fitted_dummy, best_x = fit_delay(tgrid, np.sqrt(LdL), shifted_xi, x0=[-50])
        shift_val = best_x
        def apply_fit(waveform, shift_val, time):
            waveform_resampled = np.interp(time, np.linspace(time[0], time[-1], len(waveform)), waveform)
            dt = time[1] - time[0]
            shift_idx = -shift_val / dt 
            return nd_shift(waveform_resampled, shift=shift_idx, mode='constant', cval=0.0)
        
        delay_opt_waveform = apply_fit(shifted_xi, shift_val*2, tgrid)
        axes[0].plot(tgrid, np.abs(delay_opt_waveform)*1e1, lw=1, alpha=0.8, color="black", linestyle="--", label=rf"$\psi_{m-1}(t{round(shift_val[0]*2, 0)})$")

        T_vals = np.linspace(-600, 1000, 801)  # ns範囲
        F_vals = fidelity_vs_delay(tgrid, np.sqrt(LdL), np.abs(shifted_xi), -T_vals)
        all_F_vals.append(F_vals)
        mode_labels.append(f"m={m}")
        axes[1].plot(T_vals, F_vals, lw=1.5, color="tab:green")
        axes[1].set_xlabel("Delay T (ns)")
        axes[1].set_ylabel("Fidelity F(T)")
        axes[1].set_ylim(-0.1, 1)
        axes[1].set_title("Fidelity vs Delay")
        F_max = F_vals.max()
        T_opt = T_vals[F_vals.argmax()]
        axes[1].axvline(T_opt, color="red", linestyle="--", alpha=0.6, label=fr"$T_\mathrm{{opt}}={T_opt:.1f}$ ns")
        axes[1].legend(loc="lower left",)
        axes[1].set_title(fr"Max F = {F_max:.3f}")
     
    axes[0].set_xlabel(r"Time (ns)")
    axes[0].set_ylim(-0.1, 1)
    if n == 0:
        axes[0].legend(loc="upper center", bbox_to_anchor=(0.5, 1), ncol=2)
        axes[0].set_ylabel("Amplitude (arb. unit)")
        axes[0].set_title(f"(m, n)=({m}, {n})")
    else:
        axes[0].set_title(f"({m}, {n})")
    plt.tight_layout()
    plt.show()

plt.figure(figsize=(4,2))
for F_vals, label in zip(all_F_vals, mode_labels):
    plt.plot(T_vals, F_vals, lw=1.5, label=label)
plt.xlabel("Delay T (ns)")
plt.ylabel("Fidelity F(T)")
plt.ylim(-0.1, 1.05)
# plt.title("Fidelity vs Delay for all modes")
plt.legend(loc="center right", bbox_to_anchor=(1.5, 0.5), ncol=1)
plt.tight_layout()
plt.show()
# Out:
# best_x: [-56.]
# C:\Users\qipe\AppData\Local\Temp\ipykernel_27444\3965529470.py:24: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   overlap = np.trapz(np.conjugate(psi_prime) * shifted, dx=dt)
# best_x: [-54.]
# best_x: [-51.]
# best_x: [-49.]
# best_x: [-48.]
# best_x: [-46.]
# best_x: [-47.]

# %% [markdown]
# ## mode preservation

# %%
base_args = {
    "center": 0.0,
    "fogi_mode": 7,
    "g_interps": g_interps,
    "g_interps_rvs": g_interps_rvs,
    "g_u_interps": g_u_interps,
    "input_num": 0,
    "input": 1,
}
results = {} 

for m in range(8):
    args_mn = base_args.copy()
    args_mn["input_num"] = m
    n=0

    H_m = [
        H_fogi,
        [H_c, g_u], [H_c.dag(), g_u_conj],
        [H_d, g_time_rvs], [H_d.dag(), g_time_conj_rvs],
    ]
    psi0_m = vc1

    def total_c_op(t, args):
        c_op = np.conjugate(g_u(t, args)) * vc + np.sqrt(kappa_r) * a
        return c_op

    c_ops_mn = [
        total_c_op,
        np.sqrt(1/T1ge)*etog, np.sqrt(1/T1ef)*ftoe,
        np.sqrt(1/Tphige)*dechoge, np.sqrt(1/Tphief)*dechoef
    ]

    result_mn = qt.mesolve(
        H_m, psi0_m, tgrid, c_ops_mn, e_ops=e_ops,
        args=args_mn, options=options, progress_bar=True
    )

    results[(m, n)] = result_mn 
    print(f"mode {m} finished")
# Out:
# 10.0%. Run time:   1.13s. Est. time left: 00:00:00:10
# 20.0%. Run time:   2.13s. Est. time left: 00:00:00:08
# 30.0%. Run time:   3.81s. Est. time left: 00:00:00:08
# 40.0%. Run time:   4.94s. Est. time left: 00:00:00:07
# 50.0%. Run time:   7.56s. Est. time left: 00:00:00:07
# 60.0%. Run time:   8.60s. Est. time left: 00:00:00:05
# 70.0%. Run time:  11.42s. Est. time left: 00:00:00:04
# 80.0%. Run time:  12.40s. Est. time left: 00:00:00:03
# 90.0%. Run time:  13.41s. Est. time left: 00:00:00:01
# 100.0%. Run time:  15.12s. Est. time left: 00:00:00:00
# Total run time:  15.12s
# mode 0 finished
# 10.0%. Run time:   0.98s. Est. time left: 00:00:00:08
# 20.0%. Run time:   1.96s. Est. time left: 00:00:00:07
# 30.0%. Run time:   3.50s. Est. time left: 00:00:00:08
# 40.0%. Run time:   4.43s. Est. time left: 00:00:00:06
# 50.0%. Run time:   5.40s. Est. time left: 00:00:00:05
# 60.0%. Run time:   6.32s. Est. time left: 00:00:00:04
# 70.0%. Run time:   7.24s. Est. time left: 00:00:00:03
# 80.0%. Run time:   8.14s. Est. time left: 00:00:00:02
# 90.0%. Run time:   9.29s. Est. time left: 00:00:00:01
# 100.0%. Run time:  10.24s. Est. time left: 00:00:00:00
# Total run time:  10.24s
# mode 1 finished
# 10.0%. Run time:   0.95s. Est. time left: 00:00:00:08
# 20.0%. Run time:   1.88s. Est. time left: 00:00:00:07
# 30.0%. Run time:   2.83s. Est. time left: 00:00:00:06
# 40.0%. Run time:   3.74s. Est. time left: 00:00:00:05
# 50.0%. Run time:   4.69s. Est. time left: 00:00:00:04
# 60.0%. Run time:   5.61s. Est. time left: 00:00:00:03
# 70.0%. Run time:   6.60s. Est. time left: 00:00:00:02
# 80.0%. Run time:   7.89s. Est. time left: 00:00:00:01
# 90.0%. Run time:   8.88s. Est. time left: 00:00:00:00
# 100.0%. Run time:   9.77s. Est. time left: 00:00:00:00
# Total run time:   9.77s
# mode 2 finished
# 10.0%. Run time:   0.91s. Est. time left: 00:00:00:08
# 20.0%. Run time:   1.79s. Est. time left: 00:00:00:07
# 30.0%. Run time:   2.73s. Est. time left: 00:00:00:06
# 40.0%. Run time:   3.63s. Est. time left: 00:00:00:05
# 50.0%. Run time:   4.59s. Est. time left: 00:00:00:04
# 60.0%. Run time:   5.52s. Est. time left: 00:00:00:03
# 70.0%. Run time:   6.40s. Est. time left: 00:00:00:02
# 80.0%. Run time:   7.32s. Est. time left: 00:00:00:01
# 90.0%. Run time:   8.23s. Est. time left: 00:00:00:00
# 100.0%. Run time:   9.25s. Est. time left: 00:00:00:00
# Total run time:   9.25s
# mode 3 finished
# 10.0%. Run time:   1.10s. Est. time left: 00:00:00:09
# 20.0%. Run time:   2.02s. Est. time left: 00:00:00:08
# 30.0%. Run time:   3.23s. Est. time left: 00:00:00:07
# 40.0%. Run time:   4.15s. Est. time left: 00:00:00:06
# 50.0%. Run time:   5.03s. Est. time left: 00:00:00:05
# 60.0%. Run time:   5.96s. Est. time left: 00:00:00:03
# 70.0%. Run time:   6.89s. Est. time left: 00:00:00:02
# 80.0%. Run time:   7.79s. Est. time left: 00:00:00:01
# 90.0%. Run time:   8.67s. Est. time left: 00:00:00:00
# 100.0%. Run time:   9.68s. Est. time left: 00:00:00:00
# Total run time:   9.68s
# mode 4 finished
# 10.0%. Run time:   1.00s. Est. time left: 00:00:00:09
# 20.0%. Run time:   1.93s. Est. time left: 00:00:00:07
# 30.0%. Run time:   3.06s. Est. time left: 00:00:00:07
# 40.0%. Run time:   4.11s. Est. time left: 00:00:00:06
# 50.0%. Run time:   5.21s. Est. time left: 00:00:00:05
# 60.0%. Run time:   6.24s. Est. time left: 00:00:00:04
# 70.0%. Run time:   7.44s. Est. time left: 00:00:00:03
# 80.0%. Run time:   8.68s. Est. time left: 00:00:00:02
# 90.0%. Run time:   9.67s. Est. time left: 00:00:00:01
# 100.0%. Run time:  10.67s. Est. time left: 00:00:00:00
# Total run time:  10.67s
# mode 5 finished
# 10.0%. Run time:   0.90s. Est. time left: 00:00:00:08
# 20.0%. Run time:   1.84s. Est. time left: 00:00:00:07
# 30.0%. Run time:   2.73s. Est. time left: 00:00:00:06
# 40.0%. Run time:   3.60s. Est. time left: 00:00:00:05
# 50.0%. Run time:   4.54s. Est. time left: 00:00:00:04
# 60.0%. Run time:   5.45s. Est. time left: 00:00:00:03
# 70.0%. Run time:   6.40s. Est. time left: 00:00:00:02
# 80.0%. Run time:   7.29s. Est. time left: 00:00:00:01
# 90.0%. Run time:   8.20s. Est. time left: 00:00:00:00
# 100.0%. Run time:   9.21s. Est. time left: 00:00:00:00
# Total run time:   9.21s
# mode 6 finished
# 10.0%. Run time:   0.93s. Est. time left: 00:00:00:08
# 20.0%. Run time:   1.82s. Est. time left: 00:00:00:07
# 30.0%. Run time:   2.70s. Est. time left: 00:00:00:06
# 40.0%. Run time:   4.04s. Est. time left: 00:00:00:06
# 50.0%. Run time:   4.97s. Est. time left: 00:00:00:04
# 60.0%. Run time:   5.91s. Est. time left: 00:00:00:03
# 70.0%. Run time:   6.79s. Est. time left: 00:00:00:02
# 80.0%. Run time:   7.71s. Est. time left: 00:00:00:01
# 90.0%. Run time:   8.61s. Est. time left: 00:00:00:00
# 100.0%. Run time:   9.61s. Est. time left: 00:00:00:00
# Total run time:   9.62s
# mode 7 finished

# %%
all_F_vals = []
mode_labels = []

for m in range(8):    
    fig, axes = plt.subplots(1, 2, figsize=(5, 2.5))
    plt.subplots_adjust(wspace=0.4)

    n=0
    states = results[(m, n)].states
    vcdvc_s = qt.expect(vc.dag() * vc, states)
    ada_s = qt.expect(a.dag() * a, states)
    vcda_s = qt.expect(vc.dag() * a, states)
    advc_s = qt.expect(a.dag() * vc, states)
    args = {
        "center": 0.0,
        "fogi_mode": n,
        "g_interps": g_interps,
        "g_interps_rvs": g_interps_rvs,
        "g_u_interps": g_u_interps,
        "input_num": m,
        "input": 0,
    }  

    gu_values = np.array([g_u(t, args) for t in tgrid])
    LdL = (
        gu_values * np.conjugate(gu_values) * vcdvc_s
        + kappa_r * ada_s
        + np.sqrt(kappa_r) * (gu_values * vcda_s + np.conjugate(gu_values) * advc_s)
    )
    input_xi = xi_m(tgrid, m, kappa_ph)
    
    axes[0].plot(tgrid, np.abs(input_xi)*1e1, lw=1, alpha=0.6, color="tab:blue", linestyle=":", label=rf"$\psi_{m}(t)$")
    if m ==7:
        axes[0].plot(tgrid, np.abs(np.sqrt(LdL))*1e1, lw=1, alpha=0.8, color="tab:orange", label="abs")
    if m < 7:
        axes[0].plot(tgrid, np.abs(np.sqrt(LdL))*1e1, lw=1, alpha=0.8, color="tab:orange", label=rf"$\psi_{m}'(t)$")
        nonshifted_xi = xi_m(tgrid, m, kappa_ph)
        axes[0].plot(tgrid, np.abs(nonshifted_xi)*1e1, lw=1, alpha=0.8, color="tab:red", label= rf"$\psi_{m}(t)$")

        fitted_dummy, best_x = fit_delay(tgrid, np.sqrt(LdL), nonshifted_xi, x0=[-50])
        shift_val = best_x
        def apply_fit(waveform, shift_val, time):
            waveform_resampled = np.interp(time, np.linspace(time[0], time[-1], len(waveform)), waveform)
            dt = time[1] - time[0]
            shift_idx = -shift_val / dt 
            return nd_shift(waveform_resampled, shift=shift_idx, mode='constant', cval=0.0)
        
        delay_opt_waveform = apply_fit(nonshifted_xi, shift_val*2, tgrid)
        axes[0].plot(tgrid, np.abs(delay_opt_waveform)*1e1, lw=1, alpha=0.8, color="black", linestyle="--", label=rf"$\psi_{m}(t{round(shift_val[0]*2, 0)})$")

        T_vals = np.linspace(-600, 1000, 801)  # ns範囲
        F_vals = fidelity_vs_delay(tgrid, np.sqrt(LdL), np.abs(nonshifted_xi), -T_vals)
        all_F_vals.append(F_vals)
        mode_labels.append(f"m={m}")
        axes[1].plot(T_vals, F_vals, lw=1.5, color="tab:green")
        axes[1].set_xlabel("Delay T (ns)")
        axes[1].set_ylabel("Fidelity F(T)")
        axes[1].set_ylim(-0.1, 1)
        axes[1].set_title("Fidelity vs Delay")
        F_max = F_vals.max()
        T_opt = T_vals[F_vals.argmax()]
        axes[1].axvline(T_opt, color="red", linestyle="--", alpha=0.6, label=fr"$T_\mathrm{{opt}}={T_opt:.1f}$ ns")
        axes[1].legend(loc="lower left",)
        axes[1].set_title(fr"Max F = {F_max:.3f}")
     
    axes[0].set_xlabel(r"Time (ns)")
    axes[0].set_ylim(-0.1, 1)
    if n == 0:
        axes[0].legend(loc="upper center", bbox_to_anchor=(0.5, 1), ncol=2)
        axes[0].set_ylabel("Amplitude (arb. unit)")
        axes[0].set_title(f"(m, n)=({m}, {n})")
    else:
        axes[0].set_title(f"({m}, {n})")
    plt.tight_layout()
    plt.show()

plt.figure(figsize=(4,2))
for F_vals, label in zip(all_F_vals, mode_labels):
    plt.plot(T_vals, F_vals, lw=1.5, label=label)
plt.xlabel("Delay T (ns)")
plt.ylabel("Fidelity F(T)")
plt.ylim(-0.1, 1.05)
# plt.title("Fidelity vs Delay for all modes")
plt.legend(loc="center right", bbox_to_anchor=(1.5, 0.5), ncol=1)
plt.tight_layout()
plt.show()
# Out:
# best_x: [-5.]
# C:\Users\qipe\AppData\Local\Temp\ipykernel_27444\3965529470.py:24: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   overlap = np.trapz(np.conjugate(psi_prime) * shifted, dx=dt)
# best_x: [-5.]
# best_x: [-107.]
# best_x: [-109.]
# best_x: [-100.]
# best_x: [-10.]
# best_x: [-26.]

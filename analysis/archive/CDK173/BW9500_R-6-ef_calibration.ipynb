# %% [markdown]
# ## 2/3 ef calibration - OP9500_read

# %% [markdown]
# ef_freq =
#
# ef_pi_amp = 0.875
#
#
# T1 = 20e-6

# %%
from plottr.data.datadict_storage import datadict_from_hdf5
import numpy as np
import matplotlib.pyplot as plt
import lmfit

import sklearn
from sklearn.decomposition import PCA

# %%
def PCA_transform(Re_c, Im_c):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c]).T, np.array([Im_c]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    return c_PCA1, c_PCA2

# %%
def Rabi(delay, amp, phi0, detun, const):
    return - amp * np.cos(2*np.pi*detun*delay+phi0) + const

# %% [markdown]
# amp

# %%
header = "D:/K_sunada/result/CDK173"
ef = "/2025-02-07/2025-02-07T172914_9d2c171e-d0_ef_pi_amp"
dd_ef = datadict_from_hdf5(header + ef +"/data")

Rabi_ef = dd_ef['s11']['values']
amp_ef = dd_ef['amplitude']['values']
I = (Rabi_ef.real)
Q = (Rabi_ef.imag)
PCAef = PCA_transform(I, Q)

y = PCAef[0]
x = amp_ef
plt.plot(x, y)
plt.show()

# %%
par_ini= {'amp': 0.0002,'phi0':0,'detun':1/0.4,'const':0}
par_min = {'amp': 0,'phi0':-2*np.pi,'detun':-np.inf,'const':-np.inf}
par_max = {'amp': np.inf,'phi0':2*np.pi,'detun':np.inf,'const':np.inf,}
par_vary = {'amp': True,'phi0':True,'detun':True,'const':True}

model = lmfit.Model(Rabi)

params = model.make_params()
for name in model.param_names:
    params[name].set(value = par_ini[name],min = par_min[name],max = par_max[name],vary = par_vary[name])

result_ef = model.fit(data = y, params = params, delay = x)
result_ef
# Out:
# <h2>Fit Result</h2> <p>Model: Model(Rabi)</p> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>leastsq</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>71</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>26</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>4</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 2.3325e-07</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 1.0602e-08</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'>-473.760703</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-align:right'>-468.728317</td></tr><tr><td style='text-align:left'>R-squared</td><td style='text-align:right'> 0.72610110</td></tr></table><table class="jp-toc-ignore"><caption>Parameters</caption><tr><th style='text-align:left'>name</th><th style='text-align:left'>value</th><th style='text-align:left'>standard error</th><th style='text-align:left'>relative error</th><th style='text-align:left'>initial value</th><th style='text-align:left'>min</th><th style='text-align:left'>max</th><th style='text-align:right'>vary</th></tr><tr><td style='text-align:left'>amp</td><td style='text-align:left'> 2.1955e-04</td><td style='text-align:left'> 2.8791e-05</td><td style='text-align:left'>(13.11%)</td><td style='text-align:left'>0.0002</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>phi0</td><td style='text-align:left'> 0.07293834</td><td style='text-align:left'> 0.26451626</td><td style='text-align:left'>(362.66%)</td><td style='text-align:left'>0</td><td style='text-align:left'>-6.28318531</td><td style='text-align:left'> 6.28318531</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>detun</td><td style='text-align:left'> 2.77100088</td><td style='text-align:left'> 0.06985599</td><td style='text-align:left'>(2.52%)</td><td style='text-align:left'>2.5</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>const</td><td style='text-align:left'>-7.1654e-06</td><td style='text-align:left'> 2.0717e-05</td><td style='text-align:left'>(289.12%)</td><td style='text-align:left'>0</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr></table><table class="jp-toc-ignore"><caption>Correlations (unreported values are < 0.100)</caption><tr><th style='text-align:left'>Parameter1</th><th style='text-align:left'>Parameter 2</th><th style='text-align:right'>Correlation</th></tr><tr><td style='text-align:left'>phi0</td><td style='text-align:left'>detun</td><td style='text-align:right'>-0.8719</td></tr><tr><td style='text-align:left'>detun</td><td style='text-align:left'>const</td><td style='text-align:right'>+0.2157</td></tr><tr><td style='text-align:left'>phi0</td><td style='text-align:left'>const</td><td style='text-align:right'>-0.2056</td></tr></table>

# %%
fig, ax = plt.subplots(figsize=(8,6),constrained_layout=True)
plt.rcParams["font.size"] = 20
# plt.title("Rabi(amp)")
plt.tick_params(top='on',bottom='on',left='on',right='on',)
plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result_ef.plot_fit(ax = ax)
plt.plot(amp_ef,result_ef.init_fit)

plt.title("")
plt.legend("")
ax.set_xlabel('$\pi_{ef}$ pulse DAC amplitude (V)', size='large')
ax.set_ylabel('S$_{11}$ (arb. u.)', size='large')
# # ax.set_ylim(-40, 40)
# ax.set_xlim(0, 1.)
# plt.savefig('ef_rabi.png', bbox_inches='tight')
plt.show()

# %%
np.pi/(2.77100088*2*np.pi)*5
# Out:
# 0.9022010848296808

# %% [markdown]
# ramsey

# %%
pl = "/2025-02-07/2025-02-07T172728_5e324341-d2_ef_T2r1d"
mi = "/2025-02-07/2025-02-07T172754_6d5fbb5b-d2_ef_T2r1d"
dd_pl = datadict_from_hdf5(header + pl +"/data")
dd_mi = datadict_from_hdf5(header + mi +"/data")

# %%
Rabi_pl = dd_pl['s11']['values']
delay_pl = dd_pl['delay']['values']
Rabi_mi = dd_mi['s11']['values']
delay_mi = dd_mi['delay']['values']

I_pl = (Rabi_pl.real)
Q_pl = (Rabi_pl.imag)
I_mi = (Rabi_mi.real)
Q_mi = (Rabi_mi.imag)

PCA_pl = PCA_transform(I_pl, Q_pl)
y_pl = PCA_pl[0]
x_pl = delay_pl

PCA_mi = PCA_transform(I_mi, Q_mi)
y_mi = PCA_mi[0]
x_mi = delay_mi

fig, ax = plt.subplots(1,2,figsize=(12,6),constrained_layout=True)
ax[0].plot(x_pl, y_pl)
ax[1].plot(x_mi, y_mi)
plt.show()

# %%
par_ini_pl = {'amp': 0.00015,'phi0':0,'detun':1/200,'const':0.00001}
par_ini_mi = {'amp': 0.00015,'phi0':0,'detun':1/200,'const':0.00001}
par_min = {'amp': 0,'phi0':-2*np.pi,'detun':-np.inf,'const':0}
par_max = {'amp': np.inf,'phi0':2*np.pi,'detun':np.inf,'const':np.inf,}
par_vary = {'amp': True,'phi0':True,'detun':True,'const':True}

model = lmfit.Model(Rabi)

# %%
params_pl = model.make_params()
for name in model.param_names:
    params_pl[name].set(value = par_ini_pl[name],min = par_min[name],max = par_max[name],vary = par_vary[name])
    
result_pl = model.fit(data = y_pl, params = params_pl, delay = x_pl)
result_pl
# Out:
# <h2>Fit Result</h2> <p>Model: Model(Rabi)</p> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>leastsq</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>26</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>51</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>4</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 4.0091e-08</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 8.5300e-10</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'>-1061.16118</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-align:right'>-1053.43388</td></tr><tr><td style='text-align:left'>R-squared</td><td style='text-align:right'> 0.93383592</td></tr></table><table class="jp-toc-ignore"><caption>Parameters</caption><tr><th style='text-align:left'>name</th><th style='text-align:left'>value</th><th style='text-align:left'>standard error</th><th style='text-align:left'>relative error</th><th style='text-align:left'>initial value</th><th style='text-align:left'>min</th><th style='text-align:left'>max</th><th style='text-align:right'>vary</th></tr><tr><td style='text-align:left'>amp</td><td style='text-align:left'> 1.4875e-04</td><td style='text-align:left'> 5.7760e-06</td><td style='text-align:left'>(3.88%)</td><td style='text-align:left'>0.00015</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>phi0</td><td style='text-align:left'> 0.78649877</td><td style='text-align:left'> 0.07575215</td><td style='text-align:left'>(9.63%)</td><td style='text-align:left'>0</td><td style='text-align:left'>-6.28318531</td><td style='text-align:left'> 6.28318531</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>detun</td><td style='text-align:left'> 0.00495707</td><td style='text-align:left'> 2.1322e-05</td><td style='text-align:left'>(0.43%)</td><td style='text-align:left'>0.005</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>const</td><td style='text-align:left'> 1.3293e-06</td><td style='text-align:left'> 4.1209e-06</td><td style='text-align:left'>(310.00%)</td><td style='text-align:left'>1e-05</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr></table><table class="jp-toc-ignore"><caption>Correlations (unreported values are < 0.100)</caption><tr><th style='text-align:left'>Parameter1</th><th style='text-align:left'>Parameter 2</th><th style='text-align:right'>Correlation</th></tr><tr><td style='text-align:left'>phi0</td><td style='text-align:left'>detun</td><td style='text-align:right'>-0.8577</td></tr><tr><td style='text-align:left'>detun</td><td style='text-align:left'>const</td><td style='text-align:right'>+0.1215</td></tr><tr><td style='text-align:left'>phi0</td><td style='text-align:left'>const</td><td style='text-align:right'>-0.1091</td></tr></table>

# %%
params_mi = model.make_params()
for name in model.param_names:
    params_mi[name].set(value = par_ini_mi[name],min = par_min[name],max = par_max[name],vary = par_vary[name])
    
result_mi = model.fit(data = y_mi, params = params_mi, delay = x_mi)
result_mi
# Out:
# <h2>Fit Result</h2> <p>Model: Model(Rabi)</p> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>leastsq</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>26</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>51</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>4</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 2.2629e-08</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 4.8147e-10</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'>-1090.32898</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-align:right'>-1082.60168</td></tr><tr><td style='text-align:left'>R-squared</td><td style='text-align:right'> 0.95565681</td></tr></table><table class="jp-toc-ignore"><caption>Parameters</caption><tr><th style='text-align:left'>name</th><th style='text-align:left'>value</th><th style='text-align:left'>standard error</th><th style='text-align:left'>relative error</th><th style='text-align:left'>initial value</th><th style='text-align:left'>min</th><th style='text-align:left'>max</th><th style='text-align:right'>vary</th></tr><tr><td style='text-align:left'>amp</td><td style='text-align:left'> 1.3853e-04</td><td style='text-align:left'> 4.3539e-06</td><td style='text-align:left'>(3.14%)</td><td style='text-align:left'>0.00015</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>phi0</td><td style='text-align:left'> 0.75760383</td><td style='text-align:left'> 0.06085455</td><td style='text-align:left'>(8.03%)</td><td style='text-align:left'>0</td><td style='text-align:left'>-6.28318531</td><td style='text-align:left'> 6.28318531</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>detun</td><td style='text-align:left'> 0.00502784</td><td style='text-align:left'> 1.6964e-05</td><td style='text-align:left'>(0.34%)</td><td style='text-align:left'>0.005</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>const</td><td style='text-align:left'> 2.2776e-06</td><td style='text-align:left'> 3.0871e-06</td><td style='text-align:left'>(135.54%)</td><td style='text-align:left'>1e-05</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr></table><table class="jp-toc-ignore"><caption>Correlations (unreported values are < 0.100)</caption><tr><th style='text-align:left'>Parameter1</th><th style='text-align:left'>Parameter 2</th><th style='text-align:right'>Correlation</th></tr><tr><td style='text-align:left'>phi0</td><td style='text-align:left'>detun</td><td style='text-align:right'>-0.8572</td></tr></table>

# %%
fig, ax = plt.subplots(1,2,figsize=(12,6),constrained_layout=True)
plt.rcParams["font.size"] = 20

plt.tick_params(top='on',bottom='on',left='on',right='on',)

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result_pl.plot_fit(ax = ax[0])
ax[0].plot(x_pl,result_pl.init_fit)
result_mi.plot_fit(ax = ax[1])
ax[1].plot(x_mi,result_mi.init_fit)

plt.title("")
plt.legend("")
plt.xlabel(r"Delay ${\tau}$ (ns)")
plt.ylabel("$S_{11}$ (arb. u.)")
plt.xlim(0, 1000)
# plt.savefig('ef_ramsey_exp.png', bbox_inches='tight')
plt.show()

# %%
detun = ((0.005-0.00495707)+ (0.00502784-0.005))/2 #GHz
detun
# Out:
# 3.538499999999976e-05

# %% [markdown]
# drag

# %%
drag = "/2025-02-07/2025-02-07T173038_cf80a618-d1_ef_pi_drag" #n=7
dd_drag = datadict_from_hdf5(header + drag +"/data")

drag1 = "/2025-02-07/2025-02-07T173115_e5068ded-d1_ef_pi_drag" #n=11
dd_drag1 = datadict_from_hdf5(header + drag1 +"/data")

drag2 = "/2025-02-07/2025-02-07T173151_fa9045ee-d1_ef_pi_drag" #n=17
dd_drag2 = datadict_from_hdf5(header + drag2 +"/data")

# %%
Rabi_drag = dd_drag['s11']['values']
drag = dd_drag['beta']['values']
I_drag = (Rabi_drag.real)
Q_drag = (Rabi_drag.imag)

Rabi_drag1 = dd_drag1['s11']['values']
drag1 = dd_drag1['beta']['values']
I_drag1 = (Rabi_drag1.real)
Q_drag1 = (Rabi_drag1.imag)

Rabi_drag2 = dd_drag2['s11']['values']
drag2 = dd_drag2['beta']['values']
I_drag2 = (Rabi_drag2.real)
Q_drag2 = (Rabi_drag2.imag)

# %%
def PCA_transform1(Re_c_amp, Im_c_amp, Re_c_drag, Im_c_drag):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c_amp]).T, np.array([Im_c_amp]).T], axis = 1)
    c1_data = np.concatenate([np.array([Re_c_drag]).T, np.array([Im_c_drag]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    
    c1_pca = pca.transform(c1_data)
    c1_PCA1 = c1_pca.T[0]
    c1_PCA2 = c1_pca.T[1]
    return c_PCA1, c_PCA2, c1_PCA1, c1_PCA2,

# %%
PCA_drag = PCA_transform1(I_drag, Q_drag, I_drag, Q_drag)
y = PCA_drag[0]
y0 = PCA_drag[2]
x0 = drag

PCA_drag1 = PCA_transform1(I_drag, Q_drag, I_drag1, Q_drag1)
y1 = PCA_drag1[2]
x1 = drag1

PCA_drag2 = PCA_transform1(I_drag, Q_drag, I_drag2, Q_drag2)
y2 = PCA_drag2[2]
x2 = drag2

# %%
plt.plot(x0, y0)
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.show()

# %%
par_ini= {'amp': 0.0002,'phi0':np.pi/2,'detun':1/0.3,'const':0}
par_min = {'amp': 0,'phi0':-2*np.pi,'detun':-np.inf,'const':-np.pi}
par_max = {'amp': np.inf,'phi0':2*np.pi,'detun':np.inf,'const':np.inf,}
par_vary = {'amp': True,'phi0':True,'detun':True,'const':True}
model = lmfit.Model(Rabi)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )
    
result0 = model.fit(data = y0, params = params, delay = x0)
result1 = model.fit(data = y1, params = params, delay = x1)
result2 = model.fit(data = y2, params = params, delay = x2)

# %%
fig, ax = plt.subplots(1,3,figsize=(18,6),constrained_layout=True)
plt.title("Rabi(drag)")
plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result0.plot_fit(ax = ax[0])
ax[0].plot(x0,result0.init_fit)
result1.plot_fit(ax = ax[1])
ax[1].plot(x1,result1.init_fit)
result2.plot_fit(ax = ax[2])
ax[2].plot(x2,result2.init_fit)
plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")
plt.show()

# %%
result0
# Out:
# <h2>Fit Result</h2> <p>Model: Model(Rabi)</p> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>leastsq</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>47</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>101</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>4</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 1.4969e-07</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 1.5432e-09</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'>-2045.31444</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-align:right'>-2034.85396</td></tr><tr><td style='text-align:left'>R-squared</td><td style='text-align:right'> 0.93817364</td></tr></table><table class="jp-toc-ignore"><caption>Parameters</caption><tr><th style='text-align:left'>name</th><th style='text-align:left'>value</th><th style='text-align:left'>standard error</th><th style='text-align:left'>relative error</th><th style='text-align:left'>initial value</th><th style='text-align:left'>min</th><th style='text-align:left'>max</th><th style='text-align:right'>vary</th></tr><tr><td style='text-align:left'>amp</td><td style='text-align:left'> 2.1263e-04</td><td style='text-align:left'> 5.5476e-06</td><td style='text-align:left'>(2.61%)</td><td style='text-align:left'>0.0002</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>phi0</td><td style='text-align:left'> 1.88279284</td><td style='text-align:left'> 0.02594506</td><td style='text-align:left'>(1.38%)</td><td style='text-align:left'>3.141592653589793</td><td style='text-align:left'>-6.28318531</td><td style='text-align:left'> 6.28318531</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>detun</td><td style='text-align:left'> 1.24543740</td><td style='text-align:left'> 0.00352187</td><td style='text-align:left'>(0.28%)</td><td style='text-align:left'>1.0</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>const</td><td style='text-align:left'> 4.1048e-07</td><td style='text-align:left'> 3.9132e-06</td><td style='text-align:left'>(953.32%)</td><td style='text-align:left'>0</td><td style='text-align:left'>-3.14159265</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr></table>

# %%
res0 = (-2*np.pi-1.88279284)/(2*np.pi*1.24543740)
res0
# Out:
# -1.0435336110060838

# %%
result1
# Out:
# <h2>Fit Result</h2> <p>Model: Model(Rabi)</p> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>leastsq</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>36</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>101</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>4</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 1.7884e-07</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 1.8438e-09</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'>-2027.33896</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-align:right'>-2016.87848</td></tr><tr><td style='text-align:left'>R-squared</td><td style='text-align:right'> 0.90568914</td></tr></table><table class="jp-toc-ignore"><caption>Parameters</caption><tr><th style='text-align:left'>name</th><th style='text-align:left'>value</th><th style='text-align:left'>standard error</th><th style='text-align:left'>relative error</th><th style='text-align:left'>initial value</th><th style='text-align:left'>min</th><th style='text-align:left'>max</th><th style='text-align:right'>vary</th></tr><tr><td style='text-align:left'>amp</td><td style='text-align:left'> 1.8379e-04</td><td style='text-align:left'> 6.0228e-06</td><td style='text-align:left'>(3.28%)</td><td style='text-align:left'>0.0002</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>phi0</td><td style='text-align:left'> 2.68523764</td><td style='text-align:left'> 0.03302745</td><td style='text-align:left'>(1.23%)</td><td style='text-align:left'>3.141592653589793</td><td style='text-align:left'>-6.28318531</td><td style='text-align:left'> 6.28318531</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>detun</td><td style='text-align:left'> 2.31742150</td><td style='text-align:left'> 0.00454578</td><td style='text-align:left'>(0.20%)</td><td style='text-align:left'>2.5</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>const</td><td style='text-align:left'>-1.3580e-05</td><td style='text-align:left'> 4.2787e-06</td><td style='text-align:left'>(31.51%)</td><td style='text-align:left'>0</td><td style='text-align:left'>-3.14159265</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr></table>

# %%
res1 = (-4*np.pi-2.68523764)/(2*np.pi*2.31742150)
res1
# Out:
# -1.0474438265902062

# %%
result2
# Out:
# <h2>Fit Result</h2> <p>Model: Model(Rabi)</p> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>leastsq</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>47</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>101</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>4</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 2.8936e-07</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 2.9831e-09</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'>-1978.74215</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-align:right'>-1968.28167</td></tr><tr><td style='text-align:left'>R-squared</td><td style='text-align:right'> 0.85857633</td></tr></table><table class="jp-toc-ignore"><caption>Parameters</caption><tr><th style='text-align:left'>name</th><th style='text-align:left'>value</th><th style='text-align:left'>standard error</th><th style='text-align:left'>relative error</th><th style='text-align:left'>initial value</th><th style='text-align:left'>min</th><th style='text-align:left'>max</th><th style='text-align:right'>vary</th></tr><tr><td style='text-align:left'>amp</td><td style='text-align:left'> 1.8731e-04</td><td style='text-align:left'> 7.7192e-06</td><td style='text-align:left'>(4.12%)</td><td style='text-align:left'>0.0002</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>phi0</td><td style='text-align:left'> 1.12572460</td><td style='text-align:left'> 0.04087060</td><td style='text-align:left'>(3.63%)</td><td style='text-align:left'>1.5707963267948966</td><td style='text-align:left'>-6.28318531</td><td style='text-align:left'> 6.28318531</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>detun</td><td style='text-align:left'> 3.01746840</td><td style='text-align:left'> 0.00553136</td><td style='text-align:left'>(0.18%)</td><td style='text-align:left'>3.3333333333333335</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>const</td><td style='text-align:left'> 7.3989e-06</td><td style='text-align:left'> 5.4373e-06</td><td style='text-align:left'>(73.49%)</td><td style='text-align:left'>0</td><td style='text-align:left'>-3.14159265</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr></table>

# %%
res2 = (-6*np.pi-1.12572460)/(2*np.pi*3.01746840)
res2
# Out:
# -1.053586720129413

# %%
beta = (res0 + res1 + res2)/3
beta
# Out:
# -1.0481880525752343

# %% [markdown]
# half drag

# %%
drag = "/2025-02-07/2025-02-07T173233_13bf5324-d1_ef_half_pi_drag" #n=7
dd_drag = datadict_from_hdf5(header + drag +"/data")

drag1 = "/2025-02-07/2025-02-07T173322_30e4c304-d1_ef_half_pi_drag" #n=13
dd_drag1 = datadict_from_hdf5(header + drag1 +"/data")

drag2 = "/2025-02-07/2025-02-07T173404_49feed15-d1_ef_half_pi_drag" #n=17
dd_drag2 = datadict_from_hdf5(header + drag2 +"/data")

# %%
Rabi_drag = dd_drag['s11']['values']
drag = dd_drag['beta']['values']
I_drag = (Rabi_drag.real)
Q_drag = (Rabi_drag.imag)

Rabi_drag1 = dd_drag1['s11']['values']
drag1 = dd_drag1['beta']['values']
I_drag1 = (Rabi_drag1.real)
Q_drag1 = (Rabi_drag1.imag)

Rabi_drag2 = dd_drag2['s11']['values']
drag2 = dd_drag2['beta']['values']
I_drag2 = (Rabi_drag2.real)
Q_drag2 = (Rabi_drag2.imag)

# %%
PCA_drag = PCA_transform1(I_drag, Q_drag, I_drag, Q_drag)
y = PCA_drag[0]
y0 = PCA_drag[2]
x0 = drag

PCA_drag1 = PCA_transform1(I_drag, Q_drag, I_drag1, Q_drag1)
y1 = PCA_drag1[2]
x1 = drag1

PCA_drag2 = PCA_transform1(I_drag, Q_drag, I_drag2, Q_drag2)
y2 = PCA_drag2[2]
x2 = drag2

# %%
plt.plot(x0, y0)
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.show()

# %%
par_ini= {'amp': 0.0001,'phi0':np.pi,'detun':1/1.2,'const':0}
par_min = {'amp': 0,'phi0':-2*np.pi,'detun':-np.inf,'const':-np.pi}
par_max = {'amp': np.inf,'phi0':2*np.pi,'detun':np.inf,'const':np.inf,}
par_vary = {'amp': True,'phi0':True,'detun':True,'const':True}
model = lmfit.Model(Rabi)

model = lmfit.Model(Rabi)
params = model.make_params()
for name in model.param_names:
    params[name].set(value = par_ini[name],min = par_min[name],max = par_max[name],vary = par_vary[name])
    
result0 = model.fit(data = y0, params = params, delay = x0)
result1 = model.fit(data = y1, params = params, delay = x1)
result2 = model.fit(data = y2, params = params, delay = x2)

# %%
fig, ax = plt.subplots(1,3,figsize=(18,6),constrained_layout=True)
plt.title("Rabi(drag)")
plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result0.plot_fit(ax = ax[0])
ax[0].plot(x0,result0.init_fit)
result1.plot_fit(ax = ax[1])
ax[1].plot(x1,result1.init_fit)
result2.plot_fit(ax = ax[2])
ax[2].plot(x2,result2.init_fit)
plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")
plt.show()

# %%
result0
# Out:
# <h2>Fit Result</h2> <p>Model: Model(Rabi)</p> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>leastsq</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>26</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>101</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>4</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 8.6685e-08</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 8.9366e-10</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'>-2100.48714</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-align:right'>-2090.02665</td></tr><tr><td style='text-align:left'>R-squared</td><td style='text-align:right'> 0.82291692</td></tr></table><table class="jp-toc-ignore"><caption>Parameters</caption><tr><th style='text-align:left'>name</th><th style='text-align:left'>value</th><th style='text-align:left'>standard error</th><th style='text-align:left'>relative error</th><th style='text-align:left'>initial value</th><th style='text-align:left'>min</th><th style='text-align:left'>max</th><th style='text-align:right'>vary</th></tr><tr><td style='text-align:left'>amp</td><td style='text-align:left'> 9.4727e-05</td><td style='text-align:left'> 4.4739e-06</td><td style='text-align:left'>(4.72%)</td><td style='text-align:left'>0.0001</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>phi0</td><td style='text-align:left'> 2.78545613</td><td style='text-align:left'> 0.04337700</td><td style='text-align:left'>(1.56%)</td><td style='text-align:left'>3.141592653589793</td><td style='text-align:left'>-6.28318531</td><td style='text-align:left'> 6.28318531</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>detun</td><td style='text-align:left'> 0.41084073</td><td style='text-align:left'> 0.00572525</td><td style='text-align:left'>(1.39%)</td><td style='text-align:left'>0.5</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>const</td><td style='text-align:left'> 1.4932e-05</td><td style='text-align:left'> 3.1734e-06</td><td style='text-align:left'>(21.25%)</td><td style='text-align:left'>0</td><td style='text-align:left'>-3.14159265</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr></table><table class="jp-toc-ignore"><caption>Correlations (unreported values are < 0.100)</caption><tr><th style='text-align:left'>Parameter1</th><th style='text-align:left'>Parameter 2</th><th style='text-align:right'>Correlation</th></tr><tr><td style='text-align:left'>detun</td><td style='text-align:left'>const</td><td style='text-align:right'>-0.2524</td></tr><tr><td style='text-align:left'>amp</td><td style='text-align:left'>const</td><td style='text-align:right'>+0.2290</td></tr></table>

# %%
res0 = (-2.78545613)/(2*np.pi*0.41084073)
res0
# Out:
# -1.0790534615570395

# %%
result1
# Out:
# <h2>Fit Result</h2> <p>Model: Model(Rabi)</p> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>leastsq</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>51</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>101</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>4</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 1.1788e-07</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 1.2153e-09</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'>-2069.43668</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-align:right'>-2058.97620</td></tr><tr><td style='text-align:left'>R-squared</td><td style='text-align:right'> 0.78465782</td></tr></table><table class="jp-toc-ignore"><caption>Parameters</caption><tr><th style='text-align:left'>name</th><th style='text-align:left'>value</th><th style='text-align:left'>standard error</th><th style='text-align:left'>relative error</th><th style='text-align:left'>initial value</th><th style='text-align:left'>min</th><th style='text-align:left'>max</th><th style='text-align:right'>vary</th></tr><tr><td style='text-align:left'>amp</td><td style='text-align:left'> 9.2216e-05</td><td style='text-align:left'> 4.9109e-06</td><td style='text-align:left'>(5.33%)</td><td style='text-align:left'>0.0001</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>phi0</td><td style='text-align:left'> 5.22148380</td><td style='text-align:left'> 0.05337649</td><td style='text-align:left'>(1.02%)</td><td style='text-align:left'>3.141592653589793</td><td style='text-align:left'>-6.28318531</td><td style='text-align:left'> 6.28318531</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>detun</td><td style='text-align:left'> 0.74223709</td><td style='text-align:left'> 0.00732138</td><td style='text-align:left'>(0.99%)</td><td style='text-align:left'>0.8333333333333334</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>const</td><td style='text-align:left'>-3.0456e-06</td><td style='text-align:left'> 3.4972e-06</td><td style='text-align:left'>(114.83%)</td><td style='text-align:left'>0</td><td style='text-align:left'>-3.14159265</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr></table><table class="jp-toc-ignore"><caption>Correlations (unreported values are < 0.100)</caption><tr><th style='text-align:left'>Parameter1</th><th style='text-align:left'>Parameter 2</th><th style='text-align:right'>Correlation</th></tr><tr><td style='text-align:left'>detun</td><td style='text-align:left'>const</td><td style='text-align:right'>-0.1271</td></tr></table>

# %%
res1 = (-5.22148380)/(2*np.pi*0.74223709)
res1
# Out:
# -1.1196219755661272

# %%
result2
# Out:
# <h2>Fit Result</h2> <p>Model: Model(Rabi)</p> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>leastsq</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>41</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>101</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>4</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 1.1664e-07</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 1.2025e-09</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'>-2070.51023</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-align:right'>-2060.04975</td></tr><tr><td style='text-align:left'>R-squared</td><td style='text-align:right'> 0.73392797</td></tr></table><table class="jp-toc-ignore"><caption>Parameters</caption><tr><th style='text-align:left'>name</th><th style='text-align:left'>value</th><th style='text-align:left'>standard error</th><th style='text-align:left'>relative error</th><th style='text-align:left'>initial value</th><th style='text-align:left'>min</th><th style='text-align:left'>max</th><th style='text-align:right'>vary</th></tr><tr><td style='text-align:left'>amp</td><td style='text-align:left'> 7.9850e-05</td><td style='text-align:left'> 4.8838e-06</td><td style='text-align:left'>(6.12%)</td><td style='text-align:left'>0.0001</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>phi0</td><td style='text-align:left'> 0.57607519</td><td style='text-align:left'> 0.06121489</td><td style='text-align:left'>(10.63%)</td><td style='text-align:left'>3.141592653589793</td><td style='text-align:left'>-6.28318531</td><td style='text-align:left'> 6.28318531</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>detun</td><td style='text-align:left'> 0.98817710</td><td style='text-align:left'> 0.00848285</td><td style='text-align:left'>(0.86%)</td><td style='text-align:left'>1.0</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>const</td><td style='text-align:left'>-1.2283e-05</td><td style='text-align:left'> 3.4985e-06</td><td style='text-align:left'>(28.48%)</td><td style='text-align:left'>0</td><td style='text-align:left'>-3.14159265</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr></table><table class="jp-toc-ignore"><caption>Correlations (unreported values are < 0.100)</caption><tr><th style='text-align:left'>Parameter1</th><th style='text-align:left'>Parameter 2</th><th style='text-align:right'>Correlation</th></tr><tr><td style='text-align:left'>detun</td><td style='text-align:left'>const</td><td style='text-align:right'>+0.1652</td></tr></table>

# %%
res2 = (-2*np.pi-0.57607519)/(2*np.pi*0.98817710)
res2
# Out:
# -1.1047465217328987

# %%
(res0+res1+res2)/3
# Out:
# -1.1011406529520218

# %% [markdown]
# T1

# %%
def Dephase(delay, amp, gamma, const):
    return amp*np.exp(-gamma*delay) + const

t1 ="/2025-02-03/2025-02-03T145241_14e61950-d3_ef_T1"

dd_t1 = datadict_from_hdf5(header + t1 +"/data")

# %%
s11_t1 = dd_t1['s11']['values']
delay_t1 = dd_t1['delay']['values']
I_t1 = (s11_t1.real)
Q_t1 = (s11_t1.imag)
PCA_t1 = PCA_transform(I_t1, Q_t1)

y_t1 = PCA_t1[0]
x_t1 = delay_t1

plt.plot(x_t1, y_t1)
plt.show()

# %%
par_ini_t1 = {'gamma': 1/40000e-3,'amp':30,'const':-2.4}
par_min_t1 = {'gamma': 0,'amp':0,'const':-np.inf}
par_max_t1 = {'gamma': np.inf,'amp':np.inf,'const':np.inf,}
par_vary_t1 = {'gamma': True,'amp':True,'const':True}

model = lmfit.Model(Dephase)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini_t1[name],
    min = par_min_t1[name],
    max = par_max_t1[name],
    vary = par_vary_t1[name]
    )
result_t1 = model.fit(data = y_t1, params = params, delay = x_t1*1e-3)
result_t1
# Out:
# <h2>Fit Result</h2> <p>Model: Model(Dephase)</p> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>leastsq</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>30</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>101</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>3</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 404.702652</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 4.12961890</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'> 146.191241</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-align:right'> 154.036603</td></tr><tr><td style='text-align:left'>R-squared</td><td style='text-align:right'> 0.93231488</td></tr></table><table class="jp-toc-ignore"><caption>Parameters</caption><tr><th style='text-align:left'>name</th><th style='text-align:left'>value</th><th style='text-align:left'>standard error</th><th style='text-align:left'>relative error</th><th style='text-align:left'>initial value</th><th style='text-align:left'>min</th><th style='text-align:left'>max</th><th style='text-align:right'>vary</th></tr><tr><td style='text-align:left'>amp</td><td style='text-align:left'> 28.6529415</td><td style='text-align:left'> 0.79913445</td><td style='text-align:left'>(2.79%)</td><td style='text-align:left'>30</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>gamma</td><td style='text-align:left'> 0.07983110</td><td style='text-align:left'> 0.00568260</td><td style='text-align:left'>(7.12%)</td><td style='text-align:left'>0.025</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>const</td><td style='text-align:left'>-7.12143074</td><td style='text-align:left'> 0.50199115</td><td style='text-align:left'>(7.05%)</td><td style='text-align:left'>-2.4</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr></table><table class="jp-toc-ignore"><caption>Correlations (unreported values are < 0.100)</caption><tr><th style='text-align:left'>Parameter1</th><th style='text-align:left'>Parameter 2</th><th style='text-align:right'>Correlation</th></tr><tr><td style='text-align:left'>gamma</td><td style='text-align:left'>const</td><td style='text-align:right'>+0.8299</td></tr><tr><td style='text-align:left'>amp</td><td style='text-align:left'>gamma</td><td style='text-align:right'>+0.2182</td></tr><tr><td style='text-align:left'>amp</td><td style='text-align:left'>const</td><td style='text-align:right'>-0.1957</td></tr></table>

# %%
fig, ax = plt.subplots(figsize=(8,6),constrained_layout=True)
plt.rcParams["font.size"] = 20

plt.tick_params(top='on',bottom='on',left='on',right='on',)
plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result_t1.plot_fit(ax = ax)
# plt.plot(delay_t1,result_t1.init_fit)

plt.title("")
plt.legend("")
ax.set_xlabel(r'Delay $\tau$ ($\mu$s)')#, size='large')
ax.set_ylabel('S$_{11}$ (arb. u.)')
ax.set_xlim(0, 100)
# plt.savefig('ef_T1.png', bbox_inches='tight')

plt.show()

# %%
T1 = (1/0.07983110)*1e-9
T1
# Out:
# 1.2526446460088864e-08

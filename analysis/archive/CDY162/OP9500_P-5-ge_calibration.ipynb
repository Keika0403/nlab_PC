# %% [markdown]
# ## 7/12 ge calibration

# %% [markdown]
# T1 = 36e-06
#
# T2_echo = 5.5e-06
#
# T2_star = 4.8e-06

# %%
from plottr.data.datadict_storage import datadict_from_hdf5
import numpy as np
import matplotlib.pyplot as plt
import lmfit

# %%
import sklearn
from sklearn.decomposition import PCA

# %%
def Rabi(delay, amp, phi0, detun, const):
    return - amp * np.cos(2*np.pi*detun*delay+phi0) + const

# %%
def PCA_transform(Re_c, Im_c):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c]).T, np.array([Im_c]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    return c_PCA1, c_PCA2

# %%
header = "D:/K_Sunada/result/CDY162"

# %%
amp = "/2024-07-12/2024-07-12T171001_2326bb93-21_ge_pi_amp"
dd_amp = datadict_from_hdf5(header + amp +"/data")

# %%
Rabi_amp = dd_amp['s11']['values']
imag_amp = Rabi_amp.imag
amp = dd_amp['amplitude']['values']

# %%
def PCA_transform(Re_c, Im_c):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c]).T, np.array([Im_c]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    return c_PCA1, c_PCA2, pca

# %%
I_amp = (Rabi_amp.real)
Q_amp = (Rabi_amp.imag)
PCA_amp = PCA_transform(I_amp, Q_amp)

# %%
PCA_amp = PCA_transform(I_amp, Q_amp)
y = I_amp
x = amp

fig, (ax1) = plt.subplots(nrows=1)
ax1.set_xlabel('Amplitude (V)', size='large')
ax1.set_ylabel('PCA[$S_{11}$] (V)', size='large')
plt.rcParams["font.size"] = 17
plt.plot(x, PCA_amp[0])
ax1.tick_params(axis="x", direction="in")
ax1.tick_params(axis="y", direction="in")
# ax1.set_xlim(0, 1)
# ax1.set_ylim(-48, 160)
plt.tick_params(
            top='on',
            bottom='on`',
            left='on',
            right='on',
            )
plt.show()

# %%
par_ini= {
    'amp': 10,
    'phi0':0,
    'detun':1/0.55,
    'const':1
}

par_min = {
    'amp': 0,
    'phi0':-2*np.pi,
    'detun':-np.inf,
    'const':-np.inf
}

par_max = {
    'amp': np.inf,
    'phi0':2*np.pi,
    'detun':np.inf,
    'const':np.inf,
}

par_vary = {
    'amp': True,
    'phi0':True,
    'detun':True,
    'const':True
}

# %%
model = lmfit.Model(Rabi)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )
    
result = model.fit(data = PCA_amp[0], params = params, delay = x)
result
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>56</td><td></td></tr><tr><td># data points</td><td>31</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 4.66345713</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.17272063</td><td></td></tr><tr><td>Akaike info crit.</td><td>-50.7211349</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-44.9851861</td><td></td></tr><tr><td>R-squared</td><td> 0.99672630</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  9.35085945 </td><td>  0.10332705 </td><td> (1.11%) </td><td> 10 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  3.11114994 </td><td>  0.02356720 </td><td> (0.76%) </td><td> 0 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  1.71281443 </td><td>  0.00438115 </td><td> (0.26%) </td><td> 1.8181818181818181 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  0.18651329 </td><td>  0.07560752 </td><td> (40.54%) </td><td> 1 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>-0.8677</td></tr><tr><td>phi0</td><td>const</td><td>+0.1048</td></tr></table>

# %%
fig, ax = plt.subplots(figsize=(8,6),constrained_layout=True)
plt.rcParams["font.size"] = 20
# plt.title("Rabi(amp)")
plt.tick_params(top='on',bottom='on',left='on',right='on',)
plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result.plot_fit(ax = ax)
plt.plot(x,result.init_fit)

plt.title("")
plt.legend("")
ax.set_xlabel('$\pi_{ge}$ pulse DAC amplitude (V)', size='large')
ax.set_ylabel('S$_{11}$ (arb. u.)', size='large')
ax.set_xlim(0, 1.)
# plt.savefig('ge_rabi.png', bbox_inches='tight')
plt.show()

# %%
np.pi/(1.71281443*2*np.pi)*5
# Out:
# 1.4595860218202388

# %% [markdown]
# ramsey

# %%
pl ="/2024-07-12/2024-07-12T171110_4c7ffbb9-23_ge_T2r1d"
mi =  "/2024-07-12/2024-07-12T171213_72176011-23_ge_T2r1d"
dd_pl = datadict_from_hdf5(header + pl +"/data")
dd_mi = datadict_from_hdf5(header + mi +"/data")

# %%
Rabi_pl = dd_pl['s11']['values']
imag_pl = Rabi_pl.imag
delay_pl = dd_pl['delay']['values']

Rabi_mi = dd_mi['s11']['values']
imag_mi = Rabi_mi.imag
delay_mi = dd_mi['delay']['values']

# %%
I_pl = (Rabi_pl.real)
Q_pl = (Rabi_pl.imag)
I_mi = (Rabi_mi.real)
Q_mi = (Rabi_mi.imag)


PCA_pl = PCA_transform(I_pl, Q_pl)
y_pl = PCA_pl[0]
x_pl = delay_pl

PCA_mi = PCA_transform(I_mi, Q_mi)
y_mi = PCA_mi[0]
x_mi = delay_mi



plt.plot(x_pl, y_pl)
plt.show()

# %%
par_ini_pl = {
    'amp': 10,
    'phi0':0,
    'detun':1/230,
    'const':0.1
}

par_min_pl = {
    'amp': 0,
    'phi0':-2*np.pi,
    'detun':-np.inf,
    'const':0
}

par_max_pl = {
    'amp': np.inf,
    'phi0':2*np.pi,
    'detun':np.inf,
    'const':np.inf,
}

par_vary_pl = {
    'amp': True,
    'phi0':True,
    'detun':True,
    'const':True
}

# %%
model = lmfit.Model(Rabi)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini_pl[name],
    min = par_min_pl[name],
    max = par_max_pl[name],
    vary = par_vary_pl[name]
    )
    
result_pl = model.fit(data = y_pl, params = params, delay = x_pl)
result_pl
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>62</td><td></td></tr><tr><td># data points</td><td>51</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 16.7545368</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.35647951</td><td></td></tr><tr><td>Akaike info crit.</td><td>-48.7709843</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-41.0436818</td><td></td></tr><tr><td>R-squared</td><td> 0.98989030</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  7.95029310 </td><td>  0.11726556 </td><td> (1.47%) </td><td> 10 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td> -0.31474234 </td><td>  0.03059081 </td><td> (9.72%) </td><td> 0 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  0.00501392 </td><td>  8.3813e-06 </td><td> (0.17%) </td><td> 0.004347826086956522 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  0.17020174 </td><td>  0.08447571 </td><td> (49.63%) </td><td> 0.1 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>-0.8713</td></tr><tr><td>detun</td><td>const</td><td>+0.1399</td></tr><tr><td>phi0</td><td>const</td><td>-0.1179</td></tr></table>

# %%
fig, ax = plt.subplots(figsize=(8,6),constrained_layout=True)

# plt.title("Rabi(+5MHz)")


plt.rcParams["font.size"] = 20

plt.tick_params(top='on',bottom='on',left='on',right='on',)

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'

result_pl.plot_fit(ax = ax)
plt.plot(x_pl,result_pl.init_fit)
plt.title("")
plt.legend("")
plt.xlabel(r"Delay ${\tau}$ (ns)")
plt.ylabel("$S_{11}$ (arb. u.)")
plt.xlim(0, 1000)
# plt.savefig('ge_ramsey.png', bbox_inches='tight')

plt.show()

# %%
plt.plot(x_mi, y_mi)
plt.show()

# %%
par_ini_mi = {
    'amp': 10,
    'phi0':np.pi,
    'detun':1/200,
    'const':0.1
}

par_min_mi = {
    'amp': 0,
    'phi0':-2*np.pi,
    'detun':-np.inf,
    'const':0
}

par_max_mi = {
    'amp': np.inf,
    'phi0':2*np.pi,
    'detun':np.inf,
    'const':np.inf,
}

par_vary_mi = {
    'amp': True,
    'phi0':True,
    'detun':True,
    'const':True
}

# %%
model = lmfit.Model(Rabi)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini_mi[name],
    min = par_min_mi[name],
    max = par_max_mi[name],
    vary = par_vary_mi[name]
    )
    
result_mi = model.fit(data = y_mi, params = params, delay = x_mi)
result_mi
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>88</td><td></td></tr><tr><td># data points</td><td>51</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 20.5316617</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.43684387</td><td></td></tr><tr><td>Akaike info crit.</td><td>-38.4027308</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-30.6754283</td><td></td></tr><tr><td>R-squared</td><td> 0.98798193</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  8.07530066 </td><td>  0.13004736 </td><td> (1.61%) </td><td> 10 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  2.88917011 </td><td>  0.03326329 </td><td> (1.15%) </td><td> 3.141592653589793 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  0.00498985 </td><td>  9.0909e-06 </td><td> (0.18%) </td><td> 0.005 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  8.8427e-10 </td><td>  0.05852483 </td><td> (6618459757.76%) </td><td> 0.1 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>-0.8712</td></tr><tr><td>detun</td><td>const</td><td>+0.1442</td></tr><tr><td>phi0</td><td>const</td><td>-0.1219</td></tr></table>

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(-5MHz)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result_mi.plot_fit(ax = ax)
plt.plot(x_mi,result_mi.init_fit)

plt.xlabel("delay (ns)")
plt.ylabel("mag[S11](a.u.)")


plt.show()

# %%
detun = ((0.005-0.00501392)+ (0.00498985-0.005))/2 #GHz
detun
# Out:
# -1.2035000000000084e-05

# %% [markdown]
# drag

# %%
drag = "/2024-06-18/2024-06-18T112805_6510b935-22_ge_pi_drag" # n=7
dd_drag = datadict_from_hdf5(header + drag +"/data")

drag1 = "/2024-06-18/2024-06-18T112855_825580c4-22_ge_pi_drag" # n=13
dd_drag1 = datadict_from_hdf5(header + drag1 +"/data")

drag2 = "/2024-06-18/2024-06-18T112945_a01b1892-22_ge_pi_drag" # n=17
dd_drag2 = datadict_from_hdf5(header + drag2 +"/data")

# %%
Rabi_drag = dd_drag['s11']['values']
imag_drag = Rabi_drag.imag
drag = dd_drag['beta']['values']
I_drag = (Rabi_drag.real)
Q_drag = (Rabi_drag.imag)

Rabi_drag1 = dd_drag1['s11']['values']
imag_drag1 = Rabi_drag1.imag
drag1 = dd_drag1['beta']['values']
I_drag1 = (Rabi_drag1.real)
Q_drag1 = (Rabi_drag1.imag)

Rabi_drag2 = dd_drag2['s11']['values']
imag_drag2 = Rabi_drag2.imag
drag2 = dd_drag2['beta']['values']
I_drag2 = (Rabi_drag2.real)
Q_drag2 = (Rabi_drag2.imag)

# %%
def PCA_transform1(Re_c_amp, Im_c_amp, Re_c_drag, Im_c_drag):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c_amp]).T, np.array([Im_c_amp]).T], axis = 1)
    c1_data = np.concatenate([np.array([Re_c_drag]).T, np.array([Im_c_drag]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    
    c1_pca = pca.transform(c1_data)
    c1_PCA1 = c1_pca.T[0]
    c1_PCA2 = c1_pca.T[1]
    return c_PCA1, c_PCA2, c1_PCA1, c1_PCA2,

# %%
PCA_drag = PCA_transform1(I_drag, Q_drag, I_drag, Q_drag)
y = PCA_drag[0]
x = amp
y0 = PCA_drag[2]
x0 = drag

PCA_drag1 = PCA_transform1(I_drag, Q_drag, I_drag1, Q_drag1)
y1 = PCA_drag1[2]
x1 = drag1

PCA_drag2 = PCA_transform1(I_drag, Q_drag, I_drag2, Q_drag2)
y2 = PCA_drag2[2]
x2 = drag2

# %%
plt.plot(x0, y0)
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.show()

# %%
par_ini= {
    'amp': 0.00025,
    'phi0':0,
    'detun':1/1.6,
    'const':0.,
}

par_min = {
    'amp': 0,
    'phi0':-2*np.pi,
    'detun':-np.inf,
    'const':-np.pi
}

par_max = {
    'amp': np.inf,
    'phi0':2*np.pi,
    'detun':np.inf,
    'const':np.inf,
}

par_vary = {
    'amp': True,
    'phi0':True,
    'detun':True,
    'const':True
}

# %%
model = lmfit.Model(Rabi)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )
    
result0 = model.fit(data = y0, params = params, delay = x0)
result1 = model.fit(data = y1, params = params, delay = x1)
result2 = model.fit(data = y2, params = params, delay = x2)

# %%
result0
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>37</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 6.0115e-08</td><td></td></tr><tr><td>reduced chi-square</td><td> 6.1974e-10</td><td></td></tr><tr><td>Akaike info crit.</td><td>-2137.45511</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-2126.99463</td><td></td></tr><tr><td>R-squared</td><td> 0.98681697</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  3.2181e-04 </td><td>  7.0009e-06 </td><td> (2.18%) </td><td> 0.00025 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td> -0.00212873 </td><td>  0.01032475 </td><td> (485.02%) </td><td> 0 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  0.29453393 </td><td>  0.00665813 </td><td> (2.26%) </td><td> 0.625 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  3.8058e-05 </td><td>  8.7898e-06 </td><td> (23.10%) </td><td> 0.0 </td><td> -3.14159265 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>detun</td><td>const</td><td>-0.9581</td></tr><tr><td>amp</td><td>detun</td><td>-0.8420</td></tr><tr><td>amp</td><td>const</td><td>+0.8342</td></tr></table>

# %%
res0 = (0.00212873)/(2*np.pi*0.29453393)
res0
# Out:
# 0.001150284797435767

# %%
result1
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>41</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 5.2795e-07</td><td></td></tr><tr><td>reduced chi-square</td><td> 5.4427e-09</td><td></td></tr><tr><td>Akaike info crit.</td><td>-1918.00880</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-1907.54831</td><td></td></tr><tr><td>R-squared</td><td> 0.88111394</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  2.9690e-04 </td><td>  1.1120e-05 </td><td> (3.75%) </td><td> 0.00025 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  0.07976771 </td><td>  0.03424904 </td><td> (42.94%) </td><td> 0 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  0.51862494 </td><td>  0.00598725 </td><td> (1.15%) </td><td> 0.625 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  2.6882e-05 </td><td>  7.7588e-06 </td><td> (28.86%) </td><td> 0.0 </td><td> -3.14159265 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>amp</td><td>const</td><td>-0.2657</td></tr><tr><td>detun</td><td>const</td><td>+0.1588</td></tr></table>

# %%
res1 = (-0.07976771)/(2*np.pi*0.51862494)
res1
# Out:
# -0.024479010488043268

# %%
result2
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>26</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 3.8766e-07</td><td></td></tr><tr><td>reduced chi-square</td><td> 3.9965e-09</td><td></td></tr><tr><td>Akaike info crit.</td><td>-1949.20429</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-1938.74381</td><td></td></tr><tr><td>R-squared</td><td> 0.92966040</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  3.2253e-04 </td><td>  9.1334e-06 </td><td> (2.83%) </td><td> 0.00025 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  0.03686514 </td><td>  0.02726379 </td><td> (73.96%) </td><td> 0 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  0.64464062 </td><td>  0.00546129 </td><td> (0.85%) </td><td> 0.625 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  4.4483e-05 </td><td>  6.8904e-06 </td><td> (15.49%) </td><td> 0.0 </td><td> -3.14159265 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>detun</td><td>const</td><td>+0.4069</td></tr><tr><td>amp</td><td>detun</td><td>-0.1652</td></tr></table>

# %%
res2 = (0.03686514)/(2*np.pi*0.64464062	)
res2
# Out:
# 0.009101612707518731

# %%
beta = (res0 + res1 + res2)/3
beta
# Out:
# -0.004742370994362923

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(drag)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result0.plot_fit(ax = ax)
plt.plot(x0,result0.init_fit)


plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(drag)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result1.plot_fit(ax = ax)
plt.plot(x1,result1.init_fit)


plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(drag)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result2.plot_fit(ax = ax)

plt.plot(x2,result2.init_fit)


plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,6),constrained_layout=True)
plt.rcParams["font.size"] = 20
plt.tick_params(top='on',bottom='on',left='on',right='on',)
plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'

plt.plot(x0, y0*1e3, 'o', label="n=5")
plt.plot(x0, y1*1e3, 'o', label="n=11")
plt.plot(x0, y2*1e3, 'o', label="n=13")
plt.plot(x0, (1.7083e-5-1.1027e-4*np.cos(2*np.pi*0.63526460*x0+4.07498125))*1e3, color='blue')
plt.plot(x0, (2.0782e-5-1.0850e-4*np.cos(2*np.pi*1.43345157*x0-0.13875923))*1e3, color='orange')
plt.plot(x0, (2.1621e-5-1.0893e-4*np.cos(2*np.pi*1.68136672*x0-3.48994880))*1e3, color='green')
plt.vlines(2.129117898677454, -0.12, 0.15, color='r', linestyles='dotted')
plt.ylim(-0.12, 0.15)
plt.xlim(0.5, 2.5)

plt.title("")
plt.legend(title_fontsize=18, fontsize=18, loc='upper right', bbox_to_anchor=(1.35, 1))
plt.xlabel(r"DRAG coefficient ${\beta}$")
plt.ylabel("$S_{11}$ (arb. u.)")
# plt.savefig('drag_ge_pi.png', bbox_inches='tight')

plt.show()

# %% [markdown]
# half drag

# %%
drag = "/2024-06-18/2024-06-18T113156_ee59315b-22_ge_pi_drag" # n=7
dd_drag = datadict_from_hdf5(header + drag +"/data")

drag1 = "/2024-06-18/2024-06-18T113248_0d8be0fd-22_ge_pi_drag" # n=13
dd_drag1 = datadict_from_hdf5(header + drag1 +"/data")

drag2 = "/2024-06-18/2024-06-18T113346_2feeb99e-22_ge_pi_drag" # n=17
dd_drag2 = datadict_from_hdf5(header + drag2 +"/data")

# %%
Rabi_drag = dd_drag['s11']['values']
imag_drag = Rabi_drag.imag
drag = dd_drag['beta']['values']
I_drag = (Rabi_drag.real)
Q_drag = (Rabi_drag.imag)

Rabi_drag1 = dd_drag1['s11']['values']
imag_drag1 = Rabi_drag1.imag
drag1 = dd_drag1['beta']['values']
I_drag1 = (Rabi_drag1.real)
Q_drag1 = (Rabi_drag1.imag)

Rabi_drag2 = dd_drag2['s11']['values']
imag_drag2 = Rabi_drag2.imag
drag2 = dd_drag2['beta']['values']
I_drag2 = (Rabi_drag2.real)
Q_drag2 = (Rabi_drag2.imag)

# %%
def PCA_transform1(Re_c_amp, Im_c_amp, Re_c_drag, Im_c_drag):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c_amp]).T, np.array([Im_c_amp]).T], axis = 1)
    c1_data = np.concatenate([np.array([Re_c_drag]).T, np.array([Im_c_drag]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    
    c1_pca = pca.transform(c1_data)
    c1_PCA1 = c1_pca.T[0]
    c1_PCA2 = c1_pca.T[1]
    return c_PCA1, c_PCA2, c1_PCA1, c1_PCA2,

# %%
PCA_drag = PCA_transform1(I_drag, Q_drag, I_drag, Q_drag)
y = PCA_drag[0]
x = amp
y0 = PCA_drag[2]
x0 = drag

PCA_drag1 = PCA_transform1(I_drag, Q_drag, I_drag1, Q_drag1)
y1 = PCA_drag1[2]
x1 = drag1

PCA_drag2 = PCA_transform1(I_drag, Q_drag, I_drag2, Q_drag2)
y2 = PCA_drag2[2]
x2 = drag2

# %%
plt.plot(x0, y0)
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.show()

# %%
par_ini= {
    'amp': 5e-4,
    'phi0':0,
    'detun':1/0.6,
    'const':0.0
}
par_min = {
    'amp': 0,
    'phi0':-2*np.pi,
    'detun':-np.inf,
    'const':-np.inf
}
par_max = {
    'amp': np.inf,
    'phi0':2*np.pi,
    'detun':np.inf,
    'const':np.inf,
}
par_vary = {
    'amp': True,
    'phi0':True,
    'detun':True,
    'const':True
}

# %%
model = lmfit.Model(Rabi)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )
    
result0 = model.fit(data = y0, params = params, delay = x0)
result1 = model.fit(data = y1, params = params, delay = x1)
result2 = model.fit(data = y2, params = params, delay = x2)

# %%
result0
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>56</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 1.1979e-07</td><td></td></tr><tr><td>reduced chi-square</td><td> 1.2350e-09</td><td></td></tr><tr><td>Akaike info crit.</td><td>-2067.81390</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-2057.35342</td><td></td></tr><tr><td>R-squared</td><td> 0.99414785</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  6.5690e-04 </td><td>  5.1227e-06 </td><td> (0.78%) </td><td> 0.0005 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  0.14573222 </td><td>  0.00737977 </td><td> (5.06%) </td><td> 0 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  0.86691509 </td><td>  0.00129731 </td><td> (0.15%) </td><td> 0.5 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  7.2678e-05 </td><td>  3.5733e-06 </td><td> (4.92%) </td><td> 0.0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>amp</td><td>const</td><td>+0.1532</td></tr><tr><td>detun</td><td>const</td><td>-0.1289</td></tr></table>

# %%
res0 = (-0.14573222)/(2*np.pi*0.86691509)
res0
# Out:
# -0.02675464234998559

# %%
result1
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>36</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 3.3433e-07</td><td></td></tr><tr><td>reduced chi-square</td><td> 3.4467e-09</td><td></td></tr><tr><td>Akaike info crit.</td><td>-1964.15075</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-1953.69027</td><td></td></tr><tr><td>R-squared</td><td> 0.98203877</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  6.0906e-04 </td><td>  8.3704e-06 </td><td> (1.37%) </td><td> 0.0005 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  0.23542921 </td><td>  0.01341654 </td><td> (5.70%) </td><td> 0 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  1.60422086 </td><td>  0.00241903 </td><td> (0.15%) </td><td> 1.6666666666666667 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  8.7925e-05 </td><td>  5.9074e-06 </td><td> (6.72%) </td><td> 0.0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>detun</td><td>const</td><td>-0.1433</td></tr></table>

# %%
res1 = (-0.23542921)/(2*np.pi*1.60422086)
res1
# Out:
# -0.023356960038357733

# %%
result2
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>58</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 5.6574e-07</td><td></td></tr><tr><td>reduced chi-square</td><td> 5.8324e-09</td><td></td></tr><tr><td>Akaike info crit.</td><td>-1911.02556</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-1900.56508</td><td></td></tr><tr><td>R-squared</td><td> 0.97195244</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  6.2012e-04 </td><td>  1.0701e-05 </td><td> (1.73%) </td><td> 0.0005 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  0.35550293 </td><td>  0.01745698 </td><td> (4.91%) </td><td> 0 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  2.10534970 </td><td>  0.00321959 </td><td> (0.15%) </td><td> 1.6666666666666667 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  7.5912e-05 </td><td>  7.6216e-06 </td><td> (10.04%) </td><td> 0.0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table>

# %%
res2 = (-0.35550293)/(2*np.pi*2.10534970)
res2
# Out:
# -0.026874418341595246

# %%
beta = (res0 + res1 + res2)/3
beta
# Out:
# -0.025662006909979523

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(drag)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result0.plot_fit(ax = ax)
plt.plot(x0,result0.init_fit)


plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(drag)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result1.plot_fit(ax = ax)
plt.plot(x1,result1.init_fit)


plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(drag)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result2.plot_fit(ax = ax)

plt.plot(x2,result2.init_fit)


plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,6),constrained_layout=True)
plt.rcParams["font.size"] = 20
plt.tick_params(top='on',bottom='on',left='on',right='on',)
plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'

plt.plot(x0, y0*1e3, 'o', label="n=11")
plt.plot(x0, y1*1e3, 'o', label="n=17")
plt.plot(x0, y2*1e3, 'o', label="n=23")
plt.plot(x0, (1.2144e-5-5.5709e-5*np.cos(2*np.pi*0.47743047*x0+4.95160969))*1e3, color='blue')
plt.plot(x0, (1.5352e-5-5.2466e-5*np.cos(2*np.pi*0.70875990*x0+1.18869153))*1e3, color='orange')
plt.plot(x0, (1.8510e-5-4.8021e-5*np.cos(2*np.pi*0.97589009*x0-3.01057149))*1e3, color='green')
plt.vlines(2.5445789598717314, -0.07, 0.1, color='r', linestyles='dotted')
plt.ylim(-0.07, 0.1)
plt.xlim(1.5, 3)

plt.title("")
plt.legend(title_fontsize=18, fontsize=18, loc='upper right', bbox_to_anchor=(1.35, 1))
plt.xlabel(r"DRAG coefficient ${\beta}$")
plt.ylabel("$S_{11}$ (arb. u.)")
# plt.savefig('drag_ge_half_pi.png', bbox_inches='tight')

plt.show()

# %% [markdown]
# T1

# %%
def Dephase(delay, amp, gamma, const):
    return amp*np.exp(-gamma*delay) + const

t1 ="/2024-07-12/2024-07-12T171407_b5abdd50-24_ge_T1"

dd_t1 = datadict_from_hdf5(header + t1 +"/data")

# %%
s11_t1 = dd_t1['s11']['values'][0:180]
phase_t1 = s11_t1.imag
delay_t1 = dd_t1['delay']['values'][0:180]

I_t1 = (s11_t1.real)
Q_t1 = (s11_t1.imag)
ang_t1 = np.angle(s11_t1)

PCA_t1 = PCA_transform(I_t1, Q_t1)

y_t1 = PCA_t1[0]
x_t1 = delay_t1

fig, (ax1) = plt.subplots(nrows=1)
ax1.set_xlabel('Delay (ns)', size='large')
ax1.set_ylabel('PCA[S$_{11}$] (arb. unit.)', size='large')
plt.rcParams["font.size"] = 10
ax1.tick_params(axis="x", direction="in")
ax1.tick_params(axis="y", direction="in")
# ax1.set_xlim(0, 250000)
# ax1.set_ylim(-48, 160)
plt.tick_params(
            top='on',
            bottom='on`',
            left='on',
            right='on',
            )

plt.plot(x_t1, -ang_t1)
plt.show()

# %%
par_ini_t1 = {
    'gamma': 1/40000e-3,
    'amp':0.25,
    'const':2.8
}

par_min_t1 = {
    'gamma': 0,
    'amp':0,
    'const':-np.inf
}

par_max_t1 = {
    'gamma': np.inf,
    'amp':np.inf,
    'const':np.inf,
}

par_vary_t1 = {
    'gamma': True,
    'amp':True,
    'const':True
}

# %%
model = lmfit.Model(Dephase)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini_t1[name],
    min = par_min_t1[name],
    max = par_max_t1[name],
    vary = par_vary_t1[name]
    )
result_t1 = model.fit(data = -ang_t1, params = params, delay = x_t1*1e-3)
result_t1
# Out:
# <h2> Model</h2> Model(Dephase) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>21</td><td></td></tr><tr><td># data points</td><td>180</td><td></td></tr><tr><td># variables</td><td>3</td><td></td></tr><tr><td>chi-square</td><td> 0.00436643</td><td></td></tr><tr><td>reduced chi-square</td><td> 2.4669e-05</td><td></td></tr><tr><td>Akaike info crit.</td><td>-1906.81808</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-1897.23921</td><td></td></tr><tr><td>R-squared</td><td> 0.99546376</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  0.28374706 </td><td>  0.00148144 </td><td> (0.52%) </td><td> 0.25 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> gamma </td><td>  0.04464632 </td><td>  5.9329e-04 </td><td> (1.33%) </td><td> 0.025 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td> -0.28274711 </td><td>  9.2268e-04 </td><td> (0.33%) </td><td> 2.8 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>gamma</td><td>const</td><td>+0.8309</td></tr><tr><td>amp</td><td>gamma</td><td>+0.2357</td></tr><tr><td>amp</td><td>const</td><td>-0.1790</td></tr></table>

# %%
fig, ax = plt.subplots(figsize=(8,6),constrained_layout=True)
plt.rcParams["font.size"] = 20

plt.tick_params(top='on',bottom='on',left='on',right='on',)

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'

result_t1.plot_fit(ax = ax)
# plt.plot(x_t1,result_t1.init_fit, label='init fit')

# ax.set_ylim(-8, 15)
plt.title("")
plt.legend("")
ax.set_xlabel(r'Delay $\tau$ ($\mu$s)')#, size='large')
ax.set_ylabel('S$_{11}$ (arb. u.)')
plt.xlim(0, 90)
# plt.savefig('ge_T1.png', bbox_inches='tight')
plt.show()

# %%
T1 = (1/0.04464632)*1e-9	
T1
# Out:
# 2.2398262611565746e-08

# %% [markdown]
# T2_echo

# %%
t2e = "/2024-07-12/2024-07-12T172004_8a5e7c7f-25_ge_T2e"
dd_t2e = datadict_from_hdf5(header + t2e +"/data")

# %%
s11_t2e = dd_t2e['s11']['values']
imag_t2e = s11_t2e.imag
delay_t2e = dd_t2e['delay']['values']

I_t2e = (s11_t2e.real)
Q_t2e = (s11_t2e.imag)

PCA_t2e = PCA_transform(I_t2e, Q_t2e)

y_t2e = PCA_t2e[0]
x_t2e = delay_t2e

plt.plot(x_t2e, y_t2e)
plt.show()

# %%
par_ini_t2e = {
    'gamma': 1/5000e-3,
    'amp':10,
    'const':-2
}

par_min_t2e = {
    'gamma': 0,
    'amp':0,
    'const':-np.inf
}

par_max_t2e = {
    'gamma': np.inf,
    'amp':np.inf,
    'const':np.inf,
}

par_vary_t2e = {
    'gamma': True,
    'amp':True,
    'const':True
}

# %%
model = lmfit.Model(Dephase)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini_t2e[name],
    min = par_min_t2e[name],
    max = par_max_t2e[name],
    vary = par_vary_t2e[name]
    )
result_t2e = model.fit(data = y_t2e, params = params, delay = x_t2e*1e-3)
result_t2e
# Out:
# <h2> Model</h2> Model(Dephase) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>17</td><td></td></tr><tr><td># data points</td><td>51</td><td></td></tr><tr><td># variables</td><td>3</td><td></td></tr><tr><td>chi-square</td><td> 5.32462137</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.11092961</td><td></td></tr><tr><td>Akaike info crit.</td><td>-109.233685</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-103.438209</td><td></td></tr><tr><td>R-squared</td><td> 0.98453888</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  10.0406404 </td><td>  0.19398426 </td><td> (1.93%) </td><td> 10 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> gamma </td><td>  0.25340313 </td><td>  0.01078825 </td><td> (4.26%) </td><td> 0.2 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td> -2.03079661 </td><td>  0.08862665 </td><td> (4.36%) </td><td> -2 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>gamma</td><td>const</td><td>+0.7425</td></tr><tr><td>amp</td><td>gamma</td><td>+0.3514</td></tr><tr><td>amp</td><td>const</td><td>-0.1271</td></tr></table>

# %%
fig, ax = plt.subplots(figsize=(8,6),constrained_layout=True)
plt.rcParams["font.size"] = 20

plt.tick_params(top='on',bottom='on',left='on',right='on',)

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result_t2e.plot_fit(ax = ax)
# plt.plot(delay_t2e,result_t2e.init_fit)

# ax.set_ylim(-10, 35)

plt.title("")
plt.legend("")
ax.set_xlabel(r'Delay $\tau$ ($\mu$s)')
ax.set_ylabel('S$_{11}$ (arb. u.)')
plt.xlim(0, 20)
# plt.savefig('ge_T2e.png', bbox_inches='tight')
plt.show()

# %%
T2 = (1/0.25340313)*1e-6
T2
# Out:
# 3.946281168665912e-06

# %% [markdown]
# T2 star

# %%
def Damping(delay, amp, gamma, omega, phi0, const):
    return const + amp * np.exp(- gamma*delay)*np.cos(omega*delay + phi0)

# %%
t2 = "/2024-07-12/2024-07-12T172329_049c1878-23_ge_T2r1d"
dd_t2 = datadict_from_hdf5(header + t2 +"/data")

# %%
s11_t2 = dd_t2['s11']['values']
imag_t2 = s11_t2.imag
delay_t2 = dd_t2['delay']['values']

I_t2 = (s11_t2.real)
Q_t2 = (s11_t2.imag)

PCA_t2 = PCA_transform(I_t2, Q_t2)

y_t2 = PCA_t2[0]
x_t2 = delay_t2

plt.plot(x_t2, y_t2)
plt.show()

# %%
par_ini_t2 = {
    'amp':7,
    'gamma': 1/3000e-3,
    'omega':2*np.pi/700e-3,
    'phi0':0,
    'const':0
}

par_min_t2 = {
    'amp':-np.inf,
    'gamma': 0,
    'omega':-2*np.pi,
    'phi0':-2*np.pi,
    'const':-np.inf
}

par_max_t2 = {
    'amp':np.inf,
    'gamma': np.inf,
    'omega':np.inf,
    'phi0':2*np.pi,
    'const':np.inf
}

par_vary_t2 = {
    'amp':True,
    'gamma': True,
    'omega':True,
    'phi0':True,
    'const':True
}

# %%
model = lmfit.Model(Damping)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini_t2[name],
    min = par_min_t2[name],
    max = par_max_t2[name],
    vary = par_vary_t2[name]
    )
result_t2 = model.fit(data = y_t2, params = params, delay = x_t2*1e-3)
result_t2
# Out:
# <h2> Model</h2> Model(Damping) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>94</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>5</td><td></td></tr><tr><td>chi-square</td><td> 22.7687945</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.23717494</td><td></td></tr><tr><td>Akaike info crit.</td><td>-140.462688</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-127.387085</td><td></td></tr><tr><td>R-squared</td><td> 0.96985504</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td> -10.2019827 </td><td>  0.26295282 </td><td> (2.58%) </td><td> 7 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> gamma </td><td>  0.35390803 </td><td>  0.01302778 </td><td> (3.68%) </td><td> 0.3333333333333333 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> omega </td><td>  6.14397128 </td><td>  0.01261829 </td><td> (0.21%) </td><td> 8.975979010256552 </td><td> -6.28318531 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  0.65549110 </td><td>  0.02411460 </td><td> (3.68%) </td><td> 0 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> const </td><td> -0.05116654 </td><td>  0.04867167 </td><td> (95.12%) </td><td> 0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>amp</td><td>gamma</td><td>-0.7142</td></tr><tr><td>omega</td><td>phi0</td><td>-0.6918</td></tr><tr><td>amp</td><td>phi0</td><td>-0.1046</td></tr></table>

# %%
fig, ax = plt.subplots(figsize=(8,6),constrained_layout=True)
plt.rcParams["font.size"] = 20

plt.tick_params(top='on',bottom='on',left='on',right='on',)

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result_t2.plot_fit(ax = ax)
# plt.plot(delay_t2*1e-3,result_t2.init_fit)
# ax.set_ylim(-10, 35)
plt.title("")
plt.legend("")
ax.tick_params(axis="x", direction="in")
ax.tick_params(axis="y", direction="in")
ax.set_xlabel(r'Delay $\tau$ ($\mu$s)')
ax.set_ylabel('S$_{11}$ (arb. u.)')
ax.set_xlim(0, 10)
# plt.savefig('ge_T2star.png', bbox_inches='tight')
plt.show()

# %%
T2_star = (1/0.35390803)*1e-6
T2_star
# Out:
# 2.8255928524707394e-06

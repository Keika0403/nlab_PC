# %%
from plottr.data.datadict_storage import datadict_from_hdf5
import numpy as np
import matplotlib.pyplot as plt
import lmfit
import scipy.constants as spc

# %%
res_dressed = "/2024-07-30/2024-07-30T101156_b6fb088a-10_spectrum"
# punchout =  "/2024-07-12/2024-07-12T163402_1c9bb492-cw_punchout"  # R.T.: -30dB, vna output: -20 ~ 20dB

# %%
header = "D:/K_sunada/result/CDY163/"
dd_d = datadict_from_hdf5(header + res_dressed +"/data")

freq_d = dd_d['frequency']['values']
s11_d = dd_d['s11']['values']
# freq_b = dd_b['frequency']['values']
# s11_b = dd_b['s21']['values']

fig,ax = plt.subplots(1,2)
ax[0].plot(freq_d,np.abs(s11_d))
ax[1].plot(freq_d,np.angle(s11_d))

# %% [markdown]
# double pole

# %%
def S11_dpr_model(freq, fr, ff, kf_e, kf_i, gamma, g, a0, a1, Poff,ed):
    numer = (1j*(freq-ff)+(kf_e-kf_i)/2)*(1j*(freq-fr)-gamma/2) + (g**2)
    denom = (1j*(freq-ff)-(kf_e+kf_i)/2)*(1j*(freq-fr)-gamma/2) + (g**2)
    model = (numer/denom * (a0+a1*(freq-freq[0])) * np.exp(1j*(Poff-ed*2*np.pi*(freq-freq[0])))).conj()
    return model

par_ini = {'fr': 10.4e9,  'ff': 10.38e9,    'kf_e': 180e6,   'kf_i': 0.e6,  'g': 14e6, 'gamma': 0.e6,
           'a0': 270,  'a1': -3.9765e-08	,        'Poff': -42472,   'ed': 6e-12}
par_min = {'fr': 0,     'ff': 0,        'kf_e': 0,        'kf_i': 0,        'g': 0,     'gamma': 0,
           'a0': -np.inf,     'a1': -np.inf,  'Poff': -np.inf,'ed': -np.inf}
par_max = {'fr': np.inf,'ff': np.inf,   'kf_e': np.inf,   'kf_i': np.inf,   'g': np.inf,'gamma': np.inf,
           'a0': np.inf,'a1': np.inf,   'Poff': np.inf, 'ed': np.inf}
par_var = {'fr': True, 'ff': True,    'kf_e': True,    'kf_i': False,    'g': True, 'gamma': False,
           'a0': True, 'a1': True,    'Poff': True,  'ed': True}

model=lmfit.Model(S11_dpr_model)
params = model.make_params()

for name in list(par_ini):
    params[name].set(value=par_ini[name])
for name in list(par_min):
    params[name].set(min=par_min[name])  
for name in list(par_max):
    params[name].set(max=par_max[name]) 
for name in list(par_var):
    params[name].set(vary=par_var[name])
    
result_d = model.fit(freq=freq_d, data=s11_d, params=params, method='leastsq')
# result_b = model.fit(freq=freq_b, data=s11_b, params=params, method='leastsq')

# %% [markdown]
# one pole

# %%
def resonator(freq, fc, ke, ki, a0, a1, Poff, ed):
    numer = 1j*(freq-fc)+(ke-ki)/2
    denom = 1j*(freq-fc)-(ke+ki)/2
    return (numer/denom * (a0+a1*(freq-freq[0])) * np.exp(1j*(-Poff-ed*2*np.pi*freq))).conj()
    
par_ini = {'fc':9.37e9, 'ke':50e6, 'ki':1e6, 'a0':382, 'a1':-7.0880e-08, 'Poff':-42512, 'ed':8.5089e-10}
par_min = {'fc':0, 'ke':0, 'ki':0, 'a0':-np.inf, 'a1':-np.inf, 'Poff':-np.inf, 'ed':-np.inf}
par_max = {'fc':np.inf, 'ke':np.inf, 'ki':np.inf, 'a0':np.inf, 'a1':np.inf, 'Poff':np.inf, 'ed':np.inf}
par_var = {'fc':True, 'ke':True, 'ki':True, 'a0':True, 'a1':True, 'Poff':True, 'ed':True}
model=lmfit.Model(resonator)
params = model.make_params()

for name in list(par_ini):
    params[name].set(value=par_ini[name])
for name in list(par_min):
    params[name].set(min=par_min[name])  
for name in list(par_max):
    params[name].set(max=par_max[name]) 
for name in list(par_var):
    params[name].set(vary=par_var[name])
    
result_d = model.fit(freq=freq_d, data=s11_d, params=params, method='leastsq')

# %% [markdown]
# plot

# %%
fig, ax = plt.subplots(1, 2, figsize=(12,6))#,constrained_layout=True)
plt.rcParams["font.size"] = 20
plt.subplots_adjust(wspace=0.3)
plt.tick_params(pad = 10, top='on',bottom='on',left='on',right='on',)
ax[0].set_aspect("equal", adjustable="box")
ax[0].set_xlabel('Re[S$_{11}$] (arb. u.) ')
ax[0].set_ylabel('Im[S$_{11}$] (arb. u.) ')
ax[0].tick_params(axis="x", direction="in")
ax[0].tick_params(axis="y", direction="in")
ax[0].plot(np.real(s11_d)*1e2,np.imag(s11_d)*1e2, ls='', marker='o')
ax[0].plot(np.real(result_d.best_fit)*1e2,np.imag(result_d.best_fit)*1e2)
ax[0].plot(np.real(result_d.init_fit)*1e2,np.imag(result_d.init_fit)*1e2, color='green', ls='--', )
# plt.xticks([-0.6, -0.4, 0.2, 0, 0.2, 0.4, 0.6])
# ax[0].set_ylim(-0.7, 0.7)
# ax[0].set_xlim(-0.7, 0.7)


ax[1].set_xlabel('Probe frequency $\omega_\mathrm{p}/2\pi$ (GHz)')
ax[1].set_ylabel('Phase[S$_{11}$] (rad) ')
ax[1].tick_params(axis="x", direction="in")
ax[1].tick_params(axis="y", direction="in")
ax[1].set_xlim(9.36, 9.38)
ax[1].set_ylim(1, np.pi)
# ax[1].set_aspect("equal", adjustable="box")
ax[1].plot(freq_d*1e-9,np.angle(s11_d), ls='', marker='o')
ax[1].plot(freq_d*1e-9,np.angle(result_d.best_fit))
ax[1].plot(freq_d*1e-9,np.angle(result_d.init_fit), color='green', ls='--', )

result_d
# plt.savefig('dressed_res.png', bbox_inches='tight')
# plt.show()
# Out:
# <h2> Model</h2> Model(resonator) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>16000</td><td></td></tr><tr><td># data points</td><td>402</td><td></td></tr><tr><td># variables</td><td>7</td><td></td></tr><tr><td>chi-square</td><td> 539798.327</td><td></td></tr><tr><td>reduced chi-square</td><td> 1366.57804</td><td></td></tr><tr><td>Akaike info crit.</td><td> 2909.40451</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 2937.37968</td><td></td></tr><tr><td>R-squared</td><td>-5.3980e+20</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> fc </td><td>  9.3810e+09 </td><td> 9370000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> ke </td><td>  3.6647e+08 </td><td> 50000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> ki </td><td>  3.3448e+08 </td><td> 1000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> a0 </td><td>  1795.50967 </td><td> 382 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> a1 </td><td>  3.7022e-05 </td><td> -7.088e-08 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> Poff </td><td> -42519.7917 </td><td> -42512 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> ed </td><td>  8.8690e-10 </td><td> 8.5089e-10 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table>

# %%
fig, ax = plt.subplots(1,2,figsize=(12,6),constrained_layout=True)
ax[0].set_xlabel('Frequency(GHz)',fontsize=18)
ax[0].set_ylabel('Re[$S_{11}]$', fontsize=18)
ax[1].set_xlabel('Frequency(GHz)',fontsize=16)
ax[1].set_ylabel('Im[$S_{11}]$', fontsize=16)
# ax.tick_params(direction='in')

ax[0].plot(freq_d,np.real(s11_d), ls='', marker='.')
ax[0].plot(freq_d,np.real(result_d.best_fit), color='orange')
ax[0].plot(freq_d,np.real(result_d.init_fit), color='green', ls='--', marker='')
ax[1].plot(freq_d,np.imag(s11_d), ls='', marker='.')
ax[1].plot(freq_d,np.imag(result_d.best_fit), color='orange')

# %% [markdown]
# punchout

# %%
dd = datadict_from_hdf5(header + punchout +"/data")
dd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 dd = datadict_from_hdf5(header + punchout +"/data")
#       2 dd
#
# NameError: name 'punchout' is not defined

# %%
dd = datadict_from_hdf5(header + punchout +"/data")
x = np.unique(dd['power']['values'])
y = np.unique(dd['frequency']['values'])
z = dd['s11']['values']

# %%
cm = plt.cm.get_cmap('magma')
fig= plt.figure()
plt.rcParams["font.size"] = 20
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'

ax = fig.add_axes((0.1, 0.1, 0.9, 0.9))
ax.set_xlabel("VNA power $P_{\mathrm{VNA}}$ (dBm)")
ax.set_ylabel("Probe frequency $\omega_\mathrm{p}/2\pi$ (GHz)")
ax.set_xlim(-20, 20)
# ax.set_ylim(9, 10.)

maingraph = ax.pcolormesh(x,y*1e-9, np.real(z).reshape(20, 201).T, vmin=min(np.unique(np.real(z))), vmax=max(np.unique(np.real(z))), cmap=cm, shading='auto')


plt.tick_params(pad=10, top='on',bottom='on',left='on',right='on')
# plt.savefig('punchout.png', bbox_inches='tight')
plt.show()
# Out:
# C:\Users\qipe\AppData\Local\Temp\ipykernel_8428\1458322726.py:1: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cm = plt.cm.get_cmap('magma')

# %% [markdown]
# # frequency optimization

# %%
import sklearn
from sklearn.decomposition import PCA

# %%
def PCA_transform(Re_c, Im_c):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c]).T, np.array([Im_c]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    return c_PCA1, c_PCA2

# %%
def Lorentzian(freq, amp, const, center, k):
    return const + amp*k**2/((freq-center)**2 + k**2)

# %%
data = "/2024-08-01/2024-08-01T094005_986e08c8-26_freq_optimize" # only readout resonator
# data = "/2024-08-02/2024-08-02T135152_efb0551c-26_freq_optimize"
# data = "/2024-08-02/2024-08-02T141309_e8e56937-26_freq_optimize"
dd = datadict_from_hdf5(header + data +"/data")
ed = 0#1e-9/9/(10.25-10)

freq = dd['frequency']['values']
s11_eg = dd['s11_eg']['values']* np.exp(1j*(ed*2*np.pi*freq))
s11_g = dd['s11_g']['values']* np.exp(1j*(ed*2*np.pi*freq))
s11_e = dd['s11_e']['values']* np.exp(1j*(ed*2*np.pi*freq))
s11_eg_div = s11_e / s11_g

I = s11_eg.real
Q = s11_eg.imag
plt.plot(freq, np.abs(s11_eg))
PCAge = PCA_transform(I, Q)

# %% [markdown]
# S11^e-S11^g

# %%
model = lmfit.Model(Lorentzian)

par_ini = {'amp': 30,'const':-30,'center':9.37e9,'k':0.008e9}
par_min = {'amp': 0,'const':-np.inf,'center':0,'k':0}
par_max = {'amp': np.inf,'const':np.inf,'center':np.inf,'k':np.inf}
par_vary = {'amp': True,'const':True,'center':True,'k':True}

params = model.make_params()
for name in model.param_names:
    params[name].set(value = par_ini[name], min = par_min[name], max = par_max[name], vary = par_vary[name])

result = model.fit(data = -np.abs(s11_eg), params = params, freq = freq)
result
# Out:
# <h2> Model</h2> Model(Lorentzian) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>54</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 220.751921</td><td></td></tr><tr><td>reduced chi-square</td><td> 2.27579300</td><td></td></tr><tr><td>Akaike info crit.</td><td> 86.9738216</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 97.4343036</td><td></td></tr><tr><td>R-squared</td><td> 0.96308137</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  27.0753028 </td><td>  0.58569901 </td><td> (2.16%) </td><td> 30 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td> -28.1013606 </td><td>  0.26872557 </td><td> (0.96%) </td><td> -30 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> center </td><td>  9.3691e+09 </td><td>  18815.8361 </td><td> (0.00%) </td><td> 9370000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> k </td><td>  886152.599 </td><td>  36117.2336 </td><td> (4.08%) </td><td> 8000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>const</td><td>k</td><td>-0.6690</td></tr><tr><td>amp</td><td>k</td><td>-0.3911</td></tr><tr><td>amp</td><td>const</td><td>-0.1896</td></tr></table>

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("S11^e-S11^g")
plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result.plot_fit(ax = ax)
plt.xlim(9.365e9, 9.375e9)
plt.ylim(-40, 10)
plt.xlabel("frequency (Hz)")
plt.ylabel("mag[S11](a.u.)")
plt.show()

# %% [markdown]
# S11^e/S11^g

# %%
I = s11_eg_div.real
Q = s11_eg_div.imag
plt.plot(freq, np.angle(s11_eg_div))

# %%
def s11_ge_dp(f, f_r, f_f, k_ex, k_in, chi, g, gamma, phi):
    k_tot = k_ex + k_in
    s11_g = np.cos(phi) + np.exp(1j*phi) * k_ex * (1j*(f-f_r) - gamma/2)/((1j*(f-f_f)-k_tot/2) * (1j*(f-f_r)-gamma/2) + g**2)
    s11_e = np.cos(phi) + np.exp(1j*phi) * k_ex * (1j*(f-(f_r+chi)) - gamma/2)/((1j*(f-f_f)-k_tot/2) * (1j*(f-(f_r+chi))-gamma/2) + g**2)
    return (s11_e/s11_g).conj()
def s11_ge(f, f_r, k_ex, k_in, chi, phi, a0):
    s11_g = np.cos(phi) + np.exp(1j*phi) *(1j*(f-f_r)+(k_ex-k_in)/2)/(1j*(f-f_r)-(k_ex+k_in)/2)
    s11_e = np.cos(phi) + np.exp(1j*phi) *(1j*(f-(f_r+chi))+(k_ex-k_in)/2)/(1j*(f-(f_r+chi))-(k_ex+k_in)/2)
    return (s11_e/s11_g).conj() + a0

def guess_params(data,x):
    par_ini = {"f_r":9.37e9, "k_ex": 0.03e6, "k_in":1e6, "chi":-2e6, "phi":0, "a0":-0.9,}
    par_max = {"f_r":np.inf, "k_ex":np.inf, "k_in":np.inf, "chi":0, "phi":np.pi,"a0":np.inf,}
    par_min = {"f_r":0, "k_ex":0, "k_in":0e-3, "chi":-np.inf,"phi":-np.pi,"a0":-np.inf,}
    par_vary = {"f_r":0,"k_ex":1, "k_in":1, "chi":1, "phi":1, "a0":1,}
    return par_ini,par_max,par_min,par_vary
def guess_params_dp(data,x):
    par_ini = {"f_r":9.368e9, "f_f":9.37e9, "k_ex": 3e6, "k_in":1e6, "chi":-5e6, "g":44499830, "gamma":0, "phi":0,}
    par_max = {"f_r":np.inf, "f_f":np.inf, "k_ex":np.inf, "k_in":np.inf, "chi":0, "g":np.inf, "gamma":np.inf, "phi":np.pi,}
    par_min = {"f_r":0, "f_f":0, "k_ex":0, "k_in":0e-3, "chi":-np.inf, "g":0, "gamma":0, "phi":-np.pi,}
    par_vary = {"f_r":1, "f_f":1, "k_ex":1, "k_in":0, "chi":1, "g":1, "gamma":0, "phi":1}
    return par_ini,par_max,par_min,par_vary

def probe_resonator_fit(data, x):
    import lmfit as lmf
    model = lmf.Model(s11_ge, nan_policy='omit')
    params = model.make_params()
    par_ini,par_max,par_min,par_vary=guess_params(data,x)
    for name in params:
        params[name].set(
            value=par_ini[name],  # ???
            min=par_min[name],  # ???
            max=par_max[name],  # ???
            vary=par_vary[name] # ?????????????
        )
    result=model.fit(data, f=x, params=params, method='leastsq')
    return result
def probe_resonator_fit_dp(data, x):
    import lmfit as lmf
    model = lmf.Model(s11_ge_dp, nan_policy='omit')
    params = model.make_params()
    par_ini,par_max,par_min,par_vary=guess_params_dp(data,x)
    for name in params:
        params[name].set(
            value=par_ini[name],  # ???
            min=par_min[name],  # ???
            max=par_max[name],  # ???
            vary=par_vary[name] # ?????????????
        )
    result=model.fit(data, f=x, params=params, method='leastsq')
    return result

# %%
result = probe_resonator_fit(s11_eg_div, freq)
# result = probe_resonator_fit_dp(s11_eg_div, freq)

fig, ax = plt.subplots(dpi=80)

plt.title("g-e transition")
plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
# result.plot_fit(ax = ax)
plt.plot(freq, np.angle(s11_eg_div), marker='o')
plt.plot(freq, np.angle(result.best_fit))
plt.plot(freq, np.angle(result.init_fit))
plt.xlim(9.365e9, 9.375e9)
plt.ylim(-0.45, 0.25)

plt.xlabel("frequency (Hz)")
plt.ylabel("mag[S11](a.u.)")


plt.show()
result
# Out:
# <h2> Model</h2> Model(s11_ge) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>121</td><td></td></tr><tr><td># data points</td><td>202</td><td></td></tr><tr><td># variables</td><td>5</td><td></td></tr><tr><td>chi-square</td><td> 3.93048003</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.01995168</td><td></td></tr><tr><td>Akaike info crit.</td><td>-785.780239</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-769.238901</td><td></td></tr><tr><td>R-squared</td><td>-3.9305e+15</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> f_r </td><td>  9.3700e+09 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 9370000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> 0 </td></tr><tr><td> k_ex </td><td>  56584.3550 </td><td>  1.9105e+08 </td><td> (337629.68%) </td><td> 30000.0 </td><td>  0.00000000 </td><td>         inf </td><td> 1 </td></tr><tr><td> k_in </td><td>  998933.995 </td><td>  1.9140e+08 </td><td> (19160.17%) </td><td> 1000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> 1 </td></tr><tr><td> chi </td><td> -1413155.00 </td><td>  526328.842 </td><td> (37.24%) </td><td> -2000000.0 </td><td>        -inf </td><td>  0.00000000 </td><td> 1 </td></tr><tr><td> phi </td><td>  0.95540494 </td><td>  4774.10764 </td><td> (499694.68%) </td><td> 0 </td><td> -3.14159265 </td><td>  3.14159265 </td><td> 1 </td></tr><tr><td> a0 </td><td> -0.02749514 </td><td>  0.01412609 </td><td> (51.38%) </td><td> -0.9 </td><td>        -inf </td><td>         inf </td><td> 1 </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>k_ex</td><td>phi</td><td>-1.0000</td></tr><tr><td>k_in</td><td>phi</td><td>+1.0000</td></tr><tr><td>k_ex</td><td>k_in</td><td>-1.0000</td></tr><tr><td>k_in</td><td>chi</td><td>+0.7344</td></tr><tr><td>chi</td><td>phi</td><td>+0.7335</td></tr><tr><td>k_ex</td><td>chi</td><td>-0.7334</td></tr></table>

# %% [markdown]
# Chi fitting

# %% [markdown]
# - one pole

# %%
par_ini = {'fc':9.37e+09,  'ke':53388.7446, 'ki':1340874, 'a0':-116.913492, 'a1':6.9928e-07	, 'Poff':-43391.8335, 'ed':3.5092e-09}
par_min = {'fc':0, 'ke':0, 'ki':0, 'a0':-np.inf, 'a1':-np.inf, 'Poff':-np.inf, 'ed':-np.inf}
par_max = {'fc':np.inf, 'ke':np.inf, 'ki':np.inf, 'a0':np.inf, 'a1':np.inf, 'Poff':np.inf, 'ed':np.inf}
par_var = {'fc':True, 'ke':False, 'ki':False, 'a0':True, 'a1':True, 'Poff':True, 'ed':False}
model=lmfit.Model(resonator)
params = model.make_params()

for name in list(par_ini):
    params[name].set(value=par_ini[name])
for name in list(par_min):
    params[name].set(min=par_min[name])  
for name in list(par_max):
    params[name].set(max=par_max[name]) 
for name in list(par_var):
    params[name].set(vary=par_var[name])
# result_d = model.fit(freq=freq_d, data=s11_d, params=params, method='leastsq')

# %% [markdown]
# - double pole

# %%
par_ini = {'fr': 9.369e9,  'ff': 9.36e9,    'kf_e': 100e6,   'kf_i': 5e6,  'g': 50e6, 'gamma': 0.e6,
           'a0': 300,  'a1': 3.5e-7	,        'Poff': -19575,   'ed': 4.8018e-09}
par_min = {'fr': 0,     'ff': 0,        'kf_e': 0,        'kf_i': 0,        'g': 0,     'gamma': 0,
           'a0': -np.inf,     'a1': -np.inf,  'Poff': -np.inf,'ed': -np.inf}
par_max = {'fr': np.inf,'ff': np.inf,   'kf_e': np.inf,   'kf_i': np.inf,   'g': np.inf,'gamma': np.inf,
           'a0': np.inf,'a1': np.inf,   'Poff': np.inf, 'ed': np.inf}
par_var = {'fr': False, 'ff': True,    'kf_e': True,    'kf_i': True,    'g': True, 'gamma': False,
           'a0': True, 'a1': True,    'Poff': True,  'ed':  True}

model=lmfit.Model(S11_dpr_model)
params = model.make_params()

for name in list(par_ini):
    params[name].set(value=par_ini[name])
for name in list(par_min):
    params[name].set(min=par_min[name])  
for name in list(par_max):
    params[name].set(max=par_max[name]) 
for name in list(par_var):
    params[name].set(vary=par_var[name])

# %%
res = model.fit(data = s11_g, params = params, freq = freq)

fig, ax = plt.subplots(1, 2, figsize=(16,6))#,constrained_layout=True)
plt.rcParams["font.size"] = 20
plt.subplots_adjust(wspace=0.3)
plt.tick_params(pad = 10, top='on',bottom='on',left='on',right='on',)
ax[0].set_aspect("equal", adjustable="box")
ax[0].set_xlabel('Re[S$_{11}$] (arb. u.) ')
ax[0].set_ylabel('Im[S$_{11}$] (arb. u.) ')
ax[0].tick_params(axis="x", direction="in")
ax[0].tick_params(axis="y", direction="in")
ax[0].set_xlim(-200, 200)
ax[0].set_ylim(-200, 200)
ax[0].get_xaxis().set_tick_params(pad=10)

ax[1].set_xlabel('Probe frequency $\omega_\mathrm{p}/2\pi$ (GHz)')
ax[1].set_ylabel('Phase[S$_{11}$] (rad) ')
ax[1].tick_params(axis="x", direction="in")
ax[1].tick_params(axis="y", direction="in")
ax[1].set_xlim(9.365, 9.375)
ax[1].set_ylim(1, np.pi)


ax[0].plot(np.real(s11_g),np.imag(s11_g) , ls='', marker='o')
ax[0].plot(np.real(res.init_fit), np.imag(res.init_fit), '--', label='initial fit', color='green')
ax[0].plot(np.real(res.best_fit), np.imag(res.best_fit))
ax[1].plot(freq*1e-9, np.angle(s11_g),  ls='', marker='o')
ax[1].plot(freq*1e-9, np.angle(res.init_fit), '--', label='initial fit', color='green')
ax[1].plot(freq*1e-9, np.angle(res.best_fit))
# plt.savefig('chi_g.png', bbox_inches='tight')
plt.show()
res
# Out:
# <h2> Model</h2> Model(resonator) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>21</td><td></td></tr><tr><td># data points</td><td>202</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 3911.27934</td><td></td></tr><tr><td>reduced chi-square</td><td> 19.7539361</td><td></td></tr><tr><td>Akaike info crit.</td><td> 606.597124</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 619.830195</td><td></td></tr><tr><td>R-squared</td><td>-3.9113e+18</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> fc </td><td>  9.3703e+09 </td><td>  108655.276 </td><td> (0.00%) </td><td> 9370000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> ke </td><td>  53388.7446 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 53388.7446 </td><td>  0.00000000 </td><td>         inf </td><td> False </td></tr><tr><td> ki </td><td>  1340874.00 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 1340874 </td><td>  0.00000000 </td><td>         inf </td><td> False </td></tr><tr><td> a0 </td><td> -118.763871 </td><td>  0.89363338 </td><td> (0.75%) </td><td> -116.913492 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> a1 </td><td>  9.3727e-07 </td><td>  1.5344e-07 </td><td> (16.37%) </td><td> 6.9928e-07 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> Poff </td><td> -43391.6398 </td><td>  0.00406143 </td><td> (0.00%) </td><td> -43391.8335 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> ed </td><td>  3.5092e-09 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 3.5092e-09 </td><td>        -inf </td><td>         inf </td><td> False </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>a0</td><td>a1</td><td>-0.8576</td></tr><tr><td>fc</td><td>a1</td><td>-0.1256</td></tr><tr><td>a0</td><td>Poff</td><td>-0.1118</td></tr><tr><td>fc</td><td>a0</td><td>+0.1052</td></tr></table>

# %%
par_ini = {'fc':9.368e+09,  'ke':50000, 'ki':500000, 'a0':-135, 'a1':1.0698e-06	, 'Poff':-44206, 'ed':1.1527e-09}
par_min = {'fc':0, 'ke':0, 'ki':0, 'a0':-np.inf, 'a1':-np.inf, 'Poff':-np.inf, 'ed':-np.inf}
par_max = {'fc':np.inf, 'ke':np.inf, 'ki':np.inf, 'a0':np.inf, 'a1':np.inf, 'Poff':np.inf, 'ed':np.inf}
par_var = {'fc':False, 'ke':True, 'ki':True, 'a0':True, 'a1':True, 'Poff':True, 'ed':True}
model=lmfit.Model(resonator)
params = model.make_params()

for name in list(par_ini):
    params[name].set(value=par_ini[name])
for name in list(par_min):
    params[name].set(min=par_min[name])  
for name in list(par_max):
    params[name].set(max=par_max[name]) 
for name in list(par_var):
    params[name].set(vary=par_var[name])
# result_d = model.fit(freq=freq_d, data=s11_d, params=params, method='leastsq')

# %%
par_ini = {'fr': 9.369e9,  'ff': 9.36e9,    'kf_e': 77e6,   'kf_i': 5e6,  'g': 39e6, 'gamma': 0.e6,
           'a0': 137.,  'a1': 3.5e-7	,        'Poff': -19575,   'ed': -3.9616e-09}
par_min = {'fr': 0,     'ff': 0,        'kf_e': 0,        'kf_i': 0,        'g': 0,     'gamma': 0,
           'a0': -np.inf,     'a1': -np.inf,  'Poff': -np.inf,'ed': -np.inf}
par_max = {'fr': np.inf,'ff': np.inf,   'kf_e': np.inf,   'kf_i': np.inf,   'g': np.inf,'gamma': np.inf,
           'a0': np.inf,'a1': np.inf,   'Poff': np.inf, 'ed': np.inf}
par_var = {'fr': True, 'ff': True,    'kf_e': False,    'kf_i': False,    'g': False, 'gamma': False,
           'a0': True, 'a1': True,    'Poff': True,  'ed':  False}

model=lmfit.Model(S11_dpr_model)
params = model.make_params()

for name in list(par_ini):
    params[name].set(value=par_ini[name])
for name in list(par_min):
    params[name].set(min=par_min[name])  
for name in list(par_max):
    params[name].set(max=par_max[name]) 
for name in list(par_var):
    params[name].set(vary=par_var[name])

# %%
res = model.fit(data = s11_e, params = params, freq = freq, method='nelder')

fig, ax = plt.subplots(1, 2, figsize=(16,6))#,constrained_layout=True)
plt.rcParams["font.size"] = 20
plt.subplots_adjust(wspace=0.3)
plt.tick_params(pad = 10, top='on',bottom='on',left='on',right='on',)
ax[0].set_aspect("equal", adjustable="box")
ax[0].set_xlabel('Re[S$_{11}$] (arb. u.) ')
ax[0].set_ylabel('Im[S$_{11}$] (arb. u.) ')
ax[0].tick_params(axis="x", direction="in")
ax[0].tick_params(axis="y", direction="in")
ax[0].set_xlim(-200, 200)
ax[0].set_ylim(-200, 200)
ax[0].get_xaxis().set_tick_params(pad=10)

ax[1].set_xlabel('Probe frequency $\omega_\mathrm{p}/2\pi$ (GHz)')
ax[1].set_ylabel('Phase[S$_{11}$] (rad) ')
ax[1].tick_params(axis="x", direction="in")
ax[1].tick_params(axis="y", direction="in")
ax[1].set_xlim(9.365, 9.375)
ax[1].set_ylim(1, np.pi)

ax[0].plot(np.real(s11_e), np.imag(s11_e),  ls='', marker='o')
# ax[0].plot(x, np.real(s11_e),'.', color='k')
ax[0].plot(np.real(res.init_fit), np.imag(res.init_fit),'--', label='initial fit', color='green')
ax[0].plot(np.real(res.best_fit),np.imag(res.best_fit), '-', label='best fit', color='red')
ax[0].plot(np.real(res.best_fit), np.imag(res.best_fit))
ax[1].plot(freq*1e-9, np.angle(s11_e),  ls='', marker='o')
ax[1].plot(freq*1e-9, np.angle(res.init_fit), '--', label='initial fit', color='green')
ax[1].plot(freq*1e-9, np.angle(res.best_fit))
# plt.savefig('chi_e.png', bbox_inches='tight')
plt.show()
res
# Out:
# <h2> Model</h2> Model(resonator) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>Nelder-Mead</td><td></td></tr><tr><td># function evals</td><td>1204</td><td></td></tr><tr><td># data points</td><td>202</td><td></td></tr><tr><td># variables</td><td>6</td><td></td></tr><tr><td>chi-square</td><td> 1006.20977</td><td></td></tr><tr><td>reduced chi-square</td><td> 5.13372333</td><td></td></tr><tr><td>Akaike info crit.</td><td> 336.346987</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 356.196593</td><td></td></tr><tr><td>R-squared</td><td>-1.0062e+18</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> fc </td><td>  9.3680e+09 </td><td> 9368000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> False </td></tr><tr><td> ke </td><td>  53388.7446 </td><td> 50000 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> ki </td><td>  1340874.90 </td><td> 500000 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> a0 </td><td> -116.913492 </td><td> -135 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> a1 </td><td>  6.9928e-07 </td><td> 1.0698e-06 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> Poff </td><td> -43391.8335 </td><td> -44206 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> ed </td><td>  3.5092e-09 </td><td> 1.1527e-09 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table>

# %%
(10.383-10.387)/2
# Out:
# -0.002000000000000668

# %%
# f_hg = 9.3867e+09
f_lg = 9.3703e+09
# f_he = 9.3866e+09
f_le = 9.3680e+09

chi_l = (f_le - f_lg)/2
# chi_h = (f_he - f_hg)/2 
chi = chi_l
chi
# Out:
# -1150000.0

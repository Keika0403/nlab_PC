# %% [markdown]
# ## 7/19 ge calibration

# %% [markdown]
# T1 = 36e-06
#
# T2_echo = 5.5e-06
#
# T2_star = 4.8e-06

# %%
from plottr.data.datadict_storage import datadict_from_hdf5
import numpy as np
import matplotlib.pyplot as plt
import lmfit
import sklearn
from sklearn.decomposition import PCA

# %%
def PCA_transform(Re_c, Im_c):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c]).T, np.array([Im_c]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    return c_PCA1, c_PCA2

# %%
def Rabi(delay, amp, phi0, detun, const):
    return - amp * np.cos(2*np.pi*detun*delay+phi0) + const

# %%
header = "D:/K_Sunada/result/CDY163"
amp = "/2024-07-30/2024-07-30T103259_a7e51b68-21_ge_pi_amp"
dd_amp = datadict_from_hdf5(header + amp +"/data")

Rabi_amp = dd_amp['s11']['values']
imag_amp = Rabi_amp.imag
amp = dd_amp['amplitude']['values']

I_amp = (Rabi_amp.real)
Q_amp = (Rabi_amp.imag)
PCA_amp = PCA_transform(I_amp, Q_amp)

# %%
fig, (ax1) = plt.subplots(nrows=1)
ax1.set_xlabel('Amplitude (V)', size='large')
ax1.set_ylabel('PCA[$S_{11}$] (V)', size='large')
plt.rcParams["font.size"] = 17
plt.plot(amp, PCA_amp[0])
ax1.tick_params(axis="x", direction="in")
ax1.tick_params(axis="y", direction="in")
# ax1.set_xlim(0, 1)
# ax1.set_ylim(-48, 160)
plt.tick_params(top='on',bottom='on`',left='on',right='on',)
plt.show()

# %%
par_ini= {'amp': 10,'phi0':np.pi,'detun':1/0.3,'const':1}
par_min = {'amp': 0,'phi0':-2*np.pi,'detun':-np.inf,'const':-np.inf}
par_max = {'amp': np.inf,'phi0':2*np.pi,'detun':np.inf,'const':np.inf,}
par_vary = {'amp': True,'phi0':True,'detun':True,'const':True}

model = lmfit.Model(Rabi)

params = model.make_params()
for name in model.param_names:
    params[name].set(value = par_ini[name],min = par_min[name],max = par_max[name],vary = par_vary[name])
    
result = model.fit(data = PCA_amp[0], params = params, delay = amp)
result
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>41</td><td></td></tr><tr><td># data points</td><td>31</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 201.921348</td><td></td></tr><tr><td>reduced chi-square</td><td> 7.47856846</td><td></td></tr><tr><td>Akaike info crit.</td><td> 66.0906226</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 71.8265715</td><td></td></tr><tr><td>R-squared</td><td> 0.90045508</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  10.7914609 </td><td>  0.69171200 </td><td> (6.41%) </td><td> 10 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  3.36617547 </td><td>  0.13005258 </td><td> (3.86%) </td><td> 3.141592653589793 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  3.26040132 </td><td>  0.02373225 </td><td> (0.73%) </td><td> 3.3333333333333335 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td> -0.11825818 </td><td>  0.49755526 </td><td> (420.74%) </td><td> 1 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>-0.8672</td></tr><tr><td>detun</td><td>const</td><td>-0.1590</td></tr><tr><td>phi0</td><td>const</td><td>+0.1370</td></tr></table>

# %%
fig, ax = plt.subplots(figsize=(8,6),constrained_layout=True)
plt.rcParams["font.size"] = 20
# plt.title("Rabi(amp)")
plt.tick_params(top='on',bottom='on',left='on',right='on',)
plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result.plot_fit(ax = ax)
plt.plot(amp,result.init_fit)

plt.title("")
plt.legend("")
ax.set_xlabel('$\pi_{ge}$ pulse DAC amplitude (V)', size='large')
ax.set_ylabel('S$_{11}$ (arb. u.)', size='large')
ax.set_xlim(0, 1.)
# plt.savefig('ge_rabi.png', bbox_inches='tight')
plt.show()

# %%
np.pi/(3.26040132*2*np.pi)*5
# Out:
# 0.7667767721306161

# %% [markdown]
# ramsey

# %%
pl ="/2024-07-30/2024-07-30T103019_484858c0-23_ge_T2r1d"
mi =  "/2024-07-30/2024-07-30T103126_70155d0f-23_ge_T2r1d"
dd_pl = datadict_from_hdf5(header + pl +"/data")
dd_mi = datadict_from_hdf5(header + mi +"/data")

Rabi_pl = dd_pl['s11']['values']
delay_pl = dd_pl['delay']['values']
Rabi_mi = dd_mi['s11']['values']
delay_mi = dd_mi['delay']['values']

I_pl = (Rabi_pl.real)
Q_pl = (Rabi_pl.imag)
I_mi = (Rabi_mi.real)
Q_mi = (Rabi_mi.imag)

PCA_pl = PCA_transform(I_pl, Q_pl)
y_pl = PCA_pl[0]
x_pl = delay_pl

PCA_mi = PCA_transform(I_mi, Q_mi)
y_mi = PCA_mi[0]
x_mi = delay_mi

fig, ax = plt.subplots(1,2,figsize=(12,6),constrained_layout=True)
ax[0].plot(x_pl, y_pl)
ax[1].plot(x_mi, y_mi)
plt.show()

# %%
par_ini_pl = {'amp': 10,'phi0':np.pi,'detun':1/200,'const':0.1}
par_ini_mi = {'amp': 10,'phi0':np.pi,'detun':1/200,'const':0.1}
par_min = {'amp': 0,'phi0':-2*np.pi,'detun':-np.inf,'const':0}
par_max = {'amp': np.inf,'phi0':2*np.pi,'detun':np.inf,'const':np.inf,}
par_vary = {'amp': True,'phi0':True,'detun':True,'const':True}

model = lmfit.Model(Rabi)

params_pl = model.make_params()
for name in model.param_names:
    params_pl[name].set(value = par_ini_pl[name],min = par_min[name],max = par_max[name],vary = par_vary[name])
    
result_pl = model.fit(data = y_pl, params = params_pl, delay = x_pl)
result_pl
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>93</td><td></td></tr><tr><td># data points</td><td>51</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 108.999536</td><td></td></tr><tr><td>reduced chi-square</td><td> 2.31913906</td><td></td></tr><tr><td>Akaike info crit.</td><td> 46.7354176</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 54.4627201</td><td></td></tr><tr><td>R-squared</td><td> 0.96174650</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  10.3545908 </td><td>  0.30142132 </td><td> (2.91%) </td><td> 10 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  3.77537275 </td><td>  0.05695825 </td><td> (1.51%) </td><td> 3.141592653589793 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  0.00503329 </td><td>  1.5895e-05 </td><td> (0.32%) </td><td> 0.005 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  2.4596e-09 </td><td>  0.17413945 </td><td> (7080001463.44%) </td><td> 0.1 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>-0.8588</td></tr><tr><td>detun</td><td>const</td><td>+0.1009</td></tr></table>

# %%
params_mi = model.make_params()
for name in model.param_names:
    params_mi[name].set(value = par_ini_mi[name],min = par_min[name],max = par_max[name],vary = par_vary[name])
    
result_mi = model.fit(data = y_mi, params = params_mi, delay = x_mi)
result_mi
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>94</td><td></td></tr><tr><td># data points</td><td>51</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 40.7100011</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.86617024</td><td></td></tr><tr><td>Akaike info crit.</td><td>-3.49294401</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 4.23435852</td><td></td></tr><tr><td>R-squared</td><td> 0.98557459</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  10.4493506 </td><td>  0.18444872 </td><td> (1.77%) </td><td> 10 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  4.01811616 </td><td>  0.03414811 </td><td> (0.85%) </td><td> 3.141592653589793 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  0.00498127 </td><td>  9.5798e-06 </td><td> (0.19%) </td><td> 0.005 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  1.4498e-09 </td><td>  0.09478213 </td><td> (6537534225.78%) </td><td> 0.1 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>-0.8564</td></tr><tr><td>detun</td><td>const</td><td>+0.1012</td></tr></table>

# %%
fig, ax = plt.subplots(1,2,figsize=(12,6),constrained_layout=True)
plt.rcParams["font.size"] = 20

plt.tick_params(top='on',bottom='on',left='on',right='on',)

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result_pl.plot_fit(ax = ax[0])
ax[0].plot(x_pl,result_pl.init_fit)
result_mi.plot_fit(ax = ax[1])
ax[1].plot(x_mi,result_mi.init_fit)

plt.title("")
plt.legend("")
plt.xlabel(r"Delay ${\tau}$ (ns)")
plt.ylabel("$S_{11}$ (arb. u.)")
plt.xlim(0, 1000)
# plt.savefig('ef_ramsey_exp.png', bbox_inches='tight')
plt.show()

# %%
detun = ((0.005-0.00503329)+ (0.00498127-0.005))/2 #GHz
detun
# Out:
# -2.6009999999999922e-05

# %% [markdown]
# drag

# %%
drag = "/2024-07-30/2024-07-30T104217_f47a07bc-22_ge_pi_drag" # n=7
dd_drag = datadict_from_hdf5(header + drag +"/data")

drag1 = "/2024-07-30/2024-07-30T104250_08129c22-22_ge_pi_drag" # n=13
dd_drag1 = datadict_from_hdf5(header + drag1 +"/data")

drag2 = "/2024-07-30/2024-07-30T104331_206a68f2-22_ge_pi_drag" # n=17
dd_drag2 = datadict_from_hdf5(header + drag2 +"/data")

# %%
Rabi_drag = dd_drag['s11']['values']
drag = dd_drag['beta']['values']
I_drag = (Rabi_drag.real)
Q_drag = (Rabi_drag.imag)

Rabi_drag1 = dd_drag1['s11']['values']
drag1 = dd_drag1['beta']['values']
I_drag1 = (Rabi_drag1.real)
Q_drag1 = (Rabi_drag1.imag)

Rabi_drag2 = dd_drag2['s11']['values']
drag2 = dd_drag2['beta']['values']
I_drag2 = (Rabi_drag2.real)
Q_drag2 = (Rabi_drag2.imag)

# %%
def PCA_transform1(Re_c_amp, Im_c_amp, Re_c_drag, Im_c_drag):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c_amp]).T, np.array([Im_c_amp]).T], axis = 1)
    c1_data = np.concatenate([np.array([Re_c_drag]).T, np.array([Im_c_drag]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    
    c1_pca = pca.transform(c1_data)
    c1_PCA1 = c1_pca.T[0]
    c1_PCA2 = c1_pca.T[1]
    return c_PCA1, c_PCA2, c1_PCA1, c1_PCA2,

# %%
PCA_drag = PCA_transform1(I_drag, Q_drag, I_drag, Q_drag)
y = PCA_drag[0]
x = amp
y0 = PCA_drag[2]
x0 = drag

PCA_drag1 = PCA_transform1(I_drag, Q_drag, I_drag1, Q_drag1)
y1 = PCA_drag1[2]
x1 = drag1

PCA_drag2 = PCA_transform1(I_drag, Q_drag, I_drag2, Q_drag2)
y2 = PCA_drag2[2]
x2 = drag2

# %%
plt.plot(x0, y0)
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.show()

# %%
par_ini= {'amp': 0.0002,'phi0':-np.pi/2,'detun':1/0.3,'const':0}
par_min = {'amp': 0,'phi0':-2*np.pi,'detun':-np.inf,'const':-np.pi}
par_max = {'amp': np.inf,'phi0':2*np.pi,'detun':np.inf,'const':np.inf,}
par_vary = {'amp': True,'phi0':True,'detun':True,'const':True}
model = lmfit.Model(Rabi)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )
    
result0 = model.fit(data = y0, params = params, delay = x0)
result1 = model.fit(data = y1, params = params, delay = x1)
result2 = model.fit(data = y2, params = params, delay = x2)

# %%
fig, ax = plt.subplots(1,3,figsize=(18,6),constrained_layout=True)
plt.title("Rabi(drag)")
plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result0.plot_fit(ax = ax[0])
ax[0].plot(x0,result0.init_fit)
result1.plot_fit(ax = ax[1])
ax[1].plot(x1,result1.init_fit)
result2.plot_fit(ax = ax[2])
ax[2].plot(x2,result2.init_fit)
plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")
plt.show()

# %%
result0
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>32</td><td></td></tr><tr><td># data points</td><td>51</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 1.9277e-09</td><td></td></tr><tr><td>reduced chi-square</td><td> 4.1015e-11</td><td></td></tr><tr><td>Akaike info crit.</td><td>-1215.93740</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-1208.21010</td><td></td></tr><tr><td>R-squared</td><td> 0.99781789</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  1.8129e-04 </td><td>  1.2380e-06 </td><td> (0.68%) </td><td> 0.0002 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td> -1.47540405 </td><td>  0.00721443 </td><td> (0.49%) </td><td> 0 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  1.38029335 </td><td>  0.00205079 </td><td> (0.15%) </td><td> 1.4285714285714286 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  1.0730e-06 </td><td>  9.0077e-07 </td><td> (83.95%) </td><td> 0 </td><td> -3.14159265 </td><td>         inf </td><td> True </td></tr></table>

# %%
res0 = (1.47540405+np.pi)/(2*np.pi*1.38029335)
res0
# Out:
# 0.5323635353421805

# %%
result1
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>37</td><td></td></tr><tr><td># data points</td><td>51</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 2.2141e-09</td><td></td></tr><tr><td>reduced chi-square</td><td> 4.7108e-11</td><td></td></tr><tr><td>Akaike info crit.</td><td>-1208.87346</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-1201.14616</td><td></td></tr><tr><td>R-squared</td><td> 0.99740061</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  1.8291e-04 </td><td>  1.3627e-06 </td><td> (0.75%) </td><td> 0.0002 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  0.82861168 </td><td>  0.00743037 </td><td> (0.90%) </td><td> -1.5707963267948966 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  2.56074005 </td><td>  0.00200574 </td><td> (0.08%) </td><td> 2.5 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  2.3144e-06 </td><td>  9.6522e-07 </td><td> (41.70%) </td><td> 0 </td><td> -3.14159265 </td><td>         inf </td><td> True </td></tr></table>

# %%
res1 = (3*np.pi-0.82861168)/(2*np.pi*2.56074005)
res1
# Out:
# 0.5342683476303345

# %%
result2
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>21</td><td></td></tr><tr><td># data points</td><td>51</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 2.3349e-09</td><td></td></tr><tr><td>reduced chi-square</td><td> 4.9678e-11</td><td></td></tr><tr><td>Akaike info crit.</td><td>-1206.16401</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-1198.43671</td><td></td></tr><tr><td>R-squared</td><td> 0.99734585</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  1.8380e-04 </td><td>  1.3835e-06 </td><td> (0.75%) </td><td> 0.0002 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td> -1.82752790 </td><td>  0.00766983 </td><td> (0.42%) </td><td> -1.5707963267948966 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  3.35772344 </td><td>  0.00211223 </td><td> (0.06%) </td><td> 3.3333333333333335 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  7.7048e-06 </td><td>  9.8782e-07 </td><td> (12.82%) </td><td> 0 </td><td> -3.14159265 </td><td>         inf </td><td> True </td></tr></table>

# %%
res2 = (3*np.pi+1.82752790)/(2*np.pi*3.35772344)
res2
# Out:
# 0.5333554507763006

# %%
beta = (res0 + res1 + res2)/3
beta
# Out:
# 0.5333291112496052

# %% [markdown]
# half drag

# %%
drag = "/2024-07-30/2024-07-30T105331_85f1ecdd-22_ge_pi_drag" # n=7
dd_drag = datadict_from_hdf5(header + drag +"/data")

drag1 = "/2024-07-30/2024-07-30T105407_9b5e6e9d-22_ge_pi_drag" # n=13
dd_drag1 = datadict_from_hdf5(header + drag1 +"/data")

drag2 = "/2024-07-30/2024-07-30T105443_b107c107-22_ge_pi_drag" # n=17
dd_drag2 = datadict_from_hdf5(header + drag2 +"/data")

# %%
Rabi_drag = dd_drag['s11']['values']
imag_drag = Rabi_drag.imag
drag = dd_drag['beta']['values']
I_drag = (Rabi_drag.real)
Q_drag = (Rabi_drag.imag)

Rabi_drag1 = dd_drag1['s11']['values']
imag_drag1 = Rabi_drag1.imag
drag1 = dd_drag1['beta']['values']
I_drag1 = (Rabi_drag1.real)
Q_drag1 = (Rabi_drag1.imag)

Rabi_drag2 = dd_drag2['s11']['values']
imag_drag2 = Rabi_drag2.imag
drag2 = dd_drag2['beta']['values']
I_drag2 = (Rabi_drag2.real)
Q_drag2 = (Rabi_drag2.imag)

# %%
PCA_drag = PCA_transform1(I_drag, Q_drag, I_drag, Q_drag)
y = PCA_drag[0]
x = amp
y0 = PCA_drag[2]
x0 = drag

PCA_drag1 = PCA_transform1(I_drag, Q_drag, I_drag1, Q_drag1)
y1 = PCA_drag1[2]
x1 = drag1

PCA_drag2 = PCA_transform1(I_drag, Q_drag, I_drag2, Q_drag2)
y2 = PCA_drag2[2]
x2 = drag2

# %%
plt.plot(x0, y0)
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.show()

# %%
par_ini= {'amp': 0.0001,'phi0':0,'detun':1/1.,'const':0}
par_min = {'amp': 0,'phi0':-2*np.pi,'detun':-np.inf,'const':-np.pi}
par_max = {'amp': np.inf,'phi0':2*np.pi,'detun':np.inf,'const':np.inf,}
par_vary = {'amp': True,'phi0':True,'detun':True,'const':True}
model = lmfit.Model(Rabi)

model = lmfit.Model(Rabi)
params = model.make_params()
for name in model.param_names:
    params[name].set(value = par_ini[name],min = par_min[name],max = par_max[name],vary = par_vary[name])
    
result0 = model.fit(data = y0, params = params, delay = x0)
result1 = model.fit(data = y1, params = params, delay = x1)
result2 = model.fit(data = y2, params = params, delay = x2)

# %%
fig, ax = plt.subplots(1,3,figsize=(18,6),constrained_layout=True)
plt.title("Rabi(drag)")
plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result0.plot_fit(ax = ax[0])
ax[0].plot(x0,result0.init_fit)
result1.plot_fit(ax = ax[1])
ax[1].plot(x1,result1.init_fit)
result2.plot_fit(ax = ax[2])
ax[2].plot(x2,result2.init_fit)
plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")
plt.show()

# %%
result0
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>16</td><td></td></tr><tr><td># data points</td><td>51</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 1.9498e-09</td><td></td></tr><tr><td>reduced chi-square</td><td> 4.1485e-11</td><td></td></tr><tr><td>Akaike info crit.</td><td>-1215.35524</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-1207.62794</td><td></td></tr><tr><td>R-squared</td><td> 0.99306252</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  1.0471e-04 </td><td>  1.2841e-06 </td><td> (1.23%) </td><td> 0.0001 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  0.31097445 </td><td>  0.02560104 </td><td> (8.23%) </td><td> 0 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  0.45104062 </td><td>  0.00297955 </td><td> (0.66%) </td><td> 0.5 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  9.9789e-06 </td><td>  9.9799e-07 </td><td> (10.00%) </td><td> 0 </td><td> -3.14159265 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>-0.8743</td></tr><tr><td>detun</td><td>const</td><td>+0.3992</td></tr><tr><td>phi0</td><td>const</td><td>-0.3953</td></tr><tr><td>amp</td><td>const</td><td>+0.1314</td></tr></table>

# %%
res0 = (2*np.pi-0.31097445)/(2*np.pi*0.45104062)
res0
# Out:
# 2.107364252707919

# %%
result1
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>21</td><td></td></tr><tr><td># data points</td><td>51</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 1.8940e-09</td><td></td></tr><tr><td>reduced chi-square</td><td> 4.0297e-11</td><td></td></tr><tr><td>Akaike info crit.</td><td>-1216.83750</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-1209.11020</td><td></td></tr><tr><td>R-squared</td><td> 0.99247804</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  1.0178e-04 </td><td>  1.2963e-06 </td><td> (1.27%) </td><td> 0.0001 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  1.40823802 </td><td>  0.02297801 </td><td> (1.63%) </td><td> 0 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  0.83581640 </td><td>  0.00246555 </td><td> (0.29%) </td><td> 1.0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  9.1931e-06 </td><td>  8.9245e-07 </td><td> (9.71%) </td><td> 0 </td><td> -3.14159265 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>-0.8509</td></tr></table>

# %%
res1 = (4*np.pi-1.40823802)/(2*np.pi*0.83581640)
res1
# Out:
# 2.124715377763653

# %%
result2
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>31</td><td></td></tr><tr><td># data points</td><td>51</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 2.2517e-09</td><td></td></tr><tr><td>reduced chi-square</td><td> 4.7908e-11</td><td></td></tr><tr><td>Akaike info crit.</td><td>-1208.01379</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-1200.28648</td><td></td></tr><tr><td>R-squared</td><td> 0.99088356</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  1.0090e-04 </td><td>  1.4141e-06 </td><td> (1.40%) </td><td> 0.0001 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td> -2.03031976 </td><td>  0.02559390 </td><td> (1.26%) </td><td> 0 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  1.09366061 </td><td>  0.00282305 </td><td> (0.26%) </td><td> 1.0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  6.2096e-06 </td><td>  9.9915e-07 </td><td> (16.09%) </td><td> 0 </td><td> -3.14159265 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>-0.8548</td></tr><tr><td>detun</td><td>const</td><td>-0.2213</td></tr><tr><td>phi0</td><td>const</td><td>+0.1741</td></tr><tr><td>amp</td><td>const</td><td>+0.1074</td></tr></table>

# %%
res2 = (4*np.pi+2.03031976)/(2*np.pi*1.09366061)
res2
# Out:
# 2.124183137455367

# %%
beta = (res0 + res1 + res2)/3
beta
# Out:
# 2.1187542559756465

# %% [markdown]
# T1

# %%
def Dephase(delay, amp, gamma, const):
    return amp*np.exp(-gamma*delay) + const

t1 ="/2024-07-30/2024-07-30T105830_37f76c4b-24_ge_T1"
# t1 ="/2024-07-24/2024-07-24T145128_c4f7a1fb-24_ge_T1"

dd_t1 = datadict_from_hdf5(header + t1 +"/data")

# %%
s11_t1 = dd_t1['s11']['values']#[0:180]
delay_t1 = dd_t1['delay']['values']#[0:180]
I_t1 = (s11_t1.real)
Q_t1 = (s11_t1.imag)
PCA_t1 = PCA_transform(I_t1, Q_t1)

y_t1 = PCA_t1[0]
x_t1 = delay_t1

fig, (ax1) = plt.subplots(nrows=1)
ax1.set_xlabel('Delay (ns)', size='large')
ax1.set_ylabel('PCA[S$_{11}$] (arb. unit.)', size='large')
plt.rcParams["font.size"] = 10
ax1.tick_params(axis="x", direction="in")
ax1.tick_params(axis="y", direction="in")
# ax1.set_xlim(0, 250000)
# ax1.set_ylim(-48, 160)
plt.tick_params(top='on',bottom='on`',left='on',right='on',)

plt.plot(x_t1, y_t1)
plt.show()

# %%
par_ini_t1 = {'gamma': 1/40000e-3,'amp':16,'const':-2.4}
par_min_t1 = {'gamma': 0,'amp':0,'const':-np.inf}
par_max_t1 = {'gamma': np.inf,'amp':np.inf,'const':np.inf,}
par_vary_t1 = {'gamma': True,'amp':True,'const':True}

model = lmfit.Model(Dephase)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini_t1[name],
    min = par_min_t1[name],
    max = par_max_t1[name],
    vary = par_vary_t1[name]
    )
result_t1 = model.fit(data = y_t1, params = params, delay = x_t1*1e-3)
result_t1
# Out:
# <h2> Model</h2> Model(Dephase) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>29</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>3</td><td></td></tr><tr><td>chi-square</td><td> 36.7396463</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.37489435</td><td></td></tr><tr><td>Akaike info crit.</td><td>-96.1376704</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-88.2923088</td><td></td></tr><tr><td>R-squared</td><td> 0.96938940</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  19.1319039 </td><td>  0.42274813 </td><td> (2.21%) </td><td> 16 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> gamma </td><td>  0.08071430 </td><td>  0.00293934 </td><td> (3.64%) </td><td> 0.025 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td> -1.27068708 </td><td>  0.07015681 </td><td> (5.52%) </td><td> -2.4 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>amp</td><td>gamma</td><td>+0.5832</td></tr><tr><td>gamma</td><td>const</td><td>+0.3744</td></tr></table>

# %%
fig, ax = plt.subplots(figsize=(8,6),constrained_layout=True)
plt.rcParams["font.size"] = 20
plt.tick_params(top='on',bottom='on',left='on',right='on',)
plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result_t1.plot_fit(ax = ax)
# plt.plot(x_t1,result_t1.init_fit, label='init fit')
# ax.set_ylim(-8, 15)
plt.title("")
plt.legend("")
ax.set_xlabel(r'Delay $\tau$ ($\mu$s)')#, size='large')
ax.set_ylabel('S$_{11}$ (arb. u.)')
plt.xlim(0, 200)
# plt.savefig('ge_T1.png', bbox_inches='tight')
plt.show()

# %%
T1 = (1/0.08071430)*1e-9	
T1
# Out:
# 1.2389378338163125e-08

# %% [markdown]
# T2_echo

# %%
t2e = "/2024-07-30/2024-07-30T110537_36a9537c-25_ge_T2e"
dd_t2e = datadict_from_hdf5(header + t2e +"/data")

# %%
s11_t2e = dd_t2e['s11']['values']
delay_t2e = dd_t2e['delay']['values']
I_t2e = (s11_t2e.real)
Q_t2e = (s11_t2e.imag)
PCA_t2e = PCA_transform(I_t2e, Q_t2e)

y_t2e = PCA_t2e[0]
x_t2e = delay_t2e
plt.plot(x_t2e, y_t2e)
plt.show()

# %%
par_ini_t2e = {'gamma': 1/5000e-3,'amp':10,'const':-2.5}
par_min_t2e = {'gamma': 0,'amp':0,'const':-np.inf}
par_max_t2e = {'gamma': np.inf,'amp':np.inf,'const':np.inf,}
par_vary_t2e = {'gamma': True,'amp':True,'const':True}

model = lmfit.Model(Dephase)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini_t2e[name],
    min = par_min_t2e[name],
    max = par_max_t2e[name],
    vary = par_vary_t2e[name]
    )
result_t2e = model.fit(data = y_t2e, params = params, delay = x_t2e*1e-3)
result_t2e
# Out:
# <h2> Model</h2> Model(Dephase) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>57</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>3</td><td></td></tr><tr><td>chi-square</td><td> 138.973847</td><td></td></tr><tr><td>reduced chi-square</td><td> 1.41810048</td><td></td></tr><tr><td>Akaike info crit.</td><td> 38.2356898</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 46.0810513</td><td></td></tr><tr><td>R-squared</td><td> 0.79587547</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  9.48658459 </td><td>  0.54383172 </td><td> (5.73%) </td><td> 10 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> gamma </td><td>  0.14548743 </td><td>  0.01679164 </td><td> (11.54%) </td><td> 0.2 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td> -1.65676295 </td><td>  0.20184842 </td><td> (12.18%) </td><td> -2.5 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>gamma</td><td>const</td><td>+0.6921</td></tr><tr><td>amp</td><td>gamma</td><td>+0.4513</td></tr></table>

# %%
fig, ax = plt.subplots(figsize=(8,6),constrained_layout=True)
plt.rcParams["font.size"] = 20
plt.tick_params(top='on',bottom='on',left='on',right='on',)

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result_t2e.plot_fit(ax = ax)
# plt.plot(delay_t2e,result_t2e.init_fit)

ax.set_ylim(-5, 10)

plt.title("")
plt.legend("")
ax.set_xlabel(r'Delay $\tau$ ($\mu$s)')
ax.set_ylabel('S$_{11}$ (arb. u.)')
plt.xlim(0, 40)
# plt.savefig('ge_T2e.png', bbox_inches='tight')
plt.show()

# %%
T2 = (1/0.14548743)*1e-6
T2
# Out:
# 6.873446042726853e-06

# %% [markdown]
# T2 star

# %%
def Damping(delay, amp, gamma, omega, phi0, const):
    return const + amp * np.exp(- gamma*delay)*np.cos(omega*delay + phi0)

# %%
t2 = "/2024-07-30/2024-07-30T110328_e9d2fbd0-23_ge_T2r1d"
dd_t2 = datadict_from_hdf5(header + t2 +"/data")

s11_t2 = dd_t2['s11']['values']
delay_t2 = dd_t2['delay']['values']
I_t2 = (s11_t2.real)
Q_t2 = (s11_t2.imag)
PCA_t2 = PCA_transform(I_t2, Q_t2)

y_t2 = PCA_t2[0]
x_t2 = delay_t2

plt.plot(x_t2, y_t2)
plt.show()

# %%
par_ini_t2 = {'amp':10,'gamma': 1/3000e-3,'omega':2*np.pi/1500e-3,'phi0':np.pi,'const':0}
par_min_t2 = {'amp':-np.inf,'gamma': 0,'omega':-2*np.pi,'phi0':-2*np.pi,'const':-np.inf}
par_max_t2 = {'amp':np.inf,'gamma': np.inf,'omega':np.inf,'phi0':2*np.pi,'const':np.inf}
par_vary_t2 = {'amp':True,'gamma': True,'omega':True,'phi0':True,'const':True}

model = lmfit.Model(Damping)

params = model.make_params()
for name in model.param_names:
    params[name].set(value = par_ini_t2[name],min = par_min_t2[name],max = par_max_t2[name],vary = par_vary_t2[name])
result_t2 = model.fit(data = y_t2, params = params, delay = x_t2*1e-3)
result_t2
# Out:
# <h2> Model</h2> Model(Damping) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>88</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>5</td><td></td></tr><tr><td>chi-square</td><td> 115.562542</td><td></td></tr><tr><td>reduced chi-square</td><td> 1.20377648</td><td></td></tr><tr><td>Akaike info crit.</td><td> 23.6038269</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 36.6794295</td><td></td></tr><tr><td>R-squared</td><td> 0.90719663</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td> -10.2719687 </td><td>  0.49242724 </td><td> (4.79%) </td><td> 10 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> gamma </td><td>  0.11598435 </td><td>  0.00852417 </td><td> (7.35%) </td><td> 0.3333333333333333 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> omega </td><td>  2.93528366 </td><td>  0.00834437 </td><td> (0.28%) </td><td> 4.1887902047863905 </td><td> -6.28318531 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  3.69905908 </td><td>  0.04612482 </td><td> (1.25%) </td><td> 3.141592653589793 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> const </td><td>  0.03681937 </td><td>  0.10942805 </td><td> (297.20%) </td><td> 0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>amp</td><td>gamma</td><td>-0.7314</td></tr><tr><td>omega</td><td>phi0</td><td>-0.7182</td></tr></table>

# %%
fig, ax = plt.subplots(figsize=(8,6),constrained_layout=True)
plt.rcParams["font.size"] = 20

plt.tick_params(top='on',bottom='on',left='on',right='on',)

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result_t2.plot_fit(ax = ax)
# plt.plot(delay_t2*1e-3,result_t2.init_fit)
# ax.set_ylim(-10, 35)
plt.title("")
plt.legend("")
ax.tick_params(axis="x", direction="in")
ax.tick_params(axis="y", direction="in")
ax.set_xlabel(r'Delay $\tau$ ($\mu$s)')
ax.set_ylabel('S$_{11}$ (arb. u.)')
ax.set_xlim(0, 20)
# plt.savefig('ge_T2star.png', bbox_inches='tight')
plt.show()

# %%
T2_star = (1/0.11598435)*1e-6
T2_star
# Out:
# 8.621852862045612e-06

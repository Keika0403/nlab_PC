# %% [markdown]
# ## 7/19 ef calibration - OP9500_read

# %% [markdown]
# ef_freq =
#
# ef_pi_amp = 0.875
#
#
# T1 = 20e-6

# %%
from plottr.data.datadict_storage import datadict_from_hdf5
import numpy as np
import matplotlib.pyplot as plt
import lmfit

import sklearn
from sklearn.decomposition import PCA

# %%
def PCA_transform(Re_c, Im_c):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c]).T, np.array([Im_c]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    return c_PCA1, c_PCA2

# %%
def Rabi(delay, amp, phi0, detun, const):
    return - amp * np.cos(2*np.pi*detun*delay+phi0) + const

# %% [markdown]
# amp

# %%
header = "D:/K_sunada/result/CDY163"
ef = "/2024-07-30/2024-07-30T113232_f94ce179-30_ef_pi_amp"
dd_ef = datadict_from_hdf5(header + ef +"/data")

Rabi_ef = dd_ef['s11']['values']
amp_ef = dd_ef['amplitude']['values']
I = (Rabi_ef.real)
Q = (Rabi_ef.imag)
PCAef = PCA_transform(I, Q)

y = PCAef[0]
x = amp_ef
plt.plot(x, y)
plt.show()

# %%
par_ini= {'amp': 5,'phi0':np.pi,'detun':1/0.18,'const':1}
par_min = {'amp': 0,'phi0':-2*np.pi,'detun':-np.inf,'const':-np.inf}
par_max = {'amp': np.inf,'phi0':2*np.pi,'detun':np.inf,'const':np.inf,}
par_vary = {'amp': True,'phi0':True,'detun':True,'const':True}

model = lmfit.Model(Rabi)

params = model.make_params()
for name in model.param_names:
    params[name].set(value = par_ini[name],min = par_min[name],max = par_max[name],vary = par_vary[name])

result_ef = model.fit(data = y, params = params, delay = x)
result_ef
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>98</td><td></td></tr><tr><td># data points</td><td>21</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 319.283094</td><td></td></tr><tr><td>reduced chi-square</td><td> 18.7813585</td><td></td></tr><tr><td>Akaike info crit.</td><td> 65.1526700</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 69.3307597</td><td></td></tr><tr><td>R-squared</td><td> 0.57718574</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  6.43956301 </td><td>  1.33685174 </td><td> (20.76%) </td><td> 5 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  3.30610306 </td><td>  0.41903915 </td><td> (12.67%) </td><td> 3.141592653589793 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  5.68156444 </td><td>  0.11030723 </td><td> (1.94%) </td><td> 5.555555555555555 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  0.02844803 </td><td>  0.95064725 </td><td> (3341.70%) </td><td> 1 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>-0.8684</td></tr><tr><td>detun</td><td>const</td><td>-0.1015</td></tr></table>

# %%
fig, ax = plt.subplots(figsize=(8,6),constrained_layout=True)
plt.rcParams["font.size"] = 20
# plt.title("Rabi(amp)")
plt.tick_params(top='on',bottom='on',left='on',right='on',)
plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result_ef.plot_fit(ax = ax)
plt.plot(amp_ef,result_ef.init_fit)

plt.title("")
plt.legend("")
ax.set_xlabel('$\pi_{ef}$ pulse DAC amplitude (V)', size='large')
ax.set_ylabel('S$_{11}$ (arb. u.)', size='large')
ax.set_ylim(-10, 10)
ax.set_xlim(0, 1.)
# plt.savefig('ef_rabi.png', bbox_inches='tight')
plt.show()

# %%
np.pi/(5.68156444*2*np.pi)*5
# Out:
# 0.44001965064396953

# %% [markdown]
# ramsey

# %%
pl = "/2024-07-30/2024-07-30T112931_8d27261e-32_ef_T2r1d"
mi = "/2024-07-30/2024-07-30T113019_a9c49f54-32_ef_T2r1d"
dd_pl = datadict_from_hdf5(header + pl +"/data")
dd_mi = datadict_from_hdf5(header + mi +"/data")

# %%
Rabi_pl = dd_pl['s11']['values']
delay_pl = dd_pl['delay']['values']
Rabi_mi = dd_mi['s11']['values']
delay_mi = dd_mi['delay']['values']

I_pl = (Rabi_pl.real)
Q_pl = (Rabi_pl.imag)
I_mi = (Rabi_mi.real)
Q_mi = (Rabi_mi.imag)

PCA_pl = PCA_transform(I_pl, Q_pl)
y_pl = PCA_pl[0]
x_pl = delay_pl

PCA_mi = PCA_transform(I_mi, Q_mi)
y_mi = PCA_mi[0]
x_mi = delay_mi

fig, ax = plt.subplots(1,2,figsize=(12,6),constrained_layout=True)
ax[0].plot(x_pl, y_pl)
ax[1].plot(x_mi, y_mi)
plt.show()

# %%
par_ini_pl = {'amp': 6,'phi0':0,'detun':1/180,'const':0.1}
par_ini_mi = {'amp': 6,'phi0':0,'detun':1/200,'const':0.1}
par_min = {'amp': 0,'phi0':-2*np.pi,'detun':-np.inf,'const':0}
par_max = {'amp': np.inf,'phi0':2*np.pi,'detun':np.inf,'const':np.inf,}
par_vary = {'amp': True,'phi0':True,'detun':True,'const':True}

model = lmfit.Model(Rabi)

# %%
params_pl = model.make_params()
for name in model.param_names:
    params_pl[name].set(value = par_ini_pl[name],min = par_min[name],max = par_max[name],vary = par_vary[name])
    
result_pl = model.fit(data = y_pl, params = params_pl, delay = x_pl)
result_pl
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>105</td><td></td></tr><tr><td># data points</td><td>51</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 244.285866</td><td></td></tr><tr><td>reduced chi-square</td><td> 5.19757162</td><td></td></tr><tr><td>Akaike info crit.</td><td> 87.8921879</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 95.6194904</td><td></td></tr><tr><td>R-squared</td><td> 0.55446484</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  3.50034563 </td><td>  0.45832694 </td><td> (13.09%) </td><td> 6 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  0.88938807 </td><td>  0.24768771 </td><td> (27.85%) </td><td> 0 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  0.00570545 </td><td>  6.7567e-05 </td><td> (1.18%) </td><td> 0.005555555555555556 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  5.2381e-10 </td><td>  0.42947730 </td><td> (81990682353.89%) </td><td> 0.1 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>-0.8579</td></tr><tr><td>detun</td><td>const</td><td>-0.1121</td></tr></table>

# %%
params_mi = model.make_params()
for name in model.param_names:
    params_mi[name].set(value = par_ini_mi[name],min = par_min[name],max = par_max[name],vary = par_vary[name])
    
result_mi = model.fit(data = y_mi, params = params_mi, delay = x_mi)
result_mi
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>59</td><td></td></tr><tr><td># data points</td><td>51</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 195.656663</td><td></td></tr><tr><td>reduced chi-square</td><td> 4.16290773</td><td></td></tr><tr><td>Akaike info crit.</td><td> 76.5713244</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 84.2986270</td><td></td></tr><tr><td>R-squared</td><td> 0.67848004</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  4.08898425 </td><td>  0.41077561 </td><td> (10.05%) </td><td> 6 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  0.59845546 </td><td>  0.18940701 </td><td> (31.65%) </td><td> 0 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  0.00423827 </td><td>  5.1192e-05 </td><td> (1.21%) </td><td> 0.005 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  0.05743000 </td><td>  0.28688327 </td><td> (499.54%) </td><td> 0.1 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>-0.8568</td></tr></table>

# %%
fig, ax = plt.subplots(1,2,figsize=(12,6),constrained_layout=True)
plt.rcParams["font.size"] = 20

plt.tick_params(top='on',bottom='on',left='on',right='on',)

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result_pl.plot_fit(ax = ax[0])
ax[0].plot(x_pl,result_pl.init_fit)
result_mi.plot_fit(ax = ax[1])
ax[1].plot(x_mi,result_mi.init_fit)

plt.title("")
plt.legend("")
plt.xlabel(r"Delay ${\tau}$ (ns)")
plt.ylabel("$S_{11}$ (arb. u.)")
plt.xlim(0, 1000)
# plt.savefig('ef_ramsey_exp.png', bbox_inches='tight')
plt.show()

# %%
detun = ((0.005-0.00570545)+ (0.00423827-0.005))/2 #GHz
detun
# Out:
# -0.0007335900000000001

# %% [markdown]
# drag

# %%
drag = "/2024-07-30/2024-07-30T113741_b17fa9cf-31_ef_pi_drag" #n=7
dd_drag = datadict_from_hdf5(header + drag +"/data")

drag1 = "/2024-07-30/2024-07-30T113836_d2196bee-31_ef_pi_drag" #n=11
dd_drag1 = datadict_from_hdf5(header + drag1 +"/data")

drag2 = "/2024-07-30/2024-07-30T113931_f2f97fb9-31_ef_pi_drag" #n=17
dd_drag2 = datadict_from_hdf5(header + drag2 +"/data")

# %%
Rabi_drag = dd_drag['s11']['values']
drag = dd_drag['beta']['values']
I_drag = (Rabi_drag.real)
Q_drag = (Rabi_drag.imag)

Rabi_drag1 = dd_drag1['s11']['values']
drag1 = dd_drag1['beta']['values']
I_drag1 = (Rabi_drag1.real)
Q_drag1 = (Rabi_drag1.imag)

Rabi_drag2 = dd_drag2['s11']['values']
drag2 = dd_drag2['beta']['values']
I_drag2 = (Rabi_drag2.real)
Q_drag2 = (Rabi_drag2.imag)

# %%
def PCA_transform1(Re_c_amp, Im_c_amp, Re_c_drag, Im_c_drag):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c_amp]).T, np.array([Im_c_amp]).T], axis = 1)
    c1_data = np.concatenate([np.array([Re_c_drag]).T, np.array([Im_c_drag]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    
    c1_pca = pca.transform(c1_data)
    c1_PCA1 = c1_pca.T[0]
    c1_PCA2 = c1_pca.T[1]
    return c_PCA1, c_PCA2, c1_PCA1, c1_PCA2,

# %%
PCA_drag = PCA_transform1(I_drag, Q_drag, I_drag, Q_drag)
y = PCA_drag[0]
y0 = PCA_drag[2]
x0 = drag

PCA_drag1 = PCA_transform1(I_drag, Q_drag, I_drag1, Q_drag1)
y1 = PCA_drag1[2]
x1 = drag1

PCA_drag2 = PCA_transform1(I_drag, Q_drag, I_drag2, Q_drag2)
y2 = PCA_drag2[2]
x2 = drag2

# %%
plt.plot(x0, y0)
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.show()

# %%
par_ini= {'amp': 0.00012,'phi0':0,'detun':1/0.4,'const':0}
par_min = {'amp': 0,'phi0':-2*np.pi,'detun':-np.inf,'const':-np.pi}
par_max = {'amp': np.inf,'phi0':2*np.pi,'detun':np.inf,'const':np.inf,}
par_vary = {'amp': True,'phi0':True,'detun':True,'const':True}
model = lmfit.Model(Rabi)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )
    
result0 = model.fit(data = y0, params = params, delay = x0)
result1 = model.fit(data = y1, params = params, delay = x1)
result2 = model.fit(data = y2, params = params, delay = x2)

# %%
fig, ax = plt.subplots(1,3,figsize=(18,6),constrained_layout=True)
plt.title("Rabi(drag)")
plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result0.plot_fit(ax = ax[0])
ax[0].plot(x0,result0.init_fit)
result1.plot_fit(ax = ax[1])
ax[1].plot(x1,result1.init_fit)
result2.plot_fit(ax = ax[2])
ax[2].plot(x2,result2.init_fit)
plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")
plt.show()

# %%
result0
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>60</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 9.5462e-07</td><td></td></tr><tr><td>reduced chi-square</td><td> 9.8414e-09</td><td></td></tr><tr><td>Akaike info crit.</td><td>-1858.18459</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-1847.72411</td><td></td></tr><tr><td>R-squared</td><td> 0.01665283</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  1.7955e-05 </td><td>  1.4021e-05 </td><td> (78.09%) </td><td> 0.00012 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td> -1.30010554 </td><td>  1.54495206 </td><td> (118.83%) </td><td> 0 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  2.57996207 </td><td>  0.16909380 </td><td> (6.55%) </td><td> 2.5 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  8.7679e-07 </td><td>  9.8955e-06 </td><td> (1128.61%) </td><td> 0 </td><td> -3.14159265 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>-0.8645</td></tr></table>

# %%
res0 = (2*np.pi-0.06464370)/(2*np.pi*1.21715804)
res0
# Out:
# 0.8131332194176283

# %%
result1
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>36</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 7.3935e-09</td><td></td></tr><tr><td>reduced chi-square</td><td> 7.6221e-11</td><td></td></tr><tr><td>Akaike info crit.</td><td>-2349.11691</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-2338.65643</td><td></td></tr><tr><td>R-squared</td><td> 0.99081345</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  1.2767e-04 </td><td>  1.2482e-06 </td><td> (0.98%) </td><td> 0.00012 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  1.05376093 </td><td>  0.01852609 </td><td> (1.76%) </td><td> 0 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  2.25955739 </td><td>  0.00202661 </td><td> (0.09%) </td><td> 2.5 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td> -1.8641e-06 </td><td>  8.7364e-07 </td><td> (46.87%) </td><td> 0 </td><td> -3.14159265 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>-0.8587</td></tr></table>

# %%
res1 = (4*np.pi-1.05376093)/(2*np.pi*2.25955739)
res1
# Out:
# 0.8109060417152704

# %%
result2
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>52</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 1.0994e-08</td><td></td></tr><tr><td>reduced chi-square</td><td> 1.1334e-10</td><td></td></tr><tr><td>Akaike info crit.</td><td>-2309.04529</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-2298.58480</td><td></td></tr><tr><td>R-squared</td><td> 0.98637954</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  1.2580e-04 </td><td>  1.5016e-06 </td><td> (1.19%) </td><td> 0.00012 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  3.78993937 </td><td>  0.02335070 </td><td> (0.62%) </td><td> 0 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  2.95803705 </td><td>  0.00259160 </td><td> (0.09%) </td><td> 2.5 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td> -1.0974e-06 </td><td>  1.0613e-06 </td><td> (96.71%) </td><td> 0 </td><td> -3.14159265 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>-0.8602</td></tr></table>

# %%
res2 = (6*np.pi-3.78993937)/(2*np.pi*2.95803705)
res2
# Out:
# 0.8102712625745903

# %%
beta = (res0 + res1 + res2)/3
beta
# Out:
# 0.8114368412358296

# %% [markdown]
# half drag

# %%
drag = "/2024-07-30/2024-07-30T121350_be87bbc5-31_ef_pi_drag" #n=7
dd_drag = datadict_from_hdf5(header + drag +"/data")

drag1 = "/2024-07-30/2024-07-30T121505_eb386f4a-31_ef_pi_drag" #n=13
dd_drag1 = datadict_from_hdf5(header + drag1 +"/data")

drag2 = "/2024-07-30/2024-07-30T121611_129dd39e-31_ef_pi_drag" #n=17
dd_drag2 = datadict_from_hdf5(header + drag2 +"/data")

# %%
Rabi_drag = dd_drag['s11']['values']
drag = dd_drag['beta']['values']
I_drag = (Rabi_drag.real)
Q_drag = (Rabi_drag.imag)

Rabi_drag1 = dd_drag1['s11']['values']
drag1 = dd_drag1['beta']['values']
I_drag1 = (Rabi_drag1.real)
Q_drag1 = (Rabi_drag1.imag)

Rabi_drag2 = dd_drag2['s11']['values']
drag2 = dd_drag2['beta']['values']
I_drag2 = (Rabi_drag2.real)
Q_drag2 = (Rabi_drag2.imag)

# %%
PCA_drag = PCA_transform1(I_drag, Q_drag, I_drag, Q_drag)
y = PCA_drag[0]
y0 = PCA_drag[2]
x0 = drag

PCA_drag1 = PCA_transform1(I_drag, Q_drag, I_drag1, Q_drag1)
y1 = PCA_drag1[2]
x1 = drag1

PCA_drag2 = PCA_transform1(I_drag, Q_drag, I_drag2, Q_drag2)
y2 = PCA_drag2[2]
x2 = drag2

# %%
plt.plot(x0, y0)
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.show()

# %%
par_ini= {'amp': 0.00007,'phi0':-np.pi/2,'detun':1/1,'const':0}
par_min = {'amp': 0,'phi0':-2*np.pi,'detun':-np.inf,'const':-np.pi}
par_max = {'amp': np.inf,'phi0':2*np.pi,'detun':np.inf,'const':np.inf,}
par_vary = {'amp': True,'phi0':True,'detun':True,'const':True}
model = lmfit.Model(Rabi)

model = lmfit.Model(Rabi)
params = model.make_params()
for name in model.param_names:
    params[name].set(value = par_ini[name],min = par_min[name],max = par_max[name],vary = par_vary[name])
    
result0 = model.fit(data = y0, params = params, delay = x0)
result1 = model.fit(data = y1, params = params, delay = x1)
result2 = model.fit(data = y2, params = params, delay = x2)

# %%
fig, ax = plt.subplots(1,3,figsize=(18,6),constrained_layout=True)
plt.title("Rabi(drag)")
plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result0.plot_fit(ax = ax[0])
ax[0].plot(x0,result0.init_fit)
result1.plot_fit(ax = ax[1])
ax[1].plot(x1,result1.init_fit)
result2.plot_fit(ax = ax[2])
ax[2].plot(x2,result2.init_fit)
plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")
plt.show()

# %%
result0
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>57</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 6.1226e-09</td><td></td></tr><tr><td>reduced chi-square</td><td> 6.3120e-11</td><td></td></tr><tr><td>Akaike info crit.</td><td>-2368.16641</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-2357.70593</td><td></td></tr><tr><td>R-squared</td><td> 0.97279243</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  6.8124e-05 </td><td>  1.3912e-06 </td><td> (2.04%) </td><td> 7e-05 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  1.94345457 </td><td>  0.17149690 </td><td> (8.82%) </td><td> -1.5707963267948966 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  0.45765971 </td><td>  0.00952155 </td><td> (2.08%) </td><td> 1.0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  5.0789e-06 </td><td>  1.6548e-06 </td><td> (32.58%) </td><td> 0 </td><td> -3.14159265 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>+0.9956</td></tr><tr><td>detun</td><td>const</td><td>-0.8766</td></tr><tr><td>phi0</td><td>const</td><td>-0.8706</td></tr><tr><td>amp</td><td>detun</td><td>-0.5532</td></tr><tr><td>amp</td><td>phi0</td><td>-0.5459</td></tr><tr><td>amp</td><td>const</td><td>+0.5295</td></tr></table>

# %%
res0 = (-5*np.pi+4.33976063)/(2*np.pi*0.45765790)
res0
# Out:
# -3.953401970991656

# %%
result1
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>68</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 3.1813e-07</td><td></td></tr><tr><td>reduced chi-square</td><td> 3.2797e-09</td><td></td></tr><tr><td>Akaike info crit.</td><td>-1969.16905</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-1958.70856</td><td></td></tr><tr><td>R-squared</td><td> 0.04549477</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  1.6960e-05 </td><td>  7.9014e-06 </td><td> (46.59%) </td><td> 7e-05 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  6.28318531 </td><td>  1.59719222 </td><td> (25.42%) </td><td> -1.5707963267948966 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  1.40726083 </td><td>  0.13882515 </td><td> (9.86%) </td><td> 1.0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  9.5320e-06 </td><td>  5.7224e-06 </td><td> (60.03%) </td><td> 0 </td><td> -3.14159265 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>+0.9829</td></tr></table>

# %%
res1 = (-5*np.pi-2.52732437)/(2*np.pi*0.69689338)
res1
# Out:
# -4.164533986938016

# %%
result2
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>31</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 9.8261e-09</td><td></td></tr><tr><td>reduced chi-square</td><td> 1.0130e-10</td><td></td></tr><tr><td>Akaike info crit.</td><td>-2320.38804</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-2309.92756</td><td></td></tr><tr><td>R-squared</td><td> 0.96921140</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  7.9659e-05 </td><td>  1.4515e-06 </td><td> (1.82%) </td><td> 7e-05 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td> -3.82221987 </td><td>  0.09951453 </td><td> (2.60%) </td><td> -1.5707963267948966 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  0.93917046 </td><td>  0.00508527 </td><td> (0.54%) </td><td> 1.0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  1.2287e-05 </td><td>  1.0804e-06 </td><td> (8.79%) </td><td> 0 </td><td> -3.14159265 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>+0.9843</td></tr><tr><td>phi0</td><td>const</td><td>-0.3683</td></tr><tr><td>detun</td><td>const</td><td>-0.3681</td></tr><tr><td>amp</td><td>phi0</td><td>-0.1147</td></tr><tr><td>amp</td><td>detun</td><td>-0.1089</td></tr><tr><td>amp</td><td>const</td><td>+0.1046</td></tr></table>

# %%
res2 = (-9*np.pi+3.82221987)/(2*np.pi*0.93917046)
res2
# Out:
# -4.143736392758178

# %%
(res0+res1+res2)/3
# Out:
# -4.08722411689595

# %% [markdown]
# T1

# %%
def Dephase(delay, amp, gamma, const):
    return amp*np.exp(-gamma*delay) + const

t1 ="/2024-07-30/2024-07-30T122104_c0b4c8fc-33_ef_T1"

dd_t1 = datadict_from_hdf5(header + t1 +"/data")

# %%
s11_t1 = dd_t1['s11']['values']
delay_t1 = dd_t1['delay']['values']
I_t1 = (s11_t1.real)
Q_t1 = (s11_t1.imag)
PCA_t1 = PCA_transform(I_t1, Q_t1)

y_t1 = PCA_t1[0]
x_t1 = delay_t1

plt.plot(x_t1, y_t1)
plt.show()

# %%
par_ini_t1 = {'gamma': 1/4000e-3,'amp':1,'const':-2.4}
par_min_t1 = {'gamma': 0,'amp':0,'const':-np.inf}
par_max_t1 = {'gamma': np.inf,'amp':np.inf,'const':np.inf,}
par_vary_t1 = {'gamma': True,'amp':True,'const':True}

model = lmfit.Model(Dephase)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini_t1[name],
    min = par_min_t1[name],
    max = par_max_t1[name],
    vary = par_vary_t1[name]
    )
result_t1 = model.fit(data = y_t1, params = params, delay = x_t1*1e-3)
result_t1
# Out:
# <h2> Model</h2> Model(Dephase) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>17</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>3</td><td></td></tr><tr><td>chi-square</td><td> 2518.47028</td><td></td></tr><tr><td>reduced chi-square</td><td> 25.6986763</td><td></td></tr><tr><td>Akaike info crit.</td><td> 330.844931</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 338.690293</td><td></td></tr><tr><td>R-squared</td><td> 0.00334248</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  2.68044170 </td><td>  5.01426066 </td><td> (187.07%) </td><td> 1 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> gamma </td><td>  0.88727682 </td><td>  3.51684860 </td><td> (396.36%) </td><td> 0.25 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td> -0.04511717 </td><td>  0.51686019 </td><td> (1145.60%) </td><td> -2.4 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>amp</td><td>gamma</td><td>+0.3615</td></tr><tr><td>gamma</td><td>const</td><td>+0.1561</td></tr></table>

# %%
fig, ax = plt.subplots(figsize=(8,6),constrained_layout=True)
plt.rcParams["font.size"] = 20

plt.tick_params(top='on',bottom='on',left='on',right='on',)
plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result_t1.plot_fit(ax = ax)
# plt.plot(delay_t1,result_t1.init_fit)

plt.title("")
plt.legend("")
ax.set_xlabel(r'Delay $\tau$ ($\mu$s)')#, size='large')
ax.set_ylabel('S$_{11}$ (arb. u.)')
ax.set_xlim(0, 20)
ax.set_ylim(-5, 5)
# plt.savefig('ef_T1.png', bbox_inches='tight')

plt.show()

# %%
T1 = (1/0.88727682)*1e-9
T1
# Out:
# 1.127043981606552e-09

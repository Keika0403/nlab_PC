# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal
from plottr.data.datadict_storage import datadict_from_hdf5
import lmfit

from sequence_parser import Sequence, Variable, Variables
from sequence_parser.iq_port import Port
from sequence_parser.instruction import *

# %%
import sklearn
from sklearn.decomposition import PCA

# %%
def PCA_transform(Re_c, Im_c):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c]).T, np.array([Im_c]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    return c_PCA1, c_PCA2

# %% [markdown]
# ## active reset
# ef freq

# %%
def Lorentzian(freq, amp, const, center, k):
    return const - amp*k**2/((freq-center)**2 + k**2)

# %%
header = "D:/K_sunada/result/CDY168/"
ef_freq = "/2024-10-21/2024-10-21T162919_2f8f10f0-h2_active_reset_ef_freq"
dd = datadict_from_hdf5(header + ef_freq +"/data")

S11 = dd['s11']['values']
freq = dd['anhm']['values']
S11_PCA = PCA_transform(S11.real, S11.imag)[0]

plt.plot(freq, S11_PCA)

# %%
par_ini = {'amp': 5e-04,'const':-2e-5,'center':-0.372,'k':0.002}
par_min = {'amp': 0,'const':-np.inf,'center':-np.inf,'k':0}
par_max = {'amp': np.inf,'const':np.inf,'center':np.inf,'k':np.inf}
par_vary = {'amp': True,'const':True,'center':True,'k':True}

model = lmfit.Model(Lorentzian)

params = model.make_params()
for name in model.param_names:
    params[name].set(value = par_ini[name],min = par_min[name],max = par_max[name],vary = par_vary[name])
result = model.fit(data = S11_PCA, params = params, freq = freq)
result
# Out:
# <h2>Fit Result</h2> <p>Model: Model(Lorentzian)</p> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>leastsq</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>3306</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>61</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>4</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 3.3954e-08</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 5.9568e-10</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'>-1291.85767</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-align:right'>-1283.41418</td></tr><tr><td style='text-align:left'>R-squared</td><td style='text-align:right'> 0.95486564</td></tr></table><table class="jp-toc-ignore"><caption>Parameters</caption><tr><th style='text-align:left'>name</th><th style='text-align:left'>value</th><th style='text-align:left'>standard error</th><th style='text-align:left'>relative error</th><th style='text-align:left'>initial value</th><th style='text-align:left'>min</th><th style='text-align:left'>max</th><th style='text-align:right'>vary</th></tr><tr><td style='text-align:left'>amp</td><td style='text-align:left'> 41.8185750</td><td style='text-align:left'> 811993.266</td><td style='text-align:left'>(1941704.77%)</td><td style='text-align:left'>0.0005</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>const</td><td style='text-align:left'> 2.4229e-05</td><td style='text-align:left'> 3.3954e-06</td><td style='text-align:left'>(14.01%)</td><td style='text-align:left'>-2e-05</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>center</td><td style='text-align:left'>-0.37226660</td><td style='text-align:left'> 5.9786e-06</td><td style='text-align:left'>(0.00%)</td><td style='text-align:left'>-0.372</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>k</td><td style='text-align:left'> 9.4425e-07</td><td style='text-align:left'> 0.00919766</td><td style='text-align:left'>(974071.00%)</td><td style='text-align:left'>0.002</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr></table><table class="jp-toc-ignore"><caption>Correlations (unreported values are < 0.100)</caption><tr><th style='text-align:left'>Parameter1</th><th style='text-align:left'>Parameter 2</th><th style='text-align:right'>Correlation</th></tr><tr><td style='text-align:left'>amp</td><td style='text-align:left'>k</td><td style='text-align:right'>-1.0000</td></tr><tr><td style='text-align:left'>amp</td><td style='text-align:left'>center</td><td style='text-align:right'>+0.7914</td></tr><tr><td style='text-align:left'>center</td><td style='text-align:left'>k</td><td style='text-align:right'>-0.7914</td></tr><tr><td style='text-align:left'>const</td><td style='text-align:left'>k</td><td style='text-align:right'>+0.3310</td></tr><tr><td style='text-align:left'>amp</td><td style='text-align:left'>const</td><td style='text-align:right'>-0.3310</td></tr><tr><td style='text-align:left'>const</td><td style='text-align:left'>center</td><td style='text-align:right'>-0.2414</td></tr></table>

# %%
fig, ax = plt.subplots(figsize=(8,6),constrained_layout=True)
plt.rcParams["font.size"] = 20
plt.tick_params(top='on',bottom='on',left='on',right='on',)
plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result.plot_fit(ax = ax)
plt.plot(freq, result.init_fit)
# plt.xlim(7.95, 8.065)

plt.title("")
plt.legend("")
plt.xlabel("Drive frequency $\omega_\mathrm{d}$ (GHz)")
plt.ylabel("$S_{11}$ (arb. u.)")
# plt.savefig('ge_peak.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ef amplitude

# %%
ef_amp =  "/2024-10-21/2024-10-21T163058_6a82da2f-h3_active_reset_ef_amp"
dd = datadict_from_hdf5(header + ef_amp +"/data")

S11 = dd['s11']['values'][0:60]
freq = dd['amplitude']['values'][0:60]
S11_PCA = PCA_transform(S11.real, S11.imag)[0]

plt.plot(freq, S11_PCA)

# %%
def cos(x, amp, freq, phi, const):
    return amp * np.cos(2*np.pi*x*freq+phi) + const

# %%
par_ini= {'amp': 0.0004,'freq':1/0.012,'phi':np.pi,'const':0}
par_min= {'amp': 0,'freq':0,'phi':-2*np.pi,'const':-np.inf}
par_max= {'amp': np.inf,'freq':np.inf,'phi':2*np.pi,'const':np.inf}
par_vary= {'amp': True,'freq': True,'phi': True,'const': True}

model = lmfit.Model(cos)

params = model.make_params()
for name in model.param_names:
    params[name].set(value = par_ini[name],min = par_min[name],max = par_max[name],vary = par_vary[name])
result = model.fit(data = -S11_PCA, params = params, x = freq)
result
# Out:
# <h2>Fit Result</h2> <p>Model: Model(cos)</p> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>leastsq</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>31</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>51</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>4</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 3.6013e-08</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 7.6624e-10</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'>-1066.63161</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-align:right'>-1058.90431</td></tr><tr><td style='text-align:left'>R-squared</td><td style='text-align:right'> 0.99098338</td></tr></table><table class="jp-toc-ignore"><caption>Parameters</caption><tr><th style='text-align:left'>name</th><th style='text-align:left'>value</th><th style='text-align:left'>standard error</th><th style='text-align:left'>relative error</th><th style='text-align:left'>initial value</th><th style='text-align:left'>min</th><th style='text-align:left'>max</th><th style='text-align:right'>vary</th></tr><tr><td style='text-align:left'>amp</td><td style='text-align:left'> 3.9584e-04</td><td style='text-align:left'> 5.5089e-06</td><td style='text-align:left'>(1.39%)</td><td style='text-align:left'>0.0004</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>freq</td><td style='text-align:left'> 86.2888932</td><td style='text-align:left'> 0.14884204</td><td style='text-align:left'>(0.17%)</td><td style='text-align:left'>83.33333333333333</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>phi</td><td style='text-align:left'> 3.07182786</td><td style='text-align:left'> 0.02783038</td><td style='text-align:left'>(0.91%)</td><td style='text-align:left'>3.141592653589793</td><td style='text-align:left'>-6.28318531</td><td style='text-align:left'> 6.28318531</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>const</td><td style='text-align:left'> 1.6755e-05</td><td style='text-align:left'> 3.8963e-06</td><td style='text-align:left'>(23.25%)</td><td style='text-align:left'>0</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr></table><table class="jp-toc-ignore"><caption>Correlations (unreported values are < 0.100)</caption><tr><th style='text-align:left'>Parameter1</th><th style='text-align:left'>Parameter 2</th><th style='text-align:right'>Correlation</th></tr><tr><td style='text-align:left'>freq</td><td style='text-align:left'>phi</td><td style='text-align:right'>-0.8673</td></tr></table>

# %%
fig, ax = plt.subplots(figsize=(8,6),constrained_layout=True)
plt.rcParams["font.size"] = 20
plt.tick_params(top='on',bottom='on',left='on',right='on',)
plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result.plot_fit(ax = ax)
plt.plot(freq, result.init_fit)
# plt.xlim(7.95, 8.065)

plt.title("")
plt.legend("")
plt.xlabel("Drive frequency $\omega_\mathrm{d}$ (GHz)")
plt.ylabel("$S_{11}$ (arb. u.)")
# plt.savefig('ge_peak.png', bbox_inches='tight')
plt.show()

# %%
(2*np.pi-3.07182786)/(2*np.pi*86.2888932)
# Out:
# 0.00592316569142877

# %% [markdown]
# ## FFT

# %%
def FFT(x, y):
    off_ini = np.mean(y)
    y_mod = y - off_ini
    Y = np.abs(np.fft.fft(y_mod))
    dt = 2e-9
    N = len(y)
    t = x
    f = np.fft.fftfreq(N, dt)
    sorted_idx=np.argsort(f)
    x_fft = f[sorted_idx]
    y_fft = Y[sorted_idx]
    return x_fft, y_fft

# %%
def LPF(x, samplerate, fp, fs, gpass, gstop):
    fn = samplerate/2
    wp = fp/fn
    ws = fs/fn
    N, Wn = signal.buttord(wp, ws, gpass, gstop)
    b, a = signal.butter(N, Wn, "low")
    y = signal.filtfilt(b, a, x)
    return y

# %% [markdown]
# ## 10/13 photon shape & photon number

# %%
header = "D:/K_sunada/result/CDY168/"
atten = -105.96 #dBm

# %%
from scipy.constants import *

# %%
def watt_dbm(watt):
    return 10*np.log10(watt*1e3)

def dbm_watt(dBm):
    return (10**(dBm/10))*1e-3

# %%
def photon_number(pulse, freq, atten, sample_rate):
    #pulse: [x, y, env], atten: dBm, samplerate: s, P_vna: W (AWG amp=1.0)
    x = pulse[0]
    y = pulse[2] #env

    atten_W = dbm_watt(atten)
    ene = 0
    for t in range(int(len(x)/2)):
        ene = ene + (y[2*t]**2)*sample_rate

    return ene * atten_W / (2*np.pi*hbar*freq)

# %% [markdown]
# ## Photon shape

# %%
readout_lo_freq = 9.5e9
target_freq = 9.35e9
ph_if = readout_lo_freq - target_freq
duration = 1000
const = 2.5e-3 * 2 * np.pi
sample_rate = 2e-9
amp = 0.07

# %%
## sech_0
x = np.arange(0, 1001, 2)
y_env = (const/2)**0.5/np.cosh(const * (x - duration/2)) * amp
y = (const/2)**0.5/np.cosh(const * (x - duration/2))*np.cos(2*np.pi* ph_if*x*1e-9) * amp
plt.plot(x, y_env)
plt.plot(x, y)

pulse = [x, y, y_env]
photon_number(pulse, target_freq, atten, sample_rate)
# Out:
# 0.010025321596313717

# %%
## sech_1
y_env = (6*const**3/(np.pi**2))**0.5*(x - duration/2)/np.cosh(const * (x - duration/2)) * amp
y = (6*const**3/(np.pi**2))**0.5*(x - duration/2)/np.cosh(const * (x - duration/2))*np.cos(2*np.pi* ph_if*x*1e-9) * amp
plt.plot(x, y_env)
plt.plot(x, y)


pulse = [x, y, y_env]
photon_number(pulse, target_freq, atten, sample_rate)
# Out:
# 0.020365318460978967

# %%
## sech_2
y_env = (45*(2*const)**5/64/(np.pi**4))**0.5*((x - duration/2)**2-(np.pi/2/const)**2/3)/np.cosh(const * (x - duration/2)) * amp
y = (45*(2*const)**5/64/(np.pi**4))**0.5*((x - duration/2)**2-(np.pi/2/const)**2/3)/np.cosh(const * (x - duration/2))*np.cos(2*np.pi* ph_if*x*1e-9) * amp
plt.plot(x, y_env)
plt.plot(x, y)


pulse = [x, y, y_env]
photon_number(pulse, target_freq, atten, sample_rate)
# Out:
# 0.020352022707611432

# %%
## sech_3
y_env = (175*(2*const)**7)**0.5/24/(np.pi**3)*((x - duration/2)**3-(7*(x - duration/2)*(np.pi/(2*const))**2/5))/np.cosh(const * (x - duration/2)) * amp
y = (175*(2*const)**7)**0.5/24/(np.pi**3)*((x - duration/2)**3-(7*(x - duration/2)*(np.pi/(2*const))**2/5))/np.cosh(const * (x - duration/2))*np.cos(2*np.pi* ph_if*x*1e-9) * amp
plt.plot(x, y_env)
plt.plot(x, y)


pulse = [x, y, y_env]
photon_number(pulse, target_freq, atten, sample_rate)
# Out:
# 0.020202799427517626

# %%
amp = 0.011

y_env0 = 1/np.cosh(const * (x - duration/2))
y_env1 = (x - duration/2)/np.cosh(const * (x - duration/2)) 
m = sum(np.abs(y_env0))/sum(np.abs(y_env1))
y_env = (y_env0 + y_env1*m)* amp
y = y_env*np.cos(2*np.pi* ph_if*x*1e-9) * amp
plt.plot(x, y_env)
plt.plot(x, y)


pulse = [x, y, y_env]
photon_number(pulse, target_freq, atten, sample_rate)
# Out:
# 0.03352424221193056

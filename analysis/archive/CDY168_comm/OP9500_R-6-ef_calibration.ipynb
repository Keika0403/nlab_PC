# %% [markdown]
# ## 10/21 ef calibration - OP9500_read

# %% [markdown]
# ef_freq =
#
# ef_pi_amp = 0.875
#
#
# T1 = 20e-6

# %%
from plottr.data.datadict_storage import datadict_from_hdf5
import numpy as np
import matplotlib.pyplot as plt
import lmfit

import sklearn
from sklearn.decomposition import PCA

# %%
def PCA_transform(Re_c, Im_c):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c]).T, np.array([Im_c]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    return c_PCA1, c_PCA2

# %%
def Rabi(delay, amp, phi0, detun, const):
    return - amp * np.cos(2*np.pi*detun*delay+phi0) + const

# %% [markdown]
# amp

# %%
header = "D:/K_sunada/result/CDY168"
ef = "/2024-10-21/2024-10-21T153014_ee94a3f7-d0_ef_pi_amp"
dd_ef = datadict_from_hdf5(header + ef +"/data")

Rabi_ef = dd_ef['s11']['values']
amp_ef = dd_ef['amplitude']['values']
I = (Rabi_ef.real)
Q = (Rabi_ef.imag)
PCAef = PCA_transform(I, Q)

y = PCAef[0]
x = amp_ef
plt.plot(x, y)
plt.show()

# %%
par_ini= {'amp': 0.001,'phi0':np.pi,'detun':1/0.25,'const':0}
par_min = {'amp': 0,'phi0':-2*np.pi,'detun':-np.inf,'const':-np.inf}
par_max = {'amp': np.inf,'phi0':2*np.pi,'detun':np.inf,'const':np.inf,}
par_vary = {'amp': True,'phi0':True,'detun':True,'const':True}

model = lmfit.Model(Rabi)

params = model.make_params()
for name in model.param_names:
    params[name].set(value = par_ini[name],min = par_min[name],max = par_max[name],vary = par_vary[name])

result_ef = model.fit(data = y, params = params, delay = x)
result_ef
# Out:
# <h2>Fit Result</h2> <p>Model: Model(Rabi)</p> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>leastsq</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>31</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>21</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>4</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 3.4244e-07</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 2.0144e-08</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'>-368.565308</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-align:right'>-364.387219</td></tr><tr><td style='text-align:left'>R-squared</td><td style='text-align:right'> 0.96639706</td></tr></table><table class="jp-toc-ignore"><caption>Parameters</caption><tr><th style='text-align:left'>name</th><th style='text-align:left'>value</th><th style='text-align:left'>standard error</th><th style='text-align:left'>relative error</th><th style='text-align:left'>initial value</th><th style='text-align:left'>min</th><th style='text-align:left'>max</th><th style='text-align:right'>vary</th></tr><tr><td style='text-align:left'>amp</td><td style='text-align:left'> 9.5164e-04</td><td style='text-align:left'> 4.3054e-05</td><td style='text-align:left'>(4.52%)</td><td style='text-align:left'>0.001</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>phi0</td><td style='text-align:left'> 3.36051811</td><td style='text-align:left'> 0.09438204</td><td style='text-align:left'>(2.81%)</td><td style='text-align:left'>3.141592653589793</td><td style='text-align:left'>-6.28318531</td><td style='text-align:left'> 6.28318531</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>detun</td><td style='text-align:left'> 4.02598259</td><td style='text-align:left'> 0.02610276</td><td style='text-align:left'>(0.65%)</td><td style='text-align:left'>4.0</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>const</td><td style='text-align:left'>-4.7957e-05</td><td style='text-align:left'> 3.1378e-05</td><td style='text-align:left'>(65.43%)</td><td style='text-align:left'>0</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr></table><table class="jp-toc-ignore"><caption>Correlations (unreported values are < 0.100)</caption><tr><th style='text-align:left'>Parameter1</th><th style='text-align:left'>Parameter 2</th><th style='text-align:right'>Correlation</th></tr><tr><td style='text-align:left'>phi0</td><td style='text-align:left'>detun</td><td style='text-align:right'>-0.8671</td></tr><tr><td style='text-align:left'>detun</td><td style='text-align:left'>const</td><td style='text-align:right'>-0.1433</td></tr><tr><td style='text-align:left'>phi0</td><td style='text-align:left'>const</td><td style='text-align:right'>+0.1344</td></tr></table>

# %%
fig, ax = plt.subplots(figsize=(8,6),constrained_layout=True)
plt.rcParams["font.size"] = 20
# plt.title("Rabi(amp)")
plt.tick_params(top='on',bottom='on',left='on',right='on',)
plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result_ef.plot_fit(ax = ax)
plt.plot(amp_ef,result_ef.init_fit)

plt.title("")
plt.legend("")
ax.set_xlabel('$\pi_{ef}$ pulse DAC amplitude (V)', size='large')
ax.set_ylabel('S$_{11}$ (arb. u.)', size='large')
# ax.set_ylim(-40, 40)
ax.set_xlim(0, 1.)
# plt.savefig('ef_rabi.png', bbox_inches='tight')
plt.show()

# %%
np.pi/(4.02598259*2*np.pi)*5
# Out:
# 0.6209664210197193

# %% [markdown]
# ramsey

# %%
pl = "/2024-10-21/2024-10-21T153138_20bb2bfe-d2_ef_T2r1d"
mi = "/2024-10-21/2024-10-21T153232_40b40667-d2_ef_T2r1d"
dd_pl = datadict_from_hdf5(header + pl +"/data")
dd_mi = datadict_from_hdf5(header + mi +"/data")

# %%
Rabi_pl = dd_pl['s11']['values']
delay_pl = dd_pl['delay']['values']
Rabi_mi = dd_mi['s11']['values']
delay_mi = dd_mi['delay']['values']

I_pl = (Rabi_pl.real)
Q_pl = (Rabi_pl.imag)
I_mi = (Rabi_mi.real)
Q_mi = (Rabi_mi.imag)

PCA_pl = PCA_transform(I_pl, Q_pl)
y_pl = PCA_pl[0]
x_pl = delay_pl

PCA_mi = PCA_transform(I_mi, Q_mi)
y_mi = PCA_mi[0]
x_mi = delay_mi

fig, ax = plt.subplots(1,2,figsize=(12,6),constrained_layout=True)
ax[0].plot(x_pl, y_pl)
ax[1].plot(x_mi, y_mi)
plt.show()

# %%
par_ini_pl = {'amp': 0.0004,'phi0':np.pi,'detun':1/200,'const':0.}
par_ini_mi = {'amp': 0.0004,'phi0':np.pi,'detun':1/200,'const':0.}
par_min = {'amp': 0,'phi0':-2*np.pi,'detun':-np.inf,'const':0}
par_max = {'amp': np.inf,'phi0':2*np.pi,'detun':np.inf,'const':np.inf,}
par_vary = {'amp': True,'phi0':True,'detun':True,'const':True}

model = lmfit.Model(Rabi)

# %%
params_pl = model.make_params()
for name in model.param_names:
    params_pl[name].set(value = par_ini_pl[name],min = par_min[name],max = par_max[name],vary = par_vary[name])
    
result_pl = model.fit(data = y_pl, params = params_pl, delay = x_pl)
result_pl
# Out:
# <h2>Fit Result</h2> <p>Model: Model(Rabi)</p> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>leastsq</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>87</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>51</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>4</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 3.4995e-08</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 7.4458e-10</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'>-1068.09404</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-align:right'>-1060.36673</td></tr><tr><td style='text-align:left'>R-squared</td><td style='text-align:right'> 0.99091997</td></tr></table><table class="jp-toc-ignore"><caption>Parameters</caption><tr><th style='text-align:left'>name</th><th style='text-align:left'>value</th><th style='text-align:left'>initial value</th><th style='text-align:left'>min</th><th style='text-align:left'>max</th><th style='text-align:right'>vary</th></tr><tr><td style='text-align:left'>amp</td><td style='text-align:left'> 3.8971e-04</td><td style='text-align:left'>0.0004</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>phi0</td><td style='text-align:left'> 4.21356703</td><td style='text-align:left'>3.141592653589793</td><td style='text-align:left'>-6.28318531</td><td style='text-align:left'> 6.28318531</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>detun</td><td style='text-align:left'> 0.00501605</td><td style='text-align:left'>0.005</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>const</td><td style='text-align:left'> 4.8876e-12</td><td style='text-align:left'>0.0</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr></table>

# %%
params_mi = model.make_params()
for name in model.param_names:
    params_mi[name].set(value = par_ini_mi[name],min = par_min[name],max = par_max[name],vary = par_vary[name])
    
result_mi = model.fit(data = y_mi, params = params_mi, delay = x_mi)
result_mi
# Out:
# <h2>Fit Result</h2> <p>Model: Model(Rabi)</p> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>leastsq</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>96</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>51</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>4</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 3.9450e-08</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 8.3937e-10</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'>-1061.98262</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-align:right'>-1054.25532</td></tr><tr><td style='text-align:left'>R-squared</td><td style='text-align:right'> 0.99040299</td></tr></table><table class="jp-toc-ignore"><caption>Parameters</caption><tr><th style='text-align:left'>name</th><th style='text-align:left'>value</th><th style='text-align:left'>initial value</th><th style='text-align:left'>min</th><th style='text-align:left'>max</th><th style='text-align:right'>vary</th></tr><tr><td style='text-align:left'>amp</td><td style='text-align:left'> 3.9734e-04</td><td style='text-align:left'>0.0004</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>phi0</td><td style='text-align:left'> 3.61947853</td><td style='text-align:left'>3.141592653589793</td><td style='text-align:left'>-6.28318531</td><td style='text-align:left'> 6.28318531</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>detun</td><td style='text-align:left'> 0.00499384</td><td style='text-align:left'>0.005</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>const</td><td style='text-align:left'> 8.4621e-13</td><td style='text-align:left'>0.0</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr></table>

# %%
fig, ax = plt.subplots(1,2,figsize=(12,6),constrained_layout=True)
plt.rcParams["font.size"] = 20

plt.tick_params(top='on',bottom='on',left='on',right='on',)

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result_pl.plot_fit(ax = ax[0])
ax[0].plot(x_pl,result_pl.init_fit)
result_mi.plot_fit(ax = ax[1])
ax[1].plot(x_mi,result_mi.init_fit)

plt.title("")
plt.legend("")
plt.xlabel(r"Delay ${\tau}$ (ns)")
plt.ylabel("$S_{11}$ (arb. u.)")
plt.xlim(0, 1000)
# plt.savefig('ef_ramsey_exp.png', bbox_inches='tight')
plt.show()

# %%
detun = ((0.005-0.00501605)+ (0.00499384-0.005))/2 #GHz
detun
# Out:
# -1.1104999999999969e-05

# %% [markdown]
# drag

# %%
drag = "/2024-10-21/2024-10-21T153429_8626a583-d1_ef_pi_drag" #n=7
dd_drag = datadict_from_hdf5(header + drag +"/data")

drag1 = "/2024-10-21/2024-10-21T153609_c22fe5b0-d1_ef_pi_drag" #n=11
dd_drag1 = datadict_from_hdf5(header + drag1 +"/data")

drag2 = "/2024-10-21/2024-10-21T153716_ea0c0e81-d1_ef_pi_drag" #n=17
dd_drag2 = datadict_from_hdf5(header + drag2 +"/data")

# %%
Rabi_drag = dd_drag['s11']['values']
drag = dd_drag['beta']['values']
I_drag = (Rabi_drag.real)
Q_drag = (Rabi_drag.imag)

Rabi_drag1 = dd_drag1['s11']['values']
drag1 = dd_drag1['beta']['values']
I_drag1 = (Rabi_drag1.real)
Q_drag1 = (Rabi_drag1.imag)

Rabi_drag2 = dd_drag2['s11']['values']
drag2 = dd_drag2['beta']['values']
I_drag2 = (Rabi_drag2.real)
Q_drag2 = (Rabi_drag2.imag)

# %%
def PCA_transform1(Re_c_amp, Im_c_amp, Re_c_drag, Im_c_drag):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c_amp]).T, np.array([Im_c_amp]).T], axis = 1)
    c1_data = np.concatenate([np.array([Re_c_drag]).T, np.array([Im_c_drag]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    
    c1_pca = pca.transform(c1_data)
    c1_PCA1 = c1_pca.T[0]
    c1_PCA2 = c1_pca.T[1]
    return c_PCA1, c_PCA2, c1_PCA1, c1_PCA2,

# %%
PCA_drag = PCA_transform1(I_drag, Q_drag, I_drag, Q_drag)
y = PCA_drag[0]
y0 = PCA_drag[2]
x0 = drag

PCA_drag1 = PCA_transform1(I_drag, Q_drag, I_drag1, Q_drag1)
y1 = PCA_drag1[2]
x1 = drag1

PCA_drag2 = PCA_transform1(I_drag, Q_drag, I_drag2, Q_drag2)
y2 = PCA_drag2[2]
x2 = drag2

# %%
plt.plot(x0, y0)
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.show()

# %%
par_ini= {'amp': 0.0004,'phi0':np.pi/2,'detun':1/0.3,'const':0}
par_min = {'amp': 0,'phi0':-2*np.pi,'detun':-np.inf,'const':-np.pi}
par_max = {'amp': np.inf,'phi0':2*np.pi,'detun':np.inf,'const':np.inf,}
par_vary = {'amp': True,'phi0':True,'detun':True,'const':True}
model = lmfit.Model(Rabi)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )
    
result0 = model.fit(data = y0, params = params, delay = x0)
result1 = model.fit(data = y1, params = params, delay = x1)
result2 = model.fit(data = y2, params = params, delay = x2)

# %%
fig, ax = plt.subplots(1,3,figsize=(18,6),constrained_layout=True)
plt.title("Rabi(drag)")
plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result0.plot_fit(ax = ax[0])
ax[0].plot(x0,result0.init_fit)
result1.plot_fit(ax = ax[1])
ax[1].plot(x1,result1.init_fit)
result2.plot_fit(ax = ax[2])
ax[2].plot(x2,result2.init_fit)
plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")
plt.show()

# %%
result0
# Out:
# <h2>Fit Result</h2> <p>Model: Model(Rabi)</p> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>leastsq</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>42</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>101</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>4</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 9.5820e-08</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 9.8783e-10</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'>-2090.36759</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-align:right'>-2079.90711</td></tr><tr><td style='text-align:left'>R-squared</td><td style='text-align:right'> 0.99116710</td></tr></table><table class="jp-toc-ignore"><caption>Parameters</caption><tr><th style='text-align:left'>name</th><th style='text-align:left'>value</th><th style='text-align:left'>standard error</th><th style='text-align:left'>relative error</th><th style='text-align:left'>initial value</th><th style='text-align:left'>min</th><th style='text-align:left'>max</th><th style='text-align:right'>vary</th></tr><tr><td style='text-align:left'>amp</td><td style='text-align:left'> 4.5900e-04</td><td style='text-align:left'> 4.4012e-06</td><td style='text-align:left'>(0.96%)</td><td style='text-align:left'>0.0004</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>phi0</td><td style='text-align:left'>-2.12994298</td><td style='text-align:left'> 0.00971163</td><td style='text-align:left'>(0.46%)</td><td style='text-align:left'>-1.5707963267948966</td><td style='text-align:left'>-6.28318531</td><td style='text-align:left'> 6.28318531</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>detun</td><td style='text-align:left'> 1.41000386</td><td style='text-align:left'> 0.00134087</td><td style='text-align:left'>(0.10%)</td><td style='text-align:left'>1.6666666666666667</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>const</td><td style='text-align:left'> 1.1155e-05</td><td style='text-align:left'> 3.1375e-06</td><td style='text-align:left'>(28.13%)</td><td style='text-align:left'>0</td><td style='text-align:left'>-3.14159265</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr></table>

# %%
res0 = (-3*np.pi+2.12994298)/(2*np.pi*1.41000386)
res0
# Out:
# -0.8234084169309422

# %%
result1
# Out:
# <h2>Fit Result</h2> <p>Model: Model(Rabi)</p> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>leastsq</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>26</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>101</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>4</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 1.1149e-07</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 1.1494e-09</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'>-2075.06528</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-align:right'>-2064.60480</td></tr><tr><td style='text-align:left'>R-squared</td><td style='text-align:right'> 0.98827997</td></tr></table><table class="jp-toc-ignore"><caption>Parameters</caption><tr><th style='text-align:left'>name</th><th style='text-align:left'>value</th><th style='text-align:left'>standard error</th><th style='text-align:left'>relative error</th><th style='text-align:left'>initial value</th><th style='text-align:left'>min</th><th style='text-align:left'>max</th><th style='text-align:right'>vary</th></tr><tr><td style='text-align:left'>amp</td><td style='text-align:left'> 4.3077e-04</td><td style='text-align:left'> 4.7634e-06</td><td style='text-align:left'>(1.11%)</td><td style='text-align:left'>0.0004</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>phi0</td><td style='text-align:left'>-2.10738209</td><td style='text-align:left'> 0.01110543</td><td style='text-align:left'>(0.53%)</td><td style='text-align:left'>-1.5707963267948966</td><td style='text-align:left'>-6.28318531</td><td style='text-align:left'> 6.28318531</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>detun</td><td style='text-align:left'> 2.61886586</td><td style='text-align:left'> 0.00152088</td><td style='text-align:left'>(0.06%)</td><td style='text-align:left'>2.5</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>const</td><td style='text-align:left'> 2.3586e-05</td><td style='text-align:left'> 3.3767e-06</td><td style='text-align:left'>(14.32%)</td><td style='text-align:left'>0</td><td style='text-align:left'>-3.14159265</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr></table>

# %%
res1 = (-5*np.pi+2.10738209)/(2*np.pi*2.61886586)
res1
# Out:
# -0.8265408917863286

# %%
result2
# Out:
# <h2>Fit Result</h2> <p>Model: Model(Rabi)</p> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>leastsq</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>26</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>101</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>4</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 2.3021e-07</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 2.3733e-09</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'>-2001.83756</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-align:right'>-1991.37708</td></tr><tr><td style='text-align:left'>R-squared</td><td style='text-align:right'> 0.97518722</td></tr></table><table class="jp-toc-ignore"><caption>Parameters</caption><tr><th style='text-align:left'>name</th><th style='text-align:left'>value</th><th style='text-align:left'>standard error</th><th style='text-align:left'>relative error</th><th style='text-align:left'>initial value</th><th style='text-align:left'>min</th><th style='text-align:left'>max</th><th style='text-align:right'>vary</th></tr><tr><td style='text-align:left'>amp</td><td style='text-align:left'> 4.2204e-04</td><td style='text-align:left'> 6.8357e-06</td><td style='text-align:left'>(1.62%)</td><td style='text-align:left'>0.0004</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>phi0</td><td style='text-align:left'> 2.08860884</td><td style='text-align:left'> 0.01629588</td><td style='text-align:left'>(0.78%)</td><td style='text-align:left'>1.5707963267948966</td><td style='text-align:left'>-6.28318531</td><td style='text-align:left'> 6.28318531</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>detun</td><td style='text-align:left'> 3.42158745</td><td style='text-align:left'> 0.00223761</td><td style='text-align:left'>(0.07%)</td><td style='text-align:left'>3.3333333333333335</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>const</td><td style='text-align:left'> 1.9906e-05</td><td style='text-align:left'> 4.8498e-06</td><td style='text-align:left'>(24.36%)</td><td style='text-align:left'>0</td><td style='text-align:left'>-3.14159265</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr></table>

# %%
res2 = (-5*np.pi-2.08860884)/(2*np.pi*3.42158745)
res2
# Out:
# -0.8278065261992439

# %%
beta = (res0 + res1 + res2)/3
beta
# Out:
# -0.8259186116388383

# %% [markdown]
# half drag

# %%
drag = "/2024-10-21/2024-10-21T154226_a297041f-d1_ef_half_pi_drag" #n=7
dd_drag = datadict_from_hdf5(header + drag +"/data")

drag1 = "/2024-10-21/2024-10-21T154324_c50190ff-d1_ef_half_pi_drag" #n=13
dd_drag1 = datadict_from_hdf5(header + drag1 +"/data")

drag2 = "/2024-10-21/2024-10-21T154719_513fd231-d1_ef_half_pi_drag" #n=17
dd_drag2 = datadict_from_hdf5(header + drag2 +"/data")

# %%
Rabi_drag = dd_drag['s11']['values']
drag = dd_drag['beta']['values']
I_drag = (Rabi_drag.real)
Q_drag = (Rabi_drag.imag)

Rabi_drag1 = dd_drag1['s11']['values']
drag1 = dd_drag1['beta']['values']
I_drag1 = (Rabi_drag1.real)
Q_drag1 = (Rabi_drag1.imag)

Rabi_drag2 = dd_drag2['s11']['values']
drag2 = dd_drag2['beta']['values']
I_drag2 = (Rabi_drag2.real)
Q_drag2 = (Rabi_drag2.imag)

# %%
PCA_drag = PCA_transform1(I_drag, Q_drag, I_drag, Q_drag)
y = PCA_drag[0]
y0 = PCA_drag[2]
x0 = drag

PCA_drag1 = PCA_transform1(I_drag, Q_drag, I_drag1, Q_drag1)
y1 = PCA_drag1[2]
x1 = drag1

PCA_drag2 = PCA_transform1(I_drag, Q_drag, I_drag2, Q_drag2)
y2 = PCA_drag2[2]
x2 = drag2

# %%
plt.plot(x0, y0)
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.show()

# %%
par_ini= {'amp': 0.0003,'phi0':np.pi/2,'detun':1/1,'const':0}
par_min = {'amp': 0,'phi0':-2*np.pi,'detun':-np.inf,'const':-np.pi}
par_max = {'amp': np.inf,'phi0':2*np.pi,'detun':np.inf,'const':np.inf,}
par_vary = {'amp': True,'phi0':True,'detun':True,'const':True}
model = lmfit.Model(Rabi)

model = lmfit.Model(Rabi)
params = model.make_params()
for name in model.param_names:
    params[name].set(value = par_ini[name],min = par_min[name],max = par_max[name],vary = par_vary[name])
    
result0 = model.fit(data = y0, params = params, delay = x0)
result1 = model.fit(data = y1, params = params, delay = x1)
result2 = model.fit(data = y2, params = params, delay = x2)

# %%
fig, ax = plt.subplots(1,3,figsize=(18,6),constrained_layout=True)
plt.title("Rabi(drag)")
plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result0.plot_fit(ax = ax[0])
ax[0].plot(x0,result0.init_fit)
result1.plot_fit(ax = ax[1])
ax[1].plot(x1,result1.init_fit)
result2.plot_fit(ax = ax[2])
ax[2].plot(x2,result2.init_fit)
plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")
plt.show()

# %%
result0
# Out:
# <h2>Fit Result</h2> <p>Model: Model(Rabi)</p> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>leastsq</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>26</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>101</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>4</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 9.4182e-08</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 9.7095e-10</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'>-2092.10852</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-align:right'>-2081.64804</td></tr><tr><td style='text-align:left'>R-squared</td><td style='text-align:right'> 0.96940101</td></tr></table><table class="jp-toc-ignore"><caption>Parameters</caption><tr><th style='text-align:left'>name</th><th style='text-align:left'>value</th><th style='text-align:left'>standard error</th><th style='text-align:left'>relative error</th><th style='text-align:left'>initial value</th><th style='text-align:left'>min</th><th style='text-align:left'>max</th><th style='text-align:right'>vary</th></tr><tr><td style='text-align:left'>amp</td><td style='text-align:left'> 2.4288e-04</td><td style='text-align:left'> 4.4024e-06</td><td style='text-align:left'>(1.81%)</td><td style='text-align:left'>0.0003</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>phi0</td><td style='text-align:left'>-0.42604107</td><td style='text-align:left'> 0.01818291</td><td style='text-align:left'>(4.27%)</td><td style='text-align:left'>0</td><td style='text-align:left'>-6.28318531</td><td style='text-align:left'> 6.28318531</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>detun</td><td style='text-align:left'> 0.49623103</td><td style='text-align:left'> 0.00270935</td><td style='text-align:left'>(0.55%)</td><td style='text-align:left'>0.5</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>const</td><td style='text-align:left'> 5.2693e-07</td><td style='text-align:left'> 3.3261e-06</td><td style='text-align:left'>(631.21%)</td><td style='text-align:left'>0</td><td style='text-align:left'>-3.14159265</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr></table><table class="jp-toc-ignore"><caption>Correlations (unreported values are < 0.100)</caption><tr><th style='text-align:left'>Parameter1</th><th style='text-align:left'>Parameter 2</th><th style='text-align:right'>Correlation</th></tr><tr><td style='text-align:left'>detun</td><td style='text-align:left'>const</td><td style='text-align:right'>+0.3619</td></tr><tr><td style='text-align:left'>phi0</td><td style='text-align:left'>detun</td><td style='text-align:right'>-0.1124</td></tr></table>

# %%
res0 = (0.42604107-np.pi)/(2*np.pi*0.49623103)
res0
# Out:
# -0.870952100172655

# %%
result1
# Out:
# <h2>Fit Result</h2> <p>Model: Model(Rabi)</p> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>leastsq</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>26</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>101</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>4</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 1.5301e-07</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 1.5774e-09</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'>-2043.09629</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-align:right'>-2032.63581</td></tr><tr><td style='text-align:left'>R-squared</td><td style='text-align:right'> 0.94650315</td></tr></table><table class="jp-toc-ignore"><caption>Parameters</caption><tr><th style='text-align:left'>name</th><th style='text-align:left'>value</th><th style='text-align:left'>standard error</th><th style='text-align:left'>relative error</th><th style='text-align:left'>initial value</th><th style='text-align:left'>min</th><th style='text-align:left'>max</th><th style='text-align:right'>vary</th></tr><tr><td style='text-align:left'>amp</td><td style='text-align:left'> 2.2816e-04</td><td style='text-align:left'> 5.5112e-06</td><td style='text-align:left'>(2.42%)</td><td style='text-align:left'>0.0003</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>phi0</td><td style='text-align:left'> 1.92136396</td><td style='text-align:left'> 0.02501251</td><td style='text-align:left'>(1.30%)</td><td style='text-align:left'>1.5707963267948966</td><td style='text-align:left'>-6.28318531</td><td style='text-align:left'> 6.28318531</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>detun</td><td style='text-align:left'> 0.91350758</td><td style='text-align:left'> 0.00352038</td><td style='text-align:left'>(0.39%)</td><td style='text-align:left'>1.0</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>const</td><td style='text-align:left'>-9.5954e-07</td><td style='text-align:left'> 3.9777e-06</td><td style='text-align:left'>(414.54%)</td><td style='text-align:left'>0</td><td style='text-align:left'>-3.14159265</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr></table>

# %%
res1 = (-np.pi-1.92136396)/(2*np.pi*0.91350758)
res1
# Out:
# -0.8820885445883423

# %%
result2
# Out:
# <h2>Fit Result</h2> <p>Model: Model(Rabi)</p> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>leastsq</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>68</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>101</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>4</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 1.1795e-07</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 1.2160e-09</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'>-2069.37698</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-align:right'>-2058.91650</td></tr><tr><td style='text-align:left'>R-squared</td><td style='text-align:right'> 0.95453753</td></tr></table><table class="jp-toc-ignore"><caption>Parameters</caption><tr><th style='text-align:left'>name</th><th style='text-align:left'>value</th><th style='text-align:left'>standard error</th><th style='text-align:left'>relative error</th><th style='text-align:left'>initial value</th><th style='text-align:left'>min</th><th style='text-align:left'>max</th><th style='text-align:right'>vary</th></tr><tr><td style='text-align:left'>amp</td><td style='text-align:left'> 2.2446e-04</td><td style='text-align:left'> 4.9760e-06</td><td style='text-align:left'>(2.22%)</td><td style='text-align:left'>0.0003</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>phi0</td><td style='text-align:left'> 3.51908493</td><td style='text-align:left'> 0.02161955</td><td style='text-align:left'>(0.61%)</td><td style='text-align:left'>1.5707963267948966</td><td style='text-align:left'>-6.28318531</td><td style='text-align:left'> 6.28318531</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>detun</td><td style='text-align:left'> 1.18584770</td><td style='text-align:left'> 0.00290701</td><td style='text-align:left'>(0.25%)</td><td style='text-align:left'>1.0</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>const</td><td style='text-align:left'>-3.4958e-06</td><td style='text-align:left'> 3.5025e-06</td><td style='text-align:left'>(100.19%)</td><td style='text-align:left'>0</td><td style='text-align:left'>-3.14159265</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr></table><table class="jp-toc-ignore"><caption>Correlations (unreported values are < 0.100)</caption><tr><th style='text-align:left'>Parameter1</th><th style='text-align:left'>Parameter 2</th><th style='text-align:right'>Correlation</th></tr><tr><td style='text-align:left'>detun</td><td style='text-align:left'>const</td><td style='text-align:right'>+0.1233</td></tr></table>

# %%
res2 = (-np.pi-3.51908493)/(2*np.pi*1.18584770)
res2
# Out:
# -0.893942587880127

# %%
(res0+res1+res2)/3
# Out:
# -0.8823277442137082

# %% [markdown]
# T1

# %%
def Dephase(delay, amp, gamma, const):
    return amp*np.exp(-gamma*delay) + const

t1 ="/2024-10-13/2024-10-13T131738_14f99c4f-33_ef_T1"

dd_t1 = datadict_from_hdf5(header + t1 +"/data")

# %%
s11_t1 = dd_t1['s11']['values']
delay_t1 = dd_t1['delay']['values']
I_t1 = (s11_t1.real)
Q_t1 = (s11_t1.imag)
PCA_t1 = PCA_transform(I_t1, Q_t1)

y_t1 = PCA_t1[0]
x_t1 = delay_t1

plt.plot(x_t1, y_t1)
plt.show()

# %%
par_ini_t1 = {'gamma': 1/40000e-3,'amp':1,'const':-2.4}
par_min_t1 = {'gamma': 0,'amp':0,'const':-np.inf}
par_max_t1 = {'gamma': np.inf,'amp':np.inf,'const':np.inf,}
par_vary_t1 = {'gamma': True,'amp':True,'const':True}

model = lmfit.Model(Dephase)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini_t1[name],
    min = par_min_t1[name],
    max = par_max_t1[name],
    vary = par_vary_t1[name]
    )
result_t1 = model.fit(data = y_t1, params = params, delay = x_t1*1e-3)
result_t1
# Out:
# <h2>Fit Result</h2> <p>Model: Model(Dephase)</p> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>leastsq</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>35</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>101</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>3</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 157.375885</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 1.60587637</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'> 50.7951763</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-align:right'> 58.6405378</td></tr><tr><td style='text-align:left'>R-squared</td><td style='text-align:right'> 0.97867712</td></tr></table><table class="jp-toc-ignore"><caption>Parameters</caption><tr><th style='text-align:left'>name</th><th style='text-align:left'>value</th><th style='text-align:left'>standard error</th><th style='text-align:left'>relative error</th><th style='text-align:left'>initial value</th><th style='text-align:left'>min</th><th style='text-align:left'>max</th><th style='text-align:right'>vary</th></tr><tr><td style='text-align:left'>amp</td><td style='text-align:left'> 38.2333629</td><td style='text-align:left'> 0.67758491</td><td style='text-align:left'>(1.77%)</td><td style='text-align:left'>1</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>gamma</td><td style='text-align:left'> 0.08401049</td><td style='text-align:left'> 0.00263277</td><td style='text-align:left'>(3.13%)</td><td style='text-align:left'>0.025</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>const</td><td style='text-align:left'>-4.69691674</td><td style='text-align:left'> 0.17317643</td><td style='text-align:left'>(3.69%)</td><td style='text-align:left'>-2.4</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr></table><table class="jp-toc-ignore"><caption>Correlations (unreported values are < 0.100)</caption><tr><th style='text-align:left'>Parameter1</th><th style='text-align:left'>Parameter 2</th><th style='text-align:right'>Correlation</th></tr><tr><td style='text-align:left'>gamma</td><td style='text-align:left'>const</td><td style='text-align:right'>+0.5534</td></tr><tr><td style='text-align:left'>amp</td><td style='text-align:left'>gamma</td><td style='text-align:right'>+0.5405</td></tr></table>

# %%
fig, ax = plt.subplots(figsize=(8,6),constrained_layout=True)
plt.rcParams["font.size"] = 20

plt.tick_params(top='on',bottom='on',left='on',right='on',)
plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result_t1.plot_fit(ax = ax)
# plt.plot(delay_t1,result_t1.init_fit)

plt.title("")
plt.legend("")
ax.set_xlabel(r'Delay $\tau$ ($\mu$s)')#, size='large')
ax.set_ylabel('S$_{11}$ (arb. u.)')
ax.set_xlim(0, 100)
# plt.savefig('ef_T1.png', bbox_inches='tight')

plt.show()

# %%
T1 = (1/0.08401049)*1e-9
T1
# Out:
# 1.1903275412391956e-08

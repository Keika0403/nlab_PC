# %%
from plottr.data.datadict_storage import datadict_from_hdf5
import numpy as np
import matplotlib.pyplot as plt
import lmfit
import scipy.constants as spc

# %%
res_dressed = "/2024-04-28/2024-04-28T150336_0ce4c726-cw_sparameter" # R.T.: -20dB, vna output: 0dB
punchout =  "/2024-04-28/2024-04-28T152110_813bd52a-cw_punchout"  # R.T.: -30dB, vna output: -20 ~ 10dB

# %%
header = "D:/K_sunada/result/CDY157/"
dd_d = datadict_from_hdf5(header + res_dressed +"/data")

# %% [markdown]
# dpr

# %%
def S11_dpr_model(freq, fr, ff, kf_e, kf_i, gamma, g, a0, a1, Poff,ed):
    numer = (1j*(freq-ff)+(kf_e-kf_i)/2)*(1j*(freq-fr)-gamma/2) + (g**2)
    denom = (1j*(freq-ff)-(kf_e+kf_i)/2)*(1j*(freq-fr)-gamma/2) + (g**2)
    model = (numer/denom * (a0+a1*(freq-freq[0])) * np.exp(1j*(Poff-ed*2*np.pi*(freq-freq[0])))).conj()
    return model

# %%
freq_d = dd_d['frequency']['values']
s11_d = dd_d['s21']['values']
# freq_b = dd_b['frequency']['values']
# s11_b = dd_b['s21']['values']

# %%
fig,ax = plt.subplots(1,2)
ax[0].plot(freq_d,np.abs(s11_d))
ax[1].plot(freq_d,np.angle(s11_d))

# %%
par_ini = {'fr': 9.15e9,  'ff': 8.95e9,    'kf_e': 210e6,   'kf_i': 0.e6,  'g': 82e6, 'gamma': 0.e6,
           'a0': 7e-5,  'a1': -3e-14,        'Poff': -0.2,   'ed': -6e-6}
par_min = {'fr': 0,     'ff': 0,        'kf_e': 0,        'kf_i': 0,        'g': 0,     'gamma': 0,
           'a0': -np.inf,     'a1': -np.inf,  'Poff': -np.inf,'ed': -np.inf}
par_max = {'fr': np.inf,'ff': np.inf,   'kf_e': np.inf,   'kf_i': np.inf,   'g': np.inf,'gamma': np.inf,
           'a0': np.inf,'a1': np.inf,   'Poff': np.inf, 'ed': np.inf}
par_var = {'fr': True, 'ff': True,    'kf_e': True,    'kf_i': False,    'g': True, 'gamma': False,
           'a0': True, 'a1': True,    'Poff': True,  'ed': True}

model=lmfit.Model(S11_dpr_model)
params = model.make_params()

for name in list(par_ini):
    params[name].set(value=par_ini[name])
for name in list(par_min):
    params[name].set(min=par_min[name])  
for name in list(par_max):
    params[name].set(max=par_max[name]) 
for name in list(par_var):
    params[name].set(vary=par_var[name])
    
result_d = model.fit(freq=freq_d, data=s11_d, params=params, method='leastsq')
# result_b = model.fit(freq=freq_b, data=s11_b, params=params, method='leastsq')

# %% [markdown]
# dressed

# %%
fig, ax = plt.subplots(1, 2, figsize=(16,6))#,constrained_layout=True)
plt.rcParams["font.size"] = 20
plt.subplots_adjust(wspace=0.3)
plt.tick_params(pad = 10, top='on',bottom='on',left='on',right='on',)
ax[0].set_aspect("equal", adjustable="box")
ax[0].set_xlabel('Re[S$_{11}$] (arb. u.) ')
ax[0].set_ylabel('Im[S$_{11}$] (arb. u.) ')
ax[0].tick_params(axis="x", direction="in")
ax[0].tick_params(axis="y", direction="in")
# plt.xticks([-0.6, -0.4, 0.2, 0, 0.2, 0.4, 0.6])
ax[0].set_ylim(-0.01, 0.01)
ax[0].set_xlim(-0.01, 0.01)

ax[1].set_xlabel('Probe frequency $\omega_\mathrm{p}/2\pi$ (GHz)')
ax[1].set_ylabel('Phase[S$_{11}$] (rad) ')
ax[1].tick_params(axis="x", direction="in")
ax[1].tick_params(axis="y", direction="in")
ax[1].set_xlim(8.5, 10.)
ax[1].set_ylim(-np.pi, np.pi)
# ax[1].set_aspect("equal", adjustable="box")

ax[0].plot(np.real(s11_d)*1e2,np.imag(s11_d)*1e2, ls='', marker='o')
ax[0].plot(np.real(result_d.best_fit)*1e2,np.imag(result_d.best_fit)*1e2)
# ax[0].plot(np.real(result_d.init_fit),np.imag(result_d.init_fit), color='green', ls='--', )

ax[1].plot(freq_d*1e-9,np.angle(s11_d), ls='', marker='o')
ax[1].plot(freq_d*1e-9,np.angle(result_d.best_fit))
# ax[1].plot(freq_d*1e-9,np.angle(result_d.init_fit), color='green', ls='--', )

result_d
# plt.savefig('dressed_res.png', bbox_inches='tight')
# plt.show()
# Out:
# <h2> Model</h2> Model(S11_dpr_model) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>127</td><td></td></tr><tr><td># data points</td><td>602</td><td></td></tr><tr><td># variables</td><td>8</td><td></td></tr><tr><td>chi-square</td><td> 2.8297e-07</td><td></td></tr><tr><td>reduced chi-square</td><td> 4.7639e-10</td><td></td></tr><tr><td>Akaike info crit.</td><td>-12913.8590</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-12878.6569</td><td></td></tr><tr><td>R-squared</td><td>-2.8297e+08</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> fr </td><td>  9.1295e+09 </td><td>  1406293.68 </td><td> (0.02%) </td><td> 9150000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> ff </td><td>  8.9885e+09 </td><td>  8042739.40 </td><td> (0.09%) </td><td> 8950000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> kf_e </td><td>  4.0667e+08 </td><td>  19412468.7 </td><td> (4.77%) </td><td> 210000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> kf_i </td><td>  0.00000000 </td><td>  0.00000000 </td><td>  </td><td> 0.0 </td><td>  0.00000000 </td><td>         inf </td><td> False </td></tr><tr><td> gamma </td><td>  0.00000000 </td><td>  0.00000000 </td><td>  </td><td> 0.0 </td><td>  0.00000000 </td><td>         inf </td><td> False </td></tr><tr><td> g </td><td>  60084466.7 </td><td>  2941084.90 </td><td> (4.89%) </td><td> 82000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> a0 </td><td>  7.9941e-05 </td><td>  2.5134e-06 </td><td> (3.14%) </td><td> 7e-05 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> a1 </td><td> -3.3536e-14 </td><td>  3.0585e-15 </td><td> (9.12%) </td><td> -3e-14 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> Poff </td><td> -0.20698185 </td><td>  0.07806768 </td><td> (37.72%) </td><td> -0.2 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> ed </td><td> -6.0000e-06 </td><td>  1.6367e-11 </td><td> (0.00%) </td><td> -6e-06 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>Poff</td><td>ed</td><td>+0.8702</td></tr><tr><td>a0</td><td>a1</td><td>-0.8352</td></tr><tr><td>kf_e</td><td>ed</td><td>-0.8028</td></tr><tr><td>kf_e</td><td>Poff</td><td>-0.7039</td></tr><tr><td>ff</td><td>Poff</td><td>+0.6384</td></tr><tr><td>fr</td><td>g</td><td>-0.5696</td></tr><tr><td>a1</td><td>ed</td><td>+0.3220</td></tr><tr><td>ff</td><td>ed</td><td>+0.3067</td></tr><tr><td>a1</td><td>Poff</td><td>+0.2801</td></tr><tr><td>kf_e</td><td>a1</td><td>-0.2585</td></tr><tr><td>ff</td><td>kf_e</td><td>-0.2074</td></tr><tr><td>g</td><td>Poff</td><td>-0.1952</td></tr><tr><td>g</td><td>ed</td><td>-0.1949</td></tr><tr><td>kf_e</td><td>g</td><td>+0.1780</td></tr></table>

# %%
fig, ax = plt.subplots(1,2,figsize=(16,6),constrained_layout=True)
ax[0].set_xlabel('Frequency(GHz)',fontsize=18)
ax[0].set_ylabel('Re[$S_{11}]$', fontsize=18)
ax[1].set_xlabel('Frequency(GHz)',fontsize=16)
ax[1].set_ylabel('Im[$S_{11}]$', fontsize=16)
# ax.tick_params(direction='in')

ax[0].plot(freq_d,np.real(s11_d), ls='', marker='.')
ax[0].plot(freq_d,np.real(result_d.best_fit), color='orange')
ax[0].plot(freq_d,np.real(result_d.init_fit), color='green', ls='--', marker='')

ax[1].plot(freq_d,np.imag(s11_d), ls='', marker='.')
ax[1].plot(freq_d,np.imag(result_d.best_fit), color='orange')
ax[1].plot(freq_d,np.imag(result_d.init_fit), color='green', ls='--', marker='')

# %% [markdown]
# punchout

# %%
dd = datadict_from_hdf5(header + punchout +"/data")
dd
# Out:
# s11: (20, 301)
#   ⌙ frequency (Hz): (20, 301)
#   ⌙ power (dBm): (20,)

# %%
dd = datadict_from_hdf5(header + punchout +"/data")
x = np.unique(dd['power']['values'])
y = np.unique(dd['frequency']['values'])
z = dd['s11']['values']

# %%
cm = plt.cm.get_cmap('magma')
fig= plt.figure()
plt.rcParams["font.size"] = 20
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'

ax = fig.add_axes((0.1, 0.1, 0.9, 0.9))
ax.set_xlabel("VNA power $P_{\mathrm{VNA}}$ (dBm)")
ax.set_ylabel("Probe frequency $\omega_\mathrm{p}/2\pi$ (GHz)")
ax.set_xlim(-30, 10)
ax.set_ylim(8.5, 10.)

maingraph = ax.pcolormesh(x,y*1e-9, np.angle(z).reshape(20, 301).T, vmin=min(np.unique(np.angle(z))), vmax=max(np.unique(np.angle(z))), cmap=cm, shading='auto')


plt.tick_params(pad=10, top='on',bottom='on',left='on',right='on')
# plt.savefig('punchout.png', bbox_inches='tight')
plt.show()
# Out:
# C:\Users\qipe\AppData\Local\Temp\ipykernel_16148\1447686587.py:1: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cm = plt.cm.get_cmap('magma')

# %% [markdown]
# 平均光子数

# %%
def ave_photon_number(Power, k_ex, k_in, omega_r, omega_p):
    n = (k_ex/(((k_in + k_ex)/2)**2 + (omega_r - omega_p)**2))*(Power/(spc.hbar * omega_p))
    return n

# %%
spc.hbar
# Out:
# 1.0545718176461565e-34

# %%
k_ex = 2.0003e8*(2*np.pi)
k_in = 0

omega_r = 1.0267e+10*2*np.pi
omega_p = 1.0177e+10*2*np.pi

Power =  10**((-22.4-10-2.3-50-20)/10) *1e-3#J/s
Power
# ave_photon_number(Power, k_ex, k_in, omega_r, omega_p)
# Out:
# 3.3884415613920344e-14

# %%
P =  (10**((-50)/10) *1e-3  /6.626e-34 )*1e-9#GHz/s
P
# Out:
# 1.509206157561123e+16

# %%
kai = (0.13e9)*2*np.pi/2
delta = (10.2503210-8.02-0.00233)*1e9*2*np.pi
g = (kai*delta)**0.5
g
# Out:
# 2391075352.76259

# %%
delta**2/(4*g**2)
# Out:
# 8.569196153846155

# %%
k_ex
# Out:
# 1256825556.9951327

# %%
Power, omega_p, omega_r, k_ex, k_in
# Out:
# (3.3884415613920344e-14,
#  63943976871.16665,
#  64509463548.81281,
#  1256825556.9951327,
#  0)

# %%
1/(10.209-10.066)
# Out:
# 6.993006993007047

# %% [markdown]
# # frequency optimization

# %%
header = "D:/K_sunada/result/CDY157/"
data = "/2024-05-02/2024-05-02T113814_062927ab-26_freq_optimize"
dd = datadict_from_hdf5(header + data +"/data")
ed = 0#1e-9/9/(10.25-10)

freq = dd['frequency']['values']
s11_eg = dd['s11_eg']['values']* np.exp(1j*(ed*2*np.pi*freq))
s11_g = dd['s11_g']['values']* np.exp(1j*(ed*2*np.pi*freq))
s11_e = dd['s11_e']['values']* np.exp(1j*(ed*2*np.pi*freq))

# %% [markdown]
# eg-peak

# %%
plt.plot(freq, np.angle(s11_g))
plt.show()

# %%
def Lorentzian(freq, amp, const, center, k):
    return const + amp*k**2/((freq-center)**2 + k**2)

# %%
import sklearn
from sklearn.decomposition import PCA

# %%
def PCA_transform(Re_c, Im_c):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c]).T, np.array([Im_c]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    return c_PCA1, c_PCA2

# %%
I = s11_eg.real
Q = s11_eg.imag
plt.plot(freq, np.abs(s11_eg))
PCAge = PCA_transform(I, Q)

# %%
par_ini = {
    'amp': 15,
    'const':1,
    'center':9.15e9,
    'k':0.008e9
}

par_min = {
    'amp': 0,
    'const':0,
    'center':0,
    'k':0
}

par_max = {
    'amp': np.inf,
    'const':np.inf,
    'center':np.inf,
    'k':np.inf
}

par_vary = {
    'amp': True,
    'const':True,
    'center':True,
    'k':True
}

# %%
model = lmfit.Model(Lorentzian)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )

# %%
result = model.fit(data = np.abs(s11_eg), params = params, freq = freq)
result
# Out:
# <h2> Model</h2> Model(Lorentzian) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>29</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 33.4591562</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.34493975</td><td></td></tr><tr><td>Akaike info crit.</td><td>-103.584299</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-93.1238170</td><td></td></tr><tr><td>R-squared</td><td> 0.93355585</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  16.5087658 </td><td>  0.56827218 </td><td> (3.44%) </td><td> 15 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  0.88746030 </td><td>  0.06268979 </td><td> (7.06%) </td><td> 1 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> center </td><td>  9.1504e+09 </td><td>  472913.565 </td><td> (0.01%) </td><td> 9150000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> k </td><td>  11684317.5 </td><td>  579182.043 </td><td> (4.96%) </td><td> 8000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>amp</td><td>k</td><td>-0.6169</td></tr><tr><td>const</td><td>k</td><td>-0.2561</td></tr></table>

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("g-e transition")


plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result.plot_fit(ax = ax)
# plt.xlim(10.05e9, 10.55e9)
plt.ylim(0, 20)

plt.xlabel("frequency (Hz)")
plt.ylabel("mag[S11](a.u.)")


plt.show()

# %% [markdown]
# omega_g, _e fitting

# %%
par_ini = {'fr': 9.12e9,  'ff': 9.0e9,    'kf_e': 190e6,   'kf_i': 0,  'g': 50e6, 'gamma': 0,
           'a0': 31,  'a1': -3e-14,        'Poff': -0.35,   'ed': -6e-6}
par_min = {'fr': 0,     'ff': 0,        'kf_e': 0,        'kf_i': 0,        'g': 0,     'gamma': 0,
           'a0': 0,     'a1': -np.inf,  'Poff': -np.inf,'ed': -np.inf}
par_max = {'fr': np.inf,'ff': np.inf,   'kf_e': np.inf,   'kf_i': np.inf,   'g': np.inf,'gamma': np.inf,
           'a0': np.inf,'a1': np.inf,   'Poff': np.inf, 'ed': np.inf}
par_var = {'fr': True, 'ff': True,    'kf_e': True,    'kf_i':False,    'g': True, 'gamma': False,
           'a0': True, 'a1': False,    'Poff': True,  'ed': True}

model=lmfit.Model(S11_dpr_model)
params = model.make_params()

for name in list(par_ini):
    params[name].set(value=par_ini[name])
for name in list(par_min):
    params[name].set(min=par_min[name])  
for name in list(par_max):
    params[name].set(max=par_max[name]) 
for name in list(par_var):
    params[name].set(vary=par_var[name])

# %%
res = model.fit(data = s11_g, params = params, freq = freq)

fig, ax = plt.subplots(1, 2, figsize=(16,6))#,constrained_layout=True)
plt.rcParams["font.size"] = 20
plt.subplots_adjust(wspace=0.3)
plt.tick_params(pad = 10, top='on',bottom='on',left='on',right='on',)
ax[0].set_aspect("equal", adjustable="box")
ax[0].set_xlabel('Re[S$_{11}$] (arb. u.) ')
ax[0].set_ylabel('Im[S$_{11}$] (arb. u.) ')
ax[0].tick_params(axis="x", direction="in")
ax[0].tick_params(axis="y", direction="in")
ax[0].set_xlim(-100, 100)
ax[0].set_ylim(-100, 100)
ax[0].get_xaxis().set_tick_params(pad=10)

ax[1].set_xlabel('Probe frequency $\omega_\mathrm{p}/2\pi$ (GHz)')
ax[1].set_ylabel('Phase[S$_{11}$] (rad) ')
ax[1].tick_params(axis="x", direction="in")
ax[1].tick_params(axis="y", direction="in")
# ax[1].set_xlim(9.8, 10.8)
ax[1].set_ylim(-np.pi, np.pi)


ax[0].plot(np.real(s11_g),np.imag(s11_g) , ls='', marker='o')
ax[0].plot(freq*1e-9, np.real(res.init_fit), '--', label='initial fit', color='green')
ax[0].plot(np.real(res.best_fit), np.imag(res.best_fit))
ax[1].plot(freq*1e-9, np.angle(s11_g),  ls='', marker='o')
ax[1].plot(freq*1e-9, np.angle(res.init_fit), '--', label='initial fit', color='green')
ax[1].plot(freq*1e-9, np.angle(res.best_fit))
# plt.savefig('chi_g.png', bbox_inches='tight')
plt.show()
res
# Out:
# <h2> Model</h2> Model(S11_dpr_model) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>94</td><td></td></tr><tr><td># data points</td><td>202</td><td></td></tr><tr><td># variables</td><td>7</td><td></td></tr><tr><td>chi-square</td><td> 127073.799</td><td></td></tr><tr><td>reduced chi-square</td><td> 651.660508</td><td></td></tr><tr><td>Akaike info crit.</td><td> 1315.73963</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 1338.89750</td><td></td></tr><tr><td>R-squared</td><td>-0.60017727+0.33250974j</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> fr </td><td>  9.1142e+09 </td><td>  9116335.72 </td><td> (0.10%) </td><td> 9120000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> ff </td><td>  8.9410e+09 </td><td>  15473558.9 </td><td> (0.17%) </td><td> 9000000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> kf_e </td><td>  1.6751e+08 </td><td>  26862250.3 </td><td> (16.04%) </td><td> 190000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> kf_i </td><td>  0.00000000 </td><td>  0.00000000 </td><td>  </td><td> 0 </td><td>  0.00000000 </td><td>         inf </td><td> False </td></tr><tr><td> gamma </td><td>  0.00000000 </td><td>  0.00000000 </td><td>  </td><td> 0 </td><td>  0.00000000 </td><td>         inf </td><td> False </td></tr><tr><td> g </td><td>  82233417.1 </td><td>  10804864.5 </td><td> (13.14%) </td><td> 50000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> a0 </td><td>  31.9285603 </td><td>  2.65042779 </td><td> (8.30%) </td><td> 31 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> a1 </td><td> -3.0000e-14 </td><td>  0.00000000 </td><td> (0.00%) </td><td> -3e-14 </td><td>        -inf </td><td>         inf </td><td> False </td></tr><tr><td> Poff </td><td> -0.35704275 </td><td>  0.23164146 </td><td> (64.88%) </td><td> -0.35 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> ed </td><td> -5.9995e-06 </td><td>  6.0103e-11 </td><td> (0.00%) </td><td> -6e-06 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>fr</td><td>g</td><td>-0.8963</td></tr><tr><td>Poff</td><td>ed</td><td>+0.8889</td></tr><tr><td>kf_e</td><td>ed</td><td>-0.5983</td></tr><tr><td>fr</td><td>ff</td><td>-0.5203</td></tr><tr><td>ff</td><td>Poff</td><td>+0.4817</td></tr><tr><td>kf_e</td><td>Poff</td><td>-0.4558</td></tr><tr><td>ff</td><td>g</td><td>+0.4339</td></tr><tr><td>ff</td><td>ed</td><td>+0.3115</td></tr><tr><td>a0</td><td>ed</td><td>+0.2855</td></tr><tr><td>a0</td><td>Poff</td><td>+0.2540</td></tr><tr><td>g</td><td>Poff</td><td>-0.1781</td></tr><tr><td>kf_e</td><td>a0</td><td>-0.1707</td></tr><tr><td>g</td><td>ed</td><td>-0.1555</td></tr><tr><td>ff</td><td>kf_e</td><td>-0.1260</td></tr></table>

# %%
par_ini = {'fr': 9.12e9,  'ff': 9.0e9,    'kf_e': 210e6,   'kf_i': 0,  'g': 70e6, 'gamma': 0,
           'a0': 31,  'a1': -3e-14,        'Poff': -0.35,   'ed': -6e-6}
par_min = {'fr': 0,     'ff': 0,        'kf_e': 0,        'kf_i': 0,        'g': 0,     'gamma': 0,
           'a0': 0,     'a1': -np.inf,  'Poff': -np.inf,'ed': -np.inf}
par_max = {'fr': np.inf,'ff': np.inf,   'kf_e': np.inf,   'kf_i': np.inf,   'g': np.inf,'gamma': np.inf,
           'a0': np.inf,'a1': np.inf,   'Poff': np.inf, 'ed': np.inf}
par_var = {'fr': False, 'ff': False,    'kf_e': True,    'kf_i':False,    'g': True, 'gamma': False,
           'a0': True, 'a1': False,    'Poff': True,  'ed': True}

model=lmfit.Model(S11_dpr_model)
params = model.make_params()

for name in list(par_ini):
    params[name].set(value=par_ini[name])
for name in list(par_min):
    params[name].set(min=par_min[name])  
for name in list(par_max):
    params[name].set(max=par_max[name]) 
for name in list(par_var):
    params[name].set(vary=par_var[name])

# %%
res = model.fit(data = s11_e, params = params, freq = freq, method='nelder')

fig, ax = plt.subplots(1, 2, figsize=(16,6))#,constrained_layout=True)
plt.rcParams["font.size"] = 20
plt.subplots_adjust(wspace=0.3)
plt.tick_params(pad = 10, top='on',bottom='on',left='on',right='on',)
ax[0].set_aspect("equal", adjustable="box")
ax[0].set_xlabel('Re[S$_{11}$] (arb. u.) ')
ax[0].set_ylabel('Im[S$_{11}$] (arb. u.) ')
ax[0].tick_params(axis="x", direction="in")
ax[0].tick_params(axis="y", direction="in")
ax[0].set_xlim(-100, 100)
ax[0].set_ylim(-100, 100)
ax[0].get_xaxis().set_tick_params(pad=10)

ax[1].set_xlabel('Probe frequency $\omega_\mathrm{p}/2\pi$ (GHz)')
ax[1].set_ylabel('Phase[S$_{11}$] (rad) ')
ax[1].tick_params(axis="x", direction="in")
ax[1].tick_params(axis="y", direction="in")
# ax[1].set_xlim(9.8, 10.8)
ax[1].set_ylim(-np.pi, np.pi)

ax[0].plot(np.real(s11_e), np.imag(s11_e),  ls='', marker='o')
# ax[0].plot(x, np.real(s11_e),'.', color='k')
ax[0].plot(np.real(res.init_fit), np.imag(res.init_fit),'--', label='initial fit', color='green')
# ax[0].plot(np.real(res.best_fit),np.imag(res.best_fit), '-', label='best fit', color='red')
ax[0].plot(np.real(res.best_fit), np.imag(res.best_fit))
ax[1].plot(freq*1e-9, np.angle(s11_e),  ls='', marker='o')
ax[1].plot(freq*1e-9, np.angle(res.init_fit), '--', label='initial fit', color='green')
ax[1].plot(freq*1e-9, np.angle(res.best_fit))
# plt.savefig('chi_e.png', bbox_inches='tight')
plt.show()
res
# Out:
# <h2> Model</h2> Model(S11_dpr_model) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>Nelder-Mead</td><td></td></tr><tr><td># function evals</td><td>1994</td><td></td></tr><tr><td># data points</td><td>202</td><td></td></tr><tr><td># variables</td><td>5</td><td></td></tr><tr><td>chi-square</td><td> 44486.9582</td><td></td></tr><tr><td>reduced chi-square</td><td> 225.822123</td><td></td></tr><tr><td>Akaike info crit.</td><td> 1099.72610</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 1116.26744</td><td></td></tr><tr><td>R-squared</td><td>0.44071759+0.11877582j</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> fr </td><td>  9.1200e+09 </td><td> 9120000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> False </td></tr><tr><td> ff </td><td>  9.0000e+09 </td><td> 9000000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> False </td></tr><tr><td> kf_e </td><td>  5.4342e+08 </td><td> 210000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> kf_i </td><td>  0.00000000 </td><td> 0 </td><td>  0.00000000 </td><td>         inf </td><td> False </td></tr><tr><td> gamma </td><td>  0.00000000 </td><td> 0 </td><td>  0.00000000 </td><td>         inf </td><td> False </td></tr><tr><td> g </td><td>  2.2841e+08 </td><td> 70000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> a0 </td><td>  42.7664229 </td><td> 31 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> a1 </td><td> -3.0000e-14 </td><td> -3e-14 </td><td>        -inf </td><td>         inf </td><td> False </td></tr><tr><td> Poff </td><td> -2.13728040 </td><td> -0.35 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> ed </td><td> -6.0000e-06 </td><td> -6e-06 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table>

# %%
f_hg = 10.266e9
f_lg = 10.183e9
f_he = 10.263e9
f_le = 10.183e9

# chi_l = (f_le - f_lg)/2
chi_h = (f_he - f_hg)/2
chi = chi_h
chi
# Out:
# -1500000.0

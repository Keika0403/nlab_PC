# %% [markdown]
# ge: 7.71e+09 Hz
#
# ef: 7.38e+09 Hz

# %%
from plottr.data.datadict_storage import datadict_from_hdf5
import numpy as np
import matplotlib.pyplot as plt
import lmfit

# %%
import sklearn
from sklearn.decomposition import PCA

# %%
def Lorentzian(freq, amp, const, center, k):
    return const - amp*k**2/((freq-center)**2 + k**2)

# %%
header = "D:/K_sunada/result/CDY157/"
# twotone(redout: 10.26GHz)
three_peak = "/2024-04-28/2024-04-28T154642_126d4ead-cw_twotone" #drive: R.T.-10dB, lo power: -20~20dB, readout: R.T.: -30 dB, vna power: -10dB
ge_peak ="/2024-04-28/2024-04-28T155516_44a3b6cd-cw_twotone"#<ge>drive: R.T.-60dB, lo power: -20~10dB, readout: R.T.: -30 dB, vna power: -10dB
ef_peak = "/2024-04-28/2024-04-28T160554_c177b039-cw_twotone" #<ef>drive: R.T.-40dB, lo power: 0~24dB, readout: R.T.: -30 dB, vna power: -10dB

# %%
ddtwotone = datadict_from_hdf5(header + three_peak +"/data")
x = np.unique(ddtwotone['power']['values'])
y = np.unique(ddtwotone['frequency']['values'])
z = np.angle(ddtwotone['s11']['values'])

# %%
z.shape
# Out:
# (21, 101)

# %%
cm = plt.cm.get_cmap('magma')
fig= plt.figure()
plt.rcParams["font.size"] = 20
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'

ax = fig.add_axes((0.1, 0.1, 0.9, 0.9))
ax.set_ylabel("Drive power $P_{\mathrm{d}}$ (dBm)")
ax.set_xlabel("Drive frequency $\omega_\mathrm{d}/2\pi$ (GHz)")
# ax.set_xlim(-10, 20)
# ax.set_ylim(10, 10.6)

maingraph = ax.pcolormesh(y*1e-9,x, z.reshape(21, 101), vmin=min(np.unique(z)), vmax=max(np.unique(z)), cmap=cm, shading='auto')
plt.colorbar(maingraph, label="Phase[S$_{11}$] (arg)")
plt.tick_params(top='on',bottom='on',left='on',right='on')
# plt.savefig('three_peaks.png', bbox_inches='tight')
plt.show()
# Out:
# C:\Users\qipe\AppData\Local\Temp\ipykernel_564\3353848839.py:1: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cm = plt.cm.get_cmap('magma')

# %% [markdown]
# ge, ef peak

# %%
ddge = datadict_from_hdf5(header + ge_peak +"/data")
ddef = datadict_from_hdf5(header + ef_peak +"/data")

# %%
def PCA_transform(Re_c, Im_c):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c]).T, np.array([Im_c]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    return c_PCA1, c_PCA2

# %% [markdown]
# ## ge遷移
# 初期値設定

# %%
S11ge = ddge['s11']['values']
ge_phase = np.angle(S11ge)
freqge = ddge['frequency']['values']

y = ge_phase[4]
x = freqge[4]
plt.plot(x, y)
plt.show()

# %%
I = (S11ge.real)[4]
Q = (S11ge.imag)[4]
#c_data = np.concatenate([np.array([I]).T, np.array([Q]).T], axis = 1)

# %%
PCAge = PCA_transform(I, Q)
y = PCAge[0]*1e4
x = freqge[0]*1e-9

plt.plot(x, -y)
plt.title("data after PCA")
plt.show()

# %%
par_ini = {
    'amp': 0.08,
    'const':0.02,
    'center':7.7,
    'k':0.002
}

par_min = {
    'amp': 0,
    'const':0,
    'center':0,
    'k':0
}

par_max = {
    'amp': np.inf,
    'const':np.inf,
    'center':np.inf,
    'k':np.inf
}

par_vary = {
    'amp': True,
    'const':True,
    'center':True,
    'k':True
}

# %% [markdown]
# fitting

# %%
model = lmfit.Model(Lorentzian)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )

# %%
result = model.fit(data = -y, params = params, freq = x)

# %%
result
# Out:
# <h2> Model</h2> Model(Lorentzian) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>54</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 0.01276680</td><td></td></tr><tr><td>reduced chi-square</td><td> 1.3162e-04</td><td></td></tr><tr><td>Akaike info crit.</td><td>-898.578818</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-888.118336</td><td></td></tr><tr><td>R-squared</td><td> 0.70954921</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  0.06204354 </td><td>  0.00428558 </td><td> (6.91%) </td><td> 0.08 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  0.01636994 </td><td>  0.00217066 </td><td> (13.26%) </td><td> 0.02 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> center </td><td>  7.71305804 </td><td>  0.00129772 </td><td> (0.02%) </td><td> 7.7 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> k </td><td>  0.01932848 </td><td>  0.00258694 </td><td> (13.38%) </td><td> 0.002 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>const</td><td>k</td><td>+0.6953</td></tr><tr><td>amp</td><td>k</td><td>-0.3399</td></tr><tr><td>amp</td><td>const</td><td>+0.2244</td></tr></table>

# %%
fig, ax = plt.subplots(figsize=(8,6),constrained_layout=True)
plt.rcParams["font.size"] = 20

plt.tick_params(top='on',bottom='on',left='on',right='on',)

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result.plot_fit(ax = ax)
plt.plot(x,result.init_fit)
plt.xlim(7.6, 7.8)


plt.title("")
plt.legend("")
plt.xlabel("Drive frequency $\omega_\mathrm{d}$ (GHz)")
plt.ylabel("$S_{11}$ (arb. u.)")
# plt.savefig('ge_peak.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## ef
# 初期値

# %%
S11ef = ddef['s11']['values']
magef = np.angle(S11ef)
freqef = ddef['frequency']['values']

x = freqef[8]
y = magef[8]


plt.plot(x, y)
plt.show()

# %%
I = (S11ef.real)[8]
Q = (S11ef.imag)[8]
#c_data = np.concatenate([np.array([I]).T, np.array([Q]).T], axis = 1)

# %%
def PCA_transform(Re_c, Im_c):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c]).T, np.array([Im_c]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    return c_PCA1, c_PCA2

# %%
PCAef = PCA_transform(I, Q)

# %%
y = PCAef[0]
x = freqef[0]

plt.plot(x, -y)
plt.show()

# %%
par_ini = {
    'amp': 1.5e-5,
    'const':0.5e-5,
    'center':7.37,
    'k':0.001
}

par_min = {
    'amp': 0,
    'const':0,
    'center':0,
    'k':0
}

par_max = {
    'amp': np.inf,
    'const':np.inf,
    'center':np.inf,
    'k':np.inf
}

par_vary = {
    'amp': True,
    'const':True,
    'center':True,
    'k':True
}

# %%
model = lmfit.Model(Lorentzian)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )

# %%
result1 = model.fit(data = -y*1e4, params = params, freq = x*1e-9)

# %%
result1
# Out:
# <h2> Model</h2> Model(Lorentzian) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>108</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 0.03029680</td><td></td></tr><tr><td>reduced chi-square</td><td> 3.1234e-04</td><td></td></tr><tr><td>Akaike info crit.</td><td>-811.295206</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-800.834724</td><td></td></tr><tr><td>R-squared</td><td> 0.83756350</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  0.13428427 </td><td>  0.00602610 </td><td> (4.49%) </td><td> 1.5e-05 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  0.05232101 </td><td>  0.00510030 </td><td> (9.75%) </td><td> 5e-06 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> center </td><td>  7.37586537 </td><td>  8.7731e-04 </td><td> (0.01%) </td><td> 7.37 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> k </td><td>  0.02316732 </td><td>  0.00225693 </td><td> (9.74%) </td><td> 0.001 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>const</td><td>k</td><td>+0.8190</td></tr><tr><td>amp</td><td>const</td><td>+0.5265</td></tr></table>

# %%
fig, ax = plt.subplots(dpi=80)
plt.title("g-f transition")


plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result1.plot_fit(ax = ax)

plt.xlabel("frequency (Hz)")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,6),constrained_layout=True)
plt.rcParams["font.size"] = 20

plt.tick_params(top='on',bottom='on',left='on',right='on',)

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result1.plot_fit(ax = ax)
# plt.plot(x*1e-9, result1.init_fit)
plt.xlim(7.65, 7.715)

plt.title("")
plt.legend("")
plt.xlabel("Drive frequency $\omega_\mathrm{d}$ (GHz)")
plt.ylabel("$S_{11}$ (arb. u.)")
# plt.savefig('ef_peak.png', bbox_inches='tight')
plt.show()

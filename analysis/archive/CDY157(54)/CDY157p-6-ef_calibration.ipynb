# %%
readout_freq = 9.13
readout_lo_freq = 9.25 # 10.387
readout_if_freq = readout_lo_freq - readout_freq
JPA_if_freq = readout_freq * 2 - readout_lo_freq * 2

qubit_lo_freq = 7.5
ge_freq = 7.73 + 0.00498 + 0.00283 -5e-6
anharmonicity = 7.42-ge_freq -0.005 -0.003 -4e-5
ge_if_freq = ge_freq-qubit_lo_freq

2 * qubit_lo_freq - readout_lo_freq , 2 * ge_freq + anharmonicity - readout_freq
# Out:
# (5.75, 6.019765)

# %%
2 * ge_freq + anharmonicity - 10301110000.0e-9
# Out:
# 5.421912000000001

# %%
qubit_lo_freq = 7.85
ge_freq = 8.012+0.0089-2.8e-05
anharmonicity = 7.682-ge_freq+0.0208-6.5e-4
ge_if_freq = ge_freq-qubit_lo_freq
print(ge_freq, anharmonicity+ge_freq)
# Out:
# 8.020872 7.7021500000000005

# %% [markdown]
# ## `4/30 ef calibration - DPR1-L-120-54_readout

# %% [markdown]
# T1 = 11e-6

# %%
from plottr.data.datadict_storage import datadict_from_hdf5
import numpy as np
import matplotlib.pyplot as plt
import lmfit

# %%
import sklearn
from sklearn.decomposition import PCA

# %%
def Rabi(delay, amp, phi0, detun, const):
    return - amp * np.cos(2*np.pi*detun*delay+phi0) + const

# %% [markdown]
# amp

# %%
header = "D:/K_sunada/result/CDY157/"
ef = "/2024-05-02/2024-05-02T115156_f0051667-30_ef_pi_amp"
dd_ef = datadict_from_hdf5(header + ef +"/data")

# %%
def PCA_transform(Re_c, Im_c):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c]).T, np.array([Im_c]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    return c_PCA1, c_PCA2

# %%
Rabi_ef = dd_ef['s11']['values']
#imag_ge = Rabi_ge.imag
amp_ef = dd_ef['amplitude']['values']

I = (Rabi_ef.real)
Q = (Rabi_ef.imag)

PCAef = PCA_transform(I, Q)

# %%
y = PCAef[0]
x = amp_ef

plt.plot(x, y)
plt.show()

# %%
par_ini = {
    'amp': 7,
    'phi0':np.pi,
    'detun':1/0.21,
    'const':1e-6
}

par_min = {
    'amp': 0,
    'phi0':-2*np.pi,
    'detun':-np.inf,
    'const':-np.inf
}

par_max = {
    'amp': np.inf,
    'phi0':2*np.pi,
    'detun':np.inf,
    'const':np.inf,
}

par_vary = {
    'amp': True,
    'phi0':True,
    'detun':True,
    'const':True
}

# %%
model = lmfit.Model(Rabi)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )

# %%
result_ef = model.fit(data = y, params = params, delay = x)
result_ef
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>56</td><td></td></tr><tr><td># data points</td><td>51</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 503.683537</td><td></td></tr><tr><td>reduced chi-square</td><td> 10.7166710</td><td></td></tr><tr><td>Akaike info crit.</td><td> 124.796249</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 132.523552</td><td></td></tr><tr><td>R-squared</td><td> 0.68105396</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  6.59824944 </td><td>  0.65895772 </td><td> (9.99%) </td><td> 7 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  3.72735941 </td><td>  0.18848383 </td><td> (5.06%) </td><td> 3.141592653589793 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  4.24035343 </td><td>  0.05093218 </td><td> (1.20%) </td><td> 4.761904761904762 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td> -0.09552169 </td><td>  0.46028228 </td><td> (481.86%) </td><td> 1e-06 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>-0.8570</td></tr></table>

# %%
fig, ax = plt.subplots(figsize=(8,6),constrained_layout=True)
plt.rcParams["font.size"] = 20
# plt.title("Rabi(amp)")
plt.tick_params(top='on',bottom='on',left='on',right='on',)
plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result_ef.plot_fit(ax = ax)
plt.plot(amp_ef,result_ef.init_fit)

plt.title("")
plt.legend("")
ax.set_xlabel('$\pi_{ef}$ pulse DAC amplitude (V)', size='large')
ax.set_ylabel('S$_{11}$ (arb. u.)', size='large')
ax.set_ylim(-8, 8)
ax.set_xlim(0, 1)
# plt.savefig('ef_rabi.png', bbox_inches='tight')
plt.show()

# %%
np.pi/(4.24035343*2*np.pi)*5
# Out:
# 0.5895734969431545

# %% [markdown]
# ramsey

# %%
pl = "/2024-05-02/2024-05-02T115534_7252d275-32_ef_T2r1d"
mi = "/2024-05-02/2024-05-02T115642_9a81f621-32_ef_T2r1d"
dd_pl = datadict_from_hdf5(header + pl +"/data")
dd_mi = datadict_from_hdf5(header + mi +"/data")

# %%
Rabi_pl = dd_pl['s11']['values']
imag_pl = Rabi_pl.imag
delay_pl = dd_pl['delay']['values']

Rabi_mi = dd_mi['s11']['values']
imag_mi = Rabi_mi.imag
delay_mi = dd_mi['delay']['values']

# %%
def PCA_transform(Re_c, Im_c):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c]).T, np.array([Im_c]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    return c_PCA1, c_PCA2


I_pl = (Rabi_pl.real)
Q_pl = (Rabi_pl.imag)
I_mi = (Rabi_mi.real)
Q_mi = (Rabi_mi.imag)


PCA_pl = PCA_transform(I_pl, Q_pl)
y_pl = PCA_pl[0]
x_pl = delay_pl

PCA_mi = PCA_transform(I_mi, Q_mi)
y_mi = PCA_mi[0]
x_mi = delay_mi



plt.plot(x_pl, y_pl)
plt.show()

# %%
par_ini_pl = {
    'amp': 7,
    'phi0':0,
    'detun':1/220,
    'const':1e-6
}

par_min_pl = {
    'amp': 0,
    'phi0':-2*np.pi,
    'detun':-np.inf,
    'const':0
}

par_max_pl = {
    'amp': np.inf,
    'phi0':2*np.pi,
    'detun':np.inf,
    'const':np.inf,
}

par_vary_pl = {
    'amp': True,
    'phi0':True,
    'detun':True,
    'const':True
}

# %%
model = lmfit.Model(Rabi)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini_pl[name],
    min = par_min_pl[name],
    max = par_max_pl[name],
    vary = par_vary_pl[name]
    )
    
result_pl = model.fit(data = y_pl, params = params, delay = x_pl)
result_pl
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>96</td><td></td></tr><tr><td># data points</td><td>51</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 13.0598028</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.27786814</td><td></td></tr><tr><td>Akaike info crit.</td><td>-61.4766171</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-53.7493146</td><td></td></tr><tr><td>R-squared</td><td> 0.98684879</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  6.21318437 </td><td> 7 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td> -2.36480064 </td><td> 0 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  0.00503191 </td><td> 0.004545454545454545 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  3.4541e-12 </td><td> 1e-06 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table>

# %%
fig, ax = plt.subplots(figsize=(8,6),constrained_layout=True)

# plt.title("Rabi(+5MHz)")

# plt.plot(x_pl,result_pl.init_fit)
plt.rcParams["font.size"] = 20

plt.tick_params(top='on',bottom='on',left='on',right='on',)

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result_pl.plot_fit(ax = ax)
plt.plot(x_pl,result_pl.init_fit)

plt.title("")
plt.legend("")
plt.xlabel(r"Delay ${\tau}$ (ns)")
plt.ylabel("$S_{11}$ (arb. u.)")
plt.xlim(0, 1000)
# plt.savefig('ef_ramsey_exp.png', bbox_inches='tight')
plt.show()

# %%
plt.plot(x_mi, y_mi)
plt.show()

# %%
par_ini_mi = {
    'amp': 7,
    'phi0':np.pi/2,
    'detun':1/220,
    'const':1e-6
}

par_min_mi = {
    'amp': 0,
    'phi0':-2*np.pi,
    'detun':-np.inf,
    'const':0
}

par_max_mi = {
    'amp': np.inf,
    'phi0':2*np.pi,
    'detun':np.inf,
    'const':np.inf,
}

par_vary_mi = {
    'amp': True,
    'phi0':True,
    'detun':True,
    'const':True
}

# %%
model = lmfit.Model(Rabi)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini_mi[name],
    min = par_min_mi[name],
    max = par_max_mi[name],
    vary = par_vary_mi[name]
    )
    
result_mi = model.fit(data = y_mi, params = params, delay = x_mi)
result_mi
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>47</td><td></td></tr><tr><td># data points</td><td>51</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 14.5985858</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.31060821</td><td></td></tr><tr><td>Akaike info crit.</td><td>-55.7959497</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-48.0686472</td><td></td></tr><tr><td>R-squared</td><td> 0.98588126</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  6.36252949 </td><td>  0.11121212 </td><td> (1.75%) </td><td> 7 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  1.59875571 </td><td>  0.03351475 </td><td> (2.10%) </td><td> 1.5707963267948966 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  0.00496247 </td><td>  9.1984e-06 </td><td> (0.19%) </td><td> 0.004545454545454545 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  0.00703859 </td><td>  0.07805892 </td><td> (1109.01%) </td><td> 1e-06 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>-0.8575</td></tr></table>

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(-5MHz)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result_mi.plot_fit(ax = ax)
plt.plot(x_mi,result_mi.init_fit)

plt.xlabel("delay (ns)")
plt.ylabel("mag[S11](a.u.)")


plt.show()

# %%
detun = ((0.005-0.00503191)+ (0.00496247-0.005))/2 #GHz
detun
# Out:
# -3.47199999999998e-05

# %% [markdown]
# drag

# %%
drag = "/2024-02-18/2024-02-18T133204_aacd9b18-31_ef_pi_drag" #n=7
dd_drag = datadict_from_hdf5(header + drag +"/data")

drag1 = "/2024-02-18/2024-02-18T134044_e083dc6d-31_ef_pi_drag" #n=11
dd_drag1 = datadict_from_hdf5(header + drag1 +"/data")

drag2 = "/2024-02-18/2024-02-18T134219_19933a1e-31_ef_pi_drag" #n=17
dd_drag2 = datadict_from_hdf5(header + drag2 +"/data")

# %%
Rabi_drag = dd_drag['s11']['values']
imag_drag = Rabi_drag.imag
drag = dd_drag['beta']['values']
I_drag = (Rabi_drag.real)
Q_drag = (Rabi_drag.imag)

Rabi_drag1 = dd_drag1['s11']['values']
imag_drag1 = Rabi_drag1.imag
drag1 = dd_drag1['beta']['values']
I_drag1 = (Rabi_drag1.real)
Q_drag1 = (Rabi_drag1.imag)

Rabi_drag2 = dd_drag2['s11']['values']
imag_drag2 = Rabi_drag2.imag
drag2 = dd_drag2['beta']['values']
I_drag2 = (Rabi_drag2.real)
Q_drag2 = (Rabi_drag2.imag)

# %%
def PCA_transform1(Re_c_amp, Im_c_amp, Re_c_drag, Im_c_drag):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c_amp]).T, np.array([Im_c_amp]).T], axis = 1)
    c1_data = np.concatenate([np.array([Re_c_drag]).T, np.array([Im_c_drag]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    
    c1_pca = pca.transform(c1_data)
    c1_PCA1 = c1_pca.T[0]
    c1_PCA2 = c1_pca.T[1]
    return c_PCA1, c_PCA2, c1_PCA1, c1_PCA2,

# %%
PCA_drag = PCA_transform1(I_drag, Q_drag, I_drag, Q_drag)
y = PCA_drag[0]
# x = amp_ef
y0 = PCA_drag[2]
x0 = drag

PCA_drag1 = PCA_transform1(I_drag, Q_drag, I_drag1, Q_drag1)
y1 = PCA_drag1[2]
x1 = drag1

PCA_drag2 = PCA_transform1(I_drag, Q_drag, I_drag2, Q_drag2)
y2 = PCA_drag2[2]
x2 = drag2

# %%
plt.plot(x0, y0)
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.show()

# %%
par_ini= {
    'amp': 0.00007,
    'phi0':0,
    'detun':1/2,
    'const':0.
}

par_min = {
    'amp': 0,
    'phi0':-2*np.pi,
    'detun':0,
    'const':-np.inf
}

par_max = {
    'amp': np.inf,
    'phi0':2*np.pi,
    'detun':np.inf,
    'const':np.inf,
}

par_vary = {
    'amp': True,
    'phi0':True,
    'detun':True,
    'const':True
}

# %%
model = lmfit.Model(Rabi)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )
    
result0 = model.fit(data = y0, params = params, delay = x0)
result1 = model.fit(data = y1, params = params, delay = x1)
result2 = model.fit(data = y2, params = params, delay = x2)

# %%
result0
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>41</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 1.5114e-08</td><td></td></tr><tr><td>reduced chi-square</td><td> 1.5582e-10</td><td></td></tr><tr><td>Akaike info crit.</td><td>-2276.89865</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-2266.43817</td><td></td></tr><tr><td>R-squared</td><td> 0.85932461</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  5.4977e-05 </td><td>  8.2054e-06 </td><td> (14.93%) </td><td> 7e-05 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td> -0.11217886 </td><td>  0.03387127 </td><td> (30.19%) </td><td> 0 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  0.24571336 </td><td>  0.03021846 </td><td> (12.30%) </td><td> 0.5 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  1.6800e-05 </td><td>  9.2863e-06 </td><td> (55.28%) </td><td> 0.0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>detun</td><td>const</td><td>-0.9882</td></tr><tr><td>amp</td><td>const</td><td>+0.9705</td></tr><tr><td>amp</td><td>detun</td><td>-0.9611</td></tr><tr><td>phi0</td><td>const</td><td>+0.5116</td></tr><tr><td>phi0</td><td>detun</td><td>-0.5073</td></tr><tr><td>amp</td><td>phi0</td><td>+0.5067</td></tr></table>

# %%
res0 = (+0.11217886)/(2*np.pi*0.24571336)
res0
# Out:
# 0.07266116941876379

# %%
result1
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>26</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 1.6726e-08</td><td></td></tr><tr><td>reduced chi-square</td><td> 1.7244e-10</td><td></td></tr><tr><td>Akaike info crit.</td><td>-2266.66144</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-2256.20096</td><td></td></tr><tr><td>R-squared</td><td> 0.80160958</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  3.8957e-05 </td><td>  1.9753e-06 </td><td> (5.07%) </td><td> 7e-05 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  0.18248180 </td><td>  0.04654774 </td><td> (25.51%) </td><td> 0 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  0.52035924 </td><td>  0.00813622 </td><td> (1.56%) </td><td> 0.5 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  3.0621e-06 </td><td>  1.3815e-06 </td><td> (45.12%) </td><td> 0.0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>amp</td><td>const</td><td>-0.2621</td></tr><tr><td>detun</td><td>const</td><td>+0.1642</td></tr></table>

# %%
res1 = (-0.18248180)/(2*np.pi*0.52035924)
res1
# Out:
# -0.05581313496865478

# %%
result2
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>31</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 1.7426e-08</td><td></td></tr><tr><td>reduced chi-square</td><td> 1.7965e-10</td><td></td></tr><tr><td>Akaike info crit.</td><td>-2262.52393</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-2252.06345</td><td></td></tr><tr><td>R-squared</td><td> 0.82952570</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  4.0671e-05 </td><td>  1.8896e-06 </td><td> (4.65%) </td><td> 7e-05 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  0.08347951 </td><td>  0.04675265 </td><td> (56.00%) </td><td> 0 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  0.67069489 </td><td>  0.00965897 </td><td> (1.44%) </td><td> 0.5 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  8.6800e-06 </td><td>  1.4498e-06 </td><td> (16.70%) </td><td> 0.0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>detun</td><td>const</td><td>+0.3916</td></tr><tr><td>amp</td><td>detun</td><td>-0.1360</td></tr></table>

# %%
res2 = (-0.08347951)/(2*np.pi*0.67069489)
res2
# Out:
# -0.019809568943322812

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(drag)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result0.plot_fit(ax = ax)
plt.plot(x0,result0.init_fit)

plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(drag)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result1.plot_fit(ax = ax)
plt.plot(x1,result1.init_fit)


plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(drag)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result2.plot_fit(ax = ax)

plt.plot(x2,result2.init_fit)


plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
beta = (res0 + res1 + res2)/3
beta
# Out:
# -0.0009871781644046028

# %%
fig, ax = plt.subplots(figsize=(8,6),constrained_layout=True)
plt.rcParams["font.size"] = 20
plt.tick_params(top='on',bottom='on',left='on',right='on',)
plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'

plt.plot(x0, y0*1e3, 'o', label="n=11")
plt.plot(x0, y1*1e3, 'o', label="n=17")
plt.plot(x0, y2*1e3, 'o', label="n=23")
plt.plot(x0, (3.4823e-7-8.4064e-5*np.cos(2*np.pi*0.65672748*x0+0.41313693))*1e3, color='blue')
plt.plot(x0, (-3.5304e-7-7.5781e-5*np.cos(2*np.pi*1.41618906*x0+1.00579675))*1e3, color='orange')
plt.plot(x0, (-6.2264e-6-6.9263e-5*np.cos(2*np.pi*2.14863394*x0+1.4817749))*1e3, color='green')
plt.vlines(-0.10763833733475762, -0.1, 0.1, color='r', linestyles='dotted')
plt.ylim(-0.1, 0.1)

plt.title("")
plt.legend(title_fontsize=18, fontsize=18, loc='upper right', bbox_to_anchor=(1.35, 1))
plt.xlabel(r"DRAG coefficient ${\beta}$")
plt.ylabel("$S_{11}$ (arb. u.)")
plt.xlim(-1, 0.5)
# plt.savefig('drag_ef_pi.png', bbox_inches='tight')

plt.show()

# %% [markdown]
# half drag

# %%
drag = "/2024-02-18/2024-02-18T134720_ccfa6254-31_ef_pi_drag" #n=27
dd_drag = datadict_from_hdf5(header + drag +"/data")

drag1 = "/2024-02-18/2024-02-18T134820_f041ba5a-31_ef_pi_drag" #n=17
dd_drag1 = datadict_from_hdf5(header + drag1 +"/data")

drag2 = "/2024-02-18/2024-02-18T135046_47686088-31_ef_pi_drag" #n=23
dd_drag2 = datadict_from_hdf5(header + drag2 +"/data")

# %%
Rabi_drag = dd_drag['s11']['values']
imag_drag = Rabi_drag.imag
drag = dd_drag['beta']['values']
I_drag = (Rabi_drag.real)
Q_drag = (Rabi_drag.imag)

Rabi_drag1 = dd_drag1['s11']['values']
imag_drag1 = Rabi_drag1.imag
drag1 = dd_drag1['beta']['values']
I_drag1 = (Rabi_drag1.real)
Q_drag1 = (Rabi_drag1.imag)

Rabi_drag2 = dd_drag2['s11']['values']
imag_drag2 = Rabi_drag2.imag
drag2 = dd_drag2['beta']['values']
I_drag2 = (Rabi_drag2.real)
Q_drag2 = (Rabi_drag2.imag)

# %%
def PCA_transform1(Re_c_amp, Im_c_amp, Re_c_drag, Im_c_drag):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c_amp]).T, np.array([Im_c_amp]).T], axis = 1)
    c1_data = np.concatenate([np.array([Re_c_drag]).T, np.array([Im_c_drag]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    
    c1_pca = pca.transform(c1_data)
    c1_PCA1 = c1_pca.T[0]
    c1_PCA2 = c1_pca.T[1]
    return c_PCA1, c_PCA2, c1_PCA1, c1_PCA2,

# %%
PCA_drag = PCA_transform1(I_drag, Q_drag, I_drag, Q_drag)
y = PCA_drag[0]
# x = amp_ef
y0 = PCA_drag[2]
x0 = drag

PCA_drag1 = PCA_transform1(I_drag, Q_drag, I_drag1, Q_drag1)
y1 = PCA_drag1[2]
x1 = drag1

PCA_drag2 = PCA_transform1(I_drag, Q_drag, I_drag2, Q_drag2)
y2 = PCA_drag2[2]
x2 = drag2

# %%
plt.plot(x0, y0)
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.show()

# %%
par_ini= {
    'amp': 10e-5,
    'phi0':0,
    'detun':1/0.6,
    'const':0.
}

par_min = {
    'amp': 0,
    'phi0':-2*np.pi,
    'detun':-np.inf,
    'const':-np.pi
}

par_max = {
    'amp': np.inf,
    'phi0':2*np.pi,
    'detun':np.inf,
    'const':np.inf,
}

par_vary = {
    'amp': True,
    'phi0':True,
    'detun':True,
    'const':True
}

# %%
model = lmfit.Model(Rabi)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )
    
result0 = model.fit(data = y0, params = params, delay = x0)
result1 = model.fit(data = y1, params = params, delay = x1)
result2 = model.fit(data = y2, params = params, delay = x2)

# %%
result0
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>26</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 1.6123e-08</td><td></td></tr><tr><td>reduced chi-square</td><td> 1.6622e-10</td><td></td></tr><tr><td>Akaike info crit.</td><td>-2270.36983</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-2259.90934</td><td></td></tr><tr><td>R-squared</td><td> 0.95117771</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  8.1705e-05 </td><td>  1.8814e-06 </td><td> (2.30%) </td><td> 0.0001 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  0.01864409 </td><td>  0.02174185 </td><td> (116.62%) </td><td> 0 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  0.86640252 </td><td>  0.00381828 </td><td> (0.44%) </td><td> 1.0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  9.1589e-06 </td><td>  1.3110e-06 </td><td> (14.31%) </td><td> 0.0 </td><td> -3.14159265 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>amp</td><td>const</td><td>+0.1547</td></tr><tr><td>detun</td><td>const</td><td>-0.1287</td></tr></table>

# %%
res0 = (-0.01864409)/(2*np.pi*0.86640252)
res0
# Out:
# -0.0034248504759083285

# %%
result1
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>26</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 1.7584e-08</td><td></td></tr><tr><td>reduced chi-square</td><td> 1.8128e-10</td><td></td></tr><tr><td>Akaike info crit.</td><td>-2261.61262</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-2251.15214</td><td></td></tr><tr><td>R-squared</td><td> 0.94770435</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  8.0494e-05 </td><td>  1.9217e-06 </td><td> (2.39%) </td><td> 0.0001 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  0.10125244 </td><td>  0.02325335 </td><td> (22.97%) </td><td> 0 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  1.60502276 </td><td>  0.00418920 </td><td> (0.26%) </td><td> 1.4285714285714286 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  8.2829e-06 </td><td>  1.3554e-06 </td><td> (16.36%) </td><td> 0.0 </td><td> -3.14159265 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>detun</td><td>const</td><td>-0.1466</td></tr></table>

# %%
res1 = (-0.10125244)/(2*np.pi*1.60502276)
res1
# Out:
# -0.01004024785674413

# %%
result2
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>47</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 1.7164e-08</td><td></td></tr><tr><td>reduced chi-square</td><td> 1.7695e-10</td><td></td></tr><tr><td>Akaike info crit.</td><td>-2264.05046</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-2253.58998</td><td></td></tr><tr><td>R-squared</td><td> 0.95105943</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  8.0730e-05 </td><td>  1.8604e-06 </td><td> (2.30%) </td><td> 0.0001 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  0.20255291 </td><td>  0.02339774 </td><td> (11.55%) </td><td> 0 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  2.10122325 </td><td>  0.00433638 </td><td> (0.21%) </td><td> 1.6666666666666667 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  4.5098e-06 </td><td>  1.3278e-06 </td><td> (29.44%) </td><td> 0.0 </td><td> -3.14159265 </td><td>         inf </td><td> True </td></tr></table>

# %%
res2 = (-0.20255291)/(2*np.pi*2.10122325	)
res2
# Out:
# -0.015342156938415659

# %%
(res0+res1+res2)/3
# Out:
# -0.009602418423689371

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(drag)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result0.plot_fit(ax = ax)
plt.plot(x0,result0.init_fit)


plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(drag)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result1.plot_fit(ax = ax)
plt.plot(x1,result1.init_fit)


plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(drag)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result2.plot_fit(ax = ax)

plt.plot(x2,result2.init_fit)


plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,6),constrained_layout=True)
plt.rcParams["font.size"] = 20
plt.tick_params(top='on',bottom='on',left='on',right='on',)
plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'


plt.plot(x0, y1*1e3, 'o', label="n=17")
plt.plot(x0, y2*1e3, 'o', label="n=23")
plt.plot(x0, y0*1e3, 'o', label="n=27")

plt.plot(x0, (-1.5919e-6-3.4841e-5*np.cos(2*np.pi*0.69538804*x0+3.88957417))*1e3, color='blue')
plt.plot(x0, (8.1124e-7-3.4585e-5*np.cos(2*np.pi*0.94793540*x0+4.15857227))*1e3, color='orange')
plt.plot(x0, (4.4413e-6-3.0849e-5*np.cos(2*np.pi*1.10944739*x0+4.43656298))*1e3, color='green')
plt.vlines(-0.17590277984430594, -0.06, 0.06, color='r', linestyles='dotted')
plt.ylim(-0.06, 0.06)

plt.title("")
plt.legend(title_fontsize=18, fontsize=18, loc='upper right', bbox_to_anchor=(1.35, 1))
plt.xlabel(r"DRAG coefficient ${\beta}$")
plt.ylabel("$S_{11}$ (arb. u.)")
plt.xlim(-1, 0.5)
# plt.savefig('drag_ef_half_pi.png', bbox_inches='tight')

plt.show()

# %% [markdown]
# T1

# %%
def Dephase(delay, amp, gamma, const):
    return amp*np.exp(-gamma*delay) + const

t1 ="/2024-05-02/2024-05-02T115859_ec479342-33_ef_T1"

dd_t1 = datadict_from_hdf5(header + t1 +"/data")

# %%
s11_t1 = dd_t1['s11']['values'][0:-2]
imag_t1 = s11_t1.imag
delay_t1 = dd_t1['delay']['values'][0:-2]

I_t1 = (s11_t1.real)
Q_t1 = (s11_t1.imag)

PCA_t1 = PCA_transform(I_t1, Q_t1)

y_t1 = PCA_t1[0]
x_t1 = delay_t1

plt.plot(x_t1, y_t1)
plt.show()

# %%
par_ini_t1 = {
    'gamma': 1/20000e-3,
    'amp':15,
    'const':-0.5
}

par_min_t1 = {
    'gamma': 0,
    'amp':0,
    'const':-np.inf
}

par_max_t1 = {
    'gamma': np.inf,
    'amp':np.inf,
    'const':np.inf,
}

par_vary_t1 = {
    'gamma': True,
    'amp':True,
    'const':True
}

# %%
model = lmfit.Model(Dephase)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini_t1[name],
    min = par_min_t1[name],
    max = par_max_t1[name],
    vary = par_vary_t1[name]
    )
result_t1 = model.fit(data = y_t1, params = params, delay = x_t1*1e-3)
result_t1
# Out:
# <h2> Model</h2> Model(Dephase) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>25</td><td></td></tr><tr><td># data points</td><td>99</td><td></td></tr><tr><td># variables</td><td>3</td><td></td></tr><tr><td>chi-square</td><td> 59.1598999</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.61624896</td><td></td></tr><tr><td>Akaike info crit.</td><td>-44.9727145</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-37.1873549</td><td></td></tr><tr><td>R-squared</td><td> 0.96614433</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  19.1487190 </td><td>  0.43834705 </td><td> (2.29%) </td><td> 15 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> gamma </td><td>  0.09322532 </td><td>  0.00370996 </td><td> (3.98%) </td><td> 0.05 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td> -2.17277311 </td><td>  0.10476330 </td><td> (4.82%) </td><td> -0.5 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>amp</td><td>gamma</td><td>+0.5509</td></tr><tr><td>gamma</td><td>const</td><td>+0.5252</td></tr></table>

# %%
fig, ax = plt.subplots(figsize=(8,6),constrained_layout=True)
plt.rcParams["font.size"] = 20

plt.tick_params(top='on',bottom='on',left='on',right='on',)
plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result_t1.plot_fit(ax = ax)
# plt.plot(delay_t1,result_t1.init_fit)

plt.title("")
plt.legend("")
ax.set_xlabel(r'Delay $\tau$ ($\mu$s)')#, size='large')
ax.set_ylabel('S$_{11}$ (arb. u.)')
ax.set_xlim(0, 100)
# plt.savefig('ef_T1.png', bbox_inches='tight')

plt.show()

# %%
T1 = (1/0.09322532)*1e-9	
T1
# Out:
# 1.0726699570460043e-08

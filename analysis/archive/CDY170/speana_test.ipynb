# %%
from qcodes_drivers.E4407B import E4407B
spectrum_analyzer = E4407B("spectrum_analyzer", "GPIB0::18::INSTR")
# Out:
# Connected to: Hewlett-Packard E4407B (serial:MY49510151, firmware:A.14.06) in 0.39s

# %%
spectrum_analyzer.span(0.5e9)
spectrum_analyzer.center(8e9)
dbm = spectrum_analyzer.trace()

# %%
import matplotlib.pyplot as plt
plt.plot(dbm)

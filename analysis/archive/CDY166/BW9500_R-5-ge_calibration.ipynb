# %% [markdown]
# ## 9/20 ge calibration

# %% [markdown]
# T1 = 36e-06
#
# T2_echo = 5.5e-06
#
# T2_star = 4.8e-06

# %%
from plottr.data.datadict_storage import datadict_from_hdf5
import numpy as np
import matplotlib.pyplot as plt
import lmfit
import sklearn
from sklearn.decomposition import PCA

# %%
def PCA_transform(Re_c, Im_c):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c]).T, np.array([Im_c]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    return c_PCA1, c_PCA2

# %%
def Rabi(delay, amp, phi0, detun, const):
    return - amp * np.cos(2*np.pi*detun*delay+phi0) + const

# %%
header = "D:/K_Sunada/result/CDY166"
amp = "/2024-09-20/2024-09-20T180303_24ea877e-21_ge_pi_amp"
dd_amp = datadict_from_hdf5(header + amp +"/data")

Rabi_amp = dd_amp['s11']['values']
imag_amp = Rabi_amp.imag
amp = dd_amp['amplitude']['values']

I_amp = (Rabi_amp.real)
Q_amp = (Rabi_amp.imag)
PCA_amp = PCA_transform(I_amp, Q_amp)

# %%
fig, (ax1) = plt.subplots(nrows=1)
ax1.set_xlabel('Amplitude (V)', size='large')
ax1.set_ylabel('PCA[$S_{11}$] (V)', size='large')
plt.rcParams["font.size"] = 17
plt.plot(amp, PCA_amp[0])
ax1.tick_params(axis="x", direction="in")
ax1.tick_params(axis="y", direction="in")
# ax1.set_xlim(0, 1)
# ax1.set_ylim(-48, 160)
plt.tick_params(top='on',bottom='on`',left='on',right='on',)
plt.show()

# %%
par_ini= {'amp': 20,'phi0':np.pi,'detun':1/0.45,'const':1}
par_min = {'amp': 0,'phi0':-2*np.pi,'detun':-np.inf,'const':-np.inf}
par_max = {'amp': np.inf,'phi0':2*np.pi,'detun':np.inf,'const':np.inf,}
par_vary = {'amp': True,'phi0':True,'detun':True,'const':True}

model = lmfit.Model(Rabi)

params = model.make_params()
for name in model.param_names:
    params[name].set(value = par_ini[name],min = par_min[name],max = par_max[name],vary = par_vary[name])
    
result = model.fit(data = PCA_amp[0], params = params, delay = amp)
result
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>26</td><td></td></tr><tr><td># data points</td><td>31</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 11.1934298</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.41457147</td><td></td></tr><tr><td>Akaike info crit.</td><td>-23.5784669</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-17.8425181</td><td></td></tr><tr><td>R-squared</td><td> 0.99900103</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  26.4118162 </td><td>  0.16083693 </td><td> (0.61%) </td><td> 20 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  3.20108278 </td><td>  0.01267221 </td><td> (0.40%) </td><td> 3.141592653589793 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  2.38862294 </td><td>  0.00234008 </td><td> (0.10%) </td><td> 2.2222222222222223 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  0.58852049 </td><td>  0.11638394 </td><td> (19.78%) </td><td> 1 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>-0.8658</td></tr></table>

# %%
fig, ax = plt.subplots(figsize=(8,6),constrained_layout=True)
plt.rcParams["font.size"] = 20
# plt.title("Rabi(amp)")
plt.tick_params(top='on',bottom='on',left='on',right='on',)
plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result.plot_fit(ax = ax)
plt.plot(amp, result.init_fit)

plt.title("")
plt.legend("")
ax.set_xlabel('$\pi_{ge}$ pulse DAC amplitude (V)', size='large')
ax.set_ylabel('S$_{11}$ (arb. u.)', size='large')
ax.set_xlim(0, 1.5)
# plt.savefig('ge_rabi.png', bbox_inches='tight')
plt.show()

# %%
np.pi/(2.38862294*2*np.pi)*5
# Out:
# 1.0466281463410883

# %% [markdown]
# ramsey

# %%
pl ="/2024-09-20/2024-09-20T180421_52fc1953-23_ge_T2r1d"
mi =  "/2024-09-20/2024-09-20T180457_68e01b51-23_ge_T2r1d"
dd_pl = datadict_from_hdf5(header + pl +"/data")
dd_mi = datadict_from_hdf5(header + mi +"/data")

Rabi_pl = dd_pl['s11']['values']
delay_pl = dd_pl['delay']['values']
Rabi_mi = dd_mi['s11']['values']
delay_mi = dd_mi['delay']['values']

I_pl = (Rabi_pl.real)
Q_pl = (Rabi_pl.imag)
I_mi = (Rabi_mi.real)
Q_mi = (Rabi_mi.imag)

PCA_pl = PCA_transform(I_pl, Q_pl)
y_pl = PCA_pl[0]
x_pl = delay_pl

PCA_mi = PCA_transform(I_mi, Q_mi)
y_mi = PCA_mi[0]
x_mi = delay_mi

fig, ax = plt.subplots(1,2,figsize=(12,6),constrained_layout=True)
ax[0].plot(x_pl, y_pl)
ax[1].plot(x_mi, y_mi)
plt.show()

# %%
par_ini_pl = {'amp': 25,'phi0':np.pi/2,'detun':1/200,'const':0.1}
par_ini_mi = {'amp': 25,'phi0':0,'detun':1/200,'const':0.1}
par_min = {'amp': 0,'phi0':-2*np.pi,'detun':-np.inf,'const':0}
par_max = {'amp': np.inf,'phi0':2*np.pi,'detun':np.inf,'const':np.inf,}
par_vary = {'amp': True,'phi0':True,'detun':True,'const':True}

model = lmfit.Model(Rabi)

params_pl = model.make_params()
for name in model.param_names:
    params_pl[name].set(value = par_ini_pl[name],min = par_min[name],max = par_max[name],vary = par_vary[name])
    
result_pl = model.fit(data = y_pl, params = params_pl, delay = x_pl)
result_pl
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>26</td><td></td></tr><tr><td># data points</td><td>51</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 29.0399952</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.61787224</td><td></td></tr><tr><td>Akaike info crit.</td><td>-20.7207320</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-12.9934294</td><td></td></tr><tr><td>R-squared</td><td> 0.99813376</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  24.8629209 </td><td>  0.15692440 </td><td> (0.63%) </td><td> 25 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  1.20651167 </td><td>  0.01197679 </td><td> (0.99%) </td><td> 1.5707963267948966 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  0.00499981 </td><td>  3.3154e-06 </td><td> (0.07%) </td><td> 0.005 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  0.17364179 </td><td>  0.11024866 </td><td> (63.49%) </td><td> 0.1 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>-0.8547</td></tr></table>

# %%
params_mi = model.make_params()
for name in model.param_names:
    params_mi[name].set(value = par_ini_mi[name],min = par_min[name],max = par_max[name],vary = par_vary[name])
    
result_mi = model.fit(data = y_mi, params = params_mi, delay = x_mi)
result_mi
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>21</td><td></td></tr><tr><td># data points</td><td>51</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 54.5532911</td><td></td></tr><tr><td>reduced chi-square</td><td> 1.16070832</td><td></td></tr><tr><td>Akaike info crit.</td><td> 11.4349729</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 19.1622755</td><td></td></tr><tr><td>R-squared</td><td> 0.99680530</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  25.6080389 </td><td>  0.21160761 </td><td> (0.83%) </td><td> 25 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  0.20876575 </td><td>  0.01684424 </td><td> (8.07%) </td><td> 0 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  0.00500894 </td><td>  4.6979e-06 </td><td> (0.09%) </td><td> 0.005 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  0.52999228 </td><td>  0.15247834 </td><td> (28.77%) </td><td> 0.1 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>-0.8664</td></tr><tr><td>detun</td><td>const</td><td>+0.1423</td></tr><tr><td>phi0</td><td>const</td><td>-0.1267</td></tr></table>

# %%
fig, ax = plt.subplots(1,2,figsize=(12,6),constrained_layout=True)
plt.rcParams["font.size"] = 20

plt.tick_params(top='on',bottom='on',left='on',right='on',)

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result_pl.plot_fit(ax = ax[0])
ax[0].plot(x_pl,result_pl.init_fit)
result_mi.plot_fit(ax = ax[1])
ax[1].plot(x_mi,result_mi.init_fit)

plt.title("")
plt.legend("")
plt.xlabel(r"Delay ${\tau}$ (ns)")
plt.ylabel("$S_{11}$ (arb. u.)")
plt.xlim(0, 1000)
# plt.savefig('ef_ramsey_exp.png', bbox_inches='tight')
plt.show()

# %%
detun = ((0.005-0.00499981)+ (0.00500894-0.005))/2 #GHz
detun
# Out:
# 4.5649999999997776e-06

# %% [markdown]
# drag

# %%
drag = "/2024-09-20/2024-09-20T180714_ba21264f-22_ge_pi_drag" # n=7
dd_drag = datadict_from_hdf5(header + drag +"/data")

drag1 = "/2024-09-20/2024-09-20T180758_d49d8200-22_ge_pi_drag" # n=13
dd_drag1 = datadict_from_hdf5(header + drag1 +"/data")

drag2 = "/2024-09-20/2024-09-20T180829_e70db004-22_ge_pi_drag" # n=17
dd_drag2 = datadict_from_hdf5(header + drag2 +"/data")

# %%
Rabi_drag = dd_drag['s11']['values']
drag = dd_drag['beta']['values']
I_drag = (Rabi_drag.real)
Q_drag = (Rabi_drag.imag)

Rabi_drag1 = dd_drag1['s11']['values']
drag1 = dd_drag1['beta']['values']
I_drag1 = (Rabi_drag1.real)
Q_drag1 = (Rabi_drag1.imag)

Rabi_drag2 = dd_drag2['s11']['values']
drag2 = dd_drag2['beta']['values']
I_drag2 = (Rabi_drag2.real)
Q_drag2 = (Rabi_drag2.imag)

# %%
def PCA_transform1(Re_c_amp, Im_c_amp, Re_c_drag, Im_c_drag):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c_amp]).T, np.array([Im_c_amp]).T], axis = 1)
    c1_data = np.concatenate([np.array([Re_c_drag]).T, np.array([Im_c_drag]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    
    c1_pca = pca.transform(c1_data)
    c1_PCA1 = c1_pca.T[0]
    c1_PCA2 = c1_pca.T[1]
    return c_PCA1, c_PCA2, c1_PCA1, c1_PCA2,

# %%
PCA_drag = PCA_transform1(I_drag, Q_drag, I_drag, Q_drag)
y = PCA_drag[0]
x = amp
y0 = PCA_drag[2]
x0 = drag

PCA_drag1 = PCA_transform1(I_drag, Q_drag, I_drag1, Q_drag1)
y1 = PCA_drag1[2]
x1 = drag1

PCA_drag2 = PCA_transform1(I_drag, Q_drag, I_drag2, Q_drag2)
y2 = PCA_drag2[2]
x2 = drag2

# %%
plt.plot(x0, y0)
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.show()

# %%
par_ini= {'amp': 0.0002,'phi0':0,'detun':1/0.8,'const':0}
par_min = {'amp': 0,'phi0':-2*np.pi,'detun':-np.inf,'const':-np.pi}
par_max = {'amp': np.inf,'phi0':2*np.pi,'detun':np.inf,'const':np.inf,}
par_vary = {'amp': True,'phi0':True,'detun':True,'const':True}
model = lmfit.Model(Rabi)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )
    
result0 = model.fit(data = y0, params = params, delay = x0)
result1 = model.fit(data = y1, params = params, delay = x1)
result2 = model.fit(data = y2, params = params, delay = x2)

# %%
fig, ax = plt.subplots(1,3,figsize=(18,6),constrained_layout=True)
plt.title("Rabi(drag)")
plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result0.plot_fit(ax = ax[0])
ax[0].plot(x0,result0.init_fit)
result1.plot_fit(ax = ax[1])
ax[1].plot(x1,result1.init_fit)
result2.plot_fit(ax = ax[2])
ax[2].plot(x2,result2.init_fit)
plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")
plt.show()

# %%
result0
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>41</td><td></td></tr><tr><td># data points</td><td>51</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 4.6459e-09</td><td></td></tr><tr><td>reduced chi-square</td><td> 9.8849e-11</td><td></td></tr><tr><td>Akaike info crit.</td><td>-1171.07415</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-1163.34685</td><td></td></tr><tr><td>R-squared</td><td> 0.99364621</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  1.6803e-04 </td><td>  1.9887e-06 </td><td> (1.18%) </td><td> 0.0002 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  1.79998582 </td><td>  0.01236401 </td><td> (0.69%) </td><td> 0 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  0.49778169 </td><td>  0.00226328 </td><td> (0.45%) </td><td> 0.6666666666666666 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  7.9677e-06 </td><td>  1.4586e-06 </td><td> (18.31%) </td><td> 0 </td><td> -3.14159265 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>const</td><td>+0.2880</td></tr><tr><td>amp</td><td>detun</td><td>-0.1676</td></tr></table>

# %%
res0 = (-1.79998582+np.pi)/(2*np.pi*0.49778169)
res0
# Out:
# 0.42894980579073005

# %%
result1
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>36</td><td></td></tr><tr><td># data points</td><td>51</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 5.1040e-09</td><td></td></tr><tr><td>reduced chi-square</td><td> 1.0860e-10</td><td></td></tr><tr><td>Akaike info crit.</td><td>-1166.27838</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-1158.55107</td><td></td></tr><tr><td>R-squared</td><td> 0.99284383</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  1.6825e-04 </td><td>  2.0878e-06 </td><td> (1.24%) </td><td> 0.0002 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  0.66250634 </td><td>  0.01223938 </td><td> (1.85%) </td><td> 0 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  0.91519136 </td><td>  0.00221222 </td><td> (0.24%) </td><td> 0.6666666666666666 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  6.4393e-06 </td><td>  1.4945e-06 </td><td> (23.21%) </td><td> 0 </td><td> -3.14159265 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>detun</td><td>const</td><td>-0.1936</td></tr></table>

# %%
res1 = (np.pi-0.66250634)/(2*np.pi*0.91519136)
res1
# Out:
# 0.4311216849329523

# %%
result2
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>21</td><td></td></tr><tr><td># data points</td><td>51</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 7.9107e-09</td><td></td></tr><tr><td>reduced chi-square</td><td> 1.6831e-10</td><td></td></tr><tr><td>Akaike info crit.</td><td>-1143.93040</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-1136.20309</td><td></td></tr><tr><td>R-squared</td><td> 0.98832659</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  1.6605e-04 </td><td>  2.6335e-06 </td><td> (1.59%) </td><td> 0.0002 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td> -0.13554110 </td><td>  0.01520932 </td><td> (11.22%) </td><td> 0 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  1.19327304 </td><td>  0.00266098 </td><td> (0.22%) </td><td> 1.25 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  8.4958e-06 </td><td>  1.8383e-06 </td><td> (21.64%) </td><td> 0 </td><td> -3.14159265 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>amp</td><td>const</td><td>-0.1081</td></tr><tr><td>detun</td><td>const</td><td>+0.1042</td></tr></table>

# %%
res2 = (np.pi+0.13554110)/(2*np.pi*1.19327304)
res2
# Out:
# 0.4370936228116852

# %%
beta = (res0 + res1 + res2)/3
beta
# Out:
# 0.4323883711784558

# %% [markdown]
# half drag

# %%
drag = "/2024-09-20/2024-09-20T181157_62dc482d-22_ge_pi_drag" # n=7
dd_drag = datadict_from_hdf5(header + drag +"/data")

drag1 = "/2024-09-20/2024-09-20T181230_76af8e1e-22_ge_pi_drag" # n=13
dd_drag1 = datadict_from_hdf5(header + drag1 +"/data")

drag2 = "/2024-09-20/2024-09-20T181302_899687d3-22_ge_pi_drag" # n=17
dd_drag2 = datadict_from_hdf5(header + drag2 +"/data")

# %%
Rabi_drag = dd_drag['s11']['values']
imag_drag = Rabi_drag.imag
drag = dd_drag['beta']['values']
I_drag = (Rabi_drag.real)
Q_drag = (Rabi_drag.imag)

Rabi_drag1 = dd_drag1['s11']['values']
imag_drag1 = Rabi_drag1.imag
drag1 = dd_drag1['beta']['values']
I_drag1 = (Rabi_drag1.real)
Q_drag1 = (Rabi_drag1.imag)

Rabi_drag2 = dd_drag2['s11']['values']
imag_drag2 = Rabi_drag2.imag
drag2 = dd_drag2['beta']['values']
I_drag2 = (Rabi_drag2.real)
Q_drag2 = (Rabi_drag2.imag)

# %%
PCA_drag = PCA_transform1(I_drag, Q_drag, I_drag, Q_drag)
y = PCA_drag[0]
x = amp
y0 = PCA_drag[2]
x0 = drag

PCA_drag1 = PCA_transform1(I_drag, Q_drag, I_drag1, Q_drag1)
y1 = PCA_drag1[2]
x1 = drag1

PCA_drag2 = PCA_transform1(I_drag, Q_drag, I_drag2, Q_drag2)
y2 = PCA_drag2[2]
x2 = drag2

# %%
plt.plot(x0, y0)
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.show()

# %%
par_ini= {'amp': 0.00025,'phi0':0,'detun':1/0.3,'const':0}
par_min = {'amp': 0,'phi0':-2*np.pi,'detun':-np.inf,'const':-np.pi}
par_max = {'amp': np.inf,'phi0':2*np.pi,'detun':np.inf,'const':np.inf,}
par_vary = {'amp': True,'phi0':True,'detun':True,'const':True}
model = lmfit.Model(Rabi)

model = lmfit.Model(Rabi)
params = model.make_params()
for name in model.param_names:
    params[name].set(value = par_ini[name],min = par_min[name],max = par_max[name],vary = par_vary[name])
    
result0 = model.fit(data = y0, params = params, delay = x0)
result1 = model.fit(data = y1, params = params, delay = x1)
result2 = model.fit(data = y2, params = params, delay = x2)

# %%
fig, ax = plt.subplots(1,3,figsize=(18,6),constrained_layout=True)
plt.title("Rabi(drag)")
plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result0.plot_fit(ax = ax[0])
ax[0].plot(x0,result0.init_fit)
result1.plot_fit(ax = ax[1])
ax[1].plot(x1,result1.init_fit)
result2.plot_fit(ax = ax[2])
ax[2].plot(x2,result2.init_fit)
plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")
plt.show()

# %%
result0
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>26</td><td></td></tr><tr><td># data points</td><td>51</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 8.4532e-09</td><td></td></tr><tr><td>reduced chi-square</td><td> 1.7985e-10</td><td></td></tr><tr><td>Akaike info crit.</td><td>-1140.54797</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-1132.82066</td><td></td></tr><tr><td>R-squared</td><td> 0.99718534</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  3.4266e-04 </td><td>  2.6565e-06 </td><td> (0.78%) </td><td> 0.00025 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td> -0.87206148 </td><td>  0.00779639 </td><td> (0.89%) </td><td> 0 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  1.50501791 </td><td>  0.00140835 </td><td> (0.09%) </td><td> 1.4285714285714286 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  1.4603e-05 </td><td>  1.8879e-06 </td><td> (12.93%) </td><td> 0 </td><td> -3.14159265 </td><td>         inf </td><td> True </td></tr></table>

# %%
res0 = (np.pi+0.87206148)/(2*np.pi*1.50501791)
res0
# Out:
# 0.4244420554583527

# %%
result1
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>42</td><td></td></tr><tr><td># data points</td><td>51</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 1.7160e-08</td><td></td></tr><tr><td>reduced chi-square</td><td> 3.6512e-10</td><td></td></tr><tr><td>Akaike info crit.</td><td>-1104.43669</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-1096.70938</td><td></td></tr><tr><td>R-squared</td><td> 0.99417782</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  3.3837e-04 </td><td>  3.7783e-06 </td><td> (1.12%) </td><td> 0.00025 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  1.98582287 </td><td>  0.01122533 </td><td> (0.57%) </td><td> 0 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  2.79219239 </td><td>  0.00203054 </td><td> (0.07%) </td><td> 2.857142857142857 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  8.7552e-06 </td><td>  2.6797e-06 </td><td> (30.61%) </td><td> 0 </td><td> -3.14159265 </td><td>         inf </td><td> True </td></tr></table>

# %%
res1 = (3*np.pi-1.98582287)/(2*np.pi*2.79219239)
res1
# Out:
# 0.4240203785293483

# %%
result2
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>37</td><td></td></tr><tr><td># data points</td><td>51</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 2.6452e-08</td><td></td></tr><tr><td>reduced chi-square</td><td> 5.6280e-10</td><td></td></tr><tr><td>Akaike info crit.</td><td>-1082.36810</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-1074.64080</td><td></td></tr><tr><td>R-squared</td><td> 0.99075888</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  3.3114e-04 </td><td>  4.6655e-06 </td><td> (1.41%) </td><td> 0.00025 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td> -0.29349164 </td><td>  0.01429370 </td><td> (4.87%) </td><td> 0 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  3.65084957 </td><td>  0.00262046 </td><td> (0.07%) </td><td> 3.3333333333333335 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  1.1538e-05 </td><td>  3.3292e-06 </td><td> (28.86%) </td><td> 0 </td><td> -3.14159265 </td><td>         inf </td><td> True </td></tr></table>

# %%
res2 = (3*np.pi+0.29349164)/(2*np.pi*3.65084957)
res2
# Out:
# 0.42365773105851273

# %%
beta = (res0 + res1 + res2)/3
beta
# Out:
# 0.4240400550154046

# %% [markdown]
# T1

# %%
def Dephase(delay, amp, gamma, const):
    return amp*np.exp(-gamma*delay) + const

t1 ="/2024-09-20/2024-09-20T181737_2de0a81e-24_ge_T1"

dd_t1 = datadict_from_hdf5(header + t1 +"/data")

# %%
s11_t1 = dd_t1['s11']['values']#[0:180]
delay_t1 = dd_t1['delay']['values']#[0:180]
I_t1 = (s11_t1.real)
Q_t1 = (s11_t1.imag)
PCA_t1 = PCA_transform(I_t1, Q_t1)

y_t1 = PCA_t1[0]
x_t1 = delay_t1

fig, (ax1) = plt.subplots(nrows=1)
ax1.set_xlabel('Delay (ns)', size='large')
ax1.set_ylabel('PCA[S$_{11}$] (arb. unit.)', size='large')
plt.rcParams["font.size"] = 10
ax1.tick_params(axis="x", direction="in")
ax1.tick_params(axis="y", direction="in")
# ax1.set_xlim(0, 250000)
# ax1.set_ylim(-48, 160)
plt.tick_params(top='on',bottom='on`',left='on',right='on',)

plt.plot(x_t1, y_t1)
plt.show()

# %%
par_ini_t1 = {'gamma': 1/40000e-3,'amp':1,'const':-2.4}
par_min_t1 = {'gamma': 0,'amp':0,'const':-np.inf}
par_max_t1 = {'gamma': np.inf,'amp':np.inf,'const':np.inf,}
par_vary_t1 = {'gamma': True,'amp':True,'const':True}

model = lmfit.Model(Dephase)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini_t1[name],
    min = par_min_t1[name],
    max = par_max_t1[name],
    vary = par_vary_t1[name]
    )
result_t1 = model.fit(data = y_t1, params = params, delay = x_t1*1e-3)
result_t1
# Out:
# <h2> Model</h2> Model(Dephase) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>59</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>3</td><td></td></tr><tr><td>chi-square</td><td> 86.4643248</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.88228903</td><td></td></tr><tr><td>Akaike info crit.</td><td>-9.69425041</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-1.84888886</td><td></td></tr><tr><td>R-squared</td><td> 0.99231373</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  52.7700185 </td><td>  0.57244834 </td><td> (1.08%) </td><td> 1 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> gamma </td><td>  0.05790815 </td><td>  0.00105462 </td><td> (1.82%) </td><td> 0.025 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td> -4.77748212 </td><td>  0.11524452 </td><td> (2.41%) </td><td> -2.4 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>amp</td><td>gamma</td><td>+0.5730</td></tr><tr><td>gamma</td><td>const</td><td>+0.4544</td></tr></table>

# %%
fig, ax = plt.subplots(figsize=(8,6),constrained_layout=True)
plt.rcParams["font.size"] = 20
plt.tick_params(top='on',bottom='on',left='on',right='on',)
plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result_t1.plot_fit(ax = ax)
# plt.plot(x_t1,result_t1.init_fit, label='init fit')
# ax.set_ylim(-8, 15)
plt.title("")
plt.legend("")
ax.set_xlabel(r'Delay $\tau$ ($\mu$s)')#, size='large')
ax.set_ylabel('S$_{11}$ (arb. u.)')
plt.xlim(0, 200)
# plt.savefig('ge_T1.png', bbox_inches='tight')
plt.show()

# %%
T1 = (1/0.05790815)*1e-9	
T1
# Out:
# 1.726872642279196e-08

# %% [markdown]
# T2_echo

# %%
t2e = "/2024-07-23/2024-07-23T103831_44d82307-25_ge_T2e"
dd_t2e = datadict_from_hdf5(header + t2e +"/data")

# %%
s11_t2e = dd_t2e['s11']['values']
delay_t2e = dd_t2e['delay']['values']
I_t2e = (s11_t2e.real)
Q_t2e = (s11_t2e.imag)
PCA_t2e = PCA_transform(I_t2e, Q_t2e)

y_t2e = PCA_t2e[0]
x_t2e = delay_t2e
plt.plot(x_t2e, y_t2e)
plt.show()

# %%
par_ini_t2e = {'gamma': 1/5000e-3,'amp':80,'const':-10}
par_min_t2e = {'gamma': 0,'amp':0,'const':-np.inf}
par_max_t2e = {'gamma': np.inf,'amp':np.inf,'const':np.inf,}
par_vary_t2e = {'gamma': True,'amp':True,'const':True}

model = lmfit.Model(Dephase)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini_t2e[name],
    min = par_min_t2e[name],
    max = par_max_t2e[name],
    vary = par_vary_t2e[name]
    )
result_t2e = model.fit(data = y_t2e, params = params, delay = x_t2e*1e-3)
result_t2e

# %%
fig, ax = plt.subplots(figsize=(8,6),constrained_layout=True)
plt.rcParams["font.size"] = 20
plt.tick_params(top='on',bottom='on',left='on',right='on',)

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result_t2e.plot_fit(ax = ax)
# plt.plot(delay_t2e,result_t2e.init_fit)

# ax.set_ylim(-10, 35)

plt.title("")
plt.legend("")
ax.set_xlabel(r'Delay $\tau$ ($\mu$s)')
ax.set_ylabel('S$_{11}$ (arb. u.)')
plt.xlim(0, 100)
# plt.savefig('ge_T2e.png', bbox_inches='tight')
plt.show()

# %%
T2 = (1/0.26060864)*1e-6
T2
# Out:
# 3.8371713232531355e-06

# %% [markdown]
# T2 star

# %%
def Damping(delay, amp, gamma, omega, phi0, const):
    return const + amp * np.exp(- gamma*delay)*np.cos(omega*delay + phi0)

# %%
t2 = "/2024-07-23/2024-07-23T103007_1832335e-23_ge_T2r1d"
dd_t2 = datadict_from_hdf5(header + t2 +"/data")

s11_t2 = dd_t2['s11']['values']
delay_t2 = dd_t2['delay']['values']
I_t2 = (s11_t2.real)
Q_t2 = (s11_t2.imag)
PCA_t2 = PCA_transform(I_t2, Q_t2)

y_t2 = PCA_t2[0]
x_t2 = delay_t2

plt.plot(x_t2, y_t2)
plt.show()

# %%
par_ini_t2 = {'amp':60,'gamma': 1/3000e-3,'omega':2*np.pi/1500e-3,'phi0':np.pi,'const':0}
par_min_t2 = {'amp':-np.inf,'gamma': 0,'omega':-2*np.pi,'phi0':-2*np.pi,'const':-np.inf}
par_max_t2 = {'amp':np.inf,'gamma': np.inf,'omega':np.inf,'phi0':2*np.pi,'const':np.inf}
par_vary_t2 = {'amp':True,'gamma': True,'omega':True,'phi0':True,'const':True}

model = lmfit.Model(Damping)

params = model.make_params()
for name in model.param_names:
    params[name].set(value = par_ini_t2[name],min = par_min_t2[name],max = par_max_t2[name],vary = par_vary_t2[name])
result_t2 = model.fit(data = y_t2, params = params, delay = x_t2*1e-3)
result_t2

# %%
fig, ax = plt.subplots(figsize=(8,6),constrained_layout=True)
plt.rcParams["font.size"] = 20

plt.tick_params(top='on',bottom='on',left='on',right='on',)

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result_t2.plot_fit(ax = ax)
# plt.plot(delay_t2*1e-3,result_t2.init_fit)
# ax.set_ylim(-10, 35)
plt.title("")
plt.legend("")
ax.tick_params(axis="x", direction="in")
ax.tick_params(axis="y", direction="in")
ax.set_xlabel(r'Delay $\tau$ ($\mu$s)')
ax.set_ylabel('S$_{11}$ (arb. u.)')
ax.set_xlim(0, 20)
# plt.savefig('ge_T2star.png', bbox_inches='tight')
plt.show()

# %%
T2_star = (1/0.20007773)*1e-6
T2_star
# Out:
# 4.998057504950701e-06

# %%
from plottr.data.datadict_storage import datadict_from_hdf5
import numpy as np
import matplotlib.pyplot as plt
import lmfit

# %%
import sklearn
from sklearn.decomposition import PCA

# %%
def Lorentzian(freq, amp, const, center, k):
    return const - amp*k**2/((freq-center)**2 + k**2)

# %% [markdown]
# ## ge遷移
# 初期値設定

# %%
header = "D:/K_sunada/database/"
ge ="/2023-06-14/2023-06-14T114322_3a987f5a-cw_twotone/"
ddge = datadict_from_hdf5(header + ge +"/data")

# %%
S11ge = ddge['s11']['values']
magge = np.abs(S11ge)
freqge = ddge['frequency']['values']

y = magge[0]
x = freqge[0]

plt.plot(x, y)
plt.show()

# %% [markdown]
# PCA

# %%
I = (S11ge.real)[0]
Q = (S11ge.imag)[0]
#c_data = np.concatenate([np.array([I]).T, np.array([Q]).T], axis = 1)

# %%
def PCA_transform(Re_c, Im_c):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c]).T, np.array([Im_c]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    return c_PCA1, c_PCA2

# %%
PCAge = PCA_transform(I, Q)

# %%
y = PCAge[0]
x = freqge[0]

plt.plot(x, -y)
plt.title("data after PCA")
plt.show()

# %%
par_ini = {
    'amp': 0.0017,
    'const':0.0002,
    'center':8.025e9,
    'k':0.008e9
}

par_min = {
    'amp': 0,
    'const':0,
    'center':0,
    'k':0
}

par_max = {
    'amp': np.inf,
    'const':np.inf,
    'center':np.inf,
    'k':np.inf
}

par_vary = {
    'amp': True,
    'const':True,
    'center':True,
    'k':True
}

# %% [markdown]
# fitting

# %%
model = lmfit.Model(Lorentzian)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )

# %%
result = model.fit(data = -y, params = params, freq = x)

# %%
result
# Out:
# <h2> Model</h2> Model(Lorentzian) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>26</td><td></td></tr><tr><td># data points</td><td>1001</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 1.8311e-05</td><td></td></tr><tr><td>reduced chi-square</td><td> 1.8366e-08</td><td></td></tr><tr><td>Akaike info crit.</td><td>-17826.5652</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-17806.9302</td><td></td></tr><tr><td>R-squared</td><td> 0.87410294</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  0.00162389 </td><td>  2.4343e-05 </td><td> (1.50%) </td><td> 0.0017 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  1.9149e-04 </td><td>  5.5478e-06 </td><td> (2.90%) </td><td> 0.0002 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> center </td><td>  8.0236e+09 </td><td>  118467.754 </td><td> (0.00%) </td><td> 8025000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> k </td><td>  7912382.55 </td><td>  191318.939 </td><td> (2.42%) </td><td> 8000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>amp</td><td>k</td><td>-0.5976</td></tr><tr><td>const</td><td>k</td><td>+0.4814</td></tr></table>

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("g-e transition")


plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result.plot_fit(ax = ax)

plt.xlabel("frequency (Hz)")
plt.ylabel("mag[S11](a.u.)")


plt.show()

# %% [markdown]
# ## 二光子遷移
# 初期値

# %%
gf = "/2023-06-14/2023-06-14T114644_b2b682b6-cw_twotone/"
ddgf = datadict_from_hdf5(header +gf +"/data")

# %%
S11gf = ddgf['s11']['values']
maggf = np.abs(S11gf)
freqgf = ddgf['frequency']['values']

x = freqgf[0]
y = maggf[0]


plt.plot(x, y)
plt.show()

# %%
I = (S11gf.real)[0]
Q = (S11gf.imag)[0]
#c_data = np.concatenate([np.array([I]).T, np.array([Q]).T], axis = 1)

# %%
def PCA_transform(Re_c, Im_c):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c]).T, np.array([Im_c]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    return c_PCA1, c_PCA2

# %%
PCAgf = PCA_transform(I, Q)

# %%
PCAgf[0]
# Out:
# array([-1.76608849e-04, -1.42784252e-04, -1.23471200e-04, ...,
#        -1.43309744e-04, -3.24524220e-04, -9.46209061e-05])

# %%
y = PCAgf[0]
x = freqgf[0]

plt.plot(x, -y)
plt.show()

# %%
par_ini = {
    'amp': 0.003,
    'const':0.00025,
    'center':7.865e9,
    'k':0.001e9
}

par_min = {
    'amp': 0,
    'const':0,
    'center':0,
    'k':0
}

par_max = {
    'amp': np.inf,
    'const':np.inf,
    'center':np.inf,
    'k':np.inf
}

par_vary = {
    'amp': True,
    'const':True,
    'center':True,
    'k':True
}

# %%
model = lmfit.Model(Lorentzian)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )

# %%
result1 = model.fit(data = -y, params = params, freq = x)

# %%
result1
# Out:
# <h2> Model</h2> Model(Lorentzian) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>36</td><td></td></tr><tr><td># data points</td><td>1001</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 1.6918e-05</td><td></td></tr><tr><td>reduced chi-square</td><td> 1.6969e-08</td><td></td></tr><tr><td>Akaike info crit.</td><td>-17905.8025</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-17886.1675</td><td></td></tr><tr><td>R-squared</td><td> 0.92906715</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  0.00278082 </td><td>  3.2231e-05 </td><td> (1.16%) </td><td> 0.003 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  1.7687e-04 </td><td>  4.7058e-06 </td><td> (2.66%) </td><td> 0.00025 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> center </td><td>  7.8657e+09 </td><td>  24133.8675 </td><td> (0.00%) </td><td> 7865000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> k </td><td>  2082058.61 </td><td>  36509.6683 </td><td> (1.75%) </td><td> 1000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>amp</td><td>k</td><td>-0.6556</td></tr><tr><td>const</td><td>k</td><td>+0.3554</td></tr></table>

# %%
fig, ax = plt.subplots(dpi=80)
plt.title("g-f transition")


plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result1.plot_fit(ax = ax)

plt.xlabel("frequency (Hz)")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
ge_freq = 8.02-0.00233#7.42
anharmonicity = -318e-3-0.00081

readout_freq = 10.297
qubit_lo_freq = 7.85
readout_lo_freq = 10.4 

2 * qubit_lo_freq - readout_lo_freq , 2 * ge_freq + anharmonicity - readout_freq
# Out:
# (5.299999999999999, 5.419529999999998)

# %%
readout_freq = 10.297
readout_lo_freq = 10.4 # 10.387
readout_if_freq = readout_lo_freq - readout_freq
JPA_if_freq = readout_freq * 2 - readout_lo_freq * 2

qubit_lo_freq = 7.85
ge_freq = 8.02-0.00233#7.42
anharmonicity = -318e-3-0.00081
ge_if_freq = ge_freq-qubit_lo_freq

fogi_lo_freq = 2 * qubit_lo_freq - readout_lo_freq 
fogi_lo_freq
# Out:
# 5.299999999999999

# %% [markdown]
# ## 11/8 ef calibration - DPR1-L-120-44

# %% [markdown]
# ef_freq =  (8.2779 -0.001898495-0.38408638 -0.0009)e9
#
# ef_pi_amp = 0.976
#
#
# T1 = 14.50e-06
#
# T2 =
#
# T2_star =

# %%
from plottr.data.datadict_storage import datadict_from_hdf5
import numpy as np
import matplotlib.pyplot as plt
import lmfit

# %%
import sklearn
from sklearn.decomposition import PCA

# %%
def Rabi(delay, amp, phi0, detun, const):
    return - amp * np.cos(2*np.pi*detun*delay+phi0) + const

# %% [markdown]
# amp

# %%
header = "D:/K_sunada/result/CDY151/"
ef = "/2023-11-14/2023-11-14T113822_e12b5608-30_ef_pi_amp"
dd_ef = datadict_from_hdf5(header + ef +"/data")

# %%
def PCA_transform(Re_c, Im_c):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c]).T, np.array([Im_c]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    return c_PCA1, c_PCA2

# %%
Rabi_ef = dd_ef['s11']['values']
#imag_ge = Rabi_ge.imag
amp_ef = dd_ef['amplitude']['values']

I = (Rabi_ef.real)
Q = (Rabi_ef.imag)

PCAef = PCA_transform(I, Q)

# %%
y = PCAef[0]
x = amp_ef

plt.plot(x, y)
plt.show()

# %%
par_ini = {
    'amp': 10,
    'phi0':np.pi,
    'detun':1/0.3,
    'const':0
}

par_min = {
    'amp': 0,
    'phi0':-2*np.pi,
    'detun':-np.inf,
    'const':0
}

par_max = {
    'amp': np.inf,
    'phi0':2*np.pi,
    'detun':np.inf,
    'const':np.inf,
}

par_vary = {
    'amp': True,
    'phi0':True,
    'detun':True,
    'const':True
}

# %%
model = lmfit.Model(Rabi)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )

# %%
result_ef = model.fit(data = y, params = params, delay = x)
result_ef
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>206</td><td></td></tr><tr><td># data points</td><td>88</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 898.706023</td><td></td></tr><tr><td>reduced chi-square</td><td> 10.6988812</td><td></td></tr><tr><td>Akaike info crit.</td><td> 212.478486</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 222.387834</td><td></td></tr><tr><td>R-squared</td><td> 0.86862201</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  11.4573373 </td><td>  0.48684713 </td><td> (4.25%) </td><td> 10 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  3.19088910 </td><td>  0.08912312 </td><td> (2.79%) </td><td> 3.141592653589793 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  3.55412091 </td><td>  0.02889578 </td><td> (0.81%) </td><td> 3.3333333333333335 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  2.2854e-10 </td><td>  1.40245481 </td><td> (613657558462.72%) </td><td> 0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>-0.8714</td></tr><tr><td>detun</td><td>const</td><td>+0.1872</td></tr><tr><td>phi0</td><td>const</td><td>-0.1850</td></tr></table>

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi")


plt.rcParams["font.size"] = 14
plt.tick_params(
            top='on',
            bottom='on`',
            left='on',
            right='on',
            )
result_ef.plot_fit(ax = ax)
# plt.plot(amp_ef,result_ef.init_fit)

ax.tick_params(axis="x", direction="in")
ax.tick_params(axis="y", direction="in")
ax.set_xlabel("Amplitude (V)", size='large')
ax.set_ylabel("PCA[S11](Arb. unit.)", size='large')


plt.show()

# %%
np.pi/(	3.55412091*2*np.pi)*5
# Out:
# 0.7034088212828977

# %% [markdown]
# ramsey

# %%
pl = "/2023-11-09/2023-11-09T100030_6126262c-32_ef_T2r1d"
mi = "/2023-11-09/2023-11-09T100235_ab4c6c1b-32_ef_T2r1d"
dd_pl = datadict_from_hdf5(header + pl +"/data")
dd_mi = datadict_from_hdf5(header + mi +"/data")

# %%
Rabi_pl = dd_pl['s11']['values']
imag_pl = Rabi_pl.imag
delay_pl = dd_pl['delay']['values']

Rabi_mi = dd_mi['s11']['values']
imag_mi = Rabi_mi.imag
delay_mi = dd_mi['delay']['values']

# %%
def PCA_transform(Re_c, Im_c):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c]).T, np.array([Im_c]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    return c_PCA1, c_PCA2


I_pl = (Rabi_pl.real)
Q_pl = (Rabi_pl.imag)
I_mi = (Rabi_mi.real)
Q_mi = (Rabi_mi.imag)


PCA_pl = PCA_transform(I_pl, Q_pl)
y_pl = PCA_pl[0]
x_pl = delay_pl

PCA_mi = PCA_transform(I_mi, Q_mi)
y_mi = PCA_mi[0]
x_mi = delay_mi



plt.plot(x_pl, y_pl)
plt.show()

# %%
par_ini_pl = {
    'amp': 7.5,
    'phi0':-np.pi,
    'detun':1/180,
    'const':0
}

par_min_pl = {
    'amp': 0,
    'phi0':-2*np.pi,
    'detun':-np.inf,
    'const':0
}

par_max_pl = {
    'amp': np.inf,
    'phi0':2*np.pi,
    'detun':np.inf,
    'const':np.inf,
}

par_vary_pl = {
    'amp': True,
    'phi0':True,
    'detun':True,
    'const':True
}

# %%
model = lmfit.Model(Rabi)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini_pl[name],
    min = par_min_pl[name],
    max = par_max_pl[name],
    vary = par_vary_pl[name]
    )
    
result_pl = model.fit(data = y_pl, params = params, delay = x_pl)
result_pl
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>146</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 132.797593</td><td></td></tr><tr><td>reduced chi-square</td><td> 1.36904735</td><td></td></tr><tr><td>Akaike info crit.</td><td> 35.6442651</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 46.1047472</td><td></td></tr><tr><td>R-squared</td><td> 0.94669143</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  6.85330104 </td><td>  0.16519304 </td><td> (2.41%) </td><td> 7.5 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td> -5.04548139 </td><td>  0.04686047 </td><td> (0.93%) </td><td> -3.141592653589793 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  0.00581072 </td><td>  1.3077e-05 </td><td> (0.23%) </td><td> 0.005555555555555556 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  3.1739e-10 </td><td>  0.11281139 </td><td> (35543969567.70%) </td><td> 0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>-0.8593</td></tr></table>

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(+5MHz)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result_pl.plot_fit(ax = ax)
plt.plot(x_pl,result_pl.init_fit)

plt.xlabel("delay (ns)")
plt.ylabel("mag[S11](a.u.)")


plt.show()

# %%
plt.plot(x_mi, y_mi)
plt.show()

# %%
par_ini_mi = {
    'amp': 7.5,
    'phi0':-np.pi/2,
    'detun':1/200,
    'const':0
}

par_min_mi = {
    'amp': 0,
    'phi0':-2*np.pi,
    'detun':-np.inf,
    'const':0
}

par_max_mi = {
    'amp': np.inf,
    'phi0':2*np.pi,
    'detun':np.inf,
    'const':np.inf,
}

par_vary_mi = {
    'amp': True,
    'phi0':True,
    'detun':True,
    'const':True
}

# %%
model = lmfit.Model(Rabi)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini_mi[name],
    min = par_min_mi[name],
    max = par_max_mi[name],
    vary = par_vary_mi[name]
    )
    
result_mi = model.fit(data = y_mi, params = params, delay = x_mi)
result_mi
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>89</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 130.290638</td><td></td></tr><tr><td>reduced chi-square</td><td> 1.34320245</td><td></td></tr><tr><td>Akaike info crit.</td><td> 33.7193585</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 44.1798406</td><td></td></tr><tr><td>R-squared</td><td> 0.95227771</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  7.31414182 </td><td>  0.16625162 </td><td> (2.27%) </td><td> 7.5 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  1.01807818 </td><td>  0.04236625 </td><td> (4.16%) </td><td> -1.5707963267948966 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  0.00419220 </td><td>  1.1536e-05 </td><td> (0.28%) </td><td> 0.005 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  4.6929e-11 </td><td>  0.12217037 </td><td> (260328289559.79%) </td><td> 0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>-0.8554</td></tr></table>

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(-5MHz)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result_mi.plot_fit(ax = ax)
plt.plot(x_mi,result_pl.init_fit)

plt.xlabel("delay (ns)")
plt.ylabel("mag[S11](a.u.)")


plt.show()

# %%
detun = ((0.005-0.00581072)+ (	0.00419220-0.005))/2 #GHz
detun
# Out:
# -0.00080926

# %% [markdown]
# drag

# %%
drag = "/2023-11-09/2023-11-09T103854_be5b698c-31_ef_pi_drag"
dd_drag = datadict_from_hdf5(header + drag +"/data")

drag1 = "/2023-11-09/2023-11-09T103749_97830d1f-31_ef_pi_drag"
dd_drag1 = datadict_from_hdf5(header + drag1 +"/data")

drag2 = "/2023-11-09/2023-11-09T103553_52336533-31_ef_pi_drag"
dd_drag2 = datadict_from_hdf5(header + drag2 +"/data")

# %%
Rabi_drag = dd_drag['s11']['values']
imag_drag = Rabi_drag.imag
drag = dd_drag['beta']['values']
I_drag = (Rabi_drag.real)
Q_drag = (Rabi_drag.imag)

Rabi_drag1 = dd_drag1['s11']['values']
imag_drag1 = Rabi_drag1.imag
drag1 = dd_drag1['beta']['values']
I_drag1 = (Rabi_drag1.real)
Q_drag1 = (Rabi_drag1.imag)

Rabi_drag2 = dd_drag2['s11']['values']
imag_drag2 = Rabi_drag2.imag
drag2 = dd_drag2['beta']['values']
I_drag2 = (Rabi_drag2.real)
Q_drag2 = (Rabi_drag2.imag)

# %%
def PCA_transform1(Re_c_amp, Im_c_amp, Re_c_drag, Im_c_drag):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c_amp]).T, np.array([Im_c_amp]).T], axis = 1)
    c1_data = np.concatenate([np.array([Re_c_drag]).T, np.array([Im_c_drag]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    
    c1_pca = pca.transform(c1_data)
    c1_PCA1 = c1_pca.T[0]
    c1_PCA2 = c1_pca.T[1]
    return c_PCA1, c_PCA2, c1_PCA1, c1_PCA2,

# %%
PCA_drag = PCA_transform1(I, Q, I_drag, Q_drag)
y = PCA_drag[0]
x = amp_ef
y0 = PCA_drag[2]
x0 = drag

PCA_drag1 = PCA_transform1(I, Q, I_drag1, Q_drag1)
y1 = PCA_drag1[2]
x1 = drag1

PCA_drag2 = PCA_transform1(I, Q, I_drag2, Q_drag2)
y2 = PCA_drag2[2]
x2 = drag2


plt.plot(x, y)
plt.show()

# %%
plt.plot(x0, y0)
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.show()

# %%
par_ini= {
    'amp': 0.00015,
    'phi0':np.pi/2,
    'detun':1/0.5,
    'const':0.89945
}

par_min = {
    'amp': 0,
    'phi0':-2*np.pi,
    'detun':0,
    'const':-np.inf
}

par_max = {
    'amp': np.inf,
    'phi0':2*np.pi,
    'detun':np.inf,
    'const':np.inf,
}

par_vary = {
    'amp': True,
    'phi0':True,
    'detun':True,
    'const':True
}

# %%
model = lmfit.Model(Rabi)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )
    
result0 = model.fit(data = y0, params = params, delay = x0)
result1 = model.fit(data = y1, params = params, delay = x1)
result2 = model.fit(data = y2, params = params, delay = x2)

# %%
result0
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>52</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 8.9611e-07</td><td></td></tr><tr><td>reduced chi-square</td><td> 9.2383e-09</td><td></td></tr><tr><td>Akaike info crit.</td><td>-1864.57211</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-1854.11163</td><td></td></tr><tr><td>R-squared</td><td> 0.03617185</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  2.6355e-05 </td><td>  1.3834e-05 </td><td> (52.49%) </td><td> 0.00015 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  1.41601497 </td><td>  0.97741513 </td><td> (69.03%) </td><td> 1.5707963267948966 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  2.21268941 </td><td>  0.26730453 </td><td> (12.08%) </td><td> 2.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  0.89943526 </td><td>  9.7013e-06 </td><td> (0.00%) </td><td> 0.89945 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>-0.8542</td></tr><tr><td>detun</td><td>const</td><td>-0.1055</td></tr></table>

# %%
res0 = (np.pi-2.29164748)/(2*np.pi*0.87150303)
res0
# Out:
# 0.15521802113977118

# %%
result1
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>21</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 2.3096e-08</td><td></td></tr><tr><td>reduced chi-square</td><td> 2.3810e-10</td><td></td></tr><tr><td>Akaike info crit.</td><td>-2234.07292</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-2223.61244</td><td></td></tr><tr><td>R-squared</td><td> 0.96418773</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  1.1372e-04 </td><td>  2.2341e-06 </td><td> (1.96%) </td><td> 0.00015 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  1.20688612 </td><td>  0.03551740 </td><td> (2.94%) </td><td> 1.5707963267948966 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  2.08981915 </td><td>  0.00968798 </td><td> (0.46%) </td><td> 2.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  0.89945148 </td><td>  1.5397e-06 </td><td> (0.00%) </td><td> 0.89945 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>-0.8502</td></tr></table>

# %%
res1 = (np.pi-1.20688573)/(2*np.pi*2.08981927)
res1
# Out:
# 0.14734200930371813

# %%
result2
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>36</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 3.5007e-08</td><td></td></tr><tr><td>reduced chi-square</td><td> 3.6090e-10</td><td></td></tr><tr><td>Akaike info crit.</td><td>-2192.06634</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-2181.60586</td><td></td></tr><tr><td>R-squared</td><td> 0.94512451</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  1.1556e-04 </td><td>  2.8365e-06 </td><td> (2.45%) </td><td> 0.00015 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  1.48787363 </td><td>  0.04433410 </td><td> (2.98%) </td><td> 1.5707963267948966 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  1.65008492 </td><td>  0.01198756 </td><td> (0.73%) </td><td> 2.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  0.89944748 </td><td>  2.0172e-06 </td><td> (0.00%) </td><td> 0.89945 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>-0.8598</td></tr><tr><td>detun</td><td>const</td><td>+0.2571</td></tr><tr><td>amp</td><td>const</td><td>-0.2247</td></tr><tr><td>phi0</td><td>const</td><td>-0.1708</td></tr></table>

# %%
res2 = (np.pi-1.48787363)/(2*np.pi*1.65008492)
res2
# Out:
# 0.15950546174885247

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(drag)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result0.plot_fit(ax = ax)
plt.plot(x0,result0.init_fit)

plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(drag)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result1.plot_fit(ax = ax)
plt.plot(x1,result1.init_fit)


plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(drag)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result2.plot_fit(ax = ax)

plt.plot(x2,result2.init_fit)


plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
beta = (res0 + res1 + res2)/3
beta
# Out:
# 0.1540218307307806

# %% [markdown]
# half drag

# %%
drag = "/2023-11-09/2023-11-09T105250_b028e29d-31_ef_pi_drag"
dd_drag = datadict_from_hdf5(header + drag +"/data")

drag1 = "/2023-11-09/2023-11-09T105400_d9e82cc5-31_ef_pi_drag"
dd_drag1 = datadict_from_hdf5(header + drag1 +"/data")

drag2 = "/2023-11-09/2023-11-09T105504_004c8509-31_ef_pi_drag"
dd_drag2 = datadict_from_hdf5(header + drag2 +"/data")

# %%
Rabi_drag = dd_drag['s11']['values']
imag_drag = Rabi_drag.imag
drag = dd_drag['beta']['values']
I_drag = (Rabi_drag.real)
Q_drag = (Rabi_drag.imag)

Rabi_drag1 = dd_drag1['s11']['values']
imag_drag1 = Rabi_drag1.imag
drag1 = dd_drag1['beta']['values']
I_drag1 = (Rabi_drag1.real)
Q_drag1 = (Rabi_drag1.imag)

Rabi_drag2 = dd_drag2['s11']['values']
imag_drag2 = Rabi_drag2.imag
drag2 = dd_drag2['beta']['values']
I_drag2 = (Rabi_drag2.real)
Q_drag2 = (Rabi_drag2.imag)

# %%
def PCA_transform1(Re_c_amp, Im_c_amp, Re_c_drag, Im_c_drag):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c_amp]).T, np.array([Im_c_amp]).T], axis = 1)
    c1_data = np.concatenate([np.array([Re_c_drag]).T, np.array([Im_c_drag]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    
    c1_pca = pca.transform(c1_data)
    c1_PCA1 = c1_pca.T[0]
    c1_PCA2 = c1_pca.T[1]
    return c_PCA1, c_PCA2, c1_PCA1, c1_PCA2,

# %%
PCA_drag = PCA_transform1(I, Q, I_drag, Q_drag)
y = PCA_drag[0]
x = amp_ef
y0 = PCA_drag[2]
x0 = drag

PCA_drag1 = PCA_transform1(I, Q, I_drag1, Q_drag1)
y1 = PCA_drag1[2]
x1 = drag1

PCA_drag2 = PCA_transform1(I, Q, I_drag2, Q_drag2)
y2 = PCA_drag2[2]
x2 = drag2


plt.plot(x, y)
plt.show()

# %%
plt.plot(x0, y0)
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.show()

# %%
par_ini= {
    'amp': 0.00006,
    'phi0':np.pi/2,
    'detun':1/1.1,
    'const':0.89954
}

par_min = {
    'amp': 0,
    'phi0':-2*np.pi,
    'detun':-np.inf,
    'const':0
}

par_max = {
    'amp': np.inf,
    'phi0':2*np.pi,
    'detun':np.inf,
    'const':np.inf,
}

par_vary = {
    'amp': True,
    'phi0':True,
    'detun':True,
    'const':True
}

# %%
model = lmfit.Model(Rabi)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )
    
result0 = model.fit(data = y0, params = params, delay = x0)
result1 = model.fit(data = y1, params = params, delay = x1)
result2 = model.fit(data = y2, params = params, delay = x2)

# %%
result0
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>33</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 2.1831e-08</td><td></td></tr><tr><td>reduced chi-square</td><td> 2.2506e-10</td><td></td></tr><tr><td>Akaike info crit.</td><td>-2239.76044</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-2229.29996</td><td></td></tr><tr><td>R-squared</td><td> 0.86313019</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  7.6379e-05 </td><td>  2.1159e-05 </td><td> (27.70%) </td><td> 6e-05 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  2.56353300 </td><td>  0.18792606 </td><td> (7.33%) </td><td> 1.5707963267948966 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  0.42779534 </td><td>  0.09615967 </td><td> (22.48%) </td><td> 0.9090909090909091 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  0.89951193 </td><td>  2.2224e-05 </td><td> (0.00%) </td><td> 0.89954 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>amp</td><td>const</td><td>-0.9949</td></tr><tr><td>detun</td><td>const</td><td>+0.9773</td></tr><tr><td>amp</td><td>detun</td><td>-0.9745</td></tr><tr><td>phi0</td><td>detun</td><td>-0.9470</td></tr><tr><td>amp</td><td>phi0</td><td>+0.8682</td></tr><tr><td>phi0</td><td>const</td><td>-0.8652</td></tr></table>

# %%
res0 = (np.pi-2.56353244)/(2*np.pi*0.42779581)
res0
# Out:
# 0.21505853551387613

# %%
result1
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>26</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 3.2755e-08</td><td></td></tr><tr><td>reduced chi-square</td><td> 3.3768e-10</td><td></td></tr><tr><td>Akaike info crit.</td><td>-2198.78339</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-2188.32291</td><td></td></tr><tr><td>R-squared</td><td> 0.74689567</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  4.0642e-05 </td><td>  2.5040e-06 </td><td> (6.16%) </td><td> 6e-05 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  2.20407632 </td><td>  0.18484664 </td><td> (8.39%) </td><td> 1.5707963267948966 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  0.70396334 </td><td>  0.06202402 </td><td> (8.81%) </td><td> 0.9090909090909091 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  0.89954907 </td><td>  2.6623e-06 </td><td> (0.00%) </td><td> 0.89954 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>-0.8881</td></tr><tr><td>detun</td><td>const</td><td>+0.5551</td></tr><tr><td>amp</td><td>const</td><td>-0.2868</td></tr><tr><td>phi0</td><td>const</td><td>-0.2816</td></tr><tr><td>amp</td><td>detun</td><td>-0.1673</td></tr></table>

# %%
res1 = (2*np.pi-4.30230786)/(2*np.pi*1.63131373)
res1
# Out:
# 0.1932592312441862

# %%
result2
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>26</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 2.6442e-08</td><td></td></tr><tr><td>reduced chi-square</td><td> 2.7260e-10</td><td></td></tr><tr><td>Akaike info crit.</td><td>-2220.40696</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-2209.94647</td><td></td></tr><tr><td>R-squared</td><td> 0.68486366</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  3.5626e-05 </td><td>  2.4735e-06 </td><td> (6.94%) </td><td> 6e-05 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  1.20185553 </td><td>  0.11482421 </td><td> (9.55%) </td><td> 1.5707963267948966 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  1.12022158 </td><td>  0.03056450 </td><td> (2.73%) </td><td> 0.9090909090909091 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  0.89955996 </td><td>  1.6622e-06 </td><td> (0.00%) </td><td> 0.89954 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>-0.8371</td></tr><tr><td>amp</td><td>detun</td><td>+0.1261</td></tr><tr><td>amp</td><td>phi0</td><td>-0.1064</td></tr></table>

# %%
res2 = (1*np.pi-1.20185553)/(2*np.pi*1.12022158)
res2
# Out:
# 0.2755872204480923

# %%
(res0+res1+res2)/3
# Out:
# 0.22796832906871822

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(drag)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result0.plot_fit(ax = ax)
plt.plot(x0,result0.init_fit)


plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(drag)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result1.plot_fit(ax = ax)
plt.plot(x1,result1.init_fit)


plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(drag)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result2.plot_fit(ax = ax)

plt.plot(x2,result2.init_fit)


plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %% [markdown]
# T1

# %%
def Dephase(delay, amp, gamma, const):
    return amp*np.exp(-gamma*delay) + const

t1 ="/2023-11-09/2023-11-09T101024_c306f41e-33_ef_T1"

dd_t1 = datadict_from_hdf5(header + t1 +"/data")

# %%
s11_t1 = dd_t1['s11']['values'][0:99]
imag_t1 = s11_t1.imag
delay_t1 = dd_t1['delay']['values'][0:99]

I_t1 = (s11_t1.real)
Q_t1 = (s11_t1.imag)

PCA_t1 = PCA_transform(I_t1, Q_t1)

y_t1 = PCA_t1[0]
x_t1 = delay_t1

plt.plot(x_t1, y_t1)
plt.show()

# %%
par_ini_t1 = {
    'gamma': 1/20000,
    'amp':20,
    'const':-5
}

par_min_t1 = {
    'gamma': 0,
    'amp':0,
    'const':-np.inf
}

par_max_t1 = {
    'gamma': np.inf,
    'amp':np.inf,
    'const':np.inf,
}

par_vary_t1 = {
    'gamma': True,
    'amp':True,
    'const':True
}

# %%
model = lmfit.Model(Dephase)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini_t1[name],
    min = par_min_t1[name],
    max = par_max_t1[name],
    vary = par_vary_t1[name]
    )
result_t1 = model.fit(data = y_t1, params = params, delay = x_t1)
result_t1
# Out:
# <h2> Model</h2> Model(Dephase) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>21</td><td></td></tr><tr><td># data points</td><td>99</td><td></td></tr><tr><td># variables</td><td>3</td><td></td></tr><tr><td>chi-square</td><td> 283.580090</td><td></td></tr><tr><td>reduced chi-square</td><td> 2.95395927</td><td></td></tr><tr><td>Akaike info crit.</td><td> 110.185099</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 117.970459</td><td></td></tr><tr><td>R-squared</td><td> 0.88032713</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  19.3203775 </td><td>  0.83276098 </td><td> (4.31%) </td><td> 20 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> gamma </td><td>  6.6683e-05 </td><td>  5.4997e-06 </td><td> (8.25%) </td><td> 5e-05 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td> -3.02114463 </td><td>  0.27103595 </td><td> (8.97%) </td><td> -5 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>gamma</td><td>const</td><td>+0.6464</td></tr><tr><td>amp</td><td>gamma</td><td>+0.4876</td></tr></table>

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("T1")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result_t1.plot_fit(ax = ax)
plt.plot(delay_t1,result_t1.init_fit)

plt.xlabel("delay (ns)")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
T1 = (1/6.6683e-05)*1e-9	
T1
# Out:
# 1.4996325900154463e-05

# %% [markdown]
# ## no data
#
# T2_star

# %%
t2e = "/2023-07-01/2023-07-01T181335_8e8e04ba-td_ge_T2e"
dd_t2e = datadict_from_hdf5(header + t2e +"/data")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\K_Sunada\analysis\CDY151(44)\CDY151-ef_calibration.ipynb Cell 74 line 2
#       <a href='vscode-notebook-cell:/d%3A/K_Sunada/analysis/CDY151%2844%29/CDY151-ef_calibration.ipynb#Y132sZmlsZQ%3D%3D?line=0'>1</a> t2e = "/2023-07-01/2023-07-01T181335_8e8e04ba-td_ge_T2e"
# ----> <a href='vscode-notebook-cell:/d%3A/K_Sunada/analysis/CDY151%2844%29/CDY151-ef_calibration.ipynb#Y132sZmlsZQ%3D%3D?line=1'>2</a> dd_t2e = datadict_from_hdf5(header + t2e +"/data")
#
# File d:\K_Sunada\.venv\lib\site-packages\plottr\data\datadict_storage.py:263, in datadict_from_hdf5(path, groupname, startidx, stopidx, structure_only, ignore_unequal_lengths, file_timeout)
#     261 filepath = _data_file_path(path)
#     262 if not filepath.exists():
# --> 263     raise ValueError("Specified file does not exist.")
#     265 if startidx is None:
#     266     startidx = 0
#
# ValueError: Specified file does not exist.

# %%
s11_t2e = dd_t2e['s11']['values']
imag_t2e = s11_t2e.imag
delay_t2e = dd_t2e['delay']['values']

I_t2e = (s11_t2e.real)
Q_t2e = (s11_t2e.imag)

PCA_t2e = PCA_transform(I_t2e, Q_t2e)

y_t2e = PCA_t2e[0]
x_t2e = delay_t2e

plt.plot(x_t2e, y_t2e)
plt.show()

# %%
par_ini_t2e = {
    'gamma': 1/2000,
    'amp':70,
    'const':0
}

par_min_t2e = {
    'gamma': 0,
    'amp':0,
    'const':-np.inf
}

par_max_t2e = {
    'gamma': np.inf,
    'amp':np.inf,
    'const':np.inf,
}

par_vary_t2e = {
    'gamma': True,
    'amp':True,
    'const':True
}

# %%
model = lmfit.Model(Dephase)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini_t2e[name],
    min = par_min_t2e[name],
    max = par_max_t2e[name],
    vary = par_vary_t2e[name]
    )
result_t2e = model.fit(data = y_t2e, params = params, delay = x_t2e)
result_t2e
# Out:
# <h2> Model</h2> Model(Dephase) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>29</td><td></td></tr><tr><td># data points</td><td>51</td><td></td></tr><tr><td># variables</td><td>3</td><td></td></tr><tr><td>chi-square</td><td> 191.594875</td><td></td></tr><tr><td>reduced chi-square</td><td> 3.99155989</td><td></td></tr><tr><td>Akaike info crit.</td><td> 73.5014316</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 79.2969085</td><td></td></tr><tr><td>R-squared</td><td> 0.96665825</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  68.3281014 </td><td>  1.97040220 </td><td> (2.88%) </td><td> 70 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> gamma </td><td>  0.00132869 </td><td>  7.9142e-05 </td><td> (5.96%) </td><td> 0.0005 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td> -2.43852809 </td><td>  0.29547471 </td><td> (12.12%) </td><td> 0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>amp</td><td>gamma</td><td>+0.3687</td></tr><tr><td>gamma</td><td>const</td><td>+0.2337</td></tr><tr><td>amp</td><td>const</td><td>-0.1195</td></tr></table>

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("T2")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result_t2e.plot_fit(ax = ax)
plt.plot(delay_t2e,result_t2e.init_fit)

plt.xlabel("delay (ns)")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
T2 = (1/0.00132869)*1e-9	
T2
# Out:
# 7.526210026416998e-07

# %% [markdown]
# T2 star

# %%
def Damping(delay, amp, gamma, omega, phi0, const):
    return const + amp * np.exp(- gamma*delay)*np.cos(omega*delay + phi0)

# %%
t2 = "/2023-07-01/2023-07-01T182745_892e135d-td_ge_T2r1d"
dd_t2 = datadict_from_hdf5(header + t2 +"/data")

# %%
s11_t2 = dd_t2['s11']['values']
imag_t2 = s11_t2.imag
delay_t2 = dd_t2['delay']['values']

I_t2 = (s11_t2.real)
Q_t2 = (s11_t2.imag)

PCA_t2 = PCA_transform(I_t2, Q_t2)

y_t2 = PCA_t2[0]
x_t2 = delay_t2

plt.plot(x_t2, y_t2)
plt.show()

# %%
par_ini_t2 = {
    'amp':60,
    'gamma': 1/1500,
    'omega':2*np.pi/500,
    'phi0':0,
    'const':0
}

par_min_t2 = {
    'amp':-np.inf,
    'gamma': 0,
    'omega':-2*np.pi,
    'phi0':-2*np.pi,
    'const':-np.inf
}

par_max_t2 = {
    'amp':np.inf,
    'gamma': np.inf,
    'omega':2*np.pi,
    'phi0':2*np.pi,
    'const':np.inf
}

par_vary_t2 = {
    'amp':True,
    'gamma': True,
    'omega':True,
    'phi0':True,
    'const':True
}

# %%
model = lmfit.Model(Damping)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini_t2[name],
    min = par_min_t2[name],
    max = par_max_t2[name],
    vary = par_vary_t2[name]
    )
result_t2 = model.fit(data = y_t2, params = params, delay = x_t2)
result_t2
# Out:
# <h2> Model</h2> Model(Damping) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>43</td><td></td></tr><tr><td># data points</td><td>31</td><td></td></tr><tr><td># variables</td><td>5</td><td></td></tr><tr><td>chi-square</td><td> 97.7683953</td><td></td></tr><tr><td>reduced chi-square</td><td> 3.76032290</td><td></td></tr><tr><td>Akaike info crit.</td><td> 45.6070391</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 52.7769751</td><td></td></tr><tr><td>R-squared</td><td> 0.98958790</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  69.5196638 </td><td>  1.88680504 </td><td> (2.71%) </td><td> 60 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> gamma </td><td>  0.00157781 </td><td>  6.5042e-05 </td><td> (4.12%) </td><td> 0.0006666666666666666 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> omega </td><td>  0.01245770 </td><td>  6.9543e-05 </td><td> (0.56%) </td><td> 0.012566370614359173 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> phi0 </td><td>  0.52254294 </td><td>  0.03031269 </td><td> (5.80%) </td><td> 0 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> const </td><td> -0.43875330 </td><td>  0.35377664 </td><td> (80.63%) </td><td> 0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>omega</td><td>phi0</td><td>-0.7012</td></tr><tr><td>amp</td><td>gamma</td><td>+0.6482</td></tr><tr><td>amp</td><td>phi0</td><td>+0.3063</td></tr><tr><td>amp</td><td>omega</td><td>-0.2258</td></tr><tr><td>gamma</td><td>phi0</td><td>+0.2099</td></tr><tr><td>phi0</td><td>const</td><td>+0.1682</td></tr><tr><td>gamma</td><td>omega</td><td>-0.1535</td></tr><tr><td>omega</td><td>const</td><td>-0.1258</td></tr></table>

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("T2star")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result_t2.plot_fit(ax = ax)
plt.plot(delay_t2,result_t2.init_fit)

plt.xlabel("delay (ns)")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
T2_star = (1/0.00157781	)*1e-9	
T2_star
# Out:
# 6.337898733054044e-07

# %%
from plottr.data.datadict_storage import datadict_from_hdf5
import numpy as np
import matplotlib.pyplot as plt
import lmfit
import scipy.constants as spc

# %%
res_dressed = "/2023-12-25/2023-12-25T141923_2a876859-cw_sparameter" # R.T.: -30dB, vna output: -10dB
res_bare = "/2023-12-25/2023-12-25T131522_38c68282-cw_sparameter" # R.T.: -30dB, vna output: 20dB
punchout = "/2023-12-25/2023-12-25T131044_9334f0c3-cw_punchout" # R.T.: -30dB, vna output: -20 ~ 20dB

# %%
header = "D:/K_sunada/result/CDY153/"
dd_d = datadict_from_hdf5(header + res_dressed +"/data")
dd_b = datadict_from_hdf5(header + res_bare +"/data")

# %% [markdown]
# dpr

# %%
def S11_dpr_model(freq, fr, ff, kf_e, kf_i, gamma, g, a0, a1, Poff,ed):
    numer = (1j*(freq-ff)+(kf_e-kf_i)/2)*(1j*(freq-fr)-gamma/2) + (g**2)
    denom = (1j*(freq-ff)-(kf_e+kf_i)/2)*(1j*(freq-fr)-gamma/2) + (g**2)
    model = (numer/denom * (a0+a1*(freq-freq[0])) * np.exp(1j*(Poff-ed*2*np.pi*(freq-freq[0])))).conj()
    return model

# %%
freq_d = dd_d['frequency']['values']
s11_d = dd_d['s21']['values']
freq_b = dd_b['frequency']['values']
s11_b = dd_b['s21']['values']

# %%
fig,ax = plt.subplots(1,2)
ax[0].plot(freq_d,np.abs(s11_d))
ax[1].plot(freq_d,np.angle(s11_d))

# %%
par_ini = {'fr': 10.26e9,  'ff': 10.193e9,    'kf_e': 210e6,   'kf_i': 0.e6,  'g': 95e6, 'gamma': 0.e6,
           'a0': 0.003,  'a1': 0.0,        'Poff': -1,   'ed': -7e-6}
par_min = {'fr': 0,     'ff': 0,        'kf_e': 0,        'kf_i': 0,        'g': 0,     'gamma': 0,
           'a0': -np.inf,     'a1': -np.inf,  'Poff': -np.inf,'ed': -np.inf}
par_max = {'fr': np.inf,'ff': np.inf,   'kf_e': np.inf,   'kf_i': np.inf,   'g': np.inf,'gamma': np.inf,
           'a0': np.inf,'a1': np.inf,   'Poff': np.inf, 'ed': np.inf}
par_var = {'fr': True, 'ff': True,    'kf_e': True,    'kf_i': False,    'g': True, 'gamma': False,
           'a0': True, 'a1': True,    'Poff': True,  'ed': True}

model=lmfit.Model(S11_dpr_model)
params = model.make_params()

for name in list(par_ini):
    params[name].set(value=par_ini[name])
for name in list(par_min):
    params[name].set(min=par_min[name])  
for name in list(par_max):
    params[name].set(max=par_max[name]) 
for name in list(par_var):
    params[name].set(vary=par_var[name])
    
result_d = model.fit(freq=freq_d, data=s11_d, params=params, method='leastsq')
result_b = model.fit(freq=freq_b, data=s11_b, params=params, method='leastsq')

# %% [markdown]
# dressed

# %%
fig, ax = plt.subplots(1, 2, figsize=(16,6))#,constrained_layout=True)
plt.rcParams["font.size"] = 20
plt.subplots_adjust(wspace=0.3)
ax[0].set_xlabel('Re[S$_{11}$] (arb. u.) ')
ax[0].set_ylabel('Im[S$_{11}$] (arb. u.) ')
ax[0].tick_params(axis="x", direction="in")
ax[0].tick_params(axis="y", direction="in")

ax[1].set_xlabel('Probe frequency $\omega_\mathrm{p}$ (GHz)')
ax[1].set_ylabel('Phase[S$_{11}$] (rad) ')
ax[1].tick_params(axis="x", direction="in")
ax[1].tick_params(axis="y", direction="in")

plt.tick_params(top='on',bottom='on',left='on',right='on',)
ax[0].plot(np.real(s11_d),np.imag(s11_d), ls='', marker='o')
ax[0].plot(np.real(result_d.best_fit),np.imag(result_d.best_fit))
# ax[0].plot(np.real(result_d.init_fit),np.imag(result_d.init_fit), color='green', ls='--', )

ax[1].plot(freq_d*1e-9,np.angle(s11_d), ls='', marker='o')
ax[1].plot(freq_d*1e-9,np.angle(result_d.best_fit))
# ax[1].plot(freq_d,np.angle(result_d.init_fit), color='green', ls='--', )

result_d
# plt.savefig('dressed_res.png', bbox_inches='tight')
# plt.show()
# Out:
# <h2> Model</h2> Model(S11_dpr_model) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>67</td><td></td></tr><tr><td># data points</td><td>402</td><td></td></tr><tr><td># variables</td><td>8</td><td></td></tr><tr><td>chi-square</td><td> 3.2562e-04</td><td></td></tr><tr><td>reduced chi-square</td><td> 8.2644e-07</td><td></td></tr><tr><td>Akaike info crit.</td><td>-5622.54709</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-5590.57547</td><td></td></tr><tr><td>R-squared</td><td>0.83384949-0.23549843j</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> fr </td><td>  1.0266e+10 </td><td>  2048424.88 </td><td> (0.02%) </td><td> 10260000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> ff </td><td>  1.0192e+10 </td><td>  4294246.59 </td><td> (0.04%) </td><td> 10193000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> kf_e </td><td>  2.3224e+08 </td><td>  9531314.97 </td><td> (4.10%) </td><td> 210000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> kf_i </td><td>  0.00000000 </td><td>  0.00000000 </td><td>  </td><td> 0.0 </td><td>  0.00000000 </td><td>         inf </td><td> False </td></tr><tr><td> gamma </td><td>  0.00000000 </td><td>  0.00000000 </td><td>  </td><td> 0.0 </td><td>  0.00000000 </td><td>         inf </td><td> False </td></tr><tr><td> g </td><td>  87888556.8 </td><td>  1673100.74 </td><td> (1.90%) </td><td> 95000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> a0 </td><td>  0.00383955 </td><td>  1.2813e-04 </td><td> (3.34%) </td><td> 0.003 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> a1 </td><td> -1.2046e-12 </td><td>  2.3101e-13 </td><td> (19.18%) </td><td> 0.0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> Poff </td><td> -0.47508707 </td><td>  0.06188978 </td><td> (13.03%) </td><td> -1 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> ed </td><td> -6.9998e-06 </td><td>  1.7894e-11 </td><td> (0.00%) </td><td> -7e-06 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>Poff</td><td>ed</td><td>+0.8778</td></tr><tr><td>a0</td><td>a1</td><td>-0.8470</td></tr><tr><td>kf_e</td><td>ed</td><td>-0.7504</td></tr><tr><td>kf_e</td><td>Poff</td><td>-0.6497</td></tr><tr><td>fr</td><td>g</td><td>-0.5290</td></tr><tr><td>ff</td><td>Poff</td><td>+0.4545</td></tr><tr><td>fr</td><td>ff</td><td>-0.3728</td></tr><tr><td>g</td><td>ed</td><td>-0.3144</td></tr><tr><td>g</td><td>Poff</td><td>-0.3099</td></tr><tr><td>a1</td><td>ed</td><td>+0.2909</td></tr><tr><td>a1</td><td>Poff</td><td>+0.2552</td></tr><tr><td>kf_e</td><td>g</td><td>+0.2540</td></tr><tr><td>kf_e</td><td>a1</td><td>-0.2182</td></tr><tr><td>ff</td><td>ed</td><td>+0.1863</td></tr><tr><td>ff</td><td>g</td><td>+0.1714</td></tr><tr><td>fr</td><td>Poff</td><td>+0.1127</td></tr></table>

# %%
fig, ax = plt.subplots(1,2,figsize=(16,6),constrained_layout=True)
ax[0].set_xlabel('Frequency(GHz)',fontsize=18)
ax[0].set_ylabel('Re[$S_{11}]$', fontsize=18)
ax[1].set_xlabel('Frequency(GHz)',fontsize=16)
ax[1].set_ylabel('Im[$S_{11}]$', fontsize=16)
# ax.tick_params(direction='in')

ax[0].plot(freq_d,np.real(s11_d), ls='', marker='.')
ax[0].plot(freq_d,np.real(result_d.best_fit), color='orange')
ax[0].plot(freq_d,np.real(result_d.init_fit), color='green', ls='--', marker='')
ax[1].plot(freq_d,np.imag(s11_d), ls='', marker='.')
ax[1].plot(freq_d,np.imag(result_d.best_fit), color='orange')

# %% [markdown]
# bare

# %%
par_ini = {'fr': 10.255e9,  'ff': 10.192e9,    'kf_e': 248e6,   'kf_i': 0.e6,  'g': 86e6, 'gamma': 0.e6,
           'a0': 0.0037,  'a1': 0.0,        'Poff': -0.47,   'ed': -7e-6}
par_min = {'fr': 0,     'ff': 0,        'kf_e': 0,        'kf_i': 0,        'g': 0,     'gamma': 0,
           'a0': -np.inf,     'a1': -np.inf,  'Poff': -np.inf,'ed': -np.inf}
par_max = {'fr': np.inf,'ff': np.inf,   'kf_e': np.inf,   'kf_i': np.inf,   'g': np.inf,'gamma': np.inf,
           'a0': np.inf,'a1': np.inf,   'Poff': np.inf, 'ed': np.inf}
par_var = {'fr': True, 'ff': True,    'kf_e': True,    'kf_i': False,    'g': True, 'gamma': False,
           'a0': True, 'a1': True,    'Poff': True,  'ed': True}

model=lmfit.Model(S11_dpr_model)
params = model.make_params()

for name in list(par_ini):
    params[name].set(value=par_ini[name])
for name in list(par_min):
    params[name].set(min=par_min[name])  
for name in list(par_max):
    params[name].set(max=par_max[name]) 
for name in list(par_var):
    params[name].set(vary=par_var[name])
    
result_d = model.fit(freq=freq_d, data=s11_d, params=params, method='leastsq')
result_b = model.fit(freq=freq_b, data=s11_b, params=params, method='leastsq')

# %%
fig, ax = plt.subplots(1, 2, figsize=(16,6))#,constrained_layout=True)
plt.rcParams["font.size"] = 20
plt.subplots_adjust(wspace=0.3)
ax[0].set_xlabel('Re[S$_{11}$] (arb. u.) ')
ax[0].set_ylabel('Im[S$_{11}$] (arb. u.) ')
ax[0].tick_params(axis="x", direction="in")
ax[0].tick_params(axis="y", direction="in")

ax[1].set_xlabel('Probe frequency $\omega_\mathrm{p}$ (GHz)')
ax[1].set_ylabel('Phase[S$_{11}$] (rad) ')
ax[1].tick_params(axis="x", direction="in")
ax[1].tick_params(axis="y", direction="in")

plt.tick_params(top='on',bottom='on',left='on',right='on',)
ax[0].plot(np.real(s11_b),np.imag(s11_b), ls='', marker='o')
ax[0].plot(np.real(result_b.best_fit),np.imag(result_b.best_fit))
# ax[0].plot(np.real(result_d.init_fit),np.imag(result_d.init_fit), color='green', ls='--', )

ax[1].plot(freq_b*1e-9,np.angle(s11_b), ls='', marker='o')
ax[1].plot(freq_b*1e-9,np.angle(result_b.best_fit))
# ax[1].plot(freq_d,np.angle(result_d.init_fit), color='green', ls='--', )

result_b
# plt.savefig('bare_res.png', bbox_inches='tight')
# Out:
# <h2> Model</h2> Model(S11_dpr_model) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>94</td><td></td></tr><tr><td># data points</td><td>402</td><td></td></tr><tr><td># variables</td><td>8</td><td></td></tr><tr><td>chi-square</td><td> 3.6157e-04</td><td></td></tr><tr><td>reduced chi-square</td><td> 9.1769e-07</td><td></td></tr><tr><td>Akaike info crit.</td><td>-5580.44562</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-5548.47400</td><td></td></tr><tr><td>R-squared</td><td>0.80050020-0.27653225j</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> fr </td><td>  1.0255e+10 </td><td>  2077649.47 </td><td> (0.02%) </td><td> 10255000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> ff </td><td>  1.0194e+10 </td><td>  4732363.23 </td><td> (0.05%) </td><td> 10192000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> kf_e </td><td>  2.4661e+08 </td><td>  10851715.8 </td><td> (4.40%) </td><td> 248000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> kf_i </td><td>  0.00000000 </td><td>  0.00000000 </td><td>  </td><td> 0.0 </td><td>  0.00000000 </td><td>         inf </td><td> False </td></tr><tr><td> gamma </td><td>  0.00000000 </td><td>  0.00000000 </td><td>  </td><td> 0.0 </td><td>  0.00000000 </td><td>         inf </td><td> False </td></tr><tr><td> g </td><td>  86799659.7 </td><td>  1727802.14 </td><td> (1.99%) </td><td> 86000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> a0 </td><td>  0.00381536 </td><td>  1.3503e-04 </td><td> (3.54%) </td><td> 0.0037 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> a1 </td><td> -1.2049e-12 </td><td>  2.4399e-13 </td><td> (20.25%) </td><td> 0.0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> Poff </td><td> -0.55222258 </td><td>  0.06770659 </td><td> (12.26%) </td><td> -0.47 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> ed </td><td> -6.9998e-06 </td><td>  1.9532e-11 </td><td> (0.00%) </td><td> -7e-06 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>Poff</td><td>ed</td><td>+0.8790</td></tr><tr><td>a0</td><td>a1</td><td>-0.8461</td></tr><tr><td>kf_e</td><td>ed</td><td>-0.7654</td></tr><tr><td>kf_e</td><td>Poff</td><td>-0.6634</td></tr><tr><td>ff</td><td>Poff</td><td>+0.4733</td></tr><tr><td>fr</td><td>g</td><td>-0.4369</td></tr><tr><td>g</td><td>ed</td><td>-0.3415</td></tr><tr><td>g</td><td>Poff</td><td>-0.3282</td></tr><tr><td>fr</td><td>ff</td><td>-0.3249</td></tr><tr><td>a1</td><td>ed</td><td>+0.2979</td></tr><tr><td>kf_e</td><td>g</td><td>+0.2766</td></tr><tr><td>a1</td><td>Poff</td><td>+0.2618</td></tr><tr><td>kf_e</td><td>a1</td><td>-0.2280</td></tr><tr><td>ff</td><td>ed</td><td>+0.1930</td></tr><tr><td>fr</td><td>Poff</td><td>+0.1221</td></tr><tr><td>ff</td><td>g</td><td>+0.1100</td></tr><tr><td>ff</td><td>kf_e</td><td>-0.1028</td></tr><tr><td>g</td><td>a1</td><td>-0.1017</td></tr></table>

# %%
fig, ax = plt.subplots(figsize=(10,6),constrained_layout=True)
plt.rcParams["font.size"] = 15
ax.set_xlabel('Frequency (GHz)',fontsize=18)
ax.set_ylabel('Phase[S$_{11}$] (arg) ', fontsize=18)
# ax.tick_params(direction='in')
ax.tick_params(axis="x", direction="in")
ax.tick_params(axis="y", direction="in")
# ax1.set_xlim(0, 250000)
# ax1.set_ylim(-48, 160)

plt.tick_params(
            top='on',
            bottom='on`',
            left='on',
            right='on',
            )

ax.plot(freq_b,np.angle(s11_b), ls='', marker='o')

ax.plot(freq_b,np.angle(result_b.best_fit), color='orange')
ax.plot(freq_b,np.angle(result_b.init_fit), color='green', ls='--', )

# ax[1][0].plot(freq,np.abs(s11) - np.abs(result.best_fit), ls='', marker='.')
# error_phi = np.angle(s11) - np.angle(result.best_fit)
# error_phi[error_phi>np.pi] -= 2*np.pi
# error_phi[error_phi<-np.pi] += 2*np.pi
# ax[1][1].plot(freq,error_phi, ls='', marker='.')

result_b
# Out:
# <h2> Model</h2> Model(S11_dpr_model) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>58</td><td></td></tr><tr><td># data points</td><td>402</td><td></td></tr><tr><td># variables</td><td>8</td><td></td></tr><tr><td>chi-square</td><td> 3.6144e-04</td><td></td></tr><tr><td>reduced chi-square</td><td> 9.1737e-07</td><td></td></tr><tr><td>Akaike info crit.</td><td>-5580.58768</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-5548.61606</td><td></td></tr><tr><td>R-squared</td><td>0.80057068-0.27643455j</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> fr </td><td>  1.0255e+10 </td><td>  2072101.33 </td><td> (0.02%) </td><td> 10260000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> ff </td><td>  1.0194e+10 </td><td>  4760901.19 </td><td> (0.05%) </td><td> 10193000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> kf_e </td><td>  2.4847e+08 </td><td>  10938891.7 </td><td> (4.40%) </td><td> 210000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> kf_i </td><td>  0.00000000 </td><td>  0.00000000 </td><td>  </td><td> 0.0 </td><td>  0.00000000 </td><td>         inf </td><td> False </td></tr><tr><td> gamma </td><td>  0.00000000 </td><td>  0.00000000 </td><td>  </td><td> 0.0 </td><td>  0.00000000 </td><td>         inf </td><td> False </td></tr><tr><td> g </td><td>  86936382.7 </td><td>  1731232.95 </td><td> (1.99%) </td><td> 95000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> a0 </td><td>  0.00379624 </td><td>  1.3502e-04 </td><td> (3.56%) </td><td> 0.003 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> a1 </td><td> -1.1634e-12 </td><td>  2.4415e-13 </td><td> (20.99%) </td><td> 0.0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> Poff </td><td> -0.56081075 </td><td>  0.06806979 </td><td> (12.14%) </td><td> -1 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> ed </td><td> -6.9998e-06 </td><td>  1.9565e-11 </td><td> (0.00%) </td><td> -7e-06 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>Poff</td><td>ed</td><td>+0.8799</td></tr><tr><td>a0</td><td>a1</td><td>-0.8459</td></tr><tr><td>kf_e</td><td>ed</td><td>-0.7667</td></tr><tr><td>kf_e</td><td>Poff</td><td>-0.6634</td></tr><tr><td>ff</td><td>Poff</td><td>+0.4781</td></tr><tr><td>fr</td><td>g</td><td>-0.4332</td></tr><tr><td>g</td><td>ed</td><td>-0.3444</td></tr><tr><td>g</td><td>Poff</td><td>-0.3307</td></tr><tr><td>fr</td><td>ff</td><td>-0.3197</td></tr><tr><td>a1</td><td>ed</td><td>+0.3005</td></tr><tr><td>kf_e</td><td>g</td><td>+0.2783</td></tr><tr><td>a1</td><td>Poff</td><td>+0.2643</td></tr><tr><td>kf_e</td><td>a1</td><td>-0.2304</td></tr><tr><td>ff</td><td>ed</td><td>+0.1984</td></tr><tr><td>fr</td><td>Poff</td><td>+0.1235</td></tr><tr><td>ff</td><td>kf_e</td><td>-0.1063</td></tr><tr><td>g</td><td>a1</td><td>-0.1035</td></tr><tr><td>ff</td><td>g</td><td>+0.1031</td></tr></table>

# %% [markdown]
# punchout

# %%
dd = datadict_from_hdf5(header + punchout +"/data")
dd
# Out:
# s11: (20, 1001)
#   ⌙ frequency (Hz): (20, 1001)
#   ⌙ power (dBm): (20,)

# %%
dd = datadict_from_hdf5(header + punchout +"/data")
x = np.unique(dd['power']['values'])
y = np.unique(dd['frequency']['values'])
z = dd['s11']['values']

# %%
cm = plt.cm.get_cmap('magma')
fig= plt.figure()
plt.rcParams["font.size"] = 20
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'

ax = fig.add_axes((0.1, 0.1, 0.9, 0.9))
ax.set_xlabel("VNA power $P_{\mathrm{VNA}}$ (dBm)")
ax.set_ylabel("Probe frequency $\omega_\mathrm{p}$ (GHz)")
ax.set_xlim(-10, 20)
ax.set_ylim(10, 10.6)

maingraph = ax.pcolormesh(x,y*1e-9, np.angle(z).reshape(20, 1001).T, vmin=min(np.unique(np.angle(z))), vmax=max(np.unique(np.angle(z))), cmap=cm, shading='auto')
plt.colorbar(maingraph, label="Phase[S$_{11}$] (arg)")
plt.tick_params(top='on',bottom='on',left='on',right='on')
# plt.savefig('punchout.png', bbox_inches='tight')
plt.show()
# Out:
# C:\Users\qipe\AppData\Local\Temp\ipykernel_11816\1979531795.py:1: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cm = plt.cm.get_cmap('magma')

# %% [markdown]
# 平均光子数

# %%
def ave_photon_number(Power, k_ex, k_in, omega_r, omega_p):
    n = (k_ex/(((k_in + k_ex)/2)**2 + (omega_r - omega_p)**2))*(Power/(spc.hbar * omega_p))
    return n

# %%
spc.hbar
# Out:
# 1.0545718176461565e-34

# %%
k_ex = 0.19078723e9*(2*np.pi)
k_in = 0

omega_r = 10.2503210e9*2*np.pi
omega_p = 10.297e9*2*np.pi

Power =  10**((-22.4-10-2.3-50-20)/10) *1e-3#J/s
Power
# ave_photon_number(Power, k_ex, k_in, omega_r, omega_p)
# Out:
# 3.3884415613920344e-14

# %%
P =  (10**((-50)/10) *1e-3  /6.626e-34 )*1e-9#GHz/s
P
# Out:
# 1.509206157561123e+16

# %%
kai = (0.13e9)*2*np.pi/2
delta = (10.2503210-8.02-0.00233)*1e9*2*np.pi
g = (kai*delta)**0.5
g
# Out:
# 2391075352.76259

# %%
delta**2/(4*g**2)
# Out:
# 8.569196153846155

# %%
k_ex
# Out:
# 1198751520.3334923

# %%
Power, omega_p, omega_r, k_ex, k_in
# Out:
# (3.3884415613920344e-14,
#  64697959108.0282,
#  64404666301.07436,
#  1198751520.3334923,
#  0)

# %%
1/(10.209-10.066)
# Out:
# 6.993006993007047

# %% [markdown]
# # frequency optimization

# %%
header = "D:/K_sunada/result/CDY153/"
data = "/2023-12-27/2023-12-27T120627_ed335f3d-26_freq_optimize"
dd = datadict_from_hdf5(header + data +"/data")
ed = 1e-9/9/(10.25-10)

freq = dd['frequency']['values']
s11_eg = dd['s11_eg']['values']* np.exp(1j*(ed*2*np.pi*freq))
s11_g = dd['s11_g']['values']* np.exp(1j*(ed*2*np.pi*freq))
s11_e = dd['s11_e']['values']* np.exp(1j*(ed*2*np.pi*freq))

# %% [markdown]
# eg-peak

# %%
plt.plot(freq, np.angle(s11_g))
plt.show()

# %%
def Lorentzian(freq, amp, const, center, k):
    return const - amp*k**2/((freq-center)**2 + k**2)

# %%
import sklearn
from sklearn.decomposition import PCA

# %%
def PCA_transform(Re_c, Im_c):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c]).T, np.array([Im_c]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    return c_PCA1, c_PCA2

# %%
I = s11_eg.real
Q = s11_eg.imag
plt.plot(freq, I)
PCAge = PCA_transform(I, Q)

# %%
y = PCAge[0]
x = freq

plt.plot(x, Q)
plt.title("data after PCA")
plt.show()

# %%
par_ini = {
    'amp': 23,
    'const':2.5,
    'center':10.3e9,
    'k':0.008e9
}

par_min = {
    'amp': 0,
    'const':0,
    'center':0,
    'k':0
}

par_max = {
    'amp': np.inf,
    'const':np.inf,
    'center':np.inf,
    'k':np.inf
}

par_vary = {
    'amp': True,
    'const':True,
    'center':True,
    'k':True
}

# %%
model = lmfit.Model(Lorentzian)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )

# %%
result = model.fit(data = -Q, params = params, freq = x)
result
# Out:
# <h2> Model</h2> Model(Lorentzian) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>5081</td><td></td></tr><tr><td># data points</td><td>201</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 1735.90936</td><td></td></tr><tr><td>reduced chi-square</td><td> 8.81172265</td><td></td></tr><tr><td>Akaike info crit.</td><td> 441.352337</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 454.565556</td><td></td></tr><tr><td>R-squared</td><td> 0.05047167</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  25926.5610 </td><td> 23 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  1.5363e-12 </td><td> 2.5 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> center </td><td>  1.0277e+10 </td><td> 10300000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> k </td><td>  29879.0905 </td><td> 8000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table>

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("g-e transition")


plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result.plot_fit(ax = ax)

plt.xlabel("frequency (Hz)")
plt.ylabel("mag[S11](a.u.)")


plt.show()

# %% [markdown]
# omega_g, _e fitting

# %%
par_ini = {'fr': 10.23e9,  'ff': 10.17e9,    'kf_e': 200e6,   'kf_i': 0,  'g': 103e6, 'gamma': 0,
           'a0': 50,  'a1': 0,        'Poff': 1.5,   'ed': -0.5e-9}
par_min = {'fr': 0,     'ff': 0,        'kf_e': 0,        'kf_i': 0,        'g': 0,     'gamma': 0,
           'a0': 0,     'a1': -np.inf,  'Poff': -np.inf,'ed': -np.inf}
par_max = {'fr': np.inf,'ff': np.inf,   'kf_e': np.inf,   'kf_i': np.inf,   'g': np.inf,'gamma': np.inf,
           'a0': np.inf,'a1': np.inf,   'Poff': np.inf, 'ed': np.inf}
par_var = {'fr': True, 'ff': True,    'kf_e': True,    'kf_i':False,    'g': True, 'gamma': False,
           'a0': True, 'a1': False,    'Poff': True,  'ed': True}

model=lmfit.Model(S11_dpr_model)
params = model.make_params()

for name in list(par_ini):
    params[name].set(value=par_ini[name])
for name in list(par_min):
    params[name].set(min=par_min[name])  
for name in list(par_max):
    params[name].set(max=par_max[name]) 
for name in list(par_var):
    params[name].set(vary=par_var[name])

# %%
res = model.fit(data = s11_g, params = params, freq = x)

fig, ax = plt.subplots(1, 2, figsize=(16,6))#,constrained_layout=True)
plt.rcParams["font.size"] = 20
plt.subplots_adjust(wspace=0.3)
ax[0].set_xlabel('Re[S$_{11}$] (arb. u.) ')
ax[0].set_ylabel('Im[S$_{11}$] (arb. u.) ')
ax[0].tick_params(axis="x", direction="in")
ax[0].tick_params(axis="y", direction="in")

ax[1].set_xlabel('Probe frequency $\omega_\mathrm{p}$ (GHz)')
ax[1].set_ylabel('Phase[S$_{11}$] (rad) ')
ax[1].tick_params(axis="x", direction="in")
ax[1].tick_params(axis="y", direction="in")

ax[0].plot(np.real(s11_g),np.imag(s11_g) , ls='', marker='o')
# ax[0].plot(x, np.real(res.init_fit), '--', label='initial fit', color='orange')
ax[0].plot(np.real(res.best_fit), np.imag(res.best_fit))
ax[1].plot(x*1e-9, np.angle(s11_g),  ls='', marker='o')
# ax[1].plot(x, np.angle(res.init_fit), '--', label='initial fit', color='orange')
ax[1].plot(x*1e-9, np.angle(res.best_fit))
# plt.savefig('chi_g.png', bbox_inches='tight')
plt.show()
res
# Out:
# <h2> Model</h2> Model(S11_dpr_model) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>68</td><td></td></tr><tr><td># data points</td><td>402</td><td></td></tr><tr><td># variables</td><td>7</td><td></td></tr><tr><td>chi-square</td><td> 76834.8660</td><td></td></tr><tr><td>reduced chi-square</td><td> 194.518648</td><td></td></tr><tr><td>Akaike info crit.</td><td> 2125.69061</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 2153.66577</td><td></td></tr><tr><td>R-squared</td><td>-7.6835e+19</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> fr </td><td>  1.0267e+10 </td><td>  2178489.83 </td><td> (0.02%) </td><td> 10270000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> ff </td><td>  1.0192e+10 </td><td>  5070592.90 </td><td> (0.05%) </td><td> 10192000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> kf_e </td><td>  2.4943e+08 </td><td>  11033120.2 </td><td> (4.42%) </td><td> 200000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> kf_i </td><td>  0.00000000 </td><td>  0.00000000 </td><td>  </td><td> 0 </td><td>  0.00000000 </td><td>         inf </td><td> False </td></tr><tr><td> gamma </td><td>  0.00000000 </td><td>  0.00000000 </td><td>  </td><td> 0 </td><td>  0.00000000 </td><td>         inf </td><td> False </td></tr><tr><td> g </td><td>  89363879.9 </td><td>  1864317.20 </td><td> (2.09%) </td><td> 103000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> a0 </td><td>  46.5207880 </td><td>  0.98374563 </td><td> (2.11%) </td><td> 50 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> a1 </td><td>  0.00000000 </td><td>  0.00000000 </td><td>  </td><td> 0 </td><td>        -inf </td><td>         inf </td><td> False </td></tr><tr><td> Poff </td><td>  3.55776918 </td><td>  0.07341602 </td><td> (2.06%) </td><td> 3.55 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> ed </td><td> -6.2357e-10 </td><td>  1.8969e-11 </td><td> (3.04%) </td><td> -6.0612e-10 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>Poff</td><td>ed</td><td>+0.8975</td></tr><tr><td>kf_e</td><td>ed</td><td>-0.7420</td></tr><tr><td>kf_e</td><td>Poff</td><td>-0.6090</td></tr><tr><td>ff</td><td>Poff</td><td>+0.5549</td></tr><tr><td>fr</td><td>g</td><td>-0.5174</td></tr><tr><td>g</td><td>ed</td><td>-0.3467</td></tr><tr><td>g</td><td>Poff</td><td>-0.3407</td></tr><tr><td>ff</td><td>ed</td><td>+0.3216</td></tr><tr><td>fr</td><td>ff</td><td>-0.3015</td></tr><tr><td>kf_e</td><td>g</td><td>+0.2485</td></tr><tr><td>ff</td><td>kf_e</td><td>-0.1723</td></tr><tr><td>fr</td><td>Poff</td><td>+0.1469</td></tr></table>

# %%
par_ini = {'fr': 10.27e9,  'ff': 10.192e9,    'kf_e': 200e6,   'kf_i': 0,  'g': 103e6, 'gamma': 0,
           'a0': 50,  'a1': 0,        'Poff': 3.55,   'ed': -6.0612e-10}
par_min = {'fr': 0,     'ff': 0,        'kf_e': 0,        'kf_i': 0,        'g': 0,     'gamma': 0,
           'a0': 0,     'a1': -np.inf,  'Poff': -np.inf,'ed': -np.inf}
par_max = {'fr': np.inf,'ff': np.inf,   'kf_e': np.inf,   'kf_i': np.inf,   'g': np.inf,'gamma': np.inf,
           'a0': np.inf,'a1': np.inf,   'Poff': np.inf, 'ed': np.inf}
par_var = {'fr': True, 'ff': True,    'kf_e': True,    'kf_i': False,    'g': True, 'gamma': False,
           'a0': True, 'a1': False,    'Poff': True,  'ed': True}

model=lmfit.Model(S11_dpr_model)
params = model.make_params()

for name in list(par_ini):
    params[name].set(value=par_ini[name])
for name in list(par_min):
    params[name].set(min=par_min[name])  
for name in list(par_max):
    params[name].set(max=par_max[name]) 
for name in list(par_var):
    params[name].set(vary=par_var[name])

# %%
res = model.fit(data = s11_e, params = params, freq = x, method='nelder')

fig, ax = plt.subplots(1, 2, figsize=(16,6))#,constrained_layout=True)
plt.rcParams["font.size"] = 20
plt.subplots_adjust(wspace=0.3)
ax[0].set_xlabel('Re[S$_{11}$] (arb. u.) ')
ax[0].set_ylabel('Im[S$_{11}$] (arb. u.) ')
ax[0].tick_params(axis="x", direction="in")
ax[0].tick_params(axis="y", direction="in")

ax[1].set_xlabel('Probe frequency $\omega_\mathrm{p}$ (GHz)')
ax[1].set_ylabel('Phase[S$_{11}$] (rad) ')
ax[1].tick_params(axis="x", direction="in")
ax[1].tick_params(axis="y", direction="in")

ax[0].plot(np.real(s11_e), np.imag(s11_e),  ls='', marker='o')
# ax[0].plot(x, np.real(s11_e),'.', color='k')
# ax[0].plot(np.real(res.init_fit), np.imag(res.init_fit),'--', label='initial fit', color='orange')
# ax[0].plot(np.real(res.best_fit),np.imag(res.best_fit), '-', label='best fit', color='red')
ax[0].plot(np.real(res.best_fit), np.imag(res.best_fit))
ax[1].plot(x*1e-9, np.angle(s11_e),  ls='', marker='o')
# ax[1].plot(x, np.angle(res.init_fit), '--', label='initial fit', color='orange')
ax[1].plot(x*1e-9, np.angle(res.best_fit))
# plt.savefig('chi_e.png', bbox_inches='tight')
plt.show()
res
# Out:
# <h2> Model</h2> Model(S11_dpr_model) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>Nelder-Mead</td><td></td></tr><tr><td># function evals</td><td>1097</td><td></td></tr><tr><td># data points</td><td>402</td><td></td></tr><tr><td># variables</td><td>7</td><td></td></tr><tr><td>chi-square</td><td> 77259.5221</td><td></td></tr><tr><td>reduced chi-square</td><td> 195.593727</td><td></td></tr><tr><td>Akaike info crit.</td><td> 2127.90629</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 2155.88146</td><td></td></tr><tr><td>R-squared</td><td>-7.7260e+19</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> fr </td><td>  1.0263e+10 </td><td> 10270000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> ff </td><td>  1.0192e+10 </td><td> 10192000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> kf_e </td><td>  2.5390e+08 </td><td> 200000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> kf_i </td><td>  0.00000000 </td><td> 0 </td><td>  0.00000000 </td><td>         inf </td><td> False </td></tr><tr><td> gamma </td><td>  0.00000000 </td><td> 0 </td><td>  0.00000000 </td><td>         inf </td><td> False </td></tr><tr><td> g </td><td>  89099628.8 </td><td> 103000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> a0 </td><td>  46.4870960 </td><td> 50 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> a1 </td><td>  0.00000000 </td><td> 0 </td><td>        -inf </td><td>         inf </td><td> False </td></tr><tr><td> Poff </td><td>  3.54042988 </td><td> 3.55 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> ed </td><td> -6.3355e-10 </td><td> -6.0612e-10 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table>

# %%
f_hg = 10.267e9
f_lg = 10.192e9
f_he = 10.263e9
f_le = 10.192e9

# chi_l = (f_le - f_lg)/2
chi_h = (f_he - f_hg)/2
chi = chi_h
chi
# Out:
# -2000000.0

# %% [markdown]
# ge: 8.0155e+09 Hz
#
# ef: 7.6853e+09 Hz

# %%
from plottr.data.datadict_storage import datadict_from_hdf5
import numpy as np
import matplotlib.pyplot as plt
import lmfit

# %%
import sklearn
from sklearn.decomposition import PCA

# %%
def Lorentzian(freq, amp, const, center, k):
    return const - amp*k**2/((freq-center)**2 + k**2)

# %%
header = "D:/K_sunada/result/CDY153/"
# twotone(redout: 10.26GHz)
three_peak = "/2023-12-25/2023-12-25T141525_9c8938d0-cw_twotone" #drive: R.T.-40dB, lo power: -20-24dB, readout: R.T.: -30 dB, vna power: -10dB
ge_peak = "/2023-12-25/2023-12-25T143323_1eecd489-cw_twotone" #<ge>drive: R.T.-60dB, lo power: -20-10dB, readout: R.T.: -30 dB, vna power: -10dB
ef_peak = "/2023-12-25/2023-12-25T142915_8aec733f-cw_twotone" #<ef>drive: R.T.-40dB, lo power: 0-24dB, readout: R.T.: -30 dB, vna power: -10dB

# %% [markdown]
# three peaks

# %%
ddtwotone = datadict_from_hdf5(header + three_peak +"/data")
x = np.unique(ddtwotone['power']['values'])
y = np.unique(ddtwotone['frequency']['values'])
z = np.angle(ddtwotone['s11']['values'])

# %%
cm = plt.cm.get_cmap('magma')
fig= plt.figure()
plt.rcParams["font.size"] = 20
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'

ax = fig.add_axes((0.1, 0.1, 0.9, 0.9))
ax.set_ylabel("Drive power $P_{\mathrm{d}}$ (dBm)")
ax.set_xlabel("Drive frequency $\omega_\mathrm{d}$ (GHz)")
# ax.set_xlim(-10, 20)
# ax.set_ylim(10, 10.6)

maingraph = ax.pcolormesh(y*1e-9,x, z.reshape(22, 601), vmin=min(np.unique(z)), vmax=max(np.unique(z)), cmap=cm, shading='auto')
plt.colorbar(maingraph, label="Phase[S$_{11}$] (arg)")
plt.tick_params(top='on',bottom='on',left='on',right='on')
# plt.savefig('three_peaks.png', bbox_inches='tight')
plt.show()
# Out:
# C:\Users\qipe\AppData\Local\Temp\ipykernel_16080\2066972944.py:1: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cm = plt.cm.get_cmap('magma')

# %% [markdown]
# ge, ef peak

# %%
ddge = datadict_from_hdf5(header + ge_peak +"/data")
ddef = datadict_from_hdf5(header + ef_peak +"/data")

# %%
def PCA_transform(Re_c, Im_c):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c]).T, np.array([Im_c]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    return c_PCA1, c_PCA2

# %% [markdown]
# ## ge遷移
# 初期値設定

# %%
S11ge = ddge['s11']['values']
ge_phase = np.angle(S11ge)
freqge = ddge['frequency']['values']

y = ge_phase[0]
x = freqge[0]
plt.plot(x, y)
plt.show()

# %%
I = (S11ge.real)[12]
Q = (S11ge.imag)[12]
#c_data = np.concatenate([np.array([I]).T, np.array([Q]).T], axis = 1)

# %%
PCAge = PCA_transform(I, Q)
y = PCAge[0]*1e4
x = freqge[0]*1e-9

plt.plot(x, -y)
plt.title("data after PCA")
plt.show()

# %%
par_ini = {
    'amp': 15e-1,
    'const':0,
    'center':8.018,
    'k':0.008
}

par_min = {
    'amp': 0,
    'const':0,
    'center':0,
    'k':0
}

par_max = {
    'amp': np.inf,
    'const':np.inf,
    'center':np.inf,
    'k':np.inf
}

par_vary = {
    'amp': True,
    'const':True,
    'center':True,
    'k':True
}

# %% [markdown]
# fitting

# %%
model = lmfit.Model(Lorentzian)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )

# %%
result = model.fit(data = -y, params = params, freq = x)

# %%
result
# Out:
# <h2> Model</h2> Model(Lorentzian) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>128</td><td></td></tr><tr><td># data points</td><td>181</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 9.73876347</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.05502126</td><td></td></tr><tr><td>Akaike info crit.</td><td>-520.951300</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-508.157312</td><td></td></tr><tr><td>R-squared</td><td> 0.86432781</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  3.03851635 </td><td>  0.11701886 </td><td> (3.85%) </td><td> 1.5 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  0.25992881 </td><td>  0.02091020 </td><td> (8.04%) </td><td> 0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> center </td><td>  8.00876167 </td><td>  1.6431e-04 </td><td> (0.00%) </td><td> 8.018 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> k </td><td>  0.00426819 </td><td>  2.5481e-04 </td><td> (5.97%) </td><td> 0.008 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>amp</td><td>k</td><td>-0.6341</td></tr><tr><td>const</td><td>k</td><td>+0.4095</td></tr></table>

# %%
fig, ax = plt.subplots(figsize=(8,6),constrained_layout=True)
plt.rcParams["font.size"] = 20

plt.tick_params(top='on',bottom='on',left='on',right='on',)

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result.plot_fit(ax = ax)
plt.xlim(7.95, 8.065)

plt.title("")
plt.legend("")
plt.xlabel("Drive frequency $\omega_\mathrm{d}$ (GHz)")
plt.ylabel("$S_{11}$ (arb. u.)")
# plt.savefig('ge_peak.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## ef
# 初期値

# %%
S11ef = ddef['s11']['values']
magef = np.angle(S11ef)
freqef = ddef['frequency']['values']

x = freqef[14]
y = magef[14]


plt.plot(x, y)
plt.show()

# %%
I = (S11ef.real)[14]
Q = (S11ef.imag)[14]
#c_data = np.concatenate([np.array([I]).T, np.array([Q]).T], axis = 1)

# %%
def PCA_transform(Re_c, Im_c):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c]).T, np.array([Im_c]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    return c_PCA1, c_PCA2

# %%
PCAef = PCA_transform(I, Q)

# %%
y = PCAef[0]
x = freqef[0]

plt.plot(x, -y)
plt.show()

# %%
par_ini = {
    'amp': 3,
    'const':0.5,
    'center':7.685,
    'k':0.001
}

par_min = {
    'amp': 0,
    'const':0,
    'center':0,
    'k':0
}

par_max = {
    'amp': np.inf,
    'const':np.inf,
    'center':np.inf,
    'k':np.inf
}

par_vary = {
    'amp': True,
    'const':True,
    'center':True,
    'k':True
}

# %%
model = lmfit.Model(Lorentzian)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )

# %%
result1 = model.fit(data = -y*1e4, params = params, freq = x*1e-9)

# %%
result1
# Out:
# <h2> Model</h2> Model(Lorentzian) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>36</td><td></td></tr><tr><td># data points</td><td>181</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 9.73876492</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.05502127</td><td></td></tr><tr><td>Akaike info crit.</td><td>-520.951273</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-508.157285</td><td></td></tr><tr><td>R-squared</td><td> 0.86432779</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  3.03857055 </td><td>  0.11704374 </td><td> (3.85%) </td><td> 3 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  0.25992259 </td><td>  0.02091016 </td><td> (8.04%) </td><td> 0.5 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> center </td><td>  7.68525669 </td><td>  9.8615e-05 </td><td> (0.00%) </td><td> 7.685 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> k </td><td>  0.00256080 </td><td>  1.5290e-04 </td><td> (5.97%) </td><td> 0.001 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>amp</td><td>k</td><td>-0.6342</td></tr><tr><td>const</td><td>k</td><td>+0.4095</td></tr></table>

# %%
fig, ax = plt.subplots(dpi=80)
plt.title("g-f transition")


plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result1.plot_fit(ax = ax)

plt.xlabel("frequency (Hz)")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,6),constrained_layout=True)
plt.rcParams["font.size"] = 20

plt.tick_params(top='on',bottom='on',left='on',right='on',)

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result1.plot_fit(ax = ax)
# plt.plot(x*1e-9, result1.init_fit)
plt.xlim(7.65, 7.72)

plt.title("")
plt.legend("")
plt.xlabel("Drive frequency $\omega_\mathrm{d}$ (GHz)")
plt.ylabel("$S_{11}$ (arb. u.)")
# plt.savefig('ef_peak.png', bbox_inches='tight')
plt.show()

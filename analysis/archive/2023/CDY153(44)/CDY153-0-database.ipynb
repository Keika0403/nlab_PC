# %% [markdown]
# ## cw

# %%
# resonator S11
res_dressed = "/2023-12-25/2023-12-25T141923_2a876859-cw_sparameter" # R.T.: -30dB, vna output: -10dB
res_bare = "/2023-12-25/2023-12-25T131522_38c68282-cw_sparameter" # R.T.: -30dB, vna output: 20dB
punchout = "/2023-12-25/2023-12-25T131044_9334f0c3-cw_punchout" # R.T.: -30dB, vna output: -20 ~ 20dB

# twotone(redout: 10.26GHz)
three_peak = "/2023-12-25/2023-12-25T141525_9c8938d0-cw_twotone" #drive: R.T.-40dB, lo power: -20~24dB, readout: R.T.: -30 dB, vna power: -10dB
ge_peak = "/2023-12-25/2023-12-25T143323_1eecd489-cw_twotone" #<ge>drive: R.T.-60dB, lo power: -20~10dB, readout: R.T.: -30 dB, vna power: -10dB
ef_peak = "/2023-12-25/2023-12-25T142915_8aec733f-cw_twotone" #<ef>drive: R.T.-40dB, lo power: 0~24dB, readout: R.T.: -30 dB, vna power: -10dB

# ac Stark shift
     #drive: R.T.-60dB, lo power: -10dB, readout: R.T.: -30 dB, vna power: -10~-5dB
ac1033 = "/2023-12-29/2023-12-29T172638_fcb4636c-cw_attenuation"
ac1031 = "/2023-12-25/2023-12-25T162657_fc4e3f61-cw_attenuation"
ac1030 = "/2023-12-25/2023-12-25T153516_c43cbc37-cw_attenuation" 
ac1029 = "/2023-12-29/2023-12-29T171620_8c5c01d3-cw_attenuation"
ac1028 = "/2023-12-25/2023-12-25T155119_01ffdcb4-cw_attenuation"
ac1026 = "/2023-12-25/2023-12-25T160037_4ee6adc4-cw_attenuation"
ac1022 = "/2023-12-25/2023-12-25T144800_29c21d05-cw_attenuation"

# JPA
current = "/2023-12-25/2023-12-25T173939_242db88a-cw_JPA_current_vs_freq" #LO 10.35
currnt0 = "/2023-12-27/2023-12-27T153455_0c6a30fa-cw_JPA_current_vs_freq" #LO 10.38
current1 = "/2023-12-27/2023-12-27T141626_156ab6b2-cw_JPA_current_vs_freq" # wide range
pump ="/2023-12-27/2023-12-27T162851_9570e0e8-cw_JPA_gain_amp" #pump 0.4~0.5 v
pump = "/2023-12-27/2023-12-27T165854_c7bb706a-cw_JPA_gain_amp" #pump 0.2~0.4 v
#  "RFout1C - 10dB -ZVA213s+ -ZVA213s+ - 1000mm -  In3H",

# %% [markdown]
# ## td

# %% [markdown]
# qubit calibration

# %%
# ge
ge_pi = "/2023-12-26/2023-12-26T142821_953642e3-21_ge_pi_amp"
ge_ramsey = "/2023-12-26/2023-12-26T143119_ff9aa32c-23_ge_T2r1d" #+0.5MHz detuning
ge_drag0 = "/2023-12-26/2023-12-26T153905_76c5d905-22_ge_pi_drag" #n=5
ge_drag1 = "/2023-12-26/2023-12-26T154044_b1ce554b-22_ge_pi_drag" #n=7
ge_drag2 = "/2023-12-26/2023-12-26T154224_ed559ee3-22_ge_pi_drag" #n=11
half_ge_drag0 = "/2023-12-26/2023-12-26T155045_17e8926a-22_ge_pi_drag" #n=11
half_ge_drag1 = "/2023-12-26/2023-12-26T155409_91a6e143-22_ge_pi_drag" #n=17
half_ge_drag2 = "/2023-12-26/2023-12-26T155550_cdfd7065-22_ge_pi_drag" #n=23
ge_T1 = "/2023-12-26/2023-12-26T160052_81ed8a85-24_ge_T1"
ge_T2_ramsey = "/2023-12-26/2023-12-26T160517_202251da-23_ge_T2r1d" #+0.1MHz detuning
ge_T2_echo = "/2023-12-26/2023-12-26T161141_04e3b19f-25_ge_T2e"

# ef
ef_pi = "/2023-12-26/2023-12-26T165105_85b0d96d-30_ef_pi_amp"
ef_ramsey = "/2023-12-26/2023-12-26T165310_d0758254-32_ef_T2r1d"#+0.5MHz detuning
ef_drag0 = "/2023-12-26/2023-12-26T171035_3f40577e-31_ef_pi_drag" #n=5
ef_drag1 = "/2023-12-26/2023-12-26T171142_66e2e99c-31_ef_pi_drag" #n=11
ef_drag2 = "/2023-12-26/2023-12-26T171306_98f9e9d8-31_ef_pi_drag" #n=17
half_ef_drag0 = "/2023-12-26/2023-12-26T172744_a4da97a7-31_ef_pi_drag" #n=11
half_ef_drag1 =  "/2023-12-26/2023-12-26T172620_7287a78b-31_ef_pi_drag" #n=17
half_ef_drag2 = "/2023-12-26/2023-12-26T172454_3f67e725-31_ef_pi_drag" #n=23
ef_T1 = "/2023-12-26/2023-12-26T173313_6870724b-33_ef_T1"

# freq optimize
chi = "/2023-12-27/2023-12-27T120627_ed335f3d-26_freq_optimize"

# %%
# JPA
vac_squeeze = "/2023-12-28/2023-12-28T170549_e984b5f8-80_JPA_vac_squeeze"
ge_phase_opt = "/2023-12-28/2023-12-28T171706_7d584589-81_JPA_phase_optimization_for_ge"

# %% [markdown]
# photon generation

# %%
# ac Stark shift
ac = "/2023-12-27/2023-12-27T112604_49021806-42_fogi_ac_Stark_shift"

# square photon generation
ph = "/2023-12-27/2023-12-27T171445_fe986df6-70_JPA_photon_generation"

# %% [markdown]
# photon absorption

# %%
square = "/2023-12-29/2023-12-29T003655_ee2a511e-74_JPA_ab_tr_waveform_qstate"

# %% [markdown]
# photon absorption on on-reso 12/14

# %%
#square
data_square="/2023-12-13/2023-12-13T223637_a391a785-731_JPA_ab_sq_waveform_qstate copy"
#time-reversed
data_tr="/2023-12-13/2023-12-13T191710_c71728ec-74_JPA_ab_tr_waveform_qstate"
#time-unreersed
data_utr="/2023-12-14/2023-12-14T093557_bf6254b4-74_JPA_ab_tr_waveform_qstate"

# %% [markdown]
# ## 1/4-

# %%
# ac Stark shift
ac = "/2024-01-04/2024-01-04T145816_40dd2156-42_fogi_ac_Stark_shift"
pi_fogi = "/2024-01-04/2024-01-04T153255_18350386-41_fogi_duration_sweep"
ph = "/2024-01-04/2024-01-04T161954_a8691b2e-70_JPA_photon_generation"
ph06 = "/2024-01-05/2024-01-05T091433_66fecb2f-70_JPA_photon_generation"

# active reset
ef_freq = "/2024-01-04/2024-01-04T194532_623b62a0-72_active_reset_ef_freq"
ef_amp = "/2024-01-04/2024-01-04T195255_6a5c4b5f-73_active_reset_ef_amp"

# %%
# photon absorption
# square = "/2024-01-04/2024-01-04T221316_05839672-74_JPA_ab_tr_waveform_qstate"
# time-reverse = "/2024-01-05/2024-01-05T101531_ebad52db-74_JPA_ab_tr_waveform_qstate"
# time-reverse1 = "/2024-01-05/2024-01-05T115902_61325f8f-74_JPA_ab_tr_waveform_qstate"
# generated-shape = "/2024-01-05/2024-01-05T125508_379d6d27-74_JPA_ab_tr_waveform_qstate"

# %%
# photon absorption - 500ns
square = "/2024-01-05/2024-01-05T213121_554572a4-74_JPA_ab_waveform_qstate"
time-reverse = "/2024-01-05/2024-01-05T202436_023b7a9f-74_JPA_ab_waveform_qstate"
generated-shape = "/2024-01-05/2024-01-05T224611_c99b426d-74_JPA_ab_waveform_qstate"

# %%
# JPA
vac_squeeze =  "/2024-01-04/2024-01-04T181314_7dab30b4-80_JPA_vac_squeeze"
ge_phase_opt = "/2024-01-04/2024-01-04T181740_1c41d195-81_JPA_phase_optimization_for_ge" # 0dB
ge_phase_opt1 = "/2024-01-05/2024-01-05T173118_cc8b219a-81_JPA_phase_optimization_for_ge" #10dB

readout_fidelity_thre ="/2024-01-04/2024-01-04T183951_3558e596-82_readout_fidelity_threshold"
readout_fidelity = "/2024-01-04/2024-01-04T184101_5f5d8f4b-83_readout_fidelity"

readout_fidelity_thre1 ="/2024-01-04/2024-01-04T184625_206936bd-82_readout_fidelity_threshold"
readout_fidelity1 = "/2024-01-04/2024-01-04T184802_5a3c360f-83_readout_fidelity"

readout_fidelity_thre2 ="/2024-01-04/2024-01-04T200911_afe8b102-82_readout_fidelity_threshold"
readout_fidelity2 = "/2024-01-04/2024-01-04T201103_f31c850f-83_readout_fidelity"

readout_fidelity_thre3 ="/2024-01-05/2024-01-05T173332_1c672042-82_readout_fidelity_threshold"
readout_fidelity3 = "/2024-01-05/2024-01-05T173436_427225ac-83_readout_fidelity"
QND_fidelity3 = "/2024-01-05/2024-01-05T161443_19507e86-84_QND_fidelity"

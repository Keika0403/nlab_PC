# %% [markdown]
# ## 12/? ge calibration - DPR1-L-120-44

# %% [markdown]
# ge_freq = 8.03+0.005106 GHz
#
# ge_pi_amp = 0.900
#
#
# T1 = 30.55e-06
#
# T2 = 11.32e-06
#
# T2_star = 6.29e-06

# %%
from plottr.data.datadict_storage import datadict_from_hdf5
import numpy as np
import matplotlib.pyplot as plt
import lmfit

# %%
import sklearn
from sklearn.decomposition import PCA

# %%
def Rabi(delay, amp, phi0, detun, const):
    return - amp * np.cos(2*np.pi*detun*delay+phi0) + const

# %%
def PCA_transform(Re_c, Im_c):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c]).T, np.array([Im_c]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    return c_PCA1, c_PCA2

# %%
header = "D:/K_Sunada/result/CDY153/"

# %%
amp = "/2023-12-26/2023-12-26T142821_953642e3-21_ge_pi_amp"
dd_amp = datadict_from_hdf5(header + amp +"/data")

# %%
Rabi_amp = dd_amp['s11']['values']
imag_amp = Rabi_amp.imag
amp = dd_amp['amplitude']['values']

# %%
def PCA_transform(Re_c, Im_c):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c]).T, np.array([Im_c]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    return c_PCA1, c_PCA2, pca

# %%
I_amp = (Rabi_amp.real)
Q_amp = (Rabi_amp.imag)
PCA_amp = PCA_transform(I_amp, Q_amp)

# %%
PCA_amp = PCA_transform(I_amp, Q_amp)
y = I_amp
x = amp

fig, (ax1) = plt.subplots(nrows=1)
ax1.set_xlabel('Amplitude (V)', size='large')
ax1.set_ylabel('PCA[$S_{11}$] (V)', size='large')
plt.rcParams["font.size"] = 17
plt.plot(x, PCA_amp[0])
ax1.tick_params(axis="x", direction="in")
ax1.tick_params(axis="y", direction="in")
# ax1.set_xlim(0, 1)
# ax1.set_ylim(-48, 160)
plt.tick_params(
            top='on',
            bottom='on`',
            left='on',
            right='on',
            )
plt.show()

# %%
par_ini= {
    'amp': 7,
    'phi0':np.pi,
    'detun':1/0.38,
    'const':0
}

par_min = {
    'amp': 0,
    'phi0':-2*np.pi,
    'detun':-np.inf,
    'const':-np.inf
}

par_max = {
    'amp': np.inf,
    'phi0':2*np.pi,
    'detun':np.inf,
    'const':np.inf,
}

par_vary = {
    'amp': True,
    'phi0':True,
    'detun':True,
    'const':True
}

# %%
model = lmfit.Model(Rabi)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )
    
result = model.fit(data = PCA_amp[0], params = params, delay = x)
result
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>21</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 65.7479328</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.67781374</td><td></td></tr><tr><td>Akaike info crit.</td><td>-35.3585210</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-24.8980389</td><td></td></tr><tr><td>R-squared</td><td> 0.97482887</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  7.13322528 </td><td>  0.11663304 </td><td> (1.64%) </td><td> 7 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  3.19398541 </td><td>  0.03296882 </td><td> (1.03%) </td><td> 3.141592653589793 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  2.74144832 </td><td>  0.00896022 </td><td> (0.33%) </td><td> 2.6315789473684212 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  0.39520683 </td><td>  0.08365417 </td><td> (21.17%) </td><td> 0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>-0.8693</td></tr><tr><td>phi0</td><td>const</td><td>+0.1866</td></tr><tr><td>detun</td><td>const</td><td>-0.1702</td></tr></table>

# %%
fig, ax = plt.subplots(figsize=(8,6),constrained_layout=True)
plt.rcParams["font.size"] = 20
# plt.title("Rabi(amp)")
plt.tick_params(top='on',bottom='on',left='on',right='on',)
plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result.plot_fit(ax = ax)
# plt.plot(x,result.init_fit)

plt.title("")
plt.legend("")
ax.set_xlabel('$\pi_{ge}$ pulse DAC amplitude (V)', size='large')
ax.set_ylabel('S$_{11}$ (arb. u.)', size='large')
# plt.savefig('ge_rabi.png', bbox_inches='tight')
plt.show()

# %%
np.pi/(2.74144832*2*np.pi)*5
# Out:
# 0.9119267292990589

# %% [markdown]
# ramsey

# %%
pl = "/2023-12-26/2023-12-26T143119_ff9aa32c-23_ge_T2r1d"
mi = "/2023-12-26/2023-12-26T142619_4c6f80a6-23_ge_T2r1d"
dd_pl = datadict_from_hdf5(header + pl +"/data")
dd_mi = datadict_from_hdf5(header + mi +"/data")

# %%
Rabi_pl = dd_pl['s11']['values']
imag_pl = Rabi_pl.imag
delay_pl = dd_pl['delay']['values']

Rabi_mi = dd_mi['s11']['values']
imag_mi = Rabi_mi.imag
delay_mi = dd_mi['delay']['values']

# %%
I_pl = (Rabi_pl.real)
Q_pl = (Rabi_pl.imag)
I_mi = (Rabi_mi.real)
Q_mi = (Rabi_mi.imag)


PCA_pl = PCA_transform(I_pl, Q_pl)
y_pl = PCA_pl[0]
x_pl = delay_pl

PCA_mi = PCA_transform(I_mi, Q_mi)
y_mi = PCA_mi[0]
x_mi = delay_mi



plt.plot(x_pl, y_pl)
plt.show()

# %%
par_ini_pl = {
    'amp': 7.5,
    'phi0':np.pi/2,
    'detun':1/200,
    'const':0.1
}

par_min_pl = {
    'amp': 0,
    'phi0':-2*np.pi,
    'detun':-np.inf,
    'const':0
}

par_max_pl = {
    'amp': np.inf,
    'phi0':2*np.pi,
    'detun':np.inf,
    'const':np.inf,
}

par_vary_pl = {
    'amp': True,
    'phi0':True,
    'detun':True,
    'const':True
}

# %%
model = lmfit.Model(Rabi)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini_pl[name],
    min = par_min_pl[name],
    max = par_max_pl[name],
    vary = par_vary_pl[name]
    )
    
result_pl = model.fit(data = y_pl, params = params, delay = x_pl)
result_pl
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>66</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 75.4690313</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.77803125</td><td></td></tr><tr><td>Akaike info crit.</td><td>-21.4312107</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-10.9707287</td><td></td></tr><tr><td>R-squared</td><td> 0.96765569</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  6.67771417 </td><td>  0.12398366 </td><td> (1.86%) </td><td> 7.5 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  1.22980111 </td><td>  0.03630189 </td><td> (2.95%) </td><td> 1.5707963267948966 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  0.00490958 </td><td>  1.0238e-05 </td><td> (0.21%) </td><td> 0.005 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  1.3492e-11 </td><td>  0.00379535 </td><td> (28131067678.21%) </td><td> 0.1 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>-0.8585</td></tr></table>

# %%
fig, ax = plt.subplots(figsize=(8,6),constrained_layout=True)

# plt.title("Rabi(+5MHz)")

# plt.plot(x_pl,result_pl.init_fit)
plt.rcParams["font.size"] = 20

plt.tick_params(top='on',bottom='on',left='on',right='on',)

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'

result_pl.plot_fit(ax = ax)
plt.title("")
plt.legend("")
plt.xlabel(r"Delay ${\tau}$ (ns)")
plt.ylabel("$S_{11}$ (arb. u.)")
# plt.savefig('ge_ramsey.png', bbox_inches='tight')

plt.show()

# %%
plt.plot(x_mi, y_mi)
plt.show()

# %%
par_ini_mi = {
    'amp': 7.5,
    'phi0':-np.pi/2,
    'detun':1/200,
    'const':0
}

par_min_mi = {
    'amp': 0,
    'phi0':-2*np.pi,
    'detun':-np.inf,
    'const':0
}

par_max_mi = {
    'amp': np.inf,
    'phi0':2*np.pi,
    'detun':np.inf,
    'const':np.inf,
}

par_vary_mi = {
    'amp': True,
    'phi0':True,
    'detun':True,
    'const':True
}

# %%
model = lmfit.Model(Rabi)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini_mi[name],
    min = par_min_mi[name],
    max = par_max_mi[name],
    vary = par_vary_mi[name]
    )
    
result_mi = model.fit(data = y_mi, params = params, delay = x_mi)
result_mi
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>73</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 60.5681219</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.62441363</td><td></td></tr><tr><td>Akaike info crit.</td><td>-43.6465321</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-33.1860500</td><td></td></tr><tr><td>R-squared</td><td> 0.97638317</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  7.05622388 </td><td>  0.11149208 </td><td> (1.58%) </td><td> 7.5 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  1.17051833 </td><td>  0.03060354 </td><td> (2.61%) </td><td> -1.5707963267948966 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  0.00498332 </td><td>  8.5665e-06 </td><td> (0.17%) </td><td> 0.005 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  0.02037410 </td><td>  0.07880540 </td><td> (386.79%) </td><td> 0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>-0.8579</td></tr></table>

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(-5MHz)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result_mi.plot_fit(ax = ax)
plt.plot(x_mi,result_mi.init_fit)

plt.xlabel("delay (ns)")
plt.ylabel("mag[S11](a.u.)")


plt.show()

# %%
detun = ((0.005-0.00498678)+ (	0.00498332-0.005))/2 #GHz
detun
# Out:
# -1.7299999999997005e-06

# %% [markdown]
# drag

# %%
drag = "/2023-12-26/2023-12-26T153905_76c5d905-22_ge_pi_drag"
dd_drag = datadict_from_hdf5(header + drag +"/data")

drag1 = "/2023-12-26/2023-12-26T154044_b1ce554b-22_ge_pi_drag"
dd_drag1 = datadict_from_hdf5(header + drag1 +"/data")

drag2 = "/2023-12-26/2023-12-26T154224_ed559ee3-22_ge_pi_drag"
dd_drag2 = datadict_from_hdf5(header + drag2 +"/data")

# %%
Rabi_drag = dd_drag['s11']['values']
imag_drag = Rabi_drag.imag
drag = dd_drag['beta']['values']
I_drag = (Rabi_drag.real)
Q_drag = (Rabi_drag.imag)

Rabi_drag1 = dd_drag1['s11']['values']
imag_drag1 = Rabi_drag1.imag
drag1 = dd_drag1['beta']['values']
I_drag1 = (Rabi_drag1.real)
Q_drag1 = (Rabi_drag1.imag)

Rabi_drag2 = dd_drag2['s11']['values']
imag_drag2 = Rabi_drag2.imag
drag2 = dd_drag2['beta']['values']
I_drag2 = (Rabi_drag2.real)
Q_drag2 = (Rabi_drag2.imag)

# %%
def PCA_transform1(Re_c_amp, Im_c_amp, Re_c_drag, Im_c_drag):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c_amp]).T, np.array([Im_c_amp]).T], axis = 1)
    c1_data = np.concatenate([np.array([Re_c_drag]).T, np.array([Im_c_drag]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    
    c1_pca = pca.transform(c1_data)
    c1_PCA1 = c1_pca.T[0]
    c1_PCA2 = c1_pca.T[1]
    return c_PCA1, c_PCA2, c1_PCA1, c1_PCA2,

# %%
PCA_drag = PCA_transform1(I_amp, Q_amp, I_drag, Q_drag)
y = PCA_drag[0]
x = amp
y0 = PCA_drag[2]
x0 = drag

PCA_drag1 = PCA_transform1(I_amp, Q_amp, I_drag1, Q_drag1)
y1 = PCA_drag1[2]
x1 = drag1

PCA_drag2 = PCA_transform1(I_amp, Q_amp, I_drag2, Q_drag2)
y2 = PCA_drag2[2]
x2 = drag2


plt.plot(x, y)
plt.show()

# %%
plt.plot(x0, y0)
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.show()

# %%
par_ini= {
    'amp': 0.0001,
    'phi0':np.pi/2,
    'detun':1/1.2,
    'const':0.3389,
}

par_min = {
    'amp': 0,
    'phi0':-2*np.pi,
    'detun':-np.inf,
    'const':-np.pi
}

par_max = {
    'amp': np.inf,
    'phi0':2*np.pi,
    'detun':np.inf,
    'const':np.inf,
}

par_vary = {
    'amp': True,
    'phi0':True,
    'detun':True,
    'const':True
}

# %%
model = lmfit.Model(Rabi)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )
    
result0 = model.fit(data = y0, params = params, delay = x0)
result1 = model.fit(data = y1, params = params, delay = x1)
result2 = model.fit(data = y2, params = params, delay = x2)

# %%
result0
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>36</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 1.4987e-08</td><td></td></tr><tr><td>reduced chi-square</td><td> 1.5451e-10</td><td></td></tr><tr><td>Akaike info crit.</td><td>-2277.75003</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-2267.28955</td><td></td></tr><tr><td>R-squared</td><td> 0.97140638</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  9.1540e-05 </td><td>  1.6179e-06 </td><td> (1.77%) </td><td> 0.0001 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  4.41262473 </td><td>  0.17648258 </td><td> (4.00%) </td><td> 1.5707963267948966 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  0.68489390 </td><td>  0.01896603 </td><td> (2.77%) </td><td> 0.8333333333333334 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  0.33891490 </td><td>  1.6218e-06 </td><td> (0.00%) </td><td> 0.3389 </td><td> -3.14159265 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>-0.9883</td></tr><tr><td>detun</td><td>const</td><td>+0.2867</td></tr><tr><td>phi0</td><td>const</td><td>-0.1951</td></tr><tr><td>amp</td><td>const</td><td>-0.1489</td></tr><tr><td>amp</td><td>detun</td><td>-0.1238</td></tr><tr><td>amp</td><td>phi0</td><td>+0.1048</td></tr></table>

# %%
res0 = (4*np.pi-4.41262473)/(2*np.pi*0.68489390)
res0
# Out:
# 1.8947591184721597

# %%
result1
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>26</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 1.6655e-08</td><td></td></tr><tr><td>reduced chi-square</td><td> 1.7170e-10</td><td></td></tr><tr><td>Akaike info crit.</td><td>-2267.09555</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-2256.63507</td><td></td></tr><tr><td>R-squared</td><td> 0.96282839</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  9.5318e-05 </td><td>  2.1028e-06 </td><td> (2.21%) </td><td> 0.0001 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  1.87074265 </td><td>  0.16677038 </td><td> (8.91%) </td><td> 1.5707963267948966 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  0.86937577 </td><td>  0.01893175 </td><td> (2.18%) </td><td> 0.8333333333333334 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  0.33891556 </td><td>  2.3714e-06 </td><td> (0.00%) </td><td> 0.3389 </td><td> -3.14159265 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>-0.9933</td></tr><tr><td>detun</td><td>const</td><td>+0.8273</td></tr><tr><td>phi0</td><td>const</td><td>-0.8130</td></tr><tr><td>amp</td><td>const</td><td>-0.4253</td></tr><tr><td>amp</td><td>detun</td><td>-0.4071</td></tr><tr><td>amp</td><td>phi0</td><td>+0.3895</td></tr></table>

# %%
res1 = (4*np.pi-1.87074265)/(2*np.pi*0.86937577)
res1
# Out:
# 1.9580279537807552

# %%
result2
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>43</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 1.7796e-08</td><td></td></tr><tr><td>reduced chi-square</td><td> 1.8347e-10</td><td></td></tr><tr><td>Akaike info crit.</td><td>-2260.39859</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-2249.93811</td><td></td></tr><tr><td>R-squared</td><td> 0.95409582</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  8.7654e-05 </td><td>  1.9524e-06 </td><td> (2.23%) </td><td> 0.0001 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td> -4.48981550 </td><td>  0.11206320 </td><td> (2.50%) </td><td> 1.5707963267948966 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  1.39413099 </td><td>  0.01210256 </td><td> (0.87%) </td><td> 0.8333333333333334 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  0.33891670 </td><td>  1.4149e-06 </td><td> (0.00%) </td><td> 0.3389 </td><td> -3.14159265 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>-0.9800</td></tr><tr><td>amp</td><td>const</td><td>+0.2109</td></tr></table>

# %%
res2 = (4*np.pi-(-4.48981550))/(2*np.pi*	1.40345004)
res2
# Out:
# 1.9342165756008027

# %%
beta = (res0 + res1 + res2)/3
beta
# Out:
# 1.9290012159512393

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(drag)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result0.plot_fit(ax = ax)
plt.plot(x0,result0.init_fit)


plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(drag)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result1.plot_fit(ax = ax)
plt.plot(x1,result1.init_fit)


plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(drag)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result2.plot_fit(ax = ax)

plt.plot(x2,result2.init_fit)


plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %% [markdown]
# half drag

# %%
drag = "/2023-12-26/2023-12-26T155045_17e8926a-22_ge_pi_drag"
dd_drag = datadict_from_hdf5(header + drag +"/data")

drag1 = "/2023-12-26/2023-12-26T155409_91a6e143-22_ge_pi_drag"
dd_drag1 = datadict_from_hdf5(header + drag1 +"/data")

drag2 = "/2023-12-26/2023-12-26T155550_cdfd7065-22_ge_pi_drag"
dd_drag2 = datadict_from_hdf5(header + drag2 +"/data")

# %%
Rabi_drag = dd_drag['s11']['values']
imag_drag = Rabi_drag.imag
drag = dd_drag['beta']['values']
I_drag = (Rabi_drag.real)
Q_drag = (Rabi_drag.imag)

Rabi_drag1 = dd_drag1['s11']['values']
imag_drag1 = Rabi_drag1.imag
drag1 = dd_drag1['beta']['values']
I_drag1 = (Rabi_drag1.real)
Q_drag1 = (Rabi_drag1.imag)

Rabi_drag2 = dd_drag2['s11']['values']
imag_drag2 = Rabi_drag2.imag
drag2 = dd_drag2['beta']['values']
I_drag2 = (Rabi_drag2.real)
Q_drag2 = (Rabi_drag2.imag)

# %%
def PCA_transform1(Re_c_amp, Im_c_amp, Re_c_drag, Im_c_drag):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c_amp]).T, np.array([Im_c_amp]).T], axis = 1)
    c1_data = np.concatenate([np.array([Re_c_drag]).T, np.array([Im_c_drag]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    
    c1_pca = pca.transform(c1_data)
    c1_PCA1 = c1_pca.T[0]
    c1_PCA2 = c1_pca.T[1]
    return c_PCA1, c_PCA2, c1_PCA1, c1_PCA2,

# %%
PCA_drag = PCA_transform1(I_amp, Q_amp, I_drag, Q_drag)
y = PCA_drag[0]
x = amp
y0 = PCA_drag[2]
x0 = drag

PCA_drag1 = PCA_transform1(I_amp, Q_amp, I_drag1, Q_drag1)
y1 = PCA_drag1[2]
x1 = drag1

PCA_drag2 = PCA_transform1(I_amp, Q_amp, I_drag2, Q_drag2)
y2 = PCA_drag2[2]
x2 = drag2


plt.plot(x, y)
plt.show()

# %%
plt.plot(x0, y0)
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.show()

# %%
par_ini= {
    'amp': 0.00006,
    'phi0':np.pi,
    'detun':1/1.5,
    'const':0.33896
}
par_min = {
    'amp': 0,
    'phi0':-2*np.pi,
    'detun':-np.inf,
    'const':-np.inf
}
par_max = {
    'amp': np.inf,
    'phi0':2*np.pi,
    'detun':np.inf,
    'const':np.inf,
}
par_vary = {
    'amp': True,
    'phi0':True,
    'detun':True,
    'const':True
}

# %%
model = lmfit.Model(Rabi)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )
    
result0 = model.fit(data = y0, params = params, delay = x0)
result1 = model.fit(data = y1, params = params, delay = x1)
result2 = model.fit(data = y2, params = params, delay = x2)

# %%
result0
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>94</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 1.6408e-08</td><td></td></tr><tr><td>reduced chi-square</td><td> 1.6915e-10</td><td></td></tr><tr><td>Akaike info crit.</td><td>-2268.60321</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-2258.14273</td><td></td></tr><tr><td>R-squared</td><td> 0.58520139</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  5.4093e-05 </td><td>  6.1313e-05 </td><td> (113.35%) </td><td> 6e-05 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  2.30989005 </td><td>  3.70022650 </td><td> (160.19%) </td><td> 3.141592653589793 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  0.41107059 </td><td>  0.27844645 </td><td> (67.74%) </td><td> 0.6666666666666666 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  0.33895116 </td><td>  6.2521e-05 </td><td> (0.02%) </td><td> 0.33896 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>+0.9999</td></tr><tr><td>amp</td><td>const</td><td>-0.9995</td></tr><tr><td>phi0</td><td>const</td><td>+0.9979</td></tr><tr><td>detun</td><td>const</td><td>+0.9975</td></tr><tr><td>amp</td><td>phi0</td><td>-0.9964</td></tr><tr><td>amp</td><td>detun</td><td>-0.9959</td></tr></table>

# %%
res0 = (-np.pi-2.30989005)/(2*np.pi*0.41107059)
res0
# Out:
# -2.1106604086083736

# %%
result1
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>57</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 1.6400e-08</td><td></td></tr><tr><td>reduced chi-square</td><td> 1.6908e-10</td><td></td></tr><tr><td>Akaike info crit.</td><td>-2268.64975</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-2258.18927</td><td></td></tr><tr><td>R-squared</td><td> 0.70018584</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  6.2645e-05 </td><td>  4.7666e-05 </td><td> (76.09%) </td><td> 6e-05 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  3.00550729 </td><td>  2.87025442 </td><td> (95.50%) </td><td> 3.141592653589793 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  0.47367107 </td><td>  0.22044267 </td><td> (46.54%) </td><td> 0.6666666666666666 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  0.33894183 </td><td>  4.8866e-05 </td><td> (0.01%) </td><td> 0.33896 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>+0.9999</td></tr><tr><td>amp</td><td>const</td><td>-0.9991</td></tr><tr><td>phi0</td><td>const</td><td>+0.9980</td></tr><tr><td>detun</td><td>const</td><td>+0.9978</td></tr><tr><td>amp</td><td>phi0</td><td>-0.9959</td></tr><tr><td>amp</td><td>detun</td><td>-0.9956</td></tr></table>

# %%
res1 = (-np.pi-3.00550729)/(2*np.pi*0.47367107	)
res1
# Out:
# -2.065444574654362

# %%
result2
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>128</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 2.4508e-08</td><td></td></tr><tr><td>reduced chi-square</td><td> 2.5265e-10</td><td></td></tr><tr><td>Akaike info crit.</td><td>-2228.08011</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-2217.61963</td><td></td></tr><tr><td>R-squared</td><td> 0.79109542</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  3.3654e-04 </td><td>  0.00111806 </td><td> (332.22%) </td><td> 6e-05 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  6.28318531 </td><td>  3.18626747 </td><td> (50.71%) </td><td> 3.141592653589793 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  0.24500268 </td><td>  0.42631746 </td><td> (174.01%) </td><td> 0.6666666666666666 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  0.33864970 </td><td>  0.00111975 </td><td> (0.33%) </td><td> 0.33896 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>+1.0000</td></tr><tr><td>amp</td><td>const</td><td>-1.0000</td></tr><tr><td>phi0</td><td>const</td><td>+0.9999</td></tr><tr><td>detun</td><td>const</td><td>+0.9999</td></tr><tr><td>amp</td><td>phi0</td><td>-0.9999</td></tr><tr><td>amp</td><td>detun</td><td>-0.9999</td></tr></table>

# %%
res2 = (np.pi-6.28318531)/(2*np.pi*0.24500268)
res2
# Out:
# -2.0407940045753086

# %%
beta = (res0 + res1 + res2)/3
beta
# Out:
# -2.0722996626126817

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(drag)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result0.plot_fit(ax = ax)
plt.plot(x0,result0.init_fit)


plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(drag)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result1.plot_fit(ax = ax)
plt.plot(x1,result1.init_fit)


plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(drag)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result2.plot_fit(ax = ax)

plt.plot(x2,result2.init_fit)


plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %% [markdown]
# T1

# %%
def Dephase(delay, amp, gamma, const):
    return amp*np.exp(-gamma*delay) + const

t1 ="/2023-12-26/2023-12-26T160052_81ed8a85-24_ge_T1"

dd_t1 = datadict_from_hdf5(header + t1 +"/data")

# %%
s11_t1 = dd_t1['s11']['values']#[0:247]
imag_t1 = s11_t1.imag
delay_t1 = dd_t1['delay']['values']#[0:247]

I_t1 = (s11_t1.real)
Q_t1 = (s11_t1.imag)
ang_t1 = np.angle(s11_t1)

PCA_t1 = PCA_transform(I_t1, Q_t1)

y_t1 = PCA_t1[0]
x_t1 = delay_t1

fig, (ax1) = plt.subplots(nrows=1)
ax1.set_xlabel('Delay (ns)', size='large')
ax1.set_ylabel('PCA[S$_{11}$] (arb. unit.)', size='large')
plt.rcParams["font.size"] = 10
ax1.tick_params(axis="x", direction="in")
ax1.tick_params(axis="y", direction="in")
# ax1.set_xlim(0, 250000)
# ax1.set_ylim(-48, 160)
plt.tick_params(
            top='on',
            bottom='on`',
            left='on',
            right='on',
            )

plt.plot(x_t1, y_t1)
plt.show()

# %%
par_ini_t1 = {
    'gamma': 1/40000,
    'amp':15,
    'const':0
}

par_min_t1 = {
    'gamma': 0,
    'amp':0,
    'const':-np.inf
}

par_max_t1 = {
    'gamma': np.inf,
    'amp':np.inf,
    'const':np.inf,
}

par_vary_t1 = {
    'gamma': True,
    'amp':True,
    'const':True
}

# %%
model = lmfit.Model(Dephase)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini_t1[name],
    min = par_min_t1[name],
    max = par_max_t1[name],
    vary = par_vary_t1[name]
    )
result_t1 = model.fit(data = y_t1, params = params, delay = x_t1)
result_t1
# Out:
# <h2> Model</h2> Model(Dephase) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>21</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>3</td><td></td></tr><tr><td>chi-square</td><td> 84.3207542</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.86041586</td><td></td></tr><tr><td>Akaike info crit.</td><td>-12.2297413</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-4.38437975</td><td></td></tr><tr><td>R-squared</td><td> 0.93341813</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  14.1081173 </td><td>  0.42916410 </td><td> (3.04%) </td><td> 15 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> gamma </td><td>  2.9982e-05 </td><td>  1.8102e-06 </td><td> (6.04%) </td><td> 2.5e-05 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td> -2.39434900 </td><td>  0.15370382 </td><td> (6.42%) </td><td> 0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>gamma</td><td>const</td><td>+0.6803</td></tr><tr><td>amp</td><td>gamma</td><td>+0.4620</td></tr></table>

# %%
fig, ax = plt.subplots(figsize=(8,6),constrained_layout=True)
plt.rcParams["font.size"] = 20

plt.tick_params(top='on',bottom='on',left='on',right='on',)

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'

result_t1.plot_fit(ax = ax)
# plt.plot(x_t1,result_t1.init_fit, label='init fit')

# ax.set_ylim(-8, 15)
plt.title("")
plt.legend("")
ax.set_xlabel(r'Delay $\tau$ (ns)')#, size='large')
ax.set_ylabel('S$_{11}$ (arb. u.)')
# plt.savefig('ge_T1.png', bbox_inches='tight')
plt.show()

# %%
T1 = (1/2.9982e-05)*1e-9	
T1
# Out:
# 3.335334534053766e-05

# %% [markdown]
# T2_echo

# %%
t2e = "/2023-12-26/2023-12-26T161141_04e3b19f-25_ge_T2e"
dd_t2e = datadict_from_hdf5(header + t2e +"/data")

# %%
s11_t2e = dd_t2e['s11']['values']
imag_t2e = s11_t2e.imag
delay_t2e = dd_t2e['delay']['values']

I_t2e = (s11_t2e.real)
Q_t2e = (s11_t2e.imag)

PCA_t2e = PCA_transform(I_t2e, Q_t2e)

y_t2e = PCA_t2e[0]
x_t2e = delay_t2e

plt.plot(x_t2e, y_t2e)
plt.show()

# %%
par_ini_t2e = {
    'gamma': 1/20000,
    'amp':10,
    'const':0
}

par_min_t2e = {
    'gamma': 0,
    'amp':0,
    'const':-np.inf
}

par_max_t2e = {
    'gamma': np.inf,
    'amp':np.inf,
    'const':np.inf,
}

par_vary_t2e = {
    'gamma': True,
    'amp':True,
    'const':True
}

# %%
model = lmfit.Model(Dephase)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini_t2e[name],
    min = par_min_t2e[name],
    max = par_max_t2e[name],
    vary = par_vary_t2e[name]
    )
result_t2e = model.fit(data = y_t2e, params = params, delay = x_t2e)
result_t2e
# Out:
# <h2> Model</h2> Model(Dephase) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>21</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>3</td><td></td></tr><tr><td>chi-square</td><td> 64.0458678</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.65352926</td><td></td></tr><tr><td>Akaike info crit.</td><td>-40.0076215</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-32.1622600</td><td></td></tr><tr><td>R-squared</td><td> 0.85193482</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  7.53226299 </td><td>  0.33961840 </td><td> (4.51%) </td><td> 10 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> gamma </td><td>  7.9671e-05 </td><td>  8.0890e-06 </td><td> (10.15%) </td><td> 5e-05 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td> -1.58489642 </td><td>  0.16317215 </td><td> (10.30%) </td><td> 0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>gamma</td><td>const</td><td>+0.7679</td></tr><tr><td>amp</td><td>gamma</td><td>+0.3573</td></tr><tr><td>amp</td><td>const</td><td>-0.1077</td></tr></table>

# %%
fig, ax = plt.subplots(figsize=(8,6),constrained_layout=True)
plt.rcParams["font.size"] = 20

plt.tick_params(top='on',bottom='on',left='on',right='on',)

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result_t2e.plot_fit(ax = ax)
# plt.plot(delay_t2e,result_t2e.init_fit)

# ax.set_ylim(-10, 35)

plt.title("")
plt.legend("")
ax.set_xlabel(r'Delay $\tau$ (ns)')
ax.set_ylabel('S$_{11}$ (arb. u.)')
# plt.savefig('ge_T2e.png', bbox_inches='tight')
plt.show()

# %%
T2 = (1/7.9671e-05	)*1e-9	
T2
# Out:
# 1.2551618531209599e-05

# %% [markdown]
# T2 star

# %%
def Damping(delay, amp, gamma, omega, phi0, const):
    return const + amp * np.exp(- gamma*delay)*np.cos(omega*delay + phi0)

# %%
t2 = "/2023-12-26/2023-12-26T160517_202251da-23_ge_T2r1d"
dd_t2 = datadict_from_hdf5(header + t2 +"/data")

# %%
s11_t2 = dd_t2['s11']['values']
imag_t2 = s11_t2.imag
delay_t2 = dd_t2['delay']['values']

I_t2 = (s11_t2.real)
Q_t2 = (s11_t2.imag)

PCA_t2 = PCA_transform(I_t2, Q_t2)

y_t2 = PCA_t2[0]
x_t2 = delay_t2

plt.plot(x_t2, y_t2)
plt.show()

# %%
par_ini_t2 = {
    'amp':8,
    'gamma': 1/15000,
    'omega':2*np.pi/2000,
    'phi0':0,
    'const':0
}

par_min_t2 = {
    'amp':-np.inf,
    'gamma': 0,
    'omega':-2*np.pi,
    'phi0':-2*np.pi,
    'const':-np.inf
}

par_max_t2 = {
    'amp':np.inf,
    'gamma': np.inf,
    'omega':2*np.pi,
    'phi0':2*np.pi,
    'const':np.inf
}

par_vary_t2 = {
    'amp':True,
    'gamma': True,
    'omega':True,
    'phi0':True,
    'const':True
}

# %%
model = lmfit.Model(Damping)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini_t2[name],
    min = par_min_t2[name],
    max = par_max_t2[name],
    vary = par_vary_t2[name]
    )
result_t2 = model.fit(data = y_t2, params = params, delay = x_t2)
result_t2
# Out:
# <h2> Model</h2> Model(Damping) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>118</td><td></td></tr><tr><td># data points</td><td>201</td><td></td></tr><tr><td># variables</td><td>5</td><td></td></tr><tr><td>chi-square</td><td> 469.681848</td><td></td></tr><tr><td>reduced chi-square</td><td> 2.39633596</td><td></td></tr><tr><td>Akaike info crit.</td><td> 180.598878</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 197.115403</td><td></td></tr><tr><td>R-squared</td><td> 0.81032505</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  7.46914378 </td><td>  0.40776810 </td><td> (5.46%) </td><td> 8 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> gamma </td><td>  1.2934e-04 </td><td>  1.3905e-05 </td><td> (10.75%) </td><td> 6.666666666666667e-05 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> omega </td><td>  0.00624216 </td><td>  1.3922e-05 </td><td> (0.22%) </td><td> 0.0031415926535897933 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> phi0 </td><td>  0.19130465 </td><td>  0.05466387 </td><td> (28.57%) </td><td> 0 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> const </td><td>  0.00448640 </td><td>  0.10954453 </td><td> (2441.70%) </td><td> 0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>omega</td><td>phi0</td><td>-0.7749</td></tr><tr><td>amp</td><td>gamma</td><td>+0.7738</td></tr></table>

# %%
fig, ax = plt.subplots(figsize=(8,6),constrained_layout=True)
plt.rcParams["font.size"] = 20

plt.tick_params(top='on',bottom='on',left='on',right='on',)

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result_t2.plot_fit(ax = ax)
# plt.plot(delay_t2,result_t2.init_fit)
# ax.set_ylim(-10, 35)
plt.title("")
plt.legend("")
ax.tick_params(axis="x", direction="in")
ax.tick_params(axis="y", direction="in")
ax.set_xlabel(r'Delay $\tau$ (ns)')
ax.set_ylabel('S$_{11}$ (arb. u.)')
# plt.savefig('ge_T2star.png', bbox_inches='tight')
plt.show()

# %%
T2_star = (1/1.2934e-04	)*1e-9	
T2_star
# Out:
# 7.731560228854184e-06

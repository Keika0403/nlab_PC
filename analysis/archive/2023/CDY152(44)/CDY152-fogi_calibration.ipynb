# %%
header = "D:/K_sunada/result/CDY152/"

# %% [markdown]
# ## 11_27 fogi calibration - DPR1-L-120-44

# %%
from plottr.data.datadict_storage import datadict_from_hdf5
import numpy as np
import matplotlib.pyplot as plt
import lmfit

# %%
import sklearn
from sklearn.decomposition import PCA

# %%
def Lorentzian(freq, amp, const, center, k):
    return const - amp*k**2/((freq-center)**2 + k**2)

# %%
fogi = "/2023-11-14/2023-11-14T114020_275a8990-40_fogi_frequency_sweep"
dd_fogi = datadict_from_hdf5(header + fogi +"/data")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\K_Sunada\analysis\CDY152(44)\CDY152-fogi_calibration.ipynb Cell 6 line 2
#       <a href='vscode-notebook-cell:/d%3A/K_Sunada/analysis/CDY152%2844%29/CDY152-fogi_calibration.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> fogi = "/2023-11-14/2023-11-14T114020_275a8990-40_fogi_frequency_sweep"
# ----> <a href='vscode-notebook-cell:/d%3A/K_Sunada/analysis/CDY152%2844%29/CDY152-fogi_calibration.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> dd_fogi = datadict_from_hdf5(header + fogi +"/data")
#
# File d:\K_Sunada\.venv\lib\site-packages\plottr\data\datadict_storage.py:263, in datadict_from_hdf5(path, groupname, startidx, stopidx, structure_only, ignore_unequal_lengths, file_timeout)
#     261 filepath = _data_file_path(path)
#     262 if not filepath.exists():
# --> 263     raise ValueError("Specified file does not exist.")
#     265 if startidx is None:
#     266     startidx = 0
#
# ValueError: Specified file does not exist.

# %%
def PCA_transform(Re_c, Im_c):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c]).T, np.array([Im_c]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    return c_PCA1, c_PCA2

# %%
Fogi = dd_fogi['s11']['values']
#imag_ge = Rabi_ge.imag
Fogi_freq = dd_fogi['fogi_freq']['values']

I = (Fogi.real)
Q = (Fogi.imag)

PCAfogi = PCA_transform(I, Q)

# %%
y = PCAfogi[0]
x = Fogi_freq

plt.plot(x, -y)
plt.show()

# %%
par_ini = {
    'amp': 35,
    'const':13,
    'center':5.425,
    'k':0.025
}

par_min = {
    'amp': 0,
    'const':-np.inf,
    'center':0,
    'k':0
}

par_max = {
    'amp': np.inf,
    'const':np.inf,
    'center':np.inf,
    'k':np.inf
}

par_vary = {
    'amp': True,
    'const':True,
    'center':True,
    'k':True
}

# %%
model = lmfit.Model(Lorentzian)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )

# %%
result = model.fit(data = -y, params=params, freq = x)
result
# Out:
# <h2> Model</h2> Model(Lorentzian) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>31</td><td></td></tr><tr><td># data points</td><td>201</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 643.112975</td><td></td></tr><tr><td>reduced chi-square</td><td> 3.26453287</td><td></td></tr><tr><td>Akaike info crit.</td><td> 241.766115</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 254.979335</td><td></td></tr><tr><td>R-squared</td><td> 0.97489944</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  38.5741757 </td><td>  0.47309235 </td><td> (1.23%) </td><td> 35 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  18.2877688 </td><td>  0.46938315 </td><td> (2.57%) </td><td> 13 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> center </td><td>  5.42084936 </td><td>  3.4199e-04 </td><td> (0.01%) </td><td> 5.425 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> k </td><td>  0.04059450 </td><td>  0.00101344 </td><td> (2.50%) </td><td> 0.025 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>const</td><td>k</td><td>+0.8522</td></tr><tr><td>amp</td><td>const</td><td>+0.7224</td></tr><tr><td>amp</td><td>k</td><td>+0.3579</td></tr></table>

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Fogi")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result.plot_fit(ax = ax)
plt.plot(x,result.init_fit)


plt.xlabel("Frequency (GHz)")
plt.ylabel("PCA[S11](a.u.)")

plt.show()

# %% [markdown]
# ## ac stark shift

# %%
def double_Lorentzian(freq, amp1, const, center1, k1, amp2, center2, k2):
    return const - amp1*k1**2/((freq-center1)**2 + k2**2)- amp2*k2**2/((freq-center2)**2 + k2**2)

# %%
ac = "/2023-11-27/2023-11-27T104900_22b27732-42_fogi_ac_Stark_shift"
dd_ac = datadict_from_hdf5(header + ac +"/data")

xs = []
ys = []

for i in range(11):
    ini = 71*i
    fin = 71*(1+i)
    x = dd_ac['fogi_freq']['values'][ini:fin]
    y = dd_ac['s11']['values'][ini:fin].real
    xs.append(x)
    ys.append(y)

# %%
plt.plot(xs[0], -ys[0])
plt.show()

# %%
par_ini = {
    'amp1': 60,
    'const':7,
    'center1':5.35,
    'k1':0.07,
    'amp2': 3,
    'center2':5.5,
    'k2':0.12,
}

par_min = {
    'amp1': 0,
    'const':-np.inf,
    'center1':0,
    'k1':0,
    'amp2': 0,
    'center2':0,
    'k2':0,
}

par_max = {
    'amp1': np.inf,
    'const':np.inf,
    'center1':np.inf,
    'k1':np.inf,
    'amp2': np.inf,
    'center2':np.inf,
    'k2':np.inf,
}

par_vary = {
    'amp1': True,
    'const':True,
    'center1':True,
    'k1':True,
    'amp2': True,
    'center2':True,
    'k2':True,
}

# %%
model = lmfit.Model(double_Lorentzian)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )

# %%
results = []
for i in range(10):
    result = model.fit(data = -ys[i], params=params, freq = xs[i])
    results.append(result)

# %%
results[4]
# Out:
# <h2> Model</h2> Model(double_Lorentzian) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>144</td><td></td></tr><tr><td># data points</td><td>71</td><td></td></tr><tr><td># variables</td><td>7</td><td></td></tr><tr><td>chi-square</td><td> 143.003613</td><td></td></tr><tr><td>reduced chi-square</td><td> 2.23443145</td><td></td></tr><tr><td>Akaike info crit.</td><td> 63.7134913</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 79.5522505</td><td></td></tr><tr><td>R-squared</td><td> 0.97585803</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp1 </td><td>  41.5076035 </td><td>  1.0618e+11 </td><td> (255810596313.60%) </td><td> 60 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  8.33146504 </td><td>  0.39257964 </td><td> (4.71%) </td><td> 7 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> center1 </td><td>  5.38567228 </td><td>  0.00172736 </td><td> (0.03%) </td><td> 5.35 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> k1 </td><td>  0.05764978 </td><td>  73736072.3 </td><td> (127903482614.38%) </td><td> 0.07 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> amp2 </td><td>  10.7664651 </td><td>  0.72940578 </td><td> (6.77%) </td><td> 3 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> center2 </td><td>  5.54371792 </td><td>  0.00484453 </td><td> (0.09%) </td><td> 5.5 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> k2 </td><td>  0.06738550 </td><td>  0.00287416 </td><td> (4.27%) </td><td> 0.12 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>amp1</td><td>k1</td><td>-1.0000</td></tr><tr><td>const</td><td>k2</td><td>+0.6431</td></tr><tr><td>center1</td><td>amp2</td><td>-0.4072</td></tr><tr><td>amp2</td><td>k2</td><td>-0.3939</td></tr><tr><td>amp1</td><td>center1</td><td>+0.3216</td></tr><tr><td>center1</td><td>k1</td><td>-0.3216</td></tr><tr><td>center2</td><td>k2</td><td>+0.3198</td></tr><tr><td>const</td><td>center2</td><td>+0.2974</td></tr><tr><td>center1</td><td>center2</td><td>+0.2942</td></tr><tr><td>amp2</td><td>center2</td><td>-0.2418</td></tr><tr><td>const</td><td>amp2</td><td>+0.1275</td></tr></table>

# %%
fig, ax = plt.subplots(dpi=80)


plt.rcParams["font.size"] = 10
ax.tick_params(axis="x", direction="in")
ax.tick_params(axis="y", direction="in")
plt.tick_params(
            top='on',
            bottom='on`',
            left='on',
            right='on',
            )

results[4].plot_fit(ax = ax)
# plt.plot(xs[0],results[0].init_fit)
ax.set_xlabel('F0g1 frequency (GHz)', size='large')
ax.set_ylabel('Re[S$_{11}$] (Arb. u.)', size='large')
plt.show()

# %%
x =[ 0.2, 0.4, 0.6, 0.8, 0.9, 
     1.0, 1.1, 1.2, 1.3, 1.4]
y1 =[5.45170904, 5.44252632, 5.42614787, 5.40136339, 5.38567228, 
     5.36739227, 5.34771135, 5.32682746, 5.29869813, 5.27653596]
y2 =[5.62165854, 5.61231752, 5.58917815, 5.56575065, 5.54371784,
     5.52253094, 5.48555466, 5.46898425, 5.45077474, 5.44070221]

plt.plot(x, y1)
plt.plot(x, y2)
plt.show()

# %%
def ac_stark(amp, const, alpha):
    return const - alpha*(amp**2)

# %%
par_ini = {
    'const':5.45,
    'alpha':0.14
}

par_min = {
    'const':0,
    'alpha':-np.inf
}

par_max = {
    'const':np.inf,
    'alpha':np.inf
}

par_vary = {
    'const':True,
    'alpha':True
}

# %%
model = lmfit.Model(ac_stark)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )

# %%
result = model.fit(data = y1, params=params, amp = x)
result
# Out:
# <h2> Model</h2> Model(ac_stark) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>7</td><td></td></tr><tr><td># data points</td><td>10</td><td></td></tr><tr><td># variables</td><td>2</td><td></td></tr><tr><td>chi-square</td><td> 3.8516e-05</td><td></td></tr><tr><td>reduced chi-square</td><td> 4.8145e-06</td><td></td></tr><tr><td>Akaike info crit.</td><td>-120.670118</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-120.064948</td><td></td></tr><tr><td>R-squared</td><td> 0.99881286</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> const </td><td>  5.45854352 </td><td>  0.00125795 </td><td> (0.02%) </td><td> 5.45 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> alpha </td><td>  0.09246521 </td><td>  0.00112705 </td><td> (1.22%) </td><td> 0.14 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>const</td><td>alpha</td><td>+0.8341</td></tr></table>

# %%
result2 = model.fit(data = y2, params=params, amp = x)
result2
# Out:
# <h2> Model</h2> Model(ac_stark) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>10</td><td></td></tr><tr><td># data points</td><td>10</td><td></td></tr><tr><td># variables</td><td>2</td><td></td></tr><tr><td>chi-square</td><td> 6.4060e-04</td><td></td></tr><tr><td>reduced chi-square</td><td> 8.0074e-05</td><td></td></tr><tr><td>Akaike info crit.</td><td>-92.5569749</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-91.9518047</td><td></td></tr><tr><td>R-squared</td><td> 0.98404514</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> const </td><td>  5.62517009 </td><td>  0.00513019 </td><td> (0.09%) </td><td> 5.45 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> alpha </td><td>  0.10209789 </td><td>  0.00459632 </td><td> (4.50%) </td><td> 0.14 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>const</td><td>alpha</td><td>+0.8341</td></tr></table>

# %%
fig, ax = plt.subplots(dpi=80)

plt.rcParams["font.size"] = 10
ax.tick_params(axis="x", direction="in")
ax.tick_params(axis="y", direction="in")
plt.tick_params(
            top='on',
            bottom='on`',
            left='on',
            right='on',
            )


plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result.plot_fit(ax = ax)
result2.plot_fit(ax = ax)
# plt.plot(x ,result.init_fit)

plt.xlabel("F0g1 amplitude (V)", size = "large")
plt.ylabel("F0g1 frequency(GHz)", size = "large")



plt.show()

# %%
(0.09246521+0.10209789)/2
# Out:
# 0.09728155

# %% [markdown]
# fogi duration

# %%
fogi_duration = "/2023-11-27/2023-11-27T124156_e994318a-41_fogi_duration_sweep"
dd_fogi_duration = datadict_from_hdf5(header + fogi_duration +"/data")

# %%
x_duration = dd_fogi_duration['fogi_duration']['values']
y_duration = dd_fogi_duration['s11']['values']

PCAduration = PCA_transform(y_duration.real, y_duration.imag)

# %%
fig, ax = plt.subplots(dpi=80)

#plt.title("fogi duration")
plt.rcParams["font.size"] = 15
plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
plt.scatter(x_duration ,PCAduration[0])

plt.xlabel("Fogi duration (ns)", size="large")
plt.ylabel("PCA[S11] (Arb. u.)", size="large")
plt.tick_params(
            top='on',
            bottom='on`',
            left='on',
            right='on',
            )

plt.show()

# %%
def ave_ph_number(alpha):
    return np.exp(-(alpha**2)/2)*alpha

# %%
ph_amp = "/2023-11-30/2023-11-30T174155_50e3db80-61_ab1_ph_amp_sweep"
dd_ph_amp = datadict_from_hdf5(header + ph_amp +"/data")

# %%
x = dd_ph_amp['photon_amp']['values']
y = dd_ph_amp['s11']['values'].real

# %%
PCA_ph_amp = PCA_transform(y.real, y.imag)
y = PCA_ph_amp[0]

# %%
plt.plot(x, -y)
plt.show()

# %%
def ave_ph_number(ph_amp, amp, const, a):
    return const + amp*np.exp(-(a*ph_amp)**2)*(a*ph_amp)**2

# %%
par_ini = {'amp': 150,'const':-40, 'a':2}
par_min = {'amp': 0, 'const':-np.inf, 'a':0}
par_max = {'amp': np.inf,'const':np.inf, 'a':np.inf}
par_vary = {'amp': True,'const':True, 'a':True}

# %%
model = lmfit.Model(ave_ph_number)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )

# %%
result = model.fit(data = -y, params=params, ph_amp = x)
result
# Out:
# <h2> Model</h2> Model(ave_ph_number) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>33</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>3</td><td></td></tr><tr><td>chi-square</td><td> 2895.96220</td><td></td></tr><tr><td>reduced chi-square</td><td> 29.5506347</td><td></td></tr><tr><td>Akaike info crit.</td><td> 344.951171</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 352.796532</td><td></td></tr><tr><td>R-squared</td><td> 0.54469760</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  50.0921861 </td><td>  4.62628716 </td><td> (9.24%) </td><td> 150 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td> -10.9323262 </td><td>  1.15883604 </td><td> (10.60%) </td><td> -40 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> a </td><td>  1.24638842 </td><td>  0.03879391 </td><td> (3.11%) </td><td> 2 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>amp</td><td>const</td><td>-0.8707</td></tr><tr><td>const</td><td>a</td><td>+0.1518</td></tr></table>

# %%
fig, ax = plt.subplots(dpi=80)
# plt.title("ph_amp")
plt.rcParams["font.size"] = 14
plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
# result.plot_fit(ax = ax)
# plt.plot(x,result.init_fit)
plt.scatter(x, y)


plt.xlabel("Photon amplitude (V)", size="large")
plt.ylabel("Re[S11](Arb. u.)", size="large")

plt.show()

# %%
x = np.linspace(0, 1.5)
plt.plot(x, ave_ph_number(x**0.5))
plt.show()

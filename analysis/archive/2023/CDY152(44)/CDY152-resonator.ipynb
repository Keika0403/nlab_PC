# %%
from plottr.data.datadict_storage import datadict_from_hdf5
import numpy as np
import matplotlib.pyplot as plt
import lmfit
import scipy.constants as spc

# %%
def S11_resonator(freq, fc, ke, ki, a0, a1, Poff, ed):
    numer = 1j*(freq-fc)+(ke-ki)/2
    denom = 1j*(freq-fc)-(ke+ki)/2
    model = (numer/denom * (a0+a1*(freq-freq[0])) * np.exp(1j*(-Poff-ed*2*np.pi*freq))).conj()
    return model

# %%
header = "D:/K_sunada/result/CDY152/"
data = "/2023-11-25/2023-11-25T163514_2c71eaad-10_spectrum"
dd = datadict_from_hdf5(header + data +"/data")

# %%
s11 = dd['s11']['values']
s11_real = dd['s11']['values'].real
s11_imag = dd['s11']['values'].imag
freq = dd['frequency']['values']*1e-9

# %%
# plt.plot(freq, s11)
plt.plot(freq, s11_real)
plt.plot(freq, s11_imag)
plt.show()

# %%
par_ini = {
    'fc':10.2e9,
    'ke':0.030*1e9,
    'ki':0.0001*1e9,
    'a0':3.9356e-06,
    'a1':0.000001,
    'Poff':np.pi/2,
    'ed':0,
}

par_min = {
    'fc':0,
    'ke':0,
    'ki':0,
    'a0':- np.inf,
    'a1':- np.inf,
    'Poff':- np.pi,
    'ed':- np.inf,
}

par_max = {
    'fc':np.inf,
    'ke':np.inf,
    'ki':np.inf,
    'a0':np.inf,
    'a1':np.inf,
    'Poff':np.pi,
    'ed':np.inf,
}

par_vary = {
    'fc':True,
    'ke':True,
    'ki':True,
    'a0':True,
    'a1':True,
    'Poff':True,
    'ed':True,
}

# %%
model = lmfit.Model(S11_resonator)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )

# %% [markdown]
# dpr

# %%
def S11_dpr_model(freq, fr, ff, kf_e, kf_i, gamma, g, a0, a1, Poff,ed):
    numer = (1j*(freq-ff)+(kf_e-kf_i)/2)*(1j*(freq-fr)-gamma/2) + (g**2)
    denom = (1j*(freq-ff)-(kf_e+kf_i)/2)*(1j*(freq-fr)-gamma/2) + (g**2)
    model = (numer/denom * (a0+a1*(freq-freq[0])) * np.exp(1j*(Poff-ed*2*np.pi*(freq-freq[0])))).conj()
    return model

# %%
fig,ax = plt.subplots(1,2)
ax[0].plot(freq,np.abs(s11))
ax[1].plot(freq,np.angle(s11))

# %%
par_ini = {'fr': 10.225,  'ff': 10.21,    'kf_e': 230e-3,   'kf_i': 0.00001,  'g': 103e-3, 'gamma': 0.00001,
           'a0': 1.5,  'a1': 0.01,        'Poff': 0.02,   'ed': 0}
par_min = {'fr': 0,     'ff': 0,        'kf_e': 0,        'kf_i': 0,        'g': 0,     'gamma': 0,
           'a0': 0,     'a1': -np.inf,  'Poff': -np.inf,'ed': -np.inf}
par_max = {'fr': np.inf,'ff': np.inf,   'kf_e': np.inf,   'kf_i': np.inf,   'g': np.inf,'gamma': np.inf,
           'a0': np.inf,'a1': np.inf,   'Poff': np.inf, 'ed': np.inf}
par_var = {'fr': True, 'ff': True,    'kf_e': True,    'kf_i': False,    'g': True, 'gamma': False,
           'a0': True, 'a1': True,    'Poff': True,  'ed': True}

model=lmfit.Model(S11_dpr_model)
params = model.make_params()

for name in list(par_ini):
    params[name].set(value=par_ini[name])
for name in list(par_min):
    params[name].set(min=par_min[name])  
for name in list(par_max):
    params[name].set(max=par_max[name]) 
for name in list(par_var):
    params[name].set(vary=par_var[name])
result = model.fit(freq=freq, data=s11, params=params, method='leastsq')

# %%
fig, ax = plt.subplots(figsize=(10,6),constrained_layout=True)
plt.rcParams["font.size"] = 15
ax.set_xlabel('Frequency (GHz)',fontsize=18)
ax.set_ylabel('Phase[S$_{11}$] (arg) ', fontsize=18)
# ax.tick_params(direction='in')
ax.tick_params(axis="x", direction="in")
ax.tick_params(axis="y", direction="in")
# ax1.set_xlim(0, 250000)
# ax1.set_ylim(-48, 160)

plt.tick_params(
            top='on',
            bottom='on`',
            left='on',
            right='on',
            )

ax.plot(freq,np.angle(s11), ls='', marker='o')

ax.plot(freq,np.angle(result.best_fit), color='orange')
# ax.plot(freq,np.angle(result.init_fit), color='green', ls='--', )

# ax[1][0].plot(freq,np.abs(s11) - np.abs(result.best_fit), ls='', marker='.')
# error_phi = np.angle(s11) - np.angle(result.best_fit)
# error_phi[error_phi>np.pi] -= 2*np.pi
# error_phi[error_phi<-np.pi] += 2*np.pi
# ax[1][1].plot(freq,error_phi, ls='', marker='.')

result
# Out:
# <h2> Model</h2> Model(S11_dpr_model) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>168</td><td></td></tr><tr><td># data points</td><td>202</td><td></td></tr><tr><td># variables</td><td>8</td><td></td></tr><tr><td>chi-square</td><td> 6612.73522</td><td></td></tr><tr><td>reduced chi-square</td><td> 34.0862640</td><td></td></tr><tr><td>Akaike info crit.</td><td> 720.673960</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 747.140102</td><td></td></tr><tr><td>R-squared</td><td>-6.6127e+18</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> fr </td><td>  10.2557302 </td><td>  0.00226196 </td><td> (0.02%) </td><td> 10.225 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> ff </td><td>  10.1676834 </td><td>  0.00393378 </td><td> (0.04%) </td><td> 10.21 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> kf_e </td><td>  0.21238950 </td><td>  0.00770689 </td><td> (3.63%) </td><td> 0.23 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> kf_i </td><td>  1.0000e-05 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 1e-05 </td><td>  0.00000000 </td><td>         inf </td><td> False </td></tr><tr><td> gamma </td><td>  1.0000e-05 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 1e-05 </td><td>  0.00000000 </td><td>         inf </td><td> False </td></tr><tr><td> g </td><td>  0.10110600 </td><td>  0.00161348 </td><td> (1.60%) </td><td> 0.103 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> a0 </td><td>  35.0587831 </td><td>  1.15340013 </td><td> (3.29%) </td><td> 1.5 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> a1 </td><td> -5.42468072 </td><td>  1.99263602 </td><td> (36.73%) </td><td> 0.01 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> Poff </td><td> -32.7749969 </td><td>  0.97581874 </td><td> (2.98%) </td><td> 0.02 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> ed </td><td> -0.51133795 </td><td>  0.01502773 </td><td> (2.94%) </td><td> 0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>Poff</td><td>ed</td><td>+0.9996</td></tr><tr><td>a0</td><td>a1</td><td>-0.8638</td></tr><tr><td>kf_e</td><td>ed</td><td>-0.6968</td></tr><tr><td>kf_e</td><td>Poff</td><td>-0.6938</td></tr><tr><td>fr</td><td>g</td><td>-0.6365</td></tr><tr><td>fr</td><td>ff</td><td>-0.4564</td></tr><tr><td>g</td><td>Poff</td><td>-0.3335</td></tr><tr><td>g</td><td>ed</td><td>-0.3313</td></tr><tr><td>ff</td><td>Poff</td><td>+0.2797</td></tr><tr><td>ff</td><td>ed</td><td>+0.2662</td></tr><tr><td>kf_e</td><td>g</td><td>+0.2315</td></tr><tr><td>ff</td><td>g</td><td>+0.2231</td></tr><tr><td>ff</td><td>kf_e</td><td>-0.1228</td></tr><tr><td>fr</td><td>Poff</td><td>+0.1018</td></tr></table>

# %%
fig, ax = plt.subplots(1,2,figsize=(16,6),constrained_layout=True)
ax[0].set_xlabel('Frequency(GHz)',fontsize=16)
ax[0].set_ylabel('Re[$S_{11}]$', fontsize=16)
ax[1].set_xlabel('Frequency(GHz)',fontsize=16)
ax[1].set_ylabel('Im[$S_{11}]$', fontsize=16)
# ax.tick_params(direction='in')

ax[0].plot(freq,np.real(s11), ls='', marker='.')
ax[0].plot(freq,np.real(result.best_fit), color='orange')
# ax[0].plot(freq,np.real(result.init_fit), color='green', ls='--', marker='')
ax[1].plot(freq,np.imag(s11), ls='', marker='.')
ax[1].plot(freq,np.imag(result.best_fit), color='orange')
# ax[1].plot(freq,np.imag(result.init_fit), color='green', ls='--', )
# ax[1][0].plot(freq,np.abs(s11) - np.abs(result.best_fit), ls='', marker='.')
# error_phi = np.angle(s11) - np.angle(result.best_fit)
# error_phi[error_phi>np.pi] -= 2*np.pi
# error_phi[error_phi<-np.pi] += 2*np.pi
# ax[1][1].plot(freq,error_phi, ls='', marker='.')

result
# Out:
# <h2> Model</h2> Model(S11_dpr_model) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>168</td><td></td></tr><tr><td># data points</td><td>202</td><td></td></tr><tr><td># variables</td><td>8</td><td></td></tr><tr><td>chi-square</td><td> 6612.73522</td><td></td></tr><tr><td>reduced chi-square</td><td> 34.0862640</td><td></td></tr><tr><td>Akaike info crit.</td><td> 720.673960</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 747.140102</td><td></td></tr><tr><td>R-squared</td><td>-6.6127e+18</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> fr </td><td>  10.2557302 </td><td>  0.00226196 </td><td> (0.02%) </td><td> 10.225 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> ff </td><td>  10.1676834 </td><td>  0.00393378 </td><td> (0.04%) </td><td> 10.21 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> kf_e </td><td>  0.21238950 </td><td>  0.00770689 </td><td> (3.63%) </td><td> 0.23 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> kf_i </td><td>  1.0000e-05 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 1e-05 </td><td>  0.00000000 </td><td>         inf </td><td> False </td></tr><tr><td> gamma </td><td>  1.0000e-05 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 1e-05 </td><td>  0.00000000 </td><td>         inf </td><td> False </td></tr><tr><td> g </td><td>  0.10110600 </td><td>  0.00161348 </td><td> (1.60%) </td><td> 0.103 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> a0 </td><td>  35.0587831 </td><td>  1.15340013 </td><td> (3.29%) </td><td> 1.5 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> a1 </td><td> -5.42468072 </td><td>  1.99263602 </td><td> (36.73%) </td><td> 0.01 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> Poff </td><td> -32.7749969 </td><td>  0.97581874 </td><td> (2.98%) </td><td> 0.02 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> ed </td><td> -0.51133795 </td><td>  0.01502773 </td><td> (2.94%) </td><td> 0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>Poff</td><td>ed</td><td>+0.9996</td></tr><tr><td>a0</td><td>a1</td><td>-0.8638</td></tr><tr><td>kf_e</td><td>ed</td><td>-0.6968</td></tr><tr><td>kf_e</td><td>Poff</td><td>-0.6938</td></tr><tr><td>fr</td><td>g</td><td>-0.6365</td></tr><tr><td>fr</td><td>ff</td><td>-0.4564</td></tr><tr><td>g</td><td>Poff</td><td>-0.3335</td></tr><tr><td>g</td><td>ed</td><td>-0.3313</td></tr><tr><td>ff</td><td>Poff</td><td>+0.2797</td></tr><tr><td>ff</td><td>ed</td><td>+0.2662</td></tr><tr><td>kf_e</td><td>g</td><td>+0.2315</td></tr><tr><td>ff</td><td>g</td><td>+0.2231</td></tr><tr><td>ff</td><td>kf_e</td><td>-0.1228</td></tr><tr><td>fr</td><td>Poff</td><td>+0.1018</td></tr></table>

# %% [markdown]
# 平均光子数

# %%
def ave_photon_number(Power, k_ex, k_in, omega_r, omega_p):
    n = (k_ex/(((k_in + k_ex)/2)**2 + (omega_r - omega_p)**2))*(Power/(spc.hbar * omega_p))
    return n

# %%
spc.hbar
# Out:
# 1.0545718176461565e-34

# %%
k_ex = 0.19078723e9*(2*np.pi)
k_in = 0

omega_r = 10.2503210e9*2*np.pi
omega_p = 10.297e9*2*np.pi

Power =  10**((-22.4-10-2.3-50-20)/10) *1e-3#J/s
Power
# ave_photon_number(Power, k_ex, k_in, omega_r, omega_p)
# Out:
# 3.3884415613920344e-14

# %%
P =  (10**((-50)/10) *1e-3  /6.626e-34 )*1e-9#GHz/s
P
# Out:
# 1.509206157561123e+16

# %%
kai = (0.13e9)*2*np.pi/2
delta = (10.2503210-8.02-0.00233)*1e9*2*np.pi
g = (kai*delta)**0.5
g
# Out:
# 2391075352.76259

# %%
delta**2/(4*g**2)
# Out:
# 8.569196153846155

# %%
k_ex
# Out:
# 1198751520.3334923

# %%
delta = omega_p - 8.02e9*2*np.pi
g =
# Out:
#   Cell In[20], line 2
#     g =
#         ^
# SyntaxError: invalid syntax

# %%
Power, omega_p, omega_r, k_ex, k_in

# %%
1/(10.209-10.066)

# %% [markdown]
# # frequency optimization

# %%
data = "/2023-12-12/2023-12-12T102517_4eb0a12c-26_freq_optimize"
dd = datadict_from_hdf5(header + data +"/data")
ed = 1e-9/(9.8396-9.8147)


s11_eg = dd['s11_eg']['values']* np.exp(1j*(ed*2*np.pi*freq))
s11_g = dd['s11_g']['values']* np.exp(1j*(ed*2*np.pi*freq))
s11_e = dd['s11_e']['values']* np.exp(1j*(ed*2*np.pi*freq))
freq = dd['frequency']['values']

# %% [markdown]
# eg-peak

# %%
plt.plot(freq, s11_eg.real)
plt.show()

# %%
def Lorentzian(freq, amp, const, center, k):
    return const - amp*k**2/((freq-center)**2 + k**2)

# %%
import sklearn
from sklearn.decomposition import PCA

# %%
def PCA_transform(Re_c, Im_c):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c]).T, np.array([Im_c]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    return c_PCA1, c_PCA2

# %%
I = s11_eg.real
Q = s11_eg.imag
plt.plot(freq, I)
PCAge = PCA_transform(I, Q)

# %%
y = PCAge[0]
x = freq

plt.plot(x, Q)
plt.title("data after PCA")
plt.show()

# %%
par_ini = {
    'amp': 23,
    'const':2.5,
    'center':10.3e9,
    'k':0.008e9
}

par_min = {
    'amp': 0,
    'const':0,
    'center':0,
    'k':0
}

par_max = {
    'amp': np.inf,
    'const':np.inf,
    'center':np.inf,
    'k':np.inf
}

par_vary = {
    'amp': True,
    'const':True,
    'center':True,
    'k':True
}

# %%
model = lmfit.Model(Lorentzian)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )

# %%
result = model.fit(data = -Q, params = params, freq = x)
result
# Out:
# <h2> Model</h2> Model(Lorentzian) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>44</td><td></td></tr><tr><td># data points</td><td>201</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 534.957656</td><td></td></tr><tr><td>reduced chi-square</td><td> 2.71552109</td><td></td></tr><tr><td>Akaike info crit.</td><td> 204.755420</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 217.968640</td><td></td></tr><tr><td>R-squared</td><td> 0.90146665</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  19.0769791 </td><td>  0.51800805 </td><td> (2.72%) </td><td> 23 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  2.59937394 </td><td>  0.17930994 </td><td> (6.90%) </td><td> 2.5 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> center </td><td>  1.0306e+10 </td><td>  352322.604 </td><td> (0.00%) </td><td> 10300000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> k </td><td>  13064010.6 </td><td>  625065.599 </td><td> (4.78%) </td><td> 8000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>const</td><td>k</td><td>+0.5995</td></tr><tr><td>amp</td><td>k</td><td>-0.4975</td></tr><tr><td>amp</td><td>const</td><td>+0.1090</td></tr></table>

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("g-e transition")


plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result.plot_fit(ax = ax)

plt.xlabel("frequency (Hz)")
plt.ylabel("mag[S11](a.u.)")


plt.show()

# %% [markdown]
# omega_g, _e fitting

# %%
par_ini = {'fr': 10.23e9,  'ff': 10.17e9,    'kf_e': 200e6,   'kf_i': 5e4,  'g': 103e6, 'gamma': 1000,
           'a0': 50,  'a1': 0,        'Poff': 1.5,   'ed': -0.5e-9}
par_min = {'fr': 0,     'ff': 0,        'kf_e': 0,        'kf_i': 0,        'g': 0,     'gamma': 0,
           'a0': 0,     'a1': -np.inf,  'Poff': -np.inf,'ed': -np.inf}
par_max = {'fr': np.inf,'ff': np.inf,   'kf_e': np.inf,   'kf_i': np.inf,   'g': np.inf,'gamma': np.inf,
           'a0': np.inf,'a1': np.inf,   'Poff': np.inf, 'ed': np.inf}
par_var = {'fr': True, 'ff': True,    'kf_e': True,    'kf_i': True,    'g': True, 'gamma': True,
           'a0': True, 'a1': False,    'Poff': True,  'ed': True}

model=lmfit.Model(S11_dpr_model)
params = model.make_params()

for name in list(par_ini):
    params[name].set(value=par_ini[name])
for name in list(par_min):
    params[name].set(min=par_min[name])  
for name in list(par_max):
    params[name].set(max=par_max[name]) 
for name in list(par_var):
    params[name].set(vary=par_var[name])

# %%
res = model.fit(data = s11_g, params = params, freq = x)

fig, ax = plt.subplots(1,2,figsize=(10,4))
ax[0].plot(x, np.real(s11_g), '.', color='k')
ax[0].plot(x, np.real(res.init_fit), '--', label='initial fit', color='orange')
ax[0].plot(x, np.real(res.best_fit), '-', label='best fit', color='red')
ax[0].legend()
ax[1].plot(x, np.angle(s11_g), '.', color='k')
ax[1].plot(x, np.angle(res.init_fit), '--', label='initial fit', color='orange')
ax[1].plot(x, np.angle(res.best_fit), '-', label='best fit', color='red')
ax[1].legend()

plt.show()
res
# Out:
# <h2> Model</h2> Model(S11_dpr_model) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>140</td><td></td></tr><tr><td># data points</td><td>402</td><td></td></tr><tr><td># variables</td><td>9</td><td></td></tr><tr><td>chi-square</td><td> 39530.6431</td><td></td></tr><tr><td>reduced chi-square</td><td> 100.586878</td><td></td></tr><tr><td>Akaike info crit.</td><td> 1862.52849</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 1898.49656</td><td></td></tr><tr><td>R-squared</td><td>-3.9531e+19</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> fr </td><td>  1.0268e+10 </td><td>  2093322.16 </td><td> (0.02%) </td><td> 10230000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> ff </td><td>  1.0147e+10 </td><td>  3020008.54 </td><td> (0.03%) </td><td> 10170000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> kf_e </td><td>  1.5398e+08 </td><td>  4857891.60 </td><td> (3.15%) </td><td> 200000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> kf_i </td><td>  354.265000 </td><td>  4784845.20 </td><td> (1350640.11%) </td><td> 50000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> gamma </td><td>  1898240.40 </td><td>  2292129.70 </td><td> (120.75%) </td><td> 1000 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> g </td><td>  91686420.6 </td><td>  1658868.14 </td><td> (1.81%) </td><td> 103000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> a0 </td><td>  46.5812921 </td><td>  0.90598649 </td><td> (1.94%) </td><td> 50 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> a1 </td><td>  0.00000000 </td><td>  0.00000000 </td><td>  </td><td> 0 </td><td>        -inf </td><td>         inf </td><td> False </td></tr><tr><td> Poff </td><td>  1.21431332 </td><td>  0.04410561 </td><td> (3.63%) </td><td> 1.5 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> ed </td><td> -6.1475e-10 </td><td>  1.1434e-11 </td><td> (1.86%) </td><td> -5e-10 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>Poff</td><td>ed</td><td>+0.8928</td></tr><tr><td>fr</td><td>g</td><td>-0.8331</td></tr><tr><td>fr</td><td>ff</td><td>-0.6163</td></tr><tr><td>kf_e</td><td>ed</td><td>-0.5940</td></tr><tr><td>kf_i</td><td>a0</td><td>-0.5345</td></tr><tr><td>ff</td><td>g</td><td>+0.4907</td></tr><tr><td>kf_e</td><td>Poff</td><td>-0.4609</td></tr><tr><td>kf_i</td><td>gamma</td><td>+0.4091</td></tr><tr><td>ff</td><td>Poff</td><td>+0.3920</td></tr><tr><td>ff</td><td>ed</td><td>+0.2435</td></tr><tr><td>g</td><td>Poff</td><td>-0.2203</td></tr><tr><td>g</td><td>ed</td><td>-0.2095</td></tr><tr><td>fr</td><td>Poff</td><td>+0.1257</td></tr><tr><td>kf_e</td><td>g</td><td>+0.1144</td></tr></table>

# %%
res = model.fit(data = s11_e, params = params, freq = x, method='nelder')

fig, ax = plt.subplots(1,2,figsize=(10,4))
ax[0].plot(x, np.real(s11_e), '.', color='k')
ax[0].plot(x, np.real(res.init_fit), '--', label='initial fit', color='orange')
ax[0].plot(x, np.real(res.best_fit), '-', label='best fit', color='red')
ax[0].legend()
ax[1].plot(x, np.angle(s11_e), '.', color='k')
ax[1].plot(x, np.angle(res.init_fit), '--', label='initial fit', color='orange')
ax[1].plot(x, np.angle(res.best_fit), '-', label='best fit', color='red')
ax[1].legend()

plt.show()
res
# Out:
# <h2> Model</h2> Model(S11_dpr_model) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>Nelder-Mead</td><td></td></tr><tr><td># function evals</td><td>3120</td><td></td></tr><tr><td># data points</td><td>402</td><td></td></tr><tr><td># variables</td><td>9</td><td></td></tr><tr><td>chi-square</td><td> 38862.6590</td><td></td></tr><tr><td>reduced chi-square</td><td> 98.8871730</td><td></td></tr><tr><td>Akaike info crit.</td><td> 1855.67750</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 1891.64557</td><td></td></tr><tr><td>R-squared</td><td>-3.8863e+19</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> fr </td><td>  1.0263e+10 </td><td> 10230000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> ff </td><td>  1.0147e+10 </td><td> 10170000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> kf_e </td><td>  1.5502e+08 </td><td> 200000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> kf_i </td><td>  0.00151587 </td><td> 50000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> gamma </td><td>  1902.55013 </td><td> 1000 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> g </td><td>  92123404.5 </td><td> 103000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> a0 </td><td>  46.6827273 </td><td> 50 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> a1 </td><td>  0.00000000 </td><td> 0 </td><td>        -inf </td><td>         inf </td><td> False </td></tr><tr><td> Poff </td><td>  1.20142165 </td><td> 1.5 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> ed </td><td> -6.1643e-10 </td><td> -5e-10 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table>

# %%
f_hg = 10.268e9
f_lg = 10.147e9
f_he = 10.263e9
f_le = 10.147e9

chi_l = (f_le - f_lg)/2
chi_h = (f_he - f_hg)/2
chi = (chi_h+chi_l)/2
chi
# Out:
# -1250000.0

# %%
ge_freq = 8.02-0.00233#7.42
anharmonicity = -318e-3-0.00081

readout_freq = 10.297
qubit_lo_freq = 7.85
readout_lo_freq = 10.4 

2 * qubit_lo_freq - readout_lo_freq , 2 * ge_freq + anharmonicity - readout_freq
# Out:
# (5.299999999999999, 5.419529999999998)

# %%
readout_freq = 10.306
readout_lo_freq = 10.423  # 10.387
readout_if_freq = readout_lo_freq - readout_freq
JPA_if_freq = readout_freq * 2 - readout_lo_freq * 2

qubit_lo_freq = 7.85
ge_freq = 8.03+0.005106#8.02-0.00233#7.42
anharmonicity = -318e-3-0.00081-0.00056
ge_if_freq = ge_freq-qubit_lo_freq

fogi_lo_freq = 2 * qubit_lo_freq - readout_lo_freq 
fogi_reset_freq = 5.485
fogi_if_freq = -(fogi_reset_freq - fogi_lo_freq) 
                 
fogi_lo_freq, fogi_if_freq, 2 * ge_freq + anharmonicity - readout_freq
# Out:
# (5.276999999999999, -0.20800000000000107, 5.4448419999999995)

# %%
2 * ge_freq + anharmonicity - 5.4, 2 * ge_freq + anharmonicity - 5.3
# Out:
# (10.350841999999998, 10.450841999999998)

# %%
2 * ge_freq + anharmonicity - 10.26, 2 * ge_freq + anharmonicity - 10.34
# Out:
# (5.490841999999999, 5.410841999999999)

# %%
2 * ge_freq + anharmonicity - 10.299
# Out:
# 5.451841999999999

# %%
readout_lo_freq - 10.299
# Out:
# 0.12400000000000055

# %% [markdown]
# ## 11/26 ef calibration - DPR1-L-120-44

# %% [markdown]
# ef_freq =
#
# ef_pi_amp = 0.875
#
#
# T1 = 18.85e-06
#
# T2 = 11.69e-06
#
# T2_star = 7.631e-06

# %%
from plottr.data.datadict_storage import datadict_from_hdf5
import numpy as np
import matplotlib.pyplot as plt
import lmfit

# %%
import sklearn
from sklearn.decomposition import PCA

# %%
def Rabi(delay, amp, phi0, detun, const):
    return - amp * np.cos(2*np.pi*detun*delay+phi0) + const

# %% [markdown]
# amp

# %%
header = "D:/K_sunada/result/CDY152/"
ef = "/2023-12-03/2023-12-03T230301_ac0806f6-30_ef_pi_amp"
dd_ef = datadict_from_hdf5(header + ef +"/data")

# %%
def PCA_transform(Re_c, Im_c):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c]).T, np.array([Im_c]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    return c_PCA1, c_PCA2

# %%
Rabi_ef = dd_ef['s11']['values']
#imag_ge = Rabi_ge.imag
amp_ef = dd_ef['amplitude']['values']

I = (Rabi_ef.real)
Q = (Rabi_ef.imag)

PCAef = PCA_transform(I, Q)

# %%
y = PCAef[0]
x = amp_ef

plt.plot(x, y)
plt.show()

# %%
par_ini = {
    'amp': 5,
    'phi0':np.pi,
    'detun':1/0.38,
    'const':0
}

par_min = {
    'amp': 0,
    'phi0':-2*np.pi,
    'detun':-np.inf,
    'const':-np.inf
}

par_max = {
    'amp': np.inf,
    'phi0':2*np.pi,
    'detun':np.inf,
    'const':np.inf,
}

par_vary = {
    'amp': True,
    'phi0':True,
    'detun':True,
    'const':True
}

# %%
model = lmfit.Model(Rabi)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )

# %%
result_ef = model.fit(data = y, params = params, delay = x)
result_ef
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>57</td><td></td></tr><tr><td># data points</td><td>151</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 245.069701</td><td></td></tr><tr><td>reduced chi-square</td><td> 1.66714082</td><td></td></tr><tr><td>Akaike info crit.</td><td> 81.1236870</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 93.1928063</td><td></td></tr><tr><td>R-squared</td><td> 0.84712524</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  4.26116125 </td><td>  0.14955526 </td><td> (3.51%) </td><td> 5 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  3.49279699 </td><td>  0.06852538 </td><td> (1.96%) </td><td> 3.141592653589793 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  2.95179996 </td><td>  0.01262703 </td><td> (0.43%) </td><td> 2.6315789473684212 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  0.03737180 </td><td>  0.10560154 </td><td> (282.57%) </td><td> 0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>-0.8607</td></tr></table>

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi")


plt.rcParams["font.size"] = 14
plt.tick_params(
            top='on',
            bottom='on`',
            left='on',
            right='on',
            )
result_ef.plot_fit(ax = ax)
# plt.plot(amp_ef,result_ef.init_fit)

ax.tick_params(axis="x", direction="in")
ax.tick_params(axis="y", direction="in")
ax.set_xlabel("Amplitude (V)", size='large')
ax.set_ylabel("PCA[S11](Arb. unit.)", size='large')


plt.show()

# %%
np.pi/(2.95179996	*2*np.pi)*5
# Out:
# 0.8469408611280015

# %% [markdown]
# ramsey

# %%
pl = "/2023-11-26/2023-11-26T213544_51971882-32_ef_T2r1d"
mi = "/2023-11-26/2023-11-26T213908_cafac3dc-32_ef_T2r1d"
dd_pl = datadict_from_hdf5(header + pl +"/data")
dd_mi = datadict_from_hdf5(header + mi +"/data")

# %%
Rabi_pl = dd_pl['s11']['values']
imag_pl = Rabi_pl.imag
delay_pl = dd_pl['delay']['values']

Rabi_mi = dd_mi['s11']['values']
imag_mi = Rabi_mi.imag
delay_mi = dd_mi['delay']['values']

# %%
def PCA_transform(Re_c, Im_c):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c]).T, np.array([Im_c]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    return c_PCA1, c_PCA2


I_pl = (Rabi_pl.real)
Q_pl = (Rabi_pl.imag)
I_mi = (Rabi_mi.real)
Q_mi = (Rabi_mi.imag)


PCA_pl = PCA_transform(I_pl, Q_pl)
y_pl = PCA_pl[0]
x_pl = delay_pl

PCA_mi = PCA_transform(I_mi, Q_mi)
y_mi = PCA_mi[0]
x_mi = delay_mi



plt.plot(x_pl, y_pl)
plt.show()

# %%
par_ini_pl = {
    'amp': 4,
    'phi0':-np.pi/2,
    'detun':1/210,
    'const':0
}

par_min_pl = {
    'amp': 0,
    'phi0':-2*np.pi,
    'detun':-np.inf,
    'const':0
}

par_max_pl = {
    'amp': np.inf,
    'phi0':2*np.pi,
    'detun':np.inf,
    'const':np.inf,
}

par_vary_pl = {
    'amp': True,
    'phi0':True,
    'detun':True,
    'const':True
}

# %%
model = lmfit.Model(Rabi)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini_pl[name],
    min = par_min_pl[name],
    max = par_max_pl[name],
    vary = par_vary_pl[name]
    )
    
result_pl = model.fit(data = y_pl, params = params, delay = x_pl)
result_pl
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>116</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 16.6938523</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.17210157</td><td></td></tr><tr><td>Akaike info crit.</td><td>-173.808079</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-163.347597</td><td></td></tr><tr><td>R-squared</td><td> 0.97237311</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  3.41869973 </td><td>  0.05853964 </td><td> (1.71%) </td><td> 4 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td> -1.86221403 </td><td>  0.03325516 </td><td> (1.79%) </td><td> -1.5707963267948966 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  0.00442835 </td><td>  9.3666e-06 </td><td> (0.21%) </td><td> 0.004761904761904762 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  0.21146521 </td><td>  0.04148962 </td><td> (19.62%) </td><td> 0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>-0.8572</td></tr></table>

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(+5MHz)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result_pl.plot_fit(ax = ax)
plt.plot(x_pl,result_pl.init_fit)

plt.xlabel("delay (ns)")
plt.ylabel("mag[S11](a.u.)")


plt.show()

# %%
plt.plot(x_mi, y_mi)
plt.show()

# %%
par_ini_mi = {
    'amp': 3,
    'phi0':np.pi/2,
    'detun':1/200,
    'const':0
}

par_min_mi = {
    'amp': 0,
    'phi0':-2*np.pi,
    'detun':-np.inf,
    'const':0
}

par_max_mi = {
    'amp': np.inf,
    'phi0':2*np.pi,
    'detun':np.inf,
    'const':np.inf,
}

par_vary_mi = {
    'amp': True,
    'phi0':True,
    'detun':True,
    'const':True
}

# %%
model = lmfit.Model(Rabi)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini_mi[name],
    min = par_min_mi[name],
    max = par_max_mi[name],
    vary = par_vary_mi[name]
    )
    
result_mi = model.fit(data = y_mi, params = params, delay = x_mi)
result_mi
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>149</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 22.4518950</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.23146284</td><td></td></tr><tr><td>Akaike info crit.</td><td>-143.878295</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-133.417813</td><td></td></tr><tr><td>R-squared</td><td> 0.96041037</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  3.30480703 </td><td>  0.06832861 </td><td> (2.07%) </td><td> 3 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  1.02825308 </td><td>  0.03961982 </td><td> (3.85%) </td><td> 1.5707963267948966 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  0.00554829 </td><td>  1.0985e-05 </td><td> (0.20%) </td><td> 0.005 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  8.4951e-10 </td><td>  0.04839019 </td><td> (5696248464.95%) </td><td> 0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>-0.8577</td></tr></table>

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(-5MHz)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result_mi.plot_fit(ax = ax)
plt.plot(x_mi,result_pl.init_fit)

plt.xlabel("delay (ns)")
plt.ylabel("mag[S11](a.u.)")


plt.show()

# %%
detun = ((0.005-0.00442835)+ (0.00554829-0.005))/2 #GHz
detun
# Out:
# 0.0005599699999999999

# %% [markdown]
# drag

# %%
drag = "/2023-11-26/2023-11-26T214518_a7c72b8e-31_ef_pi_drag"
dd_drag = datadict_from_hdf5(header + drag +"/data")

drag1 = "/2023-11-26/2023-11-26T214409_7e3a6e29-31_ef_pi_drag"
dd_drag1 = datadict_from_hdf5(header + drag1 +"/data")

drag2 = "/2023-11-26/2023-11-26T214632_d3a6779d-31_ef_pi_drag"
dd_drag2 = datadict_from_hdf5(header + drag2 +"/data")

# %%
Rabi_drag = dd_drag['s11']['values']
imag_drag = Rabi_drag.imag
drag = dd_drag['beta']['values']
I_drag = (Rabi_drag.real)
Q_drag = (Rabi_drag.imag)

Rabi_drag1 = dd_drag1['s11']['values']
imag_drag1 = Rabi_drag1.imag
drag1 = dd_drag1['beta']['values']
I_drag1 = (Rabi_drag1.real)
Q_drag1 = (Rabi_drag1.imag)

Rabi_drag2 = dd_drag2['s11']['values']
imag_drag2 = Rabi_drag2.imag
drag2 = dd_drag2['beta']['values']
I_drag2 = (Rabi_drag2.real)
Q_drag2 = (Rabi_drag2.imag)

# %%
def PCA_transform1(Re_c_amp, Im_c_amp, Re_c_drag, Im_c_drag):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c_amp]).T, np.array([Im_c_amp]).T], axis = 1)
    c1_data = np.concatenate([np.array([Re_c_drag]).T, np.array([Im_c_drag]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    
    c1_pca = pca.transform(c1_data)
    c1_PCA1 = c1_pca.T[0]
    c1_PCA2 = c1_pca.T[1]
    return c_PCA1, c_PCA2, c1_PCA1, c1_PCA2,

# %%
PCA_drag = PCA_transform1(I, Q, I_drag, Q_drag)
y = PCA_drag[0]
x = amp_ef
y0 = PCA_drag[2]
x0 = drag

PCA_drag1 = PCA_transform1(I, Q, I_drag1, Q_drag1)
y1 = PCA_drag1[2]
x1 = drag1

PCA_drag2 = PCA_transform1(I, Q, I_drag2, Q_drag2)
y2 = PCA_drag2[2]
x2 = drag2


plt.plot(x, y)
plt.show()

# %%
plt.plot(x0, y0)
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.show()

# %%
par_ini= {
    'amp': 0.00006,
    'phi0':0,
    'detun':1/0.5,
    'const':-2.746-0.00052
}

par_min = {
    'amp': 0,
    'phi0':-2*np.pi,
    'detun':0,
    'const':-np.inf
}

par_max = {
    'amp': np.inf,
    'phi0':2*np.pi,
    'detun':np.inf,
    'const':np.inf,
}

par_vary = {
    'amp': True,
    'phi0':True,
    'detun':True,
    'const':True
}

# %%
model = lmfit.Model(Rabi)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )
    
result0 = model.fit(data = y0, params = params, delay = x0)
result1 = model.fit(data = y1, params = params, delay = x1)
result2 = model.fit(data = y2, params = params, delay = x2)

# %%
result0
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>26</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 5.2229e-09</td><td></td></tr><tr><td>reduced chi-square</td><td> 5.3844e-11</td><td></td></tr><tr><td>Akaike info crit.</td><td>-2384.21946</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-2373.75898</td><td></td></tr><tr><td>R-squared</td><td> 0.96305619</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  5.2390e-05 </td><td>  1.0441e-06 </td><td> (1.99%) </td><td> 6e-05 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  0.72352483 </td><td>  0.01977358 </td><td> (2.73%) </td><td> 0 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  0.88670577 </td><td>  0.00358579 </td><td> (0.40%) </td><td> 1.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td> -2.74651916 </td><td>  7.4495e-07 </td><td> (0.00%) </td><td> -2.74652 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>detun</td><td>const</td><td>-0.1381</td></tr><tr><td>amp</td><td>const</td><td>+0.1110</td></tr></table>

# %%
res0 = (-np.pi-0.72352483)/(2*np.pi*0.88670577)
res0
# Out:
# -0.6937504795353066

# %%
result1
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>41</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 4.6093e-09</td><td></td></tr><tr><td>reduced chi-square</td><td> 4.7519e-11</td><td></td></tr><tr><td>Akaike info crit.</td><td>-2396.84068</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-2386.38020</td><td></td></tr><tr><td>R-squared</td><td> 0.96819137</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  5.1790e-05 </td><td>  9.5341e-07 </td><td> (1.84%) </td><td> 6e-05 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  1.84962720 </td><td>  0.01915295 </td><td> (1.04%) </td><td> 0 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  1.23756711 </td><td>  0.00361402 </td><td> (0.29%) </td><td> 1.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td> -2.74651861 </td><td>  6.8929e-07 </td><td> (0.00%) </td><td> -2.74652 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table>

# %%
res1 = (-np.pi-1.84962720	)/(2*np.pi*1.23756711)
res1
# Out:
# -0.6418862503199699

# %%
result2
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>26</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 3.0137e-09</td><td></td></tr><tr><td>reduced chi-square</td><td> 3.1069e-11</td><td></td></tr><tr><td>Akaike info crit.</td><td>-2439.75843</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-2429.29795</td><td></td></tr><tr><td>R-squared</td><td> 0.97846911</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  5.1983e-05 </td><td>  7.8305e-07 </td><td> (1.51%) </td><td> 6e-05 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td> -0.91490205 </td><td>  0.01513405 </td><td> (1.65%) </td><td> 0 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  1.95037835 </td><td>  0.00277128 </td><td> (0.14%) </td><td> 2.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td> -2.74651576 </td><td>  5.5654e-07 </td><td> (0.00%) </td><td> -2.74652 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table>

# %%
res2 = (-3*np.pi-(-0.91490205))/(2*np.pi*1.95037835)
res2
# Out:
# -0.6944236313418838

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(drag)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result0.plot_fit(ax = ax)
plt.plot(x0,result0.init_fit)

plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(drag)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result1.plot_fit(ax = ax)
plt.plot(x1,result1.init_fit)


plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(drag)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result2.plot_fit(ax = ax)

plt.plot(x2,result2.init_fit)


plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
beta = (res0 + res1 + res2)/3
beta
# Out:
# -0.6766867870657202

# %% [markdown]
# half drag

# %%
drag = "/2023-11-26/2023-11-26T214934_3fc71d3f-31_ef_pi_drag"
dd_drag = datadict_from_hdf5(header + drag +"/data")

drag1 = "/2023-11-26/2023-11-26T215619_316d4485-31_ef_pi_drag"
dd_drag1 = datadict_from_hdf5(header + drag1 +"/data")

drag2 = "/2023-11-26/2023-11-26T215728_5a7ce813-31_ef_pi_drag"
dd_drag2 = datadict_from_hdf5(header + drag2 +"/data")

# %%
Rabi_drag = dd_drag['s11']['values']
imag_drag = Rabi_drag.imag
drag = dd_drag['beta']['values']
I_drag = (Rabi_drag.real)
Q_drag = (Rabi_drag.imag)

Rabi_drag1 = dd_drag1['s11']['values']
imag_drag1 = Rabi_drag1.imag
drag1 = dd_drag1['beta']['values']
I_drag1 = (Rabi_drag1.real)
Q_drag1 = (Rabi_drag1.imag)

Rabi_drag2 = dd_drag2['s11']['values']
imag_drag2 = Rabi_drag2.imag
drag2 = dd_drag2['beta']['values']
I_drag2 = (Rabi_drag2.real)
Q_drag2 = (Rabi_drag2.imag)

# %%
def PCA_transform1(Re_c_amp, Im_c_amp, Re_c_drag, Im_c_drag):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c_amp]).T, np.array([Im_c_amp]).T], axis = 1)
    c1_data = np.concatenate([np.array([Re_c_drag]).T, np.array([Im_c_drag]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    
    c1_pca = pca.transform(c1_data)
    c1_PCA1 = c1_pca.T[0]
    c1_PCA2 = c1_pca.T[1]
    return c_PCA1, c_PCA2, c1_PCA1, c1_PCA2,

# %%
PCA_drag = PCA_transform1(I, Q, I_drag, Q_drag)
y = PCA_drag[0]
x = amp_ef
y0 = PCA_drag[2]
x0 = drag

PCA_drag1 = PCA_transform1(I, Q, I_drag1, Q_drag1)
y1 = PCA_drag1[2]
x1 = drag1

PCA_drag2 = PCA_transform1(I, Q, I_drag2, Q_drag2)
y2 = PCA_drag2[2]
x2 = drag2


plt.plot(x, y)
plt.show()

# %%
plt.plot(x0, y0)
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.show()

# %%
par_ini= {
    'amp': 3e-5,
    'phi0':np.pi,
    'detun':1/0.7,
    'const':-2.746-49e-5
}

par_min = {
    'amp': 0,
    'phi0':-2*np.pi,
    'detun':-np.inf,
    'const':-np.pi
}

par_max = {
    'amp': np.inf,
    'phi0':2*np.pi,
    'detun':np.inf,
    'const':np.inf,
}

par_vary = {
    'amp': True,
    'phi0':True,
    'detun':True,
    'const':True
}

# %%
model = lmfit.Model(Rabi)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )
    
result0 = model.fit(data = y0, params = params, delay = x0)
result1 = model.fit(data = y1, params = params, delay = x1)
result2 = model.fit(data = y2, params = params, delay = x2)

# %%
result0
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>26</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 3.9569e-09</td><td></td></tr><tr><td>reduced chi-square</td><td> 4.0793e-11</td><td></td></tr><tr><td>Akaike info crit.</td><td>-2412.25554</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-2401.79506</td><td></td></tr><tr><td>R-squared</td><td> 0.88299996</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  2.3773e-05 </td><td>  8.8027e-07 </td><td> (3.70%) </td><td> 3e-05 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  3.21110230 </td><td>  0.03918249 </td><td> (1.22%) </td><td> 3.141592653589793 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  0.75038662 </td><td>  0.00788071 </td><td> (1.05%) </td><td> 0.8333333333333334 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td> -2.74649055 </td><td>  6.5783e-07 </td><td> (0.00%) </td><td> -2.74649 </td><td> -3.14159265 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>detun</td><td>const</td><td>-0.2158</td></tr><tr><td>amp</td><td>const</td><td>-0.1542</td></tr></table>

# %%
res0 = (np.pi-3.21110230)/(2*np.pi*0.75038662)
res0
# Out:
# -0.014742805273839

# %%
result1
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>26</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 3.8832e-09</td><td></td></tr><tr><td>reduced chi-square</td><td> 4.0034e-11</td><td></td></tr><tr><td>Akaike info crit.</td><td>-2414.15311</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-2403.69263</td><td></td></tr><tr><td>R-squared</td><td> 0.90251192</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  2.6597e-05 </td><td>  8.9132e-07 </td><td> (3.35%) </td><td> 3e-05 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  3.20012216 </td><td>  0.03358742 </td><td> (1.05%) </td><td> 3.141592653589793 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  0.99653359 </td><td>  0.00645306 </td><td> (0.65%) </td><td> 0.8333333333333334 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td> -2.74649031 </td><td>  6.5221e-07 </td><td> (0.00%) </td><td> -2.74649 </td><td> -3.14159265 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>detun</td><td>const</td><td>+0.2610</td></tr></table>

# %%
res1 = (np.pi-3.20012216)/(2*np.pi*0.99653359)
res1
# Out:
# -0.009347663094741415

# %%
result2
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>26</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 5.8801e-09</td><td></td></tr><tr><td>reduced chi-square</td><td> 6.0619e-11</td><td></td></tr><tr><td>Akaike info crit.</td><td>-2372.24862</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-2361.78814</td><td></td></tr><tr><td>R-squared</td><td> 0.83881453</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  2.4517e-05 </td><td>  1.0935e-06 </td><td> (4.46%) </td><td> 3e-05 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  3.25327444 </td><td>  0.04487665 </td><td> (1.38%) </td><td> 3.141592653589793 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  1.33131393 </td><td>  0.00844817 </td><td> (0.63%) </td><td> 1.4285714285714286 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td> -2.74648943 </td><td>  7.8959e-07 </td><td> (0.00%) </td><td> -2.74649 </td><td> -3.14159265 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>detun</td><td>const</td><td>-0.1928</td></tr></table>

# %%
res2 = (1*np.pi-3.25327444)/(2*np.pi*1.33131393)
res2
# Out:
# -0.0133512524431542

# %%
(res0+res1+res2)/3
# Out:
# -0.012480573603911539

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(drag)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result0.plot_fit(ax = ax)
plt.plot(x0,result0.init_fit)


plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(drag)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result1.plot_fit(ax = ax)
plt.plot(x1,result1.init_fit)


plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(drag)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result2.plot_fit(ax = ax)

plt.plot(x2,result2.init_fit)


plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %% [markdown]
# T1

# %%
def Dephase(delay, amp, gamma, const):
    return amp*np.exp(-gamma*delay) + const

t1 ="/2023-11-26/2023-11-26T221037_311e94a2-33_ef_T1"

dd_t1 = datadict_from_hdf5(header + t1 +"/data")

# %%
s11_t1 = dd_t1['s11']['values'][0:99]
imag_t1 = s11_t1.imag
delay_t1 = dd_t1['delay']['values'][0:99]

I_t1 = (s11_t1.real)
Q_t1 = (s11_t1.imag)

PCA_t1 = PCA_transform(I_t1, Q_t1)

y_t1 = PCA_t1[0]
x_t1 = delay_t1

plt.plot(x_t1, y_t1)
plt.show()

# %%
par_ini_t1 = {
    'gamma': 1/20000,
    'amp':20,
    'const':-5
}

par_min_t1 = {
    'gamma': 0,
    'amp':0,
    'const':-np.inf
}

par_max_t1 = {
    'gamma': np.inf,
    'amp':np.inf,
    'const':np.inf,
}

par_vary_t1 = {
    'gamma': True,
    'amp':True,
    'const':True
}

# %%
model = lmfit.Model(Dephase)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini_t1[name],
    min = par_min_t1[name],
    max = par_max_t1[name],
    vary = par_vary_t1[name]
    )
result_t1 = model.fit(data = y_t1, params = params, delay = x_t1)
result_t1
# Out:
# <h2> Model</h2> Model(Dephase) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>17</td><td></td></tr><tr><td># data points</td><td>99</td><td></td></tr><tr><td># variables</td><td>3</td><td></td></tr><tr><td>chi-square</td><td> 35.6400711</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.37125074</td><td></td></tr><tr><td>Akaike info crit.</td><td>-95.1432760</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-87.3579165</td><td></td></tr><tr><td>R-squared</td><td> 0.96455655</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  12.5188040 </td><td>  0.26755849 </td><td> (2.14%) </td><td> 20 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> gamma </td><td>  5.3063e-05 </td><td>  2.4259e-06 </td><td> (4.57%) </td><td> 5e-05 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td> -2.43405662 </td><td>  0.11458994 </td><td> (4.71%) </td><td> -5 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>gamma</td><td>const</td><td>+0.7360</td></tr><tr><td>amp</td><td>gamma</td><td>+0.4025</td></tr></table>

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("T1")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result_t1.plot_fit(ax = ax)
plt.plot(delay_t1,result_t1.init_fit)

plt.xlabel("delay (ns)")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
T1 = (1/5.3063e-05)*1e-9	
T1
# Out:
# 1.8845523245952927e-05

# %% [markdown]
# T2

# %%
t2e = "/2023-11-26/2023-11-26T223429_86615b83-34_ef_T2e"
dd_t2e = datadict_from_hdf5(header + t2e +"/data")

# %%
s11_t2e = dd_t2e['s11']['values']
imag_t2e = s11_t2e.imag
delay_t2e = dd_t2e['delay']['values']

I_t2e = (s11_t2e.real)
Q_t2e = (s11_t2e.imag)

PCA_t2e = PCA_transform(I_t2e, Q_t2e)

y_t2e = PCA_t2e[0]
x_t2e = delay_t2e

plt.plot(x_t2e, y_t2e)
plt.show()

# %%
par_ini_t2e = {
    'gamma': 1/2000,
    'amp':8,
    'const':0
}

par_min_t2e = {
    'gamma': 0,
    'amp':0,
    'const':-np.inf
}

par_max_t2e = {
    'gamma': np.inf,
    'amp':np.inf,
    'const':np.inf,
}

par_vary_t2e = {
    'gamma': True,
    'amp':True,
    'const':True
}

# %%
model = lmfit.Model(Dephase)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini_t2e[name],
    min = par_min_t2e[name],
    max = par_max_t2e[name],
    vary = par_vary_t2e[name]
    )
result_t2e = model.fit(data = y_t2e, params = params, delay = x_t2e)
result_t2e
# Out:
# <h2> Model</h2> Model(Dephase) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>38</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>3</td><td></td></tr><tr><td>chi-square</td><td> 25.2661024</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.25781737</td><td></td></tr><tr><td>Akaike info crit.</td><td>-133.951341</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-126.105980</td><td></td></tr><tr><td>R-squared</td><td> 0.95189994</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  8.51467587 </td><td>  0.19351054 </td><td> (2.27%) </td><td> 8 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> gamma </td><td>  8.5514e-05 </td><td>  5.5303e-06 </td><td> (6.47%) </td><td> 0.0005 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td> -2.42779581 </td><td>  0.15376434 </td><td> (6.33%) </td><td> 0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>gamma</td><td>const</td><td>+0.8738</td></tr><tr><td>amp</td><td>const</td><td>-0.3220</td></tr></table>

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("T2")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result_t2e.plot_fit(ax = ax)
plt.plot(delay_t2e,result_t2e.init_fit)

plt.xlabel("delay (ns)")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
T2 = (1/8.5514e-05)*1e-9	
T2
# Out:
# 1.1693991627101997e-05

# %% [markdown]
# T2 star

# %%
def Damping(delay, amp, gamma, omega, phi0, const):
    return const + amp * np.exp(- gamma*delay)*np.cos(omega*delay + phi0)

# %%
t2 = "/2023-11-26/2023-11-26T222007_84741dc8-32_ef_T2r1d"
dd_t2 = datadict_from_hdf5(header + t2 +"/data")

# %%
s11_t2 = dd_t2['s11']['values']
imag_t2 = s11_t2.imag
delay_t2 = dd_t2['delay']['values']

I_t2 = (s11_t2.real)
Q_t2 = (s11_t2.imag)

PCA_t2 = PCA_transform(I_t2, Q_t2)

y_t2 = PCA_t2[0]
x_t2 = delay_t2

plt.plot(x_t2, y_t2)
plt.show()

# %%
par_ini_t2 = {
    'amp':3,
    'gamma': 1/6000,
    'omega':2*np.pi/1000,
    'phi0':0,
    'const':0
}

par_min_t2 = {
    'amp':-np.inf,
    'gamma': 0,
    'omega':-2*np.pi,
    'phi0':-2*np.pi,
    'const':-np.inf
}

par_max_t2 = {
    'amp':np.inf,
    'gamma': np.inf,
    'omega':2*np.pi,
    'phi0':2*np.pi,
    'const':np.inf
}

par_vary_t2 = {
    'amp':True,
    'gamma': True,
    'omega':True,
    'phi0':True,
    'const':True
}

# %%
model = lmfit.Model(Damping)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini_t2[name],
    min = par_min_t2[name],
    max = par_max_t2[name],
    vary = par_vary_t2[name]
    )
result_t2 = model.fit(data = y_t2, params = params, delay = x_t2)
result_t2
# Out:
# <h2> Model</h2> Model(Damping) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>69</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>5</td><td></td></tr><tr><td>chi-square</td><td> 72.0146668</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.75015278</td><td></td></tr><tr><td>Akaike info crit.</td><td>-24.1633220</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-11.0877195</td><td></td></tr><tr><td>R-squared</td><td> 0.78892633</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td> -3.90079283 </td><td>  0.32623993 </td><td> (8.36%) </td><td> 3 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> gamma </td><td>  1.3105e-04 </td><td>  2.1330e-05 </td><td> (16.28%) </td><td> 0.00016666666666666666 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> omega </td><td>  0.00556060 </td><td>  2.0926e-05 </td><td> (0.38%) </td><td> 0.006283185307179587 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> phi0 </td><td>  0.57405705 </td><td>  0.08102002 </td><td> (14.11%) </td><td> 0 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> const </td><td> -0.02122945 </td><td>  0.08653256 </td><td> (407.61%) </td><td> 0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>amp</td><td>gamma</td><td>-0.7752</td></tr><tr><td>omega</td><td>phi0</td><td>-0.7661</td></tr></table>

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("T2star")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result_t2.plot_fit(ax = ax)
# plt.plot(delay_t2,result_t2.init_fit)

plt.xlabel("delay (ns)")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
T2_star = (1/1.3105e-04)*1e-9	
T2_star
# Out:
# 7.630675314765357e-06

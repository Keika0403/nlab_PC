# %%
from plottr.data.datadict_storage import datadict_from_hdf5
import numpy as np
import matplotlib.pyplot as plt
import lmfit

# %%
import sklearn
from sklearn.decomposition import PCA

# %%
header = "D:/K_sunada/result/CDY152/"
data = "/2023-11-27/2023-11-27T145002_cf167ff7-cw_JPA_current_vs_freq"
dd = datadict_from_hdf5(header + data +"/data")

# %%
def PCA_transform(Re_c, Im_c):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c]).T, np.array([Im_c]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    return c_PCA1, c_PCA2

# %%
x = np.unique(dd['current']['values'])
y = np.unique(dd['frequency']['values'])
z = dd['s11']['values']/dd['s11']['values'][-1]

# %%
cm = plt.cm.get_cmap('Blues')
fig= plt.figure()
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
ax = fig.add_axes((0.1, 0.1, 0.9, 0.9))
ax.set_xlabel("current (μA)")
ax.set_ylabel("frequency (GHz)")
ax.set_xlim(0, 190)

maingraph = ax.pcolormesh(x,y, np.angle(z).reshape(21, 401).T, vmin=min(np.unique(np.angle(z))), vmax=max(np.unique(np.angle(z))), cmap=cm, shading='auto')
plt.colorbar(maingraph)
plt.show()
# Out:
# C:\Users\qipe\AppData\Local\Temp\ipykernel_14888\957902420.py:1: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cm = plt.cm.get_cmap('Blues')

# %%
def S11_resonator(freq, fc, ke, ki, a0, a1, Poff, ed):
    numer = 1j*(freq-fc)+(ke-ki)/2
    denom = 1j*(freq-fc)-(ke+ki)/2
    model = (numer/denom * (a0+a1*(freq-freq[0])) * np.exp(1j*(-Poff-ed*2*np.pi*freq))).conj()
    return model

# %%
plt.plot(y, np.angle(z[0]))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\K_Sunada\analysis\CDY152(44)\CDY150-JPA.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/K_Sunada/analysis/CDY152%2844%29/CDY150-JPA.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> plt.plot(y, np.angle(z[0]))
#       <a href='vscode-notebook-cell:/d%3A/K_Sunada/analysis/CDY152%2844%29/CDY150-JPA.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> plt.show()
#
# NameError: name 'plt' is not defined

# %%
par_ini = {
    'fc':11,
    'ke':0.1,
    'ki':0.0002,
    'a0':1,
    'a1':1,
    'Poff':np.pi/2,
    'ed':0,
}

par_min = {
    'fc':0,
    'ke':0,
    'ki':0,
    'a0':0,
    'a1':- np.inf,
    'Poff':- np.pi,
    'ed':- np.inf,
}

par_max = {
    'fc':np.inf,
    'ke':np.inf,
    'ki':np.inf,
    'a0':np.inf,
    'a1':np.inf,
    'Poff':np.pi,
    'ed':np.inf,
}

par_vary = {
    'fc':True,
    'ke':True,
    'ki':True,
    'a0':True,
    'a1':True,
    'Poff':True,
    'ed':True,
}

# %%
model = lmfit.Model(S11_resonator)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )

# %%
s11 = z[0]
res = model.fit(data = s11, params = params, freq = y)

fig, ax = plt.subplots(1,2,figsize=(10,4))
ax[0].plot(y, np.abs(s11), '.', color='k')
ax[0].plot(y, np.abs(res.init_fit), '--', label='initial fit', color='orange')
ax[0].plot(y, np.abs(res.best_fit), '-', label='best fit', color='red')
ax[0].legend()
ax[1].plot(y, np.angle(s11), '.', color='k')
ax[1].plot(y, np.angle(res.init_fit), '--', label='initial fit', color='orange')
ax[1].plot(y, np.angle(res.best_fit), '-', label='best fit', color='red')
ax[1].legend()


plt.show()
res
# Out:
# <h2> Model</h2> Model(S11_resonator) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>76</td><td></td></tr><tr><td># data points</td><td>802</td><td></td></tr><tr><td># variables</td><td>7</td><td></td></tr><tr><td>chi-square</td><td> 13.1951939</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.01659773</td><td></td></tr><tr><td>Akaike info crit.</td><td>-3280.01926</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-3247.20950</td><td></td></tr><tr><td>R-squared</td><td>0.98101323-0.07240250j</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> fc </td><td>  10.8587744 </td><td>  0.00660970 </td><td> (0.06%) </td><td> 11 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> ke </td><td>  0.91182851 </td><td>  0.01180647 </td><td> (1.29%) </td><td> 0.1 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> ki </td><td>  0.00840853 </td><td>  0.01278423 </td><td> (152.04%) </td><td> 0.0002 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> a0 </td><td>  1.01468053 </td><td>  0.01286805 </td><td> (1.27%) </td><td> 1 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> a1 </td><td> -0.01208226 </td><td>  0.00701730 </td><td> (58.08%) </td><td> 1 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> Poff </td><td> -2.07025400 </td><td>  0.08729370 </td><td> (4.22%) </td><td> 1.5707963267948966 </td><td> -3.14159265 </td><td>  3.14159265 </td><td> True </td></tr><tr><td> ed </td><td>  0.03865989 </td><td>  0.00144258 </td><td> (3.73%) </td><td> 0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>Poff</td><td>ed</td><td>-0.9937</td></tr><tr><td>a0</td><td>a1</td><td>-0.7059</td></tr><tr><td>ke</td><td>Poff</td><td>+0.6403</td></tr><tr><td>fc</td><td>ed</td><td>-0.6201</td></tr><tr><td>ke</td><td>ed</td><td>-0.6112</td></tr><tr><td>ki</td><td>a1</td><td>+0.6064</td></tr><tr><td>fc</td><td>Poff</td><td>+0.5529</td></tr><tr><td>fc</td><td>ke</td><td>+0.2358</td></tr></table>

# %%
20*np.log10(1.4)
# Out:
# 2.92256071356476

# %%
cm = plt.cm.get_cmap('Blues')
fig= plt.figure()
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
ax = fig.add_axes((0.1, 0.1, 0.9, 0.9))
ax.set_xlabel("current (μA)")
ax.set_ylabel("frequency (GHz)")
ax.set_xlim(0, 190)
ax.set_ylim(8.0, 12.0)

maingraph = ax.pcolormesh(x,y, np.angle(z).reshape(21, 401).T, vmin=min(np.unique(np.angle(z))), vmax=max(np.unique(np.angle(z))), cmap=cm, shading='auto')
plt.colorbar(maingraph)

fc = [10.8587745, 10.8550501, 10.8456669, 10.8231799, 10.7864414, 10.7383513, 10.6816157, 10.6103386, 10.5260210, 10.4210533, 10.2930179, 10.1303700, 9.93985631, 9.71551017, 9.42214628, 9.07045478, 8.60424930, 7.96394895]
plt.plot(x[0:18], fc, '-o',color='red')

plt.show()
# Out:
# C:\Users\qipe\AppData\Local\Temp\ipykernel_920\3407574840.py:1: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cm = plt.cm.get_cmap('Blues')

# %%
data = "/2023-11-27/2023-11-27T161024_08bbc6b1-cw_JPA_gain_amp"
dd = datadict_from_hdf5(header + data +"/data")

# %%
s11 = dd["s11"]["values"]
freq =dd["frequency"]["values"]
Gain= 20 * np.log10(np.abs(s11))

# %%
plt.plot(freq, Gain)

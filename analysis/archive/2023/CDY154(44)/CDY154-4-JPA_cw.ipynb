# %%
from plottr.data.datadict_storage import datadict_from_hdf5
import numpy as np
import matplotlib.pyplot as plt
import lmfit

# %%
import sklearn
from sklearn.decomposition import PCA

# %%
header = "D:/K_sunada/result/CDY154/"
current = "/2024-01-16/2024-01-16T154639_00589de7-cw_JPA_current_vs_freq" 
dd = datadict_from_hdf5(header + current +"/data")

# %%
def PCA_transform(Re_c, Im_c):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c]).T, np.array([Im_c]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    return c_PCA1, c_PCA2

# %%
x = np.unique(dd['current']['values'])
y = np.unique(dd['frequency']['values'])
z = dd['s11']['values']/dd['s11']['values'][-1]

# %%
cm = plt.cm.get_cmap('magma')
fig= plt.figure()
plt.rcParams["font.size"] = 20
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
ax = fig.add_axes((0.1, 0.1, 0.9, 0.9))
ax.set_xlabel("Bias current (μA)")
ax.set_ylabel("frequency (GHz)")
ax.set_xlim(-200, 190)

maingraph = ax.pcolormesh(x,y, np.angle(z).reshape(41, 401).T, vmin=min(np.unique(np.angle(z))), vmax=max(np.unique(np.angle(z))), cmap=cm, shading='auto')
plt.colorbar(maingraph)
plt.show()
# Out:
# C:\Users\qipe\AppData\Local\Temp\ipykernel_3804\3490852084.py:1: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cm = plt.cm.get_cmap('magma')

# %%
def S11_resonator(freq, fc, ke, ki, a0, a1, Poff, ed):
    numer = 1j*(freq-fc)+(ke-ki)/2
    denom = 1j*(freq-fc)-(ke+ki)/2
    model = (numer/denom * (a0+a1*(freq-freq[0])) * np.exp(1j*(-Poff-ed*2*np.pi*freq))).conj()
    return model

# %%
plt.plot(y, np.angle(z[3]))
plt.show()

# %%
par_ini = {
    'fc':8.5,
    'ke':0.1,
    'ki':0.0002,
    'a0':0.96,
    'a1':0,
    'Poff':0.26,
    'ed':0,
}

par_min = {
    'fc':0,
    'ke':0,
    'ki':0,
    'a0':0,
    'a1':- np.inf,
    'Poff':- np.pi,
    'ed':- np.inf,
}

par_max = {
    'fc':np.inf,
    'ke':np.inf,
    'ki':np.inf,
    'a0':np.inf,
    'a1':np.inf,
    'Poff':np.pi,
    'ed':np.inf,
}

par_vary = {
    'fc':True,
    'ke':True,
    'ki':True,
    'a0':True,
    'a1':False,
    'Poff':True,
    'ed':True,
}

# %%
model = lmfit.Model(S11_resonator)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )

# %%
s11 = z[38]
res = model.fit(data = s11, params = params, freq = y)

fig, ax = plt.subplots(1,2,figsize=(10,4))
ax[0].plot(y, np.abs(s11), '.', color='k')
ax[0].plot(y, np.abs(res.init_fit), '--', label='initial fit', color='orange')
ax[0].plot(y, np.abs(res.best_fit), '-', label='best fit', color='red')
ax[0].legend()
ax[1].plot(y, np.angle(s11), '.', color='k')
ax[1].plot(y, np.angle(res.init_fit), '--', label='initial fit', color='orange')
ax[1].plot(y, np.angle(res.best_fit), '-', label='best fit', color='red')
ax[1].legend()


plt.show()
res
# Out:
# <h2> Model</h2> Model(S11_resonator) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>112</td><td></td></tr><tr><td># data points</td><td>802</td><td></td></tr><tr><td># variables</td><td>6</td><td></td></tr><tr><td>chi-square</td><td> 0.30894325</td><td></td></tr><tr><td>reduced chi-square</td><td> 3.8812e-04</td><td></td></tr><tr><td>Akaike info crit.</td><td>-6293.08845</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-6264.96579</td><td></td></tr><tr><td>R-squared</td><td>-3.0894e+14</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> fc </td><td>  8.48938022 </td><td>  7.4168e+08 </td><td> (8736605016.31%) </td><td> 8.5 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> ke </td><td>  1.0271e-07 </td><td>  2.05583217 </td><td> (2001600242.65%) </td><td> 0.1 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> ki </td><td>  24.7889604 </td><td>  2.5770e+09 </td><td> (10395590054.40%) </td><td> 0.0002 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> a0 </td><td>  1.00052731 </td><td>  0.01429208 </td><td> (1.43%) </td><td> 0.96 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> a1 </td><td>  0.00000000 </td><td>  0.00000000 </td><td>  </td><td> 0 </td><td>        -inf </td><td>         inf </td><td> False </td></tr><tr><td> Poff </td><td>  0.20854970 </td><td>  0.01795058 </td><td> (8.61%) </td><td> 0.26 </td><td> -3.14159265 </td><td>  3.14159265 </td><td> True </td></tr><tr><td> ed </td><td> -0.00302606 </td><td>  2.6495e-04 </td><td> (8.76%) </td><td> 0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>Poff</td><td>ed</td><td>-0.9818</td></tr><tr><td>ke</td><td>a0</td><td>+0.8497</td></tr><tr><td>a0</td><td>ed</td><td>-0.7744</td></tr><tr><td>a0</td><td>Poff</td><td>+0.7608</td></tr><tr><td>fc</td><td>Poff</td><td>+0.7455</td></tr><tr><td>fc</td><td>ed</td><td>-0.6210</td></tr><tr><td>fc</td><td>a0</td><td>+0.5921</td></tr><tr><td>ki</td><td>ed</td><td>+0.4804</td></tr><tr><td>ki</td><td>Poff</td><td>-0.4721</td></tr><tr><td>ke</td><td>ed</td><td>-0.4685</td></tr><tr><td>ke</td><td>Poff</td><td>+0.4512</td></tr><tr><td>ke</td><td>ki</td><td>+0.3804</td></tr><tr><td>fc</td><td>ki</td><td>-0.3748</td></tr><tr><td>fc</td><td>ke</td><td>+0.3196</td></tr><tr><td>ki</td><td>a0</td><td>-0.1577</td></tr></table>

# %%
fc = [9.11414078	, 9.45841026, 9.75758374, 9.98669081, 10.1731615
      10.3490280, 10.4872061, 10.5956749, 10.6865076, 10.7629173, 10.8263873, 10.8769442, 10.9144037, 10.9407206, 10.9559482,
      10.9601868, 10.9535854, 10.9351479	, 10.9062654, 10.8653392, 10.8134097, 10.7459835, 10.6664354, 10.5721377, 10.4582516,
      10.3121173, 10.1305671, 9.94197332, 9.68758389	, 9.39252421, 9.01614817, 8.55699688, ,]
# Out:
#   Cell In[13], line 1
#     fc = [9.11414078	, 9.45841026, 9.75758374, 9.98669081, 10.1731615
#                     	                                      ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
20*np.log10(7)
# Out:
# 16.901960800285135

# %%
cm = plt.cm.get_cmap('magma')
fig= plt.figure()
plt.rcParams["font.size"] = 20
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
ax = fig.add_axes((0.1, 0.1, 0.9, 0.9))
ax.set_xlabel("Bias current ($\mu$A)")
ax.set_ylabel("Probe frequency $\omega_\mathrm{p}/2\pi$ (GHz)")
ax.set_xlim(-190, 190)
ax.set_ylim(8.0, 12.0)

maingraph = ax.pcolormesh(x,y, np.angle(z).reshape(41, 401).T, vmin=min(np.unique(np.angle(z))), vmax=max(np.unique(np.angle(z))), cmap=cm, shading='auto')
plt.colorbar(maingraph, label="Phase[S$_{11}$] (arg)")
plt.tick_params(top='on',bottom='on',left='on',right='on')
fc = [9.11414078	, 9.45841026, 9.75758374, 9.98669081, 10.1731615,
      10.3490280, 10.4872061, 10.5956749, 10.6865076, 10.7629173, 10.8263873, 10.8769442, 10.9144037, 10.9407206, 10.9559482,
      10.9601868, 10.9535854, 10.9351479	, 10.9062654, 10.8653392, 10.8134097, 10.7459835, 10.6664354, 10.5721377, 10.4582516,
      10.3121173, 10.1305671, 9.94197332, 9.68758389	, 9.39252421, 9.01614817, 8.55699688]
plt.plot(x[5:37], fc, 'o',color='limegreen')
# plt.savefig('JPA_cw_current.png', bbox_inches='tight')
plt.show()
# Out:
# C:\Users\qipe\AppData\Local\Temp\ipykernel_7108\1044199382.py:1: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cm = plt.cm.get_cmap('magma')

# %%
data = "/2023-11-27/2023-11-27T161024_08bbc6b1-cw_JPA_gain_amp"
dd = datadict_from_hdf5(header + data +"/data")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 2
#       1 data = "/2023-11-27/2023-11-27T161024_08bbc6b1-cw_JPA_gain_amp"
# ----> 2 dd = datadict_from_hdf5(header + data +"/data")
#
# File d:\K_Sunada\.venv\lib\site-packages\plottr\data\datadict_storage.py:263, in datadict_from_hdf5(path, groupname, startidx, stopidx, structure_only, ignore_unequal_lengths, file_timeout)
#     261 filepath = _data_file_path(path)
#     262 if not filepath.exists():
# --> 263     raise ValueError("Specified file does not exist.")
#     265 if startidx is None:
#     266     startidx = 0
#
# ValueError: Specified file does not exist.

# %%
s11 = dd["s11"]["values"]
freq =dd["frequency"]["values"]
Gain= 20 * np.log10(np.abs(s11))

# %%
plt.plot(freq, Gain)

# %% [markdown]
# JPA calibration

# %%
pump ="/2024-01-17/2024-01-17T134131_afaad692-cw_JPA_gain_amp"
dd = datadict_from_hdf5(header + pump +"/data")

# %%
dd
# Out:
# s11: (21, 201)
#   ⌙ frequency (GHz): (21, 201)
#   ⌙ amplitude (V): (21,)
# s11_per_base: (21, 201)
#   ⌙ frequency (GHz): (21, 201)
#   ⌙ amplitude (V): (21,)

# %%
id = 14

fig, ax = plt.subplots(figsize=(12,6),constrained_layout=True)
plt.rcParams["font.size"] = 20
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
for id in range(5):
    id = id+10
    x = dd['frequency']['values'][id]
    y = dd['amplitude']['values'][id]
    z = 20 * np.log10(np.abs(dd['s11_per_base']['values'][id]))
    plt.plot(x*1e-9, z, 'o', label = r"${}$".format(np.round(y, 2)))
    print(np.max(z), y)

plt.title("")

legend = plt.legend(title_fontsize=18, fontsize=18, loc='upper right', bbox_to_anchor=(1.35, 1))
legend.set_title("Pump DAC amp. (V)")
ax.set_xlabel('Probe frequency $\omega_\mathrm{p}/2\pi$ (GHz)', size='large')
ax.set_ylabel('Gain G (dB)', size='large')
ax.set_xlim(10, 10.6)
# plt.savefig('JPA_cw_pump.png', bbox_inches='tight')
plt.show()

# plt.plot(np.linspace(10e9, 10.6e9, 1000), np.linspace(10.32, 10.32, 1000))
# Out:
# 10.031737051783761 0.35
# 11.564525216853154 0.375
# 13.320099412995162 0.4
# 15.634822592442752 0.42500000000000004
# 18.728836076763745 0.45000000000000007

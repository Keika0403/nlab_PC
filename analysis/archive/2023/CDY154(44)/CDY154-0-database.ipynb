# %% [markdown]
# ## cw

# %%
# resonator S11
res_dressed = "/2024-01-16/2024-01-16T134925_9fda35dc-cw_sparameter" # R.T.: -30dB, vna output: -10dB
res_bare = "/2024-01-16/2024-01-16T135757_d0b62944-cw_sparameter" # R.T.: -30dB, vna output: 20dB
punchout = "/2024-01-16/2024-01-16T135513_6f3516d4-cw_punchout" # R.T.: -30dB, vna output: -20 ~ 20dB

# twotone(redout: 10.26GHz)
three_peak = "/2024-01-16/2024-01-16T142353_70478330-cw_twotone" #drive: R.T.-40dB, lo power: -20~24dB, readout: R.T.: -30 dB, vna power: -10dB
ge_peak = "/2024-01-16/2024-01-16T142948_4396d51d-cw_twotone" #<ge>drive: R.T.-60dB, lo power: -20~10dB, readout: R.T.: -30 dB, vna power: -10dB
ef_peak = "/2024-01-16/2024-01-16T142701_e03c59ef-cw_twotone" #<ef>drive: R.T.-40dB, lo power: 0~24dB, readout: R.T.: -30 dB, vna power: -10dB

# ac Stark shift
     #drive: R.T.-60dB, lo power: -10dB, readout: R.T.: -30 dB, vna power: -10~-5dB
ac1033 = "/2024-01-16/2024-01-16T150049_98cef4e2-cw_attenuation"
ac1030 = "/2024-01-16/2024-01-16T150708_7ad4b6da-cw_attenuation" 
ac1028 = "/2024-01-16/2024-01-16T145005_1918ea27-cw_attenuation"
ac1026 = "/2024-01-16/2024-01-16T144317_25ff6022-cw_attenuation"
ac1022 = "/2024-01-16/2024-01-16T143945_a7e07411-cw_attenuation"

# JPA
currnt = "/2024-01-16/2024-01-16T154639_00589de7-cw_JPA_current_vs_freq" #LO 10.38
pump ="/2024-01-17/2024-01-17T134131_afaad692-cw_JPA_gain_amp"
#  "RFout1C - 10dB -ZVA213s+ -ZVA213s+ - 1000mm -  In3H",

# %% [markdown]
# ## td

# %% [markdown]
# qubit calibration

# %%
# ge
ge_pi = "/2024-01-16/2024-01-16T171239_038fc0f4-21_ge_pi_amp"
ge_ramsey = "/2024-01-16/2024-01-16T171412_3b3a44e2-23_ge_T2r1d" #+0.5MHz detuning
ge_drag0 = "/2024-01-16/2024-01-16T175211_89ee7351-22_ge_pi_drag" # n=5
ge_drag1 = "/2024-01-16/2024-01-16T175013_43343f69-22_ge_pi_drag" # n=11
ge_drag2 = "/2024-01-16/2024-01-16T174803_f58e2510-22_ge_pi_drag" # n=13
half_ge_drag0 = "/2024-01-16/2024-01-16T180749_b8e911b5-22_ge_pi_drag" #n = 11
half_ge_drag1 = "/2024-01-16/2024-01-16T180945_fe058ac9-22_ge_pi_drag" #n = 17
half_ge_drag2 = "/2024-01-16/2024-01-16T181149_47a2541d-22_ge_pi_drag" #n = 23
ge_T1 = "/2024-01-16/2024-01-16T181704_034d5df6-24_ge_T1"
ge_T2_ramsey = "/2024-01-16/2024-01-16T182327_e816a363-23_ge_T2r1d" #+0.1MHz detuning
ge_T2_echo = "/2024-01-16/2024-01-16T182159_b3650dea-25_ge_T2e"

# ef
ef_pi ="/2024-01-16/2024-01-16T190748_1a1469a5-30_ef_pi_amp"
ef_ramsey = "/2024-01-16/2024-01-16T191606_42aaa7c6-32_ef_T2r1d"#+0.5MHz detuning
ef_drag0 = "/2024-01-16/2024-01-16T220154_6c36a10e-31_ef_pi_drag" #n=5
ef_drag1 = "/2024-01-16/2024-01-16T220415_c037c2de-31_ef_pi_drag" #n=11
ef_drag2 = "/2024-01-16/2024-01-16T220635_13f67594-31_ef_pi_drag" #n=17
half_ef_drag0 = "/2024-01-16/2024-01-16T222649_e70937a4-31_ef_pi_drag" #n=27
half_ef_drag1 =  "/2024-01-16/2024-01-16T222208_3fe735ec-31_ef_pi_drag" #n=17
half_ef_drag2 = "/2024-01-16/2024-01-16T222405_856a6a00-31_ef_pi_drag" #n=23
ef_T1 = "/2024-01-16/2024-01-16T223549_291f1b40-33_ef_T1"

# freq optimize
chi = "/2024-01-16/2024-01-16T183015_dabc7948-26_freq_optimize"

# %% [markdown]
# photon generation

# %%
# ac Stark shift
ac = "/2024-01-17/2024-01-17T110647_11d49cb4-42_fogi_ac_Stark_shift"

# square photon generation
ph = "/2024-01-17/2024-01-17T143735_84bc5e10-70_JPA_photon_generation"

# %% [markdown]
# photon absorption on on-reso 12/14

# %%
#square
data_square="/2023-12-13/2023-12-13T223637_a391a785-731_JPA_ab_sq_waveform_qstate copy"
#time-reversed
data_tr="/2023-12-13/2023-12-13T191710_c71728ec-74_JPA_ab_tr_waveform_qstate"
#time-unreersed
data_utr="/2023-12-14/2023-12-14T093557_bf6254b4-74_JPA_ab_tr_waveform_qstate"

# %%
# JPA
vac_squeeze =  "/2024-01-04/2024-01-04T181314_7dab30b4-80_JPA_vac_squeeze"
ge_phase_opt = "/2024-01-04/2024-01-04T181740_1c41d195-81_JPA_phase_optimization_for_ge" # 0dB
ge_phase_opt1 = "/2024-01-05/2024-01-05T173118_cc8b219a-81_JPA_phase_optimization_for_ge" #10dB

readout_fidelity_thre ="/2024-01-04/2024-01-04T183951_3558e596-82_readout_fidelity_threshold"
readout_fidelity = "/2024-01-04/2024-01-04T184101_5f5d8f4b-83_readout_fidelity"

readout_fidelity_thre1 ="/2024-01-04/2024-01-04T184625_206936bd-82_readout_fidelity_threshold"
readout_fidelity1 = "/2024-01-04/2024-01-04T184802_5a3c360f-83_readout_fidelity"

readout_fidelity_thre2 ="/2024-01-04/2024-01-04T200911_afe8b102-82_readout_fidelity_threshold"
readout_fidelity2 = "/2024-01-04/2024-01-04T201103_f31c850f-83_readout_fidelity"

readout_fidelity_thre3 ="/2024-01-05/2024-01-05T173332_1c672042-82_readout_fidelity_threshold"
readout_fidelity3 = "/2024-01-05/2024-01-05T173436_427225ac-83_readout_fidelity"
QND_fidelity3 = "/2024-01-05/2024-01-05T161443_19507e86-84_QND_fidelity"

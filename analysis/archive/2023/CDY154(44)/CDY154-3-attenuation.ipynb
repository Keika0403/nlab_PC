# %%
from plottr.data.datadict_storage import datadict_from_hdf5
import numpy as np
import matplotlib.pyplot as plt
from lmfit.models import GaussianModel
import lmfit

# %%
import sklearn
from sklearn.decomposition import PCA

# %%
def PCA_transform(Re_c, Im_c):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c]).T, np.array([Im_c]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    return c_PCA1, c_PCA2

# %%
def Lorentzian(freq, amp, const, center, k):
    return const - amp*k/((freq-center)**2 + (k/2)**2)

# %%
def Gaussian(freq, amp, const, center, k):
    return const - amp*np.exp(-(freq-center)**2/(2*k**2))

# %%
header = "D:/K_sunada/result/CDY154/"
# ac1037 = "/2023-12-29/2023-12-29T173725_7e58e084-cw_attenuation"
ac1033 = "/2024-01-16/2024-01-16T150049_98cef4e2-cw_attenuation"
# ac1031 = "/2023-12-25/2023-12-25T162657_fc4e3f61-cw_attenuation"
ac1030 = "/2024-01-16/2024-01-16T150708_7ad4b6da-cw_attenuation" 
# ac1029 = "/2023-12-29/2023-12-29T171620_8c5c01d3-cw_attenuation"
ac1028 = "/2024-01-16/2024-01-16T145005_1918ea27-cw_attenuation"
ac1026 = "/2024-01-16/2024-01-16T144317_25ff6022-cw_attenuation"
ac1022 = "/2024-01-16/2024-01-16T143945_a7e07411-cw_attenuation"

# dd1037 = datadict_from_hdf5(header + ac1037+"/data")
dd1033 = datadict_from_hdf5(header + ac1033+"/data")
# dd1031 = datadict_from_hdf5(header + ac1031+"/data")
dd1030 = datadict_from_hdf5(header + ac1030+"/data")
# dd1029 = datadict_from_hdf5(header + ac1029 +"/data")
dd1028 = datadict_from_hdf5(header + ac1028 +"/data")
dd1026 = datadict_from_hdf5(header + ac1026 +"/data")
dd1022 = datadict_from_hdf5(header + ac1022+"/data")

# %% [markdown]
# 10.3 GHz

# %%
xs = []
ys = []
num_of_freq = 241

for i in range(21):
    ini = num_of_freq*i
    fin = num_of_freq*(1+i)-1
    x = dd1030['frequency']['values'][i]
    y_real = dd1030['s11']['values'][i].real
    y_imag = dd1030['s11']['values'][i].imag
    y_PCA = PCA_transform(y_real, y_imag)
    xs.append(x)
    ys.append(-y_PCA[0])

# %%
par_ini = {'amp': 0.00035,'const':0, 'center':7.96e9,'k':0.01e9}
par_min = {'amp': 0,'const':-np.inf,'center':0,'k':0}
par_max = {'amp': np.inf, 'const':np.inf,'center':np.inf,'k':np.inf}
par_vary = {'amp': True,'const':True, 'center':True,'k':True}
model = lmfit.Model(Gaussian)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )

results = []
for i in range(21):
    result = model.fit(data = ys[i], params=params, freq = xs[i])
    results.append(result)

# %%
fig, ax = plt.subplots(dpi=80)
id = 20
plt.rcParams["font.size"] = 10
ax.tick_params(axis="x", direction="in")
ax.tick_params(axis="y", direction="in")
plt.tick_params(
            top='on',
            bottom='on`',
            left='on',
            right='on',
            )

results[id].plot_fit(ax = ax)
# plt.plot(xs[0],results[0].init_fit)
ax.set_xlabel('F0g1 frequency (GHz)', size='large')
ax.set_ylabel('Re[S$_{11}$] (Arb. u.)', size='large')
plt.show()
results[id]
# Out:
# <h2> Model</h2> Model(Gaussian) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>63</td><td></td></tr><tr><td># data points</td><td>241</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 4.0668e-08</td><td></td></tr><tr><td>reduced chi-square</td><td> 1.7160e-10</td><td></td></tr><tr><td>Akaike info crit.</td><td>-5415.12939</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-5401.19020</td><td></td></tr><tr><td>R-squared</td><td> 0.97234015</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  2.2456e-04 </td><td>  2.6914e-06 </td><td> (1.20%) </td><td> 0.00035 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  5.2251e-05 </td><td>  1.1021e-06 </td><td> (2.11%) </td><td> 0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> center </td><td>  7.9289e+09 </td><td>  158825.091 </td><td> (0.00%) </td><td> 7960000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> k </td><td>  11808998.3 </td><td>  185832.066 </td><td> (1.57%) </td><td> 10000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>amp</td><td>k</td><td>-0.4046</td></tr><tr><td>const</td><td>k</td><td>+0.3695</td></tr><tr><td>amp</td><td>const</td><td>+0.3276</td></tr><tr><td>center</td><td>k</td><td>-0.1308</td></tr></table>

# %%
center1030_g = [7.9925e+09, 7.9910e+09, 7.9888e+09, 7.9862e+09, 7.9832e+09, 7.9815e+09,
                7.9800e+09, 7.9784e+09, 7.9747e+09, 7.9721e+09, 7.9693e+09, 7.9662e+09,
                7.9632e+09, 7.9596e+09, 7.9561e+09, 7.9524e+09, 7.9482e+09, 7.9442e+09,
                7.9395e+09, 7.9347e+09, 7.9289e+09]

# %% [markdown]
# 10.28 GHz

# %%
xs = []
ys = []
num_of_freq = 241

for i in range(21):
    ini = num_of_freq*i
    fin = num_of_freq*(1+i)-1
    x = dd1028['frequency']['values'][i]
    y_real = dd1028['s11']['values'][i].real
    y_imag = dd1028['s11']['values'][i].imag
    y_PCA = PCA_transform(y_real, y_imag)
    xs.append(x)
    ys.append(-y_PCA[0])

# %%
par_ini = {'amp': 0.00035,'const':0, 'center':7.99e9,'k':0.01e9}
par_min = {'amp': 0,'const':-np.inf,'center':0,'k':0}
par_max = {'amp': np.inf, 'const':np.inf,'center':np.inf,'k':np.inf}
par_vary = {'amp': True,'const':True, 'center':True,'k':True}
model = lmfit.Model(Gaussian)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )

results = []
for i in range(21):
    result = model.fit(data = ys[i], params=params, freq = xs[i])
    results.append(result)

# %%
fig, ax = plt.subplots(dpi=80)
id = 20
plt.rcParams["font.size"] = 10
ax.tick_params(axis="x", direction="in")
ax.tick_params(axis="y", direction="in")
plt.tick_params(
            top='on',
            bottom='on`',
            left='on',
            right='on',
            )

results[id].plot_fit(ax = ax)
# plt.plot(xs[0],results[0].init_fit)
ax.set_xlabel('F0g1 frequency (GHz)', size='large')
ax.set_ylabel('Re[S$_{11}$] (Arb. u.)', size='large')
plt.show()
results[id]
# Out:
# <h2> Model</h2> Model(Gaussian) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>73</td><td></td></tr><tr><td># data points</td><td>241</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 3.3068e-08</td><td></td></tr><tr><td>reduced chi-square</td><td> 1.3953e-10</td><td></td></tr><tr><td>Akaike info crit.</td><td>-5464.98749</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-5451.04830</td><td></td></tr><tr><td>R-squared</td><td> 0.96475264</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  2.0035e-04 </td><td>  2.7259e-06 </td><td> (1.36%) </td><td> 0.00035 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  3.5312e-05 </td><td>  9.6161e-07 </td><td> (2.72%) </td><td> 0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> center </td><td>  7.9639e+09 </td><td>  128911.389 </td><td> (0.00%) </td><td> 7990000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> k </td><td>  8473019.82 </td><td>  141158.411 </td><td> (1.67%) </td><td> 10000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>amp</td><td>k</td><td>-0.4090</td></tr><tr><td>const</td><td>k</td><td>+0.4074</td></tr><tr><td>amp</td><td>const</td><td>+0.2494</td></tr></table>

# %%
center1028_g = [8.0027e+09, 8.0016e+09, 8.0006e+09, 7.9993e+09, 7.9980e+09, 7.9947e+09,
                7.9946e+09, 7.9954e+09, 7.9926e+09, 7.9891e+09, 7.9872e+09, 7.9868e+09,
                7.9843e+09, 7.9818e+09, 7.9802e+09, 7.9779e+09, 7.9754e+09, 7.9727e+09,
                7.9697e+09, 7.9669e+09, 7.9639e+09]

# %% [markdown]
# 10.26 GHz

# %%
y = np.unique(dd1026['power']['values'])
x = np.unique(dd1026['frequency']['values'])
z = np.real(dd1026['s11']['values'])

# %%
center1026_g = [8.0110e+09, 8.0104e+09, 8.0097e+09, 8.0091e+09, 8.0084e+09, 8.0076e+09,
                8.0068e+09, 8.0060e+09, 8.0051e+09, 8.0040e+09, 8.0031e+09, 8.0020e+09,
                8.0009e+09, 7.9998e+09, 7.9985e+09, 7.9971e+09, 7.9957e+09, 7.9943e+09,
                7.9927e+09, 7.9910e+09, 7.9893e+09]

# %%
cm = plt.cm.get_cmap('magma')
fig= plt.figure()
plt.rcParams["font.size"] = 20
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'

ax = fig.add_axes((0.1, 0.1, 0.9, 0.9))
ax.set_ylabel("Probe power $P_{\mathrm{VNA}}$ (dBm)")
ax.set_xlabel("Drive frequency $\omega_\mathrm{d}/2\pi$ (GHz)")
ax.set_xlim(7.97, 8.02)
# ax.set_ylim(10, 10.6)

maingraph = ax.pcolormesh(x*1e-9,y, z.reshape(21, 181)*1e3, vmin=min(np.unique(z)*1e3), vmax=max(np.unique(z)*1e3), cmap=cm, shading='auto')
plt.colorbar(maingraph, label="Phase[S$_{11}$] (arb. u.)")
plt.tick_params(top='on',bottom='on',left='on',right='on')
plt.plot(np.array(center1026_g)*1e-9, y, 'o', color = 'limegreen')
# plt.savefig('ac_Stark.png', bbox_inches='tight')
plt.show()
# Out:
# C:\Users\qipe\AppData\Local\Temp\ipykernel_16948\138080072.py:1: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cm = plt.cm.get_cmap('magma')

# %%
xs = []
ys = []
num_of_freq = 181

for i in range(21):
    ini = num_of_freq*i
    fin = num_of_freq*(1+i)-1
    x = dd1026['frequency']['values'][i]
    y_real = dd1026['s11']['values'][i].real
    y_imag = dd1026['s11']['values'][i].imag
    y_PCA = PCA_transform(y_real, y_imag)
    xs.append(x)
    ys.append(-y_PCA[0])

# %%
par_ini = {'amp': 0.00035,'const':0, 'center':7.99e9,'k':0.01e9}
par_min = {'amp': 0,'const':-np.inf,'center':0,'k':0}
par_max = {'amp': np.inf, 'const':np.inf,'center':np.inf,'k':np.inf}
par_vary = {'amp': True,'const':True, 'center':True,'k':True}
model = lmfit.Model(Gaussian)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )

results = []
for i in range(21):
    result = model.fit(data = ys[i], params=params, freq = xs[i])
    results.append(result)

# %%
fig, ax = plt.subplots(dpi=80)
id = 20
plt.rcParams["font.size"] = 10
ax.tick_params(axis="x", direction="in")
ax.tick_params(axis="y", direction="in")
plt.tick_params(
            top='on',
            bottom='on`',
            left='on',
            right='on',
            )

results[id].plot_fit(ax = ax)
# plt.plot(xs[0],results[0].init_fit)
ax.set_xlabel('F0g1 frequency (GHz)', size='large')
ax.set_ylabel('Re[S$_{11}$] (Arb. u.)', size='large')
plt.show()
results[id]
# Out:
# <h2> Model</h2> Model(Gaussian) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>61</td><td></td></tr><tr><td># data points</td><td>181</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 2.7122e-08</td><td></td></tr><tr><td>reduced chi-square</td><td> 1.5323e-10</td><td></td></tr><tr><td>Akaike info crit.</td><td>-4086.47359</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-4073.67960</td><td></td></tr><tr><td>R-squared</td><td> 0.96251317</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  2.3524e-04 </td><td>  3.9727e-06 </td><td> (1.69%) </td><td> 0.00035 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  2.7765e-05 </td><td>  1.0627e-06 </td><td> (3.83%) </td><td> 0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> center </td><td>  7.9893e+09 </td><td>  81600.8747 </td><td> (0.00%) </td><td> 7990000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> k </td><td>  4261298.85 </td><td>  86019.4623 </td><td> (2.02%) </td><td> 10000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>amp</td><td>k</td><td>-0.4780</td></tr><tr><td>const</td><td>k</td><td>+0.3165</td></tr><tr><td>amp</td><td>const</td><td>+0.1892</td></tr></table>

# %%
center1026_g = [8.0110e+09, 8.0104e+09, 8.0097e+09, 8.0091e+09, 8.0084e+09, 8.0076e+09,
                8.0068e+09, 8.0060e+09, 8.0051e+09, 8.0040e+09, 8.0031e+09, 8.0020e+09,
                8.0009e+09, 7.9998e+09, 7.9985e+09, 7.9971e+09, 7.9957e+09, 7.9943e+09,
                7.9927e+09, 7.9910e+09, 7.9893e+09]

# %% [markdown]
# 10.22 GHz

# %%
xs = []
ys = []
num_of_freq = 101

for i in range(21):
    ini = num_of_freq*i
    fin = num_of_freq*(1+i)-1
    x = dd1022['frequency']['values'][i]
    y_real = dd1022['s11']['values'][i].real
    y_imag = dd1022['s11']['values'][i].imag
    y_PCA = PCA_transform(y_real, y_imag)
    xs.append(x)
    ys.append(-y_PCA[0])

# %%
par_ini = {'amp': 0.00035,'const':0, 'center':8.0e9,'k':0.01e9}
par_min = {'amp': 0,'const':-np.inf,'center':0,'k':0}
par_max = {'amp': np.inf, 'const':np.inf,'center':np.inf,'k':np.inf}
par_vary = {'amp': True,'const':True, 'center':True,'k':True}
model = lmfit.Model(Gaussian)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )
results = []
for i in range(21):
    result = model.fit(data = ys[i], params=params, freq = xs[i])
    results.append(result)

# %%
fig, ax = plt.subplots(dpi=80)
id = 20
plt.rcParams["font.size"] = 10
ax.tick_params(axis="x", direction="in")
ax.tick_params(axis="y", direction="in")
plt.tick_params(
            top='on',
            bottom='on`',
            left='on',
            right='on',
            )

results[id].plot_fit(ax = ax)
# plt.plot(xs[0],results[0].init_fit)
ax.set_xlabel('F0g1 frequency (GHz)', size='large')
ax.set_ylabel('Re[S$_{11}$] (Arb. u.)', size='large')
plt.show()
results[id]
# Out:
# <h2> Model</h2> Model(Gaussian) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>68</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 2.4012e-09</td><td></td></tr><tr><td>reduced chi-square</td><td> 2.4754e-11</td><td></td></tr><tr><td>Akaike info crit.</td><td>-2462.70594</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-2452.24545</td><td></td></tr><tr><td>R-squared</td><td> 0.97494393</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  1.2898e-04 </td><td>  2.4339e-06 </td><td> (1.89%) </td><td> 0.00035 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  1.1625e-05 </td><td>  5.5048e-07 </td><td> (4.74%) </td><td> 0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> center </td><td>  8.0071e+09 </td><td>  39062.6409 </td><td> (0.00%) </td><td> 8000000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> k </td><td>  1815790.05 </td><td>  40561.8812 </td><td> (2.23%) </td><td> 10000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>amp</td><td>k</td><td>-0.5057</td></tr><tr><td>const</td><td>k</td><td>+0.2702</td></tr><tr><td>amp</td><td>const</td><td>+0.1599</td></tr></table>

# %%
center1022_g = [8.0165e+09, 8.0163e+09, 8.0161e+09, 8.0158e+09, 8.0155e+09, 8.0152e+09,
                8.0147e+09, 8.0145e+09, 8.0140e+09, 8.0136e+09, 8.0132e+09, 8.0128e+09,
                8.0123e+09, 8.0117e+09, 8.0112e+09, 8.0106e+09, 8.0099e+09, 8.0093e+09, 
                8.0087e+09, 8.0078e+09, 8.0071e+09]

# %% [markdown]
# 10.31 GHz

# %%
xs = []
ys = []
num_of_freq = 241

for i in range(21):
    ini = num_of_freq*i
    fin = num_of_freq*(1+i)-1
    x = dd1031['frequency']['values'][i]
    y_real = dd1031['s11']['values'][i].real
    y_imag = dd1031['s11']['values'][i].imag
    y_PCA = PCA_transform(y_real, y_imag)
    xs.append(x)
    ys.append(-y_PCA[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 8
#       6 ini = num_of_freq*i
#       7 fin = num_of_freq*(1+i)-1
# ----> 8 x = dd1031['frequency']['values'][i]
#       9 y_real = dd1031['s11']['values'][i].real
#      10 y_imag = dd1031['s11']['values'][i].imag
#
# NameError: name 'dd1031' is not defined

# %%
par_ini = {'amp': 0.00035,'const':0, 'center':7.97e9,'k':0.01e9}
par_min = {'amp': 0,'const':-np.inf,'center':0,'k':0}
par_max = {'amp': np.inf, 'const':np.inf,'center':np.inf,'k':np.inf}
par_vary = {'amp': True,'const':True, 'center':True,'k':True}
model = lmfit.Model(Gaussian)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )
results = []
for i in range(21):
    result = model.fit(data = ys[i], params=params, freq = xs[i])
    results.append(result)

# %%
fig, ax = plt.subplots(dpi=80)
id = 20
plt.rcParams["font.size"] = 10
ax.tick_params(axis="x", direction="in")
ax.tick_params(axis="y", direction="in")
plt.tick_params(
            top='on',
            bottom='on`',
            left='on',
            right='on',
            )

results[id].plot_fit(ax = ax)
# plt.plot(xs[0],results[0].init_fit)
ax.set_xlabel('F0g1 frequency (GHz)', size='large')
ax.set_ylabel('Re[S$_{11}$] (Arb. u.)', size='large')
plt.show()
results[id]
# Out:
# <h2> Model</h2> Model(Gaussian) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>56</td><td></td></tr><tr><td># data points</td><td>241</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 1.2708e-08</td><td></td></tr><tr><td>reduced chi-square</td><td> 5.3620e-11</td><td></td></tr><tr><td>Akaike info crit.</td><td>-5695.46838</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-5681.52919</td><td></td></tr><tr><td>R-squared</td><td> 0.96175396</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  1.0826e-04 </td><td>  1.4699e-06 </td><td> (1.36%) </td><td> 0.00035 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  2.6485e-05 </td><td>  6.8002e-07 </td><td> (2.57%) </td><td> 0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> center </td><td>  7.9411e+09 </td><td>  174233.279 </td><td> (0.00%) </td><td> 7970000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> k </td><td>  11760740.9 </td><td>  203139.889 </td><td> (1.73%) </td><td> 10000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>const</td><td>k</td><td>+0.5142</td></tr><tr><td>amp</td><td>const</td><td>+0.3272</td></tr><tr><td>amp</td><td>k</td><td>-0.2997</td></tr></table>

# %%
center1031_g = [7.9975e+09, 7.9959e+09, 7.9950e+09, 7.9923e+09, 7.9914e+09, 7.9886e+09, 7.9868e+09,
                7.9838e+09, 7.9821e+09, 7.9797e+09, 7.9772e+09, 7.9745e+09, 7.9710e+09, 7.9685e+09,
                7.9652e+09, 7.9614e+09, 7.9572e+09, 7.9537e+09, 7.9494e+09, 7.9456e+09, 7.9411e+09]

# %%
center1031 = [7.9975e+09, 7.9959e+09, 7.9949e+09, 7.9925e+09, 7.9915e+09, 7.9887e+09, 7.9870e+09,
              7.9841e+09, 7.9824e+09, 7.9797e+09, 7.9773e+09, 7.9745e+09, 7.9635e+09, 7.9686e+09,
              7.9652e+09, 7.9616e+09, 7.9575e+09, 7.9538e+09, 7.9495e+09, 7.9458e+09, 7.9413e+09]

# %% [markdown]
# 10.29 GHz

# %%
xs = []
ys = []
num_of_freq = 241

for i in range(21):
    ini = num_of_freq*i
    fin = num_of_freq*(1+i)-1
    x = dd1029['frequency']['values'][i]
    y_real = dd1029['s11']['values'][i].real
    y_imag = dd1029['s11']['values'][i].imag
    y_PCA = PCA_transform(y_real, y_imag)
    xs.append(x)
    ys.append(-y_PCA[0])

# %%
par_ini = {'amp': 0.00035,'const':0, 'center':7.97e9,'k':0.01e9}
par_min = {'amp': 0,'const':-np.inf,'center':0,'k':0}
par_max = {'amp': np.inf, 'const':np.inf,'center':np.inf,'k':np.inf}
par_vary = {'amp': True,'const':True, 'center':True,'k':True}
model = lmfit.Model(Gaussian)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )
results = []
for i in range(21):
    result = model.fit(data = ys[i], params=params, freq = xs[i])
    results.append(result)

# %%
fig, ax = plt.subplots(dpi=80)
id = 20
plt.rcParams["font.size"] = 10
ax.tick_params(axis="x", direction="in")
ax.tick_params(axis="y", direction="in")
plt.tick_params(
            top='on',
            bottom='on`',
            left='on',
            right='on',
            )

results[id].plot_fit(ax = ax)
# plt.plot(xs[0],results[0].init_fit)
ax.set_xlabel('F0g1 frequency (GHz)', size='large')
ax.set_ylabel('Re[S$_{11}$] (Arb. u.)', size='large')
plt.show()
results[id]
# Out:
# <h2> Model</h2> Model(Gaussian) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>57</td><td></td></tr><tr><td># data points</td><td>241</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 9.5921e-09</td><td></td></tr><tr><td>reduced chi-square</td><td> 4.0473e-11</td><td></td></tr><tr><td>Akaike info crit.</td><td>-5763.25703</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-5749.31784</td><td></td></tr><tr><td>R-squared</td><td> 0.97846363</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  1.2811e-04 </td><td>  1.3046e-06 </td><td> (1.02%) </td><td> 0.00035 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  2.9699e-05 </td><td>  5.7485e-07 </td><td> (1.94%) </td><td> 0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> center </td><td>  7.9463e+09 </td><td>  124526.399 </td><td> (0.00%) </td><td> 7970000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> k </td><td>  11144659.0 </td><td>  143207.584 </td><td> (1.28%) </td><td> 10000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>const</td><td>k</td><td>+0.4939</td></tr><tr><td>amp</td><td>k</td><td>-0.3232</td></tr><tr><td>amp</td><td>const</td><td>+0.3116</td></tr></table>

# %%
center1029_g = [7.9998e+09, 7.9983e+09, 7.9966e+09, 7.9950e+09, 7.9933e+09, 7.9914e+09, 7.9895e+09,
                7.9875e+09, 7.9852e+09, 7.9830e+09, 7.9804e+09, 7.9776e+09, 7.9749e+09, 7.9719e+09,
                7.9689e+09, 7.9654e+09, 7.9623e+09, 7.9584e+09, 7.9545e+09, 7.9506e+09, 7.9463e+09]

# %% [markdown]
# 10.33 GHz

# %%
xs = []
ys = []
num_of_freq = 181

for i in range(21):
    ini = num_of_freq*i
    fin = num_of_freq*(1+i)-1
    x = dd1033['frequency']['values'][i]
    y_real = dd1033['s11']['values'][i].real
    y_imag = dd1033['s11']['values'][i].imag
    y_PCA = PCA_transform(y_real, y_imag)
    xs.append(x)
    ys.append(-y_PCA[0])

# %%
par_ini = {'amp': 0.00035,'const':0, 'center':7.99e9,'k':0.01e9}
par_min = {'amp': 0,'const':-np.inf,'center':0,'k':0}
par_max = {'amp': np.inf, 'const':np.inf,'center':np.inf,'k':np.inf}
par_vary = {'amp': True,'const':True, 'center':True,'k':True}
model = lmfit.Model(Gaussian)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )
results = []
for i in range(21):
    result = model.fit(data = ys[i], params=params, freq = xs[i])
    results.append(result)

# %%
fig, ax = plt.subplots(dpi=80)
id = 20
plt.rcParams["font.size"] = 10
ax.tick_params(axis="x", direction="in")
ax.tick_params(axis="y", direction="in")
plt.tick_params(
            top='on',
            bottom='on`',
            left='on',
            right='on',
            )

results[id].plot_fit(ax = ax)
# plt.plot(xs[0],results[0].init_fit)
ax.set_xlabel('F0g1 frequency (GHz)', size='large')
ax.set_ylabel('Re[S$_{11}$] (Arb. u.)', size='large')
plt.show()
results[id]
# Out:
# <h2> Model</h2> Model(Gaussian) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>41</td><td></td></tr><tr><td># data points</td><td>181</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 6.3576e-08</td><td></td></tr><tr><td>reduced chi-square</td><td> 3.5919e-10</td><td></td></tr><tr><td>Akaike info crit.</td><td>-3932.28452</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-3919.49053</td><td></td></tr><tr><td>R-squared</td><td> 0.88838609</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  2.3095e-04 </td><td>  7.1590e-06 </td><td> (3.10%) </td><td> 0.00035 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  1.9431e-05 </td><td>  1.5542e-06 </td><td> (8.00%) </td><td> 0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> center </td><td>  7.9813e+09 </td><td>  107447.917 </td><td> (0.00%) </td><td> 7990000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> k </td><td>  3037667.87 </td><td>  111260.411 </td><td> (3.66%) </td><td> 10000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>amp</td><td>k</td><td>-0.5111</td></tr><tr><td>const</td><td>k</td><td>+0.2598</td></tr><tr><td>amp</td><td>const</td><td>+0.1535</td></tr></table>

# %%
center1033_g = [8.0080e+09, 8.0085e+09, 8.0067e+09, 8.0053e+09, 8.0041e+09, 8.0039e+09,
                8.0029e+09, 8.0022e+09, 8.0019e+09, 8.0001e+09, 7.9984e+09, 7.9972e+09,
                7.9955e+09, 7.9939e+09, 7.9925e+09, 7.9908e+09, 7.9883e+09, 7.9872e+09,
                7.9836e+09, 7.9839e+09, 7.9813e+09]

# %% [markdown]
# 10.37 GHz

# %%
xs = []
ys = []
num_of_freq = 101

for i in range(21):
    ini = num_of_freq*i
    fin = num_of_freq*(1+i)-1
    x = dd1037['frequency']['values'][i]
    y_real = dd1037['s11']['values'][i].real
    y_imag = dd1037['s11']['values'][i].imag
    y_PCA = PCA_transform(y_real, y_imag)
    xs.append(x)
    ys.append(-y_PCA[0])

# %%
par_ini = {'amp': 0.00035,'const':0, 'center':8.02e9,'k':0.01e9}
par_min = {'amp': 0,'const':-np.inf,'center':0,'k':0}
par_max = {'amp': np.inf, 'const':np.inf,'center':np.inf,'k':np.inf}
par_vary = {'amp': True,'const':True, 'center':True,'k':True}
model = lmfit.Model(Gaussian)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )
results = []
for i in range(21):
    result = model.fit(data = ys[i], params=params, freq = xs[i])
    results.append(result)

# %%
fig, ax = plt.subplots(dpi=80)
id = 20
plt.rcParams["font.size"] = 10
ax.tick_params(axis="x", direction="in")
ax.tick_params(axis="y", direction="in")
plt.tick_params(
            top='on',
            bottom='on`',
            left='on',
            right='on',
            )

results[id].plot_fit(ax = ax)
# plt.plot(xs[0],results[0].init_fit)
ax.set_xlabel('F0g1 frequency (GHz)', size='large')
ax.set_ylabel('Re[S$_{11}$] (Arb. u.)', size='large')
plt.show()
results[id]
# Out:
# <h2> Model</h2> Model(Gaussian) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>86</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 1.2446e-09</td><td></td></tr><tr><td>reduced chi-square</td><td> 1.2831e-11</td><td></td></tr><tr><td>Akaike info crit.</td><td>-2529.07971</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-2518.61923</td><td></td></tr><tr><td>R-squared</td><td> 0.84763381</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  4.7039e-05 </td><td>  2.4138e-06 </td><td> (5.13%) </td><td> 0.00035 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  2.2075e-06 </td><td>  3.7561e-07 </td><td> (17.02%) </td><td> 0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> center </td><td>  8.0156e+09 </td><td>  55718.2500 </td><td> (0.00%) </td><td> 8020000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> k </td><td>  945457.460 </td><td>  56682.9617 </td><td> (6.00%) </td><td> 10000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>amp</td><td>k</td><td>-0.5437</td></tr><tr><td>const</td><td>k</td><td>+0.1884</td></tr><tr><td>amp</td><td>const</td><td>+0.1100</td></tr></table>

# %%
center1037_g = [8.0214e+09, 8.0214e+09, 8.0212e+09, 8.0210e+09, 8.0208e+09, 8.0207e+09, 8.0203e+09,
                8.0202e+09, 8.0198e+09, 8.0196e+09, 8.0194e+09, 8.0192e+09, 8.0188e+09, 8.0184e+09,
                8.0181e+09, 8.0179e+09, 8.0173e+09, 8.0169e+09, 8.0166e+09, 8.0161e+09, 8.0156e+09]

# %%
power_dBm = np.linspace(-10, -5, 21)
power_W = 10**((power_dBm)/10) *1e-3

# %%
# plt.plot(power_W, center1037_g, '.', label="10.37 GHz")
plt.plot(power_W, center1033_g, '.', label="10.33 GHz")
# plt.plot(power_W, center1031_g, '.', label="10.31 GHz")
plt.plot(power_W, center1030_g, '.', label="10.30 GHz")
# plt.plot(power_W, center1029_g, '.', label="10.29 GHz")
plt.plot(power_W, center1028_g, '.', label="10.28 GHz")
plt.plot(power_W, center1026_g, '.', label="10.26 GHz")
plt.plot(power_W, center1022_g, '.', label="10.22 GHz")

plt.show()

# %%
def liner_func(power, alpha, const):
    return const - alpha*power

# %%
par_ini = {'alpha': 0.015e9/0.00005,'const':8.005e9}
par_min = {'alpha': -np.inf,'const':-np.inf}
par_max = {'alpha': np.inf,'const':np.inf}
par_vary = {'alpha': True,'const':True}
model = lmfit.Model(liner_func)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )
# result1037 = model.fit(data = center1037_g, params=params, power = power_W)
result1033 = model.fit(data = center1033_g, params=params, power = power_W)
# result1031 = model.fit(data = center1031_g, params=params, power = power_W)
result1030 = model.fit(data = center1030_g, params=params, power = power_W)
# result1029 = model.fit(data = center1029_g, params=params, power = power_W)
result1028 = model.fit(data = center1028_g, params=params, power = power_W)
result1026 = model.fit(data = center1026_g, params=params, power = power_W)
result1022 = model.fit(data = center1022_g, params=params, power = power_W)

# %%
fig, ax = plt.subplots(dpi=80)
plt.rcParams["font.size"] = 10
ax.tick_params(axis="x", direction="in")
ax.tick_params(axis="y", direction="in")
# result1037.plot_fit(ax = ax)
result1033.plot_fit(ax = ax)
# result1031.plot_fit(ax = ax)
result1030.plot_fit(ax = ax)
# result1029.plot_fit(ax = ax)
result1028.plot_fit(ax = ax)
result1026.plot_fit(ax = ax)
result1022.plot_fit(ax = ax)
ax.set_xlabel('Power (W)', size='large')
ax.set_ylabel('Drive freq (Hz)', size='large')
plt.legend()
plt.show()
result1022
# Out:
# <h2> Model</h2> Model(liner_func) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>7</td><td></td></tr><tr><td># data points</td><td>21</td><td></td></tr><tr><td># variables</td><td>2</td><td></td></tr><tr><td>chi-square</td><td> 6.5553e+10</td><td></td></tr><tr><td>reduced chi-square</td><td> 3.4501e+09</td><td></td></tr><tr><td>Akaike info crit.</td><td> 463.093533</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 465.182578</td><td></td></tr><tr><td>R-squared</td><td> 0.99961721</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> alpha </td><td>  4.3904e+10 </td><td>  1.9710e+08 </td><td> (0.45%) </td><td> 300000000000.0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  8.0210e+09 </td><td>  39364.0072 </td><td> (0.00%) </td><td> 8005000000.0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>alpha</td><td>const</td><td>+0.9455</td></tr></table>

# %%
x = np.array([10.33e9, 10.30e9, 10.28e9, 10.26e9, 10.22e9])
alpha = -np.array([1.2751e+11, 2.8947e+11, 1.7952e+11, 1.0053e+11, 4.3904e+10])
plt.plot(x, alpha, '.')
plt.show()

# %%
from scipy.constants import *

# %%
# k_sunada - dpr model
# k_f =0.21238950e9
chi_Hz = -1500000.0
chi = chi_Hz*2*np.pi

# omega_p =np.array([10.37e9, 10.33e9, 10.31e9, 10.30e9,10.29e9, 10.28e9, 10.26e9, 10.22e9])*2*np.pi
# omega_f = 10.1676834e9 *2*np.pi
# omega_r =10.2557302e9*2*np.pi
omega_p=np.array([10.33e9, 10.30e9, 10.28e9, 10.26e9, 10.22e9])*2*np.pi

# g = 0.1011e9
# slope= np.array([-2.7268e+10, -1.3029e+11, -2.6321e+11, -2.8213e+11, -2.4807e+11,  -1.8144e+11, -1.0320e+11, -4.4706e+10])*2*np.pi
slope= -np.array([1.2751e+11, 2.8947e+11, 1.7952e+11, 1.0053e+11, 4.3904e+10])*2*np.pi
P = 0.0002
# P_eff = P * g* k_f**0.5/(1j*(omega_f-omega_p)+k_f/2)/k_eff**0.5
Delta_q = np.array(slope*P * 2*np.pi)
# delta_f = omega_p-omega_f
# delta_r = omega_p-omega_r

def coeff2(k_f, delta_r, delta_f, g):
    numer = k_f *g**2/(delta_r**2)
    denom = (delta_f - g**2/delta_r)**2 +(k_f/2)**2
    return numer/denom

def ac_stark_shift1(omega,  omega_r, omega_f, k_f, g, alpha):
    return 2*chi*alpha/(hbar*omega)*coeff2(k_f=k_f, delta_r=omega-omega_r, delta_f=omega-omega_f, g=g)

# %%
# x=np.array([10.37e9, 10.33e9, 10.31e9, 10.30e9,10.29e9, 10.28e9, 10.26e9, 10.22e9])*2*np.pi
# slope= np.array([-2.7268e+10, -1.3029e+11, -2.6321e+11, -2.8213e+11, -2.4807e+11,  -1.8144e+11, -1.0320e+11, -4.4706e+10])*2*np.pi

x=np.array([10.33e9, 10.30e9, 10.28e9, 10.26e9, 10.22e9])*2*np.pi
slope= -np.array([1.2751e+11, 2.8947e+11, 1.7952e+11, 1.0053e+11, 4.3904e+10])*2*np.pi
par_ini = {'omega_r':10.267e9*2*np.pi, 'omega_f':10.177e9*2*np.pi,
           'k_f':0.20e9*2*np.pi,'g':0.083e9*2*np.pi, 'alpha':4.4e-11}
par_min = {'omega_r':0, 'omega_f':0,'k_f':0,'g':0, 'alpha':0}
par_max = {'omega_r':np.inf,'omega_f':np.inf, 'k_f':np.inf,'g':np.inf, 'alpha':np.inf}
par_vary = { 'omega_r':False,'omega_f':False, 'k_f':False,'g':False, 'alpha':True}
model = lmfit.Model(ac_stark_shift1)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )
result = model.fit(data = slope, params=params, omega =x )

# %%
fig, ax = plt.subplots(figsize=(9,7),constrained_layout=True)
plt.rcParams["font.size"] = 20
# plt.title("Rabi(amp)")
plt.tick_params(top='on',bottom='on',left='on',right='on',)
plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'

# result.plot_fit(ax = ax)# result = model.fit(y, params, x=x)
x_interp = np.linspace(10.22e9, 10.33e9, 100*5)*2*np.pi
y_interp = result.model.func(x_interp, **result.best_values)
plt.xlim(10.22, 10.32)
plt.plot(x/(2*np.pi)*1e-9, slope/(2*np.pi)*1e-9,'o', label='original')
plt.plot(x_interp/(2*np.pi)*1e-9, y_interp/(2*np.pi)*1e-9, label='interpolated')
# ax.plot(x/(2*np.pi)*1e-9,result.init_fit/(2*np.pi)*1e-9)
ax.set_xlabel('Probe frequency $\omega_\mathrm{p}/2\pi$ (GHz)', size='large')
ax.set_ylabel('Shift $(\Delta_\mathrm{ac}/2\pi)$ / VNA power $P_\mathrm{VNA}$ (GHz/W)')
plt.gca().xaxis.set_major_formatter(plt.FormatStrFormatter('%.2f'))
# plt.savefig('slope.png', bbox_inches='tight')
plt.show()

result
# Out:
# <h2> Model</h2> Model(ac_stark_shift1) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>13</td><td></td></tr><tr><td># data points</td><td>5</td><td></td></tr><tr><td># variables</td><td>1</td><td></td></tr><tr><td>chi-square</td><td> 1.2543e+22</td><td></td></tr><tr><td>reduced chi-square</td><td> 3.1357e+21</td><td></td></tr><tr><td>Akaike info crit.</td><td> 248.370059</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 247.979497</td><td></td></tr><tr><td>R-squared</td><td> 0.99079514</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> omega_r </td><td>  6.4509e+10 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 64509463548.81281 </td><td>  0.00000000 </td><td>         inf </td><td> False </td></tr><tr><td> omega_f </td><td>  6.3944e+10 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 63943976871.16665 </td><td>  0.00000000 </td><td>         inf </td><td> False </td></tr><tr><td> k_f </td><td>  1.2566e+09 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 1256637061.4359171 </td><td>  0.00000000 </td><td>         inf </td><td> False </td></tr><tr><td> g </td><td>  5.2150e+08 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 521504380.49590564 </td><td>  0.00000000 </td><td>         inf </td><td> False </td></tr><tr><td> alpha </td><td>  5.7965e-11 </td><td>  1.4216e-12 </td><td> (2.45%) </td><td> 4.4e-11 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table>

# %%
def watt_dbm(watt):
    return 10*np.log10(watt*1e3)

def dbm_watt(dBm):
    return (10**(dBm/10))*1e-3

# %%
watt_dbm(5.7965e-11*1e-3) + 50
# Out:
# -52.36834159799338

# %% [markdown]
# n_crit, n_ave

# %%
omega = np.linspace(9.8, 10.8, 100)*1e9*2*np.pi
k_f = 2.0003e+08*2*np.pi
omega_f = 1.0177e+10 *2*np.pi
omega_r = 1.0267e+10 *2*np.pi
g = 82703425.3*2*np.pi
alpha = 5.7965e-11
Power = dbm_watt(-10)
n_ave = alpha*Power/(hbar*omega)*coeff2(k_f=k_f, delta_r=omega-omega_r, delta_f=omega-omega_f, g=g)
plt.plot(omega/(2*np.pi), n_ave)
plt.xlim(10.25e9, 10.35e9)
# Out:
# (10250000000.0, 10350000000.0)

# %%
readout_freq = 10.3
readout_lo_freq = 10.38 # 10.387
readout_if_freq = readout_lo_freq - readout_freq
JPA_if_freq = readout_freq * 2 - readout_lo_freq * 2

qubit_lo_freq = 7.85
ge_freq = 8.012+0.0089-2.8e-05
anharmonicity = 7.682-ge_freq+0.0208-6.5e-4
ge_if_freq = ge_freq-qubit_lo_freq
print(ge_freq, anharmonicity)
# Out:
# 8.020872 -0.3187220000000003

# %%
omega_q = 8.012e9*2*np.pi

omega_r = 1.0267e+10 *2*np.pi
delta = omega_q-omega_r
kai = -1500000 *2*np.pi
alpha = -0.3187e+9*2*np.pi
g = (kai*(delta+alpha)/2)**0.5


n_crit =( ((delta+2*alpha)/(2*g))**2-2)/5
delta, n_crit
# Out:
# (-14168582867.689964, 216.30429757417977)

# %%
ge_freq = 8.2779 -0.001898495
anharmonicity = -0.38408638 -0.0009

readout_freq = 10.5089 - 0.01

2 * ge_freq + anharmonicity - readout_freq
# Out:
# 5.668116629999998

# %%
readout_freq = 10.5089 - 0.01
readout_lo_freq = 10.633
readout_if_freq = readout_lo_freq - readout_freq

qubit_lo_freq = 8.12
ge_freq = 8.2779 -0.001898495
anharmonicity = -0.38408638 -0.0009
ge_if_freq = ge_freq-qubit_lo_freq

fogi_lo_freq = 2 * qubit_lo_freq - readout_freq - readout_if_freq
fogi_lo_freq
# Out:
# 5.606999999999999

# %% [markdown]
# ## 9/14 ef calibration - CL5R

# %% [markdown]
# ef_freq =  (8.2779 -0.001898495-0.38408638 -0.0009)e9
#
# ef_pi_amp = 0.785
#
#
# T1 = 5.97e-06
#
# T2 =
#
# T2_star =

# %%
from plottr.data.datadict_storage import datadict_from_hdf5
import numpy as np
import matplotlib.pyplot as plt
import lmfit

# %%
import sklearn
from sklearn.decomposition import PCA

# %%
def Rabi(delay, amp, phi0, detun, const):
    return - amp * np.cos(2*np.pi*detun*delay+phi0) + const

# %% [markdown]
# amp

# %%
header = "D:/K_sunada/result/CDY148/"
ef = "/2023-09-14/2023-09-14T152436_60b58d27-td_ef_pi_amp"
dd_ef = datadict_from_hdf5(header + ef +"/data")

# %%
def PCA_transform(Re_c, Im_c):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c]).T, np.array([Im_c]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    return c_PCA1, c_PCA2

# %%
Rabi_ef = dd_ef['s11']['values']
#imag_ge = Rabi_ge.imag
amp_ef = dd_ef['amplitude']['values']

I = (Rabi_ef.real)
Q = (Rabi_ef.imag)

PCAef = PCA_transform(I, Q)

# %%
y = PCAef[0]
x = amp_ef

plt.plot(x, y)
plt.show()

# %%
par_ini = {
    'amp': 0.0005,
    'phi0':0,
    'detun':1/0.5,
    'const':0
}

par_min = {
    'amp': 0,
    'phi0':-2*np.pi,
    'detun':-np.inf,
    'const':0
}

par_max = {
    'amp': np.inf,
    'phi0':2*np.pi,
    'detun':np.inf,
    'const':np.inf,
}

par_vary = {
    'amp': True,
    'phi0':True,
    'detun':True,
    'const':True
}

# %%
model = lmfit.Model(Rabi)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )

# %%
result_ef = model.fit(data = y, params = params, delay = x)
result_ef
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>124</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 5.0135e-07</td><td></td></tr><tr><td>reduced chi-square</td><td> 5.1686e-09</td><td></td></tr><tr><td>Akaike info crit.</td><td>-1923.22884</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-1912.76836</td><td></td></tr><tr><td>R-squared</td><td> 0.95896121</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  4.8079e-04 </td><td> 0.0005 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td> -2.97746121 </td><td> 0 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  3.18614324 </td><td> 2.0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  1.6609e-13 </td><td> 0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table>

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result_ef.plot_fit(ax = ax)
plt.plot(amp_ef,result_ef.init_fit)

plt.xlabel("amplitude")
plt.ylabel("mag[S11](a.u.)")


plt.show()

# %%
np.pi/(3.18614324*2*np.pi)*5
# Out:
# 0.7846477109422112

# %% [markdown]
# ramsey

# %%
pl = "/2023-09-14/2023-09-14T153749_395c3d75-td_ef_T2r1d"
mi = "/2023-09-14/2023-09-14T153956_84f9b6c0-td_ef_T2r1d"
dd_pl = datadict_from_hdf5(header + pl +"/data")
dd_mi = datadict_from_hdf5(header + mi +"/data")

# %%
Rabi_pl = dd_pl['s11']['values']
imag_pl = Rabi_pl.imag
delay_pl = dd_pl['delay']['values']

Rabi_mi = dd_mi['s11']['values']
imag_mi = Rabi_mi.imag
delay_mi = dd_mi['delay']['values']

# %%
def PCA_transform(Re_c, Im_c):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c]).T, np.array([Im_c]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    return c_PCA1, c_PCA2


I_pl = (Rabi_pl.real)
Q_pl = (Rabi_pl.imag)
I_mi = (Rabi_mi.real)
Q_mi = (Rabi_mi.imag)


PCA_pl = PCA_transform(I_pl, Q_pl)
y_pl = PCA_pl[0]
x_pl = delay_pl

PCA_mi = PCA_transform(I_mi, Q_mi)
y_mi = PCA_mi[0]
x_mi = delay_mi



plt.plot(x_pl, y_pl)
plt.show()

# %%
par_ini_pl = {
    'amp': 15,
    'phi0':0,
    'detun':1/180,
    'const':0
}

par_min_pl = {
    'amp': 0,
    'phi0':-2*np.pi,
    'detun':-np.inf,
    'const':0
}

par_max_pl = {
    'amp': np.inf,
    'phi0':2*np.pi,
    'detun':np.inf,
    'const':np.inf,
}

par_vary_pl = {
    'amp': True,
    'phi0':True,
    'detun':True,
    'const':True
}

# %%
model = lmfit.Model(Rabi)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini_pl[name],
    min = par_min_pl[name],
    max = par_max_pl[name],
    vary = par_vary_pl[name]
    )
    
result_pl = model.fit(data = y_pl, params = params, delay = x_pl)
result_pl
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>161</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 401.798450</td><td></td></tr><tr><td>reduced chi-square</td><td> 4.14225206</td><td></td></tr><tr><td>Akaike info crit.</td><td> 147.463838</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 157.924320</td><td></td></tr><tr><td>R-squared</td><td> 0.94848224</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  12.1206593 </td><td>  0.28706612 </td><td> (2.37%) </td><td> 15 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  0.48374129 </td><td>  0.04670415 </td><td> (9.65%) </td><td> 0 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  0.00592165 </td><td>  1.3000e-05 </td><td> (0.22%) </td><td> 0.005555555555555556 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  1.2058e-10 </td><td>  0.23573115 </td><td> (195489818345.40%) </td><td> 0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>-0.8630</td></tr><tr><td>detun</td><td>const</td><td>+0.1352</td></tr><tr><td>phi0</td><td>const</td><td>-0.1129</td></tr></table>

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(+5MHz)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result_pl.plot_fit(ax = ax)
plt.plot(x_pl,result_pl.init_fit)

plt.xlabel("delay (ns)")
plt.ylabel("mag[S11](a.u.)")


plt.show()

# %%
plt.plot(x_mi, y_mi)
plt.show()

# %%
par_ini_mi = {
    'amp': 15,
    'phi0':-np.pi/2,
    'detun':1/200,
    'const':0
}

par_min_mi = {
    'amp': 0,
    'phi0':-2*np.pi,
    'detun':-np.inf,
    'const':0
}

par_max_mi = {
    'amp': np.inf,
    'phi0':2*np.pi,
    'detun':np.inf,
    'const':np.inf,
}

par_vary_mi = {
    'amp': True,
    'phi0':True,
    'detun':True,
    'const':True
}

# %%
model = lmfit.Model(Rabi)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini_mi[name],
    min = par_min_mi[name],
    max = par_max_mi[name],
    vary = par_vary_mi[name]
    )
    
result_mi = model.fit(data = y_mi, params = params, delay = x_mi)
result_mi
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>85</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 441.109314</td><td></td></tr><tr><td>reduced chi-square</td><td> 4.54751870</td><td></td></tr><tr><td>Akaike info crit.</td><td> 156.891393</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 167.351875</td><td></td></tr><tr><td>R-squared</td><td> 0.94872414</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  12.8235808 </td><td>  0.30293878 </td><td> (2.36%) </td><td> 15 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  0.94139147 </td><td>  0.04487905 </td><td> (4.77%) </td><td> -1.5707963267948966 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  0.00406939 </td><td>  1.2478e-05 </td><td> (0.31%) </td><td> 0.005 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  0.13499752 </td><td>  0.21281354 </td><td> (157.64%) </td><td> 0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>-0.8557</td></tr></table>

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(-5MHz)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result_mi.plot_fit(ax = ax)
plt.plot(x_mi,result_pl.init_fit)

plt.xlabel("delay (ns)")
plt.ylabel("mag[S11](a.u.)")


plt.show()

# %%
detun = ((0.005-0.00592165)+ (0.00406939-0.005))/2 #GHz
detun
# Out:
# -0.0009261299999999998

# %% [markdown]
# drag

# %%
drag = "/2023-09-16/2023-09-16T162625_57e645fb-td_ef_pi_drag"
dd_drag = datadict_from_hdf5(header + drag +"/data")

drag1 = "/2023-09-16/2023-09-16T162733_803e1858-td_ef_pi_drag"
dd_drag1 = datadict_from_hdf5(header + drag1 +"/data")

drag2 = "/2023-09-16/2023-09-16T162845_ab3ab0ad-td_ef_pi_drag"
dd_drag2 = datadict_from_hdf5(header + drag2 +"/data")

# %%
Rabi_drag = dd_drag['s11']['values']
imag_drag = Rabi_drag.imag
drag = dd_drag['beta']['values']
I_drag = (Rabi_drag.real)
Q_drag = (Rabi_drag.imag)

Rabi_drag1 = dd_drag1['s11']['values']
imag_drag1 = Rabi_drag1.imag
drag1 = dd_drag1['beta']['values']
I_drag1 = (Rabi_drag1.real)
Q_drag1 = (Rabi_drag1.imag)

Rabi_drag2 = dd_drag2['s11']['values']
imag_drag2 = Rabi_drag2.imag
drag2 = dd_drag2['beta']['values']
I_drag2 = (Rabi_drag2.real)
Q_drag2 = (Rabi_drag2.imag)

# %%
def PCA_transform1(Re_c_amp, Im_c_amp, Re_c_drag, Im_c_drag):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c_amp]).T, np.array([Im_c_amp]).T], axis = 1)
    c1_data = np.concatenate([np.array([Re_c_drag]).T, np.array([Im_c_drag]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    
    c1_pca = pca.transform(c1_data)
    c1_PCA1 = c1_pca.T[0]
    c1_PCA2 = c1_pca.T[1]
    return c_PCA1, c_PCA2, c1_PCA1, c1_PCA2,

# %%
PCA_drag = PCA_transform1(I, Q, I_drag, Q_drag)
y = PCA_drag[0]
x = amp_ef
y0 = PCA_drag[2]
x0 = drag

PCA_drag1 = PCA_transform1(I, Q, I_drag1, Q_drag1)
y1 = PCA_drag1[2]
x1 = drag1

PCA_drag2 = PCA_transform1(I, Q, I_drag2, Q_drag2)
y2 = PCA_drag2[2]
x2 = drag2


plt.plot(x, y)
plt.show()

# %%
plt.plot(x0, y0)
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.show()

# %%
par_ini= {
    'amp': 0.00015,
    'phi0':np.pi/2,
    'detun':1/0.7,
    'const':-0.0005
}

par_min = {
    'amp': 0,
    'phi0':-2*np.pi,
    'detun':-np.inf,
    'const':-np.inf
}

par_max = {
    'amp': np.inf,
    'phi0':2*np.pi,
    'detun':np.inf,
    'const':np.inf,
}

par_vary = {
    'amp': True,
    'phi0':True,
    'detun':True,
    'const':True
}

# %%
model = lmfit.Model(Rabi)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )
    
result0 = model.fit(data = y0, params = params, delay = x0)
result1 = model.fit(data = y1, params = params, delay = x1)
result2 = model.fit(data = y2, params = params, delay = x2)

# %%
result0
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>41</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 4.6180e-08</td><td></td></tr><tr><td>reduced chi-square</td><td> 4.7608e-10</td><td></td></tr><tr><td>Akaike info crit.</td><td>-2164.09015</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-2153.62967</td><td></td></tr><tr><td>R-squared</td><td> 0.90216564</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  8.9998e-05 </td><td>  3.0499e-06 </td><td> (3.39%) </td><td> 0.00015 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  1.24759714 </td><td>  0.15295164 </td><td> (12.26%) </td><td> 1.5707963267948966 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  1.26563126 </td><td>  0.02396138 </td><td> (1.89%) </td><td> 1.4285714285714286 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td> -4.9681e-04 </td><td>  2.3994e-06 </td><td> (0.48%) </td><td> -0.0005 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>-0.9715</td></tr><tr><td>detun</td><td>const</td><td>+0.3526</td></tr><tr><td>phi0</td><td>const</td><td>-0.3309</td></tr><tr><td>amp</td><td>const</td><td>+0.2844</td></tr><tr><td>amp</td><td>phi0</td><td>-0.1629</td></tr><tr><td>amp</td><td>detun</td><td>+0.1583</td></tr></table>

# %%
res0 = (3*np.pi-1.24759714)/(2*np.pi*1.26563126)
res0
# Out:
# 1.0282921964029939

# %%
result1
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>51</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 1.0484e-07</td><td></td></tr><tr><td>reduced chi-square</td><td> 1.0808e-09</td><td></td></tr><tr><td>Akaike info crit.</td><td>-2081.28214</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-2070.82165</td><td></td></tr><tr><td>R-squared</td><td> 0.80145504</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  9.7060e-05 </td><td>  4.9263e-06 </td><td> (5.08%) </td><td> 0.00015 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td> -0.58105248 </td><td>  0.15965075 </td><td> (27.48%) </td><td> 1.5707963267948966 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  1.55200114 </td><td>  0.02473449 </td><td> (1.59%) </td><td> 1.4285714285714286 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td> -4.6204e-04 </td><td>  3.4542e-06 </td><td> (0.75%) </td><td> -0.0005 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>-0.9557</td></tr><tr><td>amp</td><td>const</td><td>+0.2624</td></tr><tr><td>phi0</td><td>const</td><td>+0.1666</td></tr><tr><td>detun</td><td>const</td><td>-0.1506</td></tr></table>

# %%
res1 = (3*np.pi-(-0.58105248))/(2*np.pi*1.55200114)
res1
# Out:
# 1.0260800287735643

# %%
result2
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>51</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 1.0880e-07</td><td></td></tr><tr><td>reduced chi-square</td><td> 1.1216e-09</td><td></td></tr><tr><td>Akaike info crit.</td><td>-2077.53953</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-2067.07904</td><td></td></tr><tr><td>R-squared</td><td> 0.83905638</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  1.1310e-04 </td><td>  5.0379e-06 </td><td> (4.45%) </td><td> 0.00015 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td> -1.13089931 </td><td>  0.13880513 </td><td> (12.27%) </td><td> 1.5707963267948966 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  1.63692528 </td><td>  0.02127195 </td><td> (1.30%) </td><td> 1.4285714285714286 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td> -4.6158e-04 </td><td>  3.5562e-06 </td><td> (0.77%) </td><td> -0.0005 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>-0.9566</td></tr><tr><td>phi0</td><td>const</td><td>+0.2603</td></tr><tr><td>detun</td><td>const</td><td>-0.2501</td></tr><tr><td>amp</td><td>const</td><td>+0.2352</td></tr></table>

# %%
res2 = (3*np.pi-(-1.13089931))/(2*np.pi*1.63692528)
res2
# Out:
# 1.0263072089189764

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(drag)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result0.plot_fit(ax = ax)
plt.plot(x0,result0.init_fit)

plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(drag)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result1.plot_fit(ax = ax)
plt.plot(x1,result1.init_fit)


plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(drag)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result2.plot_fit(ax = ax)

plt.plot(x2,result2.init_fit)


plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
beta = (res0 + res1 + res2)/3
beta
# Out:
# 1.0268931446985115

# %% [markdown]
# half drag

# %%
drag = "/2023-09-16/2023-09-16T151219_fdd17738-td_ge_pi_drag"
dd_drag = datadict_from_hdf5(header + drag +"/data")

drag1 = "/2023-09-16/2023-09-16T151407_3e0e7afb-td_ge_pi_drag"
dd_drag1 = datadict_from_hdf5(header + drag1 +"/data")

drag2 = "/2023-09-16/2023-09-16T150801_6456e0b7-td_ge_pi_drag"
dd_drag2 = datadict_from_hdf5(header + drag2 +"/data")

# %%
Rabi_drag = dd_drag['s11']['values']
imag_drag = Rabi_drag.imag
drag = dd_drag['beta']['values']
I_drag = (Rabi_drag.real)
Q_drag = (Rabi_drag.imag)

Rabi_drag1 = dd_drag1['s11']['values']
imag_drag1 = Rabi_drag1.imag
drag1 = dd_drag1['beta']['values']
I_drag1 = (Rabi_drag1.real)
Q_drag1 = (Rabi_drag1.imag)

Rabi_drag2 = dd_drag2['s11']['values']
imag_drag2 = Rabi_drag2.imag
drag2 = dd_drag2['beta']['values']
I_drag2 = (Rabi_drag2.real)
Q_drag2 = (Rabi_drag2.imag)

# %%
def PCA_transform1(Re_c_amp, Im_c_amp, Re_c_drag, Im_c_drag):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c_amp]).T, np.array([Im_c_amp]).T], axis = 1)
    c1_data = np.concatenate([np.array([Re_c_drag]).T, np.array([Im_c_drag]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    
    c1_pca = pca.transform(c1_data)
    c1_PCA1 = c1_pca.T[0]
    c1_PCA2 = c1_pca.T[1]
    return c_PCA1, c_PCA2, c1_PCA1, c1_PCA2,

# %%
PCA_drag = PCA_transform1(I_amp, Q_amp, I_drag, Q_drag)
y = PCA_drag[0]
x = amp
y0 = PCA_drag[2]
x0 = drag

PCA_drag1 = PCA_transform1(I_amp, Q_amp, I_drag1, Q_drag1)
y1 = PCA_drag1[2]
x1 = drag1

PCA_drag2 = PCA_transform1(I_amp, Q_amp, I_drag2, Q_drag2)
y2 = PCA_drag2[2]
x2 = drag2


plt.plot(x, y)
plt.show()

# %%
plt.plot(x0, y0)
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.show()

# %%
par_ini= {
    'amp': 0.0002,
    'phi0':np.pi/2,
    'detun':1/0.8,
    'const':0.0003
}

par_min = {
    'amp': 0,
    'phi0':-2*np.pi,
    'detun':-np.inf,
    'const':0
}

par_max = {
    'amp': np.inf,
    'phi0':2*np.pi,
    'detun':np.inf,
    'const':np.inf,
}

par_vary = {
    'amp': True,
    'phi0':True,
    'detun':True,
    'const':True
}

# %%
model = lmfit.Model(Rabi)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )
    
result0 = model.fit(data = y0, params = params, delay = x0)
result1 = model.fit(data = y1, params = params, delay = x1)
result2 = model.fit(data = y2, params = params, delay = x2)

# %%
result0
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>21</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 5.4606e-08</td><td></td></tr><tr><td>reduced chi-square</td><td> 5.6295e-10</td><td></td></tr><tr><td>Akaike info crit.</td><td>-2147.16257</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-2136.70209</td><td></td></tr><tr><td>R-squared</td><td> 0.97784142</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  2.1135e-04 </td><td>  3.2342e-06 </td><td> (1.53%) </td><td> 0.0002 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  1.15104633 </td><td>  0.08693328 </td><td> (7.55%) </td><td> 1.5707963267948966 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  1.14249168 </td><td>  0.01344709 </td><td> (1.18%) </td><td> 1.25 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  2.9677e-04 </td><td>  3.0051e-06 </td><td> (1.01%) </td><td> 0.0003 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>+0.9814</td></tr><tr><td>detun</td><td>const</td><td>-0.6033</td></tr><tr><td>phi0</td><td>const</td><td>-0.5861</td></tr><tr><td>amp</td><td>const</td><td>-0.1262</td></tr></table>

# %%
res0 = (-2*np.pi-1.15104633)/(2*np.pi*1.14249168)
res0
# Out:
# -1.0356265466609655

# %%
result1
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>31</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 6.8576e-08</td><td></td></tr><tr><td>reduced chi-square</td><td> 7.0697e-10</td><td></td></tr><tr><td>Akaike info crit.</td><td>-2124.15453</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-2113.69404</td><td></td></tr><tr><td>R-squared</td><td> 0.96695335</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  2.1176e-04 </td><td>  3.9844e-06 </td><td> (1.88%) </td><td> 0.0002 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  4.30230786 </td><td>  0.05914474 </td><td> (1.37%) </td><td> 1.5707963267948966 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  1.63131373 </td><td>  0.00908602 </td><td> (0.56%) </td><td> 1.25 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  2.9635e-04 </td><td>  2.8191e-06 </td><td> (0.95%) </td><td> 0.0003 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>+0.9565</td></tr><tr><td>phi0</td><td>const</td><td>+0.2569</td></tr><tr><td>detun</td><td>const</td><td>+0.2413</td></tr><tr><td>amp</td><td>const</td><td>-0.2341</td></tr></table>

# %%
result2
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>59</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 2.6154e-07</td><td></td></tr><tr><td>reduced chi-square</td><td> 2.6963e-09</td><td></td></tr><tr><td>Akaike info crit.</td><td>-1988.94999</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-1978.48951</td><td></td></tr><tr><td>R-squared</td><td> 0.88274145</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  1.9883e-04 </td><td>  7.4212e-06 </td><td> (3.73%) </td><td> 0.0002 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  6.28318531 </td><td>  0.22259603 </td><td> (3.54%) </td><td> 1.5707963267948966 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  1.94716397 </td><td>  0.02185107 </td><td> (1.12%) </td><td> 1.25 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  2.9200e-04 </td><td>  5.5994e-06 </td><td> (1.92%) </td><td> 0.0003 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>-0.9680</td></tr><tr><td>detun</td><td>const</td><td>+0.3848</td></tr><tr><td>phi0</td><td>const</td><td>-0.3743</td></tr><tr><td>amp</td><td>detun</td><td>-0.1299</td></tr><tr><td>amp</td><td>phi0</td><td>+0.1284</td></tr></table>

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(drag)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result0.plot_fit(ax = ax)
plt.plot(x0,result0.init_fit)


plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(drag)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result1.plot_fit(ax = ax)
plt.plot(x1,result1.init_fit)


plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(drag)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result2.plot_fit(ax = ax)

plt.plot(x2,result2.init_fit)


plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %% [markdown]
# T1

# %%
def Dephase(delay, amp, gamma, const):
    return amp*np.exp(-gamma*delay) + const

t1 ="/2023-09-14/2023-09-14T154646_7916e176-td_ef_T1"

dd_t1 = datadict_from_hdf5(header + t1 +"/data")

# %%
s11_t1 = dd_t1['s11']['values']
imag_t1 = s11_t1.imag
delay_t1 = dd_t1['delay']['values']

I_t1 = (s11_t1.real)
Q_t1 = (s11_t1.imag)

PCA_t1 = PCA_transform(I_t1, Q_t1)

y_t1 = PCA_t1[0]
x_t1 = delay_t1

plt.plot(x_t1, y_t1)
plt.show()

# %%
par_ini_t1 = {
    'gamma': 1/20000,
    'amp':40,
    'const':-5
}

par_min_t1 = {
    'gamma': 0,
    'amp':0,
    'const':-np.inf
}

par_max_t1 = {
    'gamma': np.inf,
    'amp':np.inf,
    'const':np.inf,
}

par_vary_t1 = {
    'gamma': True,
    'amp':True,
    'const':True
}

# %%
model = lmfit.Model(Dephase)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini_t1[name],
    min = par_min_t1[name],
    max = par_max_t1[name],
    vary = par_vary_t1[name]
    )
result_t1 = model.fit(data = y_t1, params = params, delay = x_t1)
result_t1
# Out:
# <h2> Model</h2> Model(Dephase) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>29</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>3</td><td></td></tr><tr><td>chi-square</td><td> 492.839540</td><td></td></tr><tr><td>reduced chi-square</td><td> 5.02897490</td><td></td></tr><tr><td>Akaike info crit.</td><td> 166.091376</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 173.936738</td><td></td></tr><tr><td>R-squared</td><td> 0.91066441</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  40.2748948 </td><td>  1.56858521 </td><td> (3.89%) </td><td> 40 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> gamma </td><td>  1.6746e-04 </td><td>  1.0744e-05 </td><td> (6.42%) </td><td> 5e-05 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td> -2.58619719 </td><td>  0.25546524 </td><td> (9.88%) </td><td> -5 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>amp</td><td>gamma</td><td>+0.5832</td></tr><tr><td>gamma</td><td>const</td><td>+0.3667</td></tr></table>

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("T1")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result_t1.plot_fit(ax = ax)
plt.plot(delay_t1,result_t1.init_fit)

plt.xlabel("delay (ns)")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
T1 = (1/1.6746e-04)*1e-9	
T1
# Out:
# 5.971575301564552e-06

# %% [markdown]
# ## no data
#
# T2_star

# %%
t2e = "/2023-07-01/2023-07-01T181335_8e8e04ba-td_ge_T2e"
dd_t2e = datadict_from_hdf5(header + t2e +"/data")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\K_Sunada\analysis\CDY148-ef_calibration.ipynb Cell 41 line 2
#       <a href='vscode-notebook-cell:/d%3A/K_Sunada/analysis/CDY148-ef_calibration.ipynb#X52sZmlsZQ%3D%3D?line=0'>1</a> t2e = "/2023-07-01/2023-07-01T181335_8e8e04ba-td_ge_T2e"
# ----> <a href='vscode-notebook-cell:/d%3A/K_Sunada/analysis/CDY148-ef_calibration.ipynb#X52sZmlsZQ%3D%3D?line=1'>2</a> dd_t2e = datadict_from_hdf5(header + t2e +"/data")
#
# File d:\K_Sunada\.venv\lib\site-packages\plottr\data\datadict_storage.py:263, in datadict_from_hdf5(path, groupname, startidx, stopidx, structure_only, ignore_unequal_lengths, file_timeout)
#     261 filepath = _data_file_path(path)
#     262 if not filepath.exists():
# --> 263     raise ValueError("Specified file does not exist.")
#     265 if startidx is None:
#     266     startidx = 0
#
# ValueError: Specified file does not exist.

# %%
s11_t2e = dd_t2e['s11']['values']
imag_t2e = s11_t2e.imag
delay_t2e = dd_t2e['delay']['values']

I_t2e = (s11_t2e.real)
Q_t2e = (s11_t2e.imag)

PCA_t2e = PCA_transform(I_t2e, Q_t2e)

y_t2e = PCA_t2e[0]
x_t2e = delay_t2e

plt.plot(x_t2e, y_t2e)
plt.show()

# %%
par_ini_t2e = {
    'gamma': 1/2000,
    'amp':70,
    'const':0
}

par_min_t2e = {
    'gamma': 0,
    'amp':0,
    'const':-np.inf
}

par_max_t2e = {
    'gamma': np.inf,
    'amp':np.inf,
    'const':np.inf,
}

par_vary_t2e = {
    'gamma': True,
    'amp':True,
    'const':True
}

# %%
model = lmfit.Model(Dephase)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini_t2e[name],
    min = par_min_t2e[name],
    max = par_max_t2e[name],
    vary = par_vary_t2e[name]
    )
result_t2e = model.fit(data = y_t2e, params = params, delay = x_t2e)
result_t2e
# Out:
# <h2> Model</h2> Model(Dephase) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>29</td><td></td></tr><tr><td># data points</td><td>51</td><td></td></tr><tr><td># variables</td><td>3</td><td></td></tr><tr><td>chi-square</td><td> 191.594875</td><td></td></tr><tr><td>reduced chi-square</td><td> 3.99155989</td><td></td></tr><tr><td>Akaike info crit.</td><td> 73.5014316</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 79.2969085</td><td></td></tr><tr><td>R-squared</td><td> 0.96665825</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  68.3281014 </td><td>  1.97040220 </td><td> (2.88%) </td><td> 70 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> gamma </td><td>  0.00132869 </td><td>  7.9142e-05 </td><td> (5.96%) </td><td> 0.0005 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td> -2.43852809 </td><td>  0.29547471 </td><td> (12.12%) </td><td> 0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>amp</td><td>gamma</td><td>+0.3687</td></tr><tr><td>gamma</td><td>const</td><td>+0.2337</td></tr><tr><td>amp</td><td>const</td><td>-0.1195</td></tr></table>

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("T2")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result_t2e.plot_fit(ax = ax)
plt.plot(delay_t2e,result_t2e.init_fit)

plt.xlabel("delay (ns)")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
T2 = (1/0.00132869)*1e-9	
T2
# Out:
# 7.526210026416998e-07

# %% [markdown]
# T2 star

# %%
def Damping(delay, amp, gamma, omega, phi0, const):
    return const + amp * np.exp(- gamma*delay)*np.cos(omega*delay + phi0)

# %%
t2 = "/2023-07-01/2023-07-01T182745_892e135d-td_ge_T2r1d"
dd_t2 = datadict_from_hdf5(header + t2 +"/data")

# %%
s11_t2 = dd_t2['s11']['values']
imag_t2 = s11_t2.imag
delay_t2 = dd_t2['delay']['values']

I_t2 = (s11_t2.real)
Q_t2 = (s11_t2.imag)

PCA_t2 = PCA_transform(I_t2, Q_t2)

y_t2 = PCA_t2[0]
x_t2 = delay_t2

plt.plot(x_t2, y_t2)
plt.show()

# %%
par_ini_t2 = {
    'amp':60,
    'gamma': 1/1500,
    'omega':2*np.pi/500,
    'phi0':0,
    'const':0
}

par_min_t2 = {
    'amp':-np.inf,
    'gamma': 0,
    'omega':-2*np.pi,
    'phi0':-2*np.pi,
    'const':-np.inf
}

par_max_t2 = {
    'amp':np.inf,
    'gamma': np.inf,
    'omega':2*np.pi,
    'phi0':2*np.pi,
    'const':np.inf
}

par_vary_t2 = {
    'amp':True,
    'gamma': True,
    'omega':True,
    'phi0':True,
    'const':True
}

# %%
model = lmfit.Model(Damping)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini_t2[name],
    min = par_min_t2[name],
    max = par_max_t2[name],
    vary = par_vary_t2[name]
    )
result_t2 = model.fit(data = y_t2, params = params, delay = x_t2)
result_t2
# Out:
# <h2> Model</h2> Model(Damping) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>43</td><td></td></tr><tr><td># data points</td><td>31</td><td></td></tr><tr><td># variables</td><td>5</td><td></td></tr><tr><td>chi-square</td><td> 97.7683953</td><td></td></tr><tr><td>reduced chi-square</td><td> 3.76032290</td><td></td></tr><tr><td>Akaike info crit.</td><td> 45.6070391</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 52.7769751</td><td></td></tr><tr><td>R-squared</td><td> 0.98958790</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  69.5196638 </td><td>  1.88680504 </td><td> (2.71%) </td><td> 60 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> gamma </td><td>  0.00157781 </td><td>  6.5042e-05 </td><td> (4.12%) </td><td> 0.0006666666666666666 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> omega </td><td>  0.01245770 </td><td>  6.9543e-05 </td><td> (0.56%) </td><td> 0.012566370614359173 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> phi0 </td><td>  0.52254294 </td><td>  0.03031269 </td><td> (5.80%) </td><td> 0 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> const </td><td> -0.43875330 </td><td>  0.35377664 </td><td> (80.63%) </td><td> 0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>omega</td><td>phi0</td><td>-0.7012</td></tr><tr><td>amp</td><td>gamma</td><td>+0.6482</td></tr><tr><td>amp</td><td>phi0</td><td>+0.3063</td></tr><tr><td>amp</td><td>omega</td><td>-0.2258</td></tr><tr><td>gamma</td><td>phi0</td><td>+0.2099</td></tr><tr><td>phi0</td><td>const</td><td>+0.1682</td></tr><tr><td>gamma</td><td>omega</td><td>-0.1535</td></tr><tr><td>omega</td><td>const</td><td>-0.1258</td></tr></table>

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("T2star")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result_t2.plot_fit(ax = ax)
plt.plot(delay_t2,result_t2.init_fit)

plt.xlabel("delay (ns)")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
T2_star = (1/0.00157781	)*1e-9	
T2_star
# Out:
# 6.337898733054044e-07

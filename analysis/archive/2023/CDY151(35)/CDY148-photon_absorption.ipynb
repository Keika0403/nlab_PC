# %% [markdown]
# ## 9/20 photon absorption -CL5R

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from scipy import signal
from plottr.data.datadict_storage import datadict_from_hdf5
import lmfit

# %%
import sklearn
from sklearn.decomposition import PCA

# %% [markdown]
# fogi timing

# %%
header = "D:/K_sunada/result/CDY148/"
data = "/2023-09-20/2023-09-20T100458_b7af0588-td_ab_fogi_timing_sweep"
dd = datadict_from_hdf5(header+data+"/data")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\K_Sunada\analysis\CDY159\CDY148-photon_absorption.ipynb Cell 5 line 3
#       <a href='vscode-notebook-cell:/d%3A/K_Sunada/analysis/CDY159/CDY148-photon_absorption.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> header = "D:/K_sunada/result/CDY148/"
#       <a href='vscode-notebook-cell:/d%3A/K_Sunada/analysis/CDY159/CDY148-photon_absorption.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> data = "/2023-09-20/2023-09-20T100458_b7af0588-td_ab_fogi_timing_sweep"
# ----> <a href='vscode-notebook-cell:/d%3A/K_Sunada/analysis/CDY159/CDY148-photon_absorption.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> dd = datadict_from_hdf5(header+data+"/data")
#
# File d:\K_Sunada\.venv\lib\site-packages\plottr\data\datadict_storage.py:263, in datadict_from_hdf5(path, groupname, startidx, stopidx, structure_only, ignore_unequal_lengths, file_timeout)
#     261 filepath = _data_file_path(path)
#     262 if not filepath.exists():
# --> 263     raise ValueError("Specified file does not exist.")
#     265 if startidx is None:
#     266     startidx = 0
#
# ValueError: Specified file does not exist.

# %%
def Lorentzian(freq, amp, const, center, k):
    return const - amp*k**2/((freq-center)**2 + k**2)

# %%
def PCA_transform(Re_c, Im_c):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c]).T, np.array([Im_c]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    return c_PCA1, c_PCA2

# %%
timing = dd['s11']['values']
#imag_ge = Rabi_ge.imag
Fogi_timing = dd['fogi_timing']['values']

I = (timing.real)
Q = (timing.imag)

PCAfogi = PCA_transform(I, Q)

# %%
y = PCAfogi[0]
x = Fogi_timing

plt.plot(x, -y)
plt.show()

# %%
par_ini = {
    'amp': 50,
    'const':20,
    'center':850,
    'k':0.025
}

par_min = {
    'amp': 0,
    'const':-np.inf,
    'center':0,
    'k':0
}

par_max = {
    'amp': np.inf,
    'const':np.inf,
    'center':np.inf,
    'k':np.inf
}

par_vary = {
    'amp': True,
    'const':True,
    'center':True,
    'k':True
}

# %%
model = lmfit.Model(Lorentzian)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )

result = model.fit(data = -y, params=params, freq = x)
result
# Out:
# <h2> Model</h2> Model(Lorentzian) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>92</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 1890.20346</td><td></td></tr><tr><td>reduced chi-square</td><td> 19.4866336</td><td></td></tr><tr><td>Akaike info crit.</td><td> 303.861243</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 314.321725</td><td></td></tr><tr><td>R-squared</td><td> 0.94209167</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  67.0307626 </td><td>  2.44326540 </td><td> (3.64%) </td><td> 50 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  40.3663710 </td><td>  2.66710017 </td><td> (6.61%) </td><td> 20 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> center </td><td>  878.685903 </td><td>  4.36481579 </td><td> (0.50%) </td><td> 850 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> k </td><td>  298.993676 </td><td>  17.6494358 </td><td> (5.90%) </td><td> 0.025 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>amp</td><td>const</td><td>+0.9199</td></tr><tr><td>const</td><td>k</td><td>+0.9063</td></tr><tr><td>amp</td><td>k</td><td>+0.7152</td></tr><tr><td>amp</td><td>center</td><td>+0.1753</td></tr><tr><td>const</td><td>center</td><td>+0.1663</td></tr></table>

# %%
fig, ax = plt.subplots(dpi=80)
result.plot_fit(ax = ax)
plt.show()

# %%
fogi_timing = "/2023-09-21/2023-09-21T172723_b0a8025c-td_ab_fogi_timing_sweep"
dd_fogi_timing = datadict_from_hdf5(header + fogi_timing +"/data")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\K_Sunada\analysis\CDY159\CDY148-photon_absorption.ipynb Cell 13 line 2
#       <a href='vscode-notebook-cell:/d%3A/K_Sunada/analysis/CDY159/CDY148-photon_absorption.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> fogi_timing = "/2023-09-21/2023-09-21T172723_b0a8025c-td_ab_fogi_timing_sweep"
# ----> <a href='vscode-notebook-cell:/d%3A/K_Sunada/analysis/CDY159/CDY148-photon_absorption.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a> dd_fogi_timing = datadict_from_hdf5(header + fogi_timing +"/data")
#
# File d:\K_Sunada\.venv\lib\site-packages\plottr\data\datadict_storage.py:263, in datadict_from_hdf5(path, groupname, startidx, stopidx, structure_only, ignore_unequal_lengths, file_timeout)
#     261 filepath = _data_file_path(path)
#     262 if not filepath.exists():
# --> 263     raise ValueError("Specified file does not exist.")
#     265 if startidx is None:
#     266     startidx = 0
#
# ValueError: Specified file does not exist.

# %%
x_timing = dd_fogi_timing['fogi_timing']['values']
y_timing = dd_fogi_timing['s11']['values'].imag

# %%
fig, ax = plt.subplots(dpi=80)

#plt.title("fogi duration")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
plt.plot(x_timing ,y_timing, marker = "o")

plt.xlabel("fogi timing (ns)")
plt.ylabel("Im[S11] (a.u.)")


plt.show()

# %% [markdown]
# photon amp

# %% [markdown]
# freq

# %%
data1 = "/2023-09-20/2023-09-20T135505_ddc12220-td_ab_ph_freq_sweep"
dd1 = datadict_from_hdf5(header+data1+"/data")

dd1
# Out:
# s11: (1426,)
#   ⌙ fogi_frequency (Hz): (1426,)
#   ⌙ photon_frequency (Hz): (1426,)

# %%
xs = []
ys = []

for i in range(31):
    ini = 46*i
    fin = 46*(1+i)
    x = dd1['fogi_frequency']['values'][ini:fin]
    ph = dd1['photon_frequency']['values'][ini:fin]
    y = dd1['s11']['values'][ini:fin].imag
    xs.append(x)
    ys.append(y)

# %%
plt.plot(xs[20], ys[20])
plt.show()

# %%
timing = dd1['s11']['values']
#imag_ge = Rabi_ge.imag
Fogi_timing = dd1['fogi_timing']['values']

I = (timing.real)
Q = (timing.imag)

PCAfogi = PCA_transform(I, Q)
y = PCAfogi[0]
x = Fogi_timing

plt.plot(x, -y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\K_Sunada\analysis\CDY148-photon_absorption.ipynb Cell 19 line 3
#       <a href='vscode-notebook-cell:/d%3A/K_Sunada/analysis/CDY148-photon_absorption.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> timing = dd1['s11']['values']
#       <a href='vscode-notebook-cell:/d%3A/K_Sunada/analysis/CDY148-photon_absorption.ipynb#X24sZmlsZQ%3D%3D?line=1'>2</a> #imag_ge = Rabi_ge.imag
# ----> <a href='vscode-notebook-cell:/d%3A/K_Sunada/analysis/CDY148-photon_absorption.ipynb#X24sZmlsZQ%3D%3D?line=2'>3</a> Fogi_timing = dd1['fogi_timing']['values']
#       <a href='vscode-notebook-cell:/d%3A/K_Sunada/analysis/CDY148-photon_absorption.ipynb#X24sZmlsZQ%3D%3D?line=4'>5</a> I = (timing.real)
#       <a href='vscode-notebook-cell:/d%3A/K_Sunada/analysis/CDY148-photon_absorption.ipynb#X24sZmlsZQ%3D%3D?line=5'>6</a> Q = (timing.imag)
#
# KeyError: 'fogi_timing'

# %%
par_ini = {
    'amp': 50,
    'const':20,
    'center':850,
    'k':0.025
}

par_min = {
    'amp': 0,
    'const':-np.inf,
    'center':0,
    'k':0
}

par_max = {
    'amp': np.inf,
    'const':np.inf,
    'center':np.inf,
    'k':np.inf
}

par_vary = {
    'amp': True,
    'const':True,
    'center':True,
    'k':True
}
model = lmfit.Model(Lorentzian)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )

result = model.fit(data = -y, params=params, freq = x)
result
fig, ax = plt.subplots(dpi=80)
result.plot_fit(ax = ax)
plt.show()

# %%
data = "/2023-09-22/2023-09-22T141844_7ffc0276-td_ab_ph_freq_sweep"
dd = datadict_from_hdf5(header+data+"/data")
x = dd['photon_frequency']['values']
y = dd['fogi_frequency']['values']
z = dd['s11']['values'].imag

# %%
x1 = dd['fogi_frequency']['values'][21*10:21*11-1]
z1 = dd['s11']['values'][21*10:21*11-1].imag

# %%
plt.plot(x1, z1, marker = "o")
plt.xlabel("fogi frequency (GHz)")
plt.ylabel("Im[S11] (a.u.)")

#plt.xlim(5.671, 5.693)

plt.show()

# %%
cm = plt.cm.get_cmap('Blues')
fig= plt.figure()
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
ax = fig.add_axes((0.1, 0.1, 0.9, 0.9))
ax.set_xlabel("photon_frequency(Hz)")
ax.set_ylabel("drive_frequency(Hz)")

maingraph = ax.scatter(x, y, c=z, vmin=min(z), vmax=max(z), cmap=cm)
c = 
fig.colorbar(c)
plt.show()
# Out:
# C:\Users\qipe\AppData\Local\Temp\ipykernel_16152\1949104814.py:1: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cm = plt.cm.get_cmap('Blues')

# %%
cm = plt.cm.get_cmap('Blues')
fig= plt.figure()
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
ax = fig.add_axes((0.1, 0.1, 0.9, 0.9))
ax.set_xlabel("fogi frequency(Hz)")
ax.set_ylabel("photon frequency(Hz)")
ax.set_ylim(5.658, 5.696)

maingraph = ax.pcolormesh( np.unique(x),np.unique(y), z.reshape(21, 21).T, vmin=min(z), vmax=max(z), cmap=cm, shading='auto')
plt.colorbar(maingraph)
plt.show()
# Out:
# C:\Users\qipe\AppData\Local\Temp\ipykernel_17332\2082817544.py:1: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cm = plt.cm.get_cmap('Blues')

# %% [markdown]
# photon-fogi freq

# %%
data2 = "/2023-09-22/2023-09-22T141844_7ffc0276-td_ab_ph_freq_sweep"
dd2 = datadict_from_hdf5(header+data2+"/data")

# %%
dd2
# Out:
# s11: (441,)
#   ⌙ fogi_frequency (Hz): (441,)
#   ⌙ photon_frequency (Hz): (441,)

# %%
xs = []
ys = []

for i in range(21):
    ini = 21*i
    fin = 21*(1+i)
    x = dd1['fogi_frequency']['values'][ini:fin]
    ph = dd1['photon_frequency']['values'][ini:fin]
    y = dd1['s11']['values'][ini:fin].imag
    xs.append(x)
    ys.append(y)

# plt.plot(xs[10], ys[10])
# plt.show()

# %%
timing = dd1['s11']['values']
#imag_ge = Rabi_ge.imag
Fogi_timing = dd1['fogi_timing']['values']

I = (timing.real)
Q = (timing.imag)

PCAfogi = PCA_transform(I, Q)
y = PCAfogi[0]
x = Fogi_timing

plt.plot(x, -y)
plt.show()

# %%
par_ini = {
    'amp': 50,
    'const':20,
    'center':850,
    'k':0.025
}

par_min = {
    'amp': 0,
    'const':-np.inf,
    'center':0,
    'k':0
}

par_max = {
    'amp': np.inf,
    'const':np.inf,
    'center':np.inf,
    'k':np.inf
}

par_vary = {
    'amp': True,
    'const':True,
    'center':True,
    'k':True
}
model = lmfit.Model(Lorentzian)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )

result = model.fit(data = -y, params=params, freq = x)
result
fig, ax = plt.subplots(dpi=80)
result.plot_fit(ax = ax)
plt.show()
data = "/2023-09-20/2023-09-20T110244_c994cdb5-td_ab_ph_freq_sweep"
dd = datadict_from_hdf5(header+data+"/data")
x = dd['photon_frequency']['values']
y = dd['fogi_frequency']['values']
z = dd['s11']['values'].imag

# %% [markdown]
# absorption rate - fogi & foton: square

# %%
data = "/2023-09-20/2023-09-20T204417_07f60e62-td_ab_reflection"
#fogi: square, 1000ns, 0.9V, timing:photon+200ns
#photon: square, 1000ns, 0.08V

# %%
dd = datadict_from_hdf5(header+data+"/data")
x = dd['time']['values']
y = dd['waveform']['values']
y1 = dd['waveform1']['values']
y2 = dd['waveform2']['values']

# %%
def waveform_show(data):
    header = "D:/K_sunada/result/CDY148/"
    dd = datadict_from_hdf5(header+data+"/data")
    x = dd['time']['values']
    y = dd['waveform']['values']# - dd['waveform1']['values']
    y1 = dd['waveform1']['values']
    y2 = dd['waveform2']['values']

    fig, (ax0) = plt.subplots(nrows=1)
    ax0.set_title("abosorption")
    ax0.set_xlabel('time(ns)')
    ax0.set_ylabel('waveform(V)')
    ax0.plot(x,  y)
    ax0.tick_params(axis="x", direction="in")
    ax0.tick_params(axis="y", direction="in")
    ax0.set_ylim(-0.0005, 0.0017)

    fig, (ax1) = plt.subplots(nrows=1)
    ax1.set_title("no absorption(zero fogi)")
    ax1.set_xlabel('time(ns)')
    ax1.set_ylabel('waveform(V)')
    ax1.plot(x,  y1)
    ax1.tick_params(axis="x", direction="in")
    ax1.tick_params(axis="y", direction="in")
    ax1.set_ylim(-0.0005, 0.0017)

    fig, (ax2) = plt.subplots(nrows=1)
    ax2.set_title("noise(zero fogi & photon)")
    ax2.set_xlabel('time(ns)')
    ax2.set_ylabel('waveform(V)')
    ax2.plot(x,  y2)
    ax2.tick_params(axis="x", direction="in")
    ax2.tick_params(axis="y", direction="in")
    ax2.set_ylim(-0.0005, 0.0017)

    plt.tick_params(
                top='on',
                bottom='on`',
                left='on',
                right='on',
               )
    plt.show()

# %%
waveform_show(data)

# %%
def photon_energy(data):
    header = "D:/K_sunada/result/CDY148/"
    dd = datadict_from_hdf5(header+data+"/data")
    x = dd['time']['values']
    y = dd['waveform']['values'] #- dd['waveform1']['values']
    y1 = dd['waveform1']['values']
    y2 = dd['waveform2']['values']
    offset=np.mean(y)
    offset1=np.mean(y1)
    offset2=np.mean(y2)
    E = 0
    E1 = 0
    E2 = 0
    for t in range(len(x)):
        E = E + ((y[t]-offset)**2)*2
        E1 = E1 + ((y1[t]-offset1)**2)*2
        E2 = E2 + ((y2[t]-offset2)**2)*2

    rate = 1 - (E-E2)/(E1-E2)

    return E, E1, E2, rate

# %%
photon_energy(data)[3]
# Out:
# 0.008322054795219747

# %%
data1 = "/2023-09-22/2023-09-22T143739_24d1513f-td_ab_reflection"
#fogi: square, 1000ns, 0.9V, timing:photon-830ns
#photon: square, 800ns, 0.03V

# %%
photon_energy(data1)
# Out:
# (0.0001484211017742668,
#  0.00014444179349968998,
#  1.1451166102956378e-07,
#  -0.02757142117472422)

# %%
data2 = "/2023-09-21/2023-09-21T094857_a5b6aa1b-td_ab_reflection"
#fogi: square, 1000ns, 0.9V, timing:photon+0ns
#photon: square, 1000ns, 0.08V
photon_energy(data2)
# Out:
# (6.708595315767448e-05,
#  6.759169243846019e-05,
#  1.6609447137365717e-07,
#  0.007500701455144476)

# %% [markdown]
# absorption rate - fogi: square & photon: time reversed

# %%
data = "/2023-09-21/2023-09-21T102917_480c9226-td_photon_generation"
#fogi: square, 1000ns, 0.9V

dd = datadict_from_hdf5(header+data+"/data")
x = dd['time']['values']
y = dd['waveform']['values']

# %%
fig, (ax0) = plt.subplots(nrows=1)
ax0.set_xlabel('time(ns)')
ax0.set_ylabel('waveform(V)')
ax0.plot(x,  y[::-1])
ax0.tick_params(axis="x", direction="in")
ax0.tick_params(axis="y", direction="in")
#    ax0.set_ylim(-0.0005, 0.0017)

plt.tick_params(
                top='on',
                bottom='on`',
                left='on',
                right='on',
               )
plt.show()

# %%
header = "D:/K_sunada/result/CDY148/"
data_ph = "/2023-09-21/2023-09-21T102917_480c9226-td_photon_generation"
dd = datadict_from_hdf5(header+data_ph+"/data")
y_ph = dd['waveform']['values']

def y_lerp(y): #sennkeihokann
    y_new = []
    for i in range(len(y)-1):
        y_new.append(y[i])
        y_new.append((y[i]+y[i+1])/2)
    y_new.append(y[len(y)-1])
    return y_new-np.mean(y)

# %%
fig, (ax0) = plt.subplots(nrows=1)
ax0.set_xlabel('time(ns)')
ax0.set_ylabel('waveform(V)')
ax0.plot(y_lerp(x),  y_lerp(y_ph[::-1]))
ax0.tick_params(axis="x", direction="in")
ax0.tick_params(axis="y", direction="in")

plt.show()

# %% [markdown]
# ## 11/7 ge calibration - DPR1-L-120-35

# %% [markdown]
# ge_freq = (8.2779 -0.001898495)e9
#
# ge_pi_amp = 0.7505456737244419
#
#
# T1 = 5.285948679781458e-08
#
# T2 = 8.14e-06
#
# T2_star = 4.19e-06

# %%
from plottr.data.datadict_storage import datadict_from_hdf5
import numpy as np
import matplotlib.pyplot as plt
import lmfit

# %%
import sklearn
from sklearn.decomposition import PCA

# %%
def Rabi(delay, amp, phi0, detun, const):
    return - amp * np.cos(2*np.pi*detun*delay+phi0) + const

# %%
def PCA_transform(Re_c, Im_c):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c]).T, np.array([Im_c]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    return c_PCA1, c_PCA2

# %%
header = "D:/K_Sunada/result/CDY151/"

# %%
amp = "/2023-11-07/2023-11-07T160540_0f8e6b46-21_ge_pi_amp"
dd_amp = datadict_from_hdf5(header + amp +"/data")

# %%
Rabi_amp = dd_amp['s11']['values']
imag_amp = Rabi_amp.imag
amp = dd_amp['amplitude']['values']

# %%
def PCA_transform(Re_c, Im_c):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c]).T, np.array([Im_c]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    return c_PCA1, c_PCA2, pca

# %%
I_amp = (Rabi_amp.real)
Q_amp = (Rabi_amp.imag)
PCA_amp = PCA_transform(I_amp, Q_amp)

# %%
PCA_amp = PCA_transform(I_amp, Q_amp)
PCA_amp[0]
# Out:
# array([ 1.15217434e-04,  1.41782868e-04,  1.27152726e-04,  9.89008768e-05,
#         7.31313471e-05,  7.87392405e-05,  6.68581479e-05,  5.28337357e-05,
#         3.13997450e-05,  3.94527108e-05,  4.37198492e-06,  2.15384480e-05,
#         1.65595812e-05, -2.53996834e-05, -4.59001257e-05, -8.22850682e-05,
#        -7.10040105e-05, -2.50080866e-05, -5.47653971e-05, -5.35150791e-05,
#        -3.87427127e-06, -2.31301281e-05, -3.02487232e-05, -5.55813489e-06,
#         3.76686926e-05,  2.18309550e-05,  5.66358947e-06,  2.06373873e-05,
#         5.49060912e-05,  8.08330198e-05,  4.07391372e-05,  8.07228136e-05,
#         6.49376772e-05,  4.63305155e-05,  1.64835453e-05,  3.31940046e-05,
#         2.55810022e-05,  1.78879831e-05, -2.09024565e-05, -3.41842084e-05,
#        -3.61355549e-05, -5.86109619e-05, -4.05301723e-05, -8.07117651e-05,
#        -2.91508277e-05, -2.35778673e-05, -6.72511024e-05, -1.09594950e-05,
#         2.12048203e-06, -1.50946554e-05, -5.35021761e-06,  2.57690696e-05,
#         2.43389025e-05,  1.40389041e-05,  5.76368569e-05,  2.16962978e-05,
#         7.19584470e-05,  6.02871088e-05,  1.10659314e-04,  6.93339470e-05,
#         5.73736552e-05,  6.98308705e-05,  8.98448869e-05,  1.87618698e-05,
#         1.89673731e-05,  2.14735594e-05, -1.21258233e-05, -2.77934294e-06,
#         2.81179511e-06,  7.08633970e-06, -2.44147460e-05, -8.50224427e-05,
#        -4.56499001e-05, -7.78687261e-05, -4.93165645e-05, -6.52823597e-05,
#        -1.50105092e-05, -4.14704361e-05, -1.56011866e-05,  1.46486430e-05,
#        -2.83920020e-06, -1.33646512e-05, -4.64605597e-06,  2.72670681e-05,
#         1.88376755e-05,  2.03841804e-05,  4.48082774e-05,  4.15336066e-05,
#         5.51529509e-05,  6.37580165e-05,  4.83485931e-05,  4.69408767e-05,
#         3.70214700e-05,  2.53291886e-05,  1.07386734e-05,  9.16309218e-06,
#        -3.05907511e-05,  2.71959979e-06, -3.34019664e-05, -3.95020184e-05,
#        -6.38787881e-05, -5.85318712e-05, -9.44349625e-05, -8.51247435e-05,
#        -4.56730204e-05, -3.07866081e-05, -6.88484693e-05, -8.61180796e-05,
#        -8.02719491e-05, -4.73561958e-05, -2.46412402e-06,  3.63610446e-05,
#        -8.00952075e-07, -1.54780969e-05,  2.54701067e-05,  5.03116806e-05,
#         1.66210585e-05,  7.63820389e-06,  2.52983773e-05,  9.25981201e-05,
#         4.05151448e-05,  5.82039025e-05,  5.11540278e-05,  5.50657627e-05,
#         4.88755570e-05,  4.06770032e-05,  1.79501573e-05,  9.97878819e-06,
#        -1.55429540e-05, -1.31699487e-05, -6.03258672e-05, -5.95003322e-05,
#        -6.11486418e-05, -3.61599695e-05, -5.80723738e-05, -7.13667932e-05,
#        -9.43619004e-05, -7.94603163e-05, -7.25343697e-05, -8.65044133e-05,
#        -4.73323679e-05, -6.70474909e-05, -3.53107938e-05, -2.77611956e-05,
#        -2.34054692e-05, -3.71914170e-05, -4.36166353e-05, -8.47356084e-05,
#        -1.77527055e-05, -3.81551368e-05,  9.54344734e-06])

# %%
PCA_amp = PCA_transform(I_amp, Q_amp)
y = I_amp
x = amp

fig, (ax1) = plt.subplots(nrows=1)
ax1.set_xlabel('Amplitude (V)', size='large')
ax1.set_ylabel('PCA[$S_{11}$] (V)', size='large')
plt.rcParams["font.size"] = 17
plt.plot(x, PCA_amp[0])
ax1.tick_params(axis="x", direction="in")
ax1.tick_params(axis="y", direction="in")
ax1.set_xlim(0, 1)
# ax1.set_ylim(-48, 160)
plt.tick_params(
            top='on',
            bottom='on`',
            left='on',
            right='on',
            )
plt.show()

# %%
par_ini= {
    'amp': 0.00015/2,
    'phi0':np.pi/2,
    'detun':1/0.3,
    'const':0
}

par_min = {
    'amp': 0,
    'phi0':-2*np.pi,
    'detun':-np.inf,
    'const':0
}

par_max = {
    'amp': np.inf,
    'phi0':2*np.pi,
    'detun':np.inf,
    'const':np.inf,
}

par_vary = {
    'amp': True,
    'phi0':True,
    'detun':True,
    'const':True
}

# %%
model = lmfit.Model(Rabi)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )
    
result = model.fit(data = PCA_amp[0], params = params, delay = x)
result
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>59</td><td></td></tr><tr><td># data points</td><td>151</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 1.6237e-07</td><td></td></tr><tr><td>reduced chi-square</td><td> 1.1045e-09</td><td></td></tr><tr><td>Akaike info crit.</td><td>-3110.25415</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-3098.18503</td><td></td></tr><tr><td>R-squared</td><td> 0.59205780</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  5.5704e-05 </td><td> 7.5e-05 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  3.09201978 </td><td> 1.5707963267948966 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  3.33090988 </td><td> 3.3333333333333335 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  2.7911e-13 </td><td> 0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table>

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(amp)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result.plot_fit(ax = ax)
# plt.plot(x,result.init_fit)

plt.rcParams["font.size"] = 14
plt.tick_params(
            top='on',
            bottom='on`',
            left='on',
            right='on',
            )

# plt.plot(x_t1,result_t1.init_fit, label='init fit')

# ax.set_xlim(0, 250000)
ax.tick_params(axis="x", direction="in")
ax.tick_params(axis="y", direction="in")
ax.set_xlabel('Duration (ns)', size='large')
ax.set_ylabel('PCA[S$_{11}$] (arb. unit.)', size='large')

ax.legend()
plt.show()

# %%
np.pi/(3.33090988*2*np.pi)*5
# Out:
# 0.7505456737244419

# %% [markdown]
# ramsey

# %%
pl = "/2023-09-14/2023-09-14T145010_9100daf2-td_ge_T2r1d"
mi = "/2023-09-14/2023-09-14T145128_bf48a593-td_ge_T2r1d"
dd_pl = datadict_from_hdf5(header + pl +"/data")
dd_mi = datadict_from_hdf5(header + mi +"/data")

# %%
Rabi_pl = dd_pl['s11']['values']
imag_pl = Rabi_pl.imag
delay_pl = dd_pl['delay']['values']

Rabi_mi = dd_mi['s11']['values']
imag_mi = Rabi_mi.imag
delay_mi = dd_mi['delay']['values']

# %%
I_pl = (Rabi_pl.real)
Q_pl = (Rabi_pl.imag)
I_mi = (Rabi_mi.real)
Q_mi = (Rabi_mi.imag)


PCA_pl = PCA_transform(I_pl, Q_pl)
y_pl = PCA_pl[0]
x_pl = delay_pl

PCA_mi = PCA_transform(I_mi, Q_mi)
y_mi = PCA_mi[0]
x_mi = delay_mi



plt.plot(x_pl, y_pl)
plt.show()

# %%
par_ini_pl = {
    'amp': 35,
    'phi0':np.pi,
    'detun':1/150,
    'const':0
}

par_min_pl = {
    'amp': 0,
    'phi0':-2*np.pi,
    'detun':-np.inf,
    'const':0
}

par_max_pl = {
    'amp': np.inf,
    'phi0':2*np.pi,
    'detun':np.inf,
    'const':np.inf,
}

par_vary_pl = {
    'amp': True,
    'phi0':True,
    'detun':True,
    'const':True
}

# %%
model = lmfit.Model(Rabi)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini_pl[name],
    min = par_min_pl[name],
    max = par_max_pl[name],
    vary = par_vary_pl[name]
    )
    
result_pl = model.fit(data = y_pl, params = params, delay = x_pl)
result_pl
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>132</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 1229.13468</td><td></td></tr><tr><td>reduced chi-square</td><td> 12.6714916</td><td></td></tr><tr><td>Akaike info crit.</td><td> 260.393463</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 270.853945</td><td></td></tr><tr><td>R-squared</td><td> 0.97985325</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  34.3426506 </td><td>  0.50032879 </td><td> (1.46%) </td><td> 35 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  2.11120251 </td><td>  0.02932104 </td><td> (1.39%) </td><td> 3.141592653589793 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  0.00690290 </td><td>  8.0054e-06 </td><td> (0.12%) </td><td> 0.006666666666666667 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  0.03245938 </td><td>  0.35433236 </td><td> (1091.62%) </td><td> 0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>-0.8670</td></tr></table>

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(+5MHz)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result_pl.plot_fit(ax = ax)
plt.plot(x_pl,result_pl.init_fit)

plt.xlabel("delay (ns)")
plt.ylabel("mag[S11](a.u.)")


plt.show()

# %%
plt.plot(x_mi, y_mi)
plt.show()

# %%
par_ini_mi = {
    'amp': 40,
    'phi0':-np.pi/2,
    'detun':1/300,
    'const':0
}

par_min_mi = {
    'amp': 0,
    'phi0':-2*np.pi,
    'detun':-np.inf,
    'const':0
}

par_max_mi = {
    'amp': np.inf,
    'phi0':2*np.pi,
    'detun':np.inf,
    'const':np.inf,
}

par_vary_mi = {
    'amp': True,
    'phi0':True,
    'detun':True,
    'const':True
}

# %%
model = lmfit.Model(Rabi)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini_mi[name],
    min = par_min_mi[name],
    max = par_max_mi[name],
    vary = par_vary_mi[name]
    )
    
result_mi = model.fit(data = y_mi, params = params, delay = x_mi)
result_mi
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>116</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 1065.40377</td><td></td></tr><tr><td>reduced chi-square</td><td> 10.9835441</td><td></td></tr><tr><td>Akaike info crit.</td><td> 245.954851</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 256.415333</td><td></td></tr><tr><td>R-squared</td><td> 0.98213199</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  34.2443771 </td><td>  0.46937988 </td><td> (1.37%) </td><td> 40 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  0.58047852 </td><td>  0.02635325 </td><td> (4.54%) </td><td> -1.5707963267948966 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  0.00310591 </td><td>  7.3907e-06 </td><td> (0.24%) </td><td> 0.0033333333333333335 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  0.88736421 </td><td>  0.33309527 </td><td> (37.54%) </td><td> 0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>-0.8571</td></tr><tr><td>phi0</td><td>const</td><td>-0.1334</td></tr><tr><td>detun</td><td>const</td><td>+0.1283</td></tr></table>

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(-5MHz)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result_mi.plot_fit(ax = ax)
plt.plot(x_mi,result_pl.init_fit)

plt.xlabel("delay (ns)")
plt.ylabel("mag[S11](a.u.)")


plt.show()

# %%
detun = ((0.005-0.00690290)+ (0.00310591-0.005))/2 #GHz
detun
# Out:
# -0.001898495

# %% [markdown]
# drag

# %%
drag = "/2023-09-15/2023-09-15T152647_d8f7660a-td_ge_pi_drag"
dd_drag = datadict_from_hdf5(header + drag +"/data")

drag1 = "/2023-09-15/2023-09-15T152830_166689a7-td_ge_pi_drag"
dd_drag1 = datadict_from_hdf5(header + drag1 +"/data")

drag2 = "/2023-09-15/2023-09-15T153037_61d3963e-td_ge_pi_drag"
dd_drag2 = datadict_from_hdf5(header + drag2 +"/data")

# %%
Rabi_drag = dd_drag['s11']['values']
imag_drag = Rabi_drag.imag
drag = dd_drag['beta']['values']
I_drag = (Rabi_drag.real)
Q_drag = (Rabi_drag.imag)

Rabi_drag1 = dd_drag1['s11']['values']
imag_drag1 = Rabi_drag1.imag
drag1 = dd_drag1['beta']['values']
I_drag1 = (Rabi_drag1.real)
Q_drag1 = (Rabi_drag1.imag)

Rabi_drag2 = dd_drag2['s11']['values']
imag_drag2 = Rabi_drag2.imag
drag2 = dd_drag2['beta']['values']
I_drag2 = (Rabi_drag2.real)
Q_drag2 = (Rabi_drag2.imag)

# %%
def PCA_transform1(Re_c_amp, Im_c_amp, Re_c_drag, Im_c_drag):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c_amp]).T, np.array([Im_c_amp]).T], axis = 1)
    c1_data = np.concatenate([np.array([Re_c_drag]).T, np.array([Im_c_drag]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    
    c1_pca = pca.transform(c1_data)
    c1_PCA1 = c1_pca.T[0]
    c1_PCA2 = c1_pca.T[1]
    return c_PCA1, c_PCA2, c1_PCA1, c1_PCA2,

# %%
PCA_drag = PCA_transform1(I_amp, Q_amp, I_drag, Q_drag)
y = PCA_drag[0]
x = amp
y0 = PCA_drag[2]
x0 = drag

PCA_drag1 = PCA_transform1(I_amp, Q_amp, I_drag1, Q_drag1)
y1 = PCA_drag1[2]
x1 = drag1

PCA_drag2 = PCA_transform1(I_amp, Q_amp, I_drag2, Q_drag2)
y2 = PCA_drag2[2]
x2 = drag2


plt.plot(x, y)
plt.show()

# %%
plt.plot(x0, y0)
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.show()

# %%
par_ini= {
    'amp': 0.0002,
    'phi0':np.pi/2,
    'detun':1/0.8,
    'const':0.0003
}

par_min = {
    'amp': 0,
    'phi0':-2*np.pi,
    'detun':-np.inf,
    'const':0
}

par_max = {
    'amp': np.inf,
    'phi0':2*np.pi,
    'detun':np.inf,
    'const':np.inf,
}

par_vary = {
    'amp': True,
    'phi0':True,
    'detun':True,
    'const':True
}

# %%
model = lmfit.Model(Rabi)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )
    
result0 = model.fit(data = y0, params = params, delay = x0)
result1 = model.fit(data = y1, params = params, delay = x1)
result2 = model.fit(data = y2, params = params, delay = x2)

# %%
result0
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>21</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 5.4606e-08</td><td></td></tr><tr><td>reduced chi-square</td><td> 5.6295e-10</td><td></td></tr><tr><td>Akaike info crit.</td><td>-2147.16257</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-2136.70209</td><td></td></tr><tr><td>R-squared</td><td> 0.97784142</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  2.1135e-04 </td><td>  3.2342e-06 </td><td> (1.53%) </td><td> 0.0002 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  1.15104633 </td><td>  0.08693328 </td><td> (7.55%) </td><td> 1.5707963267948966 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  1.14249168 </td><td>  0.01344709 </td><td> (1.18%) </td><td> 1.25 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  2.9677e-04 </td><td>  3.0051e-06 </td><td> (1.01%) </td><td> 0.0003 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>+0.9814</td></tr><tr><td>detun</td><td>const</td><td>-0.6033</td></tr><tr><td>phi0</td><td>const</td><td>-0.5861</td></tr><tr><td>amp</td><td>const</td><td>-0.1262</td></tr></table>

# %%
res0 = (-2*np.pi-1.15104633)/(2*np.pi*1.14249168)
res0
# Out:
# -1.0356265466609655

# %%
result1
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>31</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 6.8576e-08</td><td></td></tr><tr><td>reduced chi-square</td><td> 7.0697e-10</td><td></td></tr><tr><td>Akaike info crit.</td><td>-2124.15453</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-2113.69404</td><td></td></tr><tr><td>R-squared</td><td> 0.96695335</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  2.1176e-04 </td><td>  3.9844e-06 </td><td> (1.88%) </td><td> 0.0002 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  4.30230786 </td><td>  0.05914474 </td><td> (1.37%) </td><td> 1.5707963267948966 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  1.63131373 </td><td>  0.00908602 </td><td> (0.56%) </td><td> 1.25 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  2.9635e-04 </td><td>  2.8191e-06 </td><td> (0.95%) </td><td> 0.0003 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>+0.9565</td></tr><tr><td>phi0</td><td>const</td><td>+0.2569</td></tr><tr><td>detun</td><td>const</td><td>+0.2413</td></tr><tr><td>amp</td><td>const</td><td>-0.2341</td></tr></table>

# %%
res1 = (-2*np.pi-	4.30230786)/(2*np.pi*1.63131373)
res1
# Out:
# -1.0327465107659664

# %%
result2
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>59</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 2.6154e-07</td><td></td></tr><tr><td>reduced chi-square</td><td> 2.6963e-09</td><td></td></tr><tr><td>Akaike info crit.</td><td>-1988.94999</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-1978.48951</td><td></td></tr><tr><td>R-squared</td><td> 0.88274145</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  1.9883e-04 </td><td>  7.4212e-06 </td><td> (3.73%) </td><td> 0.0002 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  6.28318531 </td><td>  0.22259603 </td><td> (3.54%) </td><td> 1.5707963267948966 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  1.94716397 </td><td>  0.02185107 </td><td> (1.12%) </td><td> 1.25 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  2.9200e-04 </td><td>  5.5994e-06 </td><td> (1.92%) </td><td> 0.0003 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>-0.9680</td></tr><tr><td>detun</td><td>const</td><td>+0.3848</td></tr><tr><td>phi0</td><td>const</td><td>-0.3743</td></tr><tr><td>amp</td><td>detun</td><td>-0.1299</td></tr><tr><td>amp</td><td>phi0</td><td>+0.1284</td></tr></table>

# %%
res2 = (-2*np.pi-6.28318531)/(2*np.pi*1.94716397)
res2
# Out:
# -1.027134864481332

# %%
beta = (res0 + res1 + res2)/3
beta
# Out:
# -1.0318359739694214

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(drag)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result0.plot_fit(ax = ax)
plt.plot(x0,result0.init_fit)


plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(drag)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result1.plot_fit(ax = ax)
plt.plot(x1,result1.init_fit)


plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(drag)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result2.plot_fit(ax = ax)

plt.plot(x2,result2.init_fit)


plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %% [markdown]
# half drag

# %%
drag = "/2023-09-16/2023-09-16T151219_fdd17738-td_ge_pi_drag"
dd_drag = datadict_from_hdf5(header + drag +"/data")

drag1 = "/2023-09-16/2023-09-16T151407_3e0e7afb-td_ge_pi_drag"
dd_drag1 = datadict_from_hdf5(header + drag1 +"/data")

drag2 = "/2023-09-16/2023-09-16T151547_7a192eb2-td_ge_pi_drag"
dd_drag2 = datadict_from_hdf5(header + drag2 +"/data")

# %%
Rabi_drag = dd_drag['s11']['values']
imag_drag = Rabi_drag.imag
drag = dd_drag['beta']['values']
I_drag = (Rabi_drag.real)
Q_drag = (Rabi_drag.imag)

Rabi_drag1 = dd_drag1['s11']['values']
imag_drag1 = Rabi_drag1.imag
drag1 = dd_drag1['beta']['values']
I_drag1 = (Rabi_drag1.real)
Q_drag1 = (Rabi_drag1.imag)

Rabi_drag2 = dd_drag2['s11']['values']
imag_drag2 = Rabi_drag2.imag
drag2 = dd_drag2['beta']['values']
I_drag2 = (Rabi_drag2.real)
Q_drag2 = (Rabi_drag2.imag)

# %%
def PCA_transform1(Re_c_amp, Im_c_amp, Re_c_drag, Im_c_drag):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c_amp]).T, np.array([Im_c_amp]).T], axis = 1)
    c1_data = np.concatenate([np.array([Re_c_drag]).T, np.array([Im_c_drag]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    
    c1_pca = pca.transform(c1_data)
    c1_PCA1 = c1_pca.T[0]
    c1_PCA2 = c1_pca.T[1]
    return c_PCA1, c_PCA2, c1_PCA1, c1_PCA2,

# %%
PCA_drag = PCA_transform1(I_amp, Q_amp, I_drag, Q_drag)
y = PCA_drag[0]
x = amp
y0 = PCA_drag[2]
x0 = drag

PCA_drag1 = PCA_transform1(I_amp, Q_amp, I_drag1, Q_drag1)
y1 = PCA_drag1[2]
x1 = drag1

PCA_drag2 = PCA_transform1(I_amp, Q_amp, I_drag2, Q_drag2)
y2 = PCA_drag2[2]
x2 = drag2


plt.plot(x, y)
plt.show()

# %%
plt.plot(x0, y0)
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.show()

# %%
par_ini= {
    'amp': 0.0001,
    'phi0':np.pi,
    'detun':1/1.5,
    'const':0.00015
}

par_min = {
    'amp': 0,
    'phi0':-2*np.pi,
    'detun':-np.inf,
    'const':0
}

par_max = {
    'amp': np.inf,
    'phi0':2*np.pi,
    'detun':np.inf,
    'const':np.inf,
}

par_vary = {
    'amp': True,
    'phi0':True,
    'detun':True,
    'const':True
}

# %%
model = lmfit.Model(Rabi)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )
    
result0 = model.fit(data = y0, params = params, delay = x0)
result1 = model.fit(data = y1, params = params, delay = x1)
result2 = model.fit(data = y2, params = params, delay = x2)

# %%
result0
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>26</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 6.2157e-08</td><td></td></tr><tr><td>reduced chi-square</td><td> 6.4079e-10</td><td></td></tr><tr><td>Akaike info crit.</td><td>-2134.08178</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-2123.62130</td><td></td></tr><tr><td>R-squared</td><td> 0.82200541</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  8.5760e-05 </td><td>  8.9679e-06 </td><td> (10.46%) </td><td> 0.0001 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  2.42785277 </td><td>  0.24200258 </td><td> (9.97%) </td><td> 3.141592653589793 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  0.55021086 </td><td>  0.05499572 </td><td> (10.00%) </td><td> 0.6666666666666666 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  1.7061e-04 </td><td>  1.0823e-05 </td><td> (6.34%) </td><td> 0.00015 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>+0.9871</td></tr><tr><td>detun</td><td>const</td><td>-0.9699</td></tr><tr><td>phi0</td><td>const</td><td>-0.9550</td></tr><tr><td>amp</td><td>const</td><td>+0.8970</td></tr><tr><td>amp</td><td>detun</td><td>-0.8916</td></tr><tr><td>amp</td><td>phi0</td><td>-0.8750</td></tr></table>

# %%
res0 = (0-2.42785277)/(2*np.pi*0.55021086)
res0
# Out:
# -0.7022848830080353

# %%
result1
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>21</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 6.5397e-08</td><td></td></tr><tr><td>reduced chi-square</td><td> 6.7419e-10</td><td></td></tr><tr><td>Akaike info crit.</td><td>-2128.94967</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-2118.48919</td><td></td></tr><tr><td>R-squared</td><td> 0.84575881</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  8.2411e-05 </td><td>  3.7164e-06 </td><td> (4.51%) </td><td> 0.0001 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  3.09326300 </td><td>  0.14688964 </td><td> (4.75%) </td><td> 3.141592653589793 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  0.70094528 </td><td>  0.03111746 </td><td> (4.44%) </td><td> 0.6666666666666666 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  1.6516e-04 </td><td>  4.1487e-06 </td><td> (2.51%) </td><td> 0.00015 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>+0.9507</td></tr><tr><td>detun</td><td>const</td><td>-0.7808</td></tr><tr><td>phi0</td><td>const</td><td>-0.7454</td></tr><tr><td>amp</td><td>detun</td><td>-0.2739</td></tr><tr><td>amp</td><td>phi0</td><td>-0.2670</td></tr><tr><td>amp</td><td>const</td><td>+0.1672</td></tr></table>

# %%
res1 = (0-3.09326300	)/(2*np.pi*0.70094528)
res1
# Out:
# -0.7023488291885859

# %%
result2
# Out:
# <h2> Model</h2> Model(Rabi) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>26</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 8.8494e-08</td><td></td></tr><tr><td>reduced chi-square</td><td> 9.1231e-10</td><td></td></tr><tr><td>Akaike info crit.</td><td>-2098.40015</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-2087.93966</td><td></td></tr><tr><td>R-squared</td><td> 0.78401096</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  7.9108e-05 </td><td>  4.2658e-06 </td><td> (5.39%) </td><td> 0.0001 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> phi0 </td><td>  3.69712872 </td><td>  0.12841926 </td><td> (3.47%) </td><td> 3.141592653589793 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> detun </td><td>  0.86133295 </td><td>  0.02328538 </td><td> (2.70%) </td><td> 0.6666666666666666 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  1.8131e-04 </td><td>  3.2454e-06 </td><td> (1.79%) </td><td> 0.00015 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>phi0</td><td>detun</td><td>+0.8977</td></tr><tr><td>phi0</td><td>const</td><td>-0.2855</td></tr><tr><td>detun</td><td>const</td><td>-0.2764</td></tr><tr><td>amp</td><td>const</td><td>-0.2750</td></tr><tr><td>amp</td><td>detun</td><td>+0.1436</td></tr><tr><td>amp</td><td>phi0</td><td>+0.1063</td></tr></table>

# %%
res2 = (0-3.69712872)/(2*np.pi*0.86133295)
res2
# Out:
# -0.6831461759764466

# %%
beta = (res0 + res1 + res2)/3
beta
# Out:
# -0.6959266293910226

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(drag)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result0.plot_fit(ax = ax)
plt.plot(x0,result0.init_fit)


plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(drag)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result1.plot_fit(ax = ax)
plt.plot(x1,result1.init_fit)


plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("Rabi(drag)")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result2.plot_fit(ax = ax)

plt.plot(x2,result2.init_fit)


plt.xlabel("beta")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %% [markdown]
# T1

# %%
def Dephase(delay, amp, gamma, const):
    return amp*np.exp(-gamma*delay) + const

t1 ="/2023-11-07/2023-11-07T163002_76dcb5e3-24_ge_T1"

dd_t1 = datadict_from_hdf5(header + t1 +"/data")

# %%
s11_t1 = dd_t1['s11']['values'][0:100]
imag_t1 = s11_t1.imag
delay_t1 = dd_t1['delay']['values'][0:100]

I_t1 = (s11_t1.real)
Q_t1 = (s11_t1.imag)
ang_t1 = np.angle(s11_t1)

PCA_t1 = PCA_transform(I_t1, Q_t1)

y_t1 = PCA_t1[0]
x_t1 = delay_t1

fig, (ax1) = plt.subplots(nrows=1)
ax1.set_xlabel('Duration (ns)', size='large')
ax1.set_ylabel('PCA[S$_{11}$] (arb. unit.)', size='large')
plt.rcParams["font.size"] = 10
ax1.tick_params(axis="x", direction="in")
ax1.tick_params(axis="y", direction="in")
# ax1.set_xlim(0, 250000)
# ax1.set_ylim(-48, 160)
plt.tick_params(
            top='on',
            bottom='on`',
            left='on',
            right='on',
            )

plt.plot(x_t1, y_t1)
plt.show()

# %%
par_ini_t1 = {
    'gamma': 1/180,
    'amp':14.5,
    'const':0
}

par_min_t1 = {
    'gamma': 0,
    'amp':0,
    'const':-np.inf
}

par_max_t1 = {
    'gamma': np.inf,
    'amp':np.inf,
    'const':np.inf,
}

par_vary_t1 = {
    'gamma': True,
    'amp':True,
    'const':True
}

# %%
model = lmfit.Model(Dephase)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini_t1[name],
    min = par_min_t1[name],
    max = par_max_t1[name],
    vary = par_vary_t1[name]
    )
result_t1 = model.fit(data = y_t1, params = params, delay = x_t1)
result_t1
# Out:
# <h2> Model</h2> Model(Dephase) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>25</td><td></td></tr><tr><td># data points</td><td>100</td><td></td></tr><tr><td># variables</td><td>3</td><td></td></tr><tr><td>chi-square</td><td> 233.307213</td><td></td></tr><tr><td>reduced chi-square</td><td> 2.40522900</td><td></td></tr><tr><td>Akaike info crit.</td><td> 90.7185909</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 98.5341015</td><td></td></tr><tr><td>R-squared</td><td> 0.67724786</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  13.1343931 </td><td>  1.13127300 </td><td> (8.61%) </td><td> 14.5 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> gamma </td><td>  0.01891808 </td><td>  0.00268698 </td><td> (14.20%) </td><td> 0.005555555555555556 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td> -0.76201867 </td><td>  0.17471492 </td><td> (22.93%) </td><td> 0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>amp</td><td>gamma</td><td>+0.5811</td></tr><tr><td>gamma</td><td>const</td><td>+0.3444</td></tr></table>

# %%
fig, (ax) = plt.subplots(dpi=80)
plt.title("T1")


plt.rcParams["font.size"] = 12
plt.tick_params(
            top='on',
            bottom='on`',
            left='on',
            right='on',
            )

result_t1.plot_fit(ax = ax)
# plt.plot(x_t1,result_t1.init_fit, label='init fit')

# ax.set_xlim(0, 250000)
ax.tick_params(axis="x", direction="in")
ax.tick_params(axis="y", direction="in")
ax.set_xlabel('Duration (ns)', size='large')
ax.set_ylabel('PCA[S$_{11}$] (Arb. unit.)', size='large')

plt.legend(loc=7)
plt.show()

# %%
T1 = (1/0.01891808)*1e-9	
T1
# Out:
# 5.285948679781458e-08

# %% [markdown]
# T2_star

# %%
t2e = "/2023-09-14/2023-09-14T150552_c28205f5-td_ge_T2e"
dd_t2e = datadict_from_hdf5(header + t2e +"/data")

# %%
s11_t2e = dd_t2e['s11']['values']
imag_t2e = s11_t2e.imag
delay_t2e = dd_t2e['delay']['values']

I_t2e = (s11_t2e.real)
Q_t2e = (s11_t2e.imag)

PCA_t2e = PCA_transform(I_t2e, Q_t2e)

y_t2e = PCA_t2e[0]
x_t2e = delay_t2e

plt.plot(x_t2e, y_t2e)
plt.show()

# %%
par_ini_t2e = {
    'gamma': 1/2000,
    'amp':35,
    'const':0
}

par_min_t2e = {
    'gamma': 0,
    'amp':0,
    'const':-np.inf
}

par_max_t2e = {
    'gamma': np.inf,
    'amp':np.inf,
    'const':np.inf,
}

par_vary_t2e = {
    'gamma': True,
    'amp':True,
    'const':True
}

# %%
model = lmfit.Model(Dephase)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini_t2e[name],
    min = par_min_t2e[name],
    max = par_max_t2e[name],
    vary = par_vary_t2e[name]
    )
result_t2e = model.fit(data = y_t2e, params = params, delay = x_t2e)
result_t2e
# Out:
# <h2> Model</h2> Model(Dephase) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>34</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>3</td><td></td></tr><tr><td>chi-square</td><td> 677.871050</td><td></td></tr><tr><td>reduced chi-square</td><td> 6.91705153</td><td></td></tr><tr><td>Akaike info crit.</td><td> 198.287493</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 206.132854</td><td></td></tr><tr><td>R-squared</td><td> 0.92102048</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  38.4837174 </td><td>  1.33021879 </td><td> (3.46%) </td><td> 35 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> gamma </td><td>  1.2283e-04 </td><td>  7.7805e-06 </td><td> (6.33%) </td><td> 0.0005 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td> -5.35992414 </td><td>  0.38268372 </td><td> (7.14%) </td><td> 0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>gamma</td><td>const</td><td>+0.6006</td></tr><tr><td>amp</td><td>gamma</td><td>+0.5173</td></tr></table>

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("T2")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result_t2e.plot_fit(ax = ax)
plt.plot(delay_t2e,result_t2e.init_fit)

plt.xlabel("delay (ns)")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
T2 = (1/1.2283e-04)*1e-9	
T2
# Out:
# 8.141333550435562e-06

# %% [markdown]
# T2 star

# %%
def Damping(delay, amp, gamma, omega, phi0, const):
    return const + amp * np.exp(- gamma*delay)*np.cos(omega*delay + phi0)

# %%
t2 = "/2023-09-14/2023-09-14T151044_703fc5ec-td_ge_T2r1d"
dd_t2 = datadict_from_hdf5(header + t2 +"/data")

# %%
s11_t2 = dd_t2['s11']['values']
imag_t2 = s11_t2.imag
delay_t2 = dd_t2['delay']['values']

I_t2 = (s11_t2.real)
Q_t2 = (s11_t2.imag)

PCA_t2 = PCA_transform(I_t2, Q_t2)

y_t2 = PCA_t2[0]
x_t2 = delay_t2

plt.plot(x_t2, y_t2)
plt.show()

# %%
par_ini_t2 = {
    'amp':42,
    'gamma': 1/6000,
    'omega':2*np.pi/1000,
    'phi0':0,
    'const':0
}

par_min_t2 = {
    'amp':-np.inf,
    'gamma': 0,
    'omega':-2*np.pi,
    'phi0':-2*np.pi,
    'const':-np.inf
}

par_max_t2 = {
    'amp':np.inf,
    'gamma': np.inf,
    'omega':2*np.pi,
    'phi0':2*np.pi,
    'const':np.inf
}

par_vary_t2 = {
    'amp':True,
    'gamma': True,
    'omega':True,
    'phi0':True,
    'const':True
}

# %%
model = lmfit.Model(Damping)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini_t2[name],
    min = par_min_t2[name],
    max = par_max_t2[name],
    vary = par_vary_t2[name]
    )
result_t2 = model.fit(data = y_t2, params = params, delay = x_t2)
result_t2
# Out:
# <h2> Model</h2> Model(Damping) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>43</td><td></td></tr><tr><td># data points</td><td>1001</td><td></td></tr><tr><td># variables</td><td>5</td><td></td></tr><tr><td>chi-square</td><td> 35159.9088</td><td></td></tr><tr><td>reduced chi-square</td><td> 35.3011132</td><td></td></tr><tr><td>Akaike info crit.</td><td> 3572.46589</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 3597.00966</td><td></td></tr><tr><td>R-squared</td><td> 0.82662869</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  40.7788970 </td><td>  0.88158133 </td><td> (2.16%) </td><td> 42 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> gamma </td><td>  2.3884e-04 </td><td>  7.7383e-06 </td><td> (3.24%) </td><td> 0.00016666666666666666 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> omega </td><td>  0.00624341 </td><td>  7.5147e-06 </td><td> (0.12%) </td><td> 0.006283185307179587 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> phi0 </td><td>  0.51036735 </td><td>  0.02034536 </td><td> (3.99%) </td><td> 0 </td><td> -6.28318531 </td><td>  6.28318531 </td><td> True </td></tr><tr><td> const </td><td>  0.27234192 </td><td>  0.18847345 </td><td> (69.20%) </td><td> 0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>amp</td><td>gamma</td><td>+0.7408</td></tr><tr><td>omega</td><td>phi0</td><td>-0.7213</td></tr></table>

# %%
fig, ax = plt.subplots(dpi=80)

plt.title("T2star")

plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
result_t2.plot_fit(ax = ax)
plt.plot(delay_t2,result_t2.init_fit)

plt.xlabel("delay (ns)")
plt.ylabel("mag[S11](a.u.)")

plt.show()

# %%
T2_star = (1/2.3884e-04)*1e-9	
T2_star
# Out:
# 4.186903366270306e-06

# %%
from plottr.data.datadict_storage import datadict_from_hdf5
import numpy as np
import matplotlib.pyplot as plt
from lmfit.models import GaussianModel
import lmfit

# %%
import sklearn
from sklearn.decomposition import PCA
from scipy.constants import *

# %%
def PCA_transform(Re_c, Im_c):
    pca = PCA()
    c_data = np.concatenate([np.array([Re_c]).T, np.array([Im_c]).T], axis = 1)
    pca.fit(c_data)
    c_pca = pca.transform(c_data)
    c_PCA1 = c_pca.T[0]
    c_PCA2 = c_pca.T[1]
    return c_PCA1, c_PCA2

# %% [markdown]
# # td - drive-induced dephasing

# %%
header = "D:/K_sunada/result/CDY168/"
data = "/2024-10-13/2024-10-13T143234_8cc0d495-drive_induced_dephasing"
dd = datadict_from_hdf5(header + data +"/data")

# %%
def t2star(delay, amp, gamma, omega, phi0, const):
    return const + amp * np.exp(- gamma*delay)*np.cos(omega*delay + phi0)

def liner_func(power, alpha, const):
    return const + alpha*power

# %%
def watt_dbm(watt):
    return 10*np.log10(watt*1e3)

def dbm_watt(dBm):
    return (10**(dBm/10))*1e-3

# %%
num_of_amp =21
num_of_delay = 50
delay = []
s11 = []
amp = []
for i in range(num_of_amp):
    amplitude = dd['amplitude']['values'][num_of_delay*i]
    tau = dd['delay']['values'][num_of_delay*i:num_of_delay*(i+1)]
    s11_I = dd['s11']['values'][num_of_delay*i:num_of_delay*(i+1)].real
    s11_Q = dd['s11']['values'][num_of_delay*i:num_of_delay*(i+1)].imag
    s11_PCA = PCA_transform(s11_I, s11_Q)[0]
    amp.append(amplitude)
    delay.append(tau)
    s11.append(s11_PCA)
    
plt.plot(delay[5], s11[5])

# %%
par_ini = {'amp':0.01,'gamma': 1/2000,'omega':2*np.pi/2500,'phi0':0, 'const':0}
par_min = {'amp':-np.inf,'gamma': 0,'omega':-2*np.pi,'phi0':-2*np.pi,'const':-np.inf}
par_max = {'amp':np.inf,'gamma': np.inf,'omega':2*np.pi,'phi0':2*np.pi,'const':np.inf}
par_vary = {'amp':True,'gamma': True,'omega':True,'phi0':True,'const':True}
model = lmfit.Model(t2star)

params = model.make_params()
for name in model.param_names:
    params[name].set(value = par_ini[name],min = par_min[name],max = par_max[name],vary = par_vary[name])

results = []
for i in range(num_of_amp):
    result = model.fit(data = s11[i], params=params, delay = delay[i])
    results.append(result)

# %%
fig, ax = plt.subplots(dpi=80)
id = 21
plt.rcParams["font.size"] = 10
ax.tick_params(axis="x", direction="in")
ax.tick_params(axis="y", direction="in")
plt.tick_params(top='on',bottom='on`',left='on',right='on',)

results[id].plot_fit(ax = ax)
plt.plot(delay[0],results[0].init_fit)
ax.set_xlabel('Delay (ns)', size='large')
ax.set_ylabel('PCA[S$_{11}$] (Arb. u.)', size='large')
plt.show()
results[id]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[41], line 8
#       5 ax.tick_params(axis="y", direction="in")
#       6 plt.tick_params(top='on',bottom='on`',left='on',right='on',)
# ----> 8 results[id].plot_fit(ax = ax)
#       9 plt.plot(delay[0],results[0].init_fit)
#      10 ax.set_xlabel('Delay (ns)', size='large')
#
# IndexError: list index out of range

# %%
amp_squared = [0.00e+00, 4.50e-05, 9.00e-05, 1.35e-04, 1.80e-04, 2.25e-04,
       2.70e-04, 3.15e-04, 3.60e-04,4.95e-04,
       5.40e-04, 5.85e-04, 6.30e-04, 7.20e-04, 7.65e-04,
       8.10e-04, 8.55e-04, 9.00e-04]

# %%
gamma = [9.0700e-05, 1.0691e-04, 1.3778e-04, 1.4283e-04, 1.2784e-04, 2.7198e-04,
         2.1276e-04, 2.7231e-04, 3.0000e-04, 3.9201e-04,
         3.8077e-04, 4.8282e-04, 4.7849e-04, 5.0624e-04, 5.6079e-04,
         5.4001e-04, 4.8541e-04, 5.9972e-04]
# amp_squared = np.array(amp) ** 2

plt.plot(amp_squared, gamma, 'o-')

# %%
par_ini = {'alpha': 0.00005/0.001,'const':0e9}
par_min = {'alpha': -np.inf,'const':-np.inf}
par_max = {'alpha': np.inf,'const':np.inf}
par_vary = {'alpha': True,'const':True}
model = lmfit.Model(liner_func)

params = model.make_params()
for name in model.param_names:
    params[name].set(value = par_ini[name],min = par_min[name],max = par_max[name],vary = par_vary[name])

result = model.fit(data = gamma , params=params, power = amp_squared)

# %%
fig, ax = plt.subplots(dpi=80)
plt.rcParams["font.size"] = 10
ax.tick_params(axis="x", direction="in")
ax.tick_params(axis="y", direction="in")
result.plot_fit(ax = ax)
ax.set_xlabel('Omega^2 (V^2)', size='large')
ax.set_ylabel('Gamma (1/ns)', size='large')
plt.legend()
plt.show()
result
# Out:
# <h2>Fit Result</h2> <p>Model: Model(liner_func)</p> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>leastsq</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>7</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>18</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>2</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 2.3543e-08</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 1.4714e-09</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'>-364.186793</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-align:right'>-362.406049</td></tr><tr><td style='text-align:left'>R-squared</td><td style='text-align:right'> 0.95447515</td></tr></table><table class="jp-toc-ignore"><caption>Parameters</caption><tr><th style='text-align:left'>name</th><th style='text-align:left'>value</th><th style='text-align:left'>standard error</th><th style='text-align:left'>relative error</th><th style='text-align:left'>initial value</th><th style='text-align:left'>min</th><th style='text-align:left'>max</th><th style='text-align:right'>vary</th></tr><tr><td style='text-align:left'>alpha</td><td style='text-align:left'> 0.57272588</td><td style='text-align:left'> 0.03127006</td><td style='text-align:left'>(5.46%)</td><td style='text-align:left'>0.05</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>const</td><td style='text-align:left'> 8.6299e-05</td><td style='text-align:left'> 1.6464e-05</td><td style='text-align:left'>(19.08%)</td><td style='text-align:left'>0.0</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr></table><table class="jp-toc-ignore"><caption>Correlations (unreported values are < 0.100)</caption><tr><th style='text-align:left'>Parameter1</th><th style='text-align:left'>Parameter 2</th><th style='text-align:right'>Correlation</th></tr><tr><td style='text-align:left'>alpha</td><td style='text-align:left'>const</td><td style='text-align:right'>-0.8357</td></tr></table>

# %%
target_freq = 9.35
read_freq_g = 9.3703
read_freq_e = 9.3680
chi = (read_freq_e - read_freq_g)/2
kappa_ex = 0.09
kappa_in = 0.003

kappa = kappa_ex + kappa_in
coeff = (kappa*chi)**2 / (2*(kappa**2/4 + (read_freq_g - target_freq)**2)*(kappa**2/4 + (read_freq_g + chi - target_freq)**2))
atten = hbar * target_freq * 1e9 * 2*np.pi* (0.57272588 * 1e9*2*np.pi)/ coeff
atten_dbm = 10*np.log10(atten)
print(f"attenuation rate (dBm): {atten_dbm}")
# Out:
# attenuation rate (dBm): -105.95527253632329

# %%
atten_dbm +6 + 30
# Out:
# -69.98818968731345

# %% [markdown]
# ## cw acStark shift

# %%
def Lorentzian(freq, amp, const, center, k):
    return const - amp*k/((freq-center)**2 + (k/2)**2)

# %%
def Gaussian(freq, amp, const, center, k):
    return const - amp*np.exp(-(freq-center)**2/(2*k**2))

# %%
header = "D:/K_sunada/result/CDY155/"
# ac1037 = "/2023-12-29/2023-12-29T173725_7e58e084-cw_attenuation"
ac1033 = "/2024-02-17/2024-02-17T151122_5fc2ed6b-cw_attenuation"
# ac1031 = "/2023-12-25/2023-12-25T162657_fc4e3f61-cw_attenuation"
ac1030 = "/2024-02-17/2024-02-17T151927_80de451a-cw_attenuation" 
# ac1029 = "/2023-12-29/2023-12-29T171620_8c5c01d3-cw_attenuation"
ac1028 = "/2024-02-17/2024-02-17T150336_49d6dd1b-cw_attenuation"
ac1026 = "/2024-02-17/2024-02-17T145736_73524581-cw_attenuation"
ac1022 = "/2024-02-17/2024-02-17T145205_adcbe7a5-cw_attenuation"

# dd1037 = datadict_from_hdf5(header + ac1037+"/data")
dd1033 = datadict_from_hdf5(header + ac1033+"/data")
# dd1031 = datadict_from_hdf5(header + ac1031+"/data")
dd1030 = datadict_from_hdf5(header + ac1030+"/data")
# dd1029 = datadict_from_hdf5(header + ac1029 +"/data")
dd1028 = datadict_from_hdf5(header + ac1028 +"/data")
dd1026 = datadict_from_hdf5(header + ac1026 +"/data")
dd1022 = datadict_from_hdf5(header + ac1022+"/data")

# %% [markdown]
# 10.3 GHz

# %%
xs = []
ys = []
num_of_freq = 241

for i in range(21):
    ini = num_of_freq*i
    fin = num_of_freq*(1+i)-1
    x = dd1030['frequency']['values'][i]
    y_real = dd1030['s11']['values'][i].real
    y_imag = dd1030['s11']['values'][i].imag
    y_PCA = PCA_transform(y_real, y_imag)
    xs.append(x)
    ys.append(-y_PCA[0])

# %%
par_ini = {'amp': 0.00035,'const':0, 'center':7.96e9,'k':0.01e9}
par_min = {'amp': 0,'const':-np.inf,'center':0,'k':0}
par_max = {'amp': np.inf, 'const':np.inf,'center':np.inf,'k':np.inf}
par_vary = {'amp': True,'const':True, 'center':True,'k':True}
model = lmfit.Model(Gaussian)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )

results = []
for i in range(21):
    result = model.fit(data = ys[i], params=params, freq = xs[i])
    results.append(result)

# %%
fig, ax = plt.subplots(dpi=80)
id = 20
plt.rcParams["font.size"] = 10
ax.tick_params(axis="x", direction="in")
ax.tick_params(axis="y", direction="in")
plt.tick_params(
            top='on',
            bottom='on`',
            left='on',
            right='on',
            )

results[id].plot_fit(ax = ax)
# plt.plot(xs[0],results[0].init_fit)
ax.set_xlabel('F0g1 frequency (GHz)', size='large')
ax.set_ylabel('Re[S$_{11}$] (Arb. u.)', size='large')
plt.show()
results[id]
# Out:
# <h2> Model</h2> Model(Gaussian) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>57</td><td></td></tr><tr><td># data points</td><td>241</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 2.4792e-08</td><td></td></tr><tr><td>reduced chi-square</td><td> 1.0461e-10</td><td></td></tr><tr><td>Akaike info crit.</td><td>-5534.40884</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-5520.46965</td><td></td></tr><tr><td>R-squared</td><td> 0.99183479</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  3.0992e-04 </td><td>  1.9817e-06 </td><td> (0.64%) </td><td> 0.00035 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  8.0217e-05 </td><td>  8.8461e-07 </td><td> (1.10%) </td><td> 0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> center </td><td>  7.9269e+09 </td><td>  111465.351 </td><td> (0.00%) </td><td> 7960000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> k </td><td>  13974167.8 </td><td>  134162.818 </td><td> (0.96%) </td><td> 10000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>amp</td><td>k</td><td>-0.3876</td></tr><tr><td>const</td><td>k</td><td>+0.3699</td></tr><tr><td>amp</td><td>const</td><td>+0.3514</td></tr><tr><td>center</td><td>k</td><td>-0.3340</td></tr><tr><td>amp</td><td>center</td><td>+0.1429</td></tr></table>

# %%
center1030_g = [7.9876e+09, 7.9856e+09, 7.9839e+09, 7.9821e+09, 7.9798e+09, 7.9778e+09,
                7.9753e+09, 7.9730e+09, 7.9706e+09, 7.9679e+09, 7.9649e+09, 7.9620e+09,
                7.9588e+09, 7.9553e+09, 7.9520e+09, 7.9483e+09, 7.9443e+09, 7.9404e+09,
                7.9358e+09, 7.9313e+09, 7.9269e+09]

# %% [markdown]
# 10.28 GHz

# %%
xs = []
ys = []
num_of_freq = 241

for i in range(21):
    ini = num_of_freq*i
    fin = num_of_freq*(1+i)-1
    x = dd1028['frequency']['values'][i]
    y_real = dd1028['s11']['values'][i].real
    y_imag = dd1028['s11']['values'][i].imag
    y_PCA = PCA_transform(y_real, y_imag)
    xs.append(x)
    ys.append(-y_PCA[0])

# %%
par_ini = {'amp': 0.00035,'const':0, 'center':7.99e9,'k':0.01e9}
par_min = {'amp': 0,'const':-np.inf,'center':0,'k':0}
par_max = {'amp': np.inf, 'const':np.inf,'center':np.inf,'k':np.inf}
par_vary = {'amp': True,'const':True, 'center':True,'k':True}
model = lmfit.Model(Gaussian)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )

results = []
for i in range(21):
    result = model.fit(data = ys[i], params=params, freq = xs[i])
    results.append(result)

# %%
fig, ax = plt.subplots(dpi=80)
id = 20
plt.rcParams["font.size"] = 10
ax.tick_params(axis="x", direction="in")
ax.tick_params(axis="y", direction="in")
plt.tick_params(
            top='on',
            bottom='on`',
            left='on',
            right='on',
            )

results[id].plot_fit(ax = ax)
# plt.plot(xs[0],results[0].init_fit)
ax.set_xlabel('F0g1 frequency (GHz)', size='large')
ax.set_ylabel('Re[S$_{11}$] (Arb. u.)', size='large')
plt.show()
results[id]
# Out:
# <h2> Model</h2> Model(Gaussian) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>72</td><td></td></tr><tr><td># data points</td><td>241</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 6.1917e-08</td><td></td></tr><tr><td>reduced chi-square</td><td> 2.6125e-10</td><td></td></tr><tr><td>Akaike info crit.</td><td>-5313.82791</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-5299.88872</td><td></td></tr><tr><td>R-squared</td><td> 0.96804378</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  2.8394e-04 </td><td>  3.6514e-06 </td><td> (1.29%) </td><td> 0.00035 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  5.2483e-05 </td><td>  1.3354e-06 </td><td> (2.54%) </td><td> 0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> center </td><td>  7.9598e+09 </td><td>  127460.375 </td><td> (0.00%) </td><td> 7990000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> k </td><td>  8885816.42 </td><td>  140494.670 </td><td> (1.58%) </td><td> 10000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>const</td><td>k</td><td>+0.4207</td></tr><tr><td>amp</td><td>k</td><td>-0.3972</td></tr><tr><td>amp</td><td>const</td><td>+0.2586</td></tr></table>

# %%
center1028_g = [7.9980e+09, 7.9969e+09, 7.9956e+09, 7.9943e+09, 7.9930e+09, 7.9917e+09,
                7.9904e+09, 7.9890e+09, 7.9873e+09, 7.9856e+09, 7.9839e+09, 7.9820e+09,
                7.9801e+09, 7.9779e+09, 7.9757e+09, 7.9734e+09, 7.9709e+09, 7.9685e+09,
                7.9658e+09, 7.9631e+09, 7.9598e+09]

# %% [markdown]
# 10.26 GHz

# %%
y = np.unique(dd1026['power']['values'])
x = np.unique(dd1026['frequency']['values'])
z = np.real(dd1026['s11']['values'])

# %%
xs = []
ys = []
num_of_freq = 181

for i in range(21):
    ini = num_of_freq*i
    fin = num_of_freq*(1+i)-1
    x = dd1026['frequency']['values'][i]
    y_real = dd1026['s11']['values'][i].real
    y_imag = dd1026['s11']['values'][i].imag
    y_PCA = PCA_transform(y_real, y_imag)
    xs.append(x)
    ys.append(-y_PCA[0])

# %%
par_ini = {'amp': 0.00035,'const':0, 'center':7.99e9,'k':0.01e9}
par_min = {'amp': 0,'const':-np.inf,'center':0,'k':0}
par_max = {'amp': np.inf, 'const':np.inf,'center':np.inf,'k':np.inf}
par_vary = {'amp': True,'const':True, 'center':True,'k':True}
model = lmfit.Model(Gaussian)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )

results = []
for i in range(21):
    result = model.fit(data = ys[i], params=params, freq = xs[i])
    results.append(result)

# %%
fig, ax = plt.subplots(dpi=80)
id = 20
plt.rcParams["font.size"] = 10
ax.tick_params(axis="x", direction="in")
ax.tick_params(axis="y", direction="in")
plt.tick_params(
            top='on',
            bottom='on`',
            left='on',
            right='on',
            )

results[id].plot_fit(ax = ax)
# plt.plot(xs[0],results[0].init_fit)
ax.set_xlabel('F0g1 frequency (GHz)', size='large')
ax.set_ylabel('Re[S$_{11}$] (Arb. u.)', size='large')
plt.show()
results[id]
# Out:
# <h2> Model</h2> Model(Gaussian) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>56</td><td></td></tr><tr><td># data points</td><td>181</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 1.9685e-08</td><td></td></tr><tr><td>reduced chi-square</td><td> 1.1122e-10</td><td></td></tr><tr><td>Akaike info crit.</td><td>-4144.48364</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-4131.68966</td><td></td></tr><tr><td>R-squared</td><td> 0.97147450</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  2.4013e-04 </td><td>  3.5462e-06 </td><td> (1.48%) </td><td> 0.00035 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  2.5704e-05 </td><td>  8.9161e-07 </td><td> (3.47%) </td><td> 0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> center </td><td>  7.9851e+09 </td><td>  64855.9629 </td><td> (0.00%) </td><td> 7990000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> k </td><td>  3864688.93 </td><td>  67953.5087 </td><td> (1.76%) </td><td> 10000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>amp</td><td>k</td><td>-0.4892</td></tr><tr><td>const</td><td>k</td><td>+0.2986</td></tr><tr><td>amp</td><td>const</td><td>+0.1778</td></tr></table>

# %%
center1026_g = [8.0063e+09, 8.0057e+09, 8.0050e+09, 8.0043e+09, 8.0037e+09, 8.0030e+09,
                8.0022e+09, 8.0014e+09, 8.0005e+09, 7.9994e+09, 7.9985e+09, 7.9975e+09,
                7.9964e+09, 7.9951e+09, 7.9940e+09, 7.9925e+09, 7.9912e+09, 7.9900e+09,
                7.9885e+09, 7.9869e+09, 7.9851e+09]

# %% [markdown]
# 10.22 GHz

# %%
xs = []
ys = []
num_of_freq = 101

for i in range(21):
    ini = num_of_freq*i
    fin = num_of_freq*(1+i)-1
    x = dd1022['frequency']['values'][i]
    y_real = dd1022['s11']['values'][i].real
    y_imag = dd1022['s11']['values'][i].imag
    y_PCA = PCA_transform(y_real, y_imag)
    xs.append(x)
    ys.append(-y_PCA[0])

# %%
par_ini = {'amp': 0.00035,'const':0, 'center':8.0e9,'k':0.01e9}
par_min = {'amp': 0,'const':-np.inf,'center':0,'k':0}
par_max = {'amp': np.inf, 'const':np.inf,'center':np.inf,'k':np.inf}
par_vary = {'amp': True,'const':True, 'center':True,'k':True}
model = lmfit.Model(Gaussian)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )
results = []
for i in range(21):
    result = model.fit(data = ys[i], params=params, freq = xs[i])
    results.append(result)

# %%
fig, ax = plt.subplots(dpi=80)
id = 20
plt.rcParams["font.size"] = 10
ax.tick_params(axis="x", direction="in")
ax.tick_params(axis="y", direction="in")
plt.tick_params(
            top='on',
            bottom='on`',
            left='on',
            right='on',
            )

results[id].plot_fit(ax = ax)
# plt.plot(xs[0],results[0].init_fit)
ax.set_xlabel('F0g1 frequency (GHz)', size='large')
ax.set_ylabel('Re[S$_{11}$] (Arb. u.)', size='large')
plt.show()
results[id]
# Out:
# <h2> Model</h2> Model(Gaussian) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>61</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 3.6362e-09</td><td></td></tr><tr><td>reduced chi-square</td><td> 3.7486e-11</td><td></td></tr><tr><td>Akaike info crit.</td><td>-2420.79299</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-2410.33251</td><td></td></tr><tr><td>R-squared</td><td> 0.96223489</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  1.2494e-04 </td><td>  2.9022e-06 </td><td> (2.32%) </td><td> 0.00035 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  1.2018e-05 </td><td>  6.8286e-07 </td><td> (5.68%) </td><td> 0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> center </td><td>  8.0023e+09 </td><td>  51263.0154 </td><td> (0.00%) </td><td> 8000000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> k </td><td>  1937893.38 </td><td>  53396.2106 </td><td> (2.76%) </td><td> 10000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>amp</td><td>k</td><td>-0.5000</td></tr><tr><td>const</td><td>k</td><td>+0.2805</td></tr><tr><td>amp</td><td>const</td><td>+0.1664</td></tr></table>

# %%
center1022_g = [8.0117e+09, 8.0115e+09, 8.0111e+09, 8.0109e+09, 8.0106e+09, 8.0102e+09, 
                8.0098e+09, 8.0096e+09, 8.0092e+09, 8.0087e+09, 8.0083e+09, 8.0078e+09,
                8.0073e+09, 8.0069e+09, 8.0063e+09, 8.0058e+09, 8.0051e+09, 8.0045e+09,
                8.0038e+09, 8.0032e+09, 8.0023e+09]

# %% [markdown]
# 10.31 GHz

# %%
xs = []
ys = []
num_of_freq = 241

for i in range(21):
    ini = num_of_freq*i
    fin = num_of_freq*(1+i)-1
    x = dd1031['frequency']['values'][i]
    y_real = dd1031['s11']['values'][i].real
    y_imag = dd1031['s11']['values'][i].imag
    y_PCA = PCA_transform(y_real, y_imag)
    xs.append(x)
    ys.append(-y_PCA[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 8
#       6 ini = num_of_freq*i
#       7 fin = num_of_freq*(1+i)-1
# ----> 8 x = dd1031['frequency']['values'][i]
#       9 y_real = dd1031['s11']['values'][i].real
#      10 y_imag = dd1031['s11']['values'][i].imag
#
# NameError: name 'dd1031' is not defined

# %%
par_ini = {'amp': 0.00035,'const':0, 'center':7.97e9,'k':0.01e9}
par_min = {'amp': 0,'const':-np.inf,'center':0,'k':0}
par_max = {'amp': np.inf, 'const':np.inf,'center':np.inf,'k':np.inf}
par_vary = {'amp': True,'const':True, 'center':True,'k':True}
model = lmfit.Model(Gaussian)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )
results = []
for i in range(21):
    result = model.fit(data = ys[i], params=params, freq = xs[i])
    results.append(result)

# %%
fig, ax = plt.subplots(dpi=80)
id = 20
plt.rcParams["font.size"] = 10
ax.tick_params(axis="x", direction="in")
ax.tick_params(axis="y", direction="in")
plt.tick_params(
            top='on',
            bottom='on`',
            left='on',
            right='on',
            )

results[id].plot_fit(ax = ax)
# plt.plot(xs[0],results[0].init_fit)
ax.set_xlabel('F0g1 frequency (GHz)', size='large')
ax.set_ylabel('Re[S$_{11}$] (Arb. u.)', size='large')
plt.show()
results[id]
# Out:
# <h2> Model</h2> Model(Gaussian) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>56</td><td></td></tr><tr><td># data points</td><td>241</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 1.2708e-08</td><td></td></tr><tr><td>reduced chi-square</td><td> 5.3620e-11</td><td></td></tr><tr><td>Akaike info crit.</td><td>-5695.46838</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-5681.52919</td><td></td></tr><tr><td>R-squared</td><td> 0.96175396</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  1.0826e-04 </td><td>  1.4699e-06 </td><td> (1.36%) </td><td> 0.00035 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  2.6485e-05 </td><td>  6.8002e-07 </td><td> (2.57%) </td><td> 0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> center </td><td>  7.9411e+09 </td><td>  174233.279 </td><td> (0.00%) </td><td> 7970000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> k </td><td>  11760740.9 </td><td>  203139.889 </td><td> (1.73%) </td><td> 10000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>const</td><td>k</td><td>+0.5142</td></tr><tr><td>amp</td><td>const</td><td>+0.3272</td></tr><tr><td>amp</td><td>k</td><td>-0.2997</td></tr></table>

# %%
center1031_g = [7.9975e+09, 7.9959e+09, 7.9950e+09, 7.9923e+09, 7.9914e+09, 7.9886e+09, 7.9868e+09,
                7.9838e+09, 7.9821e+09, 7.9797e+09, 7.9772e+09, 7.9745e+09, 7.9710e+09, 7.9685e+09,
                7.9652e+09, 7.9614e+09, 7.9572e+09, 7.9537e+09, 7.9494e+09, 7.9456e+09, 7.9411e+09]

# %%
center1031 = [7.9975e+09, 7.9959e+09, 7.9949e+09, 7.9925e+09, 7.9915e+09, 7.9887e+09, 7.9870e+09,
              7.9841e+09, 7.9824e+09, 7.9797e+09, 7.9773e+09, 7.9745e+09, 7.9635e+09, 7.9686e+09,
              7.9652e+09, 7.9616e+09, 7.9575e+09, 7.9538e+09, 7.9495e+09, 7.9458e+09, 7.9413e+09]

# %% [markdown]
# 10.29 GHz

# %%
xs = []
ys = []
num_of_freq = 241

for i in range(21):
    ini = num_of_freq*i
    fin = num_of_freq*(1+i)-1
    x = dd1029['frequency']['values'][i]
    y_real = dd1029['s11']['values'][i].real
    y_imag = dd1029['s11']['values'][i].imag
    y_PCA = PCA_transform(y_real, y_imag)
    xs.append(x)
    ys.append(-y_PCA[0])

# %%
par_ini = {'amp': 0.00035,'const':0, 'center':7.97e9,'k':0.01e9}
par_min = {'amp': 0,'const':-np.inf,'center':0,'k':0}
par_max = {'amp': np.inf, 'const':np.inf,'center':np.inf,'k':np.inf}
par_vary = {'amp': True,'const':True, 'center':True,'k':True}
model = lmfit.Model(Gaussian)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )
results = []
for i in range(21):
    result = model.fit(data = ys[i], params=params, freq = xs[i])
    results.append(result)

# %%
fig, ax = plt.subplots(dpi=80)
id = 20
plt.rcParams["font.size"] = 10
ax.tick_params(axis="x", direction="in")
ax.tick_params(axis="y", direction="in")
plt.tick_params(
            top='on',
            bottom='on`',
            left='on',
            right='on',
            )

results[id].plot_fit(ax = ax)
# plt.plot(xs[0],results[0].init_fit)
ax.set_xlabel('F0g1 frequency (GHz)', size='large')
ax.set_ylabel('Re[S$_{11}$] (Arb. u.)', size='large')
plt.show()
results[id]
# Out:
# <h2> Model</h2> Model(Gaussian) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>57</td><td></td></tr><tr><td># data points</td><td>241</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 9.5921e-09</td><td></td></tr><tr><td>reduced chi-square</td><td> 4.0473e-11</td><td></td></tr><tr><td>Akaike info crit.</td><td>-5763.25703</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-5749.31784</td><td></td></tr><tr><td>R-squared</td><td> 0.97846363</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  1.2811e-04 </td><td>  1.3046e-06 </td><td> (1.02%) </td><td> 0.00035 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  2.9699e-05 </td><td>  5.7485e-07 </td><td> (1.94%) </td><td> 0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> center </td><td>  7.9463e+09 </td><td>  124526.399 </td><td> (0.00%) </td><td> 7970000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> k </td><td>  11144659.0 </td><td>  143207.584 </td><td> (1.28%) </td><td> 10000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>const</td><td>k</td><td>+0.4939</td></tr><tr><td>amp</td><td>k</td><td>-0.3232</td></tr><tr><td>amp</td><td>const</td><td>+0.3116</td></tr></table>

# %%
center1029_g = [7.9998e+09, 7.9983e+09, 7.9966e+09, 7.9950e+09, 7.9933e+09, 7.9914e+09, 7.9895e+09,
                7.9875e+09, 7.9852e+09, 7.9830e+09, 7.9804e+09, 7.9776e+09, 7.9749e+09, 7.9719e+09,
                7.9689e+09, 7.9654e+09, 7.9623e+09, 7.9584e+09, 7.9545e+09, 7.9506e+09, 7.9463e+09]

# %% [markdown]
# 10.33 GHz

# %%
xs = []
ys = []
num_of_freq = 181

for i in range(21):
    ini = num_of_freq*i
    fin = num_of_freq*(1+i)-1
    x = dd1033['frequency']['values'][i]
    y_real = dd1033['s11']['values'][i].real
    y_imag = dd1033['s11']['values'][i].imag
    y_PCA = PCA_transform(y_real, y_imag)
    xs.append(x)
    ys.append(-y_PCA[0])

# %%
par_ini = {'amp': 0.00035,'const':0, 'center':7.99e9,'k':0.01e9}
par_min = {'amp': 0,'const':-np.inf,'center':0,'k':0}
par_max = {'amp': np.inf, 'const':np.inf,'center':np.inf,'k':np.inf}
par_vary = {'amp': True,'const':True, 'center':True,'k':True}
model = lmfit.Model(Gaussian)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )
results = []
for i in range(21):
    result = model.fit(data = ys[i], params=params, freq = xs[i])
    results.append(result)

# %%
fig, ax = plt.subplots(dpi=80)
id = 20
plt.rcParams["font.size"] = 10
ax.tick_params(axis="x", direction="in")
ax.tick_params(axis="y", direction="in")
plt.tick_params(
            top='on',
            bottom='on`',
            left='on',
            right='on',
            )

results[id].plot_fit(ax = ax)
# plt.plot(xs[0],results[0].init_fit)
ax.set_xlabel('F0g1 frequency (GHz)', size='large')
ax.set_ylabel('Re[S$_{11}$] (Arb. u.)', size='large')
plt.show()
results[id]
# Out:
# <h2> Model</h2> Model(Gaussian) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>72</td><td></td></tr><tr><td># data points</td><td>181</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 4.7297e-08</td><td></td></tr><tr><td>reduced chi-square</td><td> 2.6722e-10</td><td></td></tr><tr><td>Akaike info crit.</td><td>-3985.82106</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-3973.02707</td><td></td></tr><tr><td>R-squared</td><td> 0.94879289</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  2.4372e-04 </td><td>  4.7605e-06 </td><td> (1.95%) </td><td> 0.00035 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  3.5344e-05 </td><td>  1.4602e-06 </td><td> (4.13%) </td><td> 0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> center </td><td>  7.9758e+09 </td><td>  115288.833 </td><td> (0.00%) </td><td> 7990000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> k </td><td>  5235847.94 </td><td>  123528.083 </td><td> (2.36%) </td><td> 10000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>amp</td><td>k</td><td>-0.4481</td></tr><tr><td>const</td><td>k</td><td>+0.3592</td></tr><tr><td>amp</td><td>const</td><td>+0.2169</td></tr></table>

# %%
center1033_g = [8.0031e+09, 8.0024e+09, 8.0016e+09, 8.0007e+09, 7.9998e+09, 7.9989e+09,
                7.9978e+09, 7.9968e+09, 7.9958e+09, 7.9946e+09, 7.9935e+09, 7.9920e+09,
                7.9906e+09, 7.9890e+09, 7.9875e+09, 7.9858e+09, 7.9841e+09, 7.9820e+09,
                7.9802e+09, 7.9781e+09, 7.9758e+09]

# %% [markdown]
# 10.37 GHz

# %%
xs = []
ys = []
num_of_freq = 101

for i in range(21):
    ini = num_of_freq*i
    fin = num_of_freq*(1+i)-1
    x = dd1037['frequency']['values'][i]
    y_real = dd1037['s11']['values'][i].real
    y_imag = dd1037['s11']['values'][i].imag
    y_PCA = PCA_transform(y_real, y_imag)
    xs.append(x)
    ys.append(-y_PCA[0])

# %%
par_ini = {'amp': 0.00035,'const':0, 'center':8.02e9,'k':0.01e9}
par_min = {'amp': 0,'const':-np.inf,'center':0,'k':0}
par_max = {'amp': np.inf, 'const':np.inf,'center':np.inf,'k':np.inf}
par_vary = {'amp': True,'const':True, 'center':True,'k':True}
model = lmfit.Model(Gaussian)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )
results = []
for i in range(21):
    result = model.fit(data = ys[i], params=params, freq = xs[i])
    results.append(result)

# %%
fig, ax = plt.subplots(dpi=80)
id = 20
plt.rcParams["font.size"] = 10
ax.tick_params(axis="x", direction="in")
ax.tick_params(axis="y", direction="in")
plt.tick_params(
            top='on',
            bottom='on`',
            left='on',
            right='on',
            )

results[id].plot_fit(ax = ax)
# plt.plot(xs[0],results[0].init_fit)
ax.set_xlabel('F0g1 frequency (GHz)', size='large')
ax.set_ylabel('Re[S$_{11}$] (Arb. u.)', size='large')
plt.show()
results[id]
# Out:
# <h2> Model</h2> Model(Gaussian) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>86</td><td></td></tr><tr><td># data points</td><td>101</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 1.2446e-09</td><td></td></tr><tr><td>reduced chi-square</td><td> 1.2831e-11</td><td></td></tr><tr><td>Akaike info crit.</td><td>-2529.07971</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-2518.61923</td><td></td></tr><tr><td>R-squared</td><td> 0.84763381</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amp </td><td>  4.7039e-05 </td><td>  2.4138e-06 </td><td> (5.13%) </td><td> 0.00035 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  2.2075e-06 </td><td>  3.7561e-07 </td><td> (17.02%) </td><td> 0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> center </td><td>  8.0156e+09 </td><td>  55718.2500 </td><td> (0.00%) </td><td> 8020000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> k </td><td>  945457.460 </td><td>  56682.9617 </td><td> (6.00%) </td><td> 10000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>amp</td><td>k</td><td>-0.5437</td></tr><tr><td>const</td><td>k</td><td>+0.1884</td></tr><tr><td>amp</td><td>const</td><td>+0.1100</td></tr></table>

# %%
center1037_g = [8.0214e+09, 8.0214e+09, 8.0212e+09, 8.0210e+09, 8.0208e+09, 8.0207e+09, 8.0203e+09,
                8.0202e+09, 8.0198e+09, 8.0196e+09, 8.0194e+09, 8.0192e+09, 8.0188e+09, 8.0184e+09,
                8.0181e+09, 8.0179e+09, 8.0173e+09, 8.0169e+09, 8.0166e+09, 8.0161e+09, 8.0156e+09]

# %%
power_dBm = np.linspace(-10, -5, 21)
power_W = 10**((power_dBm)/10) *1e-3

# %%
# plt.plot(power_W, center1037_g, '.', label="10.37 GHz")
plt.plot(power_W, center1033_g, '.', label="10.33 GHz")
# plt.plot(power_W, center1031_g, '.', label="10.31 GHz")
plt.plot(power_W, center1030_g, '.', label="10.30 GHz")
# plt.plot(power_W, center1029_g, '.', label="10.29 GHz")
plt.plot(power_W, center1028_g, '.', label="10.28 GHz")
plt.plot(power_W, center1026_g, '.', label="10.26 GHz")
plt.plot(power_W, center1022_g, '.', label="10.22 GHz")

plt.show()

# %%
def liner_func(power, alpha, const):
    return const - alpha*power

# %%
par_ini = {'alpha': 0.015e9/0.00005,'const':8.005e9}
par_min = {'alpha': -np.inf,'const':-np.inf}
par_max = {'alpha': np.inf,'const':np.inf}
par_vary = {'alpha': True,'const':True}
model = lmfit.Model(liner_func)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )
# result1037 = model.fit(data = center1037_g, params=params, power = power_W)
result1033 = model.fit(data = center1033_g, params=params, power = power_W)
# result1031 = model.fit(data = center1031_g, params=params, power = power_W)
result1030 = model.fit(data = center1030_g, params=params, power = power_W)
# result1029 = model.fit(data = center1029_g, params=params, power = power_W)
result1028 = model.fit(data = center1028_g, params=params, power = power_W)
result1026 = model.fit(data = center1026_g, params=params, power = power_W)
result1022 = model.fit(data = center1022_g, params=params, power = power_W)

# %%
fig, ax = plt.subplots(dpi=80)
plt.rcParams["font.size"] = 10
ax.tick_params(axis="x", direction="in")
ax.tick_params(axis="y", direction="in")
# result1037.plot_fit(ax = ax)
result1033.plot_fit(ax = ax)
# result1031.plot_fit(ax = ax)
result1030.plot_fit(ax = ax)
# result1029.plot_fit(ax = ax)
result1028.plot_fit(ax = ax)
result1026.plot_fit(ax = ax)
result1022.plot_fit(ax = ax)
ax.set_xlabel('Power (W)', size='large')
ax.set_ylabel('Drive freq (Hz)', size='large')
plt.legend()
plt.show()
result1022
# Out:
# <h2> Model</h2> Model(liner_func) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>7</td><td></td></tr><tr><td># data points</td><td>21</td><td></td></tr><tr><td># variables</td><td>2</td><td></td></tr><tr><td>chi-square</td><td> 5.8986e+10</td><td></td></tr><tr><td>reduced chi-square</td><td> 3.1045e+09</td><td></td></tr><tr><td>Akaike info crit.</td><td> 460.877040</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 462.966084</td><td></td></tr><tr><td>R-squared</td><td> 0.99964494</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> alpha </td><td>  4.3243e+10 </td><td>  1.8697e+08 </td><td> (0.43%) </td><td> 300000000000.0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> const </td><td>  8.0160e+09 </td><td>  37340.4883 </td><td> (0.00%) </td><td> 8005000000.0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>alpha</td><td>const</td><td>+0.9455</td></tr></table>

# %%
x = np.array([10.33e9, 10.30e9, 10.28e9, 10.26e9, 10.22e9])
alpha = -np.array([1.2620e+11, 2.8194e+11, 1.7581e+11, 9.8051e+10, 	4.3243e+10])
plt.plot(x, alpha, '.')
plt.show()

# %%
from scipy.constants import *

# %%
# k_sunada - dpr model
# k_f =0.21238950e9
chi_Hz = -1500000.0
chi = chi_Hz*2*np.pi

# omega_p =np.array([10.37e9, 10.33e9, 10.31e9, 10.30e9,10.29e9, 10.28e9, 10.26e9, 10.22e9])*2*np.pi
# omega_f = 10.1676834e9 *2*np.pi
# omega_r =10.2557302e9*2*np.pi
omega_p=np.array([10.33e9, 10.30e9, 10.28e9, 10.26e9, 10.22e9])*2*np.pi

# g = 0.1011e9
# slope= np.array([-2.7268e+10, -1.3029e+11, -2.6321e+11, -2.8213e+11, -2.4807e+11,  -1.8144e+11, -1.0320e+11, -4.4706e+10])*2*np.pi
slope= -np.array([1.2620e+11, 2.8194e+11, 1.7581e+11, 9.8051e+10, 	4.3243e+10])*2*np.pi
P = 0.0002
# P_eff = P * g* k_f**0.5/(1j*(omega_f-omega_p)+k_f/2)/k_eff**0.5
Delta_q = np.array(slope*P * 2*np.pi)
# delta_f = omega_p-omega_f
# delta_r = omega_p-omega_r

def coeff2(k_f, delta_r, delta_f, g):
    numer = k_f *g**2/(delta_r**2)
    denom = (delta_f - g**2/delta_r)**2 +(k_f/2)**2
    return numer/denom

def ac_stark_shift1(omega,  omega_r, omega_f, k_f, g, alpha):
    return 2*chi*alpha/(hbar*omega)*coeff2(k_f=k_f, delta_r=omega-omega_r, delta_f=omega-omega_f, g=g)

# %%
# x=np.array([10.37e9, 10.33e9, 10.31e9, 10.30e9,10.29e9, 10.28e9, 10.26e9, 10.22e9])*2*np.pi
# slope= np.array([-2.7268e+10, -1.3029e+11, -2.6321e+11, -2.8213e+11, -2.4807e+11,  -1.8144e+11, -1.0320e+11, -4.4706e+10])*2*np.pi

x=np.array([10.33e9, 10.30e9, 10.28e9, 10.26e9, 10.22e9])*2*np.pi
slope= -np.array([1.2620e+11, 2.8194e+11, 1.7581e+11, 9.8051e+10, 	4.3243e+10])*2*np.pi
par_ini = {'omega_r':10.267e9*2*np.pi, 'omega_f':10.176e9*2*np.pi,
           'k_f':0.20e9*2*np.pi,'g':0.083e9*2*np.pi, 'alpha':4.4e-11}
par_min = {'omega_r':0, 'omega_f':0,'k_f':0,'g':0, 'alpha':0}
par_max = {'omega_r':np.inf,'omega_f':np.inf, 'k_f':np.inf,'g':np.inf, 'alpha':np.inf}
par_vary = { 'omega_r':False,'omega_f':False, 'k_f':False,'g':False, 'alpha':True}
model = lmfit.Model(ac_stark_shift1)

params = model.make_params()
for name in model.param_names:
    params[name].set(
    value = par_ini[name],
    min = par_min[name],
    max = par_max[name],
    vary = par_vary[name]
    )
result = model.fit(data = slope, params=params, omega =x )

# %%
fig, ax = plt.subplots(figsize=(9,7),constrained_layout=True)
plt.rcParams["font.size"] = 20
# plt.title("Rabi(amp)")
plt.tick_params(top='on',bottom='on',left='on',right='on',)
plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'

# result.plot_fit(ax = ax)# result = model.fit(y, params, x=x)
x_interp = np.linspace(10.22e9, 10.33e9, 100*5)*2*np.pi
y_interp = result.model.func(x_interp, **result.best_values)
plt.xlim(10.22, 10.33)
plt.plot(x/(2*np.pi)*1e-9, slope/(2*np.pi)*1e-9,'o', label='original')
plt.plot(x_interp/(2*np.pi)*1e-9, y_interp/(2*np.pi)*1e-9, label='interpolated')
# ax.plot(x/(2*np.pi)*1e-9,result.init_fit/(2*np.pi)*1e-9)
ax.set_xlabel('Probe frequency $\omega_\mathrm{p}/2\pi$ (GHz)', size='large')
ax.set_ylabel('Shift $(\Delta_\mathrm{ac}/2\pi)$ / VNA power $P_\mathrm{VNA}$ (GHz/W)')
plt.gca().xaxis.set_major_formatter(plt.FormatStrFormatter('%.2f'))
# plt.savefig('slope.png', bbox_inches='tight')
plt.show()

result
# Out:
# <h2> Model</h2> Model(ac_stark_shift1) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>9</td><td></td></tr><tr><td># data points</td><td>5</td><td></td></tr><tr><td># variables</td><td>1</td><td></td></tr><tr><td>chi-square</td><td> 1.5315e+22</td><td></td></tr><tr><td>reduced chi-square</td><td> 3.8287e+21</td><td></td></tr><tr><td>Akaike info crit.</td><td> 249.368294</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 248.977732</td><td></td></tr><tr><td>R-squared</td><td> 0.98810556</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> omega_r </td><td>  6.4509e+10 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 64509463548.81281 </td><td>  0.00000000 </td><td>         inf </td><td> False </td></tr><tr><td> omega_f </td><td>  6.3938e+10 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 63937693685.85947 </td><td>  0.00000000 </td><td>         inf </td><td> False </td></tr><tr><td> k_f </td><td>  1.2566e+09 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 1256637061.4359171 </td><td>  0.00000000 </td><td>         inf </td><td> False </td></tr><tr><td> g </td><td>  5.2150e+08 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 521504380.49590564 </td><td>  0.00000000 </td><td>         inf </td><td> False </td></tr><tr><td> alpha </td><td>  5.6292e-11 </td><td>  1.5164e-12 </td><td> (2.69%) </td><td> 4.4e-11 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table>

# %%
def watt_dbm(watt):
    return 10*np.log10(watt*1e3)

def dbm_watt(dBm):
    return (10**(dBm/10))*1e-3

# %%
watt_dbm(5.6292e-11*1e-3) + 50
# Out:
# -52.49553321005217

# %% [markdown]
# n_crit, n_ave

# %%
omega = np.linspace(9.8, 10.8, 100)*1e9*2*np.pi
k_f = 2.0003e+08*2*np.pi
omega_f = 1.0177e+10 *2*np.pi
omega_r = 1.0267e+10 *2*np.pi
g = 82703425.3*2*np.pi
alpha = 5.7965e-11
Power = dbm_watt(-10)
n_ave = alpha*Power/(hbar*omega)*coeff2(k_f=k_f, delta_r=omega-omega_r, delta_f=omega-omega_f, g=g)
plt.plot(omega/(2*np.pi), n_ave)
plt.xlim(10.25e9, 10.35e9)
# Out:
# (10250000000.0, 10350000000.0)

# %%
readout_freq = 10.3
readout_lo_freq = 10.38 # 10.387
readout_if_freq = readout_lo_freq - readout_freq
JPA_if_freq = readout_freq * 2 - readout_lo_freq * 2

qubit_lo_freq = 7.85
ge_freq = 8.012+0.0089-2.8e-05
anharmonicity = 7.682-ge_freq+0.0208-6.5e-4
ge_if_freq = ge_freq-qubit_lo_freq
print(ge_freq, anharmonicity)
# Out:
# 8.020872 -0.3187220000000003

# %%
omega_q = 8.012e9*2*np.pi

omega_r = 1.0267e+10 *2*np.pi
delta = omega_q-omega_r
kai = -1500000 *2*np.pi
alpha = -0.3187e+9*2*np.pi
g = (kai*(delta+alpha)/2)**0.5


n_crit =( ((delta+2*alpha)/(2*g))**2-2)/5
delta, n_crit
# Out:
# (-14168582867.689964, 216.30429757417977)

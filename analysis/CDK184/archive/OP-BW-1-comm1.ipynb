# %%
import numpy as np
import matplotlib.pyplot as plt
import lmfit
from Analysis import (
    SpatiotemporalAnalysis,demodulate
)
from matplotlib.lines import Line2D
# Out:
# c:\Users\qipe\Documents\K_Sunada\analysis\CDK184\Analysis.py:725: SyntaxWarning: invalid escape sequence '\G'
#   ax.set_ylabel('$\Gamma_f $ (MHz)')
# c:\Users\qipe\Documents\K_Sunada\analysis\CDK184\Analysis.py:727: SyntaxWarning: invalid escape sequence '\G'
#   ax2.set_ylabel('$\Gamma_f $ (MHz)')
# c:\Users\qipe\Documents\K_Sunada\analysis\CDK184\Analysis.py:774: SyntaxWarning: invalid escape sequence '\G'
#   ax.set_ylabel('$\Gamma_{\mathrm{f}}$ (MHz)')
# c:\Users\qipe\Documents\K_Sunada\analysis\CDK184\Analysis.py:780: SyntaxWarning: invalid escape sequence '\G'
#   ax2.set_xlabel('$\Gamma_{\mathrm{f}}$ (GHz)')
# c:\Users\qipe\Documents\K_Sunada\analysis\CDK184\Analysis.py:810: SyntaxWarning: invalid escape sequence '\G'
#   ax.set_ylabel('$\Gamma_{\mathrm{ph}}$')

# %% [markdown]
# Fogi timing

# %%
np.linspace(158, 278, 21)
# Out:
# array([158., 164., 170., 176., 182., 188., 194., 200., 206., 212., 218.,
#        224., 230., 236., 242., 248., 254., 260., 266., 272., 278.])

# %%
cd = "CDK184"
ctrl_path = "C:/Users/qipe/Documents/K_Sunada/result/CDK184/"

result_dict_tx = dict(
   data_ph0 = dict(target_freq=9.38, date="2025-08-14", acquire_time="114745", duration=2000),
   data_ph1 = dict(target_freq=9.38, date="2025-08-14", acquire_time="114825", duration=2000),
   data_ph2 = dict(target_freq=9.38, date="2025-08-14", acquire_time="114905", duration=2000),
   data_ph3 = dict(target_freq=9.38, date="2025-08-14", acquire_time="114945", duration=2000),
   data_ph4 = dict(target_freq=9.38, date="2025-08-14", acquire_time="115025", duration=2000),
   data_ph5 = dict(target_freq=9.38, date="2025-08-14", acquire_time="115106", duration=2000),
   data_ph6 = dict(target_freq=9.38, date="2025-08-14", acquire_time="115146", duration=2000),
   data_ph7 = dict(target_freq=9.38, date="2025-08-14", acquire_time="115226", duration=2000),
)

result_dict_rx = dict(
    data_ph0 = dict(target_freq=9.38, date="2025-08-14", acquire_time="122105", duration=2000),
    data_ph1 = dict(target_freq=9.38, date="2025-08-14", acquire_time="121224", duration=2000),
    data_ph2 = dict(target_freq=9.38, date="2025-08-14", acquire_time="121303", duration=2000),
    data_ph3 = dict(target_freq=9.38, date="2025-08-14", acquire_time="121343", duration=2000),
    data_ph4 = dict(target_freq=9.38, date="2025-08-14", acquire_time="121423", duration=2000),
    data_ph5 = dict(target_freq=9.38, date="2025-08-14", acquire_time="121503", duration=2000),
    data_ph6 = dict(target_freq=9.38, date="2025-08-14", acquire_time="121543", duration=2000),
    data_ph7 = dict(target_freq=9.38, date="2025-08-14", acquire_time="121623", duration=2000),
)

# %% [markdown]
# one point

# %%
header = "C:/Users/qipe/Documents/K_Sunada/result/CDK184/"
ph0_fo0 = "/2025-08-14/2025-08-14T213246_c852bba3-j1_JPA_comm_timing"
ph0_fo1 = "/2025-08-14/2025-08-14T213354_f0f3c5ec-j1_JPA_comm_timing"
ph0_fo2 = "/2025-08-14/2025-08-14T213502_19616c70-j1_JPA_comm_timing"
ph0_fo3 = "/2025-08-14/2025-08-14T213610_41bb170c-j1_JPA_comm_timing"
ph0_fo4 = "/2025-08-14/2025-08-14T213717_6a05a8f2-j1_JPA_comm_timing"
ph0_fo5 = "/2025-08-14/2025-08-14T213826_92d28eb8-j1_JPA_comm_timing"
ph0_fo6 = "/2025-08-14/2025-08-14T213934_bb2cc7fc-j1_JPA_comm_timing"
ph0_fo7 = "/2025-08-14/2025-08-14T214041_e397fe67-j1_JPA_comm_timing"

ph1_fo0 = "/2025-08-14/2025-08-14T214149_0c0fe2e2-j1_JPA_comm_timing"
ph1_fo1 = "/2025-08-14/2025-08-14T214257_348d7f64-j1_JPA_comm_timing"
ph1_fo2 = "/2025-08-14/2025-08-14T214405_5d3d6f86-j1_JPA_comm_timing"
ph1_fo3 = "/2025-08-14/2025-08-14T214514_8630a876-j1_JPA_comm_timing"
ph1_fo4 = "/2025-08-14/2025-08-14T214623_aefe8598-j1_JPA_comm_timing"
ph1_fo5 = "/2025-08-14/2025-08-14T214731_d7bd88a8-j1_JPA_comm_timing"
ph1_fo6 = "/2025-08-14/2025-08-14T214840_00d28572-j1_JPA_comm_timing"
ph1_fo7 = "/2025-08-14/2025-08-14T214948_2953170f-j1_JPA_comm_timing"

# ph2_fo0 = "/2025-08-14/2025-08-14T215056_51cf84b2-j1_JPA_comm_timing"
ph2_fo0 = "/2025-08-14/2025-08-14T225129_c77bbea0-j1_JPA_comm_timing"
ph2_fo1 = "/2025-08-14/2025-08-14T215204_7a665d90-j1_JPA_comm_timing"
ph2_fo2 = "/2025-08-14/2025-08-14T215312_a30f843f-j1_JPA_comm_timing"
ph2_fo3 = "/2025-08-14/2025-08-14T215421_cc23020e-j1_JPA_comm_timing"
ph2_fo4 = "/2025-08-14/2025-08-14T215529_f4cd97ee-j1_JPA_comm_timing"
ph2_fo5 = "/2025-08-14/2025-08-14T215637_1d5524e2-j1_JPA_comm_timing"
ph2_fo6 = "/2025-08-14/2025-08-14T215745_45f2de73-j1_JPA_comm_timing"
ph2_fo7 = "/2025-08-14/2025-08-14T215854_6e9979f4-j1_JPA_comm_timing"

# ph3_fo0 = "/2025-08-14/2025-08-14T220002_97614ba5-j1_JPA_comm_timing"
ph3_fo0 = "/2025-08-14/2025-08-14T225248_f65dc065-j1_JPA_comm_timing"
# ph3_fo1 = "/2025-08-14/2025-08-14T220110_c01bf356-j1_JPA_comm_timing"
ph3_fo1 = "/2025-08-14/2025-08-14T225356_1f022f26-j1_JPA_comm_timing"
ph3_fo2 = "/2025-08-14/2025-08-14T220219_e8dc2022-j1_JPA_comm_timing"
ph3_fo3 = "/2025-08-14/2025-08-14T220328_11e40fa3-j1_JPA_comm_timing"
ph3_fo4 = "/2025-08-14/2025-08-14T220436_3abb651d-j1_JPA_comm_timing"
ph3_fo5 = "/2025-08-14/2025-08-14T220545_639f1adf-j1_JPA_comm_timing"
ph3_fo6 = "/2025-08-14/2025-08-14T220653_8c66f8c8-j1_JPA_comm_timing"
ph3_fo7 = "/2025-08-14/2025-08-14T220802_b53472fa-j1_JPA_comm_timing"

ph4_fo0 = "/2025-08-14/2025-08-14T220910_ddd22902-j1_JPA_comm_timing"
ph4_fo1 = "/2025-08-14/2025-08-14T221018_06d43b77-j1_JPA_comm_timing"
ph4_fo2 = "/2025-08-14/2025-08-14T221127_2fa29e61-j1_JPA_comm_timing"
ph4_fo3 = "/2025-08-14/2025-08-14T221235_588294d2-j1_JPA_comm_timing"
ph4_fo4 = "/2025-08-14/2025-08-14T221344_817c5247-j1_JPA_comm_timing"
ph4_fo5 = "/2025-08-14/2025-08-14T221453_aa4cc411-j1_JPA_comm_timing"
ph4_fo6 = "/2025-08-14/2025-08-14T221601_d32e2099-j1_JPA_comm_timing"
ph4_fo7 = "/2025-08-14/2025-08-14T221710_fc0cd9fa-j1_JPA_comm_timing"

# ph5_fo0 = "/2025-08-14/2025-08-14T221819_251c5f7a-j1_JPA_comm_timing"
ph5_fo0 = "/2025-08-14/2025-08-14T230210_4542e70e-j1_JPA_comm_timing"
ph5_fo1 = "/2025-08-14/2025-08-14T221927_4deac006-j1_JPA_comm_timing"
ph5_fo2 = "/2025-08-14/2025-08-14T222036_76af12b6-j1_JPA_comm_timing"
ph5_fo3 = "/2025-08-14/2025-08-14T222144_9f834eb6-j1_JPA_comm_timing"
ph5_fo4 = "/2025-08-14/2025-08-14T222253_c8563171-j1_JPA_comm_timing"
ph5_fo5 = "/2025-08-14/2025-08-14T222401_f1167539-j1_JPA_comm_timing"
ph5_fo6 = "/2025-08-14/2025-08-14T222510_1a2a32c1-j1_JPA_comm_timing"
ph5_fo7 = "/2025-08-14/2025-08-14T222619_432a9127-j1_JPA_comm_timing"

# ph6_fo0 = "/2025-08-14/2025-08-14T222727_6c094b75-j1_JPA_comm_timing"
ph6_fo0 = "/2025-08-14/2025-08-14T224752_45fe3a4b-j1_JPA_comm_timing"
ph6_fo1 = "/2025-08-14/2025-08-14T222836_94f29ea7-j1_JPA_comm_timing"
ph6_fo2 = "/2025-08-14/2025-08-14T222944_bdc3f578-j1_JPA_comm_timing"
ph6_fo3 = "/2025-08-14/2025-08-14T223053_e693edb5-j1_JPA_comm_timing"
ph6_fo4 = "/2025-08-14/2025-08-14T223202_0faae0f0-j1_JPA_comm_timing"
# ph6_fo5 = "/2025-08-14/2025-08-14T223311_38c3fb89-j1_JPA_comm_timing"
ph6_fo6 = "/2025-08-14/2025-08-14T223419_61ba3212-j1_JPA_comm_timing"
ph6_fo5 = "/2025-08-14/2025-08-14T224901_6f079d6c-j1_JPA_comm_timing"
# ph6_fo6 = "/2025-08-14/2025-08-14T225009_9773fa69-j1_JPA_comm_timing"
ph6_fo7 = "/2025-08-14/2025-08-14T223529_8b27e3f4-j1_JPA_comm_timing"

ph7_fo0 = "/2025-08-14/2025-08-14T223638_b434db96-j1_JPA_comm_timing"
ph7_fo1 = "/2025-08-14/2025-08-14T223747_dd344cf0-j1_JPA_comm_timing"
ph7_fo2 = "/2025-08-14/2025-08-14T223856_066fa0b1-j1_JPA_comm_timing"
ph7_fo3 = "/2025-08-14/2025-08-14T224005_2fbcc96d-j1_JPA_comm_timing"
ph7_fo4 = "/2025-08-14/2025-08-14T224114_58b13d86-j1_JPA_comm_timing"
ph7_fo5 = "/2025-08-14/2025-08-14T224223_81c3e61b-j1_JPA_comm_timing"
ph7_fo6 = "/2025-08-14/2025-08-14T224332_ab240732-j1_JPA_comm_timing"
ph7_fo7 = "/2025-08-14/2025-08-14T224441_d43b403d-j1_JPA_comm_timing"

# %%
num_of_ph_amp = 1
num_of_fogi_timing = 11
f_if = (9.5-9.38)*1e9

# %%
acquisition_00 = SpatiotemporalAnalysis(ctrl_path, ph0_fo0, ctrl_path, result_dict_tx['data_ph0'], result_dict_rx['data_ph0'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_01 = SpatiotemporalAnalysis(ctrl_path, ph0_fo1, ctrl_path, result_dict_tx['data_ph0'], result_dict_rx['data_ph1'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_02 = SpatiotemporalAnalysis(ctrl_path, ph0_fo2, ctrl_path, result_dict_tx['data_ph0'], result_dict_rx['data_ph2'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_03 = SpatiotemporalAnalysis(ctrl_path, ph0_fo3, ctrl_path, result_dict_tx['data_ph0'], result_dict_rx['data_ph3'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_04 = SpatiotemporalAnalysis(ctrl_path, ph0_fo4, ctrl_path, result_dict_tx['data_ph0'], result_dict_rx['data_ph4'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_05 = SpatiotemporalAnalysis(ctrl_path, ph0_fo5, ctrl_path, result_dict_tx['data_ph0'], result_dict_rx['data_ph5'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_06 = SpatiotemporalAnalysis(ctrl_path, ph0_fo6, ctrl_path, result_dict_tx['data_ph0'], result_dict_rx['data_ph6'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_07 = SpatiotemporalAnalysis(ctrl_path, ph0_fo7, ctrl_path, result_dict_tx['data_ph0'], result_dict_rx['data_ph7'], num_of_ph_amp, num_of_fogi_timing, f_if)
fig, ax = plt.subplots()
acquisition_00.plot_results(ax, label="ph_0 & fogi_0", color="tab:blue", fitting=True)
acquisition_01.plot_results(ax, label="ph_0 & fogi_1", color="tab:orange", fitting=True)
acquisition_02.plot_results(ax, label="ph_0 & fogi_2", color="tab:green", fitting=True)
acquisition_03.plot_results(ax, label="ph_0 & fogi_3", color="tab:red", fitting=True)
acquisition_04.plot_results(ax, label="ph_0 & fogi_4", color="tab:purple", fitting=True)
acquisition_05.plot_results(ax, label="ph_0 & fogi_5", color="tab:brown", fitting=True)
acquisition_06.plot_results(ax, label="ph_0 & fogi_6", color="tab:pink", fitting=True)
acquisition_07.plot_results(ax, label="ph_0 & fogi_7", color="tab:gray", fitting=True)

ax.set_ylim(-0.10, 1)
ax.set_xlim(0, 40)
ax.vlines(18, -10, 100, color="r", linestyle="dashed")
custom_legend = [
    Line2D([0], [0], color="none", marker="o", linestyle="None", label="$R_{nm}$"),
    Line2D([0], [0], color="tab:blue", marker="o", linestyle="None",label="(0, 0)"),
    Line2D([0], [0], color="tab:orange", marker="o", linestyle="None",label="(0, 1)"),
    Line2D([0], [0], color="tab:green", marker="o", linestyle="None",label="(0, 2)"),
    Line2D([0], [0], color="tab:red", marker="o", linestyle="None",label="(0, 3)"),
    Line2D([0], [0], color="tab:purple", marker="o", linestyle="None",label="(0, 4)"),
    Line2D([0], [0], color="tab:brown", marker="o", linestyle="None",label="(0, 5)"),
    Line2D([0], [0], color="tab:pink", marker="o", linestyle="None",label="(0, 6)"),
    Line2D([0], [0], color="tab:gray", marker="o", linestyle="None",label="(0, 7)"),
    Line2D([0], [0], color="none", marker="", label=""),
    Line2D([0], [0], color="none", linestyle="-", label="$|I_{nm}|^2$"),
    Line2D([0], [0], color="tab:blue", linestyle="-", label="(0, 0)"),
    Line2D([0], [0], color="tab:orange", linestyle="-", label="(0, 1)"),
    Line2D([0], [0], color="tab:green", linestyle="-", label="(0, 2)"),
    Line2D([0], [0], color="tab:red", linestyle="-", label="(0, 3)"),
    Line2D([0], [0], color="tab:purple", linestyle="-", label="(0, 4)"),
    Line2D([0], [0], color="tab:brown", linestyle="-", label="(0, 5)"),
    Line2D([0], [0], color="tab:pink", linestyle="-", label="(0, 6)"),
    Line2D([0], [0], color="tab:gray", linestyle="-", label="(0, 7)"),
]
plt.legend(handles=custom_legend, loc="upper left", bbox_to_anchor=(1., 1),ncol=1,  fontsize="small", 
           handletextpad=0.5, borderpad=0.3 )
plt.hlines(0, 0, 40, "black")
plt.xlabel("f0g1 delay (ns)")
plt.ylabel("Absorption rate")
# plt.savefig('abs_timing.png', bbox_inches='tight')
plt.show()
# Out:
# delay 46.79999999999999
# delay -83.70000000000024
# delay -150.30000000000044
# delay -228.60000000000065
# delay -55.80000000000017
# delay -123.30000000000035
# delay -45.000000000000156
# delay 60.29999999999998

# %%
ph_amp = 0
fogi_freq = 0
fig, axs = plt.subplots(4, 2, figsize=(3.2, 4.4) , constrained_layout=True) 
ax_00, t_00, y_abs_00 =acquisition_00.plot_waveform_8(ax=axs[0, 0], title="(0, 0)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_01, t_01, y_abs_01 =acquisition_01.plot_waveform_8(ax=axs[0, 1], title="(0, 1)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_02, t_02, y_abs_02 =acquisition_02.plot_waveform_8(ax=axs[1, 0], title="(0, 2)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_03, t_03, y_abs_03 =acquisition_03.plot_waveform_8(ax=axs[1, 1], title="(0, 3)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_04, t_04, y_abs_04 =acquisition_04.plot_waveform_8(ax=axs[2, 0], title="(0, 4)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_05, t_05, y_abs_05 =acquisition_05.plot_waveform_8(ax=axs[2, 1], title="(0, 5)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_06, t_06, y_abs_06 =acquisition_06.plot_waveform_8(ax=axs[3, 0], title="(0, 6)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_07, t_07, y_abs_07 =acquisition_07.plot_waveform_8(ax=axs[3, 1], title="(0, 7)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
fig.text(-0.02, 0.55, "Amplitude (arb. unit)", va="center", rotation="vertical")
for ax in axs[-1, :]:
    ax.set_xlabel("Time (ns)")
# plt.tight_layout()
plt.show()
# Out:
# c:\Users\qipe\Documents\K_Sunada\.venv\Lib\site-packages\matplotlib\cbook.py:1719: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# c:\Users\qipe\Documents\K_Sunada\.venv\Lib\site-packages\matplotlib\cbook.py:1355: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
acquisition_10 = SpatiotemporalAnalysis(ctrl_path, ph1_fo0, ctrl_path, result_dict_tx['data_ph1'], result_dict_rx['data_ph0'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_11 = SpatiotemporalAnalysis(ctrl_path, ph1_fo1, ctrl_path, result_dict_tx['data_ph1'], result_dict_rx['data_ph1'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_12 = SpatiotemporalAnalysis(ctrl_path, ph1_fo2, ctrl_path, result_dict_tx['data_ph1'], result_dict_rx['data_ph2'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_13 = SpatiotemporalAnalysis(ctrl_path, ph1_fo3, ctrl_path, result_dict_tx['data_ph1'], result_dict_rx['data_ph3'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_14 = SpatiotemporalAnalysis(ctrl_path, ph1_fo4, ctrl_path, result_dict_tx['data_ph1'], result_dict_rx['data_ph4'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_15 = SpatiotemporalAnalysis(ctrl_path, ph1_fo5, ctrl_path, result_dict_tx['data_ph1'], result_dict_rx['data_ph5'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_16 = SpatiotemporalAnalysis(ctrl_path, ph1_fo6, ctrl_path, result_dict_tx['data_ph1'], result_dict_rx['data_ph6'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_17 = SpatiotemporalAnalysis(ctrl_path, ph1_fo7, ctrl_path, result_dict_tx['data_ph1'], result_dict_rx['data_ph7'], num_of_ph_amp, num_of_fogi_timing, f_if)

fig, ax = plt.subplots()
acquisition_10.plot_results(ax, label="ph_1 & fogi_0", color="tab:blue", fitting=True)
acquisition_11.plot_results(ax, label="ph_1 & fogi_1", color="tab:orange", fitting=True)
acquisition_12.plot_results(ax, label="ph_1 & fogi_2", color="tab:green", fitting=True)
acquisition_13.plot_results(ax, label="ph_1 & fogi_3", color="tab:red", fitting=True)
acquisition_14.plot_results(ax, label="ph_1 & fogi_4", color="tab:purple", fitting=True)
acquisition_15.plot_results(ax, label="ph_1 & fogi_5", color="tab:brown", fitting=True)
acquisition_16.plot_results(ax, label="ph_1 & fogi_6", color="tab:pink", fitting=True)
acquisition_17.plot_results(ax, label="ph_1 & fogi_7", color="tab:gray", fitting=True)

ax.set_ylim(-0.10, 1)
ax.set_xlim(0, 40)
ax.vlines(18, -10, 100, color="r", linestyle="dashed")
custom_legend = [
    Line2D([0], [0], color="none", marker="o", linestyle="None", label="$R_{nm}$"),
    Line2D([0], [0], color="tab:blue", marker="o", linestyle="None",label="(1, 0)"),
    Line2D([0], [0], color="tab:orange", marker="o", linestyle="None",label="(1, 1)"),
    Line2D([0], [0], color="tab:green", marker="o", linestyle="None",label="(1, 2)"),
    Line2D([0], [0], color="tab:red", marker="o", linestyle="None",label="(1, 3)"),
    Line2D([0], [0], color="tab:purple", marker="o", linestyle="None",label="(1, 4)"),
    Line2D([0], [0], color="tab:brown", marker="o", linestyle="None",label="(1, 5)"),
    Line2D([0], [0], color="tab:pink", marker="o", linestyle="None",label="(1, 6)"),
    Line2D([0], [0], color="tab:gray", marker="o", linestyle="None",label="(1, 7)"),
    Line2D([0], [0], color="none", marker="", label=""),
    Line2D([0], [0], color="none", linestyle="-", label="$|I_{nm}|^2$"),
    Line2D([0], [0], color="tab:blue", linestyle="-", label="(1, 0)"),
    Line2D([0], [0], color="tab:orange", linestyle="-", label="(1, 1)"),
    Line2D([0], [0], color="tab:green", linestyle="-", label="(1, 2)"),
    Line2D([0], [0], color="tab:red", linestyle="-", label="(1, 3)"),
    Line2D([0], [0], color="tab:purple", linestyle="-", label="(1, 4)"),
    Line2D([0], [0], color="tab:brown", linestyle="-", label="(1, 5)"),
    Line2D([0], [0], color="tab:pink", linestyle="-", label="(1, 6)"),
    Line2D([0], [0], color="tab:gray", linestyle="-", label="(1, 7)"),
]
plt.legend(handles=custom_legend, loc="upper left", bbox_to_anchor=(1., 1),ncol=1,  fontsize="small", 
           handletextpad=0.5, borderpad=0.3 )
plt.hlines(0, 0, 40, "black")
plt.xlabel("f0g1 delay (ns)")
plt.ylabel("Absorption rate")
# plt.savefig('abs_timing.png', bbox_inches='tight')
plt.show()
# Out:
# delay -81.00000000000024
# delay 46.79999999999999
# delay -42.30000000000015
# delay -97.20000000000027
# delay -168.30000000000047
# delay -47.70000000000016
# delay -108.90000000000032
# delay -33.300000000000125

# %%
ph_amp = 0
fogi_freq = 0
fig, axs = plt.subplots(4, 2, figsize=(3.2, 4.4) , constrained_layout=True) 
ax_10, t_10, y_abs_10 =acquisition_10.plot_waveform_8(ax=axs[0, 0], title="(1, 0)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0, norm=True)
ax_11, t_11, y_abs_11 =acquisition_11.plot_waveform_8(ax=axs[0, 1], title="(1, 1)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_12, t_12, y_abs_12 =acquisition_12.plot_waveform_8(ax=axs[1, 0], title="(1, 2)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_13, t_13, y_abs_13 =acquisition_13.plot_waveform_8(ax=axs[1, 1], title="(1, 3)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_14, t_14, y_abs_14 =acquisition_14.plot_waveform_8(ax=axs[2, 0], title="(1, 4)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_15, t_15, y_abs_15 =acquisition_15.plot_waveform_8(ax=axs[2, 1], title="(1, 5)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_16, t_16, y_abs_16 =acquisition_16.plot_waveform_8(ax=axs[3, 0], title="(1, 6)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_17, t_17, y_abs_17 =acquisition_17.plot_waveform_8(ax=axs[3, 1], title="(1, 7)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
fig.text(-0.02, 0.55, "Amplitude (arb. unit)", va="center", rotation="vertical")
for ax in axs[-1, :]:
    ax.set_xlabel("Time (ns)")
# plt.tight_layout()
plt.show()
# Out:
# c:\Users\qipe\Documents\K_Sunada\.venv\Lib\site-packages\matplotlib\cbook.py:1719: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# c:\Users\qipe\Documents\K_Sunada\.venv\Lib\site-packages\matplotlib\cbook.py:1355: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
acquisition_20 = SpatiotemporalAnalysis(ctrl_path, ph2_fo0, ctrl_path, result_dict_tx['data_ph2'], result_dict_rx['data_ph0'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_21 = SpatiotemporalAnalysis(ctrl_path, ph2_fo1, ctrl_path, result_dict_tx['data_ph2'], result_dict_rx['data_ph1'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_22 = SpatiotemporalAnalysis(ctrl_path, ph2_fo2, ctrl_path, result_dict_tx['data_ph2'], result_dict_rx['data_ph2'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_23 = SpatiotemporalAnalysis(ctrl_path, ph2_fo3, ctrl_path, result_dict_tx['data_ph2'], result_dict_rx['data_ph3'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_24 = SpatiotemporalAnalysis(ctrl_path, ph2_fo4, ctrl_path, result_dict_tx['data_ph2'], result_dict_rx['data_ph4'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_25 = SpatiotemporalAnalysis(ctrl_path, ph2_fo5, ctrl_path, result_dict_tx['data_ph2'], result_dict_rx['data_ph5'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_26 = SpatiotemporalAnalysis(ctrl_path, ph2_fo6, ctrl_path, result_dict_tx['data_ph2'], result_dict_rx['data_ph6'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_27 = SpatiotemporalAnalysis(ctrl_path, ph2_fo7, ctrl_path, result_dict_tx['data_ph2'], result_dict_rx['data_ph7'], num_of_ph_amp, num_of_fogi_timing, f_if)

fig, ax = plt.subplots()
acquisition_20.plot_results(ax, label="ph_2 & fogi_0", color="tab:blue", fitting=True)
acquisition_21.plot_results(ax, label="ph_2 & fogi_1", color="tab:orange", fitting=True)
acquisition_22.plot_results(ax, label="ph_2 & fogi_2", color="tab:green", fitting=True)
acquisition_23.plot_results(ax, label="ph_2 & fogi_3", color="tab:red", fitting=True)
acquisition_24.plot_results(ax, label="ph_2 & fogi_4", color="tab:purple", fitting=True)
acquisition_25.plot_results(ax, label="ph_2 & fogi_5", color="tab:brown", fitting=True)
acquisition_26.plot_results(ax, label="ph_2 & fogi_6", color="tab:pink", fitting=True)
acquisition_27.plot_results(ax, label="ph_2 & fogi_7", color="tab:gray", fitting=True)

ax.set_ylim(-0.10, 1)
ax.set_xlim(0, 40)
ax.vlines(18, -10, 100, color="r", linestyle="dashed")
custom_legend = [
    Line2D([0], [0], color="none", marker="o", linestyle="None", label="$R_{nm}$"),
    Line2D([0], [0], color="tab:blue", marker="o", linestyle="None",label="(2, 0)"),
    Line2D([0], [0], color="tab:orange", marker="o", linestyle="None",label="(2, 1)"),
    Line2D([0], [0], color="tab:green", marker="o", linestyle="None",label="(2, 2)"),
    Line2D([0], [0], color="tab:red", marker="o", linestyle="None",label="(2, 3)"),
    Line2D([0], [0], color="tab:purple", marker="o", linestyle="None",label="(2, 4)"),
    Line2D([0], [0], color="tab:brown", marker="o", linestyle="None",label="(2, 5)"),
    Line2D([0], [0], color="tab:pink", marker="o", linestyle="None",label="(2, 6)"),
    Line2D([0], [0], color="tab:gray", marker="o", linestyle="None",label="(2, 7)"),
    Line2D([0], [0], color="none", marker="", label=""),
    Line2D([0], [0], color="none", linestyle="-", label="$|I_{nm}|^2$"),
    Line2D([0], [0], color="tab:blue", linestyle="-", label="(2, 0)"),
    Line2D([0], [0], color="tab:orange", linestyle="-", label="(2, 1)"),
    Line2D([0], [0], color="tab:green", linestyle="-", label="(2, 2)"),
    Line2D([0], [0], color="tab:red", linestyle="-", label="(2, 3)"),
    Line2D([0], [0], color="tab:purple", linestyle="-", label="(2, 4)"),
    Line2D([0], [0], color="tab:brown", linestyle="-", label="(2, 5)"),
    Line2D([0], [0], color="tab:pink", linestyle="-", label="(2, 6)"),
    Line2D([0], [0], color="tab:gray", linestyle="-", label="(2, 7)"),
]
plt.legend(handles=custom_legend, loc="upper left", bbox_to_anchor=(1., 1),ncol=1,  fontsize="small", 
           handletextpad=0.5, borderpad=0.3 )
plt.hlines(0, 0, 40, "black")
plt.xlabel("f0g1 delay (ns)")
plt.ylabel("Absorption rate")
# plt.savefig('abs_timing.png', bbox_inches='tight')
plt.show()
# Out:
# delay -152.10000000000042
# delay -43.20000000000015
# delay 45.89999999999999
# delay -37.80000000000013
# delay -89.10000000000025
# delay -150.30000000000044
# delay -41.40000000000015
# delay 190.79999999999998

# %%
ph_amp = 0
fogi_freq = 0
fig, axs = plt.subplots(4, 2, figsize=(3.2, 4.4) , constrained_layout=True) 
ax_20, t_20, y_abs_20 =acquisition_20.plot_waveform_8(ax=axs[0, 0], title="(2, 0)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0, norm=True)
ax_21, t_21, y_abs_21 =acquisition_21.plot_waveform_8(ax=axs[0, 1], title="(2, 1)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_22, t_22, y_abs_22 =acquisition_22.plot_waveform_8(ax=axs[1, 0], title="(2, 2)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_23, t_23, y_abs_23 =acquisition_23.plot_waveform_8(ax=axs[1, 1], title="(2, 3)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_24, t_24, y_abs_24 =acquisition_24.plot_waveform_8(ax=axs[2, 0], title="(2, 4)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_25, t_25, y_abs_25 =acquisition_25.plot_waveform_8(ax=axs[2, 1], title="(2, 5)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_26, t_26, y_abs_26 =acquisition_26.plot_waveform_8(ax=axs[3, 0], title="(2, 6)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_27, t_27, y_abs_27 =acquisition_27.plot_waveform_8(ax=axs[3, 1], title="(2, 7)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
fig.text(-0.02, 0.55, "Amplitude (arb. unit)", va="center", rotation="vertical")
for ax in axs[-1, :]:
    ax.set_xlabel("Time (ns)")
# plt.tight_layout()
plt.show()

# %%
acquisition_30 = SpatiotemporalAnalysis(ctrl_path, ph3_fo0, ctrl_path, result_dict_tx['data_ph3'], result_dict_rx['data_ph0'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_31 = SpatiotemporalAnalysis(ctrl_path, ph3_fo1, ctrl_path, result_dict_tx['data_ph3'], result_dict_rx['data_ph1'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_32 = SpatiotemporalAnalysis(ctrl_path, ph3_fo2, ctrl_path, result_dict_tx['data_ph3'], result_dict_rx['data_ph2'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_33 = SpatiotemporalAnalysis(ctrl_path, ph3_fo3, ctrl_path, result_dict_tx['data_ph3'], result_dict_rx['data_ph3'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_34 = SpatiotemporalAnalysis(ctrl_path, ph3_fo4, ctrl_path, result_dict_tx['data_ph3'], result_dict_rx['data_ph4'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_35 = SpatiotemporalAnalysis(ctrl_path, ph3_fo5, ctrl_path, result_dict_tx['data_ph3'], result_dict_rx['data_ph5'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_36 = SpatiotemporalAnalysis(ctrl_path, ph3_fo6, ctrl_path, result_dict_tx['data_ph3'], result_dict_rx['data_ph6'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_37 = SpatiotemporalAnalysis(ctrl_path, ph3_fo7, ctrl_path, result_dict_tx['data_ph3'], result_dict_rx['data_ph7'], num_of_ph_amp, num_of_fogi_timing, f_if)

fig, ax = plt.subplots()
acquisition_30.plot_results(ax, label="ph_3 & fogi_0", color="tab:blue", fitting=True)
acquisition_31.plot_results(ax, label="ph_3 & fogi_1", color="tab:orange", fitting=True)
acquisition_32.plot_results(ax, label="ph_3 & fogi_2", color="tab:green", fitting=True)
acquisition_33.plot_results(ax, label="ph_3 & fogi_3", color="tab:red", fitting=True)
acquisition_34.plot_results(ax, label="ph_3 & fogi_4", color="tab:purple", fitting=True)
acquisition_35.plot_results(ax, label="ph_3 & fogi_5", color="tab:brown", fitting=True)
acquisition_36.plot_results(ax, label="ph_3 & fogi_6", color="tab:pink", fitting=True)
acquisition_37.plot_results(ax, label="ph_3 & fogi_7", color="tab:gray", fitting=True)

ax.set_ylim(-0.10, 1)
ax.set_xlim(0, 40)
ax.vlines(18, -10, 100, color="r", linestyle="dashed")
custom_legend = [
    Line2D([0], [0], color="none", marker="o", linestyle="None", label="$R_{nm}$"),
    Line2D([0], [0], color="tab:blue", marker="o", linestyle="None",label="(3, 0)"),
    Line2D([0], [0], color="tab:orange", marker="o", linestyle="None",label="(3, 1)"),
    Line2D([0], [0], color="tab:green", marker="o", linestyle="None",label="(3, 2)"),
    Line2D([0], [0], color="tab:red", marker="o", linestyle="None",label="(3, 3)"),
    Line2D([0], [0], color="tab:purple", marker="o", linestyle="None",label="(3, 4)"),
    Line2D([0], [0], color="tab:brown", marker="o", linestyle="None",label="(3, 5)"),
    Line2D([0], [0], color="tab:pink", marker="o", linestyle="None",label="(3, 6)"),
    Line2D([0], [0], color="tab:gray", marker="o", linestyle="None",label="(3, 7)"),
    Line2D([0], [0], color="none", marker="", label=""),
    Line2D([0], [0], color="none", linestyle="-", label="$|I_{nm}|^2$"),
    Line2D([0], [0], color="tab:blue", linestyle="-", label="(3, 0)"),
    Line2D([0], [0], color="tab:orange", linestyle="-", label="(3, 1)"),
    Line2D([0], [0], color="tab:green", linestyle="-", label="(3, 2)"),
    Line2D([0], [0], color="tab:red", linestyle="-", label="(3, 3)"),
    Line2D([0], [0], color="tab:purple", linestyle="-", label="(3, 4)"),
    Line2D([0], [0], color="tab:brown", linestyle="-", label="(3, 5)"),
    Line2D([0], [0], color="tab:pink", linestyle="-", label="(3, 6)"),
    Line2D([0], [0], color="tab:gray", linestyle="-", label="(3, 7)"),
]
plt.legend(handles=custom_legend, loc="upper left", bbox_to_anchor=(1., 1),ncol=1,  fontsize="small", 
           handletextpad=0.5, borderpad=0.3 )
plt.hlines(0, 0, 40, "black")
plt.xlabel("f0g1 delay (ns)")
plt.ylabel("Absorption rate")
# plt.savefig('abs_timing.png', bbox_inches='tight')
plt.show()
# Out:
# delay -9.000000000000064
# delay -98.10000000000028
# delay -36.900000000000134
# delay 44.99999999999999
# delay -35.10000000000012
# delay -81.00000000000023
# delay -142.2000000000004
# delay -36.00000000000013

# %%
ph_amp = 0
fogi_freq = 0
fig, axs = plt.subplots(4, 2, figsize=(3.2, 4.4) , constrained_layout=True) 
ax_30, t_30, y_abs_30 =acquisition_30.plot_waveform_8(ax=axs[0, 0], title="(3, 0)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0, norm=True)
ax_31, t_31, y_abs_31 =acquisition_31.plot_waveform_8(ax=axs[0, 1], title="(3, 1)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_32, t_32, y_abs_32 =acquisition_32.plot_waveform_8(ax=axs[1, 0], title="(3, 2)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_33, t_33, y_abs_33 =acquisition_33.plot_waveform_8(ax=axs[1, 1], title="(3, 3)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_34, t_34, y_abs_34 =acquisition_34.plot_waveform_8(ax=axs[2, 0], title="(3, 4)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_35, t_35, y_abs_35 =acquisition_35.plot_waveform_8(ax=axs[2, 1], title="(3, 5)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_36, t_36, y_abs_36 =acquisition_36.plot_waveform_8(ax=axs[3, 0], title="(3, 6)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_37, t_37, y_abs_37 =acquisition_37.plot_waveform_8(ax=axs[3, 1], title="(3, 7)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
fig.text(-0.02, 0.55, "Amplitude (arb. unit)", va="center", rotation="vertical")
for ax in axs[-1, :]:
    ax.set_xlabel("Time (ns)")
# plt.tight_layout()
plt.show()

# %%
acquisition_40 = SpatiotemporalAnalysis(ctrl_path, ph4_fo0, ctrl_path, result_dict_tx['data_ph4'], result_dict_rx['data_ph0'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_41 = SpatiotemporalAnalysis(ctrl_path, ph4_fo1, ctrl_path, result_dict_tx['data_ph4'], result_dict_rx['data_ph1'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_42 = SpatiotemporalAnalysis(ctrl_path, ph4_fo2, ctrl_path, result_dict_tx['data_ph4'], result_dict_rx['data_ph2'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_43 = SpatiotemporalAnalysis(ctrl_path, ph4_fo3, ctrl_path, result_dict_tx['data_ph4'], result_dict_rx['data_ph3'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_44 = SpatiotemporalAnalysis(ctrl_path, ph4_fo4, ctrl_path, result_dict_tx['data_ph4'], result_dict_rx['data_ph4'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_45 = SpatiotemporalAnalysis(ctrl_path, ph4_fo5, ctrl_path, result_dict_tx['data_ph4'], result_dict_rx['data_ph5'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_46 = SpatiotemporalAnalysis(ctrl_path, ph4_fo6, ctrl_path, result_dict_tx['data_ph4'], result_dict_rx['data_ph6'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_47 = SpatiotemporalAnalysis(ctrl_path, ph4_fo7, ctrl_path, result_dict_tx['data_ph4'], result_dict_rx['data_ph7'], num_of_ph_amp, num_of_fogi_timing, f_if)

fig, ax = plt.subplots()
acquisition_40.plot_results(ax, label="ph_4 & fogi_0", color="tab:blue", fitting=True)
acquisition_41.plot_results(ax, label="ph_4 & fogi_1", color="tab:orange", fitting=True)
acquisition_42.plot_results(ax, label="ph_4 & fogi_2", color="tab:green", fitting=True)
acquisition_43.plot_results(ax, label="ph_4 & fogi_3", color="tab:red", fitting=True)
acquisition_44.plot_results(ax, label="ph_4 & fogi_4", color="tab:purple", fitting=True)
acquisition_45.plot_results(ax, label="ph_4 & fogi_5", color="tab:brown", fitting=True)
acquisition_46.plot_results(ax, label="ph_4 & fogi_6", color="tab:pink", fitting=True)
acquisition_47.plot_results(ax, label="ph_4 & fogi_7", color="tab:gray", fitting=True)

ax.set_ylim(-0.10, 1)
ax.set_xlim(0, 40)
ax.vlines(18, -10, 100, color="r", linestyle="dashed")
custom_legend = [
    Line2D([0], [0], color="none", marker="o", linestyle="None", label="$R_{nm}$"),
    Line2D([0], [0], color="tab:blue", marker="o", linestyle="None",label="(4, 0)"),
    Line2D([0], [0], color="tab:orange", marker="o", linestyle="None",label="(4, 1)"),
    Line2D([0], [0], color="tab:green", marker="o", linestyle="None",label="(4, 2)"),
    Line2D([0], [0], color="tab:red", marker="o", linestyle="None",label="(4, 3)"),
    Line2D([0], [0], color="tab:purple", marker="o", linestyle="None",label="(4, 4)"),
    Line2D([0], [0], color="tab:brown", marker="o", linestyle="None",label="(4, 5)"),
    Line2D([0], [0], color="tab:pink", marker="o", linestyle="None",label="(4, 6)"),
    Line2D([0], [0], color="tab:gray", marker="o", linestyle="None",label="(4, 7)"),
    Line2D([0], [0], color="none", marker="", label=""),
    Line2D([0], [0], color="none", linestyle="-", label="$|I_{nm}|^2$"),
    Line2D([0], [0], color="tab:blue", linestyle="-", label="(4, 0)"),
    Line2D([0], [0], color="tab:orange", linestyle="-", label="(4, 1)"),
    Line2D([0], [0], color="tab:green", linestyle="-", label="(4, 2)"),
    Line2D([0], [0], color="tab:red", linestyle="-", label="(4, 3)"),
    Line2D([0], [0], color="tab:purple", linestyle="-", label="(4, 4)"),
    Line2D([0], [0], color="tab:brown", linestyle="-", label="(4, 5)"),
    Line2D([0], [0], color="tab:pink", linestyle="-", label="(4, 6)"),
    Line2D([0], [0], color="tab:gray", linestyle="-", label="(4, 7)"),
]
plt.legend(handles=custom_legend, loc="upper left", bbox_to_anchor=(1., 1),ncol=1,  fontsize="small", 
           handletextpad=0.5, borderpad=0.3 )
plt.hlines(0, 0, 40, "black")
plt.xlabel("f0g1 delay (ns)")
plt.ylabel("Absorption rate")
# plt.savefig('abs_timing.png', bbox_inches='tight')
plt.show()
# Out:
# delay -52.20000000000017
# delay 73.79999999999998
# delay -87.30000000000027
# delay -36.00000000000013
# delay 46.79999999999999
# delay -34.200000000000124
# delay -77.40000000000022
# delay -140.40000000000038

# %%
ph_amp = 0
fogi_freq = 0
fig, axs = plt.subplots(4, 2, figsize=(3.2, 4.4) , constrained_layout=True) 
ax_40, t_40, y_abs_40 =acquisition_40.plot_waveform_8(ax=axs[0, 0], title="(4, 0)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0, norm=True)
ax_41, t_41, y_abs_41 =acquisition_41.plot_waveform_8(ax=axs[0, 1], title="(4, 1)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_42, t_42, y_abs_42 =acquisition_42.plot_waveform_8(ax=axs[1, 0], title="(4, 2)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_43, t_43, y_abs_43 =acquisition_43.plot_waveform_8(ax=axs[1, 1], title="(4, 3)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_44, t_44, y_abs_44 =acquisition_44.plot_waveform_8(ax=axs[2, 0], title="(4, 4)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_45, t_45, y_abs_45 =acquisition_45.plot_waveform_8(ax=axs[2, 1], title="(4, 5)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_46, t_46, y_abs_46 =acquisition_46.plot_waveform_8(ax=axs[3, 0], title="(4, 6)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_47, t_47, y_abs_47 =acquisition_47.plot_waveform_8(ax=axs[3, 1], title="(4, 7)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
fig.text(-0.02, 0.55, "Amplitude (arb. unit)", va="center", rotation="vertical")
for ax in axs[-1, :]:
    ax.set_xlabel("Time (ns)")
# plt.tight_layout()
plt.show()

# %%
acquisition_50 = SpatiotemporalAnalysis(ctrl_path, ph5_fo0, ctrl_path, result_dict_tx['data_ph5'], result_dict_rx['data_ph0'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_51 = SpatiotemporalAnalysis(ctrl_path, ph5_fo1, ctrl_path, result_dict_tx['data_ph5'], result_dict_rx['data_ph1'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_52 = SpatiotemporalAnalysis(ctrl_path, ph5_fo2, ctrl_path, result_dict_tx['data_ph5'], result_dict_rx['data_ph2'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_53 = SpatiotemporalAnalysis(ctrl_path, ph5_fo3, ctrl_path, result_dict_tx['data_ph5'], result_dict_rx['data_ph3'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_54 = SpatiotemporalAnalysis(ctrl_path, ph5_fo4, ctrl_path, result_dict_tx['data_ph5'], result_dict_rx['data_ph4'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_55 = SpatiotemporalAnalysis(ctrl_path, ph5_fo5, ctrl_path, result_dict_tx['data_ph5'], result_dict_rx['data_ph5'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_56 = SpatiotemporalAnalysis(ctrl_path, ph5_fo6, ctrl_path, result_dict_tx['data_ph5'], result_dict_rx['data_ph6'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_57 = SpatiotemporalAnalysis(ctrl_path, ph5_fo7, ctrl_path, result_dict_tx['data_ph5'], result_dict_rx['data_ph7'], num_of_ph_amp, num_of_fogi_timing, f_if)

fig, ax = plt.subplots()
acquisition_50.plot_results(ax, label="ph_5 & fogi_0", color="tab:blue", fitting=True)
acquisition_51.plot_results(ax, label="ph_5 & fogi_1", color="tab:orange", fitting=True)
acquisition_52.plot_results(ax, label="ph_5 & fogi_2", color="tab:green", fitting=True)
acquisition_53.plot_results(ax, label="ph_5 & fogi_3", color="tab:red", fitting=True)
acquisition_54.plot_results(ax, label="ph_5 & fogi_4", color="tab:purple", fitting=True)
acquisition_55.plot_results(ax, label="ph_5 & fogi_5", color="tab:brown", fitting=True)
acquisition_56.plot_results(ax, label="ph_5 & fogi_6", color="tab:pink", fitting=True)
acquisition_57.plot_results(ax, label="ph_5 & fogi_7", color="tab:gray", fitting=True)

ax.set_ylim(-0.10, 1)
ax.set_xlim(0, 40)
ax.vlines(18, -10, 100, color="r", linestyle="dashed")
custom_legend = [
    Line2D([0], [0], color="none", marker="o", linestyle="None", label="$R_{nm}$"),
    Line2D([0], [0], color="tab:blue", marker="o", linestyle="None",label="(5, 0)"),
    Line2D([0], [0], color="tab:orange", marker="o", linestyle="None",label="(5, 1)"),
    Line2D([0], [0], color="tab:green", marker="o", linestyle="None",label="(5, 2)"),
    Line2D([0], [0], color="tab:red", marker="o", linestyle="None",label="(5, 3)"),
    Line2D([0], [0], color="tab:purple", marker="o", linestyle="None",label="(5, 4)"),
    Line2D([0], [0], color="tab:brown", marker="o", linestyle="None",label="(5, 5)"),
    Line2D([0], [0], color="tab:pink", marker="o", linestyle="None",label="(5, 6)"),
    Line2D([0], [0], color="tab:gray", marker="o", linestyle="None",label="(5, 7)"),
    Line2D([0], [0], color="none", marker="", label=""),
    Line2D([0], [0], color="none", linestyle="-", label="$|I_{nm}|^2$"),
    Line2D([0], [0], color="tab:blue", linestyle="-", label="(5, 0)"),
    Line2D([0], [0], color="tab:orange", linestyle="-", label="(5, 1)"),
    Line2D([0], [0], color="tab:green", linestyle="-", label="(5, 2)"),
    Line2D([0], [0], color="tab:red", linestyle="-", label="(5, 3)"),
    Line2D([0], [0], color="tab:purple", linestyle="-", label="(5, 4)"),
    Line2D([0], [0], color="tab:brown", linestyle="-", label="(5, 5)"),
    Line2D([0], [0], color="tab:pink", linestyle="-", label="(5, 6)"),
    Line2D([0], [0], color="tab:gray", linestyle="-", label="(5, 7)"),
]
plt.legend(handles=custom_legend, loc="upper left", bbox_to_anchor=(1., 1),ncol=1,  fontsize="small", 
           handletextpad=0.5, borderpad=0.3 )
plt.hlines(0, 0, 40, "black")
plt.xlabel("f0g1 delay (ns)")
plt.ylabel("Absorption rate")
# plt.savefig('abs_timing.png', bbox_inches='tight')
plt.show()
# Out:
# delay -111.60000000000034
# delay -36.00000000000013
# delay -144.9000000000004
# delay -81.00000000000024
# delay -38.70000000000013
# delay 46.79999999999999
# delay -35.10000000000012
# delay -81.00000000000024

# %%
ph_amp = 0
fogi_freq = 0
fig, axs = plt.subplots(4, 2, figsize=(3.2, 4.4) , constrained_layout=True) 
ax_50, t_50, y_abs_50 =acquisition_50.plot_waveform_8(ax=axs[0, 0], title="(5, 0)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0, norm=True)
ax_51, t_51, y_abs_51 =acquisition_51.plot_waveform_8(ax=axs[0, 1], title="(5, 1)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_52, t_52, y_abs_52 =acquisition_52.plot_waveform_8(ax=axs[1, 0], title="(5, 2)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_53, t_53, y_abs_53 =acquisition_53.plot_waveform_8(ax=axs[1, 1], title="(5, 3)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_54, t_54, y_abs_54 =acquisition_54.plot_waveform_8(ax=axs[2, 0], title="(5, 4)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_55, t_55, y_abs_55 =acquisition_55.plot_waveform_8(ax=axs[2, 1], title="(5, 5)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_56, t_56, y_abs_56 =acquisition_56.plot_waveform_8(ax=axs[3, 0], title="(5, 6)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_57, t_57, y_abs_57 =acquisition_57.plot_waveform_8(ax=axs[3, 1], title="(5, 7)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
fig.text(-0.02, 0.55, "Amplitude (arb. unit)", va="center", rotation="vertical")
for ax in axs[-1, :]:
    ax.set_xlabel("Time (ns)")
# plt.tight_layout()
plt.show()

# %%
acquisition_60 = SpatiotemporalAnalysis(ctrl_path, ph6_fo0, ctrl_path, result_dict_tx['data_ph6'], result_dict_rx['data_ph0'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_61 = SpatiotemporalAnalysis(ctrl_path, ph6_fo1, ctrl_path, result_dict_tx['data_ph6'], result_dict_rx['data_ph1'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_62 = SpatiotemporalAnalysis(ctrl_path, ph6_fo2, ctrl_path, result_dict_tx['data_ph6'], result_dict_rx['data_ph2'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_63 = SpatiotemporalAnalysis(ctrl_path, ph6_fo3, ctrl_path, result_dict_tx['data_ph6'], result_dict_rx['data_ph3'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_64 = SpatiotemporalAnalysis(ctrl_path, ph6_fo4, ctrl_path, result_dict_tx['data_ph6'], result_dict_rx['data_ph4'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_65 = SpatiotemporalAnalysis(ctrl_path, ph6_fo5, ctrl_path, result_dict_tx['data_ph6'], result_dict_rx['data_ph5'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_66 = SpatiotemporalAnalysis(ctrl_path, ph6_fo6, ctrl_path, result_dict_tx['data_ph6'], result_dict_rx['data_ph6'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_67 = SpatiotemporalAnalysis(ctrl_path, ph6_fo7, ctrl_path, result_dict_tx['data_ph6'], result_dict_rx['data_ph7'], num_of_ph_amp, num_of_fogi_timing, f_if)

fig, ax = plt.subplots()
acquisition_60.plot_results(ax, label="ph_6 & fogi_0", color="tab:blue", fitting=True)
acquisition_61.plot_results(ax, label="ph_6 & fogi_1", color="tab:orange", fitting=True)
acquisition_62.plot_results(ax, label="ph_6 & fogi_2", color="tab:green", fitting=True)
acquisition_63.plot_results(ax, label="ph_6 & fogi_3", color="tab:red", fitting=True)
acquisition_64.plot_results(ax, label="ph_6 & fogi_4", color="tab:purple", fitting=True)
acquisition_65.plot_results(ax, label="ph_6 & fogi_5", color="tab:brown", fitting=True)
acquisition_66.plot_results(ax, label="ph_6 & fogi_6", color="tab:pink", fitting=True)
acquisition_67.plot_results(ax, label="ph_6 & fogi_7", color="tab:gray", fitting=True)

ax.set_ylim(-0.10, 1)
ax.set_xlim(0, 40)
ax.vlines(18, -10, 100, color="r", linestyle="dashed")
custom_legend = [
    Line2D([0], [0], color="none", marker="o", linestyle="None", label="$R_{nm}$"),
    Line2D([0], [0], color="tab:blue", marker="o", linestyle="None",label="(6, 0)"),
    Line2D([0], [0], color="tab:orange", marker="o", linestyle="None",label="(6, 1)"),
    Line2D([0], [0], color="tab:green", marker="o", linestyle="None",label="(6, 2)"),
    Line2D([0], [0], color="tab:red", marker="o", linestyle="None",label="(6, 3)"),
    Line2D([0], [0], color="tab:purple", marker="o", linestyle="None",label="(6, 4)"),
    Line2D([0], [0], color="tab:brown", marker="o", linestyle="None",label="(6, 5)"),
    Line2D([0], [0], color="tab:pink", marker="o", linestyle="None",label="(6, 6)"),
    Line2D([0], [0], color="tab:gray", marker="o", linestyle="None",label="(6, 7)"),
    Line2D([0], [0], color="none", marker="", label=""),
    Line2D([0], [0], color="none", linestyle="-", label="$|I_{nm}|^2$"),
    Line2D([0], [0], color="tab:blue", linestyle="-", label="(6, 0)"),
    Line2D([0], [0], color="tab:orange", linestyle="-", label="(6, 1)"),
    Line2D([0], [0], color="tab:green", linestyle="-", label="(6, 2)"),
    Line2D([0], [0], color="tab:red", linestyle="-", label="(6, 3)"),
    Line2D([0], [0], color="tab:purple", linestyle="-", label="(6, 4)"),
    Line2D([0], [0], color="tab:brown", linestyle="-", label="(6, 5)"),
    Line2D([0], [0], color="tab:pink", linestyle="-", label="(6, 6)"),
    Line2D([0], [0], color="tab:gray", linestyle="-", label="(6, 7)"),
]
plt.legend(handles=custom_legend, loc="upper left", bbox_to_anchor=(1., 1),ncol=1,  fontsize="small", 
           handletextpad=0.5, borderpad=0.3 )
plt.hlines(0, 0, 40, "black")
plt.xlabel("f0g1 delay (ns)")
plt.ylabel("Absorption rate")
# plt.savefig('abs_timing.png', bbox_inches='tight')
plt.show()
# Out:
# delay -28.80000000000011
# delay -100.8000000000003
# delay -38.70000000000013
# delay -143.1000000000004
# delay -83.70000000000024
# delay -30.600000000000115
# delay 46.79999999999999
# delay -30.600000000000115

# %%
ph_amp = 0
fogi_freq = 0
fig, axs = plt.subplots(4, 2, figsize=(3.2, 4.4) , constrained_layout=True) 
ax_60, t_60, y_abs_60 =acquisition_60.plot_waveform_8(ax=axs[0, 0], title="(6, 0)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0, norm=True)
ax_61, t_61, y_abs_61 =acquisition_61.plot_waveform_8(ax=axs[0, 1], title="(6, 1)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_62, t_62, y_abs_62 =acquisition_62.plot_waveform_8(ax=axs[1, 0], title="(6, 2)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_63, t_63, y_abs_63 =acquisition_63.plot_waveform_8(ax=axs[1, 1], title="(6, 3)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_64, t_64, y_abs_64 =acquisition_64.plot_waveform_8(ax=axs[2, 0], title="(6, 4)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_65, t_65, y_abs_65 =acquisition_65.plot_waveform_8(ax=axs[2, 1], title="(6, 5)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_66, t_66, y_abs_66 =acquisition_66.plot_waveform_8(ax=axs[3, 0], title="(6, 6)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_67, t_67, y_abs_67 =acquisition_67.plot_waveform_8(ax=axs[3, 1], title="(6, 7)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
fig.text(-0.02, 0.55, "Amplitude (arb. unit)", va="center", rotation="vertical")
for ax in axs[-1, :]:
    ax.set_xlabel("Time (ns)")
# plt.tight_layout()
plt.show()
# Out:
# c:\Users\qipe\Documents\K_Sunada\.venv\Lib\site-packages\matplotlib\cbook.py:1719: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# c:\Users\qipe\Documents\K_Sunada\.venv\Lib\site-packages\matplotlib\cbook.py:1355: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
acquisition_70 = SpatiotemporalAnalysis(ctrl_path, ph7_fo0, ctrl_path, result_dict_tx['data_ph7'], result_dict_rx['data_ph0'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_71 = SpatiotemporalAnalysis(ctrl_path, ph7_fo1, ctrl_path, result_dict_tx['data_ph7'], result_dict_rx['data_ph1'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_72 = SpatiotemporalAnalysis(ctrl_path, ph7_fo2, ctrl_path, result_dict_tx['data_ph7'], result_dict_rx['data_ph2'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_73 = SpatiotemporalAnalysis(ctrl_path, ph7_fo3, ctrl_path, result_dict_tx['data_ph7'], result_dict_rx['data_ph3'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_74 = SpatiotemporalAnalysis(ctrl_path, ph7_fo4, ctrl_path, result_dict_tx['data_ph7'], result_dict_rx['data_ph4'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_75 = SpatiotemporalAnalysis(ctrl_path, ph7_fo5, ctrl_path, result_dict_tx['data_ph7'], result_dict_rx['data_ph5'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_76 = SpatiotemporalAnalysis(ctrl_path, ph7_fo6, ctrl_path, result_dict_tx['data_ph7'], result_dict_rx['data_ph6'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_77 = SpatiotemporalAnalysis(ctrl_path, ph7_fo7, ctrl_path, result_dict_tx['data_ph7'], result_dict_rx['data_ph7'], num_of_ph_amp, num_of_fogi_timing, f_if)

fig, ax = plt.subplots()
acquisition_70.plot_results(ax, label="ph_7 & fogi_0", color="tab:blue", fitting=True)
acquisition_71.plot_results(ax, label="ph_7 & fogi_1", color="tab:orange", fitting=True)
acquisition_72.plot_results(ax, label="ph_7 & fogi_2", color="tab:green", fitting=True)
acquisition_73.plot_results(ax, label="ph_7 & fogi_3", color="tab:red", fitting=True)
acquisition_74.plot_results(ax, label="ph_7 & fogi_4", color="tab:purple", fitting=True)
acquisition_75.plot_results(ax, label="ph_7 & fogi_5", color="tab:brown", fitting=True)
acquisition_76.plot_results(ax, label="ph_7 & fogi_6", color="tab:pink", fitting=True)
acquisition_77.plot_results(ax, label="ph_7 & fogi_7", color="tab:gray", fitting=True)

ax.set_ylim(-0.10, 1)
ax.set_xlim(0, 40)
ax.vlines(18, -10, 100, color="r", linestyle="dashed")
custom_legend = [
    Line2D([0], [0], color="none", marker="o", linestyle="None", label="$R_{nm}$"),
    Line2D([0], [0], color="tab:blue", marker="o", linestyle="None",label="(7, 0)"),
    Line2D([0], [0], color="tab:orange", marker="o", linestyle="None",label="(7, 1)"),
    Line2D([0], [0], color="tab:green", marker="o", linestyle="None",label="(7, 2)"),
    Line2D([0], [0], color="tab:red", marker="o", linestyle="None",label="(7, 3)"),
    Line2D([0], [0], color="tab:purple", marker="o", linestyle="None",label="(7, 4)"),
    Line2D([0], [0], color="tab:brown", marker="o", linestyle="None",label="(7, 5)"),
    Line2D([0], [0], color="tab:pink", marker="o", linestyle="None",label="(7, 6)"),
    Line2D([0], [0], color="tab:gray", marker="o", linestyle="None",label="(7, 7)"),
    Line2D([0], [0], color="none", marker="", label=""),
    Line2D([0], [0], color="none", linestyle="-", label="$|I_{nm}|^2$"),
    Line2D([0], [0], color="tab:blue", linestyle="-", label="(7, 0)"),
    Line2D([0], [0], color="tab:orange", linestyle="-", label="(7, 1)"),
    Line2D([0], [0], color="tab:green", linestyle="-", label="(7, 2)"),
    Line2D([0], [0], color="tab:red", linestyle="-", label="(7, 3)"),
    Line2D([0], [0], color="tab:purple", linestyle="-", label="(7, 4)"),
    Line2D([0], [0], color="tab:brown", linestyle="-", label="(7, 5)"),
    Line2D([0], [0], color="tab:pink", linestyle="-", label="(7, 6)"),
    Line2D([0], [0], color="tab:gray", linestyle="-", label="(7, 7)"),
]
plt.legend(handles=custom_legend, loc="upper left", bbox_to_anchor=(1., 1),ncol=1,  fontsize="small", 
           handletextpad=0.5, borderpad=0.3 )
plt.hlines(0, 0, 40, "black")
plt.xlabel("f0g1 delay (ns)")
plt.ylabel("Absorption rate")
# plt.savefig('abs_timing.png', bbox_inches='tight')
plt.show()
# Out:
# delay 5.39999999999997
# delay 267.3
# delay 59.399999999999984
# delay -41.40000000000015
# delay 72.0
# delay -80.10000000000022
# delay -36.00000000000013
# delay 44.099999999999994

# %%
ph_amp = 0
fogi_freq = 0
fig, axs = plt.subplots(4, 2, figsize=(3.2, 4.4) , constrained_layout=True) 
ax_70, t_70, y_abs_70 =acquisition_70.plot_waveform_8(ax=axs[0, 0], title="(7, 0)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0, norm=True)
ax_71, t_71, y_abs_71 =acquisition_71.plot_waveform_8(ax=axs[0, 1], title="(7, 1)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_72, t_72, y_abs_72 =acquisition_72.plot_waveform_8(ax=axs[1, 0], title="(7, 2)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_73, t_73, y_abs_73 =acquisition_73.plot_waveform_8(ax=axs[1, 1], title="(7, 3)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_74, t_74, y_abs_74 =acquisition_74.plot_waveform_8(ax=axs[2, 0], title="(7, 4)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_75, t_75, y_abs_75 =acquisition_75.plot_waveform_8(ax=axs[2, 1], title="(7, 5)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_76, t_76, y_abs_76 =acquisition_76.plot_waveform_8(ax=axs[3, 0], title="(7, 6)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_77, t_77, y_abs_77 =acquisition_77.plot_waveform_8(ax=axs[3, 1], title="(7, 7)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
fig.text(-0.02, 0.55, "Amplitude (arb. unit)", va="center", rotation="vertical")
for ax in axs[-1, :]:
    ax.set_xlabel("Time (ns)")
# plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
i = 0
# data = np.array([[acquisition_30.get_rates()["rates"][i], acquisition_31.get_rates()["rates"][i], acquisition_32.get_rates()["rates"][i], acquisition_33.get_rates()["rates"][i]],
#                 [acquisition_20.get_rates()["rates"][i], acquisition_21.get_rates()["rates"][i], acquisition_22.get_rates()["rates"][i], acquisition_23.get_rates()["rates"][i]],
#                 [acquisition_10.get_rates()["rates"][i], acquisition_11.get_rates()["rates"][i], acquisition_12.get_rates()["rates"][i], acquisition_13.get_rates()["rates"][i]],
#                 [acquisition_00.get_rates()["rates"][i], acquisition_01.get_rates()["rates"][i], acquisition_02.get_rates()["rates"][i], acquisition_03.get_rates()["rates"][i]]])
data = np.array([
    [globals()[f"acquisition_{x}{y}"].get_rates()["rates"][i] for y in range(8)]
    for x in range(7, -1, -1) 
])

SpatiotemporalAnalysis.plot_absorption_rate_matrix(data, ax)

# plt.close()
# plt.imshow(plt.imread("abs_rate.png"))
ax.tick_params(axis="both", direction="in")
ax.tick_params(top=True, bottom=True, left=True, right=True)
plt.rcParams['xtick.major.width'] = 0.9#x軸主目盛り線の線幅
plt.rcParams['ytick.major.width'] = 0.9#y軸主目盛り線の線幅
plt.rcParams['font.size'] = 8 #フォントの大きさ
plt.rcParams['axes.linewidth'] = 0.9# 軸の線幅edge linewidth。囲みの太さ
plt.rcParams['xtick.top'] = True
plt.rcParams['xtick.bottom'] = True
plt.rcParams['ytick.left'] = True
plt.rcParams['ytick.right'] = True
plt.rcParams['lines.linewidth'] = 1
plt.rcParams['lines.markersize'] = 2.
# plt.savefig('Fig3_b1.pdf', bbox_inches='tight')
# plt.savefig('Fig3_b.png', bbox_inches='tight')
plt.show()
print(acquisition_00.get_rates()["rates"][i]+acquisition_11.get_rates()["rates"][i]
      +acquisition_22.get_rates()["rates"][i]+acquisition_33.get_rates()["rates"][i])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 12
#       3 # data = np.array([[acquisition_30.get_rates()["rates"][i], acquisition_31.get_rates()["rates"][i], acquisition_32.get_rates()["rates"][i], acquisition_33.get_rates()["rates"][i]],
#       4 #                 [acquisition_20.get_rates()["rates"][i], acquisition_21.get_rates()["rates"][i], acquisition_22.get_rates()["rates"][i], acquisition_23.get_rates()["rates"][i]],
#       5 #                 [acquisition_10.get_rates()["rates"][i], acquisition_11.get_rates()["rates"][i], acquisition_12.get_rates()["rates"][i], acquisition_13.get_rates()["rates"][i]],
#       6 #                 [acquisition_00.get_rates()["rates"][i], acquisition_01.get_rates()["rates"][i], acquisition_02.get_rates()["rates"][i], acquisition_03.get_rates()["rates"][i]]])
#       7 data = np.array([
# ...

# %%
from Analysis import overlap, separability
def plot_squaredI_matrix(signals, mode_num, value=True):
    expI_matrix = np.zeros((mode_num, mode_num))
    I_normalized = np.zeros((mode_num, mode_num))
    for m in range(mode_num):
        for m_prime in range(mode_num):
            wf_m = signals[m]
            wf_m_prime = signals[m_prime]
            expI_matrix[m, m_prime] = overlap(wf_m, wf_m_prime)
            norm_product = np.linalg.norm(wf_m) * np.linalg.norm(wf_m_prime)
            I_normalized[m, m_prime] = expI_matrix[m, m_prime] / norm_product
    
    squaredI_matrix = I_normalized**2
    plt.figure(figsize=(6, 4))
    plt.imshow(squaredI_matrix, cmap='viridis', origin='lower', vmin=0, vmax=1)
    for i in range(mode_num):
        for j in range(mode_num):
            if i != j and value:
                if squaredI_matrix[j, i]>0.5:
                    plt.text(i, j, f"{np.round(squaredI_matrix[j, i], decimals=2)}", ha='center', va='center', color="red")
                else:
                    plt.text(i, j, f"{np.round(squaredI_matrix[j, i], decimals=2)}", ha='center', va='center', color="white")

    plt.colorbar(label=r'Squared overlap $|I_{m, m^{\prime}}|^2$')
    plt.rcParams['xtick.major.width'] = 0.9#x軸主目盛り線の線幅
    plt.rcParams['ytick.major.width'] = 0.9#y軸主目盛り線の線幅
    plt.rcParams['font.size'] = 8 #フォントの大きさ
    plt.rcParams['axes.linewidth'] = 0.9# 軸の線幅edge linewidth。囲みの太さ
    plt.rcParams['xtick.top'] = True
    plt.rcParams['xtick.bottom'] = True
    plt.rcParams['ytick.left'] = True
    plt.rcParams['ytick.right'] = True
    plt.rcParams['lines.linewidth'] = 1
    plt.rcParams['lines.markersize'] = 2.
    plt.xlabel(r"Photon mode $m^{\prime}$")
    plt.ylabel(r"Photon mode $m$")
    plt.xticks(range(len(squaredI_matrix)))
    plt.yticks(range(len(squaredI_matrix)))
    plt.tight_layout()
    # plt.savefig('Fig2_c.pdf', bbox_inches='tight')
    # print("basis_fidelity:", basis_fidelity(expI_matrix))
    print("separability:", separability(expI_matrix))
    return separability(expI_matrix)[0]

## for tx

# %%
signals = [y_abs_00, y_abs_10, y_abs_20, y_abs_30, y_abs_40, y_abs_50, y_abs_60, y_abs_70]
plot_squaredI_matrix(signals, 8)

signals = [y_abs_01, y_abs_11, y_abs_21, y_abs_31, y_abs_41, y_abs_51, y_abs_61, y_abs_71]
plot_squaredI_matrix(signals, 8)

signals = [y_abs_02, y_abs_12, y_abs_22, y_abs_32, y_abs_42, y_abs_52, y_abs_62, y_abs_72]
plot_squaredI_matrix(signals, 8)

signals = [y_abs_03, y_abs_13, y_abs_23, y_abs_33, y_abs_43, y_abs_53, y_abs_63, y_abs_73]
plot_squaredI_matrix(signals, 8)

signals = [y_abs_04, y_abs_14, y_abs_24, y_abs_34, y_abs_44, y_abs_54, y_abs_64, y_abs_74]
plot_squaredI_matrix(signals, 8)

signals = [y_abs_05, y_abs_15, y_abs_25, y_abs_35, y_abs_45, y_abs_55, y_abs_65, y_abs_75]
plot_squaredI_matrix(signals, 8)

signals = [y_abs_06, y_abs_16, y_abs_26, y_abs_36, y_abs_46, y_abs_56, y_abs_66, y_abs_76]
plot_squaredI_matrix(signals, 8)

signals = [y_abs_07, y_abs_17, y_abs_27, y_abs_37, y_abs_47, y_abs_57, y_abs_67, y_abs_77]
plot_squaredI_matrix(signals, 8)
# Out:
# separability: (np.float64(0.7950170909558165), [np.float64(0.04097743811871103), np.float64(0.9447118871344259), np.float64(0.9516998029469805), np.float64(0.8923502231517264), np.float64(0.8442047031808468), np.float64(0.8581752829007143), np.float64(0.8882901303604874), np.float64(0.9397272598526403)])
# separability: (np.float64(0.8167029279813485), [np.float64(0.9396892316926758), np.float64(0.058017450441171695), np.float64(0.9155416245001704), np.float64(0.9066674324211995), np.float64(0.9216094869685231), np.float64(0.9268674673776005), np.float64(0.9271896056821193), np.float64(0.9380411247673279)])
# separability: (np.float64(0.8218928896769795), [np.float64(0.9695948605917933), np.float64(0.9372398098531581), np.float64(0.05490657634151039), np.float64(0.8749744760815571), np.float64(0.9122317888262796), np.float64(0.936149194531195), np.float64(0.937909920863382), np.float64(0.9521364903269605)])
# ...

# %% [markdown]
# 21 points

# %%
ph0_fo0 = "/2025-08-15/2025-08-15T002813_4a918e83-j1_JPA_comm_timing"
ph1_fo0 = "/2025-08-15/2025-08-15T005140_91403ccd-j1_JPA_comm_timing"
ph2_fo0 = "/2025-08-15/2025-08-15T011508_d8a82c38-j1_JPA_comm_timing"
ph3_fo0 = "/2025-08-15/2025-08-15T013836_1fea65e6-j1_JPA_comm_timing"
ph4_fo0 = "/2025-08-15/2025-08-15T020203_66c2fb8e-j1_JPA_comm_timing"
ph5_fo0 = "/2025-08-15/2025-08-15T022532_ae5a3a87-j1_JPA_comm_timing"
ph6_fo0 = "/2025-08-15/2025-08-15T024902_f6e8abb3-j1_JPA_comm_timing"
ph7_fo0 = "/2025-08-15/2025-08-15T031232_3f8077f2-j1_JPA_comm_timing"

ph0_fo7 = "/2025-08-15/2025-08-15T112238_b67b6f67-j1_JPA_comm_timing"
ph1_fo7 = "/2025-08-15/2025-08-15T115024_979fca71-j1_JPA_comm_timing"
ph2_fo7 = "/2025-08-15/2025-08-15T121350_ddb22950-j1_JPA_comm_timing"
ph3_fo7 = "/2025-08-15/2025-08-15T123723_27becba6-j1_JPA_comm_timing"
ph4_fo7 = "/2025-08-15/2025-08-15T130054_70c4d36b-j1_JPA_comm_timing"
ph5_fo7 = "/2025-08-15/2025-08-15T132434_bf1c8e6c-j1_JPA_comm_timing"
ph6_fo7 = "/2025-08-15/2025-08-15T134814_0d8e6d0a-j1_JPA_comm_timing"
ph7_fo7 = "/2025-08-15/2025-08-15T031232_3f8077f2-j1_JPA_comm_timing"

# ph1_fo1 = "/2025-08-15/2025-08-15T110133_c471ea95-j1_JPA_comm_timing"
ph1_fo1 = "/2025-08-15/2025-08-15T141314_8bdff297-j1_JPA_comm_timing"
ph2_fo2 = "/2025-08-15/2025-08-15T000242_ba5f7a1f-j1_JPA_comm_timing"
ph3_fo3 = "/2025-08-15/2025-08-15T082934_89307bd4-j1_JPA_comm_timing"
ph4_fo4 = "/2025-08-15/2025-08-15T085316_d8a568df-j1_JPA_comm_timing"
ph5_fo5 = "/2025-08-15/2025-08-15T091756_4b01c1ae-j1_JPA_comm_timing"
ph6_fo6 = "/2025-08-15/2025-08-15T094751_78c8133e-j1_JPA_comm_timing"
ph7_fo7 = "/2025-08-15/2025-08-15T101124_c3361d62-j1_JPA_comm_timing"

# %%
plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
plt.rcParams['xtick.major.width'] = 0.9#x軸主目盛り線の線幅
plt.rcParams['ytick.major.width'] = 0.9#y軸主目盛り線の線幅
plt.rcParams['font.size'] = 8 #フォントの大きさ
plt.rcParams['axes.linewidth'] = 0.9# 軸の線幅edge linewidth。囲みの太さ
plt.rcParams['xtick.top'] = True
plt.rcParams['xtick.bottom'] = True
plt.rcParams['ytick.left'] = True
plt.rcParams['ytick.right'] = True
plt.rcParams['lines.linewidth'] = 1
plt.rcParams['lines.markersize'] = 2.

# %%
num_of_ph_amp = 1
num_of_fogi_timing = 21
f_if = (9.5-9.38)*1e9

acquisition_00 = SpatiotemporalAnalysis(ctrl_path, ph0_fo0, ctrl_path, result_dict_tx['data_ph0'], result_dict_rx['data_ph0'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_10 = SpatiotemporalAnalysis(ctrl_path, ph1_fo0, ctrl_path, result_dict_tx['data_ph1'], result_dict_rx['data_ph0'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_20 = SpatiotemporalAnalysis(ctrl_path, ph2_fo0, ctrl_path, result_dict_tx['data_ph2'], result_dict_rx['data_ph0'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_30 = SpatiotemporalAnalysis(ctrl_path, ph3_fo0, ctrl_path, result_dict_tx['data_ph3'], result_dict_rx['data_ph0'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_40 = SpatiotemporalAnalysis(ctrl_path, ph4_fo0, ctrl_path, result_dict_tx['data_ph4'], result_dict_rx['data_ph0'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_50 = SpatiotemporalAnalysis(ctrl_path, ph5_fo0, ctrl_path, result_dict_tx['data_ph5'], result_dict_rx['data_ph0'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_60 = SpatiotemporalAnalysis(ctrl_path, ph6_fo0, ctrl_path, result_dict_tx['data_ph6'], result_dict_rx['data_ph0'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_70 = SpatiotemporalAnalysis(ctrl_path, ph7_fo0, ctrl_path, result_dict_tx['data_ph7'], result_dict_rx['data_ph0'], num_of_ph_amp, num_of_fogi_timing, f_if)

fig, ax = plt.subplots(1, 1, figsize=(3, 2.5))
acquisition_00.plot_results(ax, label="ph_0 & fogi_0", color="tab:blue", fitting=True, init_fit=True, eight=True)
acquisition_10.plot_results(ax, label="ph_1 & fogi_0", color="tab:orange", fitting=True, init_fit=True, eight=True)
acquisition_20.plot_results(ax, label="ph_2 & fogi_0", color="tab:green", fitting=True, init_fit=True, eight=True)
acquisition_30.plot_results(ax, label="ph_3 & fogi_0", color="tab:red", fitting=True, init_fit=True, eight=True)
acquisition_40.plot_results(ax, label="ph_4 & fogi_0", color="tab:purple", fitting=True, init_fit=True, eight=True)
acquisition_50.plot_results(ax, label="ph_5 & fogi_0", color="tab:brown", fitting=True, init_fit=True, eight=True)
acquisition_60.plot_results(ax, label="ph_6 & fogi_0", color="tab:pink", fitting=True, init_fit=True, eight=True)
acquisition_70.plot_results(ax, label="ph_7 & fogi_0", color="tab:gray", fitting=True, init_fit=True, eight=True)

ax.set_ylim(-0.10, 1)
ax.set_xlim(-42, 78)
ax.vlines(26, -10, 100, color="r", linestyle="dashed")
custom_legend = [
    Line2D([0], [0], color="none", marker="o", linestyle="None", label="$R_{nm}$"),
    Line2D([0], [0], color="tab:blue", marker="o", linestyle="None",label="(0, 0)"),
    Line2D([0], [0], color="tab:orange", marker="o", linestyle="None",label="(1, 0)"),
    Line2D([0], [0], color="tab:green", marker="o", linestyle="None",label="(2, 0)"),
    Line2D([0], [0], color="tab:red", marker="o", linestyle="None",label="(3, 0)"),
    Line2D([0], [0], color="tab:purple", marker="o", linestyle="None",label="(4, 0)"),
    Line2D([0], [0], color="tab:brown", marker="o", linestyle="None",label="(5, 0)"),
    Line2D([0], [0], color="tab:pink", marker="o", linestyle="None",label="(6, 0)"),
    Line2D([0], [0], color="tab:gray", marker="o", linestyle="None",label="(7, 0)"),
    # Line2D([0], [0], color="none", marker="", label=""),
    # Line2D([0], [0], color="none", linestyle="-", label="$|I_{nm}|^2$"),
    # Line2D([0], [0], color="tab:blue", linestyle="-", label="(0, 0)"),
    # Line2D([0], [0], color="tab:orange", linestyle="-", label="(1, 0)"),
    # Line2D([0], [0], color="tab:green", linestyle="-", label="(2, 0)"),
    # Line2D([0], [0], color="tab:red", linestyle="-", label="(3, 0)"),
    # Line2D([0], [0], color="tab:purple", linestyle="-", label="(4, 0)"),
    # Line2D([0], [0], color="tab:brown", linestyle="-", label="(5, 0)"),
    # Line2D([0], [0], color="tab:pink", linestyle="-", label="(6, 0)"),
    # Line2D([0], [0], color="tab:gray", linestyle="-", label="(7, 0)"),
]
plt.legend(handles=custom_legend, loc="upper left", bbox_to_anchor=(1., 1),ncol=1,  fontsize="small", 
           handletextpad=0.5, borderpad=0.3 )
plt.hlines(0, -42, 78, "black")
plt.xlabel("f0g1 delay (ns)")
plt.ylabel("Absorption rate")
# plt.savefig('abs_timing.png', bbox_inches='tight')
plt.show()
# Out:
# ideal efficiency 0.9493926343932371
# delay 28.800000000000004
# ideal efficiency 0.008114780078939662
# delay 83.69999999999999
# ideal efficiency 0.0004141584822710518
# delay -253.8000000000007
# ideal efficiency 0.0003661254450848247
# delay 41.4
# ideal efficiency 0.0012618518701975384
# delay -50.40000000000017
# ideal efficiency 0.004014647219138432
# delay -123.30000000000035
# ideal efficiency 0.0026931860485377357
# delay -10.800000000000068
# ideal efficiency 0.002583428481057999
# delay -266.4000000000007

# %%
num_of_ph_amp = 1
num_of_fogi_timing = 21
f_if = (9.5-9.38)*1e9

acquisition_07 = SpatiotemporalAnalysis(ctrl_path, ph0_fo7, ctrl_path, result_dict_tx['data_ph0'], result_dict_rx['data_ph7'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_17 = SpatiotemporalAnalysis(ctrl_path, ph1_fo7, ctrl_path, result_dict_tx['data_ph1'], result_dict_rx['data_ph7'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_27 = SpatiotemporalAnalysis(ctrl_path, ph2_fo7, ctrl_path, result_dict_tx['data_ph2'], result_dict_rx['data_ph7'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_37 = SpatiotemporalAnalysis(ctrl_path, ph3_fo7, ctrl_path, result_dict_tx['data_ph3'], result_dict_rx['data_ph7'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_47 = SpatiotemporalAnalysis(ctrl_path, ph4_fo7, ctrl_path, result_dict_tx['data_ph4'], result_dict_rx['data_ph7'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_57 = SpatiotemporalAnalysis(ctrl_path, ph5_fo7, ctrl_path, result_dict_tx['data_ph5'], result_dict_rx['data_ph7'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_67 = SpatiotemporalAnalysis(ctrl_path, ph6_fo7, ctrl_path, result_dict_tx['data_ph6'], result_dict_rx['data_ph7'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_77 = SpatiotemporalAnalysis(ctrl_path, ph7_fo7, ctrl_path, result_dict_tx['data_ph7'], result_dict_rx['data_ph7'], num_of_ph_amp, num_of_fogi_timing, f_if)


fig, ax = plt.subplots(1, 1, figsize=(3, 2.5))
acquisition_07.plot_results(ax, label="ph_0 & fogi_7", color="tab:blue", fitting=True, init_fit=True, eight=True)
acquisition_17.plot_results(ax, label="ph_1 & fogi_7", color="tab:orange", fitting=True, init_fit=True, eight=True)
acquisition_27.plot_results(ax, label="ph_2 & fogi_7", color="tab:green", fitting=True, init_fit=True, eight=True)
acquisition_37.plot_results(ax, label="ph_3 & fogi_7", color="tab:red", fitting=True, init_fit=True, eight=True)
acquisition_47.plot_results(ax, label="ph_4 & fogi_7", color="tab:purple", fitting=True, init_fit=True, eight=True)
acquisition_57.plot_results(ax, label="ph_5 & fogi_7", color="tab:brown", fitting=True, init_fit=True, eight=True)
acquisition_67.plot_results(ax, label="ph_6 & fogi_7", color="tab:pink", fitting=True, init_fit=True, eight=True)
acquisition_77.plot_results(ax, label="ph_7 & fogi_7", color="tab:gray", fitting=True, init_fit=True, eight=True)

ax.set_ylim(-0.10, 1)
ax.set_xlim(-42, 78)
ax.vlines(18, -10, 100, color="r", linestyle="dashed")
custom_legend = [
    Line2D([0], [0], color="none", marker="o", linestyle="None", label="$R_{nm}$"),
    Line2D([0], [0], color="tab:blue", marker="o", linestyle="None",label="(0, 7)"),
    Line2D([0], [0], color="tab:orange", marker="o", linestyle="None",label="(1, 7)"),
    Line2D([0], [0], color="tab:green", marker="o", linestyle="None",label="(2, 7)"),
    Line2D([0], [0], color="tab:red", marker="o", linestyle="None",label="(3, 7)"),
    Line2D([0], [0], color="tab:purple", marker="o", linestyle="None",label="(4, 7)"),
    Line2D([0], [0], color="tab:brown", marker="o", linestyle="None",label="(5, 7)"),
    Line2D([0], [0], color="tab:pink", marker="o", linestyle="None",label="(6, 7)"),
    Line2D([0], [0], color="tab:gray", marker="o", linestyle="None",label="(7, 7)"),
    # Line2D([0], [0], color="none", marker="", label=""),
    # Line2D([0], [0], color="none", linestyle="-", label="$|I_{nm}|^2$"),
    # Line2D([0], [0], color="tab:blue", linestyle="-", label="(0, 7)"),
    # Line2D([0], [0], color="tab:orange", linestyle="-", label="(1, 7)"),
    # Line2D([0], [0], color="tab:green", linestyle="-", label="(2, 7)"),
    # Line2D([0], [0], color="tab:red", linestyle="-", label="(3, 7)"),
    # Line2D([0], [0], color="tab:purple", linestyle="-", label="(4, 7)"),
    # Line2D([0], [0], color="tab:brown", linestyle="-", label="(5, 7)"),
    # Line2D([0], [0], color="tab:pink", linestyle="-", label="(6, 7)"),
    # Line2D([0], [0], color="tab:gray", linestyle="-", label="(7, 7)"),
]
plt.legend(handles=custom_legend, loc="upper left", bbox_to_anchor=(1., 1),ncol=1,  fontsize="small", 
           handletextpad=0.5, borderpad=0.3 )
plt.hlines(0, -42, 78, "black")
plt.xlabel("f0g1 delay (ns)")
plt.ylabel("Absorption rate")
# plt.savefig('abs_timing.png', bbox_inches='tight')
plt.show()
# Out:
# ideal efficiency 0.0005315988003759895
# delay 10.799999999999983
# ideal efficiency 0.00043987994847124556
# delay 33.3
# ideal efficiency 0.0004446643761832676
# delay 31.5
# ideal efficiency 0.004185637832182916
# delay 46.79999999999999
# ideal efficiency 0.0012375128381041317
# delay -4.263256414560601e-14
# ideal efficiency 0.0014771153136915519
# delay 65.69999999999997
# ideal efficiency 0.029020141540041122
# delay 117.89999999999998
# ideal efficiency 0.9070300477559355
# delay 46.79999999999999

# %%
num_of_ph_amp = 1
num_of_fogi_timing = 21
f_if = (9.5-9.38)*1e9

acquisition_00 = SpatiotemporalAnalysis(ctrl_path, ph0_fo0, ctrl_path, result_dict_tx['data_ph0'], result_dict_rx['data_ph0'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_11 = SpatiotemporalAnalysis(ctrl_path, ph1_fo1, ctrl_path, result_dict_tx['data_ph1'], result_dict_rx['data_ph1'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_22 = SpatiotemporalAnalysis(ctrl_path, ph2_fo2, ctrl_path, result_dict_tx['data_ph2'], result_dict_rx['data_ph2'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_33 = SpatiotemporalAnalysis(ctrl_path, ph3_fo3, ctrl_path, result_dict_tx['data_ph3'], result_dict_rx['data_ph3'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_44 = SpatiotemporalAnalysis(ctrl_path, ph4_fo4, ctrl_path, result_dict_tx['data_ph4'], result_dict_rx['data_ph4'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_55 = SpatiotemporalAnalysis(ctrl_path, ph5_fo5, ctrl_path, result_dict_tx['data_ph5'], result_dict_rx['data_ph5'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_66 = SpatiotemporalAnalysis(ctrl_path, ph6_fo6, ctrl_path, result_dict_tx['data_ph6'], result_dict_rx['data_ph6'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_77 = SpatiotemporalAnalysis(ctrl_path, ph7_fo7, ctrl_path, result_dict_tx['data_ph7'], result_dict_rx['data_ph7'], num_of_ph_amp, num_of_fogi_timing, f_if)


fig, ax = plt.subplots(figsize=(3., 2.5))
acquisition_00.plot_results(ax, label="ph_0 & fogi_0", color="tab:blue", fitting=True, init_fit=True, eight=True)
acquisition_11.plot_results(ax, label="ph_1 & fogi_1", color="tab:orange", fitting=True, init_fit=True, eight=True)
acquisition_22.plot_results(ax, label="ph_2 & fogi_2", color="tab:green", fitting=True, init_fit=True, eight=True)
acquisition_33.plot_results(ax, label="ph_3 & fogi_3", color="tab:red", fitting=True, init_fit=True, eight=True)
acquisition_44.plot_results(ax, label="ph_4 & fogi_4", color="tab:purple", fitting=True, init_fit=True, eight=True)
acquisition_55.plot_results(ax, label="ph_5 & fogi_5", color="tab:brown", fitting=True, init_fit=True, eight=True)
acquisition_66.plot_results(ax, label="ph_6 & fogi_6", color="tab:pink", fitting=True, init_fit=True, eight=True)
acquisition_77.plot_results(ax, label="ph_7 & fogi_7", color="tab:gray", fitting=True, init_fit=True, eight=True)

ax.set_ylim(-0.10, 1)
ax.set_xlim(-42, 78)
ax.vlines(18, -10, 100, color="r", linestyle="dashed")
custom_legend = [
    Line2D([0], [0], color="none", marker="o", linestyle="None", label="$R_{nm}$"),
    Line2D([0], [0], color="tab:blue", marker="o", linestyle="None",label="(0, 0)"),
    Line2D([0], [0], color="tab:orange", marker="o", linestyle="None",label="(1, 1)"),
    Line2D([0], [0], color="tab:green", marker="o", linestyle="None",label="(2, 2)"),
    Line2D([0], [0], color="tab:red", marker="o", linestyle="None",label="(3, 3)"),
    Line2D([0], [0], color="tab:purple", marker="o", linestyle="None",label="(4, 4)"),
    Line2D([0], [0], color="tab:brown", marker="o", linestyle="None",label="(5, 5)"),
    Line2D([0], [0], color="tab:pink", marker="o", linestyle="None",label="(6, 6)"),
    Line2D([0], [0], color="tab:gray", marker="o", linestyle="None",label="(7, 7)"),
    # Line2D([0], [0], color="none", marker="", label=""),
    # Line2D([0], [0], color="none", linestyle="-", label="$|I_{nm}|^2$"),
    # Line2D([0], [0], color="tab:blue", linestyle="-", label="(0, 0)"),
    # Line2D([0], [0], color="tab:orange", linestyle="-", label="(1, 1)"),
    # Line2D([0], [0], color="tab:green", linestyle="-", label="(2, 2)"),
    # Line2D([0], [0], color="tab:red", linestyle="-", label="(3, 3)"),
    # Line2D([0], [0], color="tab:purple", linestyle="-", label="(4, 4)"),
    # Line2D([0], [0], color="tab:brown", linestyle="-", label="(5, 5)"),
    # Line2D([0], [0], color="tab:pink", linestyle="-", label="(6, 6)"),
    # Line2D([0], [0], color="tab:gray", linestyle="-", label="(7, 7)"),
]
plt.legend(handles=custom_legend, loc="upper left", bbox_to_anchor=(1., 1),ncol=1,  fontsize="small", 
           handletextpad=0.5, borderpad=0.3 )
plt.hlines(0, -42, 78, "black")
plt.xlabel("f0g1 delay (ns)")
plt.ylabel("Absorption rate")
# plt.savefig('abs_timing.png', bbox_inches='tight')
plt.show()
# Out:
# ideal efficiency 0.9493926343932371
# delay 28.800000000000004
# ideal efficiency 0.9609798178355249
# delay 49.49999999999999
# ideal efficiency 0.9607959781863794
# delay 36.89999999999999
# ideal efficiency 0.9532647783267237
# delay 34.199999999999996
# ideal efficiency 0.9312046948955572
# delay 33.3
# ideal efficiency 0.9223839478049228
# delay 34.199999999999996
# ideal efficiency 0.9160521793024529
# delay -50.40000000000017
# ideal efficiency 0.9070300477559355
# delay 46.79999999999999

# %%
ph_amp = 0
fogi_freq = 17
fig, axs = plt.subplots(2, 2, figsize=(3.2, 2.2) , constrained_layout=True) 
ax_00, t_00, y_abs_00 =acquisition_00.plot_waveform_8(ax=axs[0, 0], title="(0, 0)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_01, t_01, y_abs_01 =acquisition_10.plot_waveform_8(ax=axs[0, 1], title="(1, 0)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_02, t_02, y_abs_02 =acquisition_20.plot_waveform_8(ax=axs[1, 0], title="(2, 0)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_03, t_03, y_abs_03 =acquisition_30.plot_waveform_8(ax=axs[1, 1], title="(3, 0)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
fig.text(-0.02, 0.55, "Amplitude (arb. unit)", va="center", rotation="vertical")
for ax in axs[-1, :]:
    ax.set_xlabel("Time (ns)")

# plt.tight_layout()
plt.show()

ph_amp = 0
fogi_freq = 17
fig, axs = plt.subplots(2, 2, figsize=(3.2, 2.2) , constrained_layout=True) 
ax_00, t_00, y_abs_00 =acquisition_40.plot_waveform_8(ax=axs[0, 0], title="(4, 0)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_01, t_01, y_abs_01 =acquisition_50.plot_waveform_8(ax=axs[0, 1], title="(5, 0)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_02, t_02, y_abs_02 =acquisition_60.plot_waveform_8(ax=axs[1, 0], title="(6, 0)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
ax_03, t_03, y_abs_03 =acquisition_70.plot_waveform_8(ax=axs[1, 1], title="(7, 0)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0)
fig.text(-0.02, 0.55, "Amplitude (arb. unit)", va="center", rotation="vertical")
for ax in axs[-1, :]:
    ax.set_xlabel("Time (ns)")

# plt.tight_layout()
plt.show()
# Out:
# c:\Users\qipe\Documents\K_Sunada\.venv\Lib\site-packages\matplotlib\cbook.py:1719: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# c:\Users\qipe\Documents\K_Sunada\.venv\Lib\site-packages\matplotlib\cbook.py:1355: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
ph_amp = 0
fogi_freq = 17
fig, axs = plt.subplots(2, 2, figsize=(3.2, 2.2) , constrained_layout=True) 
ax_00, t_00, y_abs_00 =acquisition_00.plot_waveform_8(ax=axs[0, 0], title="(0, 0)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0, color="tab:blue", norm=True)
ax_01, t_01, y_abs_01 =acquisition_11.plot_waveform_8(ax=axs[0, 1], title="(1, 1)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0, color="tab:orange")
ax_02, t_02, y_abs_02 =acquisition_22.plot_waveform_8(ax=axs[1, 0], title="(2, 2)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0, color="tab:green")
ax_03, t_03, y_abs_03 =acquisition_33.plot_waveform_8(ax=axs[1, 1], title="(3, 3)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0, color="tab:red")
fig.text(-0.02, 0.55, "Amplitude (arb. unit)", va="center", rotation="vertical")
for ax in axs[-1, :]:
    ax.set_xlabel("Time (ns)")

# plt.tight_layout()
plt.show()

ph_amp = 0
fogi_freq = 17
fig, axs = plt.subplots(2, 2, figsize=(3.2, 2.2) , constrained_layout=True) 
ax_00, t_00, y_abs_00 =acquisition_44.plot_waveform_8(ax=axs[0, 0], title="(4, 4)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0, color="tab:purple")
ax_01, t_01, y_abs_01 =acquisition_55.plot_waveform_8(ax=axs[0, 1], title="(5, 5)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0, color="tab:brown")
ax_02, t_02, y_abs_02 =acquisition_66.plot_waveform_8(ax=axs[1, 0], title="(6, 6)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0, color="tab:pink")
ax_03, t_03, y_abs_03 =acquisition_77.plot_waveform_8(ax=axs[1, 1], title="(7, 7)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq, show_title=True, mode=0, color="tab:gray")
fig.text(-0.02, 0.55, "Amplitude (arb. unit)", va="center", rotation="vertical")
for ax in axs[-1, :]:
    ax.set_xlabel("Time (ns)")

# plt.tight_layout()
plt.show()
# Out:
# c:\Users\qipe\Documents\K_Sunada\.venv\Lib\site-packages\matplotlib\cbook.py:1719: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# c:\Users\qipe\Documents\K_Sunada\.venv\Lib\site-packages\matplotlib\cbook.py:1355: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
fig, ax = plt.subplots(2, 2, figsize=(5, 5))

groups = [
    ([acquisition_00, acquisition_10, acquisition_20, acquisition_30], ax[0, 0]),
    ([acquisition_40, acquisition_50, acquisition_60, acquisition_70], ax[0, 1]),
    ([acquisition_00, acquisition_11, acquisition_22, acquisition_33], ax[1, 0]),
    ([acquisition_44, acquisition_55, acquisition_66, acquisition_77], ax[1, 1]),
]

colors = ["tab:blue", "tab:orange", "tab:green", "tab:red"]
colors = ["tab:purple", "tab:brown", "tab:pink", "tab:gray"]

for acquisitions, ax_target in groups:
    for i in range(4):
        acquisitions[i].plot_energy_imag(ax_target, color=colors[i])
    

# ax[0,0].set_title("E_imag (m=0)")
# ax[0,1].set_title("E_imaa (m=1)")
# ax[1,0].set_title("E_imag (m=2)")
# ax[1,1].set_title("E_imag (m=3)")
ax[0, 0].set_ylabel("Energy imag (V·ns)")
ax[1, 0].set_ylabel("Energy imag (V·ns)")
ax[0, 1].set_ylabel("Energy imag (V·ns)")
ax[1, 1].set_ylabel("Energy imag (V·ns)")

ax[0, 0].set_xlabel("Delay (ns)")
ax[0, 1].set_xlabel("Delay (ns)")
ax[1, 0].set_xlabel("Delay (ns)")
ax[1, 1].set_xlabel("Delay (ns)")
ax[0, 0].set_ylim(-0.1e-6, 8e-5)
ax[0, 1].set_ylim(-0.1e-6, 8e-5)
ax[1, 0].set_ylim(-0.1e-6, 8e-5)
ax[1, 1].set_ylim(-0.1e-6, 8e-5)
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(2, 2, figsize=(5, 5))

groups = [
    ([acquisition_00, acquisition_10, acquisition_20, acquisition_30], ax[0, 0]),
    ([acquisition_40, acquisition_50, acquisition_60, acquisition_70], ax[0, 1]),
    ([acquisition_00, acquisition_11, acquisition_22, acquisition_33], ax[1, 0]),
    ([acquisition_44, acquisition_55, acquisition_66, acquisition_77], ax[1, 1]),
]

colors = ["tab:blue", "tab:orange", "tab:green", "tab:red"]
colors = ["tab:purple", "tab:brown", "tab:pink", "tab:gray"]

for acquisitions, ax_target in groups:
    # ダミー axes（E_a 用）
    fig_dummy, ax_dummy = plt.subplots(1, 2)

    for acq, color in zip(acquisitions, colors):
        acq.plot_er_ea(
            [ax_target, ax_dummy[1]],
            color=color
        )

    plt.close(fig_dummy)

ax[0, 0].set_ylabel("Energy base (V·ns)")
ax[1, 0].set_ylabel("Energy base (V·ns)")
ax[0, 1].set_ylabel("Energy base (V·ns)")
ax[1, 1].set_ylabel("Energy base (V·ns)")

ax[0, 0].set_xlabel("Delay (ns)")
ax[0, 1].set_xlabel("Delay (ns)")
ax[1, 0].set_xlabel("Delay (ns)")
ax[1, 1].set_xlabel("Delay (ns)")
ax[0, 0].set_ylim(-0.1e-6, 8e-4)
ax[0, 1].set_ylim(-0.1e-6, 8e-4)
ax[1, 0].set_ylim(-0.1e-6, 8e-4)
ax[1, 1].set_ylim(-0.1e-6, 8e-4)
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(2.5, 2.5))
plt.rcParams["xtick.direction"] = 'in'
plt.rcParams["ytick.direction"] = 'in'
plt.rcParams['xtick.major.width'] = 0.9#x軸主目盛り線の線幅
plt.rcParams['ytick.major.width'] = 0.9#y軸主目盛り線の線幅
plt.rcParams['font.size'] = 8 #フォントの大きさ
plt.rcParams['axes.linewidth'] = 0.9# 軸の線幅edge linewidth。囲みの太さ
plt.rcParams['xtick.top'] = True
plt.rcParams['xtick.bottom'] = True
plt.rcParams['ytick.left'] = True
plt.rcParams['ytick.right'] = True
plt.rcParams['lines.linewidth'] = 1
plt.rcParams['lines.markersize'] = 2.
groups = [
    ([acquisition_00, acquisition_10, acquisition_20, acquisition_30, acquisition_40, acquisition_50, acquisition_60, acquisition_70], ax),
    # ([acquisition_07, acquisition_17, acquisition_27, acquisition_37, acquisition_47, acquisition_57, acquisition_67, acquisition_77], ax[1])
]

colors = ["tab:blue", "tab:orange", "tab:green", "tab:red", "tab:purple", "tab:brown", "tab:pink", "tab:gray"]

for acquisitions, ax_target in groups:
    fig_dummy, ax_dummy = plt.subplots(1, 2)

    for acq, color in zip(acquisitions, colors):
        acq.plot_er_ea(
            [ax_target, ax_dummy[1]],
            color=color
        )

    plt.close(fig_dummy)
ax.ticklabel_format(axis="y", style="sci", scilimits=(0, 0))
ax.set_title("E_base (n=0)")
# ax[1].set_title("E_base (n=7)")
ax.set_ylabel("Energy (V·ns)")

ax.set_xlabel("Delay (ns)")
# ax[1].set_xlabel("Delay (ns)")

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))
acquisition_00.plot_er_ea(ax, label="ph_0 & fogi_0", color="tab:blue")
acquisition_01.plot_er_ea(ax, label="ph_0 & fogi_1", color="tab:orange")
acquisition_02.plot_er_ea(ax, label="ph_0 & fogi_2", color="tab:green")
acquisition_03.plot_er_ea(ax, label="ph_0 & fogi_3", color="tab:red")

ax[0].set_title("E_r", fontsize="large")
ax[1].set_title("E_a", fontsize="large")
# Out:
# Text(0.5, 1.0, 'E_a')

# %%
ph_amp = 0
fogi_freq = 5
fig, axs = plt.subplots(4, 2, figsize=(6, 8) ) 
acquisition_00.plot_waveform(ax=axs[0, 0], title="(0, 0)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq)
acquisition_01.plot_waveform(ax=axs[0, 1], title="(0, 1)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq)
acquisition_02.plot_waveform(ax=axs[1, 0], title="(0, 2)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq)
acquisition_03.plot_waveform(ax=axs[1, 1], title="(0, 3)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq)
acquisition_04.plot_waveform(ax=axs[2, 0], title="(0, 4)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq)
acquisition_05.plot_waveform(ax=axs[2, 1], title="(0, 5)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq)
acquisition_06.plot_waveform(ax=axs[3, 0], title="(0, 6)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq)
acquisition_07.plot_waveform(ax=axs[3, 1], title="(0, 7)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq)

plt.tight_layout()
plt.show()

# %% [markdown]
# phototn 1

# %%
# header = "D:/K_sunada/result/CDY184/"
# ph1_fo0 = "/2025-08-14/2025-08-14T140310_f9643b52-j1_JPA_comm_timing"
# ph1_fo1 = "/2025-08-14/2025-08-14T141534_b4e30a86-j1_JPA_comm_timing"
# ph1_fo2 = "/2025-08-14/2025-08-14T142758_70852e4b-j1_JPA_comm_timing"
# ph1_fo3 = "/2025-08-14/2025-08-14T144024_2d036a0e-j1_JPA_comm_timing"
# ph1_fo4 = "/2025-08-14/2025-08-14T145249_e909aed9-j1_JPA_comm_timing"
# ph1_fo5 = "/2025-08-14/2025-08-14T150511_a311663f-j1_JPA_comm_timing"
# ph1_fo6 = "/2025-08-14/2025-08-14T151735_5e635c3f-j1_JPA_comm_timing"
# ph1_fo7 = "/2025-08-14/2025-08-14T152958_1965b433-j1_JPA_comm_timing"

num_of_ph_amp = 1
num_of_fogi_timing = 21
f_if = (9.5-9.38)*1e9

acquisition_10 = SpatiotemporalAnalysis(ctrl_path, ph1_fo0, ctrl_path, result_dict_tx['data_ph1'], result_dict_rx['data_ph0'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_11 = SpatiotemporalAnalysis(ctrl_path, ph1_fo1, ctrl_path, result_dict_tx['data_ph1'], result_dict_rx['data_ph1'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_12 = SpatiotemporalAnalysis(ctrl_path, ph1_fo2, ctrl_path, result_dict_tx['data_ph1'], result_dict_rx['data_ph2'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_13 = SpatiotemporalAnalysis(ctrl_path, ph1_fo3, ctrl_path, result_dict_tx['data_ph1'], result_dict_rx['data_ph3'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_14 = SpatiotemporalAnalysis(ctrl_path, ph1_fo4, ctrl_path, result_dict_tx['data_ph1'], result_dict_rx['data_ph4'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_15 = SpatiotemporalAnalysis(ctrl_path, ph1_fo5, ctrl_path, result_dict_tx['data_ph1'], result_dict_rx['data_ph5'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_16 = SpatiotemporalAnalysis(ctrl_path, ph1_fo6, ctrl_path, result_dict_tx['data_ph1'], result_dict_rx['data_ph6'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_17 = SpatiotemporalAnalysis(ctrl_path, ph1_fo7, ctrl_path, result_dict_tx['data_ph1'], result_dict_rx['data_ph7'], num_of_ph_amp, num_of_fogi_timing, f_if)


fig, ax = plt.subplots()
acquisition_10.plot_results(ax, label="ph_1 & fogi_0", color="tab:blue", fitting=True)
acquisition_11.plot_results(ax, label="ph_1 & fogi_1", color="tab:orange", fitting=True)
acquisition_12.plot_results(ax, label="ph_1 & fogi_2", color="tab:green", fitting=True)
acquisition_13.plot_results(ax, label="ph_1 & fogi_3", color="tab:red", fitting=True)
acquisition_14.plot_results(ax, label="ph_1 & fogi_4", color="tab:purple", fitting=True)
acquisition_15.plot_results(ax, label="ph_1 & fogi_5", color="tab:brown", fitting=True)
acquisition_16.plot_results(ax, label="ph_1 & fogi_6", color="tab:pink", fitting=True)
acquisition_17.plot_results(ax, label="ph_1 & fogi_7", color="tab:gray", fitting=True)

ax.set_ylim(-0.10, 1)
ax.set_xlim(0, 40)
ax.vlines(26, -10, 100, color="r", linestyle="dashed")
custom_legend = [
    Line2D([0], [0], color="none", marker="o", linestyle="None", label="$R_{nm}$"),
    Line2D([0], [0], color="tab:blue", marker="o", linestyle="None",label="(1, 0)"),
    Line2D([0], [0], color="tab:orange", marker="o", linestyle="None",label="(1, 1)"),
    Line2D([0], [0], color="tab:green", marker="o", linestyle="None",label="(1, 2)"),
    Line2D([0], [0], color="tab:red", marker="o", linestyle="None",label="(1, 3)"),
    Line2D([0], [0], color="tab:purple", marker="o", linestyle="None",label="(1, 4)"),
    Line2D([0], [0], color="tab:brown", marker="o", linestyle="None",label="(1, 5)"),
    Line2D([0], [0], color="tab:pink", marker="o", linestyle="None",label="(1, 6)"),
    Line2D([0], [0], color="tab:gray", marker="o", linestyle="None",label="(1, 7)"),
    Line2D([0], [0], color="none", marker="", label=""),
    Line2D([0], [0], color="none", linestyle="-", label="$|I_{nm}|^2$"),
    Line2D([0], [0], color="tab:blue", linestyle="-", label="(1, 0)"),
    Line2D([0], [0], color="tab:orange", linestyle="-", label="(1, 1)"),
    Line2D([0], [0], color="tab:green", linestyle="-", label="(1, 2)"),
    Line2D([0], [0], color="tab:red", linestyle="-", label="(1, 3)"),
    Line2D([0], [0], color="tab:purple", linestyle="-", label="(1, 4)"),
    Line2D([0], [0], color="tab:brown", linestyle="-", label="(1, 5)"),
    Line2D([0], [0], color="tab:pink", linestyle="-", label="(1, 6)"),
    Line2D([0], [0], color="tab:gray", linestyle="-", label="(1, 7)"),
]
plt.legend(handles=custom_legend, loc="upper left", bbox_to_anchor=(1., 1),ncol=1,  fontsize="small", 
           handletextpad=0.5, borderpad=0.3 )
plt.hlines(0, 0, 40, "black")
plt.xlabel("f0g1 delay (ns)")
plt.ylabel("Absorption rate")
# plt.savefig('abs_timing.png', bbox_inches='tight')
plt.show()
# Out:
# delay 21.533333333333335
# ...
# delay 28.33333333333334
# ...
# delay 20.4
# ...
# delay 9.066666666666652
# ...
# delay 43.066666666666706
# ...
# delay 21.533333333333335
# ...
# delay 78.2000000000001
# ...
# delay 4.533333333333314
# ...

# %%
ph_amp = 0
fogi_freq = 5
fig, axs = plt.subplots(4, 2, figsize=(6, 8) ) 
acquisition_10.plot_waveform(ax=axs[0, 0], title="(1, 0)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq)
acquisition_11.plot_waveform(ax=axs[0, 1], title="(1, 1)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq)
acquisition_12.plot_waveform(ax=axs[1, 0], title="(1, 2)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq)
acquisition_13.plot_waveform(ax=axs[1, 1], title="(1, 3)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq)
acquisition_14.plot_waveform(ax=axs[2, 0], title="(1, 4)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq)
acquisition_15.plot_waveform(ax=axs[2, 1], title="(1, 5)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq)
acquisition_16.plot_waveform(ax=axs[3, 0], title="(1, 6)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq)
acquisition_17.plot_waveform(ax=axs[3, 1], title="(1, 7)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq)

plt.tight_layout()
plt.show()

# %% [markdown]
# phototn 2

# %%
header = "D:/K_sunada/result/CDY184/"
ph2_fo0 = "/2025-08-14/2025-08-14T154225_d6fc24de-j1_JPA_comm_timing"
ph2_fo1 = "/2025-08-14/2025-08-14T155450_92df3514-j1_JPA_comm_timing"
ph2_fo2 = "/2025-08-14/2025-08-14T160714_4e882854-j1_JPA_comm_timing"
ph2_fo3 = "/2025-08-14/2025-08-14T161940_0af426c4-j1_JPA_comm_timing"
ph2_fo4 = "/2025-08-14/2025-08-14T163203_c618ab14-j1_JPA_comm_timing"
ph2_fo5 = "/2025-08-14/2025-08-14T164427_814743d1-j1_JPA_comm_timing"
ph2_fo6 = "/2025-08-14/2025-08-14T165651_3ce0e224-j1_JPA_comm_timing"
ph2_fo7 = "/2025-08-14/2025-08-14T170916_f8c127dd-j1_JPA_comm_timing"

num_of_ph_amp = 1
num_of_fogi_timing = 11
f_if = (9.5-9.38)*1e9

acquisition_20 = SpatiotemporalAnalysis(ctrl_path, ph2_fo0, ctrl_path, result_dict_tx['data_ph2'], result_dict_rx['data_ph0'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_21 = SpatiotemporalAnalysis(ctrl_path, ph2_fo1, ctrl_path, result_dict_tx['data_ph2'], result_dict_rx['data_ph1'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_22 = SpatiotemporalAnalysis(ctrl_path, ph2_fo2, ctrl_path, result_dict_tx['data_ph2'], result_dict_rx['data_ph2'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_23 = SpatiotemporalAnalysis(ctrl_path, ph2_fo3, ctrl_path, result_dict_tx['data_ph2'], result_dict_rx['data_ph3'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_24 = SpatiotemporalAnalysis(ctrl_path, ph2_fo4, ctrl_path, result_dict_tx['data_ph2'], result_dict_rx['data_ph4'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_25 = SpatiotemporalAnalysis(ctrl_path, ph2_fo5, ctrl_path, result_dict_tx['data_ph2'], result_dict_rx['data_ph5'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_26 = SpatiotemporalAnalysis(ctrl_path, ph2_fo6, ctrl_path, result_dict_tx['data_ph2'], result_dict_rx['data_ph6'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_27 = SpatiotemporalAnalysis(ctrl_path, ph2_fo7, ctrl_path, result_dict_tx['data_ph2'], result_dict_rx['data_ph7'], num_of_ph_amp, num_of_fogi_timing, f_if)


fig, ax = plt.subplots()
acquisition_20.plot_results(ax, label="ph_2 & fogi_0", color="tab:blue", fitting=True)
acquisition_21.plot_results(ax, label="ph_2 & fogi_1", color="tab:orange", fitting=True)
acquisition_22.plot_results(ax, label="ph_2 & fogi_2", color="tab:green", fitting=True)
acquisition_23.plot_results(ax, label="ph_2 & fogi_3", color="tab:red", fitting=True)
acquisition_24.plot_results(ax, label="ph_2 & fogi_4", color="tab:purple", fitting=True)
acquisition_25.plot_results(ax, label="ph_2 & fogi_5", color="tab:brown", fitting=True)
acquisition_26.plot_results(ax, label="ph_2 & fogi_6", color="tab:pink", fitting=True)
acquisition_27.plot_results(ax, label="ph_2 & fogi_7", color="tab:gray", fitting=True)

ax.set_ylim(-0.10, 1)
ax.set_xlim(0, 40)
ax.vlines(26, -10, 100, color="r", linestyle="dashed")
custom_legend = [
    Line2D([0], [0], color="none", marker="o", linestyle="None", label="$R_{nm}$"),
    Line2D([0], [0], color="tab:blue", marker="o", linestyle="None",label="(2, 0)"),
    Line2D([0], [0], color="tab:orange", marker="o", linestyle="None",label="(2, 1)"),
    Line2D([0], [0], color="tab:green", marker="o", linestyle="None",label="(2, 2)"),
    Line2D([0], [0], color="tab:red", marker="o", linestyle="None",label="(2, 3)"),
    Line2D([0], [0], color="tab:purple", marker="o", linestyle="None",label="(2, 4)"),
    Line2D([0], [0], color="tab:brown", marker="o", linestyle="None",label="(2, 5)"),
    Line2D([0], [0], color="tab:pink", marker="o", linestyle="None",label="(2, 6)"),
    Line2D([0], [0], color="tab:gray", marker="o", linestyle="None",label="(2, 7)"),
    Line2D([0], [0], color="none", marker="", label=""),
    Line2D([0], [0], color="none", linestyle="-", label="$|I_{nm}|^2$"),
    Line2D([0], [0], color="tab:blue", linestyle="-", label="(2, 0)"),
    Line2D([0], [0], color="tab:orange", linestyle="-", label="(2, 1)"),
    Line2D([0], [0], color="tab:green", linestyle="-", label="(2, 2)"),
    Line2D([0], [0], color="tab:red", linestyle="-", label="(2, 3)"),
    Line2D([0], [0], color="tab:purple", linestyle="-", label="(2, 4)"),
    Line2D([0], [0], color="tab:brown", linestyle="-", label="(2, 5)"),
    Line2D([0], [0], color="tab:pink", linestyle="-", label="(2, 6)"),
    Line2D([0], [0], color="tab:gray", linestyle="-", label="(2, 7)"),
]
plt.legend(handles=custom_legend, loc="upper left", bbox_to_anchor=(1., 1),ncol=1,  fontsize="small", 
           handletextpad=0.5, borderpad=0.3 )
plt.hlines(0, 0, 40, "black")
plt.xlabel("f0g1 delay (ns)")
plt.ylabel("Absorption rate")
# plt.savefig('abs_timing.png', bbox_inches='tight')
plt.show()
# Out:
# delay 88.96666666666678
# ...
# delay 30.033333333333346
# ...
# delay 28.33333333333334
# ...
# delay 44.200000000000045
# ...
# delay 22.666666666666668
# ...
# delay 37.9666666666667
# ...

# %%
ph_amp = 0
fogi_freq = 19
fig, axs = plt.subplots(2, 2, figsize=(6, 4) ) 
acquisition_20.plot_waveform(ax=axs[0, 0], title="(2, 0)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq)
acquisition_21.plot_waveform(ax=axs[0, 1], title="(2, 1)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq)
acquisition_22.plot_waveform(ax=axs[1, 0], title="(2, 2)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq)
acquisition_23.plot_waveform(ax=axs[1, 1], title="(2, 3)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq)

plt.tight_layout()
plt.show()

# %% [markdown]
# phototn 3

# %%
header = "D:/K_sunada/result/CDY184/"
ph3_fo0 = "/2025-08-14/2025-08-14T154225_d6fc24de-j1_JPA_comm_timing"
ph3_fo1 = "/2025-08-14/2025-08-14T155450_92df3514-j1_JPA_comm_timing"
ph3_fo2 = "/2025-08-14/2025-08-14T160714_4e882854-j1_JPA_comm_timing"
ph3_fo3 = "/2025-08-14/2025-08-14T161940_0af426c4-j1_JPA_comm_timing"
ph3_fo4 = "/2025-08-14/2025-08-14T163203_c618ab14-j1_JPA_comm_timing"
ph3_fo5 = "/2025-08-14/2025-08-14T164427_814743d1-j1_JPA_comm_timing"
ph3_fo6 = "/2025-08-14/2025-08-14T165651_3ce0e224-j1_JPA_comm_timing"
ph3_fo7 = "/2025-08-14/2025-08-14T170916_f8c127dd-j1_JPA_comm_timing"

num_of_ph_amp = 1
num_of_fogi_timing = 11
f_if = (9.5-9.38)*1e9

acquisition_30 = SpatiotemporalAnalysis(ctrl_path, ph3_fo0, ctrl_path, result_dict_tx['data_ph3'], result_dict_rx['data_ph0'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_31 = SpatiotemporalAnalysis(ctrl_path, ph3_fo1, ctrl_path, result_dict_tx['data_ph3'], result_dict_rx['data_ph1'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_32 = SpatiotemporalAnalysis(ctrl_path, ph3_fo2, ctrl_path, result_dict_tx['data_ph3'], result_dict_rx['data_ph3'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_33 = SpatiotemporalAnalysis(ctrl_path, ph3_fo3, ctrl_path, result_dict_tx['data_ph3'], result_dict_rx['data_ph3'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_34 = SpatiotemporalAnalysis(ctrl_path, ph3_fo4, ctrl_path, result_dict_tx['data_ph3'], result_dict_rx['data_ph4'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_35 = SpatiotemporalAnalysis(ctrl_path, ph3_fo5, ctrl_path, result_dict_tx['data_ph3'], result_dict_rx['data_ph5'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_36 = SpatiotemporalAnalysis(ctrl_path, ph3_fo6, ctrl_path, result_dict_tx['data_ph3'], result_dict_rx['data_ph6'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_37 = SpatiotemporalAnalysis(ctrl_path, ph3_fo7, ctrl_path, result_dict_tx['data_ph3'], result_dict_rx['data_ph7'], num_of_ph_amp, num_of_fogi_timing, f_if)


fig, ax = plt.subplots()
acquisition_30.plot_results(ax, label="ph_3 & fogi_0", color="tab:blue", fitting=True)
acquisition_31.plot_results(ax, label="ph_3 & fogi_1", color="tab:orange", fitting=True)
acquisition_32.plot_results(ax, label="ph_3 & fogi_2", color="tab:green", fitting=True)
acquisition_33.plot_results(ax, label="ph_3 & fogi_3", color="tab:red", fitting=True)
acquisition_34.plot_results(ax, label="ph_3 & fogi_4", color="tab:purple", fitting=True)
acquisition_35.plot_results(ax, label="ph_3 & fogi_5", color="tab:brown", fitting=True)
acquisition_36.plot_results(ax, label="ph_3 & fogi_6", color="tab:pink", fitting=True)
acquisition_37.plot_results(ax, label="ph_3 & fogi_7", color="tab:gray", fitting=True)

ax.set_ylim(-0.10, 1)
ax.set_xlim(0, 40)
ax.vlines(26, -10, 100, color="r", linestyle="dashed")
custom_legend = [
    Line2D([0], [0], color="none", marker="o", linestyle="None", label="$R_{nm}$"),
    Line2D([0], [0], color="tab:blue", marker="o", linestyle="None",label="(3, 0)"),
    Line2D([0], [0], color="tab:orange", marker="o", linestyle="None",label="(3, 1)"),
    Line2D([0], [0], color="tab:green", marker="o", linestyle="None",label="(3, 2)"),
    Line2D([0], [0], color="tab:red", marker="o", linestyle="None",label="(3, 3)"),
    Line2D([0], [0], color="tab:purple", marker="o", linestyle="None",label="(3, 4)"),
    Line2D([0], [0], color="tab:brown", marker="o", linestyle="None",label="(3, 5)"),
    Line2D([0], [0], color="tab:pink", marker="o", linestyle="None",label="(3, 6)"),
    Line2D([0], [0], color="tab:gray", marker="o", linestyle="None",label="(3, 7)"),
    Line2D([0], [0], color="none", marker="", label=""),
    Line2D([0], [0], color="none", linestyle="-", label="$|I_{nm}|^2$"),
    Line2D([0], [0], color="tab:blue", linestyle="-", label="(3, 0)"),
    Line2D([0], [0], color="tab:orange", linestyle="-", label="(3, 1)"),
    Line2D([0], [0], color="tab:green", linestyle="-", label="(3, 2)"),
    Line2D([0], [0], color="tab:red", linestyle="-", label="(3, 3)"),
    Line2D([0], [0], color="tab:purple", linestyle="-", label="(3, 4)"),
    Line2D([0], [0], color="tab:brown", linestyle="-", label="(3, 5)"),
    Line2D([0], [0], color="tab:pink", linestyle="-", label="(3, 6)"),
    Line2D([0], [0], color="tab:gray", linestyle="-", label="(3, 7)"),
]
plt.legend(handles=custom_legend, loc="upper left", bbox_to_anchor=(1., 1),ncol=1,  fontsize="small", 
           handletextpad=0.5, borderpad=0.3 )
plt.hlines(0, 0, 40, "black")
plt.xlabel("f0g1 delay (ns)")
plt.ylabel("Absorption rate")
# plt.savefig('abs_timing.png', bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 22
#      20 acquisition_35 = SpatiotemporalAnalysis(ctrl_path, ph3_fo5, ctrl_path, result_dict_tx['data_ph3'], result_dict_rx['data_ph5'], num_of_ph_amp, num_of_fogi_timing, f_if)
#      21 acquisition_36 = SpatiotemporalAnalysis(ctrl_path, ph3_fo6, ctrl_path, result_dict_tx['data_ph3'], result_dict_rx['data_ph6'], num_of_ph_amp, num_of_fogi_timing, f_if)
# ---> 22 acquisition_37 = SpatiotemporalAnalysis(ctrl_path, ph3_fo7, ctrl_path, result_dict_tx['data_ph3'], result_dict_rx['data_ph7'], num_of_ph_amp, num_of_fogi_timing, f_if)
#      25 fig, ax = plt.subplots()
#      26 acquisition_30.plot_results(ax, label="ph_3 & fogi_0", color="tab:blue", fitting=True)
#
# ...

# %%
ph_amp = 0
fogi_freq = 19
fig, axs = plt.subplots(2, 2, figsize=(6, 4) ) 
acquisition_30.plot_waveform(ax=axs[0, 0], title="(3, 0)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq)
acquisition_31.plot_waveform(ax=axs[0, 1], title="(3, 1)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq)
acquisition_32.plot_waveform(ax=axs[1, 0], title="(3, 2)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq)
acquisition_33.plot_waveform(ax=axs[1, 1], title="(3, 3)", ph_amp_idx=ph_amp, fogi_freq_idx=fogi_freq)

plt.tight_layout()
plt.show()

# %%
header = "D:/K_sunada/result/CDY184/"
ph4_fo0 = "/2025-08-14/2025-08-14T154225_d6fc24de-j1_JPA_comm_timing"
ph4_fo1 = "/2025-08-14/2025-08-14T155450_92df3514-j1_JPA_comm_timing"
ph4_fo2 = "/2025-08-14/2025-08-14T160714_4e882854-j1_JPA_comm_timing"
ph4_fo3 = "/2025-08-14/2025-08-14T161940_0af426c4-j1_JPA_comm_timing"
ph4_fo4 = "/2025-08-14/2025-08-14T163203_c618ab14-j1_JPA_comm_timing"
ph4_fo5 = "/2025-08-14/2025-08-14T164427_814743d1-j1_JPA_comm_timing"
ph4_fo6 = "/2025-08-14/2025-08-14T165651_3ce0e224-j1_JPA_comm_timing"
ph4_fo7 = "/2025-08-14/2025-08-14T152958_1965b433-j1_JPA_comm_timing"

num_of_ph_amp = 1
num_of_fogi_timing = 11
f_if = (9.5-9.38)*1e9

acquisition_40 = SpatiotemporalAnalysis(ctrl_path, ph4_fo0, ctrl_path, result_dict_tx['data_ph4'], result_dict_rx['data_ph0'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_41 = SpatiotemporalAnalysis(ctrl_path, ph4_fo1, ctrl_path, result_dict_tx['data_ph4'], result_dict_rx['data_ph1'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_42 = SpatiotemporalAnalysis(ctrl_path, ph4_fo2, ctrl_path, result_dict_tx['data_ph4'], result_dict_rx['data_ph4'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_43 = SpatiotemporalAnalysis(ctrl_path, ph4_fo3, ctrl_path, result_dict_tx['data_ph4'], result_dict_rx['data_ph4'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_44 = SpatiotemporalAnalysis(ctrl_path, ph4_fo4, ctrl_path, result_dict_tx['data_ph4'], result_dict_rx['data_ph4'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_45 = SpatiotemporalAnalysis(ctrl_path, ph4_fo5, ctrl_path, result_dict_tx['data_ph4'], result_dict_rx['data_ph5'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_46 = SpatiotemporalAnalysis(ctrl_path, ph4_fo6, ctrl_path, result_dict_tx['data_ph4'], result_dict_rx['data_ph6'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_47 = SpatiotemporalAnalysis(ctrl_path, ph4_fo7, ctrl_path, result_dict_tx['data_ph4'], result_dict_rx['data_ph7'], num_of_ph_amp, num_of_fogi_timing, f_if)


fig, ax = plt.subplots()
acquisition_40.plot_results(ax, label="ph_4 & fogi_0", color="tab:blue", fitting=True)
acquisition_41.plot_results(ax, label="ph_4 & fogi_1", color="tab:orange", fitting=True)
acquisition_42.plot_results(ax, label="ph_4 & fogi_2", color="tab:green", fitting=True)
acquisition_43.plot_results(ax, label="ph_4 & fogi_3", color="tab:red", fitting=True)
acquisition_44.plot_results(ax, label="ph_4 & fogi_4", color="tab:purple", fitting=True)
acquisition_45.plot_results(ax, label="ph_4 & fogi_5", color="tab:brown", fitting=True)
acquisition_46.plot_results(ax, label="ph_4 & fogi_6", color="tab:pink", fitting=True)
acquisition_47.plot_results(ax, label="ph_4 & fogi_7", color="tab:gray", fitting=True)

ax.set_ylim(-0.10, 1)
ax.set_xlim(0, 40)
ax.vlines(26, -10, 100, color="r", linestyle="dashed")
custom_legend = [
    Line2D([0], [0], color="none", marker="o", linestyle="None", label="$R_{nm}$"),
    Line2D([0], [0], color="tab:blue", marker="o", linestyle="None",label="(4, 0)"),
    Line2D([0], [0], color="tab:orange", marker="o", linestyle="None",label="(4, 1)"),
    Line2D([0], [0], color="tab:green", marker="o", linestyle="None",label="(4, 2)"),
    Line2D([0], [0], color="tab:red", marker="o", linestyle="None",label="(4, 3)"),
    Line2D([0], [0], color="tab:purple", marker="o", linestyle="None",label="(4, 4)"),
    Line2D([0], [0], color="tab:brown", marker="o", linestyle="None",label="(4, 5)"),
    Line2D([0], [0], color="tab:pink", marker="o", linestyle="None",label="(4, 6)"),
    Line2D([0], [0], color="tab:gray", marker="o", linestyle="None",label="(4, 7)"),
    Line2D([0], [0], color="none", marker="", label=""),
    Line2D([0], [0], color="none", linestyle="-", label="$|I_{nm}|^2$"),
    Line2D([0], [0], color="tab:blue", linestyle="-", label="(4, 0)"),
    Line2D([0], [0], color="tab:orange", linestyle="-", label="(4, 1)"),
    Line2D([0], [0], color="tab:green", linestyle="-", label="(4, 2)"),
    Line2D([0], [0], color="tab:red", linestyle="-", label="(4, 3)"),
    Line2D([0], [0], color="tab:purple", linestyle="-", label="(4, 4)"),
    Line2D([0], [0], color="tab:brown", linestyle="-", label="(4, 5)"),
    Line2D([0], [0], color="tab:pink", linestyle="-", label="(4, 6)"),
    Line2D([0], [0], color="tab:gray", linestyle="-", label="(4, 7)"),
]
plt.legend(handles=custom_legend, loc="upper left", bbox_to_anchor=(1., 1),ncol=1,  fontsize="small", 
           handletextpad=0.5, borderpad=0.3 )
plt.hlines(0, 0, 40, "black")
plt.xlabel("f0g1 delay (ns)")
plt.ylabel("Absorption rate")
# plt.savefig('abs_timing.png', bbox_inches='tight')
plt.show()

# %%
header = "D:/K_sunada/result/CDY184/"
ph5_fo0 = "/2025-08-14/2025-08-14T154225_d6fc24de-j1_JPA_comm_timing"
ph5_fo1 = "/2025-08-14/2025-08-14T155450_92df3514-j1_JPA_comm_timing"
ph5_fo2 = "/2025-08-14/2025-08-14T160714_4e882854-j1_JPA_comm_timing"
ph5_fo3 = "/2025-08-14/2025-08-14T161940_0af426c4-j1_JPA_comm_timing"
ph5_fo4 = "/2025-08-14/2025-08-14T163203_c618ab14-j1_JPA_comm_timing"
ph5_fo5 = "/2025-08-14/2025-08-14T164427_814743d1-j1_JPA_comm_timing"
ph5_fo6 = "/2025-08-14/2025-08-14T165651_3ce0e224-j1_JPA_comm_timing"
ph5_fo7 = "/2025-08-14/2025-08-14T152958_1965b433-j1_JPA_comm_timing"

num_of_ph_amp = 1
num_of_fogi_timing = 11
f_if = (9.5-9.38)*1e9

acquisition_50 = SpatiotemporalAnalysis(ctrl_path, ph5_fo0, ctrl_path, result_dict_tx['data_ph5'], result_dict_rx['data_ph0'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_51 = SpatiotemporalAnalysis(ctrl_path, ph5_fo1, ctrl_path, result_dict_tx['data_ph5'], result_dict_rx['data_ph1'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_52 = SpatiotemporalAnalysis(ctrl_path, ph5_fo2, ctrl_path, result_dict_tx['data_ph5'], result_dict_rx['data_ph5'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_53 = SpatiotemporalAnalysis(ctrl_path, ph5_fo3, ctrl_path, result_dict_tx['data_ph5'], result_dict_rx['data_ph5'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_54 = SpatiotemporalAnalysis(ctrl_path, ph5_fo4, ctrl_path, result_dict_tx['data_ph5'], result_dict_rx['data_ph4'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_55 = SpatiotemporalAnalysis(ctrl_path, ph5_fo5, ctrl_path, result_dict_tx['data_ph5'], result_dict_rx['data_ph5'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_56 = SpatiotemporalAnalysis(ctrl_path, ph5_fo6, ctrl_path, result_dict_tx['data_ph5'], result_dict_rx['data_ph6'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_57 = SpatiotemporalAnalysis(ctrl_path, ph5_fo7, ctrl_path, result_dict_tx['data_ph5'], result_dict_rx['data_ph7'], num_of_ph_amp, num_of_fogi_timing, f_if)


fig, ax = plt.subplots()
acquisition_50.plot_results(ax, label="ph_5 & fogi_0", color="tab:blue", fitting=True)
acquisition_51.plot_results(ax, label="ph_5 & fogi_1", color="tab:orange", fitting=True)
acquisition_52.plot_results(ax, label="ph_5 & fogi_2", color="tab:green", fitting=True)
acquisition_53.plot_results(ax, label="ph_5 & fogi_3", color="tab:red", fitting=True)
acquisition_54.plot_results(ax, label="ph_5 & fogi_4", color="tab:purple", fitting=True)
acquisition_55.plot_results(ax, label="ph_5 & fogi_5", color="tab:brown", fitting=True)
acquisition_56.plot_results(ax, label="ph_5 & fogi_6", color="tab:pink", fitting=True)
acquisition_57.plot_results(ax, label="ph_5 & fogi_7", color="tab:gray", fitting=True)

ax.set_ylim(-0.10, 1)
ax.set_xlim(0, 40)
ax.vlines(26, -10, 100, color="r", linestyle="dashed")
custom_legend = [
    Line2D([0], [0], color="none", marker="o", linestyle="None", label="$R_{nm}$"),
    Line2D([0], [0], color="tab:blue", marker="o", linestyle="None",label="(5, 0)"),
    Line2D([0], [0], color="tab:orange", marker="o", linestyle="None",label="(5, 1)"),
    Line2D([0], [0], color="tab:green", marker="o", linestyle="None",label="(5, 2)"),
    Line2D([0], [0], color="tab:red", marker="o", linestyle="None",label="(5, 3)"),
    Line2D([0], [0], color="tab:purple", marker="o", linestyle="None",label="(5, 4)"),
    Line2D([0], [0], color="tab:brown", marker="o", linestyle="None",label="(5, 5)"),
    Line2D([0], [0], color="tab:pink", marker="o", linestyle="None",label="(5, 6)"),
    Line2D([0], [0], color="tab:gray", marker="o", linestyle="None",label="(5, 7)"),
    Line2D([0], [0], color="none", marker="", label=""),
    Line2D([0], [0], color="none", linestyle="-", label="$|I_{nm}|^2$"),
    Line2D([0], [0], color="tab:blue", linestyle="-", label="(5, 0)"),
    Line2D([0], [0], color="tab:orange", linestyle="-", label="(5, 1)"),
    Line2D([0], [0], color="tab:green", linestyle="-", label="(5, 2)"),
    Line2D([0], [0], color="tab:red", linestyle="-", label="(5, 3)"),
    Line2D([0], [0], color="tab:purple", linestyle="-", label="(5, 4)"),
    Line2D([0], [0], color="tab:brown", linestyle="-", label="(5, 5)"),
    Line2D([0], [0], color="tab:pink", linestyle="-", label="(5, 6)"),
    Line2D([0], [0], color="tab:gray", linestyle="-", label="(5, 7)"),
]
plt.legend(handles=custom_legend, loc="upper left", bbox_to_anchor=(1., 1),ncol=1,  fontsize="small", 
           handletextpad=0.5, borderpad=0.3 )
plt.hlines(0, 0, 40, "black")
plt.xlabel("f0g1 delay (ns)")
plt.ylabel("Absorption rate")
# plt.savefig('abs_timing.png', bbox_inches='tight')
plt.show()

# %%
header = "D:/K_sunada/result/CDY184/"
ph6_fo0 = "/2025-08-14/2025-08-14T154225_d6fc24de-j1_JPA_comm_timing"
ph6_fo1 = "/2025-08-14/2025-08-14T155450_92df3514-j1_JPA_comm_timing"
ph6_fo2 = "/2025-08-14/2025-08-14T160714_4e882854-j1_JPA_comm_timing"
ph6_fo3 = "/2025-08-14/2025-08-14T161940_0af426c4-j1_JPA_comm_timing"
ph6_fo4 = "/2025-08-14/2025-08-14T163203_c618ab14-j1_JPA_comm_timing"
ph6_fo5 = "/2025-08-14/2025-08-14T164427_814743d1-j1_JPA_comm_timing"
ph6_fo6 = "/2025-08-14/2025-08-14T165651_3ce0e224-j1_JPA_comm_timing"
ph6_fo7 = "/2025-08-14/2025-08-14T152958_1965b433-j1_JPA_comm_timing"

num_of_ph_amp = 1
num_of_fogi_timing = 11
f_if = (9.5-9.38)*1e9

acquisition_60 = SpatiotemporalAnalysis(ctrl_path, ph6_fo0, ctrl_path, result_dict_tx['data_ph6'], result_dict_rx['data_ph0'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_61 = SpatiotemporalAnalysis(ctrl_path, ph6_fo1, ctrl_path, result_dict_tx['data_ph6'], result_dict_rx['data_ph1'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_62 = SpatiotemporalAnalysis(ctrl_path, ph6_fo2, ctrl_path, result_dict_tx['data_ph6'], result_dict_rx['data_ph6'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_63 = SpatiotemporalAnalysis(ctrl_path, ph6_fo3, ctrl_path, result_dict_tx['data_ph6'], result_dict_rx['data_ph6'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_64 = SpatiotemporalAnalysis(ctrl_path, ph6_fo4, ctrl_path, result_dict_tx['data_ph6'], result_dict_rx['data_ph4'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_65 = SpatiotemporalAnalysis(ctrl_path, ph6_fo5, ctrl_path, result_dict_tx['data_ph6'], result_dict_rx['data_ph5'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_66 = SpatiotemporalAnalysis(ctrl_path, ph6_fo6, ctrl_path, result_dict_tx['data_ph6'], result_dict_rx['data_ph6'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_67 = SpatiotemporalAnalysis(ctrl_path, ph6_fo7, ctrl_path, result_dict_tx['data_ph6'], result_dict_rx['data_ph7'], num_of_ph_amp, num_of_fogi_timing, f_if)


fig, ax = plt.subplots()
acquisition_60.plot_results(ax, label="ph_6 & fogi_0", color="tab:blue", fitting=True)
acquisition_61.plot_results(ax, label="ph_6 & fogi_1", color="tab:orange", fitting=True)
acquisition_62.plot_results(ax, label="ph_6 & fogi_2", color="tab:green", fitting=True)
acquisition_63.plot_results(ax, label="ph_6 & fogi_3", color="tab:red", fitting=True)
acquisition_64.plot_results(ax, label="ph_6 & fogi_4", color="tab:purple", fitting=True)
acquisition_65.plot_results(ax, label="ph_6 & fogi_5", color="tab:brown", fitting=True)
acquisition_66.plot_results(ax, label="ph_6 & fogi_6", color="tab:pink", fitting=True)
acquisition_67.plot_results(ax, label="ph_6 & fogi_7", color="tab:gray", fitting=True)

ax.set_ylim(-0.10, 1)
ax.set_xlim(0, 40)
ax.vlines(26, -10, 100, color="r", linestyle="dashed")
custom_legend = [
    Line2D([0], [0], color="none", marker="o", linestyle="None", label="$R_{nm}$"),
    Line2D([0], [0], color="tab:blue", marker="o", linestyle="None",label="(6, 0)"),
    Line2D([0], [0], color="tab:orange", marker="o", linestyle="None",label="(6, 1)"),
    Line2D([0], [0], color="tab:green", marker="o", linestyle="None",label="(6, 2)"),
    Line2D([0], [0], color="tab:red", marker="o", linestyle="None",label="(6, 3)"),
    Line2D([0], [0], color="tab:purple", marker="o", linestyle="None",label="(6, 4)"),
    Line2D([0], [0], color="tab:brown", marker="o", linestyle="None",label="(6, 5)"),
    Line2D([0], [0], color="tab:pink", marker="o", linestyle="None",label="(6, 6)"),
    Line2D([0], [0], color="tab:gray", marker="o", linestyle="None",label="(6, 7)"),
    Line2D([0], [0], color="none", marker="", label=""),
    Line2D([0], [0], color="none", linestyle="-", label="$|I_{nm}|^2$"),
    Line2D([0], [0], color="tab:blue", linestyle="-", label="(6, 0)"),
    Line2D([0], [0], color="tab:orange", linestyle="-", label="(6, 1)"),
    Line2D([0], [0], color="tab:green", linestyle="-", label="(6, 2)"),
    Line2D([0], [0], color="tab:red", linestyle="-", label="(6, 3)"),
    Line2D([0], [0], color="tab:purple", linestyle="-", label="(6, 4)"),
    Line2D([0], [0], color="tab:brown", linestyle="-", label="(6, 5)"),
    Line2D([0], [0], color="tab:pink", linestyle="-", label="(6, 6)"),
    Line2D([0], [0], color="tab:gray", linestyle="-", label="(6, 7)"),
]
plt.legend(handles=custom_legend, loc="upper left", bbox_to_anchor=(1., 1),ncol=1,  fontsize="small", 
           handletextpad=0.5, borderpad=0.3 )
plt.hlines(0, 0, 40, "black")
plt.xlabel("f0g1 delay (ns)")
plt.ylabel("Absorption rate")
# plt.savefig('abs_timing.png', bbox_inches='tight')
plt.show()

# %%
header = "D:/K_sunada/result/CDY184/"
ph7_fo0 = "/2025-08-14/2025-08-14T154225_d6fc24de-j1_JPA_comm_timing"
ph7_fo1 = "/2025-08-14/2025-08-14T155450_92df3514-j1_JPA_comm_timing"
ph7_fo2 = "/2025-08-14/2025-08-14T160714_4e882854-j1_JPA_comm_timing"
ph7_fo3 = "/2025-08-14/2025-08-14T161940_0af426c4-j1_JPA_comm_timing"
ph7_fo4 = "/2025-08-14/2025-08-14T163203_c618ab14-j1_JPA_comm_timing"
ph7_fo5 = "/2025-08-14/2025-08-14T164427_814743d1-j1_JPA_comm_timing"
ph7_fo6 = "/2025-08-14/2025-08-14T165651_3ce0e224-j1_JPA_comm_timing"
ph7_fo7 = "/2025-08-14/2025-08-14T152958_1965b433-j1_JPA_comm_timing"

num_of_ph_amp = 1
num_of_fogi_timing = 11
f_if = (9.5-9.38)*1e9

acquisition_70 = SpatiotemporalAnalysis(ctrl_path, ph7_fo0, ctrl_path, result_dict_tx['data_ph7'], result_dict_rx['data_ph0'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_71 = SpatiotemporalAnalysis(ctrl_path, ph7_fo1, ctrl_path, result_dict_tx['data_ph7'], result_dict_rx['data_ph1'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_72 = SpatiotemporalAnalysis(ctrl_path, ph7_fo2, ctrl_path, result_dict_tx['data_ph7'], result_dict_rx['data_ph7'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_73 = SpatiotemporalAnalysis(ctrl_path, ph7_fo3, ctrl_path, result_dict_tx['data_ph7'], result_dict_rx['data_ph7'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_74 = SpatiotemporalAnalysis(ctrl_path, ph7_fo4, ctrl_path, result_dict_tx['data_ph7'], result_dict_rx['data_ph4'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_75 = SpatiotemporalAnalysis(ctrl_path, ph7_fo5, ctrl_path, result_dict_tx['data_ph7'], result_dict_rx['data_ph5'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_76 = SpatiotemporalAnalysis(ctrl_path, ph7_fo6, ctrl_path, result_dict_tx['data_ph7'], result_dict_rx['data_ph6'], num_of_ph_amp, num_of_fogi_timing, f_if)
acquisition_77 = SpatiotemporalAnalysis(ctrl_path, ph7_fo7, ctrl_path, result_dict_tx['data_ph7'], result_dict_rx['data_ph7'], num_of_ph_amp, num_of_fogi_timing, f_if)


fig, ax = plt.subplots()
acquisition_70.plot_results(ax, label="ph_7 & fogi_0", color="tab:blue", fitting=True)
acquisition_71.plot_results(ax, label="ph_7 & fogi_1", color="tab:orange", fitting=True)
acquisition_72.plot_results(ax, label="ph_7 & fogi_2", color="tab:green", fitting=True)
acquisition_73.plot_results(ax, label="ph_7 & fogi_3", color="tab:red", fitting=True)
acquisition_74.plot_results(ax, label="ph_7 & fogi_4", color="tab:purple", fitting=True)
acquisition_75.plot_results(ax, label="ph_7 & fogi_5", color="tab:brown", fitting=True)
acquisition_76.plot_results(ax, label="ph_7 & fogi_6", color="tab:pink", fitting=True)
acquisition_77.plot_results(ax, label="ph_7 & fogi_7", color="tab:gray", fitting=True)

ax.set_ylim(-0.10, 1)
ax.set_xlim(0, 40)
ax.vlines(26, -10, 100, color="r", linestyle="dashed")
custom_legend = [
    Line2D([0], [0], color="none", marker="o", linestyle="None", label="$R_{nm}$"),
    Line2D([0], [0], color="tab:blue", marker="o", linestyle="None",label="(7, 0)"),
    Line2D([0], [0], color="tab:orange", marker="o", linestyle="None",label="(7, 1)"),
    Line2D([0], [0], color="tab:green", marker="o", linestyle="None",label="(7, 2)"),
    Line2D([0], [0], color="tab:red", marker="o", linestyle="None",label="(7, 3)"),
    Line2D([0], [0], color="tab:purple", marker="o", linestyle="None",label="(7, 4)"),
    Line2D([0], [0], color="tab:brown", marker="o", linestyle="None",label="(7, 5)"),
    Line2D([0], [0], color="tab:pink", marker="o", linestyle="None",label="(7, 6)"),
    Line2D([0], [0], color="tab:gray", marker="o", linestyle="None",label="(7, 7)"),
    Line2D([0], [0], color="none", marker="", label=""),
    Line2D([0], [0], color="none", linestyle="-", label="$|I_{nm}|^2$"),
    Line2D([0], [0], color="tab:blue", linestyle="-", label="(7, 0)"),
    Line2D([0], [0], color="tab:orange", linestyle="-", label="(7, 1)"),
    Line2D([0], [0], color="tab:green", linestyle="-", label="(7, 2)"),
    Line2D([0], [0], color="tab:red", linestyle="-", label="(7, 3)"),
    Line2D([0], [0], color="tab:purple", linestyle="-", label="(7, 4)"),
    Line2D([0], [0], color="tab:brown", linestyle="-", label="(7, 5)"),
    Line2D([0], [0], color="tab:pink", linestyle="-", label="(7, 6)"),
    Line2D([0], [0], color="tab:gray", linestyle="-", label="(7, 7)"),
]
plt.legend(handles=custom_legend, loc="upper left", bbox_to_anchor=(1., 1),ncol=1,  fontsize="small", 
           handletextpad=0.5, borderpad=0.3 )
plt.hlines(0, 0, 40, "black")
plt.xlabel("f0g1 delay (ns)")
plt.ylabel("Absorption rate")
# plt.savefig('abs_timing.png', bbox_inches='tight')
plt.show()

# %%
num_of_ph_amp = 1
num_of_fogi_timing = 51
f_if = (9.5-9.38)*1e9

fig, ax = plt.subplots(1, 2, figsize=(3.6, 2.2))
acquisition_00.plot_results(ax[0], label="ph_0 & fogi_0", color="tab:blue", fitting=True, init_fit=False)
acquisition_11.plot_results(ax[0], label="ph_1 & fogi_1", color="tab:orange", fitting=True, init_fit=False)
acquisition_22.plot_results(ax[0], label="ph_2 & fogi_2", color="green", fitting=True, init_fit=False)
acquisition_33.plot_results(ax[0], label="ph_3 & fogi_3", color="tab:red", fitting=True, init_fit=False)

acquisition_00.plot_results(ax[1], label="ph_0 & fogi_0", color="tab:blue", fitting=True, init_fit=False)
acquisition_10.plot_results(ax[1], label="ph_1 & fogi_0", color="tab:orange", fitting=True, init_fit=False)
acquisition_20.plot_results(ax[1], label="ph_2 & fogi_0", color="green", fitting=True, init_fit=False)
acquisition_30.plot_results(ax[1], label="ph_3 & fogi_0", color="tab:red", fitting=True, init_fit=False)

custom_legend0 = [
    # Line2D([0], [0], color="none", marker="o", linestyle="None", label="$(m, n)$"),
    Line2D([0], [0], color="tab:blue", marker="o", linestyle="None",label="(0, 0)"),
    Line2D([0], [0], color="tab:orange", marker="o", linestyle="None",label="(1, 1)"),
    Line2D([0], [0], color="green", marker="o", linestyle="None",label="(2, 2)"),
    Line2D([0], [0], color="tab:red", marker="o", linestyle="None",label="(3, 3)"),
]
ax[0].legend(handles=custom_legend0, title=r"$(m, n)$", loc="lower center", bbox_to_anchor=(0.5, 1),ncol=2,  fontsize="small", 
           handletextpad=0.5, borderpad=0.3 )

custom_legend1 = [
    # Line2D([0], [0], color="none", marker="o", linestyle="None", label="$(m, n)$"),
    Line2D([0], [0], color="tab:blue", marker="o", linestyle="None",label="(0, 0)"),
    Line2D([0], [0], color="tab:orange", marker="o", linestyle="None",label="(1, 0)"),
    Line2D([0], [0], color="green", marker="o", linestyle="None",label="(2, 0)"),
    Line2D([0], [0], color="tab:red", marker="o", linestyle="None",label="(3, 0)"),
]
ax[1].legend(handles=custom_legend1, title=r"$(m, n)$", loc="lower center", bbox_to_anchor=(0.5, 1),ncol=2,  fontsize="small", 
           handletextpad=0.5, borderpad=0.3 )

ax[0].set_ylim(-0.1, 1)
ax[0].set_xlim(-50, 110)
ax[0].set_xlabel(r"Delay $\Delta t$ (ns)")
ax[1].set_ylim(-0.1, 1)
ax[1].set_xlim(-50, 110)
ax[1].set_xlabel(r"Delay $\Delta t$ (ns)")

fig.text(0.02, 0.55, r"Absorption efficiency $R_{mn}$", va='center', rotation='vertical')
for a in ax:
    a.tick_params(axis="both", direction="in")
    a.axhline(0, color='black', linewidth=0.8, alpha=0.5, linestyle='-')
    a.axvline(26, color='red', linewidth=0.8, linestyle="dashed") 
ax[1].tick_params(labelleft=False) 
plt.rcParams['xtick.major.width'] = 0.9#x軸主目盛り線の線幅
plt.rcParams['ytick.major.width'] = 0.9#y軸主目盛り線の線幅
plt.rcParams['font.size'] = 8 #フォントの大きさ
plt.rcParams['axes.linewidth'] = 0.9# 軸の線幅edge linewidth。囲みの太さ
plt.rcParams['xtick.top'] = True
plt.rcParams['xtick.bottom'] = True
plt.rcParams['ytick.left'] = True
plt.rcParams['ytick.right'] = True
plt.rcParams['lines.linewidth'] = 1
plt.rcParams['lines.markersize'] = 2.
plt.subplots_adjust(left=0.12, right=0.97, top=0.93, bottom=0.2, wspace=0.2)
# plt.savefig('Fig3_a1.pdf', bbox_inches='tight')
plt.show()
# Out:
# delay 20.4
# ...
# delay 15.86666666666666
# ...
# delay 18.13333333333333
# ...
# delay 20.966666666666665
# ...
# delay 20.4
# ...
# delay 29.466666666666672
# ...
# delay 91.80000000000013
# ...
# delay -71.4000000000001
# ...

# %% [markdown]
# ## analysis

# %%
rates_00 = acquisition_00.get_rates()["rates"]
rates_11 = acquisition_11.get_rates()["rates"]
rates_22 = acquisition_22.get_rates()["rates"]
rates_33 = acquisition_33.get_rates()["rates"]
rates_44 = acquisition_33.get_rates()["rates"]
rates_55 = acquisition_33.get_rates()["rates"]
rates_66 = acquisition_33.get_rates()["rates"]
rates_77 = acquisition_33.get_rates()["rates"]


length = len(rates_00)

total_rates = [
    rates_00[i] + rates_11[i] + rates_22[i] + rates_33[i]+rates_44[i] + rates_55[i] + rates_66[i] + rates_77[i]
    for i in range(length)
]

max_i = max(range(length), key=lambda i: total_rates[i])
max_value = total_rates[max_i]

print(f"i: {max_i}")
print(f"sum: {max_value}")
# Out:
# i: 9
# sum: 753.2534368732464

# %%
fig, ax = plt.subplots(figsize=(4, 2))
i = 19
data = np.array([[acquisition_30.get_rates()["rates"][i], acquisition_31.get_rates()["rates"][i], acquisition_32.get_rates()["rates"][i], acquisition_33.get_rates()["rates"][i]],
                [acquisition_20.get_rates()["rates"][i], acquisition_21.get_rates()["rates"][i], acquisition_22.get_rates()["rates"][i], acquisition_23.get_rates()["rates"][i]],
                [acquisition_10.get_rates()["rates"][i], acquisition_11.get_rates()["rates"][i], acquisition_12.get_rates()["rates"][i], acquisition_13.get_rates()["rates"][i]],
                [acquisition_00.get_rates()["rates"][i], acquisition_01.get_rates()["rates"][i], acquisition_02.get_rates()["rates"][i], acquisition_03.get_rates()["rates"][i]]])
SpatiotemporalAnalysis.plot_absorption_rate_matrix(data, ax)

# plt.close()
# plt.imshow(plt.imread("abs_rate.png"))
ax.tick_params(axis="both", direction="in")
ax.tick_params(top=True, bottom=True, left=True, right=True)
plt.rcParams['xtick.major.width'] = 0.9#x軸主目盛り線の線幅
plt.rcParams['ytick.major.width'] = 0.9#y軸主目盛り線の線幅
plt.rcParams['font.size'] = 8 #フォントの大きさ
plt.rcParams['axes.linewidth'] = 0.9# 軸の線幅edge linewidth。囲みの太さ
plt.rcParams['xtick.top'] = True
plt.rcParams['xtick.bottom'] = True
plt.rcParams['ytick.left'] = True
plt.rcParams['ytick.right'] = True
plt.rcParams['lines.linewidth'] = 1
plt.rcParams['lines.markersize'] = 2.
# plt.savefig('Fig3_b1.pdf', bbox_inches='tight')
# plt.savefig('Fig3_b.png', bbox_inches='tight')
plt.show()
print(acquisition_00.get_rates()["rates"][i]+acquisition_11.get_rates()["rates"][i]
      +acquisition_22.get_rates()["rates"][i]+acquisition_33.get_rates()["rates"][i])
# Out:
# 379.40352286516895

# %%
M = 4  
acquisitions = [[acquisition_00, acquisition_01, acquisition_02, acquisition_03],
                [acquisition_10, acquisition_11, acquisition_12, acquisition_13],
                [acquisition_20, acquisition_21, acquisition_22, acquisition_23],
                [acquisition_30, acquisition_31, acquisition_32, acquisition_33]]

R = np.zeros((M, M))
index = 19

for m in range(M):
    for n in range(M):
        R[m, n] = acquisitions[m][n].get_rates()["rates"][index]*0.01

separability = 0.98
selectivities = []
for m in range(M):
    S_m = separability * R[m, m]
    selectivities.append(S_m)

S_total = np.mean(selectivities)

print("Mode-wise selectivity:", selectivities)
print("Total selectivity:", S_total)
# Out:
# Mode-wise selectivity: [0.9625714119132827, 0.9057868583206604, 0.9503640018028653, 0.8994322520418467]
# Total selectivity: 0.9295386310196638

# %% [markdown]
# orthogonality

# %%
def overlap(func1, func2):
    i = 0
    for t in range(len(func1)):
        i += func1[t] * np.conjugate(func2[t])
    return np.abs(i)

# %%
def waveform_complex(data):
    time = data.get_results()["time"][ph_amp][fogi_freq]
    waveform = data.get_results()["waveform"][ph_amp][fogi_freq]
    phase = np.angle(demodulate(time, waveform, f_if*1e-9))
    waveform_complex = waveform * np.exp(-1j*phase)
    
    waveform_wo_fogi = data.get_results()["waveform_zero_fogi"][ph_amp][fogi_freq]
    phase_wo_fogi = np.angle(demodulate(time, waveform_wo_fogi, f_if*1e-9))
    waveform_complex_wo_fogi = waveform_wo_fogi * np.exp(-1j*phase_wo_fogi)
    
    return time, waveform_complex, waveform_complex_wo_fogi

# %%
from scipy import signal
def LPF(x, samplerate, fp, fs, gpass, gstop):
    fn = samplerate/2
    wp = fp/fn
    ws = fs/fn
    N, Wn = signal.buttord(wp, ws, gpass, gstop)
    b, a = signal.butter(N, Wn, "low")
    y = signal.filtfilt(b, a, x)
    return y

# %%
def waveform_envelope(data):
    time = data.get_results()["time"][ph_amp][fogi_freq]

    env =  data.get_results()["y_absorbed_envs"][ph_amp][fogi_freq]
    env_wo_fogi = data.get_results()["y_base_envs"][ph_amp][fogi_freq]
    return time, env, env_wo_fogi

# %%
plt.plot(waveform_complex(acquisition_00)[0], waveform_complex(acquisition_00)[2].real )
plt.plot(waveform_complex(acquisition_00)[0], waveform_complex(acquisition_30)[2].real )
plt.plot(waveform_envelope(acquisition_00)[0], waveform_envelope(acquisition_30)[2].real )

# %%
from datataking import search_datadict_miyamura
from Analysis import start_stop, fourier_tr_padding, lowpass

# %%
def process_ctrl_pulse(datadict):
    time = datadict["time"]["values"].ravel()
    waveform = datadict["waveform"]["values"].ravel()
    time, waveform = start_stop(time, waveform, 0, 1500)


    phase = np.angle(demodulate(time, waveform, f_if*1e-9))
    signal = 2 * lowpass(time, 
                        waveform * np.exp(2j*np.pi*f_if*1e-9*time),
                        0.01, 0.03, 0.1, 90) * np.exp(-1j*phase)

    norm=np.sum(2*np.abs(signal)**2)**0.5
    return time, signal#/norm

# %%
from scipy.ndimage import shift as nd_shift

def roll_with_interpolation(array, shift):
    return nd_shift(array, shift=shift, mode='constant', cval=0.0)

# %%
def analyze_waveforms_t(datasets, passing_band= 0.01, wofogi=True, projection=False, rx_mode=0):
    fig, axes = plt.subplots(2, 2, figsize=(4.2, 2.2), sharex=True, sharey=True)
    axes = axes.flatten()

    fig_fft, axes_fft = plt.subplots(2, 2, figsize=(4.2, 2.2), sharex=True, sharey=True)
    axes_fft = axes_fft.flatten()

    fig_rcoeff, ax_r = plt.subplots(figsize=(3.5, 2.5))

    for i, (k, v) in enumerate(datasets.items()):
        if i >= 4:
            break

        ax = axes[i]
        target_freq = v["target_freq"]
        readout_lo_freq = 9.47

        time = waveform_complex(acquisition_00)[0]
        waveform_wo_fogi = v["waveform"].get_results()["waveform_zero_fogi"][ph_amp][fogi_freq]
        waveform_w_fogi = v["waveform"].get_results()["waveform"][ph_amp][fogi_freq]
        if wofogi:
            waveform = waveform_wo_fogi
        else:
            waveform = waveform_w_fogi

        xfft_wo_fogi, fourier_wo_fogi = fourier_tr_padding(time, waveform_wo_fogi)
        xfft_wo_fogi, fourier_wo_fogi = start_stop(xfft_wo_fogi, fourier_wo_fogi, xfft_wo_fogi[0], 0)

        phase_wo_fogi = np.angle(demodulate(time, waveform_wo_fogi, readout_lo_freq - target_freq))
        lpf_wo_fogi = 2 * lowpass(
            time, waveform_wo_fogi * np.exp(2j * np.pi * (readout_lo_freq - target_freq) * time),
            passing_band, 0.03, 0.1, 90
        ) 
        signal_wo_fogi =lpf_wo_fogi* np.exp(-1j * phase_wo_fogi)
        ax.plot(time, 2000 * waveform_wo_fogi, "tab:blue", lw=0.5, alpha=0.5)
        ax.plot(time, 2000 * signal_wo_fogi, "tab:blue", lw=2, alpha=1, label="reflected (w/o fogi) waveform")

        xfft, fourier = fourier_tr_padding(time, waveform)
        xfft, fourier = start_stop(xfft, fourier, xfft[0], 0)

        phase = np.angle(demodulate(time, waveform, readout_lo_freq - target_freq))
        lpf = 2 * lowpass(
            time, waveform * np.exp(2j * np.pi * (readout_lo_freq - target_freq) * time),
            passing_band, 0.03, 0.1, 90
        ) 
        signal =lpf* np.exp(-1j * phase)
        ax.plot(time, 2000 * waveform, "tab:orange", lw=0.5, alpha=0.5)
        ax.plot(time, 2000 * signal, "tab:orange", lw=2, alpha=1, label="rejected (w/ fogi) waveform")
        ax.grid(True)
        if projection:
            _, ctrl_pulse_tx_dd = search_datadict_miyamura(ctrl_path, result_dict_tx[f"data_ph{i}"]["date"], acquire_time=result_dict_tx[f"data_ph{i}"]["acquire_time"])
            time, xi_m = process_ctrl_pulse(ctrl_pulse_tx_dd)
            _, ctrl_pulse_rx_dd = search_datadict_miyamura(ctrl_path, result_dict_rx[f"data_ph{rx_mode}"]["date"], acquire_time=result_dict_rx[f"data_ph{rx_mode}"]["acquire_time"])
            time, xi_n = process_ctrl_pulse(ctrl_pulse_rx_dd)
            xi_n = roll_with_interpolation(xi_n[::-1], -250)
            inner = overlap(xi_m, xi_n)
            norm_sq = np.abs(overlap(xi_n, xi_n))
            ax.plot(time, 2000 * xi_m)
            ax.plot(time, 2000 * xi_n)
            xi_res = xi_m - (inner / norm_sq) * xi_n
            ax.plot(time, 2000 * xi_res, linestyle='--', color='red')

        ax_fft = axes_fft[i]
        ax_fft.set_xlim(target_freq-0.025, target_freq+0.025)
        ax_fft.plot(xfft_wo_fogi+readout_lo_freq, np.abs(fourier_wo_fogi), color="tab:blue", lw=1.5, alpha=1, label="reflected (w/o fogi) waveform")
        ax_fft.plot(xfft+readout_lo_freq, np.abs(fourier), color="tab:orange", lw=1.5, alpha=1, label="rejected (w/ fogi) waveform")

        # ax_fft.set_xlim(-0.2, 0.2)
        # ax_fft.set_title(f"FFT Spectrum {i}")
        ax.label_outer()
        ax.set_xlim(0, 1500)
        if i == 0:
            fig.legend(loc="upper center", bbox_to_anchor=(0.5, 1.1), ncol=1)
            fig_fft.legend(loc="upper center", bbox_to_anchor=(0.5, 1.1), ncol=1)
        if i in [2, 3]:
            ax.set_xlabel("Time (ns)")
            ax_fft.set_xlabel("Frequency (GHz)")

        eps = 1e-12
        rcoeff = fourier / (fourier_wo_fogi + eps)
        ax_r.plot(xfft+readout_lo_freq, np.abs(rcoeff), lw=1.5, label=f"mode {i}")
            
    fig.text(0.04, 0.5, "Amplitude (a.u.)", va="center", rotation="vertical")
    fig_fft.text(0.04, 0.5, "Amplitude (a.u.)", va="center", rotation="vertical")

    ax_r.set_xlim(target_freq-0.01, target_freq+0.01)
    ax_r.set_ylim(-0.1, 5)
    ax_r.set_xlabel("Frequency (GHz)")
    ax_r.set_ylabel("|r(ω)|")
    ax_r.set_title("Reflection Coefficient r(ω)")
    ax_r.legend()
    ax_r.grid(True)
    # fig.legend(handles=handles, loc="upper center", ncol=2)
    plt.subplots_adjust(wspace=0.05, hspace=0.05)
    plt.tight_layout(rect=[0.05, 0.05, 1, 0.95])

def squared_I(squaredI_matrix, ticks):
    plt.figure(figsize=(4, 2))
    plt.imshow(squaredI_matrix, cmap='viridis', origin='lower', vmin=0, vmax=1)
    for i in range(len(squaredI_matrix)):
        for j in range(len(squaredI_matrix)):
            plt.text(i, j, f"{np.round(squaredI_matrix[j, i], decimals=2)}", ha='center', va='center', color="red")

    plt.colorbar(label=r'Squared overlap $|I_{m, m^{\prime}}|^2$')
    plt.rcParams['xtick.major.width'] = 0.9#x軸主目盛り線の線幅
    plt.rcParams['ytick.major.width'] = 0.9#y軸主目盛り線の線幅
    plt.rcParams['font.size'] = 8 #フォントの大きさ
    plt.rcParams['axes.linewidth'] = 0.9# 軸の線幅edge linewidth。囲みの太さ
    plt.rcParams['xtick.top'] = True
    plt.rcParams['xtick.bottom'] = True
    plt.rcParams['ytick.left'] = True
    plt.rcParams['ytick.right'] = True
    plt.rcParams['lines.linewidth'] = 1
    plt.rcParams['lines.markersize'] = 2.
    plt.xlabel(r"Photon mode $m^{\prime}$")
    plt.ylabel(r"Photno mode $m$")
    plt.xticks(ticks=range(len(ticks)), labels=ticks)
    plt.yticks(ticks=range(len(ticks)), labels=ticks)
    plt.tight_layout()
    # plt.savefig('Fig2_c.pdf', bbox_inches='tight')
    plt.show()

from scipy.linalg import sqrtm
def basis_fidelity(I):
    M = I.shape[0]
    rho = I / np.trace(I)
    sigma = np.identity(M) / M
    sqrt_rho = sqrtm(rho)
    inner = sqrtm(sqrt_rho @ sigma @ sqrt_rho)
    F = (np.trace(inner))**2
    return np.real(F)

# %%
result_wo_fogi_dict = {
    "data_sech_0": dict(target_freq=9.35, waveform=acquisition_00, form="sech_0", center=510),
    "data_sech_1": dict(target_freq=9.35, waveform=acquisition_10, form="sech_1", center=480),
    "data_sech_2": dict(target_freq=9.35, waveform=acquisition_20, form="sech_2", center=480),
    "data_sech_3": dict(target_freq=9.35, waveform=acquisition_30, form="sech_3", center=460),
}
analyze_waveforms_t(result_wo_fogi_dict, wofogi=True)
plt.suptitle("w/o fogi_rx", y=1.)

M = 4
expI_matrix = np.zeros((M, M))
I_normalized = np.zeros((M, M))
for m in range(M):
    for m_prime in range(M):
        wf_m = waveform_envelope(globals()[f"acquisition_{m}0"])[2]
        wf_m_prime = waveform_envelope(globals()[f"acquisition_{m_prime}0"])[2]
        expI_matrix[m, m_prime] = overlap(wf_m, wf_m_prime)
        norm_product = np.linalg.norm(wf_m) * np.linalg.norm(wf_m_prime)
        I_normalized[m, m_prime] = expI_matrix[m, m_prime] / norm_product
        
        # plt.plot(wf_m)
        # plt.plot(wf_m_prime)
        # plt.show()

squared_I(np.abs(I_normalized)**2, range(4))
print("basis_fidelity:", basis_fidelity(expI_matrix))
plt.rcParams['xtick.direction'] = 'in'#x軸の目盛線が内向き('in')か外向き('out')か双方向か('inout')
plt.rcParams['ytick.direction'] = 'in'
# Out:
# d:\K_Sunada\.venv\lib\site-packages\matplotlib\cbook.py:1762: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# d:\K_Sunada\.venv\lib\site-packages\matplotlib\cbook.py:1398: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# basis_fidelity: 0.944970898500781

# %%
result_w_fogi0_dict = {
    "data_sech_0": dict(target_freq=9.35, waveform=acquisition_00, form="sech_0", center=510),
    "data_sech_1": dict(target_freq=9.35, waveform=acquisition_10, form="sech_1", center=480),
    "data_sech_2": dict(target_freq=9.35, waveform=acquisition_20, form="sech_2", center=480),
    "data_sech_3": dict(target_freq=9.35, waveform=acquisition_30, form="sech_3", center=460),
}
analyze_waveforms_t(result_wo_fogi_dict, wofogi=False)
plt.suptitle("w/ fogi_rx_0", y=1)

selected_indices = [1, 2, 3]
M_sel = len(selected_indices)
expI_matrix_abs0 = np.zeros((M_sel, M_sel))
I_normalized_sel = np.zeros((M_sel, M_sel))

for i, m in enumerate(selected_indices):
    for j, m_prime in enumerate(selected_indices):
        wf_m = waveform_envelope(globals()[f"acquisition_{m}0"])[1]
        wf_m_prime = waveform_envelope(globals()[f"acquisition_{m_prime}0"])[1]
        expI_matrix_abs0[i, j] = overlap(wf_m, wf_m_prime)
        norm_product = np.linalg.norm(wf_m) * np.linalg.norm(wf_m_prime)
        I_normalized_sel[i, j] = expI_matrix_abs0[i, j] / norm_product

squared_I(np.abs(I_normalized_sel)**2, ticks=selected_indices)
print("basis_fidelity:", basis_fidelity(expI_matrix_abs0))
# Out:
# d:\K_Sunada\.venv\lib\site-packages\matplotlib\cbook.py:1762: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# d:\K_Sunada\.venv\lib\site-packages\matplotlib\cbook.py:1398: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# basis_fidelity: 0.9757447539474052

# %%
result_w_fogi1_dict = {
    "data_sech_0": dict(target_freq=9.35, waveform=acquisition_01, form="sech_0", center=510),
    "data_sech_1": dict(target_freq=9.35, waveform=acquisition_11, form="sech_1", center=480),
    "data_sech_2": dict(target_freq=9.35, waveform=acquisition_21, form="sech_2", center=480),
    "data_sech_3": dict(target_freq=9.35, waveform=acquisition_31, form="sech_3", center=460),
}
analyze_waveforms_t(result_w_fogi1_dict, wofogi=False)
plt.suptitle("w/ fogi_rx_1", y=1.)

selected_indices = [0, 2, 3]
M_sel = len(selected_indices)
expI_matrix_abs1 = np.zeros((M_sel, M_sel))
I_normalized_sel = np.zeros((M_sel, M_sel))
for i, m in enumerate(selected_indices):
    for j, m_prime in enumerate(selected_indices):
        wf_m = waveform_envelope(globals()[f"acquisition_{m}1"])[1]
        wf_m_prime = waveform_envelope(globals()[f"acquisition_{m_prime}1"])[1]
        expI_matrix_abs1[i, j] = overlap(wf_m, wf_m_prime)
        norm_product = np.linalg.norm(wf_m) * np.linalg.norm(wf_m_prime)
        I_normalized_sel[i, j] = expI_matrix_abs1[i, j] / norm_product
squared_I(np.abs(I_normalized_sel)**2, ticks=selected_indices)
print("basis_fidelity:", basis_fidelity(expI_matrix_abs1))
# Out:
# d:\K_Sunada\.venv\lib\site-packages\matplotlib\cbook.py:1762: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# d:\K_Sunada\.venv\lib\site-packages\matplotlib\cbook.py:1398: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# basis_fidelity: 0.9546571703731358

# %%
result_w_fogi2_dict = {
    "data_sech_0": dict(target_freq=9.35, waveform=acquisition_02, form="sech_0", center=510),
    "data_sech_1": dict(target_freq=9.35, waveform=acquisition_12, form="sech_1", center=480),
    "data_sech_2": dict(target_freq=9.35, waveform=acquisition_22, form="sech_2", center=480),
    "data_sech_3": dict(target_freq=9.35, waveform=acquisition_32, form="sech_3", center=460),
}
analyze_waveforms_t(result_w_fogi2_dict, wofogi=False)
plt.suptitle("w/ fogi_rx_2", y=1)

selected_indices = [0, 1, 3]
M_sel = len(selected_indices)
expI_matrix_abs2 = np.zeros((M_sel, M_sel))
I_normalized_sel = np.zeros((M_sel, M_sel))

for i, m in enumerate(selected_indices):
    for j, m_prime in enumerate(selected_indices):
        wf_m = waveform_envelope(globals()[f"acquisition_{m}2"])[1]
        wf_m_prime = waveform_envelope(globals()[f"acquisition_{m_prime}2"])[1]
        expI_matrix_abs2[i, j] = overlap(wf_m, wf_m_prime)
        norm_product = np.linalg.norm(wf_m) * np.linalg.norm(wf_m_prime)
        I_normalized_sel[i, j] = expI_matrix_abs2[i, j] / norm_product

squared_I(np.abs(I_normalized_sel)**2, selected_indices)
print("basis_fidelity:", basis_fidelity(expI_matrix_abs2))
# Out:
# d:\K_Sunada\.venv\lib\site-packages\matplotlib\cbook.py:1762: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# d:\K_Sunada\.venv\lib\site-packages\matplotlib\cbook.py:1398: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# basis_fidelity: 0.9522745257071751

# %%
result_w_fogi3_dict = {
    "data_sech_0": dict(target_freq=9.35, waveform=acquisition_03, form="sech_0", center=510),
    "data_sech_1": dict(target_freq=9.35, waveform=acquisition_13, form="sech_1", center=480),
    "data_sech_2": dict(target_freq=9.35, waveform=acquisition_23, form="sech_2", center=480),
    "data_sech_3": dict(target_freq=9.35, waveform=acquisition_33, form="sech_3", center=460),
}
analyze_waveforms_t(result_w_fogi3_dict, wofogi=False)
plt.suptitle("w/ fogi_rx_3", y=1)

selected_indices = [0, 1, 2]
M_sel = len(selected_indices)
expI_matrix_abs3 = np.zeros((M_sel, M_sel))
I_normalized_sel = np.zeros((M_sel, M_sel))

for i, m in enumerate(selected_indices):
    for j, m_prime in enumerate(selected_indices):
        wf_m = waveform_envelope(globals()[f"acquisition_{m}3"])[1]
        wf_m_prime = waveform_envelope(globals()[f"acquisition_{m_prime}3"])[1]
        expI_matrix_abs3[i, j] = overlap(wf_m, wf_m_prime)
        norm_product = np.linalg.norm(wf_m) * np.linalg.norm(wf_m_prime)
        I_normalized_sel[i, j] = expI_matrix_abs3[i, j] / norm_product

squared_I(np.abs(I_normalized_sel)**2, selected_indices)
print("basis_fidelity:", basis_fidelity(expI_matrix_abs3))
# Out:
# d:\K_Sunada\.venv\lib\site-packages\matplotlib\cbook.py:1762: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# d:\K_Sunada\.venv\lib\site-packages\matplotlib\cbook.py:1398: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# basis_fidelity: 0.9616408142194066

# %% [markdown]
# scattering matrix

# %%
def compute_overlap_between_rejandori(datasets, passing_band= 0.01):
    fig, axes = plt.subplots(2, 2, figsize=(4, 2.2), sharex=True, sharey=True)
    axes = axes.flatten()
    overlaps = []

    for i, (k, v) in enumerate(datasets.items()):
        if i >= 4:
            break

        ax = axes[i]
        target_freq = v["target_freq"]
        readout_lo_freq = 9.47

        time = waveform_complex(acquisition_00)[0]
        waveform_orignal = v["waveform"].get_results()["waveform_zero_fogi"][ph_amp][fogi_freq]
        xfft, fourier = fourier_tr_padding(time, waveform_orignal)
        xfft, fourier = start_stop(xfft, fourier, xfft[0], 0)
        phase = np.angle(demodulate(time, waveform_orignal, readout_lo_freq - target_freq))
        lpf = 2 * lowpass(
            time, waveform_orignal * np.exp(2j * np.pi * (readout_lo_freq - target_freq) * time),
            passing_band, 0.03, 0.1, 90
        ) 
        signal_orignal =lpf* np.exp(-1j * phase)
        ax.plot(time, 2000 * waveform_orignal, "tab:blue", lw=0.5, alpha=0.5)
        ax.plot(time, 2000 * signal_orignal, "tab:blue", lw=2, alpha=1)

        waveform_rejected = v["waveform"].get_results()["waveform"][ph_amp][fogi_freq]
        xfft, fourier = fourier_tr_padding(time, waveform_rejected)
        xfft, fourier = start_stop(xfft, fourier, xfft[0], 0)
        phase = np.angle(demodulate(time, waveform_rejected, readout_lo_freq - target_freq))
        lpf = 2 * lowpass(
            time, waveform_rejected * np.exp(2j * np.pi * (readout_lo_freq - target_freq) * time),
            passing_band, 0.03, 0.1, 90
        ) 
        signal_rejected =lpf* np.exp(-1j * phase)
        ax.plot(time, 2000 * waveform_rejected, "tab:orange", lw=0.5, alpha=0.5)
        ax.plot(time, 2000 * signal_rejected, "tab:orange", lw=2, alpha=1)

        overlaps.append(overlap(signal_orignal, signal_rejected))

        ax.label_outer()
        ax.set_xlim(0, 1500)
        if i in [2, 3]:
            ax.set_xlabel("Time (ns)")

    # fig.text(0.5, 0.04, "Time (ns)", ha="center")
    fig.text(0.04, 0.5, "Amplitude (a.u.)", va="center", rotation="vertical")
    # fig.legend(handles=handles, loc="upper center", ncol=2)
    plt.subplots_adjust(wspace=0.05, hspace=0.05)
    plt.tight_layout(rect=[0.05, 0.05, 1, 0.95])
    print(overlaps)
    return overlaps

# %%
scattering_matrix =[
compute_overlap_between_rejandori(result_w_fogi0_dict),
compute_overlap_between_rejandori(result_w_fogi1_dict),
compute_overlap_between_rejandori(result_w_fogi2_dict),
compute_overlap_between_rejandori(result_w_fogi3_dict)]
# Out:
# d:\K_Sunada\.venv\lib\site-packages\matplotlib\cbook.py:1762: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# d:\K_Sunada\.venv\lib\site-packages\matplotlib\cbook.py:1398: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# [7.437545282738456e-07, 1.6646113839687186e-06, 9.80404201387315e-07, 1.474183180058609e-06]
# [4.528130896439004e-06, 1.1528260047133016e-06, 1.7337717023283016e-06, 2.070374891103466e-06]
# [5.08201580957553e-06, 4.500214865001078e-06, 1.4904664545656222e-06, 2.5888779414128115e-06]
# [5.374168280110514e-06, 5.366746586673875e-06, 4.437313749593678e-06, 1.5695860013668675e-06]

# %%
S = np.array(scattering_matrix)*1e5

fig, ax = plt.subplots(figsize=(3, 2.7))

im = ax.imshow(np.abs(S), cmap='viridis', interpolation='nearest', origin='lower')

cbar = plt.colorbar(im, ax=ax)
cbar.set_label("Overlap magnitude")

ax.set_xlabel("Input mode index $m$")
ax.set_ylabel("Output mode index $n$")
ax.set_title("Ovderlap between rejandori $|S_{nm}|$")

ax.set_xticks(np.arange(S.shape[1]))
ax.set_yticks(np.arange(S.shape[0]))
ax.set_xticklabels([f"{i}" for i in range(S.shape[1])])
ax.set_yticklabels([f"{i}" for i in range(S.shape[0])])

for i in range(S.shape[0]):
    for j in range(S.shape[1]):
        ax.text(j, i, f"{np.abs(S[i, j]):.2f}",
                ha="center", va="center", color="w" if np.abs(S[i, j]) < 0.5 else "black")

plt.tight_layout()
plt.show()

# %%
def compute_and_plot_overlap_matrix(datasets, passing_band=0.01, max_N=4, plot='both', title='No title'):
    keys = list(datasets.keys())[:max_N]
    N = len(keys)
    readout_lo_freq = 9.47
    time = waveform_complex(acquisition_00)[0]

    original_signals = []
    rejected_signals = []

    for k in keys:
        v = datasets[k]
        target_freq = v["target_freq"]

        waveform_o = v["waveform"].get_results()["waveform_zero_fogi"][ph_amp][fogi_freq]
        phase_o = np.angle(demodulate(time, waveform_o, readout_lo_freq - target_freq))
        lpf_o = 2 * lowpass(
            time, waveform_o * np.exp(2j * np.pi * (readout_lo_freq - target_freq) * time),
            passing_band, 0.03, 0.1, 90
        )
        signal_o = lpf_o * np.exp(-1j * phase_o)
        original_signals.append(signal_o)

        waveform_r = v["waveform"].get_results()["waveform"][ph_amp][fogi_freq]
        phase_r = np.angle(demodulate(time, waveform_r, readout_lo_freq - target_freq))
        lpf_r = 2 * lowpass(
            time, waveform_r * np.exp(2j * np.pi * (readout_lo_freq - target_freq) * time),
            passing_band, 0.03, 0.1, 90
        )
        signal_r = lpf_r * np.exp(-1j * phase_r)
        # signal_r = roll_with_interpolation(signal_r, -34)
        rejected_signals.append(signal_r)

    overlaps = np.zeros((N, N), dtype=np.complex128)
    normalized_overlaps =  np.zeros((N, N), dtype=np.complex128)
    for i in range(N):
        for j in range(N):
            overlaps[i, j] = overlap(original_signals[j], rejected_signals[i])
            norm_product = np.linalg.norm(original_signals[j]) * np.linalg.norm(rejected_signals[i])
            normalized_overlaps[i, j] = overlaps[i, j] / norm_product

    if plot in ['grid', 'both']:
        fig, axes = plt.subplots(N, N, figsize=(N*1.2, N*0.9), sharex=True, sharey=True)
        for i in range(N):
            for j in range(N):
                ax = axes[N-1-j, i] if N > 1 else axes
                signal_o = original_signals[i]
                signal_r = rejected_signals[j]
                ov = normalized_overlaps[j, i]

                ax.plot(time, 2000 * signal_o.real, "tab:blue", lw=2, alpha=1, label="Basis (incoming) waveform")
                ax.plot(time, 2000 * signal_r.real, "tab:orange", lw=2, alpha=1, label="Rejected waveform")
                # ax.text(0.05, 0.8, f"|⟨r{j}|o{i}⟩|={abs(ov):.2f}", transform=ax.transAxes, fontsize=8)

                if j == 0:
                    ax.set_xlabel(f"{i}", fontsize=9)
                if i == 0:
                    ax.set_ylabel(f"{j}", fontsize=9)

                ax.set_xlim(0, 1500)
                ax.label_outer()

        fig.text(0.01, 0.5, "Sender mode $m$", va="center", rotation="vertical", fontsize=10)
        fig.text(0.5, 0.01, "Basis mode $l$", ha="center", fontsize=10)
        fig.suptitle(title, fontsize=12)
        handles, labels = ax.get_legend_handles_labels()
        fig.legend(handles, labels, loc='upper right', fontsize=9, frameon=True, ncol=2, bbox_to_anchor=(1.0, 0.92))
        plt.tight_layout(rect=[0.05, 0.05, 1, 0.95])
        plt.show()

    if plot in ['matrix', 'both']:
        fig, ax = plt.subplots(figsize=(N*0.8, N * 0.7))
        squared_I = np.abs(normalized_overlaps)**2
        im = ax.imshow(squared_I, cmap='viridis', interpolation='nearest', origin='lower', vmin=0, vmax=1)

        cbar = plt.colorbar(im, ax=ax)
        cbar.set_label(r'Squared overlap $|I_{m, l}|^2$')

        ax.set_xlabel("Basis mode $l$")
        ax.set_ylabel("Sender mode $m$")
        # ax.set_title(title)

        ax.set_xticks(np.arange(N))
        ax.set_yticks(np.arange(N))
        ax.set_xticklabels([f"{i}" for i in range(N)])
        ax.set_yticklabels([f"{i}" for i in range(N)])

        for i in range(N):
            for j in range(N):
                ax.text(j, i, f"{squared_I[i, j]:.2f}",
                        ha="center", va="center", color="red")

        plt.tight_layout()
        plt.show()

    return normalized_overlaps

# %%
compute_and_plot_overlap_matrix(result_w_fogi0_dict, title="w/ fogi_rx_0")
compute_and_plot_overlap_matrix(result_w_fogi1_dict, title="w/ fogi_rx_1")
compute_and_plot_overlap_matrix(result_w_fogi2_dict, title="w/ fogi_rx_2")
compute_and_plot_overlap_matrix(result_w_fogi3_dict, title="w/ fogi_rx_3")
# Out:
# array([[0.71250996+0.j, 0.71897895+0.j, 0.30977218+0.j, 0.21235538+0.j],
#        [0.34657557+0.j, 0.57669452+0.j, 0.68147006+0.j, 0.38104195+0.j],
#        [0.17743259+0.j, 0.35118977+0.j, 0.61633167+0.j, 0.63282821+0.j],
#        [0.11870564+0.j, 0.05139935+0.j, 0.16697974+0.j, 0.60591128+0.j]])

# %% [markdown]
# photon loss rate

# %%
def photon_loss_rate(wave_tx, wave_rx, time):

    ene1 = np.sum(np.abs(wave_tx)**2) * (time[1] - time[0])
    ene2 = np.sum(np.abs(wave_rx)**2) * (time[1] - time[0])
    # plt.plot(np.abs(wave_tx))
    # plt.plot(np.abs(wave_rx))
    # plt.show()
    return 1-ene1/ene2

# %%
cd = "CDK184"
ctrl_path = f"D:\\K_Sunada\\result\\{cd}\\"

result_dict_tx = dict(
   data_ph0 = dict(target_freq=9.38, date="2025-08-14", acquire_time="114745", duration=2000),
   data_ph1 = dict(target_freq=9.38, date="2025-08-14", acquire_time="114825", duration=2000),
   data_ph2 = dict(target_freq=9.38, date="2025-08-14", acquire_time="114905", duration=2000),
   data_ph3 = dict(target_freq=9.38, date="2025-08-14", acquire_time="114945", duration=2000),
)
result_dict_rx = dict(
    data_ph0 = dict(target_freq=9.38, date="2025-08-14", acquire_time="122105", duration=2000),
    data_ph1 = dict(target_freq=9.38, date="2025-08-14", acquire_time="121224", duration=2000),
    data_ph2 = dict(target_freq=9.38, date="2025-08-14", acquire_time="121303", duration=2000),
    data_ph3 = dict(target_freq=9.38, date="2025-08-14", acquire_time="121343", duration=2000),
)

# %%
from datataking import search_datadict_miyamura
from Analysis import start_stop, lowpass
data_path = f"D:\\K_Sunada\\result\\{cd}"
readout_lo_freq = 9.5
duration = 2000
passing_band = 0.01
target_freq = 9.38

fig, axes = plt.subplots(2, 2, figsize=(6, 4), constrained_layout=True)
axes = axes.flat

mode_keys = list(result_dict_tx.keys())[:4]
mode_to_ax = {mode: ax for mode, ax in zip(mode_keys, axes)}

loss_rates = []     
loss_rates_by_mode = {m: [] for m in mode_keys}

line_kw_tx = dict(lw=1.4, alpha=0.9, color="tab:blue", label="TX")
line_kw_rx = dict(lw=1.4, alpha=0.9, color="tab:orange", label="RX")

for (k1, v1), (k2, v2) in zip(result_dict_tx.items(), result_dict_rx.items()):
    mode = k1
    if mode not in mode_to_ax:
        continue

    _, datadict1 = search_datadict_miyamura(data_path, v1["date"], acquire_time=v1["acquire_time"])
    time1, waveform1 = start_stop(datadict1["time"]["values"].ravel(),
                                  datadict1["waveform"]["values"].ravel(), 0, duration)

    _, datadict2 = search_datadict_miyamura(data_path, v2["date"], acquire_time=v2["acquire_time"])
    time2, waveform2 = start_stop(datadict2["time"]["values"].ravel(),
                                  datadict2["waveform"]["values"].ravel(), 0, duration)

    phase1 = np.angle(demodulate(time1, waveform1, readout_lo_freq - target_freq))
    signal1 = 2 * lowpass(
        time1, waveform1 * np.exp(2j * np.pi * (readout_lo_freq - target_freq) * time1),
        passing_band, 0.03, 0.1, 90
    ) * np.exp(-1j * phase1)

    phase2 = np.angle(demodulate(time2, waveform2, readout_lo_freq - target_freq))
    signal2 = 2 * lowpass(
        time2, waveform2 * np.exp(2j * np.pi * (readout_lo_freq - target_freq) * time2),
        passing_band, 0.03, 0.1, 90
        ) * np.exp(-1j * phase2)

    ax = mode_to_ax[mode]
    ax.plot(time1, 1000*np.abs(signal1), **line_kw_tx)
    ax.plot(time2, 1000*np.abs(signal2), **line_kw_rx)

    r = photon_loss_rate(signal1, signal2, time1)
    loss_rates.append(r)
    loss_rates_by_mode[mode].append(r)

for mode, ax in mode_to_ax.items():
    mr = np.mean(loss_rates_by_mode[mode]) if loss_rates_by_mode[mode] else float("nan")
    ax.set_title(f"{mode}   (mean loss={mr:.3f})", fontsize=11)
    ax.set_xlabel("Time (ns)")
    ax.set_ylabel("Amplitude (Arb. u.)")
    handles, labels = ax.get_legend_handles_labels()
    if handles:
        by_label = dict(zip(labels, handles))
        ax.legend(by_label.values(), by_label.keys(), fontsize=9, frameon=False, loc="best")
    ax.grid(True, ls=":", alpha=0.5)

mean_loss = np.mean(loss_rates) if loss_rates else float("nan")
# fig.suptitle(f"Summary by Mode (N={len(loss_rates)}), overall mean loss = {mean_loss:.3f}",
#              y=1.02, fontsize=12)

plt.show()

print("Overall mean loss rate:", mean_loss)
for m in mode_keys:
    if loss_rates_by_mode[m]:
        print(f"{m}: mean loss {np.mean(loss_rates_by_mode[m]):.3f}  (n={len(loss_rates_by_mode[m])})")
# Out:
# Overall mean loss rate: 0.397768120627677
# data_ph0: mean loss 0.436  (n=1)
# data_ph1: mean loss 0.424  (n=1)
# data_ph2: mean loss 0.356  (n=1)
# data_ph3: mean loss 0.374  (n=1)

# %%
cd = "CDK184"
ctrl_path = f"D:\\K_Sunada\\result\\{cd}\\"

result_dict_tx = dict(
   data_ph4 = dict(target_freq=9.38, date="2025-08-14", acquire_time="115025", duration=2000),
   data_ph5 = dict(target_freq=9.38, date="2025-08-14", acquire_time="115106", duration=2000),
   data_ph6 = dict(target_freq=9.38, date="2025-08-14", acquire_time="115146", duration=2000),
   data_ph7 = dict(target_freq=9.38, date="2025-08-14", acquire_time="115226", duration=2000),
)

result_dict_rx = dict(
    data_ph4 = dict(target_freq=9.38, date="2025-08-14", acquire_time="121423", duration=2000),
    data_ph5 = dict(target_freq=9.38, date="2025-08-14", acquire_time="121503", duration=2000),
    data_ph6 = dict(target_freq=9.38, date="2025-08-14", acquire_time="121543", duration=2000),
    data_ph7 = dict(target_freq=9.38, date="2025-08-14", acquire_time="121623", duration=2000),
)

# %%
from datataking import search_datadict_miyamura
from Analysis import start_stop, lowpass
data_path = f"D:\\K_Sunada\\result\\{cd}"
readout_lo_freq = 9.5
duration = 2000
passing_band = 0.01
target_freq = 9.38

fig, axes = plt.subplots(2, 2, figsize=(6, 4), constrained_layout=True)
axes = axes.flat

mode_keys = list(result_dict_tx.keys())[:4]
mode_to_ax = {mode: ax for mode, ax in zip(mode_keys, axes)}

loss_rates = []     
loss_rates_by_mode = {m: [] for m in mode_keys}

line_kw_tx = dict(lw=1.4, alpha=0.9, color="tab:blue", label="TX")
line_kw_rx = dict(lw=1.4, alpha=0.9, color="tab:orange", label="RX")

for (k1, v1), (k2, v2) in zip(result_dict_tx.items(), result_dict_rx.items()):
    mode = k1
    if mode not in mode_to_ax:
        continue

    _, datadict1 = search_datadict_miyamura(data_path, v1["date"], acquire_time=v1["acquire_time"])
    time1, waveform1 = start_stop(datadict1["time"]["values"].ravel(),
                                  datadict1["waveform"]["values"].ravel(), 0, duration)

    _, datadict2 = search_datadict_miyamura(data_path, v2["date"], acquire_time=v2["acquire_time"])
    time2, waveform2 = start_stop(datadict2["time"]["values"].ravel(),
                                  datadict2["waveform"]["values"].ravel(), 0, duration)

    phase1 = np.angle(demodulate(time1, waveform1, readout_lo_freq - target_freq))
    signal1 = 2 * lowpass(
        time1, waveform1 * np.exp(2j * np.pi * (readout_lo_freq - target_freq) * time1),
        passing_band, 0.03, 0.1, 90
    ) * np.exp(-1j * phase1)

    phase2 = np.angle(demodulate(time2, waveform2, readout_lo_freq - target_freq))
    signal2 = 2 * lowpass(
        time2, waveform2 * np.exp(2j * np.pi * (readout_lo_freq - target_freq) * time2),
        passing_band, 0.03, 0.1, 90
    ) * np.exp(-1j * phase2)

    ax = mode_to_ax[mode]
    ax.plot(time1, 1000*np.abs(signal1), **line_kw_tx)
    ax.plot(time2, 1000*np.abs(signal2), **line_kw_rx)

    r = photon_loss_rate(signal1, signal2, time1)
    loss_rates.append(r)
    loss_rates_by_mode[mode].append(r)

for mode, ax in mode_to_ax.items():
    mr = np.mean(loss_rates_by_mode[mode]) if loss_rates_by_mode[mode] else float("nan")
    ax.set_title(f"{mode}   (mean loss={mr:.3f})", fontsize=11)
    ax.set_xlabel("Time (ns)")
    ax.set_ylabel("Amplitude (Arb. u.)")
    handles, labels = ax.get_legend_handles_labels()
    if handles:
        by_label = dict(zip(labels, handles))
        ax.legend(by_label.values(), by_label.keys(), fontsize=9, frameon=False, loc="best")
    ax.grid(True, ls=":", alpha=0.5)

mean_loss = np.mean(loss_rates) if loss_rates else float("nan")
# fig.suptitle(f"Summary by Mode (N={len(loss_rates)}), overall mean loss = {mean_loss:.3f}",
#              y=1.02, fontsize=12)

plt.show()

print("Overall mean loss rate:", mean_loss)
for m in mode_keys:
    if loss_rates_by_mode[m]:
        print(f"{m}: mean loss {np.mean(loss_rates_by_mode[m]):.3f}  (n={len(loss_rates_by_mode[m])})")
# Out:
# Overall mean loss rate: 0.37045291053923557
# data_ph4: mean loss 0.373  (n=1)
# data_ph5: mean loss 0.328  (n=1)
# data_ph6: mean loss 0.400  (n=1)
# data_ph7: mean loss 0.381  (n=1)
